# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
_len = 0
def get_len(titles):
      global _len
            
      current_len = len(titles)
      print(f'current: {current_len}\n'
            f'diff: {current_len - _len}')

      _len = current_len

      return

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
get_len(titles)
# Out:
# current: 362955
# diff: 362955

# %%
get_samples(titles)
# Out:
# ['โชว์ปิงปอง',
#  'อำเภอสี่นโห่',
#  'ยุทธการแห่งเบียวิสตอค-มินสก์',
#  'อำเภอชัยบาดาล',
#  'Low_Earth_orbit',
#  'เหงื่อ',
#  'ยูกิโอ_เดอะมูวี่_แมตช์มรณะข้ามเวลาพลิกอนาคต',
#  'ลีโอนอรา_แอนสัน_เคาน์เตสแห่งลิชฟิลด์',
#  'ควร์ท_เกออร์ค_คีซิงเงอร์',
#  'กรุงแตก',
#  'รายชื่อตลาดหลักทรัพย์ในทวีปยุโรป',
#  'ประเทศเติร์กเมนิสถานในเอเชียนเกมส์_2014',
#  'Jake_Livermore',
#  'สเตซี_ลูอิส',
#  'กลุ่มภาษาเวียตติก',
#  'Charles_V_of_France',
#  'เอนรีโก_แฟร์มี',
#  'ดิสอิสเดอะวัน',
#  'ถ้ำเลเขากอบ',
#  'เมืองลากอส',
#  'เชียร์_ฑิฆัมพร',
#  'เทศบาลตำบลเปือยน้อย',
#  'ยุทธการที่วุร์สเตอร์',
#  'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป_พ.ศ._2566',
#  'โรคสั่นเพ้อเหตุขาดสุรา',
#  'รัฐเประก์',
#  'อาณาจักรสัตว์/ชั่วคราว',
#  'กรุสมบัติกุรกิหาร',
#  'สายโทงะเนะ',
#  'High_Mobility_Multipurpose_Wheeled_Vehicle',
#  'เย็น_แก้วมะณี',
#  'ลีกภูมิภาค_ดิวิชัน_2_กรุงเทพและปริมณฑล_ฤดูกาล_2552',
#  'Nolan_North',
#  'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูหนาว_1994',
#  'IRFN',
#  'สหสัมพันธ์อัตโนมัติ',
#  'สงครามอัฟกานิสถาน',
#  'เน็ตแฮ็ก',
#  'สาธารณรัฐประชาชนจีนในเอเชียนบีชเกมส์_2010',
#  'ตำบลนาทราย_(จังหวัดนครศรีธรรมราช)',
#  'The_Founding_of_a_Republic',
#  'Monte_Titano',
#  'ฟุตซอลทีมชาติสเปน',
#  'มิสแกรนด์สระบุรี',
#  'เจ้าขรัวเงิน',
#  'การจัดเรียงแบบลูป',
#  'บริษัท_สามเศียร_จำกัด',
#  'Shinba_Tsuchiya',
#  'พระภิกษุติช_กว๋าง_ดึ๊ก',
#  'วอลเลย์บอลยุวชนชายชิงแชมป์โลก_1995',
#  'Prochilodus_nigricans',
#  'แมกนากรีเชีย',
#  'เขาไท่',
#  'อำเภอท่าอุเทน',
#  'สาธารณรัฐหมู่เกาะมาร์แชลล์ในโอลิมปิกฤดูร้อน_2016',
#  'ไออี_8',
#  'วอลล์_-_อี_หุ่นจิ๋วหัวใจเกินร้อย',
#  'สนามกีฬากลางจังหวัดสระบุรี',
#  '๑_ตุลาคม',
#  "The_Snake_King's_Wife",
#  'ความผิดปกติใคร่เด็ก',
#  'สวนสาธารณะหาดริมน้ำน่านบ้านคุ้งตะเภา',
#  'กาเฐียวาร',
#  'วิลเลียม_วอลเลซ',
#  'Docusate',
#  'อคติในการสุ่มตัวอย่าง',
#  'Jupiter_Ascending',
#  'วัฏจักรไนโตรเจน',
#  'ฮิวแมนส์วิลล์,_รัฐมิสซูรี',
#  'พี_ดิดดี้',
#  "Nomura's_Jellyfish",
#  'มนุษย์กบ',
#  'เรอเนซองส์ใหม่',
#  'นำไฟ',
#  'Ruslan_and_Lyudmila_(opera)',
#  'โบรุสเซียดอร์ทมุนด์',
#  'พ.ศ._534',
#  'โมเอน_(บริษัท)',
#  'จรกะ',
#  'เอ็มบี',
#  'กษัตริยนิยม',
#  'แซร์ฌี_ซัมเปร์',
#  'False_coral_snake',
#  'อาณาจักรสมเด็จพระสังฆราชแห่งแบมเบิร์ก',
#  'แบบจำลองเชิงคลื่น',
#  'แฮร์รี่_พอตเตอร์กับนักโทษแห่งอัซคาบัน',
#  'วสเตรชานาเอลเบ',
#  'เฟอร์ดินันโดที่_1_เดอ_เมดิชิ_แกรนด์ดยุคแห่งทัสเคนี',
#  'แฟ้มพิเศษ',
#  'บุญธรรม_ชุมดวง',
#  'โพลี่แอนน่า',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล_2013–14',
#  'Siam_Lanna',
#  '9_พ.ค.',
#  'Baltimore',
#  'วัดคงคาเลียบ_(จังหวัดสงขลา)',
#  'Kikakui',
#  'การสนทนาแบบเห็นหน้า',
#  'เดอะเทรนเนอร์_ปั้นฝันสนั่นเวที',
#  'สกริลเลกซ์']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

get_len(titles)
# Out:
# current: 353833
# diff: -9122

# %%
get_samples(titles)
# Out:
# ['เซตว่าง',
#  'เขินนักรักซะเลย',
#  'เจ้าพระฝาง',
#  'การข่มขืนสตรีชาวซาบีน',
#  'ปลาซิวคาโลโครม่า',
#  'แฮร์มันน์_เฟเกไลน์',
#  'Sarawak',
#  'เทศกาลทะกะโอะกะมิกุรุมะยะมะ',
#  'Vilayanur_Subramanian_Ramachandran',
#  'สหรัฐในโอลิมปิกฤดูร้อน_1912',
#  'ท็อด_ทองดี',
#  'องค์หญิงไท่ผิง',
#  'หมึกมิมิก',
#  'การประท้วงในประเทศเลบานอน_พ.ศ._2562–2563',
#  'คิมลิป',
#  'จอห์น_ดี_ร็อกกีเฟลเลอร์',
#  'ไมเคิล_ไครซ์ตัน',
#  'กาฮารีงัน',
#  'โจวโข่วเตี้ยน',
#  'แชมป์_WWE_Tag_Team',
#  'วอลเลย์บอลหญิงเวิลด์คัพ_2023',
#  'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูร้อน_1996',
#  'หนังสือดาเนียล',
#  'ทีโท_ซานตานา',
#  'A300',
#  'เปอร์โตวิลเลียมส์',
#  'ผีฟ้า',
#  'แมงกะพรุนโนะมุระ',
#  'Dubai',
#  'ฟุตซอลไทยแลนด์ลีก_ฤดูกาล_2559',
#  'Frequencies',
#  'กีฬาฟุตบอลในซีเกมส์_2015',
#  'Aquifoliaceae',
#  'โจว_ไห่เม่ย',
#  'พ.ศ._1571',
#  'ไทยพรีเมียร์ลีก_ฤดูกาล_2557',
#  'ตัวแทนที่ชนะเลิศจากลีก',
#  'จิราวรรณ_จงสุทธนามณี_วัฒนศิริธร',
#  'ท่าอากาศยานฮาโกะดะเตะ',
#  'บุญรอด_เศรษฐบุตร',
#  'ภาษาซาซะก์',
#  'ประเทศสวีเดนในโอลิมปิกเยาวชนฤดูร้อน_2014',
#  'เก็นตะ_มิอูระ',
#  'บะราอีมามบารา',
#  'โกปาอาเมริกา_2011',
#  'เพร์ทรอฟสคาย_สเตเดียม',
#  'ยูลีอา_ฮาเคอ',
#  'ไอดริส_เอลบา',
#  'Dehradun',
#  '๑๘_กรกฎาคม',
#  'Gloripallium',
#  'ยุทธการเกาะมาดากัสการ์',
#  'มาร์เท็นต้นสน',
#  'Tatsuhisa_Susuki',
#  'เดวิด_เบนกูเรียน',
#  'Malapterurus_microstoma',
#  'ประเทศญี่ปุ่นในโอลิมปิกฤดูหนาว_1952',
#  'Stepwell',
#  'Wang_Wenyin',
#  'Lovelight_in_My_Heart',
#  'วิชิต_ลูกบางปลาสร้อย',
#  'ตูอีโตงา',
#  'อนารยชนผู้มีอารยธรรม',
#  'List_of_literary_cycles',
#  'ประเทศบรูไนดารุสซาลามในซีเกมส์_2015',
#  'Natshin_Medaw',
#  'ท่าอากาศยานชาลส์เดอโกล',
#  'กะหรี่ปั๊บ',
#  'สุทัศน์_วรทสฺสี',
#  'เรือหลวงแม่กลอง',
#  'โอซานา_เฟโดโรวา',
#  'เอ็ม_4_คาร์ไบน์',
#  'รายชื่อตอนมินิมาร์ท_ไม่ขาดรัก',
#  'เฮนรี่_หลิว',
#  'สรุปเหรียญเอเชียนเกมส์ฤดูหนาว_1996',
#  'โบรดัส_เคลย์',
#  'คริสต์ทศวรรษ_930',
#  'Dermochelyidae',
#  'เอสตาดีโอ_อัซเตกา',
#  'ยานรบสะเทินน้ำสะเทินบก',
#  'สตาร์วอร์สแบทเทิลฟรอนต์_2',
#  'Tom_Kenny',
#  'สมเด็จพระเจ้าบรมวงศ์เธอ_เจ้าฟ้าโสมนัส',
#  'รายชื่อตัวละครในระเบิดเถิดเทิง',
#  'กลีบด้านหน้า',
#  'ตำบลโคกสี',
#  'นพัตฏ์ธร_มัททวีวงศ์',
#  'ดอกบัวผุด',
#  'Amphibian',
#  'โคอิมบรา',
#  'Emperor_Francis_II',
#  'SSL/TLS',
#  'Neocerapachys',
#  'ยศทหารในกองทัพนิวซีแลนด์',
#  'น้ำมันคำฝอย',
#  'รายชื่อคณะนักบวชคาทอลิกในประเทศไทย',
#  'SDLC',
#  'พญาเกศเชษฐราช',
#  'กีฬาสเกตลีลาในโอลิมปิกฤดูหนาว_2022',
#  'พังก์โกส์คริสต์มาส']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

get_len(titles)
# Out:
# current: 465912
# diff: 112079

# %%
get_samples(titles)
# Out:
# ['หมากฮอส',
#  'แอนเน็ตต์โอทูเล',
#  'กฤษดาภรณ์',
#  'อัตโนมัติ',
#  'ShimanePrefecture',
#  'Tigrelanguage',
#  'ดาวเคราะห์แคระพลูโต',
#  'เกาะโหลน',
#  'วันรำลึกถึงการล้างชาติพันธุ์โดยนาซีสากล',
#  'EmpireStateofMind',
#  'AgnesChan',
#  'ประเทศศรีลังกาในเอเชียนเกมส์ฤดูหนาว2017',
#  'Edmond',
#  'วัดโตนด',
#  'KayneVincent',
#  'กองพันทหารช่างที่1รักษาพระองค์',
#  'เซเลสติโน',
#  'ปัญหา7ข้อของเคลย์',
#  'ซอดดี',
#  'KaioFelipeGonçalves',
#  'สหรัฐอาหรับเอมิเรตส์ในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'Hoysalaarchitecture',
#  'ไต้จง',
#  '19ส.ค.',
#  'ListofIWGPJuniorHeavyweightTagTeamChampions',
#  'ฮิโตชิซากิโมโต',
#  'Juuryoku',
#  'แสงโพลาไรซ์',
#  'เจ้าชายคาร์ลฟรันทซ์แห่งปรัสเซีย',
#  'โบสถ์ซิสทีน',
#  'ไว-ไฟ',
#  'ซงโกฮัง',
#  'ทีเด็ด',
#  'หม่อมเทวาธิราช',
#  'นัมมู',
#  'ทำขวัญ',
#  'ฮุนไดคลับ',
#  'วิกฤตการณ์อิสราเอล-เลบานอนพ.ศ.2549',
#  'เลี้ยงลูกด้วยนมแม่',
#  'เจิง',
#  'ธิรดา',
#  'วิจักษณบุญ',
#  'CTW',
#  'Carrow',
#  'เมษายนพ.ศ.2560',
#  'มาเรียอิซาเบลแห่งโปรตุเกสสมเด็จพระราชินีแห่งสเปน',
#  'สิริเวชพันธ์',
#  'Autodromo',
#  'สนามกีฬาเนลสันมันเดลาเบย์',
#  'ไนซ์',
#  'โมเซอร์',
#  'เดอะร็อก',
#  'ระเบิดปรมาณู',
#  'วาฬบรูด้า',
#  'Lateralsemicircularcanal',
#  'ดับเบิลยูอาร์จีบี',
#  'รายพระนามรัชทายาทฝรั่งเศส',
#  'ไขมันไม่อิ่มตัวที่มีพันธะคู่เดี่ยว',
#  'โดมีนีก',
#  'เมืองหลวงในทวีปเอเชีย',
#  'เบลารุสทีวี',
#  'Walden7',
#  'แคสันติสุข',
#  'HawaiiFive-0',
#  'แอดวานซ์',
#  'สาวน้อยจอมพลังคังนัมซุน',
#  'เอเวอรีบอดีเฮตส์คริส',
#  'อาลางงี',
#  'อิจิโนะเซะ',
#  'Rectalcancer',
#  '1109',
#  'คณะกรรมการพาราลิมปิกตุรกี',
#  'Whale',
#  'สปอนเซอร์ไทยพรีเมียร์ลีก',
#  'เอเบราร์โดโมราเลส',
#  'Six-red',
#  'เจ้าชายเลออปอลแห่งลิกเตนสไตน์',
#  'ประเทศอิสราเอลในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'นิทรรศการ',
#  'แม่น้ำยูรัล',
#  'มีลิตซียา',
#  'พอลแห่งทารันโท',
#  'เรียวมะจอมคนพลิกแผ่นดิน',
#  'ฉืออันไท้โฮ้ว',
#  'Complete',
#  'การสวรรคตและพิธีฝังพระบรมศพสมเด็จพระราชินีนาถเอลิซาเบธที่',
#  'มิดฟิลด์',
#  'อัลลันฟูเอนเตส',
#  'เทเลพาที',
#  'RileyKeough',
#  'โรมาโนโพรดิ',
#  'สปราค',
#  'อัลบานีส',
#  'Sula',
#  'กาชาดสากล',
#  'อึมวันซา',
#  'ดานาและซันเดย์',
#  'เทียนหยด',
#  'อัลวาอัลโต',
#  'TrevorHorn']

# %% [markdown]
# ### Exclude complete non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
#
# intend to remove non named entity which year included

# %%
titles = set([title for title in titles if "พ.ศ." not in title])

get_len(titles)
# Out:
# current: 459718
# diff: -6194

# %%
get_samples(titles)
# Out:
# ['Aden',
#  'JRสายเกียวโต',
#  'เอกอน',
#  'แกลดสตัน',
#  'สาวลืมแว่นแสนวุ่นละมุนรัก',
#  'วอลเลย์บอลชายทีมชาติลัตเวีย',
#  'มหาวิทยาลัยอีสเทิร์นเอเชีย',
#  'เจเน็ทแจ็คสัน',
#  'Eastman',
#  'โกสต์ไนน์',
#  'ตืย',
#  'ฮูโกกูทมัน',
#  'นอร่า',
#  'แอมโมนอยดี',
#  'คลองบางนา',
#  'โฮลดิ้ง',
#  'การศึกษาเพื่อการพัฒนาที่ยั่งยืน',
#  'แอ็บบา:เดอะมิวเซียม',
#  'โรงพยาบาลสงขลานครินทร์',
#  'อำเภอเนินสง่า',
#  'สถานีรถไฟโจโฮร์บะฮ์รูเซ็นตรัล',
#  'ภูมิภาคบอลข่าน',
#  'รายชื่อเพลงในคุณครูจอมเวทเนกิมะ!',
#  'Autopilot',
#  'คริสต์ทศวรรษ1830',
#  'กอธิคอังกฤษตอนต้น',
#  'โบสถ์น้อยตอร์นาบูโอนี',
#  'Picuscanicapillus',
#  'วอยแชคววอดาร์ตชึก',
#  'พระราชวัง',
#  'ยุงช้าง',
#  'เวสต์',
#  'ใยประสาทนำเข้าปฐมภูมิ',
#  'สไมล์เน็ตเวิร์ค',
#  'ไม่มีโทษโดยไม่มีกฎหมาย',
#  'UNHCR',
#  'ลือเดินไชด์',
#  'ขอเป็น',
#  'ดาบเอกซ์แคลิเบอร์',
#  'โลมาหลังโหนก',
#  'ปางห้ามพระแก่นจันทน์',
#  'ตัวละครที่ปรากฎใน',
#  'แผ่นดินไหวในจังหวัดมิยางิมีนาคมค.ศ.2021',
#  'โจรปล้นใจ',
#  'เกาะเซนต์มาร์ติน',
#  'พรรคชาติภูฏาน',
#  'กันเบลดNY',
#  'นักรบมนตรา:',
#  'EverywhereattheEndofTime',
#  'สรุปเหรียญพาราลิมปิกฤดูหนาว',
#  'ศักดิ์เสนาณรงค์',
#  'พิโกวินาที',
#  'ซงมย็อง-กึน',
#  'จินตดุลย์',
#  'ประเทศพม่าในซีเกมส์2013',
#  'ลิพมัน',
#  'สมเด็จพระพุทธเลิศหล้านภาลัย',
#  'โฮโมเธตี้',
#  'เฟลา',
#  'มุคตาร์ยูนอสจูเน',
#  'Nis',
#  'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'ลูกทุ่งไอดอลซีซั่นหญิงซีซั่น1',
#  'มูลควาย',
#  'พรรคสาธารณรัฐนูซันตารา',
#  'ปัวตีเยร์',
#  'ศรีสมรรัศมีฤกษ์เศรษฐ์',
#  'ประเทศฮังการีในโอลิมปิก',
#  'อาหารที่เป็นทั้งอาหารเช้าและอาหารกลางวัน',
#  'เกาะอังกฤษ',
#  'มาม',
#  'AxlRose',
#  'Woolf',
#  'ปริศนาฟ้าแลบ',
#  'วัดโคกหิรัญ',
#  'สนธิสัญญาทางไมตรี',
#  'ดาบแสง',
#  'ปักษ์',
#  'ด่านเจดีย์สามองค์',
#  'โรงเรียนสาธิตมหาวิทยาลัยราชภัฏอุตรดิตถ์',
#  'อาเลียช',
#  'Spectinomycin',
#  '首頁',
#  'กรดไขมันทรานส์',
#  'แลมเบิร์ท',
#  'Chernomorsky',
#  'รายชื่อคณะ',
#  'S-Bahn',
#  '.mz',
#  'ชูอันเอนริกบีเบสซีซีเลีย',
#  'คาบสมุทรมาเก๊า',
#  'ประเทศกัมพูชาในซีเกมส์2013',
#  'แอกซา',
#  'ออกซิเดส',
#  'พลเรือตรี',
#  'โอกูระ',
#  'ทังสเตนคาร์ไบด์',
#  'สมเด็จพระเจ้าน้องยาเธอกรมหมื่นดำรงราชานุภาพ',
#  'ร้องสู้ไฟ',
#  'แฟมิลี่เกม']

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

get_len(titles)
# Out:
# current: 340300
# diff: -119418

# %%
get_samples(titles)
# Out:
# ['สมเด็จพระเจ้าปีเตอร์ที่1แห่งเซอร์เบีย',
#  'พาราณสี',
#  'วัดเชียงราย',
#  'ศูนย์นิทรรศการและการประชุมไบเทค',
#  'หมู่เกาะอิซุ',
#  'ศักราชเมจิ',
#  'อะนัสอิบน์มาลิก',
#  'กลรักเกมมายา',
#  'ธงชาติคอโมโรส',
#  'รัฐมนตรีว่าการทบวงทหารบกสหรัฐ',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าจุมภฏพงษ์บริพัตรกรมหมื่นนครสวรรค์ศักดิพินิต',
#  'รายชื่อตัวละครในเกคิเรนเจอร์',
#  'ระฆังแห่งเสรีภาพ',
#  'โอลางฮู',
#  'ราชบัลลังก์คาสตีล',
#  'วัดสังฆทาน',
#  'สัตว์กินคนแห่งซาโว',
#  'ชาร์อัซนาเบิ้ล',
#  'วาราดกา',
#  'ตี่บอ',
#  'พญาหรั่นที่',
#  'ลักษณะประชากรกัมพูชา',
#  'เรือนเจ้าจอมเง็ก',
#  'นิวคาสเซิลอัพพอนไทน์',
#  'กานัล',
#  'อำพันทะเล',
#  'เดอะทรัมป์ออร์แกไนเซชั่น',
#  'โพลิบิอุส',
#  'จุดหมายปลายทางของสายการบินแอร์มาดากัสการ์',
#  'ดยุกแห่งเวนิส',
#  'กลุ่มข่าว',
#  'อัลบุคอรี',
#  'เซฟเสสกาฟ',
#  'ยุคสิ้นราชวงศ์ฮั่น',
#  'ยูโรยศวรรธน์',
#  'โดมินิกา',
#  'ลาภิสรา',
#  'อลิซบราวน์',
#  'โทคิโนะคาเคระ/24karats-typeEX-',
#  'ปลาปล้องอ้อย',
#  'เค็นเน็ธเอ.อีแวนส์',
#  'ยาพ่น',
#  'ค.ศ.484',
#  'มิจิโกะคิชิเซะ',
#  'วิจารณ์',
#  'กิ่งอ.ช้างกลาง',
#  'ทหารเรือ',
#  'ราชอาณาจักรเก่าแห่งอียิปต์',
#  'พายุบาหวี่',
#  'ระบบรถไฟฟ้าของรถไฟใต้ดินปักกิ่ง',
#  'แคเมอรูน',
#  'ฮิวไมต์',
#  'คิโดะทะคะโยะชิ',
#  'ทริสทานซารา',
#  'วี830',
#  'แขวงลาดยาว',
#  'อะซุนซิออง',
#  'วงศ์ปลาจีด',
#  'ตำบลโพธิ์หมากแข้ง',
#  'หลี่เหฺวย์เจีย',
#  'ค่าความต่างBOLD',
#  'เทศบาลเมืองแพร่',
#  'เส้นเมริเดียนที่61องศาตะวันออก',
#  'ลูอิสแคร์รอล',
#  'บัดร์,ประเทศซาอุดีอาระเบีย',
#  'ดาเวนพอร์ต',
#  'พลอย',
#  'วิลเฮล์มคอนราดเรินต์เกน',
#  'จุดใกล้โลกที่สุด',
#  'บัตแลนด์',
#  'เทศบาลตำบลเวียงเชียงแสน',
#  'รัฐกรเจนกิจณรงค์',
#  'การสร้างวงจรรวมขนาดใหญ่มาก',
#  'จังหวัดกีมารัส',
#  'แอนทราไซต์',
#  'เมแกนราพิโน',
#  'สมเด็จพระบรมโอรสาธิราชฯ',
#  'ดัสตีสปริงฟิลด์',
#  'เควินซีเกอร์ส',
#  'ดูบาดู',
#  'แซ็คแอนด์แคว็ก',
#  'อุทยานเฉลิมพระเกียรติพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราช',
#  'พระราชบัญญัติจัดการป้องกันรักษารัฐธรรมนูญพุทธศักราช2476',
#  'โอโอะกุ',
#  'พระธรรมวิโรจนเถร',
#  'ปลาใบพาย',
#  'คอนเฟอเรนซ์เนชันนัล',
#  'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน1960',
#  'แท-ย็อน',
#  'ปฏิบัติการแอ็บเซนชั่น',
#  'จังหวัดฮีลากังลาเนา',
#  'สลากเลขท้าย3ตัว2ตัว',
#  'ซัตสึมะอาเงะ',
#  'อาตาริจากัวร์',
#  'เจ้าหญิงคะโกะ',
#  'ฐากูร',
#  'เขตในประเทศบรูไน',
#  'อำเภอแลเว่',
#  'ษ',
#  'แมนนัส']

# %% [markdown]
# ### Seperate by non-thai character
#
# such as ".", ":", "-"
#
# also seperate by Thai number

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    # split by non-Thai characters & thai number
    titles_temp.update(re.split("[^\u0E00-\u0E4F]+", title))
    
titles = titles_temp
get_len(titles)
# Out:
# current: 304360
# diff: -35940

# %%
get_samples(titles)
# Out:
# ['อนุสาวรีย์ทหารอาสาสงครามโลกครั้งที่',
#  'วัดเกาะราษฏร์ศรัทธาราม',
#  'ลาวัวดูว์บงดีเยอ',
#  'พีพีพี',
#  'เยอรมันอเมริกานบุนด์',
#  'ศิรินทร์',
#  'แม่น้ำคีรีรัฐ',
#  'ภาพชีวิตประจำวัน',
#  'วินด์เซอร์',
#  'โมริทซ์',
#  'มุคาจี',
#  'กฤษณ์ศุกระมงคล',
#  'มวยทะเล',
#  'ผู้ใหญ่สันต์',
#  'เพื่อลูกจ๋าปะป๋าขอลุย',
#  'ฮัลก์โฮแกน',
#  'เฟร์นันดูเปไรรา',
#  'จิระพจชพร',
#  'ไขมันไม่อิ่มตัวแบบมีพันธะคู่เดี่ยว',
#  'อักษรเบงกอลี',
#  'อักษรอาระเบียใต้โบราณ',
#  'อำเภออุ้มผาง',
#  'คู่แฝดเซียวฮือยี้พิชิตมาร',
#  'แซนทาโมนิกา',
#  'ท่าอากาศยานนานาชาติแม่ฟ้าหลวงเชียงราย',
#  'คาเคา',
#  'ชลันธร',
#  'สีสุวัตถิ์วิชยวงศ์',
#  'การโฆษณาชวนเชื่อ',
#  'ชนชาวแองโกล',
#  'วัดกลางเหนือ',
#  'มักซ์วอนเลาอี',
#  'คลองเดินเรือสมุทร',
#  'เมย์ฟิลด์',
#  'สงครามออสซีเชียใต้',
#  'สวีทนุช',
#  'ช็อร์ต',
#  'เบ็คเค็ท',
#  'ยูนิโคด',
#  'ฮิลแบร์ท',
#  'เจ้าหญิงฌอเซฟีนการอลีนแห่งเบลเยียม',
#  'นกเขียวก้านตองปีกสีฟ้าพายัพ',
#  'วิดีโอเกมบอต',
#  'อัสนีโชติกุล',
#  'เค็นตาโรอิโต',
#  'เชี่ยววงศ์กุล',
#  'วันนี้วันสุดท้าย',
#  'กิตติศักดิ์หัตถสงเคราะห์',
#  'พระแม่มารีและพระบุตร',
#  'ประเทศอิสราเอลในเอเชียนเกมส์',
#  'ฟอร์เรสท์กัมพ์อัจฉริยะปัญญานิ่ม',
#  'ไร้จันทร์',
#  'อ่านแล้วคลั่ง',
#  'ดีดีอาร์เอสดีแรม',
#  'อาเกจิมิตสึฮิเดะ',
#  'ศวร',
#  'การเดินขบวนวันจันทร์ในเยอรมนีตะวันออก',
#  'นรีกุล',
#  'ธเนศฉิมท้วม',
#  'ไอดอลสคูล',
#  'การระบาดของไวรัสซิกาในทวีปอเมริกา',
#  'นครซินจู๋',
#  'ซุนโห',
#  'บัดดี',
#  'การรวมชาติอิตาลี',
#  'เอดวินด์',
#  'เทศบาลตำบลโคกสำโรง',
#  'ธีซีอัส',
#  'ผีทวงบ้าน',
#  'สถานีโทรทัศน์เมียวดี',
#  'ชฎิลเทพวัลย์',
#  'นายอภิสิทธิ์เวชชาชีวะ',
#  'จารุ',
#  'โฮโมไซกัส',
#  'การสร้างเซลล์สืบพันธุ์เพศเมียในสัตว์',
#  'ระเบิดปรมาณู',
#  'ปฏิทินสาธารณรัฐฝรั่งเศส',
#  'ตราสัญลักษณ์อาเซียน',
#  'อุปกรณ์จับปลา',
#  'ออลไบรตัน',
#  'ฮวนเดอฮาเรร่า',
#  'วงศ์เป็ดแดง',
#  'วัดพัฒนาราม',
#  'ดิอะเมซิ่งสไปเดอร์',
#  'สัญลักษณ์แฝงคติ',
#  'ไบต์',
#  'โสณกุล',
#  'นักบุญเบ็นนาดิคแห่งเนอร์เซีย',
#  'เจ้าชายเซบัสตีย็องแห่งลักเซมเบิร์ก',
#  'จูด',
#  'ฮีพ',
#  'เจ้าพระยาสุรสีห์',
#  'เลขอารบิก',
#  'ตาย',
#  'จังหวัดมิเอะ',
#  'กูรบันโซลตัน',
#  'โอกกากวงศ์',
#  'มหาวิทยาลัยปทุมธานี',
#  'รถไฟชานเมืองของการรถไฟแห่งชาติฟิลิปปินส์',
#  'สมเด็จพระจักรพรรดิโชมุ']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4619

# %%
get_samples(raay)
# Out:
# ['รายพระนามพระมหากษัตริย์อารากอน',
#  'รายชื่อมาสค์ไรเดอร์ที่ปรากฏตัวในมาสค์ไรเดอร์ริวคิ',
#  'รายชื่อตอนในเฟท',
#  'รายชื่อโบราณสถานในจังหวัดขอนแก่นที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายพระนามและรายนามผู้จุดกระถางคบเพลิงโอลิมปิก',
#  'รายชื่อสถานีรถไฟสายมรณะ',
#  'รายชื่อตอนในแอร์',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐประชาชนจีน',
#  'รายชื่อศิลปินแนวสกา',
#  'รายชื่อรัฐอธิปไตยเรียงตามสินทรัพย์ภายนอก',
#  'รายชื่อโรงเรียนในจังหวัดร้อยเอ็ด',
#  'รายพระนามคู่อภิเษกสมรสในจักรพรรดิเอธิโอเปีย',
#  'รายนามเสนาบดีและรัฐมนตรีว่าการกระทรวงการต่างประเทศของไทย',
#  'รายชื่อผลงานของแดง',
#  'รายชื่อเขตเทศบาลในประเทศไทยเรียงตามจำนวนประชากร',
#  'รายชื่อแชแนลที่มียอดติดตามสูงสุดในยูทูบ',
#  'รายชื่ออัลบั้มเพลงที่ขับร้องโดยพุ่มพวง',
#  'รายพระนามจักรพรรดิแห่งจักรวรรดิโมกุล',
#  'รายชื่อแหล่งมรดกโลกในประเทศมอลตา',
#  'รายชื่อวัดในจังหวัดนครสวรรค์',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐฝรั่งเศส',
#  'รายชื่อประธานาธิบดีสาธารณรัฐประชาชนจีน',
#  'รายชื่อประเทศที่ร่วมแข่งขันกีฬาโอลิมปิกฤดูร้อน',
#  'รายชื่อเอกลักษณ์ตรีโกณมิติ',
#  'รายนามองคมนตรีในรัชกาลสมเด็จพระเจ้าอยู่หัวมหาวชิราลงกรณ์บดินทรเทพยวรางกูร',
#  'รายชื่อจังหวัดของประเทศอาร์มีเนียเรียงตามดัชนีการพัฒนามนุษย์',
#  'รายชื่อแหล่งมรดกโลกในประเทศวานูอาตู',
#  'รายพระนามโดแฟ็งแห่งฝรั่งเศส',
#  'รายชื่อเพลงในคุณครูจอมเวทเนกิมะ',
#  'รายชื่อทางแยกในเขตยานนาวา',
#  'รายชื่อผลงานของมอร์นิงมุซุเมะ',
#  'รายชื่อตอนในซีเอสไอ',
#  'รายชื่อตอนในนารูโตะ',
#  'รายชื่ออุปกรณ์ที่ใช้ระบบปฏิบัติการแอนดรอยด์',
#  'รายนามนายกรัฐมนตรีสิงคโปร์',
#  'รายพระนามกษัตริย์แห่งกรีซ',
#  'รายนามรัฐมนตรีว่าการกระทรวงการพัฒนาสังคมและความมั่นคงของมนุษย์',
#  'รายชื่อรางวัลและการเสนอชื่อที่เอสปาได้รับ',
#  'รายนามองคมนตรีในรัชกาลสมเด็จพระเจ้าอยู่หัวมหาวชิราลงกรณบดินทรเทพยวรางกูร',
#  'รายชื่อตอนในเปลวฟ้าผ่าปฐพี',
#  'รายพระนามพระโพธิสัตว์',
#  'รายพระนามและรายนามผู้ได้รับปริญญาดุษฎีบัณฑิตกิตติมศักดิ์จากมหาวิทยาลัยขอนแก่น',
#  'รายชื่อสถานที่ท่องเที่ยวในประเทศไทย',
#  'รายนามบุคคลจากมหาวิทยาลัยสุโขทัยธรรมาธิราช',
#  'รายนามบุคคลจากมหาวิทยาลัยกรุงเทพ',
#  'รายชื่อตอนในเซียนเกมรัก',
#  'รายชื่อตอนในการ์ดไฟท์',
#  'รายชื่อแหล่งมรดกโลกในสาธารณรัฐประชาธิปไตยคองโก',
#  'รายชื่อระบบรถไฟรางเดี่ยว',
#  'รายชื่อของธาตุตามมวลอะตอม',
#  'รายชื่อธาตุเคมีเรียงตามสัญลักษณ์ธาตุ',
#  'รายชื่อนายกรัฐมนตรีบรูไน',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์กรีซ',
#  'รายชื่อผลงานของเอเคบี',
#  'รายนามผู้ว่าราชการรัฐมะละกา',
#  'รายชื่อแหล่งมรดกโลกที่กำลังตกอยู่ในภาวะอันตราย',
#  'รายชื่อโบราณสถานในจังหวัดสุรินทร์ที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อรางวัลและการเสนอชื่อที่ไอฟ์ได้รับ',
#  'รายชื่อเครื่องอิสริยาภรณ์บัลแกเรีย',
#  'รายชื่อตัวละครในลัคกี้',
#  'รายชื่อแม่น้ำในประเทศกัมพูชา',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งอิรัก',
#  'รายชื่อของ',
#  'รายการประเทศเรียงตามผลิตภัณฑ์มวลรวมในประเทศ',
#  'รายชื่อบริษัทอนิเมะ',
#  'รายพระนามพระมหากษัตริย์ฟินแลนด์',
#  'รายชื่อตลาดหลักทรัพย์ในทวีปแอฟริกา',
#  'รายชื่อรางวัลและการเสนอชื่อที่อภิวัชร์',
#  'รายชื่อโรงเรียนในจังหวัดสกลนคร',
#  'รายพระนามพระมหากษัตริย์',
#  'รายชื่อวิดีโอออนไลน์ที่มียอดผู้ชมมากที่สุดใน',
#  'รายชื่อผลงานการแสดงของมิตร',
#  'รายการเส้นทางเดินรถโดยสารประจำทางในจังหวัดนนทบุรี',
#  'รายชื่อตัวละครในเซนต์เซย่า',
#  'รายการโยงวน',
#  'รายชื่อแมงมุมต่างๆ',
#  'รายชื่อนายกรัฐมนตรีตุรกี',
#  'รายชื่อทางแยกในเขตจอมทอง',
#  'รายชื่อตอนในมหาเนตรผู้พิทักษ์',
#  'รายชื่อเกมในโรบล็อกซ์',
#  'รายนามบุคคลที่อยู่ในสเปกตรัมเอเซ็กชวล',
#  'รายนามผู้ครองตำแหน่งมิสยูเอสเอ',
#  'รายชื่อนครในประเทศโมนาโก',
#  'รายชื่อประธานเอเอฟซี',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายชื่อผลงานซิงเกิลของอิล',
#  'รายชื่อทางแยกในเขตสัมพันธวงศ์',
#  'รายชื่อรองประมุขแห่งรัฐที่เป็นสตรีจากการเลือกตั้งหรือแต่งตั้ง',
#  'รายชื่อนักแสดงประกอบหญิงยอดเยี่ยมรางวัลตุ๊กตาทอง',
#  'รายชื่อคณะแพทยศาสตร์ในประเทศไทย',
#  'รายชื่อสภานิติบัญญัติแห่งชาติตามจำนวนสมาชิก',
#  'รายชื่อตำแหน่งเอิร์ลของหมู่เกาะอังกฤษ',
#  'รายงานเฮิรส์ช',
#  'รายพระนามพระมหากษัตริย์น่าน',
#  'รายพระนามเจ้าชายแห่งลิกเตนสไตน์',
#  'รายพระนามและชื่อผู้ได้รับพระราชทานเหรียญดุษฎีมาลา',
#  'รายชื่อศูนย์การค้าและห้างสรรพสินค้าของกลุ่มเซ็นทรัล',
#  'รายชื่อโบราณสถานในจังหวัดสมุทรปราการ',
#  'รายชื่อตอนในโทราโดร่า',
#  'รายชื่อตอนนารูโตะนินจาจอมคาถา']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 55

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายงานเฮิรส์ช',
#  'รายาฮีเยา',
#  'รายได้พื้นฐาน',
#  'รายนานนท์',
#  'รายคอวิช',
#  'รายงานความสุขโลก',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานเค้ส',
#  'รายวนปูเลาเกอลาปา',
#  'รายา',
#  'รายงานผู้ป่วย',
#  'รายวน',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายาแห่งรัฐปะลิส',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายาแห่งซาราวัก',
#  'รายาประไหมสุหรีอากง',
#  'รายาผิวขาว',
#  'รายาแห่งซาราวะก์',
#  'รายานนท์',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายงานคนไข้',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายงานกรณี',
#  'รายได้',
#  'รายตา',
#  'รายวนปูเลาเกอราปา',
#  'รายงานประจำปี',
#  'รายหัว',
#  'รายงานเรื่องอาหาร',
#  'รายงานเคส',
#  'รายงานการประชุม',
#  'รายงานเฮิร์ช',
#  'รายกอวิช',
#  'รายงานค่าใช้จ่าย',
#  'รายยวา',
#  'รายาห์',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายาฮีเจา',
#  'รายงานทีหลัง',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายาอูงู',
#  'รายงานอาหาร',
#  'รายได้มูลฐาน',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายากับมังกรตัวสุดท้าย',
#  'ราย',
#  'รายากูนิง']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
get_len(titles)
# Out:
# current: 299796
# diff: -4564

# %%
get_samples(titles)
# Out:
# ['โพรมิธีอุส',
#  'วีรา',
#  'ควินซี',
#  'วัดเกดประยงค์เล็กตั้งตรงจิตร',
#  'อักษรไอริชอันเชียล',
#  'กูนดีเอิลเลิร์ต',
#  'รางวัลสตาร์พิกส์ไทยฟิล์มอะวอดส์สาขานักแสดงสมทบชายยอดเยี่ยม',
#  'อาเลฮันโดร',
#  'เพลงเจ็ท',
#  'อุดมอริยอุดมโรจน์',
#  'ฟาโรห์ราโฮเทป',
#  'มุขมนตรีแห่งแคว้นนครหลวงบรัสเซลส์',
#  'งาทวีสุข',
#  'เซียนผวน',
#  'ปฏิกิริยากันนิซซาโร',
#  'การเสียดินแดนของไทยในสมัยรัตนโกสินทร์',
#  'ซาฮาราตะวันตก',
#  'แค้ขี้หมู',
#  'เดอะแรมไบแคท',
#  'ต้นไม้แบบทอดข้าม',
#  'หัวเมืองเหนือ',
#  'ฮิการิ',
#  'นาตาโน่',
#  'ปลาฉลามเสือ',
#  'เพลงธงชาติสาธารณรัฐจีน',
#  'ซูเปอร์ภูเขาไฟ',
#  'หญิงสาวดี',
#  'โจฮ์กี',
#  'สถาบันศิลปะแห่งชิคาโก',
#  'ชาววิกิพีเดีย',
#  'ธงชาติหมู่เกาะพิตแคร์น',
#  'ไก่ทอด',
#  'ทราเวียน',
#  'ประเทศบัลแกเรียในโอลิมปิกเยาวชนฤดูร้อน',
#  'โรโบคาบูทัก',
#  'ทองเจริญ',
#  'ไนน์เอนเตอร์เทนอวอร์ดส์',
#  'มาเรียเทเรซาแห่งสเปน',
#  'เดอะแฮปเพนนิ่งวิบัติการณ์สยองโลก',
#  'บลูส',
#  'จักรพรรดิจิ้นหวู่ตี้',
#  'พ่อขุนเมือง',
#  'พระเจ้านดวงมยา',
#  'ฮอบบิต',
#  'ผักกาดหัวสีขาว',
#  'พระเจ้าคุนลอ',
#  'วิตามินบีหนึ่ง',
#  'พระเจ้าอานจงแห่งโครยอ',
#  'ซาโมราโน่',
#  'แห่งเม็กซิโก',
#  'เกาะแอ็นสท์',
#  'สหพันธ์กีฬาเมืองเรยคยาวิค',
#  'ฮอตเพอร์ซูท',
#  'บ็อบบีร็อบสัน',
#  'ถนนสมเด็จเจ้าพระยา',
#  'คณะผู้แทนทางการทูตของประเทศคาซัคสถาน',
#  'ลัทธิขงจื่อใหม่',
#  'กิจบูรณะ',
#  'ไอศวรรยาราย',
#  'นิโตริ',
#  'ซอฟต์แบงก์',
#  'บรอนสัน',
#  'ปักเป้าเหลี่ยม',
#  'สิ่งมีชีวิตแบบจำลอง',
#  'แม็ตต์โกรนิง',
#  'มิสเตอร์ที',
#  'จาตุรงค์พลบูรณ์',
#  'วิจิตรา',
#  'ณเณร',
#  'ผู่หนิง',
#  'ภูเขาอู่อี๋',
#  'คอร์บุต',
#  'ฐิตะวชิระ',
#  'การวิจัยปฐมภูมิ',
#  'นอร์ทอเมริกันเอฟ',
#  'การเจริญพันธุ์',
#  'คาร์ลกุสตาฟเอมิลมันเนอร์เฮม',
#  'ยอตตะไบต์',
#  'ฮาชิกามิ',
#  'ซิกซาวเออร์พี',
#  'อันเนอฟรังค์',
#  'คูมาร์ฆ',
#  'สุนทรจันทร์รังสี',
#  'กอนสตันตือนุฟวุตสกี',
#  'อมานิอัสตาบาร์กา',
#  'อัสกูลา',
#  'หม่อมเจ้าปรีดิเทพพงษ์',
#  'ลูกเสือสดุดีชั้นพิเศษ',
#  'จาคอปจอร์แดงส์',
#  'คริสฮันเตอร์',
#  'ทางพิเศษบางพลี',
#  'การปฏิบัติการจิตวิทยา',
#  'อนุศาสนาจารย์',
#  'ยูมย็อง',
#  'เวอาห์แสงเงิน',
#  'อัตล็องติก',
#  'รัฐซัลตา',
#  'พีวีซี',
#  'ชมพูบดีสูตร',
#  'พลเอกสนธิ']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal ranks and titles
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# No need processing -> name redirection of wikipedia already covered this problem.

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [title for title in titles if "ใน" in titles]
len(nai)
# Out:
# 299796

# %%
[nai][:50]
# Out:
# [['การแข่งขันระหว่าง',
#   'ซึงรี',
#   'พรรคเดโมแครต',
#   'สมเด็จพระราชินีแห่งฮังการี',
#   '',
#   'พันธ์วิศวาส',
#   'กีฬามหาวิทยาลัยอาเซียน',
#   'ฟิวส์ชั่น',
#   'ยุคอียิปต์โบราณ',
#   'นักรบสายป่วน',
#   'ค่ายกลทหารศิลาแปดประตู',
#   'ลุบเก',
#   'กลุ่มควบคุม',
#   'วานิลลาไอซ์',
#   'หลวงปู่ผาง',
#   'เขตพาคมตี',
#   'มัสยิดตงกวน',
#   'สลกบาตร',
#   'เวิร์ล',
#   'ทรานส์ฟอร์มเมอร์สกาแล็กซี่ฟอร์ซ',
#   'รอสทอค',
#   'สงวนศิริสว่าง',
#   'กัวเตมาลา',
#   'พาเรนทีโซม',
#   'เขตโทะโยะฮิระ',
#   'โตราจา',
#   'สมเด็จฮุน',
#   'คณะกรรมการโอลิมปิกดัตช์',
#   'สิรินธรวัลลี',
#   'มานวยล์เปเยกรีนี',
#   'สโมลยัน',
#   'ผู้บังคับการฮาคุบะ',
#   'ทาสก์บาร์',
#   'เทโอดอร์ม็อมเซิน',
#   'วิปลาส',
#   'หม่อมเจ้าวัฒนานุวัฒน์วัฒนวงศ์',
#   'ภาควิชาประวัติศาสตร์คณะสังคมศาสตร์มหาวิทยาลัยเกษตรศาสตร์',
#   'แบริ่ง',
#   'ลิกเทนสไตน์',
#   'คเยแบ็ก',
#   'มิสแกรนด์สิงห์บุรี',
#   'เซียร์เกย์ไอเซนสไตน์',
#   'มาริษาอมาตยกุล',
#   'สถานีโทรทัศน์แห่งประเทศลาว',
#   'ไม่มีคำตอบจาก',
#   'ไคลน์รอก',
#   'วัดสีตลาราม',
#   'ปาเอยา',
#   'มิกกีย์',
#   'ซากุราดะรีเซ็ต',
#   'ราชอาณาจักรดาลเมเชีย',
#   'บุคคลฝรั่งเศส',
#   'โบฟอร์ท',
#   'จังหวัดยอน',
#   'วอลเลย์บอลชายทีมชาติชิลี',
#   'ยางุจิ',
#   'จงเจต',
#   'เทนเนสซีน',
#   'แดเรนเฮย์ส',
#   'ธงในกองทัพรัสเซีย',
#   'สวนสัตว์',
#   'ไวส์เคานท์เนลสันที่',
#   'คาร์นิวอร์รา',
#   'จักรพรรดิฮุ่ย',
#   'ลั่วปา',
#   'ตีนครุ',
#   'ลมดาวฤกษ์',
#   'แซงค์ทัวรี่',
#   'ใจเดอะโรแมนติกมิวสิคัล',
#   'บีซีจี',
#   'ทฤฒมนรวัลกรภคณัช',
#   'ปริ้นเซส',
#   'เฮดจ์ฮอกยุโรป',
#   'วัดแก้วแจ่มฟ้า',
#   'สู่ขวัญบูลกุล',
#   'ไลฟ์สด',
#   'หม่อมราชวงศ์จักรรถ',
#   'ประเสริฐศรีจันทน์อาภรณ์',
#   'พอลมาร์ติน',
#   'เจ็ตเซ็ตเรดิโอฟิวเจอร์',
#   'กาเดนท์',
#   'เซนนัง',
#   'พระมหากษัตริย์ซาอุดิอาระเบีย',
#   'นครินทร์กิ่งศักดิ์',
#   'เอสเอไอซี',
#   'จัสมิน',
#   'เนเฟอร์ติติ',
#   'มวยไทยชิงถ้วยพระราชทานคิงส์คัพ',
#   'โลแกนเดอะวูล์ฟเวอรีน',
#   'โทรทัศน์ประเทศจีนใน',
#   'สเปกตรัมมองเห็นได้',
#   'อะโทรพาทีน',
#   'โรนัลด์เรแกน',
#   'ปลาบู่จาก',
#   'เจ้าหญิงบังจามกุฎราชกุมารแห่งเกาหลี',
#   'วัดพุน้อย',
#   'การ์เดนวอร์แฟร์',
#   'อนิเมะไซโมเอะทัวร์นาเมนต์',
#   'มีแชลฟูโก',
#   'พระอุปยุวราช',
#   'องค์การปกครอง',
#   'การโจมตีที่เพิร์ลฮาร์เบอร์',
#   'จังหวัดประจวบคีรีขันธ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'เอ็กโทเดิร์ม',
#   'ชุดสำรองและชุดเยาวชน',
#   'ดุลยวิจิตร',
#   'เท็นรีวจิ',
#   'ระบบกะฟาละ',
#   'คานาอัน',
#   'เซบาสเตียน',
#   'พันธ์เลิศ',
#   'ตูมตามยุทธนา',
#   'ปลาหมาจู',
#   'โบกอลยุบสกี้',
#   'ชาญสมอน',
#   'พื้นที่ไร้มนุษย์อาศัย',
#   'ไทระโนะชิเงะโกะ',
#   'มิกิอิโต',
#   'กามสูตร',
#   'ประสิทธิ์ตั้งศรีเกียรติกุล',
#   'ละครบรอดเวย์',
#   'วิฌี',
#   'อีรีบากิซา',
#   'โยฮันยาค็อพบัลเมอร์',
#   'การอกหัก',
#   'เครือข่ายสังคมออนไลน์',
#   'ภาษาคำตี้',
#   'ฮาร์ลาน',
#   'วัลดีมาร์',
#   'กูวารา',
#   'สุวรรณนิวาสะวัต',
#   'พิพิธภัณฑ์พระประยูรภัณฑาคาร',
#   'เอสตาดีกอร์เนยาเอลปรัต',
#   'สตรอมปิงกราวน์ส',
#   'ธาตุหายาก',
#   'โรงเรียนบ้านโคกยาง',
#   'ฮิพฮอพ',
#   'คณะวิทยาการจัดการมหาวิทยาลัยนราธิวาสราชนครินทร์',
#   'สิริมตะ',
#   'การแจกแจงแบบอเนกนาม',
#   'หลิวอวี่ฉี',
#   'มุบาร็อก',
#   'แห่งเม็กซิโก',
#   'กองทัพอากาศโซเวียต',
#   'หลวงปู่เปลี่ยนอินฺทสโร',
#   'รีโบดี',
#   'กรุงคาบูล',
#   'เอริชฮาร์ทมัน',
#   'สรรณ์ไตรภพ',
#   'เซร์เมญโญ',
#   'อัญชัญ',
#   'อดุลกิติ์',
#   'เอลวิสเพรสลีย์',
#   'แมนูเชฮร์เอฆบอล',
#   'แขวงทงชัค',
#   'เนื้องอกไม่ร้ายของกล้ามเนื้อมดลูก',
#   'สกุลโบตั๋น',
#   'เหตุหัวรถจักรชนสถานีกรุงเทพ',
#   'มกุฎราชกุมารแห่งเดนมาร์ก',
#   'โยเซ็ฟออฟเฟินบัค',
#   'ประเทศอินเดียในเอเชียนบีชเกมส์',
#   'จังหวัดซิตตเว',
#   'ทีมวอลเลย์บอลชาย',
#   'ภาษาโนไก',
#   'วัลปาไรโซ',
#   'เปาโลคันนาวาโร',
#   'ช่างคุน',
#   'คิงเกล',
#   'ฟรังเคีย',
#   'สำนักงานคณะกรรมการป้องกันและปราบปรามยาเสพติด',
#   'ดาวล้อมเดือน',
#   'การปฏิวัติอียิปต์',
#   'ริโอเดอจาเนโร',
#   'จอห์นวู',
#   'ตรอกวัดแขก',
#   'ยุดลิค',
#   'โอเดดเฟหร์',
#   'ประเทศตุรกีในโอลิมปิกซ้อน',
#   'เฮ็ลท์',
#   'บาบิดี้',
#   'พหุสัณฐาน',
#   'การประท้วงต่อต้านสงคราม',
#   'เครื่องอิสริยาภรณ์ลิทัวเนีย',
#   'ศรีมหามริอัมมันโกวิล',
#   'วินโดว์ไลฟ์ฮอตเมล',
#   'เมืองไทยพี',
#   'รักมั้ยนะเลขาคิม',
#   'ความถี่วิทยุ',
#   'แฟร์น็อง',
#   'สโมสรฟุตบอลโคเวนทรีซิตี',
#   'อัลบั้มเพลงของเบิร์ดธงไชย',
#   'ชแชชิน',
#   'กามีย์เดมูแล็ง',
#   'สถานีรถไฟหินลับ',
#   'เขมวีโร',
#   'เจ้าชายตูโปอูโตอาอูลูกาลาลา',
#   'สารในกระบวนการสร้างและสลาย',
#   'การผนวกแคว้นดอแนตสก์',
#   'บวนมาถวต',
#   'แม่น้ำแอพะแลชิโคลา',
#   'ซาราห์เจสสิคาปาร์เกอร์',
#   'สวาดิลฟารี',
#   'ลีนานนท์',
#   'อำเภอเขมราฐ',
#   'คิไมรา',
#   'นักองจัน',
#   'สโมสรวอลเลย์บอลโลโคโมติฟโนโวซีบิสค์',
#   'ชาวเน็ต',
#   'สถานีวิทยุโทรทัศน์แห่งชาติอิตาลี',
#   'รีเด็มชั่นไอส์แลนด์ส',
#   'ที่หยุดรถไฟตลาดน้ำสี่ภาค',
#   'รอดพินิจ',
#   'ปลาจิ้มฟันจระเข้ยักษ์',
#   'สถานีรถไฟเซนต์แพนครัส',
#   'นิโกลัสลอมบาร์ทส์',
#   'ตันตระรัตน์',
#   'พันเอกณรงค์กิตติขจร',
#   'กุสุมา',
#   'ประตูทุกหนแห่ง',
#   'จื๋อญอ',
#   'เดวิดวอห์น',
#   'ตูวา',
#   'พระองค์เจ้านโรดมมาลิกายุคนธร',
#   'ความคมชัด',
#   'สวนอูเอโนะ',
#   'โซเดียมไฮดรอกไซด์',
#   'วัดเจ้าย่า',
#   'โซรยาอัสฟานดิยารี',
#   'เหตุการณ์สังหารหมู่ราชวงศ์เนปาล',
#   'จอห์น',
#   'โยชิฮิโระสึมูรายะ',
#   'ฟิลิปปิโน',
#   'พระราชพิธีบรมราชาภิเษกของพระมหากษัตริย์ไทย',
#   'วอล์กแมน',
#   'แครชแบนดิคูท',
#   'มีเทน',
#   'คณะวิทยาการเกษตรมหาวิทยาลัยเกษตรศาสตร์',
#   'โอราซิโอการ์เตส',
#   'มาเลเซียตะวันตก',
#   'ทัช',
#   'แคตตาล็อกดาวฤกษ์ของสมาคมดาราศาสตร์',
#   'องค์การความร่วมมืออิสลาม',
#   'พูลภัทรอัตถปัญญาพล',
#   'อามามิ',
#   'พระเจ้าอินจงแห่งโชซอน',
#   'ฌองมิเชลจาร์',
#   'ถั่นมินอู',
#   'โรงงานช็อกโกแลต',
#   'โดริโก้',
#   'ดวงจันทร์ของดาวเสาร์',
#   'ไมเคิลคาร์บาฮาล',
#   'มหาวิทยาลัยทูรีบ้า',
#   'อีเซทิไมบ์',
#   'โรมันไวเดนเฟลเลอร์',
#   'อนันตพรกาญจนรัตน์',
#   'สตาร์มูฟวี่ส์',
#   'แรงงานบังคับภายใต้การปกครองเยอรมันในช่วงสงครามโลกครั้งที่สอง',
#   'มารีเลอชองดร์',
#   'นครแม่สอด',
#   'แอบูแจลอเลโจนูบี',
#   'ว่านสี่ทิศรางทอง',
#   'เบอร์ทรานด์รัสเซิลล์',
#   'แอร์กูลปัวโร',
#   'กีฬารักบี้ในเอเชียนเกมส์',
#   'การถอดเป็นอักษรโรมันแบบเฮปเบิร์น',
#   'ดีดีอาร์',
#   'มิอูระ',
#   'เง็กเซียนฮ่องเต้',
#   'วิลเฮล์มไคเทิล',
#   'ต่ายวารโณ',
#   'ความระมัดระวัง',
#   'ไขแสง',
#   'พระเจ้าเก้าตื้อ',
#   'หนองหิน',
#   'ไดกิ้น',
#   'ปลาสากใหญ่',
#   'วัดใหญ่สุวรรณาราม',
#   'เวเกเนอร์',
#   'ทุ่งใหญ่',
#   'ลูกาแฟนเซลี',
#   'สารานุกรมย่งเล่อ',
#   'เห็ดโคน',
#   'สถานีบางนา',
#   'ไกรอช',
#   'คลิปวิดีโอ',
#   'ดันแคนวัทมอร์',
#   'โคธา',
#   'อามันซิโอออร์เตกา',
#   'ประเทศเกรเนดาในโอลิมปิกเยาวชนฤดูร้อน',
#   'ซาเนโยริ',
#   'การต่อสู้',
#   'การท่องเที่ยวแห่งประเทศไทย',
#   'หม่อมเจ้าจันทร์จิรายุวัฒน์รัชนี',
#   'พระเจ้าเดวิดที่',
#   'ชักพระ',
#   'ภาวะขาดฮอร์โมนไทรอยด์',
#   'พระหทัย',
#   'จอห์นแมคฟอลบารอนแมคฟอลแห่งอัลคลุยธ์',
#   'คณะกรรมการโอลิมปิกแห่งชาติบอตสวานา',
#   'มิซุโนะ',
#   'องค์การบริหารส่วนตำบลขามป้อม',
#   'หลวงหิรญการโกศิต',
#   'ฐานทัพสตาร์คิลเลอร์',
#   'ปัมโปลนา',
#   'เฮาส์เซอร์',
#   'สิทธิรักษ์',
#   'โดเนียรี่',
#   'หน่วยคำนวณและตรรกะ',
#   'จิมไนด์ฮาร์ต',
#   'ปรือใหญ่',
#   'เอียนโซเมอร์ฮอลเดอร์',
#   'ทักษิณอีสาน',
#   'อากุชติญญู',
#   'อะโดะเอ็นโด',
#   'ดิบิอาซี่',
#   'โรงพยาบาลนครปฐม',
#   'สวนสนุกล็อตเต้เวิลด์',
#   'คุณชิกิโมริไม่ได้น่ารักแค่อย่างเดียวนะ',
#   'กองทัพพิราบน้อย',
#   'บังเหียน',
#   'การติดเกม',
#   'อิซะมุ',
#   'แก๊สธรรมชาติ',
#   'นกอีเสือ',
#   'ออลบอร์',
#   'สมาคมฟุตบอลดอมินีกา',
#   'รังนก',
#   'กำแพงฮาดริอานุส',
#   'สควอล',
#   'จิงจงตี้',
#   'จ็อก',
#   'ไพรเมต',
#   'เดอะเลคเฮาส์บ้านทะเลสาบบ่มรักปาฏิหารย์',
#   'ดาวคาโนปัส',
#   'อะมุโระ',
#   'ตำบลนางัว',
#   'เอวาเจลีนอาทาเนเซียคิตตี้แม็คโดเวลล์',
#   'เฮอร์ปีสซิมเพล็กซ์',
#   'เจ้ามันธาตุราช',
#   'สง่าธนสงวนวงศ์',
#   'ต้นไม้แบบทอดข้าม',
#   'เจลลี่บีน',
#   'โยโกฮามะเอฟมารินอส',
#   'โรงเรียนสาธิตมศว',
#   'ฟิดาอิ',
#   'ภาวะเลือดเป็นกรดจากคีโตนจากเบาหวาน',
#   'เจฟฟรีย์ชอเซอร์',
#   'ทังโก',
#   'จูชิงไลเกอร์',
#   'ซาอิดเบนรามา',
#   'โลคอลฮีโร',
#   'อูย',
#   'ไคลเนอไชเด็กก์',
#   'กรมพระสุทธาสิีนีนาถ',
#   'คณะกรรมการโอลิมปิกมอนเตเนโกร',
#   'วัดใหม่',
#   'ดิสทริกต์',
#   'เจ้าหญิงแคโรไลน์แห่งบาเดน',
#   'กระโดดสูงชาย',
#   'เนฟทีส',
#   'ดิสตริคท์ประวัติศาสตร์แห่งชาติ',
#   'ศรีขจรเดชา',
#   'จิตรพึงธรรม',
#   'อีร์ปิญ',
#   'อัสอเวนทูร่าสเดอกุ้ยอีเอสโตปา',
#   'สายลับเดอะซีรี่ส์',
#   'ชอว์นไรเดอร์',
#   'จักรวรรดิละตินแห่งคอนสแตนติโนเปิล',
#   'คริสโอ',
#   'สมเด็จพระราชินีเฮเทปเฮอร์เนบติ',
#   'โอเว่นวิลสัน',
#   'เครื่องบิน',
#   'องค์ชายแฮยัง',
#   'คว็อนซู',
#   'โรงเรียนเบญจธัญพิทยา',
#   'หลวงพ่อกลั่นอคฺคธมฺโม',
#   'พระเจ้าบรมวงศ์เธอกรมหลวงเทพพลภักดิ์',
#   'รัฐภูมิ',
#   'ผื่นหลายรูปแบบจากแสงแดด',
#   'ทับหลังนารายณ์บรรทมสินธุ์ของปราสาทพนมรุ้ง',
#   'ภาษาโคดาวา',
#   'ดานี่',
#   'จอชโกรบัน',
#   'สหพันธ์ฟุตบอลมาลากาซี',
#   'เอโมโตะ',
#   'การก่อกำเริบในหุบเขาเพรเชวอ',
#   'เอียนแฮมพ์เชียร์',
#   'วงศ์กบหาง',
#   'วัดชมนิมิตร',
#   'ลีเปตสค์',
#   'อูนนิลอีนเนียม',
#   'แอ็ลเซอเวียร์',
#   'เจ้าหญิงหลุยส์ดัชเชสแห่งอาร์ไจล์',
#   'ผู้อำนวยการการธุรกิจขนาดย่อม',
#   'อิลซอง',
#   'ชญานิศ',
#   'ลือชัยงามสม',
#   'วัฒนพานิช',
#   'สมิลยานิช',
#   'จิ๊บ',
#   'เพย์เอเบิลออนเดธ',
#   'ปลาเห็ดโคน',
#   'โชกุนสันธนะพานิช',
#   'ศึกนักรบกองพันปีศาจ',
#   'สุนทรพิธ',
#   'กอนเดส',
#   'มาร์กบูธแมน',
#   'โรเบย์ซิรามิเรซ',
#   'คาชุงกา',
#   'ป้ายอาญาสิทธิ์',
#   'เฉินหยางฉิง',
#   'เบคก้าชาง',
#   'วิโนน่า',
#   'เชสสวัฟ',
#   'มหาวิทยาลัยแห่งชาติไต้หวัน',
#   'ภาษาล้านนา',
#   'หาด',
#   'นิกกีมินาจ',
#   'ชนินทร์',
#   'อวทาร์',
#   'ธงชาติสาธารณรัฐแมซิโดเนีย',
#   'ยุทธการที่อัลยากูเศาะฮ์',
#   'ปีกองทัพเรือรัสเซีย',
#   'ประเทศโดมินิกัน',
#   'เทศบาลตำบลปากน้ำประแส',
#   'อัตราชีพจร',
#   'อำเภอวิหารแดง',
#   'เอนกนาวิกมูล',
#   'อีฟอร์แอลเอม',
#   'โจมาร์ดามอสมอค',
#   'ความบอด',
#   'มุโตะ',
#   'อาเธอร์ฑูตจิ๋วเจาะขุมทรัพย์มหัศจรรย์',
#   'พระอนิลมานธมฺมสากิโย',
#   'อำเภอเวียงแหง',
#   'บางประภากร',
#   'ติงศภัทิย์',
#   'ราอูลมาเซียส',
#   'มหาวิทยาลัยอิลลินอยส์เออร์แบนาแชมเปญจน์',
#   'มีไซแนปส์หลายอัน',
#   'ทอร์เนโด',
#   'พักมินย็อง',
#   'หม่อมเจ้าพระสังวรวรประสาธน์',
#   'กรึนชปัน',
#   'พระราชวังเคนซิงตัน',
#   'เจ้าชายแห่งวาซา',
#   'ปลาปักเป้าซีลอน',
#   'สโมสรฟุตบอลองค์การโทรศัพท์แห่งประเทศไทย',
#   'อดีตเจ้าหญิงทากะทาคะสึคะสะ',
#   'อุเมะซะวะ',
#   'ร่มไทรทอง',
#   'ประเทศอินเดียในพาราลิมปิกฤดูร้อน',
#   'พอลิไซคลิก',
#   'เล็คดร็อพ',
#   'แยกพรานนก',
#   'ตู้ฉีฟง',
#   'มิลิซ',
#   'กะละมัง',
#   'โตโยต้าคราวน์',
#   'เจ้าชายคาร์ดัมเจ้าชายแห่งทาร์โน',
#   'ป่าคดเคี้ยว',
#   'หักเหแสง',
#   'เซธ',
#   'เด็กๆของพระเจ้าและรองเท้าที่หายไป',
#   'โฮลี',
#   'มณฑลดาร์บีเชียร์',
#   'ดาราจักรวิทยุ',
#   'ทรอเป',
#   'มหาวิหารแม่พระแห่งเวซง',
#   'ไบรโอนี',
#   'พรรคเอกราชเปอร์โตริโก',
#   'เกอร์คอฟ',
#   'เกวันด์เฮาส์',
#   'มหัล',
#   'จังหวัดแบร์กาโม',
#   'เจ้าน้อยแก้วเมืองพรวนณลำปาง',
#   'พลังอักษะ',
#   'ไซน์',
#   'ลำเซบาย',
#   'ลิงอุรังอุตังบอร์เนียว',
#   'ปลาซิวข้างขวานใหญ่',
#   'สมเด็จพระราชินีนาถโจวันนาที่',
#   'ฟิลยู',
#   'กีฬาเอเชียนเกมส์ฤดูหนาว',
#   'ซาบีฮอลลาห์',
#   'โจอินซุง',
#   'กุสตาฟเคอร์ชอฟฟ์',
#   'ตรูบาดู',
#   'ดราก้อนบอลไค',
#   'อายะตุลลอหฺ',
#   'ลานรับสัญญาณ',
#   'โกสัมพี',
#   'อดัมลาลลานา',
#   'แฮนด์ลี่ย์',
#   'ไทต์เอนด์',
#   'มูลค่าแท้จริง',
#   'ก็อดเบลสฟิจิ',
#   'พูเร',
#   'เลอโอฮาร์ด',
#   'อุทยานแห่งชาติแมมมอทเคฟ',
#   'ซับแช',
#   'มหาวิทยาลัยเทคนิคแห่งบรันเดนบูร์ก',
#   'ศิมลา',
#   'เปนเน',
#   'พายุโทกาเงะ',
#   'ฮิบิกิยามามูระ',
#   'การคารวะแบบนาซี',
#   'จุลลทรัพย์',
#   'เขาง้อไบ๊',
#   'เจ้าชายเลกาที่',
#   'ทะลุวัง',
#   'วอนดัดลีย์',
#   'อ่าวเมาะตะมะ',
#   'วัดธรรมมิการามวรวิหาร',
#   'รอเบิร์ต',
#   'หลี่ลี่จฺวิน',
#   'นิติบุคคล',
#   'ดิง',
#   'สมาชิกวุฒิสภาจังหวัดนราธิวาส',
#   'ฟลิน',
#   'วงศ์หอยมือเสือ',
#   'ไอฟลิกซ์',
#   'คริสเตียนซาวานี',
#   'บรรณาธิการบริหาร',
#   'อิตส์ออลเลิฟ',
#   'สมเด็จพระราชินีนาถราฟอไฮ',
#   'อีสท์แมนโกดัก',
#   'ถนนราชดำเนินกลาง',
#   'เรฟผจญภัยเหนือโลก',
#   'คานยุค',
#   'พีคโคเฮียเรนซ์',
#   'เนียมหูเสือ',
#   'การลำดับชั้นหิน',
#   'วิกิพีเดียภาษาซีแลนด์',
#   'ลีโอนาโดดิคาปริโอ',
#   'สาธารณรัฐฮาวาย',
#   'เดี่ยวผสม',
#   'ในสมเด็จพระนางเจ้าสิริกิติ์',
#   'พระราชกฤษฎีกาอองบัวส์',
#   'ข้าวบัสมาติ',
#   'การเสียชีวิตของไดอานา',
#   'เบเคอร์',
#   'จังหวัดอาปาเยา',
#   'บูรณุปกรณ์',
#   'มาซะ',
#   'บีฟานา',
#   'ราชวงศ์กาโรแล็งเชียง',
#   'ปลายประสาทเมอร์เกิล',
#   'คริสโอดาวด์',
#   'โรงพยาบาลพระรามเก้า',
#   'ถิ่น',
#   'น้ำอสุจิ',
#   'ศาลเจ้าอิเซะ',
#   'พงศ์สุข',
#   'ฟอสโฟกลีเซอเรต',
#   'ร็อบโฮลดิง',
#   'กวนไฮ',
#   'ปลาใบโพจุด',
#   'วิถีการถ่ายโอนสัญญาณ',
#   'เชแปร์เทินส์',
#   'ท่าอากาศยานเมะมันเบะสึ',
#   'พายุไลออนร็อก',
#   'พระยาวิจารณ์จักรกิจ',
#   'ศิริจรรยา',
#   'เคฆัม',
#   'กัลลิโพลี',
#   'บรูตัสบีฟเค้ก',
#   'ศิริศักดิ์นันทเสน',
#   'ท่านผู้หญิงวิระยา',
#   'ไซเลม',
#   'เมธีวิจัยอาวุโสสกว',
#   'สถานีเคเซอุเอะโนะ',
#   'จอร์แดนโบเวอรี',
#   'ซียูอะเกน',
#   'อูลูกาลาลา',
#   'เอบีช',
#   'บริการวางเซิฟเวอร์ณส่วนกลาง',
#   'มิฮารุฮานาอิ',
#   'คณะกรรมการโอลิมปิกโซมาเลีย',
#   'ทูแพ็ก',
#   'เทศบาลเมืองบ้านสวน',
#   'มาศดิตถ์',
#   'เดอะเลกาซีออฟโกคู',
#   'โรแบร์ปีแรส',
#   'อำเภอหนองแซง',
#   'เพ็ญกุล',
#   'แจ็ควิลเลี่ยมสัน',
#   'ฮั่วหยวนเจี่ย',
#   'วันเลิฟ',
#   'ฟุชิงิดาเนะ',
#   'ฮิโระฮะยะมะ',
#   'ชือฆรือเนา',
#   'ทากาชินิชิยามะ',
#   'วันสงบศึก',
#   'นะโอะอะกิอะโอะยะมะ',
#   'อำแดงเหมือน',
#   'ซีบีเอสคอร์เพอเรชัน',
#   'พาราไลซด์',
#   'วัดธรรมปทีป',
#   'ดับเบิลยูซีดับเบิลยูกรีด',
#   'เต็มฟ้า',
#   'มันโรเวีย',
#   'ตู้แช่แข็งอุณหภูมิต่ำพิเศษ',
#   'เอมสาธิดา',
#   'รื่นเริง',
#   'อบารัต',
#   'ยูเอสแอร์เวส์',
#   'ทูมาร์คิน',
#   'ธัญลักษณ์โชติพิบูลย์ศิลป์',
#   'อาร์บ็อก',
#   'กุยโป',
#   'ลีไรอัน',
#   'ปลาหมอลายเมฆ',
#   'ยุทธการที่เอ็ดจ์โคทมัวร์',
#   'วินด์เซอร์พาร์ก',
#   'เดคาฮีดรอน',
#   'เพลงประจำโรงเรียนสวนกุหลาบวิทยาลัย',
#   'อะมะรตยะเสน',
#   'หนังสือใช้แล้ว',
#   'ท่าอากาศยานแห่งชาติวอชิงตันโรนัลด์เรแกน',
#   'พอยต์ไฟฟ์',
#   'โดมินิกตัน',
#   'พรพรรณฤกษ์อัตการ',
#   'แอเน็ว',
#   'เอฟเอ็กซ์เอ็กซ์',
#   'นภาพล',
#   'ภัยพิบัติวันขอบคุณพระเจ้า',
#   'หลัน',
#   'การล้อมที่เดิงแกร์ก',
#   'เอวีไอดอล',
#   'คอมแพตทิเบิล',
#   'เทเลวิเซียปอลสกา',
#   'เคนจินะงะอิ',
#   'มหาราชา',
#   'เกาะสูง',
#   'โทมัสแฟร์มาเลิน',
#   'หน้าผาการคลังสหรัฐอเมริกา',
#   'บุญรัตนธนากร',
#   'ซิดวีเชียส',
#   'เพลงไซ',
#   'พระสัมพุทธพรรณี',
#   'สนามกีฬาราชนาวีสัตหีบ',
#   'พระเจ้าโจวเจิ้นติ้ง',
#   'เน็กซัสเอส',
#   'ทวีปอาฟริกา',
#   'ฉลอง',
#   'คณะองคมนตรีไทย',
#   'บาจาจ',
#   'สิงคโปร์',
#   'โรสมีเดียแอนด์เอ็นเตอร์เทนเม้นท์',
#   'แอบเปิ้ลแอนด์อันยัน',
#   'สายใยนิรันดร์',
#   'เจ้าปิ่ง',
#   'กู้น้อย',
#   'พระเพ็ชรคีรีศรีสงคราม',
#   'กีฬาแฮนด์บอลหญิงในโอลิมปิกฤดูร้อน',
#   'สฺวีเจียยฺหวี',
#   'พฤษภาประชาธรรม',
#   'สงครามโลก',
#   'คัยยาม',
#   'การล้างจมูก',
#   'แฮ็นดริกอาเฟอร์กัมป์',
#   'ดิยุฟ',
#   'ไทโอยูเรีย',
#   'ยุวรัตน์',
#   'ชาติชายพุคยาภรณ์',
#   'โอนีจัง',
#   'พระเจ้าชังซู',
#   'ชาลส์แดนซ์',
#   'บริสตอลเคาน์ตี',
#   'ข้าวมันไก่',
#   'องค์การบริหารส่วนตำบลสะแกโพรง',
#   'ไนไตรต์',
#   'พงศ์ณริลณ์',
#   'ฟิเดลรามอส',
#   'เอฟเอคอมมูนิตีชีลด์',
#   'วัดวชิราลงกรณ์วรารามวรวิหาร',
#   'ศุภมาส',
#   'การปลุกเครื่อง',
#   'หลวงดาราหล้า',
#   'มหัศจรรย์เรียกอสูร',
#   'อิงเงอบอร์กแห่งเดนมาร์กดัชเชสแห่งเมคเลินบวร์ค',
#   'หยิบสิบ',
#   'ขริบหนังหุ้มปลายอวัยวะเพศ',
#   'จิระภาคย์',
#   'โฮเซ่เบเซอร์รา',
#   'ภาณุเดชวัฒนสุชาติ',
#   'ก่อ',
#   'สมมติฐานว่าง',
#   'อมาลีแห่งเฮ็สเซิน',
#   'เมาริซิโอฟูเนส',
#   'จังจริงจิต',
#   'โรงเรียนมัธยมปลายโทะคิวะงิ',
#   'บาร์ดังกา',
#   'วงศ์วาสนา',
#   'คุโดเมะกุมิ',
#   'นิตยสารดีไซน์อินเทลลิเจนซ์',
#   'รถไฟฟ้าสายสีส้มและสายสีน้ำเงิน',
#   'เกาะทะนากา',
#   'เลาบัค',
#   'คัตติงครูว์',
#   'ชิฟเฟอรส์',
#   'รัฐผู้พิทักษ์',
#   'แอบบีคอมบวร์ก',
#   'ดาวชาละวัน',
#   'พระเจ้าบรมวงศ์เธอพระองค์เจ้าประภา',
#   'แอนเน็ตต์โอทูเล',
#   'บิลลีชาร์ป',
#   'โนบิโอะ',
#   'ความเอนเอียงในการตีพิมพ์',
#   'หม่อมราชวงศ์นันทวัฒน์ชยวฑฺฒโน',
#   'แยกปทุมวัน',
#   'มิราอิ',
#   'ทาโอะ',
#   'อเวสตะ',
#   'ไฟฟ์แมน',
#   'คูนิชิเงะคามาโมโตะ',
#   'โรงเรียนบัวใหญ่',
#   'ผีเพื่อนซี้',
#   'วิทยาลัยปิโตรเลียมและปิโตรเคมีจุฬาลงกรณ์มหาวิทยาลัย',
#   'อัลวาเรช',
#   'วงศ์เป็ดแดง',
#   'จอห์นคูการ์เมลเลนแคมป์',
#   'สถานีรถไฟนครชุมน์',
#   'ธาราทิพย์',
#   'วัดราชประดิษฐ์สถิตย์มหาสีมาราม',
#   'สกุลปลายาด',
#   'ทานูมะ',
#   'กำเนิดประเทศญี่ปุ่น',
#   'ตำบลสะแกโพรง',
#   'ฮามาโอะ',
#   'โรเบอร์โตโมเรโน',
#   'ชีเมเวอร์ซาลย์คอ',
#   'บุษยามาทแล็ง',
#   'เอสพลานาดซีนีเพล็กซ์',
#   'สึกิฮะระ',
#   'อุงเหม่ยหลิง',
#   'ทราวิสสก็อตต์',
#   'กัญญาวีร์',
#   'ประยุทธมหากิจศิริ',
#   'เคเธอร์',
#   'แลบอราทอรี่',
#   'การดูดกลืนเชิงแสง',
#   'พระแม่เทวเสนา',
#   'วัดนวลนรดิศวรวิหาร',
#   'พระพรหมกวี',
#   'อิลกุก',
#   'คินตามณี',
#   'เดชนางพญาผมขาว',
#   'บุญสัมพันธ์',
#   'บันนาอี',
#   'แมกโนลิโอไฟต้า',
#   'โรงละครมรดกใหม่',
#   'ปราโมทย์นาครทรรพ',
#   'ดิดัน',
#   'วีโยโกอัตโมดาร์มินโต',
#   'วัลลาบีบีเทิลส์',
#   'หมอยาแห่งวังหลัง',
#   'อุทยานธรณีแห่งชาติจางเย่',
#   'ฮาซ็อง',
#   'สรุปเหรียญรางวัลเอเชียนเกมส์ตลอดกาล',
#   'ฟุตบอลทีมชาติชิลี',
#   'กิ่งดาวดารณี',
#   'ลัทธิหลัว',
#   'ฟรานซิสโคเกอแลง',
#   'มิกเกลี',
#   'ทัสเคนไรเดอร์',
#   'ศูนย์แพทยศาสตรศึกษาชั้นคลินิกโรงพยาบาลร้อยเอ็ด',
#   'ทะเลสาบเมลาเรน',
#   'ฟีลีแบร์เดอลอมเบอ',
#   'อุทกภัย',
#   'พื้นที่สงวนชีวมณฑลสวนสัก',
#   'ปาเสค',
#   'วารสารวิชาการ',
#   'เครื่องรับวิทยุ',
#   'ช่องแคบการีมาตา',
#   'รถยนต์พระที่นั่งในสมเด็จพระเจ้าลูกเธอเจ้าฟ้าจุฬาภรณ์วลัยลักษณอัครราชกุมารี',
#   'ทางพิเศษอะโอะโมะริ',
#   'แอดัมที่',
#   'การเลือกผู้นำอัมโน',
#   'จังหวัดเกลเดอร์ลันด์',
#   'องค์กรด้านสิทธิมนุษยชน',
#   'ภวังคจิต',
#   'วอลเลย์บอลหญิงทีมชาติเยอรมนีตะวันออก',
#   'กวาชแนียฟสกี',
#   'พาแปนโดรโอ',
#   'เซวิลล์',
#   'นีตสึ',
#   'กัสตาเญดา',
#   'ปฏิทินจีน',
#   'ผกาพันธ์',
#   'อินโน',
#   'ทหารที่',
#   'เสรีโรจน์',
#   'ดิสนีย์พิกเจอส์',
#   'เอเอฟเอฟฟุตซอลคัพ',
#   'กัมบะโอซาก้า',
#   'สุขุมพันธุ์บริพัตร',
#   'รีจัส',
#   'อัศเจรีย์กลับหัว',
#   'จอร์จแม็คคาร์ทนีย์เอิร์ลแม็คคาร์ทนีย์ที่',
#   'ท่านผู้หญิงมณีรัตน์บุนนาค',
#   'ทาจิบานะโนะคาจิโกะ',
#   'พิพิธภัณฑ์ในจุฬาลงกรณ์มหาวิทยาลัย',
#   'โชเซ่มูรินโญ่',
#   'โอคุโบะโทะชิมิจิ',
#   'รตาพรทิพย์มนตรี',
#   'อนุสรณ์สถานมาร์ติน',
#   'สมเด็จพระราชาธิบดีสุลต่านฮัจญีอาห์หมัดชาห์',
#   'ขั้นตอนวิธีของชไตน์เฮาส์จอห์นสันและทร็อทเทอร์',
#   'ต้นปาริชาต',
#   'ภาษาทือเกร',
#   'ฮุสตัน',
#   'งักหลิม',
#   'ไฮเซอ',
#   'เลาหกุล',
#   'วะอะลัยกุมุสซะลาม',
#   'การเดินขบวนวันจันทร์ในเยอรมนีตะวันออก',
#   'จิโรวะตะนะเบะ',
#   'บริษัทปาเต๊ะ',
#   'เมืองแหลมฉบัง',
#   'สะพานปาซูปาตี',
#   'ดูไบ',
#   'ไทยแลนด์มอเตอร์ไซค์เคิลกรังด์ปรีซ์',
#   'ไอไซริส',
#   'มาเรียอันเดอร์กัช',
#   'สโมสรฟุตบอลปัคทาคอร์ทาชเคนต์',
#   'ยาซิร',
#   'โจวมี่',
#   'มิลล์วอลล์',
#   'ปันเฑ',
#   'คณะวิทยาการสุขภาพและการกีฬา',
#   'เสียวอี่',
#   'รางวัลออสการ์สาขาภาพยนตร์นานาชาติยอดเยี่ยม',
#   'คิโยกาวะ',
#   'โพลีนีเซีย',
#   'พระเจ้าบรมวงศ์เธอพระองค์เจ้าทักษิณชานราธิราชบุตรี',
#   'พระเจ้าจูมง',
#   'งูหลามพม่า',
#   'ลูชาโน',
#   'รางวัลภาพยนตร์แห่งชาติสุพรรณหงส์สาขาภาพยนตร์ยอดเยี่ยม',
#   'ตำหนักพระองค์เจ้าอาทรทิพยนิภาพระองค์เจ้าสุจิตราภรณีและเจ้าจอมมารดาชุ่ม',
#   'เซร์คี',
#   'โซโวนีเมียร์',
#   'กรองทอง',
#   'เอสซัม',
#   'เบรุต',
#   'บีดีอาย',
#   'ฮิเดะโอะอิตะมิ',
#   'เจ้าหญิงนาเด็จแห่งบัลแกเรีย',
#   'ชมพูนุช',
#   'เกิร์ลลี่เบอร์รี่',
#   'บ้านทำเนียบ',
#   'ล็อก',
#   'สถาบันดำรงราชานุภาพ',
#   'สะเบต',
#   'ฟรานเซสกา',
#   'จิโรลาโมซาโวนาโรลา',
#   'มาตราเอสไอ',
#   'กิจกรรมรับน้อง',
#   'เลขาธิการพรรคประชาธิปัตย์',
#   'พัฒน์ดำรงจิตร',
#   'เซลล์ประสาทสั่งการบน',
#   'คาลิฟาซีเซ',
#   'กลตีหญ้าให้งูตื่น',
#   'การผนึกประตูของสึซึเมะ',
#   'ชาวเติร์กอีหลี',
#   'หลุดสี่หลุด',
#   'โรงแรมแบลเวแดร์',
#   'พยัคฆ์ร้ายใต้สะดือตอนตามล่อพ่อสายลับ',
#   'ฟริตซ์ชวิกกี',
#   'ผสมสิบ',
#   'หลิวปัง',
#   'สกุลแอมบาสทาเอีย',
#   'เฟแนร์บาห์แชสปอร์คูลือบือ',
#   'ฉวาง',
#   'คริมินอลไมน์ทีมแกร่งเด็ดขั้วอาชญากรรม',
#   'แนวการก้าวผ่านวัย',
#   'เลดี้ฝรั่งดอง',
#   'แอนดรูว์การ์ฟิลด์',
#   'เขตนัมดง',
#   'วรรณไว',
#   'การแข่งขันเอเชียนเกมส์',
#   'ลลิตาสิงห์โตทอง',
#   'กังหัน',
#   'ท่านผู้หญิงนพคุณทองใหญ่ณอยุธยา',
#   'ซิสติก',
#   'เลิศสุรีย์เดช',
#   'เวล',
#   'อาเรบีตซา',
#   'แม่น้ำแอ็สโก',
#   'เสนาะ',
#   'แยกทศกัณฑ์',
#   'อัศนัยเทียนทอง',
#   'คุซเนตซอฟ',
#   'จ็องวู',
#   'เจ้าชายโยชิฮิโตะคัตสึระโนะมิยะ',
#   'กิดาวเพชรหนูห่วง',
#   'แผนการดอวส์',
#   'ท่าเพิร์ล',
#   'อินแก้ว',
#   'อุทกภัยและดินถล่มในภาคใต้ของประเทศไทย',
#   'ติดเชื้อ',
#   'ดีเพชโมด',
#   'สิทธิเจริญฤทธิ์',
#   'ลานาแลง',
#   'โทชิโกะ',
#   'อิบน์ค็อลลิกาน',
#   'นักบุญฟรานซิสปลื้ม',
#   'หญ้าใบมะกรูดขน',
#   'ไคลมีน',
#   'รางวัลบาฟต้า',
#   'สมเด็จพระราชาธิบดีจิกมีซิงเยวังชุก',
#   'สมเล็ก',
#   'ซนโนโจอิ',
#   'บุญเรือนปุณฺณโก',
#   'สตราดา',
#   'คุณธรรมสี่ประการ',
#   'สายัณห์ม่วงเจริญ',
#   'การีมุนชวา',
#   'ดาวเอฟซิลอนแม่น้ำบี',
#   'หม่อมราชวงศ์อรฉัตร',
#   'คอชตูนีตซา',
#   'ประธานาธิบดีมาซิโดเนียเหนือ',
#   'สมเด็จพระราชินีนาถเลโอนอร์ที่',
#   'เจ้าหญิงโคโนอิ',
#   'มอสซาด',
#   'เจ้าชายเลโอโปลด์แห่งนัสเซา',
#   'มิสะคากิซากิ',
#   'อดอล์ฟดาฟีดส์',
#   'จังหวัดปกครองตนเองชนชาติลีซอ',
#   'กบฏน้ำลาย',
#   'กลุ่มอาการพาทู',
#   'บิชอปแห่งเรเกนส์บูร์ก',
#   'ทุรโยธน์',
#   'กะบาก',
#   'โมรากุล',
#   'คีเฟอร์ซัทเธอร์แลนด',
#   'นอร์เบิร์ต',
#   'เจ้าฟ้าหญิงอัสตริดแห่งเบลเยียม',
#   'แห่งเวลลิงตัน',
#   'รถจักรดีเซลไฟฟ้าในประเทศไทย',
#   'เปิดตำนานกับเผ่าทองทองเจือ',
#   'ด้วยเศียรเกล้า',
#   'เกาะฟูเอร์เตเบนตูรา',
#   'ศิลปอาชา',
#   'ถูยั่นหลิง',
#   'คารอล',
#   'ถนนเชียงราก',
#   'ขันทองพยาบาท',
#   'ทาโกะยากิ',
#   'โตะโนะโซงุ',
#   'อาบิลา',
#   'เคสท์เนอร์',
#   'แอคโนโลเกีย',
#   'ร็อคเคสตร้า',
#   'ศุภะสุขะไจนะ',
#   'เค็นซุเกะ',
#   'ไอรอนแมน',
#   'รุสลันโปรวอดนิคอฟ',
#   'ซาทูร่า',
#   'จักรวรรดิฝรั่งเศสที่',
#   'วัดท่าเยี่ยม',
#   'อัสเทอราพี',
#   'หม่อมเจ้าเกษมเสาวภา',
#   'เกร์ยม่อน',
#   'ประสิทธิ์',
#   'ตำรวจรัฐสภา',
#   'โครงสร้างขนาดใหญ่ในจักรวาล',
#   'แผ่นตราไปรษณียากรพิเศษ',
#   'ถนนพัทยา',
#   'แถวคอยลำดับความสำคัญ',
#   'มุตซามูดู',
#   'รมิตา',
#   'สมเด็จพระราชาธิบดีวิลเลิม',
#   'ปาโบลปีกัสโซ',
#   'อูรักลาโวย',
#   'เกียรติศักดิ์ส่องแสง',
#   'เฮียโรกลิฟ',
#   'หุบผาชันแม่น้ำฟิช',
#   'ฟอร์บ',
#   'นกขาบ',
#   'ดาร์บี้',
#   'ภาษามัลวี',
#   'สโมสรฟุตบอลนครศรีธรรมราช',
#   'อาการเมาอันเนื่องมาจากยานพาหนะ',
#   'ปัญญาอินทปัญโญ',
#   'สนามเป้า',
#   'หลิวหง',
#   'เรเดียส',
#   'เฮสเทีย',
#   'พระสุนทรธรรมเมธี',
#   'เอิลเคอ',
#   'สมัยอ่อนวงค์',
#   'พระราชวังพระนครคีรี',
#   'วอริกบั๊กเลอร์',
#   'ไมสูรุ',
#   'เดวิดลีน',
#   'เจ้าหญิงมาร์กาเร็ตแห่งลิกเตนสไตน์',
#   'ศิลปะอยุธยา',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 5461

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['และแคริบเบียนในฟุตบอลโลก',
#  'เจ้าจอมมารดาลูกจันทน์เล็กในรัชกาลที่',
#  'สโมสรฟุตบอลสิงห์เชียงรายยูไนเต็ดในฤดูกาล',
#  'กีฬาวู้ดบอลในกีฬาแห่งชาติครั้งที่',
#  'การเลือกตั้งทั่วไปในประเทศตองกา',
#  'เจ้าหลวงน้อยใน',
#  'โบราณสถานในเมืองเพชร',
#  'บั๊คโรเจอร์มนุษย์ในศตวรรษที่',
#  'วัดประดู่ในทรงธรรม',
#  'อิควานัลมุสลิมีนในประเทศอียิปต์',
#  'ดินแดนมหัศจรรย์ในสวนหลังบ้าน',
#  'มะเร็งในวัยเด็ก',
#  'แผ่นดินไหวในลอร์กา',
#  'สถาปัตยกรรมมหาวิหารในยุโรปตะวันตก',
#  'ตัวละครในเซียนเกมรัก',
#  'ธงในนครรัฐวาติกัน',
#  'เหรียญราชอิสริยาภรณ์อันเป็นบำเหน็จในพระองค์',
#  'สโมสรฟุตบอลบางกอกกล๊าสในฤดูกาล',
#  'คีตราชนิพนธ์บทเพลงในดวงใจราษฎร์',
#  'โบราณสถานในจังหวัดสุราษฎร์ธานี',
#  'สหรัฐอาหรับเอมิเรตส์ในพาราลิมปิกฤดูร้อน',
#  'พระราชธิดาและพระมเหสีในฟาโรห์อเมนโฮเทปที่สาม',
#  'อาวุธและวิชาโจมตีในเทพมรณะ',
#  'โฆษณาชวนเชื่อในประเทศญี่ปุ่น',
#  'การสร้างภาพในประสาท',
#  'น้ำตาลในเลือดสูง',
#  'พิธีสำเร็จการศึกษาในประเทศไทย',
#  'โล่ในตรา',
#  'กีฬาเรือพายในกีฬาแห่งชาติครั้งที่',
#  'สาธารณรัฐประชาชนจีนในเอเชียนอินดอร์เกมส์',
#  'พระราชพิธีบรมราชาภิเษกในสมเด็จพระเจ้าอยู่หัวมหาวชิราลงกรณบดินทรเทพยวรางกูร',
#  'ยุครัฐในอารักขา',
#  'ความหลากหลายทางชีวภาพในประเทศอาเซอร์ไบจาน',
#  'มวยสากลในเอเชียนเกมส์',
#  'ส้วมในประเทศไทย',
#  'แผ่นดินไหวในอีกีเก',
#  'ไวโอลินคอนแชร์โตในบันไดเสียงดีเมเจอร์',
#  'เจ้าจอมมารดาห่วงในรัชกาลที่',
#  'ธงในประเทศออสเตรีย',
#  'ดอกหญ้าในป่าปูน',
#  'ประเทศกาบูเวร์ดีในพาราลิมปิกฤดูร้อน',
#  'สภาพยอมในสุญญากาศ',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติ',
#  'ลำดับเหตุการณ์ในประวัติศาสตร์อังกฤษระหว่างปีค',
#  'เหตุโจมตีด้วยขีปนาวุธในแซร์ฮียิวกา',
#  'ชาวไทยในประเทศปากีสถาน',
#  'เพลงรักในสายลมหนาว',
#  'ในประเทศสเปน',
#  'แผ่นดินไหวในฮอนดูรัส',
#  'ตัวละครที่ปรากฏใน',
#  'ครุยวิทยฐานะในสหราชอาณาจักร',
#  'เจ้าจอมเอื้อนในรัชกาลที่',
#  'สนามกีฬาในร่มพูถ่อ',
#  'แผ่นดินไหวและคลื่นสึนามิในโทโฮกุ',
#  'วัดเจ้าเจ็ดใน',
#  'แผ่นดินไหวในประเทศไต้หวัน',
#  'พระราชนิพนธ์ในพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราชบรมนาถบพิตร',
#  'นักกีฬาคณะกรรมการพาราลิมปิกรัสเซียในพาราลิมปิกฤดูร้อน',
#  'ธงในอาร์เมเนีย',
#  'ฟุตบอลหญิงทีมชาติไทยในฟุตบอลโลกหญิง',
#  'แผ่นดินไหวในชวา',
#  'รัฐบัญญัติห้ามปกปิดใบหน้าในสาธารณสถาน',
#  'กีฬาแฮนด์บอลในเอเชียนเกมส์',
#  'มูลนิธิแห่งสภาคริสตจักรในประเทศไทย',
#  'กรมการราษฎรฝ่ายกิจการภายใน',
#  'วัดในวัง',
#  'โปรเตสแตนต์ในประเทศไทย',
#  'ธงต่างๆในเยอรมนี',
#  'คริสตจักรอีแวนเจลิคัลในเยอรมนี',
#  'รัฐประหารในประเทศกาบอง',
#  'การเลือกตั้งสภาร่างรัฐธรรมนูญในกัมพูชา',
#  'สถาปัตยกรรมอาสนวิหารในยุโรปตะวันตก',
#  'ปลาที่ว่ายในสนามฟุตบอล',
#  'ตัวละครในวรรณกรรมมังกรคู่สู้สิบทิศ',
#  'โรงเรียนสายปัญญาในพระบรมราชินูปถัมภ์',
#  'ปาปัวนิวกินีในแปซิฟิกเกมส์',
#  'นิ่วในไต',
#  'การเพิ่มจำนวนอาวุธปืนในประเทศไทย',
#  'ในประเทศซูดาน',
#  'การประท้วงในประเทศไทย',
#  'การจาริกแสวงบุญของชาวพุทธในดินแดนพุทธภูมิ',
#  'สมัยฟื้นฟูศิลปวิทยาในอิตาลี',
#  'คอร์เทกซ์กลีบขมับส่วนใน',
#  'ประเทศเติร์กเมนิสถานในพาราลิมปิกฤดูร้อน',
#  'รถรางในปราก',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศเวียดนาม',
#  'การศึกษาในประเทศออสเตรเลีย',
#  'เจ้าจอมมารดามรกฎในรัชกาลที่',
#  'มหาวิหารในสหราชอาณาจักร',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทย',
#  'ธงในประเทศสเปน',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติครั้งที่',
#  'ตัวละครในเปลวฟ้าผ่าปฐพี',
#  'อาจารย์และบุคลากรในฮอกวอตส์',
#  'การทิ้งระเบิดที่เดรสเดินในสงครามโลกครั้งที่สอง',
#  'การปล้นธนาคารในติฟลิส',
#  'ภัยพิบัติเรือผู้อพยพในเมสซีนีอา',
#  'อุทกภัยในคีวชู',
#  'คัมภีร์ทางศาสนาพุทธในประเทศไทย',
#  'พระราชนิพนธ์ในพระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลก']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 5086

# %%
get_samples(nai)
# Out:
# ['โดราเอมอนตอนโนบิตะผจญภัยในเกาะมหัศจรรย์',
#  'ภูมิภาคในประเทศกรีซ',
#  'ปีชัยในมหาสงครามผู้รักชาติค',
#  'เกณฑ์ทหารในประเทศไทย',
#  'แผ่นดินไหวและคลื่นสึนามิในโทโฮกุค',
#  'ศูนย์กีฬาในร่มมารากานังซิญญู',
#  'สนามกีฬาในร่มโตเกียว',
#  'พระราชสันตติวงศ์ในสมเด็จพระเจ้าจอร์จที่',
#  'การประท้วงในประเทศซูดาน',
#  'เจ้าจอมช้อยในรัชกาลที่',
#  'เลือดในอุจจาระ',
#  'โรคสติลล์ในผู้ใหญ่',
#  'ในบันไดเสียงเอฟเมเจอร์',
#  'เหตุโจมตีในวิทยาลัยสารพัดช่างเคียร์ช',
#  'ไรชส์ค็อมมิสซารีอาทในยูเครน',
#  'มูลนิธิมหามกุฏราชวิทยาลัยในพระบรมราชูปถัมภ์',
#  'คริสตจักรแองลิกันในประเทศไทย',
#  'ในประเทศบราซิล',
#  'เจ้าจอมตนกูสุเบียในรัชกาลที่',
#  'แผ่นดินไหวในประเทศเฮติ',
#  'ทางหลวงในประเทศฟิลิปปินส์',
#  'ดินแดนในอาณัติของสันนิบาตชาติ',
#  'การติดเชื้อในระบบทางเดินหายใจ',
#  'ตัวละครในมาจิเรนเจอร์',
#  'เด่นทักษิณศูนย์กีฬาน้อยใน',
#  'โฆษณาชวนเชื่อในประเทศญี่ปุ่นในช่วงสงครามโลกครั้งที่',
#  'เจ้าคุณจอมมารดาเรียมในรัชกาลที่',
#  'อวัยวะรูปหอยโข่งในช่องหู',
#  'แผ่นดินไหวในรัฐเชียปัส',
#  'โรงเรียนอุบลรัตนราชกัญญาราชวิทยาลัยนครปฐมในพระอุปถัมภ์ฯ',
#  'ตัวละครในลัคกี้',
#  'เหตุระเบิดในปูลีอลัม',
#  'ฟุตบอลในประเทศอิตาลี',
#  'ศาสนาพุทธในเอเชียใต้',
#  'ซิงเกิลประจำตัวละครในเค',
#  'การสมรสเพศเดียวกันในสเปน',
#  'รถรางในลอนดอน',
#  'การโจมตีด้วยแก๊สพิษซารินในรถไฟใต้ดินกรุงโตเกียว',
#  'ผู้เล่นในฟุตบอลโลกหญิง',
#  'ความลับในใจของคุณหนูไอดอล',
#  'ดัชเชสมารีอาอันนาในบาวาเรีย',
#  'วันหยุดในประเทศพม่า',
#  'การปฏิสังขรณ์จิตรกรรมฝาผนังในชาเปลซิสติน',
#  'การเลิกทาสและไพร่ในประเทศไทย',
#  'ศาสนาคริสต์ในประเทศไทย',
#  'รัฐประหารในประเทศไนเจอร์',
#  'แคนอนในบันไดเสียงดีเมเจอร์',
#  'การเลือกตั้งในประเทศเยอรมนี',
#  'แผ่นดินไหวในประเทศพม่า',
#  'กีฬาฟุตบอลในกีฬาแห่งชาติครั้งที่',
#  'ประเทศซีเรียในเอเชียนเกมส์',
#  'สหคริสตจักรแบ๊บติสต์ในประเทศไทย',
#  'กีฬาคาราเต้ในเอเชียนเกมส์',
#  'ธงในประเทศเบลเยียม',
#  'เหตุไล่แทงในตุรกุ',
#  'เหตุเพลิงไหม้โรงงานผลิตหนังในโกลกาตา',
#  'กีฬาเทเบิลเทนนิสในซีเกมส์',
#  'พระราชธิดาในพระนารายน์ราชารามาธิบดี',
#  'สมาคมนักเรียนไทยในประเทศญี่ปุ่นในพระบรมราชูปถัมภ์',
#  'เจ้าจอมมารดาทิมในสมเด็จพระเจ้าตากสินมหาราช',
#  'กรรมในพระพุทธศาสนา',
#  'ปัญหาสิ่งแวดล้อมในสหรัฐ',
#  'จังหวัดอุทัยธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'ธงในประเทศเม็กซิโก',
#  'เหตุโจมตีทางอากาศใส่โรงพยาบาลในมารีอูปอล',
#  'ธงในประเทศไนจีเรีย',
#  'สาธารณรัฐอิสลามอัฟกานิสถานในเอเชียนเกมส์',
#  'ความสำคัญในการรักษา',
#  'กีฬาเรือแคนูในเอเชียนเกมส์',
#  'รัฐประหารในอิหร่าน',
#  'ห้ามใช้พระนามพระเจ้าของเจ้าไปในทางที่ผิด',
#  'กีฬาอีสปอร์ตในกีฬาแห่งชาติครั้งที่',
#  'ภาวะมีกรดไอโซวาลิริกในเลือด',
#  'เหตุโจมตีด้วยขีปนาวุธในอูมัญ',
#  'ประเทศอิสราเอลในเอเชียนเกมส์',
#  'ภาวะมีโซเดียมในเลือดน้อย',
#  'การแปลผลให้เป็นความกลัวในสมอง',
#  'ความทรงจำในการตามเสด็จต่างประเทศทางราชการ',
#  'อันดับปลาเหล็กใน',
#  'เจ้าจอมมารดาแย้มในรัชกาลที่',
#  'เหตุเหยียบกันเสียชีวิตในซาบาริมาลา',
#  'ธงในประเทศเคนยา',
#  'บรรณพิภพในจักรวาลของอสิมอฟ',
#  'ความเอนเอียงในการรายงานผล',
#  'การเรียกร้องให้บัญญัติพุทธศาสนาเป็นศาสนาประจำชาติในรัฐธรรมนูญแห่งราชอาณาจักรไทย',
#  'พุทธสมาคมแห่งประเทศไทยในพระบรมราชูปถัมภ์',
#  'ฟุตบอลในประเทศอิสราเอล',
#  'เหตุโจมตีในมุมไบ',
#  'ภัยธรรมชาติในประเทศไทย',
#  'การปกครองของบริษัทในอินเดีย',
#  'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดนครนายก',
#  'แผ่นดินไหวในซูลาเวซีตะวันตก',
#  'จังหวัดนครราชสีมาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'เจ้าจอมสว่างในรัชกาลที่',
#  'การขนส่งในประเทศติมอร์',
#  'เจ้าจอมมารดาบัวในรัชกาลที่',
#  'สปรินเทอร์ในประเทศไทย',
#  'พุทธศาสนาในประเทศบรูไน',
#  'กีฬาสกีน้ำในเวิลด์เกมส์',
#  'บุญชูจะอยู่ในใจเสมอ']

# %% [markdown]
# Most of these are still non-named-entity
#
# Seems to be difficult to get named-entity title...
#
# Exclude all "ใน"
#
# **HELP NEEDED**

# %%
titles = set([title for title in titles if "ใน" not in title])

get_len(titles)
# Out:
# current: 292729
# diff: -7067

# %%
get_samples(titles)
# Out:
# ['สนามกีฬาชีบัส',
#  'สโมสรฟุตบอลเอ็มเอชคอนสุราษฎร์ฯซิตี้',
#  'เทศบาลเมืองสีคิ้ว',
#  'กอนตาดอร์',
#  'วงศ์นกโจรสลัด',
#  'ที่หยุดรถหนองเนียน',
#  'คลีเมนต์ที่',
#  'มุกเดน',
#  'สภาผู้แทนราษฎรแห่งฝรั่งเศส',
#  'ขนมทองเอกกระจัง',
#  'วัดเพิ่มทาน',
#  'ศิลปะใต้ดิน',
#  'เบอมงต์',
#  'งูเขียวหัวจิ้งจก',
#  'คะซะเนะ',
#  'สมเด็จพระราชินีมยองฮอน',
#  'เหตุระเบิดของเรือบรรทุกน้ำมันที่บรรจุน้ำมันซอมอสกี',
#  'ภานุวัฒน์เกิดทองทวี',
#  'โคลงสี่สุภาพ',
#  'รปปงงิ',
#  'ลาสเปเซีย',
#  'ตลาดหลักทรัพย์ฮัมบูร์ก',
#  'โลวิตต์',
#  'องค์กรการบินจำลองนานาชาติ',
#  'กวางแซมบ้า',
#  'โฟลกวังเกอร์',
#  'ปริยานุช',
#  'ไฟป่าป่าฝนแอมะซอน',
#  'ถนนธนิยะ',
#  'ดาวเทียมเป่ยโต่ว',
#  'วัดสะพาน',
#  'เมดิสันบุคคลชาย',
#  'สกุลกะพ้อ',
#  'ทอมครูซ',
#  'ณรงค์พันธ์จิตต์แก้วแท้',
#  'สี่แยกบางโพ',
#  'ตลาดการเงิน',
#  'แนวสันซุปปราคอนไดลาร์ด้านกลางลำตัว',
#  'สปริงเรดิโอ',
#  'เอลูรู',
#  'รักมั้ยนะ',
#  'เงินกู้',
#  'ประสพสายพรกุล',
#  'แย่ที่สุด',
#  'ดาบิดเฟร์เรร์',
#  'ศรีธัญญา',
#  'พระองค์เจ้านโรดมรัตนาเทวี',
#  'ชุดข้อมูล',
#  'โรดทูคิงดอม',
#  'พระยารัตนาธิเบศร์',
#  'องค์ชายชวอร์เซนเบิร์ก',
#  'นาคสวัสดิ์',
#  'เขื่อนยันฮี',
#  'บึงพลาญชัย',
#  'ฮองไทเฮา',
#  'วัดหนองจิก',
#  'กาลิเซียที่',
#  'กฤษฎีกาเพลิงไหม้ไรช์ซทัก',
#  'ทฤษฎีภาษารูปนัย',
#  'สุรชัยสมบัติเจริญ',
#  'ฟิช',
#  'อาการชักเหตุจิตใจที่ไม่ใช่โรคลมชัก',
#  'โกซีโมตูรา',
#  'เขตเศรษฐกิจวอลกา',
#  'แชจอหอ',
#  'ภาษาโภชปุระ',
#  'พวาทีเอ',
#  'ดาร์ธไทรานุส',
#  'นองต์',
#  'ไอวานเคร็ก',
#  'เด็กหญิงตาบอด',
#  'ตำบลโชคชัย',
#  'โอโรชิมารุ',
#  'โหมดผู้เล่นหลายคน',
#  'จงฮิว',
#  'ดยุกแห่งกุสซี',
#  'แขวงบางมด',
#  'ซานเซเวโร',
#  'คาโรไลน์แห่งบรันสวิค',
#  'ม้าน้ำแคระซาโตไม',
#  'อิบน์ตัยมียะฮ์',
#  'เส้นตั้งฉาก',
#  'วัดอ่างเสือดำ',
#  'ฟอม',
#  'ไจนะ',
#  'แอร์ฟูร์ท',
#  'ณัทธนพลทินโรจน์',
#  'สงครามประกาศอิสรภาพสหรัฐอเมริกา',
#  'คะนึงนิจจักรสมิทธานนท์',
#  'วิศวกรรมผันกลับ',
#  'เขตบางขุนเทียน',
#  'โรเดียม',
#  'จอมมารดาเลี่ยมเล็ก',
#  'เรเซอร์เรคชั่นแมน',
#  'ฟุบุคิชิโร่',
#  'คาน์วิค',
#  'กินต์',
#  'ธงชาติโดมินิกา',
#  'แม่บ้านพันธุ์แปลก',
#  'ออดรีย์ถัง']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)
#
# Some proper-noun like movie titles possibly holds this, so hold both

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (398, 1246)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศซานมารีโน',
#  'ประเทศกาน่า',
#  'ประเทศเมียนมา',
#  'ประเทศลิเบีย',
#  'ประเทศทาจิกิสถาน',
#  'ประเทศมอริเชียส',
#  'ประเทศบูร์กินาฟาโซ',
#  'ประเทศปาเลสไตน์',
#  'ประเทศเอสโตเนีย',
#  'ประเทศยูกันดา',
#  'ประเทศฮอลแลนด์',
#  'ประเทศแอฟริกากลาง',
#  'ประเทศต่ำ',
#  'ประเทศปากีสถาน',
#  'ประเทศตุรเคีย',
#  'ประเทศกรันโกลอมเบีย',
#  'ประเทศไอร์แลนด์',
#  'ประเทศมาซิโดเนีย',
#  'ประเทศสยาม',
#  'ประเทศโอมาน',
#  'ประเทศพัฒนาน้อยที่สุด',
#  'ประเทศเซอร์เบีย',
#  'ประเทศแซมเบีย',
#  'ประเทศสก๊อตแลนด์',
#  'ประเทศเมียนมาร์',
#  'ประเทศเยอรมนีตะวันออก',
#  'ประเทศอุรุกวัย',
#  'ประเทศกัวเตมาลา',
#  'ประเทศอิหร่าน',
#  'ประเทศหมู่เกาะมาร์แชลล์',
#  'ประเทศดอมินีกา',
#  'ประเทศตูนีเซีย',
#  'ประเทศเซนต์คิตส์และเนวิส',
#  'ประเทศเบลเยียม',
#  'ประเทศรัสเซียกับสหประชาชาติ',
#  'ประเทศสาธารณรัฐไอร์แลนด์',
#  'ประเทศเยอรมันนี',
#  'ประเทศสโลวีเนีย',
#  'ประเทศซูดานใต้',
#  'ประเทศเกาหลีเหนือกับอาวุธอานุภาพทำลายล้างสูง',
#  'ประเทศจอร์แดน',
#  'ประเทศคีร์กิซสถาน',
#  'ประเทศลิกเตนสไตน์',
#  'ประเทศรัสเซีย',
#  'ประเทศสาธารณรัฐฝรั่งเศส',
#  'ประเทศโคลัมเบีย',
#  'ประเทศคิวบา',
#  'ประเทศมองโกเลีย',
#  'ประเทศฝรั่งเศษ',
#  'ประเทศเอสวาตินิ',
#  'ประเทศฟลานเดอส์',
#  'ประเทศราชของอาณาจักรตองอู',
#  'ประเทศโซมาเลีย',
#  'ประเทศนาอูรู',
#  'ประเทศสวิสต์เซอร์แลนด์',
#  'ประเทศเลบานอน',
#  'ประเทศชิลี',
#  'ประเทศซูดาน',
#  'ประเทศแมซิโดเนีย',
#  'ประเทศไนจีเรีย',
#  'ประเทศเทกซัส',
#  'ประเทศเกาหลีใต้',
#  'ประเทศสาธารณรัฐอิตาลี',
#  'ประเทศมาซิโดเนียเหนือ',
#  'ประเทศกลุ่มนอร์ดิก',
#  'ประเทศปาเลา',
#  'ประเทศไซปรัส',
#  'ประเทศตะวันตก',
#  'ประเทศมัลดีฟส์',
#  'ประเทศจำลอง',
#  'ประเทศเซียร์ราลีโอนี',
#  'ประเทศสกอตแลนด์',
#  'ประเทศเซนต์ลูเซีย',
#  'ประเทศรัตน์',
#  'ประเทศเอริเทรีย',
#  'ประเทศเฮติ',
#  'ประเทศอินเดีย',
#  'ประเทศแมนจูกัว',
#  'ประเทศโปรตุเกส',
#  'ประเทศฮังการี',
#  'ประเทศคูเวต',
#  'ประเทศฟิลิปปินส์',
#  'ประเทศสาธารณรัฐโปรตุเกส',
#  'ประเทศที่เป็นเกาะ',
#  'ประเทศซามัว',
#  'ประเทศเช็ก',
#  'ประเทศบัลแกเรีย',
#  'ประเทศคาซักสถาน',
#  'ประเทศโบลีเวีย',
#  'ประเทศที่ไม่มีทางออกสู่ทะเล',
#  'ประเทศเบลเยี่ยม',
#  'ประเทศตรินิแดดและโตเบโก',
#  'ประเทศไทยสมัยก่อนประวัติศาสตร์',
#  'ประเทศติมอร์',
#  'ประเทศเฟรนช์เกียนา',
#  'ประเทศอัลบาเนีย',
#  'ประเทศแมนจูเรีย',
#  'ประเทศสแกนดิเนเวีย',
#  'ประเทศเปอร์โตริโก',
#  'ประเทศตูนิเซีย']

# %%
# seperate
titles_temp = set()

#holds both (before and after)
for title in titles:
    if title.startswith("ประเทศ"):
        titles_temp.add(title[6:])
        titles_temp.add(title)
    elif title.startswith("รัฐ"):
        titles_temp.add(title[3:])
        titles_temp.add(title)
    else:
        titles_temp.add(title)
        
titles = titles_temp

get_len(titles)
# Out:
# current: 293622
# diff: 893

# %%
get_samples(titles)
# Out:
# ['กิโลบิตต่อวินาที',
#  'ซะอีด',
#  'ธรรมนูญ',
#  'อุทยานธรรมชาติวิทยาสิรีรุกขชาติ',
#  'จังหวัดวากายามะ',
#  'จางเหว่ยเจี้ยน',
#  'แทรนซิต',
#  'ปวีณ',
#  'กลุ่มภาษาซิโน',
#  'ไดเทอร์พีน',
#  'นิธินพรัศม์',
#  'วัลท์ชปีราเลอ',
#  'วัดบ้านหินลับจังหวัดสระบุรี',
#  'ลิ่มนิ้ว',
#  'คริสเตียโน',
#  'เพลงชาติสาธารณรัฐสังคมนิยมโซเวียตคาซัค',
#  'สึเนะคะสึทะเคะดะ',
#  'ตำบลบางตะไนย์',
#  'มีบุตรยาก',
#  'วาฬขาว',
#  'ชไวนส์ฮัคเซอ',
#  'เซลล์เดนไดรติก',
#  'โกลิมา',
#  'รามาวดี',
#  'อินเดียนาโปลิส',
#  'พระมเหสีฮโยอึย',
#  'พุทธอมรินทร์',
#  'พระเจ้าชุงซุก',
#  'ถนนยุคล',
#  'คอนอร์โคอาดี',
#  'ดาเลียกรีบาวสเคท',
#  'เจลลี่',
#  'ปีย์มาลากุลณอยุธยา',
#  'รังสีคอสมิกไมโครเวฟพื้นหลัง',
#  'คอร์เทกซ์ก่อนคอร์เทกซ์ลาย',
#  'ชูหยา',
#  'กฎหมายหมิ่นพระบรมเดชานุภาพ',
#  'โรงเรียนน้ำพองศึกษา',
#  'คณะผู้แทนทางทูตของประเทศอิตาลี',
#  'กรรณะสุริยบุตร',
#  'ด้วงกว่างเฮอร์คิวลีส',
#  'ซิมพาธี',
#  'ปานพิมพ์',
#  'ฮิจิคะตะโทะชิโซ',
#  'ทากูยะซาโต',
#  'เทศบาลเมืองปัตตานี',
#  'อำเภอพนา',
#  'โทชิยะ',
#  'พระแม่คายตรี',
#  'ป่าต้องห้าม',
#  'โกตส์',
#  'เจ้าชายเฮนรีดยุกแห่งกลอสเตอร์',
#  'วัดลานแหลม',
#  'เซฟีพิม',
#  'สภาไอซ์แลนด์',
#  'ปูซาน',
#  'หยวนฮุ่ยจง',
#  'นิคมช่องแคบ',
#  'ฟาบริซมูอัมบา',
#  'แองเจลิน่าโจลี',
#  'วิกฤติแฮมเบอร์เกอร์',
#  'ขนมปังและละครสัตว์',
#  'บุญส่งมั่นศรี',
#  'ติ่ง',
#  'การขยายตัวของสมาคมประชาชาติแห่งเอเชียตะวันออกเฉียงใต้',
#  'เฮลเซลาสซีที่',
#  'เมเฟิสตอฟะลิส',
#  'ปาล์มพัด',
#  'โรเบิร์ตมูกาเบ',
#  'มาตีส์',
#  'เจ้าชายแคสเปียน',
#  'อันริก',
#  'สภาแห่งฟินแลนด์',
#  'วัดเทพประสิทธิ์คณาวาส',
#  'แก้วปราบเมรุณลำปาง',
#  'หมูย่างซอสขิง',
#  'ธรรมวิมล',
#  'ภาษาฮิลิกายนอน',
#  'เทพีไดแอนา',
#  'เสือไฟ',
#  'องค์การบริหารส่วนตำบลหนองแวงนางเบ้า',
#  'โปครอฟสกายา',
#  'ฟองดูว์',
#  'ประเทศนอร์เวย์',
#  'โกฮวงโก',
#  'มักกินน์',
#  'ปีเตอร์แลง',
#  'แซทเทอร์เดย์เซย์โกะ',
#  'อัครัฐนิมิตรชัย',
#  'ลาซาญญ่า',
#  'โบสถ์แม่พระเดรสเดิน',
#  'เทเดเยฟ',
#  'เพชซี',
#  'ฮิสปันโยลา',
#  'ไชนาเซ็นทรัลเทเลวิชั่น',
#  'ล่าบันทึกลับสุดขอบโลก',
#  'ซูสีไทเฮาภาค',
#  'วันประชาธิปไตยแห่งชาติ',
#  'ถงรามางกูร',
#  'กุ้งพิงก์ฟลอยด์']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %%
def rid_front(text, front):
    if text.startswith(front):
        return text[len(front):]
    else:
        return text

titles_temp = set()
for title in titles:
    title = rid_front(title, "ตำบล")
    title = rid_front(title, "อำเภอ")
    title = rid_front(title, "จังหวัด")    
    title = rid_front(title, "มณฑล")
    title = rid_front(title, "รัฐ")
    
    titles_temp.add(title)
    
titles = titles_temp
    
get_len(titles_temp)
# Out:
# current: 290131
# diff: -3491

# %% [markdown]
# Probably almost all has redirects, but seperate

# %%
get_samples(titles_temp)
# Out:
# ['ยาแก้',
#  'ผลิตภัณฑ์ระงับกลิ่นกาย',
#  'พูลิซิช',
#  'ฟิเลียสฟลิตวิก',
#  'คาซากรานเด้',
#  'เลโอนอร์แห่งอารากอนสมเด็จพระราชินีแห่งโปรตุเกส',
#  'ดูชีเตรา',
#  'ออร์เวิน',
#  'สโมสรฟุตบอลป่าตอง',
#  'กราเนีย',
#  'โฮซึกิมันเงสึ',
#  'เจ้าชายโคะโนะเอะ',
#  'งานทดลองแบบสุ่มมีกลุ่มควบคุม',
#  'โกห์เฉิงเหลียง',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าขจรจรัสวงษ์กรมหมื่นปราบปรปักษ์',
#  'ทอร์เบราว์เซอร์',
#  'ปราสาทดีน็อง',
#  'กนิษฐเสน',
#  'ซัมแวร์เฮียร์ออนเอิร์ธ',
#  'บงนาร์ด',
#  'ตุ๊กแกป่าไทย',
#  'สมชาติเลขาลาวัณย์',
#  'สุดเขตสเลดเป็ด',
#  'ออสการ์อาชิเนกา',
#  'คุณหมอสองภพ',
#  'กินตะ',
#  'ชาร์ลีบิวลีย์',
#  'ชนแองเกิล',
#  'แคทเธอรินดัชเชสแห่งเคมบริดจ์',
#  'เทศกาลภาพยนตร์ซันแดนซ์',
#  'กลุ่มเกาะอเล็กซานเดอร์',
#  'เปตรูลีนา',
#  'ไลบร้า',
#  'แนวร่วมประชาชนซาบะฮ์',
#  'รักคำโตโต',
#  'รักต้องซ่อม',
#  'ฟิสิกส์ของแสง',
#  'กราซีอาโนเปลและ',
#  'จีอีดิต',
#  'ศรีมหามริอัมมันเทวสถานัมซีฟีลด์',
#  'บุญญะสิทธิ์',
#  'สำนักบีสต์อาร์ต',
#  'เดอะสโตนโรส',
#  'โยฮันน์เซบาสเทียนบาค',
#  'ศิรินทรา',
#  'ยามาดานางามาสา',
#  'ปฏิบัติการณ์เดือด',
#  'เพลงสุพลพัวศิริรักษ์',
#  'เขตพื้นที่ภาคพายัพ',
#  'วัดพระธาตุเชิงชุมวรวิหาร',
#  'อลิษา',
#  'รูบีและแซฟไฟร์',
#  'แก๊งค์ฉึกฉักไดโนเสาร์',
#  'ตียงวีล',
#  'แห่งจักรวรรดิไบแซนไทน์',
#  'รักรักรักรักรักเธอหมดหัวใจจากแฟนสาว',
#  'เรวะ',
#  'สโมสรฟุตบอลจังหวัดขอนแก่น',
#  'เอากระดิ่งไปแขวนคอแมว',
#  'พระพุทธนฤมลธรรโมภาส',
#  'แม่ทะ',
#  'สมาชิกสภาผู้แทนราษฎรจังหวัดธนบุรี',
#  'สโมสรฟุตบอลคริสตัลพาเลซ',
#  'โคโนะ',
#  'โรบินฟานเพอร์ซี',
#  'โคทักท์',
#  'แบร์นาร์เดสกี',
#  'วิกิซอฟต์แวร์',
#  'บริษัทวอยซ์ทีวีจำกัด',
#  'ปลายี่สกปากหนา',
#  'แบล็กเบอรีแซด',
#  'อาปอลีแนร์',
#  'เดสตินี่',
#  'สนามกีฬาเทพหัสดิน',
#  'อักษรเบงกาลี',
#  'อีพีอัลบั้ม',
#  'โมบิลสูทกันดั้มดับเบิ้ลโอ',
#  'พีทีวี',
#  'เรือหลวงเชฟฟิลด์',
#  'อับดิราชิด',
#  'มูลา',
#  'โรคไข้สมองอักเสบจากเชื้อไวรัส',
#  'ยูเมเนสจอมคนพลิกโลก',
#  'อัลเบร็คท์อัลท์ดอร์ฟเฟอร์',
#  'มหาวิทยาลัยณิวัฒนา',
#  'บราซิลแหกกฏศตวรรษ',
#  'เจ้าพญายาต',
#  'โคสุเกะฟูจิชิมะ',
#  'ดอยช์เวเลย์',
#  'อาสนวิหารอาลบี',
#  'อีออน',
#  'คาชีค',
#  'เมงุมิทาคาโมโตะ',
#  'อะเล็กซานเดรียเอสคาเท',
#  'โตรณะ',
#  'เจ้าแม่ทอหูก',
#  'คณะกรรมการโอลิมปิกเวเนซุเอลา',
#  'แถบนีละนิธิ',
#  'ไทบีเรียน',
#  'อันโตนีโอซาลิเอรี']

# %% [markdown]
# ## Save

# %%
with open("wikipedia_nlp.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(titles))
