# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
_len = 0
def get_len(titles):
      global _len
            
      current_len = len(titles)
      print(f'current: {current_len}\n'
            f'diff: {current_len - _len}')

      _len = current_len

      return

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
get_len(titles)
# Out:
# current: 362955
# diff: 362955

# %%
get_samples(titles)
# Out:
# ['สกุลปลาเค้า',
#  'วิปครีม',
#  'สแตน_สตาซิแอก',
#  'วอลเลย์บอลชิงถ้วยพระราชทานสมเด็จพระจักรพรรดิและสมเด็จพระจักรพรรดินี',
#  'เรื่องจริงช็อคโลก',
#  'Megan_Fox',
#  'อะไวเทอร์เฉดออฟเพล',
#  'Mashup',
#  'พ.ศ._1707',
#  'โทรทัศน์ประเทศญี่ปุ่นใน_ค.ศ._1959',
#  'ดับเบิลยูดับเบิลยูอี_แคลชออฟแชมเปียนส์',
#  'เพชรตัดเพชร_(2527)',
#  'เทียนจินแอร์ไลน์',
#  'รายชื่ออักษรย่อของจังหวัดในประเทศไทย',
#  'สถานีรถไฟหนองวัวเฒ่า',
#  'เซท_โรลลินส์',
#  'เดอะสแควร์_ดรีมสตาร์',
#  'เอฟเอคัพ_รอบชิงชนะเลิศ_2016',
#  'Notopterus_borneensis',
#  'ราชวงศ์แลงคาสเตอร์',
#  'อิโคโมส',
#  'ประเทศเบอร์มิวดาในโอลิมปิกฤดูร้อน_2012',
#  'Gynura_pseudochina',
#  'สิมอีสาน',
#  'นินจาจูน',
#  'สมิตา_สรสุชาติ',
#  'Hush_Hush;_Hush_Hush',
#  'รายพระนามพระมหากษัตริย์ไรอาเตีย',
#  'บรรณานุกรม',
#  'จูปิเตอร์,_เนพจูน_และพลูโต_(การาวัจโจ)',
#  'ทับศัพท์สเปน',
#  'Amager',
#  '"เวียร์ด_อัล"_แยนคอวิค',
#  'ซีเมอง_ปัวซง',
#  'ศูนย์สร้างสรรค์งานออกแบบ',
#  'เปาบุ้นจิ้น_(ละครโทรทัศน์_พ.ศ._2553)',
#  'ซอดองโย_สายใยรักสองแผ่นดิน',
#  'ค.ศ._972',
#  'เกาะราชา',
#  'กีฬาโรงเรียนอาเซียน_2011',
#  'พ.ศ.2510',
#  'พระมหากษัตริย์แห่งเยอรมนี',
#  'ฮาล์ฟออฟมายฮาร์ต',
#  'พระแม่มารีแห่งเซนิกาลเลีย',
#  'วิกิพีเดียภาษาลัตเวีย',
#  'ผักแว่นใบมัน',
#  'พ.ศ._1928',
#  'ฟังก์ชันคู่และคี่',
#  'เคแอลไอเอ_เอ็กซ์เพรส',
#  'สรุปเหรียญเอเชียนเกมส์',
#  'สายบิวาโกะ',
#  'อรทัย_กาญจนชูศักดิ์',
#  'ชาวไร่ชาวนา',
#  'วอลเลย์บอลชายชิงแชมป์โลก_1960',
#  'ปฏิรูปเมจิ',
#  'วัดบุหัวแหวน',
#  'ค.ศ._756',
#  'โทบี_แม็กไกวร์',
#  'ฌ็อง_เรโน',
#  'Nigel_de_Jong',
#  'มายเดียเรสต์',
#  'Jisoo',
#  'สาธิตจุฬา',
#  'ทางรถไฟสายมรณะ',
#  'Tera_Patrick',
#  'พระนางซูสีไทเฮา',
#  'ลับแล',
#  'ดีโน_อับเบรสชีอา',
#  'ดยุคแห่งชเลสวิก-โฮลชไตน์-ซอนเดอร์บวร์ก-กลึคสบวร์ก',
#  'RS',
#  'เอกโองการ',
#  'ภาษาพหุศูนย์',
#  'ผลการแปลงฟูเรียร์',
#  'อเล็กซ์_เฟอร์กูสัน',
#  'นอร์ด-ปาส์_เดอ_กาเลส์',
#  'กิ่วแม่ปาน',
#  'รายชื่อละครชุดทางโทรทัศน์ในจักรวาลภาพยนตร์มาร์เวล',
#  'Irish_potato_famine',
#  'รายชื่อรองประธานวุฒิสภาไทย',
#  'บริษัท_จีเอ็มเอ็ม_ทีวี_จำกัด',
#  'วิลโลว์_(เพลง)',
#  'ปลาเทราต์อเมริกาใต้',
#  'Hoya_ovalifolia',
#  'การรุกรานยูซาน_วอง',
#  'แวร์วูล์ฟ',
#  'วัดพระเขี้ยวแก้ว_(ศรีลังกา)',
#  'เมืองมณฑล',
#  'มาอาซิน',
#  'อ.นิคมพัฒนา',
#  'Phlyctidocarpa',
#  'เซยูอะวอดส์',
#  'เรสเซิลเมเนีย_ครั้งที่_10',
#  'ฉีหฺวันกง',
#  'คอรอร์',
#  'รัศมีของดาวพฤหัส',
#  'ช้างสะวันนา',
#  'หย่งจาง',
#  'พระยาศรีสุนทรโวหาร',
#  'วัดปู่เปี้ย',
#  'ปอนเฟร์ราดา']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

get_len(titles)
# Out:
# current: 353833
# diff: -9122

# %%
get_samples(titles)
# Out:
# ['ฉันทนา_กิตติยาพันธ์',
#  'โรงเรียนสวนกุหลาบวิทยาลัย_ธนบุรี',
#  'ซิลอนในโอลิมปิกฤดูร้อน_1948',
#  'จอมขมังเวทย์ออร์เฟน',
#  'WrestleMania_I',
#  'Marc-André_ter_Stegen',
#  'ดีบั๊ก',
#  'พระเจ้าพฤหทรถะเมารยะ',
#  'มรดกโลกในประเทศเกาหลีใต้',
#  'วิลาส_ญาณวโร',
#  'คิลต์',
#  'อะไมโลเพกทิน',
#  'วัดใหม่อัมพวัน',
#  'ประเทศในยูโรเปียนเกมส์',
#  'คอนตีเนนทัลฮอกกี้ลีก',
#  'Neuroblastoma',
#  'Island_Records',
#  'Krakow',
#  'การถ่ายภาพขยาย',
#  'เฟินก้านดำเขาพนม',
#  'The_Hunt_in_the_Forest',
#  'Epex',
#  'Love_across_the_ocean',
#  'Procol_Harem',
#  'รองเท้านารีอินทนนท์ลาว',
#  'เสียงในใจ',
#  'จักรพรรดิบาซิลิสคัส',
#  'แคมใหญ่',
#  'พิวเมคซิลลินัม',
#  'ทารุณกรรมทางเพศต่อเด็ก',
#  'เทรลรันนิง',
#  'geography',
#  'เวลาเฉลี่ยท้องถิ่น',
#  'Paresis',
#  'Triaenodon_apicalis',
#  'ไมเคิล_ตั๋ง',
#  'ยุทธการที่บาร์เนต',
#  'เจ้าพระยาบวรราชนายก',
#  'เอ็ดดี_เอ็นเคเตียห์',
#  'Hiun_Tsang',
#  'เจ้าพระยาพิษณุโลก',
#  'เอล_ชาปูลิน_โคโลราโด',
#  'ฟุตบอลทีมชาติเดนมาร์ก',
#  'กล้ามเนื้อเอกซ์เทนเซอร์_ดิจิไต_มินิไม',
#  'สนามกีฬาทืร์คเทเลคอม',
#  'สาธารณรัฐอัปเปอร์วอลตาในโอลิมปิก',
#  'โรงเรียนลาซาล_บางนา_กรุงเทพมหานคร',
#  'ลอแวช',
#  'ตลาดน้ำอัมพวา',
#  'คาร์ลอส_สลิม_เฮลู',
#  'House_of_the_dead',
#  'สมเด็จพระเจ้าบรมวงศ์เธอ_เจ้าฟ้าลา_กรมหลวงจักรเจษฎา',
#  'เวิลด์ควีนออฟบานาน่า',
#  'นรสิงห์_ก่อเกียรติยิม',
#  'เจ้าจอมประคอง_ในรัชกาลที่_5',
#  'TNA_X_Division_Championship',
#  'การแปลสิ่งเร้าทางสัมผัสผิด',
#  'หญ้าเหงาหลับ',
#  'Romblon',
#  'สแลมมี่_อวอร์ด',
#  'โรงเรียนบ้านบึง',
#  'บีบีซีชอยส์',
#  'วอลเลย์บอลอะคาเดมีลีก',
#  'Manogea_porracea',
#  'โรโบค็อพ',
#  'ศาสนวิชชาลัยรินไซ',
#  'Tomoaki_Maeno',
#  'มอนต์กอเมอรี_คลิฟต์',
#  'เอฟซี_โตเกียว',
#  'นีด_ฟอร์_สปีด',
#  'ประเทศเวียดนามในเอเชียนเกมส์_2014',
#  'นวนิยายของมักซิม_กอร์กี',
#  'พระโพธิรังสี',
#  'Laophontopsidae',
#  'สไมลีย์',
#  'สถานีโกะทันดะ',
#  'Zarifa_Ghafari',
#  'รายชื่อภาพยนตร์ของวอลต์ดิสนีย์แอนิเมชันสตูดิโอ',
#  'รายนามหัวหน้ารัฐบาลสตรีจากการเลือกตั้งหรือแต่งตั้ง',
#  'ไข้ฉี่หนู',
#  'การกำเนิดและวิวัฒนาการของระบบสุริยะ',
#  'Noise_pop',
#  'Aloe_decumbens',
#  'พี่น้องของเจนนี่',
#  'Leningrad',
#  'บุรญุลอะร็อบ',
#  'รินะ_ซาวายามะ',
#  'Vertically_transmitted_infection',
#  'ออร์กัต',
#  'Tycho-2_Catalogue',
#  'บีเดิล',
#  'มิสแกรนด์กรุงเทพมหานคร',
#  'เมคเคลนบูร์ก-ชเตรลิทซ์',
#  'อำเภอดงเจริญ',
#  'กีฬาสเกตบอร์ดในโอลิมปิกฤดูร้อน_2020_–_รอบคัดเลือก',
#  'Die_Blaue_Vier',
#  'สสวท.',
#  'Kami-Shirataki_Station',
#  'Braille',
#  'ไพรัช_นุชิต']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

get_len(titles)
# Out:
# current: 465912
# diff: 112079

# %%
get_samples(titles)
# Out:
# ['แอนาคินสกายวอล์คเกอร์',
#  'Artemisprogram',
#  'ราชรัฐลิพเพอ',
#  'รายชื่อธงในสาธารณรัฐจีน',
#  'โลเพราไมด์',
#  'Elops',
#  'เรียวทาโรโอคิอายุ',
#  'โรแบร์ตเทาเบอ',
#  'นาตาลีแอมานุแอล',
#  'ไวตาเป',
#  'ซีซั่น',
#  'อ.นิคมน้ำอูน',
#  'OrderofaMillionElephantsandWhiteParasol',
#  'สาธารณรัฐนาอูรูในโอลิมปิกฤดูร้อน',
#  'polkka',
#  'โนวัก',
#  'โลลิ',
#  'Papes',
#  'voice',
#  'อะโอะยะกิ',
#  'โอลกาฮาร์โมนี',
#  'VoronețMonastery',
#  'Natasha',
#  'พระธาตุขามแก่น',
#  'Onoda',
#  'จอร์จลูคัส',
#  'ไซนัล',
#  'ลูกัสกราเบียล',
#  'เอบีรีกา',
#  'วอลเลย์บอลชายเวิลด์คัพ1965',
#  'ปลาพีค็อกเบส',
#  'ฮิลฟิเกอร์',
#  'อิกัวนาฟิจิ',
#  'อุทยานธารงาม-ภูฝอยลม',
#  'ทาแลส',
#  'พรรคพัฒนาแห่งชาติบรูไน',
#  'ยุทธการที่ต๋งเค้า',
#  'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'สถาบันการอาชีวศึกษาเกษตรภาคกลาง',
#  'ทิตาวีร์',
#  '10DowningStreet',
#  'RQ-11Raven',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าอ๊อสคาร์นุทิศกรมหมื่นอนุวัตรจาตุรนต์',
#  'อาริเอช',
#  'ไทยลีกดิวิชัน1ฤดูกาล2553',
#  '2015AFFFutsalChampionship',
#  'เค็นจิอานัง',
#  'วอลเลย์บอลเวิลด์กรังด์ปรีซ์2008',
#  "Who's",
#  'ยายับยั้งเอซีอี',
#  'AircraftCommunicationsAddressingandReportingSystem',
#  'ไดตะลุยแดนเวทย์มนต์',
#  'เจ้าหญิงเฮเลนาวิกตอเรียแห่งชเลสวิก-โฮลชไตน์',
#  'BenediktHöwedes',
#  'ประธานมนตรีอินเดีย',
#  'ให้',
#  'TVGlobo',
#  'เสวต',
#  'ภาษาซังซุง',
#  'เบอร์นาร์ดเฮอร์มานน์',
#  'คริสแคนยอน',
#  'กล้ามเนื้อเฟลกเซอร์คาร์ไพอัลนาริส',
#  'Dakota',
#  'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูร้อน1992',
#  'กีโยมเลอฌ็องตี',
#  'เอวาเจลีนอาทาเนเซียแคทเทอรีนแม็คโดเวลล์',
#  'อุทกภัยในคีวชูพ.ศ.2563',
#  'เซบาสเตียนโคอาเตส',
#  'พระธาตุเจดีย์',
#  'หิณโทษ',
#  'หัวใจบรรเลง',
#  'โกปาอาเมริกา2015รอบชิงชนะเลิศ',
#  'อายูมิ',
#  'ภาษาถิ่นตากใบ',
#  'มหาวิหารโนเทรอดามแห่งเบยูซ์',
#  'Backdoorvirus',
#  'โรเบิร์ตฮุก',
#  'ลำดับโปเจียมแห่งราชอาณาจักรไทย',
#  'คุ้มเจ้าบุรีรัตน์มหาอินทร์',
#  'Diddy',
#  'ธนัชพันธ์',
#  'อุลคิโอร่าซีเฟอร์',
#  'ลัทธิไศวะ',
#  'กรณ์ภัสสร',
#  'Maid',
#  'Wheeler',
#  'ซีโลไฟซิส',
#  'SirGeorgeBiddellAiry',
#  'Judy',
#  'สมเด็จพระเจ้าแทโจ',
#  'วัดโบสถ์อินทรสารเพชร',
#  'YouAreMyDestiny',
#  'บรูนฮิลเดอ',
#  'ท่าพระ',
#  'อยากบอกว่ารัก',
#  'Hawaiian',
#  'เขมรโบราณ',
#  'ชวินทร์วุฒิก้องธรนินทร์',
#  'ทัสมาเนียนเดวิล',
#  'การถ่ายภาพยนตร์ฉากสำคัญ']

# %% [markdown]
# ### Exclude complete non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
#
# intend to remove non named entity which year included

# %%
titles = set([title for title in titles if "พ.ศ." not in title])

get_len(titles)
# Out:
# current: 459718
# diff: -6194

# %%
get_samples(titles)
# Out:
# ['เลขทะเบียนสากลของวัตถุอวกาศ',
#  'เซสน่า',
#  'ตังเซียม',
#  'จอห์นผู้ประกาศข่าวประเสริฐ',
#  'WWETLC:Tables,Ladders&Chairs',
#  'tarkin',
#  'Yudhoyono',
#  'ซูวาริส',
#  'สโมสรฟุตบอลด่งท้าป',
#  'DaleyBlind',
#  'โคลอีมอเรตซ์',
#  'กลุ่มภาษามาลาโย-โพลินีเซียน',
#  'Threskiornisaethiopicus',
#  'ดี!',
#  'AlaskaPermanentFund',
#  'al-Banna',
#  'เทพบุตรนักสู้พลิกลิขิตสวรรค์',
#  'เจ้าหญิงตาเตียนาแห่งลิกเตนสไตน์',
#  'อัลบั้มแทยัง',
#  'ฟลายอิงดัตช์แมน',
#  'โรงเรียนนครระยองวิทยาคม',
#  'เอลก์',
#  'ชายหาด',
#  'Kram',
#  'เฮียะคุจูเซนไทกาโอเรนเจอร์',
#  'ภาพยนตร์โรแมนติกคอเมดี',
#  'เจ้าสร้อยศรีสมุทรพุทธางกูร',
#  'จิรายุทธ',
#  'ซัลฟาเมโทซาโซล',
#  'ชาวอเมริกา',
#  'กีฬาบาสเกตบอลในเอเชียนเกมส์2022',
#  'แร่กาลีนา',
#  'เส้นเมริเดียนที่131',
#  'Moore',
#  'การอพยพของโซเวียตที่ทาลลินน์',
#  'เทศกาลโอลิมปิกฤดูร้อนเยาวชนยุโรป2017',
#  'Fauntleroy',
#  'โลกที่สาม',
#  'Psycho',
#  'พระเจ้าฮโยโซ',
#  'อาคารราชบัณฑิตยสถาน',
#  'Hinode,Tokyo',
#  'มุมของภูเขาฟูจิ',
#  'Working!!ร้านป่วนก๊วนหลุดโลก',
#  'MarioGötze',
#  'Institutpolytechniquedessciencesavancées',
#  'เฉลิมเกียรติ',
#  'เอเชียนาแอร์ไลน์',
#  'สถานีรถไฟบ่อเต็น',
#  'ซูแฌร์',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูหนาว1998',
#  "Cobblers'",
#  'อำเภอไชยา',
#  'CestelloAnnunciation',
#  'โชปรา',
#  'ซักกอเราะฮ์',
#  'EmperorQinzongofSong',
#  'เทรนต์บาร์เรตา',
#  'Fluorite',
#  'เอิร์ลแห่งนอร์ทแธมตันที่',
#  'ยอดเขาไกรลาส',
#  'V-2',
#  'ฌอร์ฌด็องตง',
#  'ฟ้อนสาวไหม',
#  'ฟุตบอลในเอเชียนเกมส์',
#  'สัตว์รังควาน',
#  'วัดโตนด',
#  'ความร่วมรู้สึก',
#  'นอร์ธรอปที-38ทาลอน',
#  'Kanamara',
#  'เครก',
#  'สปริกกัน',
#  'ภาษาอาหรับเยเมนของชาวยิว',
#  'ดวงเดือนณเชียงใหม่',
#  'RingsofNeptune',
#  'Almana',
#  'อี๋พุทธสโร',
#  'Shiki',
#  'Arfa',
#  'สถาบันอเมริกาในไต้หวัน',
#  'MetroExodus',
#  'Aerobics',
#  'วัดนครป่าหมาก',
#  'ผงห้าเครื่องเทศ',
#  'เคนทาโระซาคากุจิ',
#  'พินทุสรศรีณรงค์',
#  'Jasminumelongatumsubsp.Sootepense',
#  'ชูเอาชิลเบร์ตู',
#  'Stephansdom',
#  'เปียนมานา',
#  'หลอน...เฉียดนรก',
#  'Light-year',
#  'Trivium',
#  '30สิงหาคม',
#  'สัตยาไสบาบา',
#  'เบิร์กลีย์โอเพนอินฟราสตรักเชอร์ฟอร์เน็ตเวิร์กคอมพิวติง',
#  'สาขานักแสดงนำหญิงยอดเยี่ยมประเภทละครโทรทัศน์',
#  'ฌ็องเคานต์แห่งปารีส',
#  'โฮเฮ็นเสตาเฟ็น',
#  'ระดับน้ำตาลในเลือดสูง']

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

get_len(titles)
# Out:
# current: 340300
# diff: -119418

# %%
get_samples(titles)
# Out:
# ['เฉียวเอิน',
#  'จันทร์แจ่ม',
#  'สถาบันนวัตกรรมการเรียนรู้',
#  'ยีราฟรอทส์ไชลด์',
#  'ฟูลอัส',
#  'ความคุ้มกันที่ให้แก่พระมหากษัตริย์',
#  'พุทธสถานในพื้นที่โฮรีวจิ',
#  'ยามางะ',
#  'สเวนสด็อททีร์',
#  'วงศ์มณเฑียรทอง',
#  'เหตุเครื่องบินของเจแปนแอร์ไลน์เฉียดกันที่อ่าวซูรูงะ',
#  'ก็อตต์ลีบเดมเลอร์',
#  'จักรวรรดิออตโตมัน',
#  'อ่อนวิมล',
#  'ฮิสทอรี:พาสเพรสเซนต์แอนด์ฟิวเจอร์บุ๊คI',
#  'สุวัจชัย',
#  'เจ้าชายเรซา',
#  'เหลียงเฉาเหว่ย',
#  'ประเทศนอร์ทมาซิโดเนียในโอลิมปิกฤดูหนาว',
#  'เพียวฤดีพงษ์ประเสริฐ',
#  'สงครามพระเจ้าหงสาวดีตะเบ็งชะเวตี้',
#  'เจ้าฟ้าอุบลรัตนราชกัญญา',
#  'เอแมท',
#  'เค็นตะมิยาเกะ',
#  'แม่น้ำเฌลัม',
#  'ลำดับ',
#  'สมเด็จพระธรรมราชรธิราชรามาธิบดีที่1',
#  'เจ้าฟ้าชายอเมเดโอแห่งเบลเยียมอาร์ชดยุกแห่งออสเตรีย-เอสเต',
#  'การเลือกตั้งประธานาธิบดีสหรัฐค.ศ.2004',
#  'เรือนนาค',
#  'อาหารโอกินาวะ',
#  'เกาะปังกอร์',
#  'ฟาฏิมะ',
#  'ทรนง',
#  'ลัทธิความเป็นอคติต่อชาวยิว',
#  'โปรแกรมลีกภูมิภาคกรุงเทพและปริมณฑล2552',
#  'หนังสือเพลงสวดสดุดีตอมีชอฟ',
#  'ดีวีดี-รอม',
#  'กราฟิกดีไซน์',
#  'โกออนเจอร์',
#  'ชีโซไฮ',
#  'เจ้าฟ้าชายวิลเล็ม-อเล็กซานเดอร์',
#  'ทีด้า',
#  'เรือนเครื่องผูก',
#  'แผ่นดินไหวในปวยบลา',
#  'บราเตียนู',
#  'อาณาจักรโปรตุเกสบราซิลและแอลการ์ฟ',
#  'เขตมุขนายก',
#  'ยะมะซะกิอะโอะอิ',
#  'เตนจิงนอร์เก',
#  'สระอา',
#  'เคิร์กฮอร์น',
#  'ตาแทนตาและฟันแทนฟัน',
#  'ปาล์มไมรา',
#  'โรคของระบบย่อยอาหาร',
#  'อเมริกันขนสั้น',
#  'ไนล์เพิร์ช',
#  'เซอร์เกคาซาคอฟ',
#  'ซาวาชิโระมิยุกิ',
#  'คิเนคสตาร์วอร์ส',
#  'คนค่อมแห่งนอทร์-ดาม',
#  'สหพันธ์ฟุตบอลกินี',
#  'คืยซิล',
#  'โซนิ',
#  'อนุราธปุระ',
#  'ชาวเปอร์เซีย',
#  'กาแฟอเมริกาโน',
#  'เอ็มเมอริค',
#  'อัชชูร์',
#  'หยวนเย',
#  'เครื่องกระตุกหัวใจไฟฟ้าชนิดอัตโนมัติ',
#  'ชาฟฟ์เฮาเซิน',
#  'สโมสรฟุตบอลเชลซีในฤดูกาล2003–04',
#  'คุณหมอหัวใจแกร่ง',
#  'แดร์อิสอะเฮลล์,',
#  'เซฮ์รา',
#  'เบรนเนร์',
#  'ด็อยท์เชอเว็ลเลอ',
#  'ฮิลลารี',
#  'ลูกทุ่งไอดอลซีซั่นหญิง',
#  'เหว่ยตง',
#  'ไอนด์โฮเวน',
#  'กีฬาบิลเลียดและสนุกเกอร์ในซีเกมส์2015',
#  'จังหวัดล็องอาน',
#  'โมเมนต์',
#  'เซฟโฟแทกซิม',
#  'วราภัทร์',
#  'เจ้าชายฮันส์-อาดัมที่2เจ้าผู้ครองลีชเทินชไตน์',
#  'รายพระนามจักรพรรดิแห่งโรมันอันศักดิ์สิทธิ์',
#  'ชียงชู',
#  'คิวชูเดอะซีรีส์',
#  'ซอยเจ้าคำรบ',
#  'สังฆาทิเสส',
#  'รายนามประมุขแห่งบาวาเรีย',
#  'ไฟนอลแฟนตาซี:อันลิมิตเต็ด',
#  'สโมสรวอลเลย์บอลหญิงนครราชสีมาในฤดูกาล2019–20',
#  'ดอกคิวเสต',
#  'มะขามป้อมดง',
#  'เจ้าผู้ครองลิกเตนสไตน์',
#  'แม็กซิมินุส']

# %% [markdown]
# ### Seperate by non-thai character
#
# such as ".", ":", "-"

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(re.split("[^\u0E00-\u0E7F]+", title))
    
titles = titles_temp
get_len(titles)
# Out:
# current: 305063
# diff: -35237

# %%
get_samples(titles)
# Out:
# ['สภานานาชาติว่าด้วยการดูแลอนุสรณ์สถานและแหล่งโบราณคดี',
#  'เจ้าชายหฤทเยนทระแห่งเนปาล',
#  'บรอนสันรีด',
#  'ตระกูลภาษา',
#  'เซ็งเค',
#  'ปริศนากัมพูสิริ',
#  'สำนักกษาปณ์',
#  'หลี่หง',
#  'ลลิตาไพศาล',
#  'ดอกเตอร์ออกโทปุส',
#  'กีตาร์เอฟเฟกต์',
#  'ยุทธการวินซบีย์',
#  'พีซทีวี',
#  'วัดวีส์',
#  'เจมีสกอตต์',
#  'เพสลีย์',
#  'เรือพี่น้อง',
#  'ฮิโตมิ',
#  'ลิงจ๋อไม่หลอกจ้าว',
#  'เมดูซ่า',
#  'ฆวนเปรอน',
#  'กระทรวงธุรกิจ',
#  'สปีกนาว',
#  'แฟ้ม',
#  'บราห์ม',
#  'ธงชาติวานูวาตู',
#  'กล้องจุลทรรศน์อิเล็กตรอนแบบส่องผ่าน',
#  'ไทฟัส',
#  'ฟลิปฟล็อป',
#  'เมฆแมเจลแลนเล็ก',
#  'เคียวจิ',
#  'ระบบห้องสมุดรัฐสภา',
#  'รถไฟฟ้าเอราวันสายซิตี้',
#  'พระพุทธบุษยรัตน์จักรพรรดิพิมลมณีมัย',
#  'รายงานผู้ป่วย',
#  'ไฮนทซ์ฮ็อฟมัน',
#  'ยูลบรีนเนอร์',
#  'ทองมี',
#  'สวนหลวงร',
#  'ฮูลิโอซีซาร์ชาเวซ',
#  'อากอน',
#  'แนวคิดโลกเป็นศูนย์กลางจักรวาล',
#  'คนเรียกผี',
#  'สหพันธ์มวยปล้ำโลก',
#  'พูบลิอัส',
#  'ปากน้ำโพ',
#  'ทรูฮิต',
#  'ทีมดราก้อนคุณหมอหัวใจแกร่ง',
#  'ปลาเอิน',
#  'รถไฟใต้ดินแอตแลนตาสายสีเขียว',
#  'ราชเลขาธิการ',
#  'พระพุทธรูปมิ่งเมือง',
#  'จาดนอก',
#  'ปรากฏการณ์มั่นใจมากเกินไป',
#  'จักรพรรดิหมินตี้',
#  'ขบวนการเทพสวรรค์โกเซย์เจอร์',
#  'ฟรานซิสโกโอลิเวนเซีย',
#  'โกทัลแบซูซาแด',
#  'เจ้าชายมัคซีมีลีอานแห่งบาเดิน',
#  'ครอบครัวเพื่อไทย',
#  'สาลิกาเขียว',
#  'โรงเรียนเฉลิมขวัญสตรี',
#  'เมทริกซ์เครื่องหมายสลับ',
#  'อาณาจักรเคานท์แห่งโอลเดนบวร์ก',
#  'วัยกระเตาะตึ่งตึงตึ๊ง',
#  'ดุน',
#  'เซ็นโทะชิฮิโระโนะคะมิกะกุชิ',
#  'เกาะไหหลำ',
#  'อีโคไล',
#  'โกรีว',
#  'การุณใสงาม',
#  'ฟาโรห์เซเคเนนเรทาโอ',
#  'บำรุงพงศ์',
#  'อุลตร้าแมนทีก้า',
#  'ดนตรีเกาหลีใต้ใน',
#  'รีเมมเบอร์มี',
#  'หน้าผาการคลังสหรัฐอเมริกา',
#  'แอมบิชันส์',
#  'ทาเกฮิโตะโคยาซุ',
#  'แผนการสู่ประชาธิปไตย',
#  'เบชิง',
#  'โรงเรียนมหาวิชานุกูล',
#  'อินโนเวียโมโนเรล',
#  'ไปรยาดึเซาราฟาแอล',
#  'สหมณฑลแห่งอเมริกากลาง',
#  'จักรวรรดิไบเซนไทน์',
#  'อีบูเปอร์ตีวี',
#  'ทะเลกรุงเทพ',
#  'ธงชาติสหรัฐอเมริกา',
#  'เจิ้งไคฮีโร่เกรียนกู้โลก',
#  'ทวนวงเดือน',
#  'บังคมเนตร',
#  'ไทยทาวน์',
#  'ประทุมวงศ์',
#  'บ้านม่วง',
#  'ยาแก้ซึมเศร้า',
#  'โมฮาเหม็ดซาลาห์',
#  'รายชื่อตอนในมิสเตอร์',
#  'สระศักดิ์สิทธิ์ทั้งสี่',
#  'มาเอดะเก็นโซ']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4621

# %%
get_samples(raay)
# Out:
# ['รายชื่อคณะเทคโนโลยีในประเทศไทย',
#  'รายพระนามกษัตริย์รัสเซีย',
#  'รายนามรองชนะเลิศมิสเตอร์โกลบอล',
#  'รายชื่อภาพยนตร์การ์ตูนที่ฉายทางทีวีอาซาฮิ',
#  'รายพระนามพระมหากษัตริย์อัสตูเรียส',
#  'รายชื่อตอนในอีวานเกเลียน',
#  'รายนามรองชนะเลิศมิสแกรนด์ไทยแลนด์',
#  'รายชื่อเมธีวิจัยอาวุโสสกว',
#  'รายนามประมุขมิสซังสยาม',
#  'รายพระนามเทวดาแห่งน้ำ',
#  'รายชื่อผลงานเพลงของศักดิ์สิทธิ์เวชสุภาพร',
#  'รายชื่ออัลบั้มประจำตัวละครในฮายาเตะพ่อบ้านประจัญบาน',
#  'รายชื่อคณะรัฐศาสตร์ในประเทศไทย',
#  'รายชื่อธงประจำจังหวัดของไทย',
#  'รายชื่อนามสกุลที่ใช้กันมาก',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์เฮติ',
#  'รายชื่อแอนิเมชันสตูดิโอญี่ปุ่น',
#  'รายชื่อธงในประเทศฮังการี',
#  'รายชื่อเมืองในประเทศแอนติกาและบาร์บูดา',
#  'รายชื่อพรรคการเมืองในประเทศกัมพูชา',
#  'รายพระนามจักรพรรดิราชวงศ์ถัง',
#  'รายชื่อประเทศที่ร่วมแข่งขันกีฬาโอลิมปิกฤดูร้อน',
#  'รายชื่อมลรัฐในสหรัฐอเมริกา',
#  'รายชื่อสารโมเลกุลชีวภาพ',
#  'รายชื่อตัวละครในเบอร์เซิร์ก',
#  'รายชื่อวัดในจังหวัดชัยภูมิ',
#  'รายชื่อผู้เข้าแข่งขันเทนนิสยูเอสโอเพนรอบชิงชนะเลิศ',
#  'รายชื่อประเทศตามระบบรัฐบาล',
#  'รายงานประจำปี',
#  'รายชื่อตัวละครในดิเอ็กซ์เพ็นเดเบิลส์',
#  'รายชื่อตัวละครในแบล็กโคลเวอร์',
#  'รายชื่อศูนย์การค้าในประเทศไทย',
#  'รายชื่อผลงานของอุรัสยาเสปอร์บันด์',
#  'รายชื่อคณะวิทยาลัยและสำนักวิชาเภสัชศาสตร์ในประเทศไทย',
#  'รายาแห่งซาราวะก์',
#  'รายชื่อประเทศเรียงตามผลผลิตฟลูออไรต์',
#  'รายชื่อบุคคลจากจุฬาลงกรณ์มหาวิทยาลัย',
#  'รายนามแชมป์โลกมวยสากลปัจจุบัน',
#  'รายชื่อธงในประเทศสเปน',
#  'รายนามรัฐมนตรีว่าการทบวงมหาวิทยาลัยของไทย',
#  'รายชื่อผู้ถือธงชาติไทยในโอลิมปิก',
#  'รายนามนักเรียนเก่า',
#  'รายชื่อตัวละครในมายลิตเติ้ลโพนี่มิตรภาพอันแสนวิเศษ',
#  'รายชื่อโบราณสถานในจังหวัดขอนแก่นที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อตอนในแขนกล',
#  'รายชื่อของการสังหารหมู่ในประเทศมาเลเซีย',
#  'รายชื่อประเทศเรียงตามประชากรเมือง',
#  'รายนามปลัดกระทรวงคมนาคมของไทย',
#  'รายชื่อขบวนการแบ่งแยกดินแดนปัตตานี',
#  'รายชื่อรหัสประเทศโดยฟีฟ่า',
#  'รายชื่ออัลบั้มเพลงของพุ่มพวง',
#  'รายชื่อนครในประเทศอาร์เจนตินาเรียงตามจำนวนประชากร',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์กรีซ',
#  'รายชื่อโปเกมอน',
#  'รายชื่อพระอิสริยยศและพระเกียรติยศในพระบาทสมเด็จพระวชิรเกล้าเจ้าอยู่หัว',
#  'รายชื่ออาวุธและวิชาโจมตีในเทพมรณะ',
#  'รายชื่อแหล่งมรดกโลกในประเทศซูดาน',
#  'รายชื่อธงในประเทศแอลเบเนีย',
#  'รายชื่อวัดในจังหวัดสิงห์บุรี',
#  'รายพระนามรัชทายาทรัสเซีย',
#  'รายชื่อกษัตริย์ตองกา',
#  'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย',
#  'รายชื่อแหล่งมรดกโลกในภูมิภาคเอเชียตะวันออกเฉียงใต้',
#  'รายพระนามพระมหากษัตริย์สเปน',
#  'รายชื่อระบบรถไฟใต้ดินในทวีปอเมริกาเหนือเรียงตามจำนวนผู้โดยสาร',
#  'รายชื่อผลงานคอนเสิร์ตของผลิตโชคอายนบุตร',
#  'รายชื่อภาพยนตร์โปเกมอน',
#  'รายชื่อสะพานในประเทศไทย',
#  'รายชื่อวัดในจังหวัดสตูล',
#  'รายพระนามพระมหากษัตริย์ทั่วโลกที่ครองราชย์สั้นที่สุด',
#  'รายพระนามพระมหากษัตริย์โบราโบรา',
#  'รายชื่อนิยายวิทยาศาสตร์ไทย',
#  'รายชื่อวัดในจังหวัดหนองบัวลำภู',
#  'รายพระนามจักรพรรดิจีนในราชวงศ์ฉิน',
#  'รายชื่อตอนในคุณครูจอมเวท',
#  'รายชื่อประเทศเรียงตามดัชนีมวลกาย',
#  'รายชื่อโบราณสถานในจังหวัดตาก',
#  'รายชื่อค่ายทหารในสังกัดกองทัพบกไทย',
#  'รายชื่อการแสดงสดของเทย์เลอร์สวิฟต์',
#  'รายชื่อประเทศเรียงตามการส่งออกข้าวโพด',
#  'รายชื่อนครเมืองและหมู่บ้านในประเทศบาร์เบโดส',
#  'รายชื่อนักแสดงภาพยนตร์ลามกเกย์',
#  'รายนามนักเขียนและรายชื่อผลงานที่ได้รับรางวัลพานแว่นฟ้า',
#  'รายชื่อฮอร์โมนในมนุษย์',
#  'รายนามประธานาธิบดีลาว',
#  'รายชื่อโรงเรียนในกรุงเทพมหานคร',
#  'รายชื่อตัวละครในขบวนการเวทมนตร์',
#  'รายพระนามเทพเจ้าจีน',
#  'รายชื่อผู้ได้รับรางวัลบทภาพยนตร์ดัดแปลงยอดเยี่ยม',
#  'รายชื่อเพลงที่เขียนโดยคิมจง',
#  'รายนามสุภาพสตรีหมายเลขหนึ่งแห่งสหรัฐอเมริกา',
#  'รายชื่อบทประพันธ์ยอดเยี่ยมรางวัลตุ๊กตาทอง',
#  'รายนามนายกรัฐมนตรีตองงา',
#  'รายนามผู้ประกาศข่าวและผู้รายงานข่าวสถานีโทรทัศน์ทีเอ็นเอ็น',
#  'รายชื่อแหล่งมรดกโลกในประเทศฝรั่งเศส',
#  'รายชื่อนายกรัฐมนตรีอินโดนีเซีย',
#  'รายชื่อเครื่องอิสริยาภรณ์โครเอเชีย',
#  'รายชื่อรางวัลที่ธงไชย',
#  'รายชื่อประเทศในภาษาต่างๆ',
#  'รายชื่อผลงานอัลบั้มเพลงของเซลีน']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 55

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายได้',
#  'รายตา',
#  'รายาแห่งรัฐปะลิส',
#  'รายวนปูเลาเกอลาปา',
#  'รายงานทีหลัง',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายานนท์',
#  'รายคอวิช',
#  'รายาผิวขาว',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายงานกรณี',
#  'รายงานความสุขโลก',
#  'รายได้พื้นฐาน',
#  'รายยวา',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายงานเฮิร์ช',
#  'รายกอวิช',
#  'รายูวันปูเลาเกอลาปา',
#  'รายาแห่งซาราวัก',
#  'รายาบีรู',
#  'รายงานผู้ป่วย',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายหัว',
#  'รายาแห่งซาราวะก์',
#  'รายาฮีเจา',
#  'รายได้มูลฐาน',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายวน',
#  'รายงานเค้ส',
#  'รายา',
#  'รายงานประจำปี',
#  'รายงานค่าใช้จ่าย',
#  'รายาห์',
#  'รายาฮีเยา',
#  'รายงานคนไข้',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายงานเฮิรส์ช',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายากับมังกรตัวสุดท้าย',
#  'รายงานการประชุม',
#  'รายนานนท์',
#  'รายงานเคส',
#  'รายได้ประชาชาติ',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายาประไหมสุหรีอากง',
#  'รายากูนิง',
#  'รายาอูงู',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
get_len(titles)
# Out:
# current: 300497
# diff: -4566

# %%
get_samples(titles)
# Out:
# ['อำเภอเมืองแม่ฮ่องสอน',
#  'ฮิการิโนะโอ',
#  'ฌ็องพีอาเจต์',
#  'การเชื่อมโยงบทความ',
#  'ซีฟีลด์',
#  'พลังสามัคคี',
#  'อิมแรนอจ',
#  'เจไดเครียร',
#  'การฉ้อโกงบัตรเครดิต',
#  'การผลิตข้าวในประเทศไทย',
#  'กรูฟ',
#  'เปอร์ออกซิโซม',
#  'แผ่นดินไหวในภาคกลางของประเทศอิตาลี',
#  'บัค',
#  'บาทไรเคินฮัล',
#  'อู้ยาซะ',
#  'ปลาข้าวสาร',
#  'เจ้าชายฟิลิปแห่งยูโกสลาเวีย',
#  'การจัดหมวดหมู่หนังสือ',
#  'จังหวัดซีลางังเนโกรส',
#  'โอเซ',
#  'เชนเฟอร์กัสสัน',
#  'สตีเวนิจ',
#  'ไมเคิลแอนเจโล',
#  'หลิงหูชง',
#  'จักรพรรดิเว่ยเจียหมิน',
#  'ซีโมนเศโลเท',
#  'การแพร่สารแบบฟาซิลิเทต',
#  'วายุภักษ์',
#  'โมซิซแลค',
#  'เจ้าชายหลุยส์ดยุกแห่งเบรอตาญ',
#  'เอนเตอร์เทนเมนท์',
#  'เลดีนิโคลัสวินด์เซอร์',
#  'เครื่องยิงจรวดหลายลำกล้อง',
#  'อากางกษา',
#  'แคว้นรอสตอฟ',
#  'เม็คเล็นบูร์ก',
#  'องศาใต้',
#  'ออมเนียมบุคคลหญิง',
#  'พลตำรวจเอกพจน์เภกะนันทน์',
#  'สุราษฎร์ธานี',
#  'บัวหลวง',
#  'ซัสกียา',
#  'ตำบลอุตตรสิริ',
#  'แอ๊บโซลูท',
#  'มาห์ดิ',
#  'ฤๅษีโคดม',
#  'ยานเมสเซนเจอร์',
#  'เหยี่ยวเคสเตรล',
#  'โชยะจิบะ',
#  'โอทสึกะอากิโอะ',
#  'อเล็กซานเดอร์คาร์ตไรต์',
#  'อันจื่อเจี๋ย',
#  'รัฐธรรมนูญพุทธศักราช',
#  'หลี่เหม่ยฉี',
#  'สโนว์ไวต์กับคนแคระทั้งเจ็ด',
#  'เบจูฮยอน',
#  'งานปริทัศน์อย่างเป็นระบบ',
#  'ท่าอากาศยานนานาชาตินาริตะ',
#  'จ่ายเจริญ',
#  'ไทชิมุราตะ',
#  'อำเภอปาย',
#  'เฮนรีจูเลียสดยุคแห่งบรันสวิค',
#  'โอเว่น',
#  'ยุกิรุ',
#  'ทะกะชิอุซะมิ',
#  'ชนองโซ',
#  'ลุดวิกผู้เยาว์',
#  'โต๊ะกลมโทรทัศน์',
#  'ดีอาร์ดีโอทักษ์',
#  'ลาริสซา',
#  'มินิอัลบั้มของออนแอนด์ออฟ',
#  'อันดรอส',
#  'มือปืนโลก',
#  'น้ำตกฮว๋างกว่อฉู้',
#  'เมาส์',
#  'ตาเขมา',
#  'อาเลสซันโดรเชิพฟ์',
#  'สถูปอัมลุกดารา',
#  'ว่านน้ำทอง',
#  'แสงอนันต์',
#  'เกาะโรบเบิน',
#  'เซี่ยเหยาหวน',
#  'ซเช',
#  'ตำบลด่านเกวียน',
#  'แคว้นเลนินกราด',
#  'รถไฟใต้ดินโทเอ',
#  'วังจะบังตีกอ',
#  'ที่หยุดรถไฟบ้านปลักแรด',
#  'รอยซ์แฟนทอม',
#  'วัดถั่วทอง',
#  'ฟุตบอลโอลิมปิกทีมชาติเยอรมนี',
#  'กาโอ',
#  'การลดมิติ',
#  'รดารงค์',
#  'กรมการรักษาดินแดน',
#  'ป้อมสนาม',
#  'หม่อมเจ้าดวงทิพย์โชติแจ้งหล้ารพีพัฒน์',
#  'โนแลนนอร์ท',
#  'เวสลีย์สมิธอัลวีสเฟย์โตซา']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal ranks and titles
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# No need processing -> name redirection of wikipedia already covered this problem.

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [title for title in titles if "ใน" in titles]
len(nai)
# Out:
# 300497

# %%
[nai][:50]
# Out:
# [['',
#   'แอฟริกันคัพ',
#   'ก็อดฟาเธอร์',
#   'กีฬากีฬาเอ็กซ์ตรีมในกีฬาแห่งชาติ',
#   'ไมจันตาน',
#   'อัลเฟรดฮิตค๊อกซ์',
#   'รวมเพลงคาราบาว',
#   'ลูคาริโอ',
#   'องค์การนาโต',
#   'การประท้วงโดยเผาตัวตายของชาวทิเบตในประเทศจีน',
#   'แก๊งสกัล',
#   'คะนะอุเอะมุระ',
#   'ชูบุง',
#   'สโมสรฟุตบอลเอร์กูเลส',
#   'ลาลิกา',
#   'ฉุยเปี่ยน',
#   'บรั่นดี',
#   'ครอบครัวตึ๋งหนืดตืดขั้นเทพ',
#   'โตโยต้าลีกคัพ',
#   'บอร์โซ',
#   'สายลับเดอะซีรี่ส์กับ',
#   'ธันเดอร์โซน',
#   'ป่าไม้เขตร้อน',
#   'สพ',
#   'ขอเกิดใหม่ใกล้ๆเธอ',
#   'สกุลปลากริม',
#   'เล่าอิ้ว',
#   'ฮอลลีวูดวูร์',
#   'แวร์เนอร์ฟ็อนบล็อมแบร์ค',
#   'ปฏิบัติการไรน์ฮาร์ท',
#   'โชคทวีพรหมรัตน์',
#   'วิลเฮ็ล์มบวร์คดอร์ฟ',
#   'การสลายปลดปล่อยรังสีบีตา',
#   'ยาระงับปวด',
#   'อุระซะวะ',
#   'เบรสต์',
#   'ประเทศชาดในโอลิมปิก',
#   'ถ้าเลือกได้',
#   'พระวรวงศ์เธอพระองค์เจ้าสายสนิทวงศ์',
#   'เออีดับเบิลยูทีเอ็นทีแชมเปียนชิป',
#   'โป๊ะแตกนิวส์',
#   'องค์ชายยองโพ',
#   'นายรำคาญ',
#   'ซีคลีนเนอร์',
#   'ชาร์ลส์โคค',
#   'นักชาตินิยม',
#   'รถไฟใต้ดินเม็กซิโกซิตี',
#   'เอี๊ยทิซิม',
#   'กาดีร์',
#   'อิสราเอลซูเปอร์คัพ',
#   'มหาวิทยาลัยนอร์ทเชียงใหม่',
#   'นิ่มสุวรรณ',
#   'พระองค์เจ้าหัสดินทร์',
#   'ท้าวสมศักดิ์',
#   'ประมุขของรัฐ',
#   'อับดุลฮะกีมจาน',
#   'อาหรับเอมิเรตส์',
#   'พื้นที่และบริเวณศักดิ์สิทธิ์รอบภูเขาบูร์คันคัลดุน',
#   'เคิร์ทสตยูเดนท์',
#   'วันเพ็ญพร้อมพัฒน์',
#   'กีฬาขี่ม้าในแพนอเมริกันเกมส์',
#   'เดอซิว',
#   'เจริญจิตต์',
#   'ทูลขิปฺปปญฺโญ',
#   'การนัดหยุดงานของสมาคมนักเขียนแห่งอเมริกา',
#   'เซ็นเซอร์นำทางความละเอียดสูง',
#   'ชินเฮ',
#   'เฟิงชุ้ยฟาน',
#   'กาญจนา',
#   'ข้าวซ้อม',
#   'ธันวาบุญสูงเนิน',
#   'เมลาโนมา',
#   'จุนซาบูโร',
#   'จักรวรรดิบาบิโลเนีย',
#   'สถานีรถไฟหลักบ็อน',
#   'ครัสนายาซเวซดา',
#   'แต',
#   'พระตำหนักวังสวนกุหลาบ',
#   'ไททีวี',
#   'อังเกอลา',
#   'เจโอวัน',
#   'โคกะ',
#   'วัดบางเบิด',
#   'สีหนุ',
#   'บากิมู',
#   'นาวาเอก',
#   'ประเทศลัตเวียในพาราลิมปิกฤดูร้อน',
#   'โจวเจี๋ย',
#   'ดาบซามูไร',
#   'บุลลีบูลัน',
#   'บุญเลิศสว่างกุล',
#   'รัฐเตลังคานา',
#   'ริฮานนา',
#   'แมตทิว',
#   'กองทัพประชาชนเวียดนาม',
#   'ป่ากงเปียญ',
#   'เอเอฟแอลพี',
#   'แร้งเทาหลังขาว',
#   'เป้าชูหยา',
#   '๑๖กรกฎาคม',
#   'นิมร์',
#   'สมเด็จพระสังฆราชวัดสวรรคเจดีย์',
#   'สถานีกักเก็บพลังงานไฟฟ้าฮอร์นสเดล',
#   'รัฐประหารตนเอง',
#   'อำเภอแคนดง',
#   'ทอมโบแอสต์',
#   'เดสมอนด์โรเบิตส์',
#   'โรงคัดหนังสือ',
#   'มาร์กชัทเทิลเวิร์ธ',
#   'ฌูเลียง',
#   'พังงา',
#   'วัดปากคาน',
#   'ปาร์กจินยัง',
#   'กอร์คคันเตอร์',
#   'ชาวอินเดีย',
#   'เปาโลดาซิลวา',
#   'พระเจ้าฮึลแฮแห่งชิลลา',
#   'คุณหญิงพจมานณป้อมเพชร',
#   'โรงเรียนราชนันทาจารย์สามเสนวิทยาลัย๒',
#   'เกียรติศักดิ์ธานี',
#   'ภูมิภาคชูโกกุ',
#   'เพ็ตโซไซตี',
#   'เวลันสมิตเธอส์',
#   'อัลวินกับสหายชิพมังค์',
#   'โลมาหัวขวดธรรรมดา',
#   'เลิศรัตนชัย',
#   'เหตุการณ์น้ำท่วมที่แม่น้ำหวง',
#   'เมตต์เฟรเดอริกเซน',
#   'เมทินีกิ่งพโยม',
#   'ไอนส์ลีย์เมตแลนด์',
#   'วัดสาขลา',
#   'รางวัลสิงโตทองคำ',
#   'สมเด็จพระแก้วมณีโชติ',
#   'กันหลง',
#   'สมเด็จเจ้าฟ้าสุทธาทิพยรัตน',
#   'สัตยวงษ์',
#   'ตำบลสบแม่ข่า',
#   'เกรย์เฮเว่นส์',
#   'ชินบำรุงพงศ์',
#   'คริสตียองเดอกาสตรี',
#   'พระแม่มารีแห่งโรซารี',
#   'ทองจุลกลาง',
#   'โชยะจิบะ',
#   'บัดดีฮอลลี',
#   'ซายึมิมีจีชีเงะ',
#   'เปรสติอันนิ',
#   'ท่าอากาศยานนานาชาติโอเอกูซี',
#   'คาถาพาต๊อง',
#   'ซีอีวีแชมเปียนส์ลีก',
#   'แองกลีไซต์',
#   'ฟาโรห์คาเฟร',
#   'ดยุกแห่งกลอสเตอร์',
#   'ระบบขนส่งมวลชนนครราชสีมา',
#   'การร้องประสานเสียง',
#   'เจลลีฟิชเอนเตอร์เทนเมนต์',
#   'บัดชตูเบอร์',
#   'สถานีเซรีวมิฮาราชิ',
#   'เชิ่น',
#   'รักโดนใจ',
#   'บทกวี',
#   'ศรีมริอัมมันมนเทียร',
#   'สหพันธ์อาหรับ',
#   'เอเชียเทเลวิชัน',
#   'อับดุลลอฮ์อันนะซูร',
#   'ตรัยนิ่มทวัฒน์',
#   'ออลบริชท์',
#   'รังสีแอลฟา',
#   'ฮาร์กรีฟส์',
#   'ลักส์',
#   'การแบ่งชนิดและสัณฐานของดาราจักร',
#   'รีเมนชไนเดอร์',
#   'การล่วงละเมิดทางเพศเด็ก',
#   'จุดตัด',
#   'ชาวชวา',
#   'มาร์ชฟอร์เอาเออร์ไลฟ์',
#   'เค็งคิตะมุระ',
#   'เก็บรัก',
#   'แม่น้ำเซาฟรันซิสกู',
#   'พระราชพิธีพระราชเพลิงพระศพสมเด็จพระเจ้าภคินีเธอ',
#   'ศรีนวล',
#   'อีวอวา',
#   'อูโน่',
#   'สวรรณาวิชัยรัตน์',
#   'นักธรรมชั้นโท',
#   'เจ็ตเตอร์มาร์',
#   'เรือดำน้ำ',
#   'จิตติพจน์',
#   'แกรฟีน',
#   'การเบียดเบียนคริสต์ศาสนิกชนในจักรวรรดิโรมัน',
#   'นักฟุตบอลเกิดปีค',
#   'โคอิมบรา',
#   'ไทรโลจี',
#   'เจมส์วาน',
#   'เอชอาร์กีเกอร์',
#   'วัสตุสังครหาลัย',
#   'โรงเรียนเสนาธิการทหารบก',
#   'โรงเรียนสิงห์บุรี',
#   'ฮิรากิ',
#   'ไพนีน',
#   'ลีกภูมิภาคดิวิชั่น',
#   '๒๐กรกฎาคม',
#   'แองเจลิน่าโจลี่',
#   'พระอัคนิ',
#   'ยูกิมูไร',
#   'วิทยาลัยช่างกลปทุมวัน',
#   'เวล์ฟ',
#   'เดลาโน',
#   'ดิจิมอนยูนิเวิร์สแอปพลิมอนสเตอร์ส',
#   'ทัศนาบุญทอง',
#   'อัลกอซิม',
#   'คณะศิลปประยุกต์และสถาปัตยกรรมศาสตร์',
#   'กัมพลปฐมอรรฆย์กุล',
#   'ดินแดนโพ้นทะเลบริติช',
#   'กันส์แอนด์โรส',
#   'แซนเดอร์',
#   'สะพานอัลอะอิมมะฮ์',
#   'วิกฤตการณ์ไครเมีย',
#   'ปานาเระ',
#   'วิเชษฐ์เกษมทองศรี',
#   'ไทร่าแบงก์ส',
#   'ถัวป้าอวี่',
#   'ชาวปรัสเซียเก่า',
#   'สงครามห้าทัพ',
#   'โอเซิรบิโยมิลามาตี',
#   'อี้หลิน',
#   'อัตถปัญญาพล',
#   'รักในเอเดน',
#   'ซาโนสุเกะ',
#   'อินดีไซน์',
#   'ชาญเฉลิม',
#   'ภาวะโมเซอิกของเซลล์สืบพันธุ์',
#   'วอลเลย์บอลชายทีมชาติเปอร์โตริโก',
#   'เฮอร์คิวลีสบี',
#   'ไรบัค',
#   'หมากเก็บ',
#   'ปลาสิงโตปีกจุด',
#   'สังคมราษฎร์นิยม',
#   'ปลาบู่จุด',
#   'คริสตัลไวโอเลต',
#   'คิกสตาร์ตส',
#   'ศาลาเฉลิมกรุง',
#   'รายาห์',
#   'เหรียญปีแยร์เดอกูแบร์แต็ง',
#   'ปลาหางนกยูง',
#   'พระราชโอรสในทุตโมสที่สี่',
#   'นักอรรถบำบัด',
#   'เจ้าชายแห่งหอคอย',
#   'โนวาสโกเชีย',
#   'อาณานิคมสิงคโปร์',
#   'โยฮันบัพทิสท์ซิมเมอร์มัน',
#   'โอริเบะ',
#   'ธนาคารเอเชีย',
#   'เชาว์',
#   'วัดมงคลเทพ',
#   'ปลาอกแล',
#   'เอวาแอร์',
#   'เจมส์ครอมเวล',
#   'ภาษาคัสตีล',
#   'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูร้อน',
#   'จักรพรรดินีฮั่นเกา',
#   'กรุงเทพฯและปริมณฑล',
#   'เมาโรแบร์รูโต',
#   'ท่าพรานนก',
#   'บิ๊กจ๊ะ',
#   'แม็กคลัสกีย์',
#   'วิทยาศาสตรบัณฑิต',
#   'สถานีสัญญาณ',
#   'เอชทีทีพีคุกกี้',
#   'ภาษาเปอร์เซียกลาง',
#   'แอนโทนีแห่งปาดัว',
#   'จอร์จแม็คคาร์ทนีย์',
#   'โรลา',
#   'บราวน์',
#   'ที่หมายตา',
#   'เรม',
#   'วัดบางพลับ',
#   'พระเจ้าลูกเธอพระองค์เจ้าศรีวิไลยลักษณ์กรมขุนสุพรรณภาควดี',
#   'เกาค์',
#   'เรื่องสนุกนึก',
#   'อับดุลละฮ์อะฮ์มัดบาดาวี',
#   'วัดปศุปตินาถ',
#   'ราชอาณาจักรมอญ',
#   'หอไอเฟล',
#   'ขวดเบียร์',
#   'ซุนฮวา',
#   'อะแพชีเล็นยา',
#   'ปราสาทเขาพระวิหาร',
#   'จักรพรรดิซูจิง',
#   'โฮยเตอฟันโฮยเตอมา',
#   'ไดโนซอร์เจาะแดนลี้ลับช็อกโลก',
#   'คอนเทคเลนส์',
#   'องค์การเพื่อความร่วมมือทางเศรษฐกิจและการพัฒนา',
#   'ชิเงโกะฮิงะชิคุนิ',
#   'อัลเบิร์ตเบียร์ชตัดท์',
#   'ราดาเมลฟัลกาโอการ์ซิอา',
#   'ภัทรกำพล',
#   'แอนน์แห่งยอร์ค',
#   'รอนไซมอนส์',
#   'บีบีเอสทีวี',
#   'เขตรักษาพันธุ์สัตว์ป่าโตนงาช้าง',
#   'ราฟาเอลาพิเมนตา',
#   'คณาวุฒิไตรพิพัฒนพงษ์',
#   'โชจิ',
#   'บัณฑิตวิทยาลัยมหาวิทยาลัยราชภัฏมหาสารคาม',
#   'วัคซีนเอชไอวี',
#   'บริเวณเธรซ',
#   'อาโป้ง',
#   'นายหนหวย',
#   'เพราะเราคู่กัน',
#   'โรมันกอนซาเลซ',
#   'ซลาตกอ',
#   'สภานิติบัญญัติเนแบรสกา',
#   'ปฏิทินเท็มโปว',
#   'สูญเสีย',
#   'วิลลาร์ดเดอออนกูร์ต',
#   'อาร์ทูร์อักซ์มันน์',
#   'ดีเอโก้มาราโดน่า',
#   'คเซนส์',
#   'เบอร์รี่',
#   'อำนาจนิยม',
#   'เลอมัวน์',
#   'ธิดาวานร',
#   'สึซึมุระ',
#   'ถนนร่วมใจ',
#   'มิสเตรสส์แห่งซอลเทิน',
#   'วิทยาลัยการสาธารณสุขสิรินธรจังหวัดชลบุรีสถาบันพระบรมราชชนก',
#   'ไม่ผลัดใบ',
#   'เกมสั่งตาย',
#   'ชิราอิ',
#   'นกน้อยอุไรพร',
#   'แคตตาล็อกของชาร์ปเลส',
#   'โนอา',
#   'พระนาลกะ',
#   'ทริปเปิ้ล',
#   'เจ้าชายกาเบรียลดยุกแห่งดาลาร์นา',
#   'แผนภาพโวโรนอย',
#   'และทัศนศาสตร์',
#   'ยูโรเปียนคัพ',
#   'สถาบันอาศรมศิลป์',
#   'กรดฟีนิลแอซีติก',
#   'จังหวัดซีลางังเนโกรส',
#   'เลนส์แว่นตาหลายชั้นไร้รอยต่อ',
#   'ไชตน์',
#   'ปินตอร์',
#   'แฮนด์บิลฟิล์มมาร์เก็ต',
#   'ตำบลสมหวัง',
#   'เก็พฮาร์ท',
#   'เจ้าชายแม็กซิมิเลียนแห่งลิกเตนสไตน์',
#   'นาโยง',
#   'จังหวัดมิยากิ',
#   'ซูเปอร์ฮีโร่',
#   'ปรีดาพัฒนถาบุตร',
#   'มาร์วิน',
#   'ตอมัชกุชต์ชัก',
#   'ต้นเตเนเร',
#   'การลดขั้ว',
#   'รหัน',
#   'เบเวอร์ลี',
#   'แอนธิติมา',
#   'ลูกสาวจากบ้านไปหลายปี',
#   'ค่ายกักกันดัคเคา',
#   'แอลีเรซอ',
#   'การค้าขายเครื่องเทศ',
#   'ค่าคลาดเคลื่อนร้อยละ',
#   'มิตซูบิชิกาแลนต์',
#   'พระเจ้ายางวอน',
#   'ไอไลค์',
#   'ปราสาทมงเบริง',
#   'การลำเลียงสารแบบแอคทีฟทรานสปอร์ต',
#   'แอมโมเนียมซีเรียม',
#   'พิพิธภัณฑ์ศิลปะอิสลาม',
#   'พระเจ้าคยองด๊อกแห่งชิลลา',
#   'ขจรศักดิ์หุตะวัฒนะ',
#   'เทศมณฑลแอรอก',
#   'มาดามโบวารี',
#   'เทเลโอคราเตอร์',
#   'เจ้าฟ้ามหาจักรีสิรสยามบรมราชกุมารี',
#   'การรู้จำคำพูด',
#   'พินทุเสนีย์',
#   'เพลค์',
#   'อรรถพงศ์หนูพรหม',
#   'พระเจ้าบรมวงศ์เธอพระองค์เจ้าเสวตรวรลาภ',
#   'แคสเซต',
#   'การโจมตีอิสราเอลของกลุ่มฮะมาส',
#   'วิทยาลัยครูฉะเชิงเทรา',
#   'ยาเงียว',
#   'อาโซ',
#   'การเป็นกลางทางเพศ',
#   'ทิมเบอร์เนิร์ส',
#   'ฦา',
#   '๓๑มีนาคม',
#   'ผีไม้จิ้มฟัน',
#   'ทาดานางะ',
#   'วัฒนคุณ',
#   'เซอร์ซาฮานเอชมากัมบีตอฟ',
#   'นิกายคาลวิน',
#   'ภาวะซึมเศร้าหลังให้กำเนิด',
#   'มีความสามารถเท่ากับคาบูโตะ',
#   'ทราวิฑะ',
#   'เสม็ดแดง',
#   'มาแยน',
#   'มิโลเชวิช',
#   'จะเป็นของเธอตลอดไป',
#   'หม่อมเจ้าประโลมจิตร',
#   'ปฏิกริยาแตกตัว',
#   'ไพฑูรย์เครือแก้ว',
#   'ซาร์ฟิโอดอร์ที่',
#   'อับดุลราซัค',
#   'เกย์',
#   'คุณธรรมทางเทววิทยา',
#   'โจเซฟเฟลเดอร์',
#   'มือคัยลอมูดรึก',
#   'การลงประชาทัณฑ์ลอราและแอล',
#   'ราเยวัช',
#   'นักบุญอักแนส',
#   'สำราญแพทยกุล',
#   'ประยุทธศิริพานิชย์',
#   'โอเยซ',
#   'เพ็กพาวเลอร์',
#   'หม่อมเจ้าฑิฆัมพรยุคล',
#   'บริษัทดีสเตชันจำกัด',
#   'ฟองน้ำอัจฉริยะ',
#   'สาธารณรัฐเชค',
#   'กรุงธนบุรีศรีมหาสมุทร',
#   'อุโมงค์ก็อทฮาร์ท',
#   'เศาวนิต',
#   'ฮัรร็อตค็อยบัร',
#   'ประเทศซามัวในพาราลิมปิกฤดูร้อน',
#   'แรปมอนสเตอร์',
#   'แบร์นบูร์ก',
#   'คลองบ้านม้า',
#   'ภาคต่อฟาร์ฟรอมโฮม',
#   'ปิดตำนานอารยชน',
#   'กุฏิ',
#   'ริโออาชา',
#   'ดาวเอฟซิลอนแม่น้ำบี',
#   'กมลาแฮร์ริส',
#   'สมาคมการจำนองแห่งชาติของรัฐบาลกลาง',
#   'ฮัมซายูซาฟ',
#   'ระมาด',
#   'ลาดพร้าว',
#   'อินโดซียาร์',
#   'เซ็นทรัลเวิลด์ทาวเวอร์',
#   'ประธานาธิบดีเบลารุส',
#   'มลาเด็น',
#   'เนสเตอร์เคิร์ชเนอร์',
#   'นิกายรัสเซียออร์โธด็อกซ์',
#   'ฮอร์โมนส์เดอะเน็กซ์เจน',
#   'สถานีรถไฟบ้านโพ',
#   'ออร์เตกา',
#   'กล้องโทรทรรศน์ขอบฟ้าเหตุการณ์',
#   'เนื้องอกของต่อมใต้สมอง',
#   'ลูกแกะหลงทาง',
#   'ฟัสตาโอลันด์',
#   'ฮอร์สพูล',
#   'ซาดาโอะอารากิ',
#   'ซันไชน์อินเดอะมิร์เรอร์',
#   'ไอโอดีนเม็ด',
#   'ธงชาติอิเควทอเรียลกินี',
#   'ใหม่ธนบุรีฟาร์ม',
#   'แผลในกระเพาะ',
#   'เวือง',
#   'การปีนเขา',
#   'นิลุบลอมรวิทวัส',
#   'ไฮเพเชีย',
#   'คาเคย์',
#   'อามาร์นา',
#   'ตรีชฎามาลยาภรณ์',
#   'จินี',
#   'ชั้นต้น',
#   'วางะ',
#   'ซอยสุกร',
#   'ฮีพซอร์ต',
#   'ทองเนื้อเก้า',
#   'เอ็กเคิลสตัน',
#   'ฟีฟ่าคลับเวิร์ลคัพ',
#   'ดินแดนนูนาวุต',
#   'คิชิโอะ',
#   'สาธารณรัฐลิทัวเนียในโอลิมปิกฤดูร้อน',
#   'ทวีพรสวรรค์',
#   'ฟาโรห์อินโยเตฟที่',
#   'มายฮีโร่',
#   'เซ็กซ์โฟน',
#   'ทรานส์ฟอร์มเมอร์สไพร์ม',
#   'ท่าอากาศยานนานาชาติปารีส',
#   'ชตีลฮันท์กรานาเทอ',
#   'โรงเรียนวัดป่าประดู่',
#   'คาร์โลมันแห่งบาวาเรีย',
#   'เนื้อสำเร็จรูป',
#   'ลมูลอติพยัคฆ์',
#   'ดาวแคระเหลือง',
#   'ขลุ่ยอู้',
#   'อาณาจักรรักนิรันดร์',
#   'จิรกิตติ์ถาวรวงศ์',
#   'อำเภอฮัมดาน',
#   'ไวรอยด์',
#   'เกาะแบงส์',
#   'อพูเลียและคาลาเบรีย',
#   'อันจง',
#   'มาร์โกฟันบัสเติน',
#   'วัดหน้าไม้',
#   'แคสตรีส์',
#   'เดธ',
#   'สุชาดา',
#   'การคัดเลือกเป็นเจ้าภาพโอลิมปิกฤดูร้อน',
#   'เทศบาลเมืองหนองสำโรง',
#   'บ้านผีสิง',
#   'กอมปานี',
#   'เทศบาลตำบลเถินบุรี',
#   'ไตรทรรศน์แห่งญี่ปุ่น',
#   'ถัน',
#   'เยียร์',
#   'มานโดลิน',
#   'หลียฺเหวียนหง',
#   'มิสทัวริซึมอินเตอร์แนชะนัล',
#   'วรผลึก',
#   'นัดนิดาหลวงแนม',
#   'ทวีณบางช้าง',
#   'สถานีวิทยุโทรทัศน์เพื่อการศึกษา',
#   'ชิโรอิโคอิบิโตะ',
#   'ตุ่มรับรส',
#   'ฟาโรห์นิโตคริส',
#   'เค็นจิฟุกุชิ',
#   'เจ้าฟ้าหญิงเซ็ตสึโกะชิชิบุ',
#   'พูแดจีแก',
#   'แม่พระและพระกุมารกับนักบุญยอห์นแบปติสต์',
#   'เพลงลิซ่า',
#   'กลุ่มดาวแพะทะเล',
#   'วิริยอุดมศิริ',
#   'ฮะมาส',
#   'ปลาชะโอน',
#   'อาร์ตี้แอช',
#   'สโมสรฟุตซอลพัทยา',
#   'คณะทัศนมาตรศาสตร์มหาวิทยาลัยรามคำแหง',
#   'เรือหลวงปัตตานี',
#   'การนุ่งห่มของพระสงฆ์',
#   'ภาษาไมถิลี',
#   'โคจรรอบ',
#   'อกฺกโชโต',
#   'กรณีพิพาทอโยธยา',
#   'ฟุตบอลชายหาดทีมชาติรัสเซีย',
#   'ฟู่เหิง',
#   'ดานีเอลแบร์นุลลี',
#   'แฮกเกอร์สเปซ',
#   'ยูรีเบสเมอร์ทนี',
#   'เจ้าจอมละม้ายในรัชกาลที่',
#   'ออกัสบรุกส์แบงก์',
#   'วิลเฮลมึส',
#   'แคร์มัตแชฟสกี',
#   'ริชาร์ดคีโอ',
#   'เรย์กะ',
#   'พระเจ้าจันทรคุปต์วิกรมาฑิตย์',
#   'แซมซั่นดัทซ์บอยยิม',
#   'ชิบิ',
#   'โตโยต้ามอเตอร์เซลล์',
#   'มาสค์ไรเดอร์เดนโอ',
#   'รอยโรคของเซลล์ประสาทสั่งการส่วนล่าง',
#   'เหรียญอิสรภาพประธานาธิบดี',
#   'ใจชื่น',
#   'สมเด็จพระราชินีหลุยส์แห่งเฮสส์',
#   'สมเด็จพระราชินีซังเก',
#   'บริษัททรูคอร์ปอเรชั่นจำกัด',
#   'พึ่งศรีจันทร์',
#   'มเบคี',
#   'เฟนรีร์',
#   'จูกัดเกียว',
#   'อาเมตอฟ',
#   'หอประชุมสุวรรณสมโภช',
#   'ศิลาจารึกหินปาแลร์โม',
#   'วัดเสาธงนอก',
#   'ไพรซ์วอเตอร์เฮาส์คูเปอร์ส',
#   'พาโบล',
#   'คาวาคามิ',
#   'โซเฟียแห่งเดนมาร์ก',
#   'ฮิโทมิ',
#   'จักรพรรดิฮั่นเฉิง',
#   'แฟลชเก็ท',
#   'มิโยโกะอาซาดะ',
#   'สามัคคีสมาคม',
#   'ศิริพูล',
#   'เลโก้ฮีโร่แฟคทอรี่',
#   'ฟิวเจอร์พาร์คบางแค',
#   'คิตะฮิโระชิมะ',
#   'สุวรรณานุช',
#   'ฺ',
#   'แม่น้ำโมนังกาฮีลา',
#   'อุ่นพรม',
#   'ตำบลฝายแก้ว',
#   'ปิงฟรุตตี้',
#   'ความเค้น',
#   'ฟุตบอลทีมชาติไอวอรีโคสต์',
#   'หลี่เผิง',
#   'เซยะซูงิชิตะ',
#   'กลองชุด',
#   'เพราะว่า',
#   'แบช',
#   'บีเอ็นเคโฟร์ตีเอตทีมบีทรีเฟิร์สสเตจ',
#   'กูเอสตา',
#   'จักรพรรดิเจาเลี่ย',
#   'มาเตโอส',
#   'กะบังลม',
#   'ความสัตย์',
#   'ยฺหวินลี่',
#   'รหัสลับดาวินชี',
#   'ขั้นตอนวิธีแบบละโมบ',
#   'สะพานทั้งเจ็ดแห่งเมืองโคนิกส์เบิร์ก',
#   'เจ้าชายเอดูอาร์ด',
#   'ทรูมเซอ',
#   'ทรัพย์สิน',
#   'ไคลเปดา',
#   'หาดรุม',
#   'ตัวละครในก้านกล้วย',
#   'กรมขุนสุพรรณภาควดี',
#   'มาตเจือ',
#   'ต้นน้ำของแผ่นดิน',
#   'สโมสรฟุตบอลวิคตอเรียเปลเซน',
#   'ทองย้อยกลิ่นทอง',
#   'วอลตา',
#   'สเปเชียลไฟนอลอินเคียวเซราโดมโอซากะ',
#   'ดัฟ',
#   'พิธีสาบานธง',
#   'พจน์สะเพียรชัย',
#   'สโมสรฟุตบอลสุรินทร์โขงชีมูล',
#   'กีฬามวยปล้ำในโอลิมปิก',
#   'รักษ์',
#   'สกุลนกแต้วแล้ว',
#   'ราชวงศ์เหลียว',
#   'จังหวัดดืซเจ',
#   'กุลมาศลิมปวุฒิวรานนท์',
#   'ดูบัวส์',
#   'ฮีร์',
#   'สนเขา',
#   'ประเทศชิลีในแพนอเมริกันเกมส์',
#   'วิชคิง',
#   'อันดับภาพยนตร์ที่ทำเงินได้มากที่สุดทั่วโลก',
#   'มากราฟแห่งบรานเดนบวร์ก',
#   'กุ้ยหยาง',
#   'ประชุมโคลงโลกนิติ',
#   'เฮคเคล',
#   'แม่น้ำมะยู',
#   'ทศนิยมสากล',
#   'วินัยสมพงษ์',
#   'โมโนทรีมาตา',
#   'หลิวเสี่ยวปัว',
#   'เส้นทางแซ็ง',
#   'อรอำไพ',
#   'ไซมอนก็อตช์',
#   'เอไออาร์',
#   'พาวเวอร์เรนเจอร์ลอสท์กาแล็คซี่',
#   'วิเอตโต้',
#   'ดุยเย',
#   'ข่าวนอกลู่',
#   'แบดมินตันในเอเชียนเกมส์',
#   'เสือโคร่งแคสเปียน',
#   'โคตรใหญ่ฟัดเหล็ก',
#   'เสริมงาม',
#   'ภาวะพร่องเอนไซม์',
#   'เมืองอุชิกุ',
#   'วีรวัลย์',
#   'ชุ่มอินทรจักร',
#   'ภาษาเอสปรานโต',
#   'สโมสรฟุตบอลอุทัยธานีฟอเรสท์',
#   'ซานจา',
#   'การรถไฟมาลายู',
#   'ทะเลสาบชูเซ็นจิ',
#   'กรุงลอนดอน',
#   'ป๊อปร็อก',
#   'สัญญาธรรมศักดิ์',
#   'เจ้าชายมิเกลดยุคแห่งบรากันซา',
#   'อาซาอิ',
#   'แคว้นออมสค์',
#   'วงศ์ปูบก',
#   'อโศกเหลือง',
#   'วัดเดรปุง',
#   'บาโรกอังกฤษ',
#   'ปีเอโตรดากอร์โตนา',
#   'สาธารณรัฐประชาชนมองโกเลีย',
#   'คมกฤษตรีวิมล',
#   'พรรคประชาธรรมไทย',
#   'เมตเต',
#   'คณะการแพทย์บูรณาการ',
#   'วัดหนองปรือ',
#   'ฌูรู',
#   'แผ่นดินไหวนอกชายฝั่งชูเอ็ตสึจังหวัดนีงาตะ',
#   'มหาวิหารเวียน',
#   'สแตนตัน',
#   'คาสซาโนวา',
#   'อาวเวอส์',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกเยาวชน',
#   'ภาษาอุบัติ',
#   'ชาตะเมธีกุล',
#   'ฮาล์มสตัด',
#   'สมัยเฮอัง',
#   'ธารดาวฤกษ์',
#   'เอกนัฏ',
#   'เกาะศักดิ์สิทธิ์โอกิโนชิมะและสถานที่ที่เกี่ยวข้องในภูมิภาคมูนากาตะ',
#   'พรรคเยาวชนอินโดนีเซีย',
#   'แผ่นดินไหวนอกชายฝั่งชูเอ็ตสึจังหวัดนีงาตะค',
#   'เจ้าผู้ครองนครเชียงใหม่',
#   'สุวิทย์ธาระรูป',
#   'กรมพระยาเทวะวงศวโรปการ',
#   'ฮอลแลนเดอร์',
#   'อิรฟาน',
#   'ซึบุรายะมิทสึฮิโกะ',
#   'นอร์แมนซัตตัน',
#   'เมืองอัจฉริยะ',
#   'โคโนฮะมารุ',
#   'วัดเทพประสิทธิ์',
#   'วิกิพีเดียภาษาอาเซอร์ไบจานใต้',
#   'ซีเอ็น',
#   'คาโต้ชิเงอากิ',
#   'ใบเมี่ยง',
#   'การถ่ายรูปจอประสาทตา',
#   'โรงเรียนมหาวิชานุกูล',
#   'ซุไปดามัง',
#   'จัดสันฮิล',
#   'ดุยลีเย',
#   'เซเว่นอีเลฟเว่น',
#   'สารบัญแฟ้มทั่วไปของเนบิวลาและกระจุกดาว',
#   'ลักษณะการปรับตัวไม่ดี',
#   'เจ้าบุญวาทย์วงศ์มานิต',
#   'เจ้าหญิงเบเนดิกเทอแห่งเดนมาร์ก',
#   'ในสวนขวัญ',
#   'นีย็องซู',
#   'หน่วยราชการข่าวกรองลับ',
#   'เปล็ยกู',
#   'กองทุนบำเหน็จบำนาญข้าราชการ',
#   'บาซิลลัสทูริงเยนซิส',
#   'สลาลม',
#   'การล้อมเมืองออร์เลอองส์',
#   'เกณฑ์ทหารในประเทศไทย',
#   'แม่อาย',
#   'เพลงคลีนแบนดิต',
#   'แบล็คสวอน',
#   'สะพานข้ามอ่าวหังโจว',
#   'แขวงโนยังจิน',
#   'ไรชส์ยูเกินด์ฟือเรอร์',
#   '๙๙๑ลงน้ำ',
#   'รักนี้เจ๊จัดให้',
#   'วัดเกดประยงค์',
#   'ฌูลโคตาร์',
#   'เทศมณฑลปกครองตนเองชนชาติไทลาหู่และว้าเมืองแลม',
#   'โฮวอี้',
#   'ลุงขี้เมา',
#   'ผู้พ่อ',
#   'สายลับเดอะซีรีส์กับ',
#   'ทะยานสู่ห้วงมืด',
#   'เชื้อไวรัสโคโรน่า',
#   'อักษะ',
#   'จักษุวิทยา',
#   'กัตซ์',
#   'ฟ้าลั่นจูเนียร์เกษตรพัฒนา',
#   'ปริ้นซ์',
#   'เพลงเรือ',
#   'ฮาร์เดน',
#   'ทองบริสุทธิ์',
#   'ปูนซิเมนต์',
#   'ม้วนคัมภีร์แห่งทะเลสาบเดดซี',
#   'พระธาตุจอมผ่อ',
#   'ผลพูน',
#   'กิ่งจังหวัดของญี่ปุ่น',
#   'โกซีโมรอสเซลลี',
#   'คณะวิทยาศาสตร์และเทคโนโลยีมหาวิทยาลัยเทคโนโลยีราชมงคลกรุงเทพ',
#   'หอดูดาวลิก',
#   'นายกรัฐมนตรีกัมพูชา',
#   'ทะไกชิ',
#   'ธาราทิพย์สุขดรุณพัฒน์',
#   'อุทยานแห่งชาติดอยขุนตาน',
#   'เอมีลเฮยบีแยร์',
#   'ลาดิสลาโอ',
#   'ซามีร์นัสรี',
#   'เขตปกครองตนเองระดับจังหวัดชนชาติหุยชางจี๋',
#   'โรงเรียนชิโนรสวิทยาลัย',
#   'เคียวริวเซนไท',
#   'จดีเมนยา',
#   'ศิวกรสายบัว',
#   'เหญิต',
#   'เตเรซีนาเมโทร',
#   'สุลต่านมะฮ์มุด',
#   'อำเภอสมุทรสาคร',
#   'อำนาจชนะวงศ์',
#   'รันเตกมโบลา',
#   'การเรียกชื่อสารเคมีตามระบบไอยูแพ็ก',
#   'แซมูเอลแอล',
#   'โปสติโก',
#   'จุดอ่อนของฉันอยู่ที่หัวใจ',
#   'จังฮีบิน',
#   'มองก์ตัน',
#   'เวอร์เท็กซ์นอร์มัล',
#   'หยุนหลิน',
#   'พระราชบัญญัติพระสันตะปาปา',
#   'วงศ์มะแฟน',
#   'ยุคสตาทีเรียน',
#   'พระวรวงศ์เธอพระองค์เจ้าปรีดา',
#   'ความรักความสุขความทรงจำ',
#   'นิการากัว',
#   'พรรคเตลังคานาประชาสมิติ',
#   'อาซึมิอาซากุระ',
#   'ประหยัดบุญญา',
#   'จักรพรรดิหมิน',
#   'จังหวัดนอร์ทบราบันท์',
#   'เอสกริบา',
#   'การเฉลิมพระยศเจ้านาย',
#   'สันนิบาตเพื่อเอกราชเวียดนาม',
#   'เกียดเป๋ง',
#   'ยาย่าตูเร',
#   'อัตสึมิทาเนซากิ',
#   'ปลาพีค็อก',
#   'เวิร์คพอยท์เอ็นเทอร์เทนเมนท์',
#   'ฟรานซิสโกโอลิเวนเซีย',
#   'ดิงกาเน',
#   'หนังสือการ์ตูน',
#   'ซายากะ',
#   'กียอแต็ง',
#   'สารให้ความหวานแทนน้ำตาล',
#   'พระเจ้าฮ็อนจงแห่งโชซอน',
#   'ศรีเจริญ',
#   'วิชวลเบสิกดอตเน็ต',
#   'ภาควิชาสาธารณสุขศาสตร์',
#   'เลอังดรูวีโซตู',
#   'เกอเรจาอายัม',
#   'สกุลเงินยูโร',
#   'สักก์ดนัยณเชียงใหม่',
#   'อัลแบร์ทลิพเพิร์ท',
#   'จินตนาปิ่นเฉลียว',
#   'ชาวไทขาว',
#   'สาวฮอตกลายเป็นนายเห่ย',
#   'ลูกาผู้ประกาศข่าวประเสริฐ',
#   'เบื้องกลาง',
#   'โอตากิโกโร่',
#   'ฟุตบอลชายหาดโลก',
#   'เกมคิวบ์',
#   'ลูกหมูสามตัว',
#   'พุฒิพงษ์ศรีวัฒน์',
#   'น้ำคือชีวิต',
#   'จังหวัดยาโลวา',
#   'วงศ์ย่อยลาน',
#   'ความกระหาย',
#   'อพอลโล่',
#   'เชื้อปัทมจินดา',
#   'ยูวะเวส',
#   'ยูคาชิอิ',
#   'ผลรวมเชซาโร',
#   'นิโจวโมนะโมโตะ',
#   'ฟาโรห์อินโยเตฟผู้อาวุโส',
#   'ลัทธิบูชาบุคคลของเฮย์แดร์',
#   'ยาเอล',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูหนาว',
#   'วลาโดกอเรสกี',
#   'เกรเทสต์ฮิตส์',
#   'เซบัสเตียนบราวน์มาควิสที่',
#   'หุบเขาซิลิกอน',
#   'ปลาเลียหินกัมพูชา',
#   'โรมูลุส',
#   'โฮะมะเระซะวะ',
#   'ฟอร์เรสต์',
#   'เทศบาลในจังหวัดอุดรธานี',
#   'โอะตะกุ',
#   'วงศ์ย่อยเพียงพอน',
#   'สังสารวัฏ',
#   'โคเวนทรี',
#   'สปาร์ตากุส',
#   'จุงโกะทาเกอุจิ',
#   'เสียงเสียดแทรกริมฝีปาก',
#   'โฟล์กร็อก',
#   'รัฐอิสระลือเบ็ค',
#   'ตันติชินานนท์',
#   'ประชาชนนอก',
#   'คือหัตถาครองพิภพ',
#   'อาการปวดขาเหตุประสาท',
#   'ประเทศอิรักในโอลิมปิกฤดูร้อน',
#   'คาทาริน่าดัลก้า',
#   'แคนเดิลอินเดอะวินด์',
#   'เจ้าฟ้าภาณุรังษีสว่างวงศ์กรมหลวงพันธุวงศ์วรเดช',
#   'สวุปสก์',
#   'ห้องรับแขก',
#   'เด็กผู้ชาย',
#   'มิจิโกะ',
#   'ภูมิศาสตร์ภูมิภาค',
#   'ชุ่มสนิท',
#   'อวอร์ด',
#   'พระเจ้ามิทริเดเตสมหาราช',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรจังหวัดแม่ฮ่องสอน',
#   'จักรพรรดิมากรีนุส',
#   'กระดี่',
#   'ชยันต์',
#   'ภัยพิบัติโภปาล',
#   'ยุทโธปกรณ์ฟอสฟอรัสขาว',
#   'อะซะมิคนโนะ',
#   'สำนักเลขาธิการสหประชาชาติ',
#   'พายุเผ่ย์ผ่า',
#   'ปลาปอดพาราโดซ่า',
#   'เจ้าหญิงศรุติราชยลักษมีเทวีศาหะ',
#   'ยูซองลยอง',
#   'ลูกบาศก์โซมา',
#   'อดัมข่าน',
#   'อันเจโลเกรสเชนโซ',
#   'อาคาโฮชิ',
#   'บุรทัต',
#   'ซามูเอลแอล',
#   'บรอดคาสติ้ง',
#   'คาเพ็ลล์บรึคเคอ',
#   'สุลต่านชะรอฟุดดีน',
#   'หม่อมเจ้ามงคลเฉลิมยุคล',
#   'เอลิชาคัทเบิร์ต',
#   'ศุภชัยมหาสารคาม',
#   'บัวคำศรี',
#   'มูร์เซีย',
#   'จงเจตวัชรานันท์',
#   'บัลเด',
#   'อากิระคามิยะ',
#   'กัลยาเลิศเกษมทรัพย์',
#   'โอเบอร์ชไตน์',
#   'ออนทาริโอ',
#   'เอลิซาเบธแห่งฮ็อลชไตน์',
#   'แซวิล',
#   'ปลากระมัน',
#   'ลองโซเมดูส',
#   'อุทยานแห่งชาติน้ำตกพาเจริญ',
#   'พระราชประวัติ',
#   'มานพอัศวเทพ',
#   'เคร็บส์',
#   'การเดิน',
#   'สุลาเวสี',
#   'จังหวัดอาเจะห์',
#   'เสียความจำ',
#   'หนี่ว์วา',
#   'เมียนมา',
#   'เขาดินวนา',
#   'ดานเตอลิเกียริ',
#   'อัรบีล',
#   'สุนิล',
#   'วันวีล',
#   'ศิลปะโรโกโก',
#   'ไซร์เรคคอร์ดส์',
#   'จอห์นชีค',
#   'รอมบิน',
#   'ทัดดาว',
#   'ธนาคารกรุงไทย',
#   'เครื่องพิมพ์',
#   'ค่าพยากรณ์ผลบวก',
#   'ถนนสมโภชเชียงใหม่',
#   'อิงวาร์คัมพรัด',
#   'การพิชิตอียิปต์ของจักรวรรดิซาเซเนียน',
#   'การแพทย์พึ่งหลักฐาน',
#   'เอลลิแฟนท์',
#   'เจ้าหญิงมารีหลุยส์แห่งบูร์บง',
#   'กานตล',
#   'เชมัน',
#   'อิกเนอร์',
#   'สาธารณรัฐประชาธิปไตยประชาชนแอลจีเรียในโอลิมปิกฤดูร้อน',
#   'ความเท่าเทียมกันของอำนาจซื้อ',
#   'บาริโซเน',
#   'การยึดครองประเทศไอซ์แลนด์',
#   'มูอัมบา',
#   'โชลา',
#   'สมาชิกสภาผู้แทนราษฎรจังหวัดยโสธร',
#   'ปิยภัทร์กิติ',
#   'ฟิลิปโป',
#   'นักบุญลองกินุส',
#   'สมัยเฮลเลนิสต์',
#   'สหภาพมาลายา',
#   'เตอร์นาตี',
#   'สกอร์เปียนที่',
#   'พลายน้อยร',
#   'นิโคไล',
#   'เดวิดอามู',
#   'คิชิโมโต้',
#   'ควักชี',
#   'ผ้าชิโน',
#   'มาร์กาเร็ตแห่งอองจูสมเด็จพระราชินีแห่งอังกฤษ',
#   'กชล',
#   'วิทยาแก้วภราดัย',
#   'การตอบสนองโดยสู้หรือหนี',
#   'โซบะ',
#   'โยอันนิสซาร์มัส',
#   'ฮาบารอฟสค์',
#   'เจ้าหญิงฮิซะโกะพระชายาทะกะมะโดะ',
#   'สถาบันสมิธโซเนียน',
#   'เหล่าซูเปอร์ฮีโร่แห่งอนาคต',
#   'สงกรานต์',
#   'กมลเวชช',
#   'สถาบันชั้นสูงวิทยาศาสตร์และเทคโนโลยีเกาหลี',
#   'ชิเงโนะไดโกะ',
#   'เจ้าอุปราชพิมพิสาร',
#   'การโจมตีเคมีที่คอนชัยคูน',
#   'กะหรี่',
#   'แอมัลเธีย',
#   'อันเดรจเพลนโควิค',
#   'ราชวงศ์ฮั่น',
#   'แซร์มัท',
#   'แทรนซ์',
#   'เจ้าหญิงอานดัชเชสแห่งกาลาเบรีย',
#   'แนวิส',
#   'วิทยาการเพศชาย',
#   'จ๊อกกี้',
#   'เพลงภัทรวี',
#   'นางาระ',
#   'ทาลัสซีเมียแบบอัลฟ่า',
#   'ยูมิจิกะ',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 5483

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['ประเทศกัวเตมาลาในพาราลิมปิกฤดูร้อน',
#  'เจ้าจอมมารดาพึ่งในรัชกาลที่',
#  'ความหลากหลายทางชีวภาพในประเทศกัมพูชา',
#  'รัฐในอารักขาอันนัม',
#  'การช่วยเหลือด้านมนุษยธรรมต่อเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮะกุ',
#  'สโมสรฟุตบอลขอนแก่นในฤดูกาล',
#  'การคมนาคมในประเทศลาว',
#  'ผลิตภัณฑ์มวลรวมในประเทศ',
#  'รูปผิดปกติของหลอดเลือดแดงและดำในสมอง',
#  'ศาลยุติธรรมสูงสุดในการพิจารณาคดีพระเจ้าชาร์ลส์ที่',
#  'อินเตอร์นิวรอนในไขสันหลัง',
#  'พืชพันธุ์ในประเทศมาซิโดเนีย',
#  'การโจมตีผู้เข้าแถวซื้อขนมปังในแชร์นีฮิว',
#  'ประเทศคีร์กีซสถานในพาราลิมปิกฤดูร้อน',
#  'ธงราชวงศ์ฝ่ายใน',
#  'ฉากในลำกล้องปืน',
#  'การขนส่งระบบรางในประเทศอินโดนีเซีย',
#  'การลงประชามติในประเทศสวิตเซอร์แลนด์ค',
#  'สหพันธ์สาธารณรัฐอิรักในเอเชียนบีชเกมส์',
#  'กีฬาว่ายน้ำในกีฬาทางน้ำชิงแชมป์โลก',
#  'อำเภอในประเทศฝรั่งเศส',
#  'กีฬาลีลาศในเวิลด์เกมส์',
#  'พระราชสันตติวงศ์ในพระเจ้าฌูเอาที่',
#  'หูชั้นในรูปหอยโข่ง',
#  'การรับบุคคลเข้าศึกษาในสถาบันอุดมศึกษาในประเทศไทย',
#  'ความสำคัญในการรักษา',
#  'เนเธอร์แลนด์ในสงครามโลกครั้งที่สอง',
#  'อุทกภัยในประเทศจีน',
#  'การปฏิวัติเกษตรกรรมในอังกฤษ',
#  'กีฬาเรือพายในเอเชียนเกมส์',
#  'ธงในนครรัฐวาติกัน',
#  'เวลาในประเทศอินโดนีเซีย',
#  'แผ่นดินไหวในจังหวัดฟูกูชิมะค',
#  'กรมการราษฎรฝ่ายกิจการภายใน',
#  'จังหวัดในประเทศญี่ปุ่น',
#  'เหตุระเบิดในบอสตันมาราธอน',
#  'ประเทศติมอร์ตะวันออกในซีเกมส์',
#  'บริการสุขภาพในประเทศอิสราเอล',
#  'ธงในประเทศรัสเซีย',
#  'ไรชส์ค็อมมิสซารีอาทในเบลเยียมและฝรั่งเศสเหนือ',
#  'จังหวัดนครปฐมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'อัลลอฮ์ในฐานะเทพแห่งดวงจันทร์',
#  'ใบอนุญาตขับขี่ในประเทศไทย',
#  'การตรวจพิจารณาในสหภาพโซเวียต',
#  'การโฆษณาชวนเชื่อในประเทศรัสเซีย',
#  'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'โทรศัพท์มือถือในประเทศไทย',
#  'คอเลสเตอรอลในเลือดแบบดี',
#  'การฉ้อราษฎร์บังหลวงในประเทศมาเลเซีย',
#  'ดาราศาสตร์ในปีค',
#  'คณะปฏิรูปการปกครองในระบอบประชาธิปไตย',
#  'การระบาดของโคโรนาไวรัสในประเทศเม็กซิโก',
#  'เจ้าจอมมารดาจันทร์ในรัชกาลที่',
#  'กีฬาเทเบิลเทนนิสในเอเชียนเกมส์',
#  'กีฬาว่ายน้ำสระเปิดในเวิลด์บีชเกมส์',
#  'สโมสรฟุตบอลอาร์เซนอลในฤดูกาล',
#  'ประเทศเซนต์วินเซนต์และเกรนาดีนส์ในพาราลิมปิกฤดูร้อน',
#  'สีที่ใช้ในเว็บ',
#  'ตัวละครในพลังอักษะ',
#  'พระราชโอรสในฟาโรห์สเนฟรู',
#  'การเปลี่ยนชื่อเมืองในประเทศอินเดีย',
#  'พุทธศาสนาในประเทศฟิลิปปินส์',
#  'เหตุระเบิดในอัดดุญัยล์ค',
#  'ฝนสีแดงในรัฐเกรละ',
#  'เหตุเรือบรรทุกน้ำตาลล่มในแม่น้ำเจ้าพระยา',
#  'มอดูลในคอร์เทกซ์',
#  'อันดับมหาวิทยาลัยในประเทศไทย',
#  'การจัดการสตริงในภาษาซี',
#  'รักร่วมเพศในประเทศไทย',
#  'ประเทศอินโดนีเซียในเอเชียนเกมส์',
#  'ความพยายามรัฐประหารในประเทศตุรกี',
#  'เจ้าหญิงคิโกะพระชายาในเจ้าชายฟูมิฮิโตะ',
#  'การลงคะแนนเสียงในสวิตเซอร์แลนด์',
#  'พระราชโอรสในรัชกาลที่',
#  'ตรวจเลือดแฝงในอุจจาระ',
#  'ธงต่างๆในประเทศเยอรมนี',
#  'โรงเรียนสาธิตมหาวิทยาลัยราชภัฏวไลยอลงกรณ์ในพระบรมราชูปถัมภ์',
#  'เซปักตะกร้อในเอเชียนเกมส์',
#  'การท่องเที่ยวในประเทศมาดากัสการ์',
#  'การเติมหมู่ซัลเฟอร์ในไทโรซีน',
#  'ช่วงว่างระหว่างรัชกาลในอังกฤษ',
#  'หมู่เกาะแฟโรในพาราลิมปิก',
#  'รัฐเดลาแวร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎร',
#  'การเกณฑ์ทหารในประเทศไทย',
#  'ลำดับเหตุการณ์ในประวัติศาสตร์อังกฤษระหว่างปีค',
#  'ศาสนาซิกข์ในประเทศอัฟกานิสถาน',
#  'กำลังภายใน',
#  'การขนส่งในประเทศกัมพูชา',
#  'กลซ่อนดาบในรอยยิ้ม',
#  'การเจริญของประสาทในมนุษย์',
#  'ชาติเอเชียในฟุตบอลโลก',
#  'เหตุกราดยิงในโรงเรียนประถมรอบบ์',
#  'พายุหมุนเขตร้อนใน',
#  'รัฐประหารในฟีจี',
#  'เลสเตในพาราลิมปิกฤดูร้อน',
#  'ตัวละครในเส้าหลินสุดยอดพลังแห่งเพลงมวย',
#  'แผลในทางเดินอาหารจากภาวะเครียด',
#  'โทรทัศน์สหรัฐอเมริกาในค',
#  'การก่อการกำเริบของนางใน',
#  'เหตุระเบิดในเบรุต']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 5108

# %%
get_samples(nai)
# Out:
# ['กีฬาปาร์กูร์ในเวิลด์เกมส์',
#  'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'กีฬาเรือใบในกีฬาแห่งชาติ',
#  'ความลำเอียงในการพิมพ์',
#  'ชาวไทยในประเทศพม่า',
#  'การโฆษณาชวนเชื่อในประเทศรัสเซีย',
#  'กีฬาวอลเลย์บอลหญิงในซีเกมส์',
#  'พืชพันธุ์ในประเทศมาซิโดเนียเหนือ',
#  'การตอบสนองต่อการประท้วงในประเทศไทย',
#  'การเรียกร้องให้บัญญัติพุทธศาสนาเป็นศาสนาประจำชาติในรัฐธรรมนูญแห่งราชอาณาจักรไทย',
#  'ปัญหาสิ่งแวดล้อมในประเทศอัฟกานิสถาน',
#  'รัฐประหารในประเทศชิลี',
#  'วันสำคัญในพุทธศาสนา',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติ',
#  'การขนส่งในจังหวัดหนองบัวลำภู',
#  'จังหวัดปราจีนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'ศาสนาพุทธในประเทศไทย',
#  'ธงในประเทศโอมาน',
#  'ศูนย์กีฬาในร่มอเนกประสงค์เขตโอตะ',
#  'พิธีไหว้ครูในประเทศไทย',
#  'กางเกงใน',
#  'แฟนทาสติกโฟร์ในภาพยนตร์',
#  'ผลสำคัญในการรักษา',
#  'เกย์ในประเทศไทย',
#  'วัตถุมงคลในคริสต์ศาสนา',
#  'สปรินเทอร์ในประเทศไทย',
#  'กีฬาไลฟ์เซฟวิงในเวิลด์เกมส์',
#  'ขบวนการต่อต้านของชาวโปแลนด์ในสงครามโลกครั้งที่สอง',
#  'วิศวกรรมสถานแห่งประเทศไทยในพระบรมราชูปถัมภ์',
#  'สงครามโลกครั้งที่สองในประเทศไทย',
#  'การประท้วงในการากัลปักสถาน',
#  'การก่อการกำเริบในเบอร์ลินตะวันออกค',
#  'วันหยุดในประเทศแอลเบเนีย',
#  'กีฬาเพาะกายในซีเกมส์',
#  'พายุหิมะในประเทศอิหร่านค',
#  'แผ่นดินไหวในเกาะสุลาเวสี',
#  'ภาวะหายใจเร็วชั่วคราวในทารกแรกเกิด',
#  'ภาวะไขมันในเลือดสูงเกิน',
#  'องค์การว่าด้วยความมั่นคงและความร่วมมือในยุโรป',
#  'รถไฟชานเมืองในกรุงเทพมหานครและปริมณฑล',
#  'การกลั่นแกล้งในโรงเรียน',
#  'การประท้วงในประเทศรัสเซีย',
#  'ตำบลในเวียงอำเภอเมืองน่าน',
#  'วันแห่งชัยชนะในทวีปยุโรป',
#  'เจ้าจอมมารดาหม่อมราชวงศ์แขพึ่งบุญในรัชกาลที่๕',
#  'เวลาในประเทศอินโดนีเซีย',
#  'ศูนย์กีฬาในร่มนครมัตสึโมโตะ',
#  'มรดกโลกในประเทศมองโกเลีย',
#  'เรือดำน้ำในภูมิภาคอาเซียน',
#  'พระนามของพระเป็นเจ้าในศาสนาอิสลาม',
#  'กลศึกมีในไม่มี',
#  'ในหลวงรัชกาลที่๙',
#  'องค์การนักศึกษาในประเทศไทย',
#  'จีนไทเปในเอเชียนบีชเกมส์',
#  'เหตุเหยียบกันเสียชีวิตในซาบาริมาลา',
#  'รถไฟในประเทศไทย',
#  'ลัทธิยูดายในสหรัฐอเมริกา',
#  'มูลนิธิส่งเสริมศิลปาชีพในสมเด็จพระนางเจ้าสิริกิติ์',
#  'กีฬาคาราเต้โดในกีฬาแห่งชาติครั้งที่',
#  'สาธารณรัฐเยเมนในเอเชียนเกมส์',
#  'มรดกโลกในประเทศมาเลเซีย',
#  'การก่อการกำเริบในสาธารณรัฐมาซิโดเนีย',
#  'มุฮัรร็อมในความเชื่อของซุนนี',
#  'วังในประเทศไทย',
#  'เหตุการณ์การสูญพันธุ์ในยุคครีเทเชียส',
#  'แผนแม่บทระบบขนส่งมวลชนในกรุงเทพมหานครและพื้นที่ต่อเนื่อง',
#  'พระราชกรณียกิจทรงเยือนต่างประเทศในรัชกาลที่',
#  'สถาบันอเมริกาในไต้หวัน',
#  'บล็อกในตารางธาตุ',
#  'ในประเทศไต้หวัน',
#  'เหตุยิงกันในทูซอนค',
#  'ตัวละครในนินจาคาถาโอ้โฮเฮะ',
#  'ยุควงการมวยปล้ำอาชีพบูมในคริสต์ทศวรรษ',
#  'เจ้าจอมมารดาเจ้าทิพเกษรในรัชกาลที่',
#  'และพระมเหสีในพระมหากษัตริย์แห่งสหราชอาณาจักร',
#  'เหตุโจมตีในจาการ์ตา',
#  'วัดในจังหวัดอุตรดิตถ์',
#  'เพลิงไหม้ครั้งใหญ่ในลอนดอนค',
#  'การข่มเหงรังแกในโรงเรียน',
#  'รัฐประหารในประเทศเมียนมา',
#  'เหตุการณ์สำคัญในสมัยกรุงศรีอยุธยา',
#  'เวลาไพรม์ไทม์ในประเทศไทย',
#  'ซุปเครื่องใน',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศมองโกเลีย',
#  'การลงคะแนนเสียงในสวิตเซอร์แลนด์',
#  'การเผยแผ่ศาสนาพุทธในสหรัฐอเมริกา',
#  'การให้กำเนิดเซลล์ในระบบประสาท',
#  'การลงคะแนนเลือกตั้งในสวิตเซอร์แลนด์',
#  'การเลือกตั้งประธานาธิบดีสหรัฐในรัฐแคลิฟอร์เนีย',
#  'ไวรัสโรคอหิวาต์แอฟริกาในสุกร',
#  'กีฬายิงธนูในเอเชียนเกมส์',
#  'มีเมตฮีโมโกลบินในเลือด',
#  'อนุสัญญาว่าด้วยสิทธิในการรวมตัวและการร่วมเจรจาต่อรอง',
#  'หมอกควันในเอเชียตะวันออกเฉียงใต้',
#  'แผ่นดินไหวในเกาะโบโฮล',
#  'สตรีในประเทศอาร์มีเนีย',
#  'โคลนถล่มขนาดใหญ่ในเมืองอะตะมิ',
#  'ไทยในอียิปต์',
#  'รัฐในประเทศสวิตเซอร์แลนด์',
#  'โบราณสถานแห่งเติงเฟิงใน']

# %% [markdown]
# Most of these are still non-named-entity
#
# Seems to be difficult to get named-entity title...
#
# Exclude all "ใน"
#
# **HELP NEEDED**

# %%
titles = set([title for title in titles if "ใน" not in title])

get_len(titles)
# Out:
# current: 293408
# diff: -7089

# %%
get_samples(titles)
# Out:
# ['การสอดแนม',
#  'มหาวิทยาลัยแห่งอินโดนีเซีย',
#  'อวัยวะรับความรู้สึก',
#  'องค์กรอุตุนิยมวิทยาโลก',
#  'เรือนเครื่องผูก',
#  'ผีดิบคลั่งบัลลังก์เดือด',
#  'สิงหนคร',
#  'วอร์ออฟเดอะเวิลด์สอภิมหาสงครามล้างโลก',
#  'โจะเซ',
#  'สนธิสัญญายูเทรกต์',
#  'หน่วยบัญชาการทหารภาคกลาง',
#  'สเตฟาโนปาลมีรี',
#  'โฮสต์',
#  'แมตริดเดิล',
#  'ซุปเป้อร์เท้สเต้อร์',
#  'มิโกอิ',
#  'การกำหนดค่า',
#  'คนเดิมของเธอ',
#  'สโรชาตันจรารักษ์',
#  'ปิยะนุวัฒน์ชัย',
#  'สงครามครูเสดอัลบิเจ็นเซียน',
#  'น้ำตกตาดกวางสี',
#  'เครื่องเสนาอิสริยาภรณ์นักบุญยากอบและพระขรรค์',
#  'ซานตามารีอาดีกอลเลมัจจีโอ',
#  'ย่่างกุ้ง',
#  'อีราทอสทีเนียส',
#  'วิชญ์วิสิฐ',
#  'บิงคส์',
#  'คาโพ',
#  'เวิงเหม่ย์หลิง',
#  'คุณพุ่มเจนเซ่น',
#  'ทีฆทัศน์',
#  'ดิเอโกเบลาสเควส',
#  'ปลาสูบ',
#  'ดิเอ็มโพเรียม',
#  'ลูย์บอฟออร์โลวา',
#  'มัสซิโมดาเลมา',
#  'ฟังก์ชันบ่งชี้',
#  'พระยะโฮวา',
#  'ความล้มเหลวจากจุดเดียว',
#  'เจฟฟรีย์กิโตเมอร์',
#  'เปสซอตโต',
#  'วิทยาลัยพยาบาลเกื้อการุณย์',
#  'โรมุลุสและแรมุส',
#  'นิวซีแลนด์เน็กซต์ท็อปโมเดล',
#  'ฮิเดะโยะ',
#  'กลุบอาเมรีกา',
#  'บีฟานา',
#  'โตนนท์วงบุญ',
#  'ซเฟิน',
#  'นกเป็ดผี',
#  'การต่อสู้ของข้าพเจ้า',
#  'วอลอดือมือร์กลึชกอ',
#  'คางคกแคระ',
#  'สำนักวิชาพยาบาลศาสตร์มหาวิทยาลัยเทคโนโลยีสุรนารี',
#  'เจเนรัล',
#  'การโจมตีของทหารราบ',
#  'คอนสตันตินเชียร์เนนโค',
#  'รถไฟเรือเมล์ลิเกกองถ่าย',
#  'สหพันธ์ว่ายน้ำนานาชาติ',
#  'ยิชรี',
#  'อัลมูอัลลาที่',
#  'ถนนที่เก็บค่าผ่านทาง',
#  'มินะโมะโตะโนะโยะชิสึเนะ',
#  'คุมเม็ลนานจิอานี',
#  'โครงการเดียร์มูน',
#  'อาเดรียโน่',
#  'พงศกรจันทร์แก้ว',
#  'พ่อขุนศรีนาวนำถุม',
#  'ออแลนโด',
#  'มีนาพระ',
#  'โจนิปาลาซิโอส',
#  'เงือก',
#  'มาสค์ไรเดอร์ดับเบิ้ลเดอะมูฟวี่ฟอร์เอเวอร์ศึกล่าไกอาเมมโมรี่',
#  'วูกี้ส์',
#  'มูลนิธิอานันทมหิดล',
#  'แอนนิมอลเพลนเนต',
#  'โมดิลยานี',
#  'คิลาน',
#  'ใครว่าโลกนี้ไม่มีผี',
#  'สมเด็จพระอมรินทราธิราช',
#  'เบสพิน',
#  'เพลกัส',
#  'นักแสดงสมทบหญิงยอดเยี่ยมรางวัลภาพยนตร์แห่งชาติสุพรรณหงส์',
#  'ท้าวธตรัฐ',
#  'ซายุมิสุซุชิโระ',
#  'คิวเรม',
#  'อุลตร้าแกแล็ตซี่',
#  'เอ็นพีซี',
#  'เซร์ฮีโอกอนซาเลซ',
#  'รูด็อล์ฟเฮ็ส',
#  'โฟรโด',
#  'อะเลกเซย์กูโรแพทกิน',
#  'เนโอมีแคมป์เบลล์',
#  'หวนจง',
#  'ถนนดาวนิง',
#  'คริสตจักรออร์ทอดอกซ์เซอร์เบีย',
#  'อิบุนรัชด์',
#  'ประวัติวัดกล้าชอุ่ม',
#  'โกสท์ไนน์']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)
#
# Some proper-noun like movie titles possibly holds this, so hold both

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (398, 1250)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศตูนีเซีย',
#  'ประเทศเบลเยี่ยม',
#  'ประเทศสหรัฐอเมริกา',
#  'ประเทศฮอลแลนด์',
#  'ประเทศเซอร์เบียและมอนเตเนโกร',
#  'ประเทศไนจีเรีย',
#  'ประเทศวานัวตู',
#  'ประเทศสแกนดิเนเวีย',
#  'ประเทศอิสราเอล',
#  'ประเทศกายอานา',
#  'ประเทศอินเดีย',
#  'ประเทศเบนิน',
#  'ประเทศสหพันธรัฐรัสเซีย',
#  'ประเทศซามัว',
#  'ประเทศทาจิกิสถาน',
#  'ประเทศมาดากัสการ์',
#  'ประเทศกาบอง',
#  'ประเทศไต้หวัน',
#  'ประเทศลักเซมเบิร์ก',
#  'ประเทศเยอรมนีที่สัมพันธมิตรยึดครอง',
#  'ประเทศบรูไนดารุสซาลาม',
#  'ประเทศอุซเบกิสถาน',
#  'ประเทศไอร์แลนด์',
#  'ประเทศเดนมาร์ก',
#  'ประเทศลิธัวเนีย',
#  'ประเทศเวียดนามเหนือ',
#  'ประเทศโปแลนด์',
#  'ประเทศสมมุติ',
#  'ประเทศโคโซโว',
#  'ประเทศกินิบิสเซา',
#  'ประเทศสาธารณรัฐไอซ์แลนด์',
#  'ประเทศสยาม',
#  'ประเทศสโลวีเนีย',
#  'ประเทศโครเอเชียกับสกุลเงินยูโร',
#  'ประเทศบูร์กินาฟาโซ',
#  'ประเทศที่มีพรรคการเมืองเดียว',
#  'ประเทศโดมินิกา',
#  'ประเทศปาเลสไตน์ท',
#  'ประเทศโลกที่สาม',
#  'ประเทศสาธารณรัฐอิตาลี',
#  'ประเทศโมแซมบิก',
#  'ประเทศที่กำลังพัฒนา',
#  'ประเทศสิงค์โปร์',
#  'ประเทศโครเอเชีย',
#  'ประเทศเทกซัส',
#  'ประเทศตูวาลู',
#  'ประเทศศรีลังกา',
#  'ประเทศเอสวาตินี',
#  'ประเทศสิงคโปร์',
#  'ประเทศราชของอาณาจักรตองอู',
#  'ประเทศจอร์เจีย',
#  'ประเทศเยอรมนี',
#  'ประเทศเซเนกัล',
#  'ประเทศยูเครน',
#  'ประเทศที่มีอดีตเป็นแดนนักโทษ',
#  'ประเทศเปอร์โตริโก้',
#  'ประเทศตุรกี',
#  'ประเทศกำลังพัฒนา',
#  'ประเทศเปอร์โตริโก',
#  'ประเทศปานามา',
#  'ประเทศคีร์กีซสถาน',
#  'ประเทศชิลี',
#  'ประเทศเอลซาวาดอร์',
#  'ประเทศเนเธอร์แลนด์',
#  'ประเทศคาซัคสถาน',
#  'ประเทศไซปรัส',
#  'ประเทศเอริเทรีย',
#  'ประเทศเหวียดนาม',
#  'ประเทศเบลิซ',
#  'ประเทศสาธารณรัฐเช็ก',
#  'ประเทศเอสวาตีนี',
#  'ประเทศรวันดา',
#  'ประเทศบุรุนดี',
#  'ประเทศอินโดนีเชีย',
#  'ประเทศซีเรีย',
#  'ประเทศกูมี',
#  'ประเทศหมู่เกาะมาร์แชลล์',
#  'ประเทศรัสเซีย',
#  'ประเทศอาร์เมเนีย',
#  'ประเทศออสเตรเลีย',
#  'ประเทศญี่ปุ่น',
#  'ประเทศจาไมกา',
#  'ประเทศโมรอกโก',
#  'ประเทศฟินแลนด์',
#  'ประเทศกรีเนดา',
#  'ประเทศที่เข้าร่วมการประกวดมิสเวิลด์',
#  'ประเทศมาซีโดเนีย',
#  'ประเทศเซียร์ราลีโอนี',
#  'ประเทศสมาพันธรัฐสวิส',
#  'ประเทศบราซิล',
#  'ประเทศเมียนมา',
#  'ประเทศต่ำ',
#  'ประเทศเช็กเกีย',
#  'ประเทศนาอูรู',
#  'ประเทศเซเชลส์',
#  'ประเทศอังกฤษ',
#  'ประเทศโดมินิกัน',
#  'ประเทศอิหร่าน',
#  'ประเทศเช็กโกสโลวาเกีย',
#  'ประเทศบัลแกเรีย']

# %%
# seperate
titles_temp = set()

#holds both (before and after)
for title in titles:
    if title.startswith("ประเทศ"):
        titles_temp.add(title[6:])
        titles_temp.add(title)
    elif title.startswith("รัฐ"):
        titles_temp.add(title[3:])
        titles_temp.add(title)
    else:
        titles_temp.add(title)
        
titles = titles_temp

get_len(titles)
# Out:
# current: 294305
# diff: 897

# %%
get_samples(titles)
# Out:
# ['สมัยเฮลลาดิค',
#  'กริสตีอาโน',
#  'ป่าเคลป์',
#  'มะอิระคูยามา',
#  'คอนเนอร์วิกคัม',
#  'เปิรตีวี',
#  'วอลเดอมาร์แฮกลุนด์',
#  'สถานีรถไฟชิมบาชิ',
#  'เหวินเสีย',
#  'อนงค์พรพรหมรัตน์',
#  'เดอะเลเจนด์ออฟเซลดาทไวไลต์พรินเซสส์',
#  'ท่าอากาศยานพิษณุโลก',
#  'ซาโมวาร์',
#  'ฮาเลย์เดวิดสัน',
#  'ช่วยที',
#  'แฮกเก็นชมิดต์',
#  'พระธรรมโกศาจารย์',
#  'มูลนิธิบอร์นดิสเวย์',
#  'ภาวะสมดุลอุทกสถิต',
#  'ตำบลหน้าไม้',
#  'แครบเกม',
#  'การตัดแท่ง',
#  'ดับเครื่องชน',
#  'โอชีร์',
#  'ทะเกะชิคุซะโอะ',
#  'พระเจ้าจียง',
#  'ทะเลสาบออนแทริโอ',
#  'หาดกมลา',
#  'โนปังคิสซะ',
#  'วัคซีนไข้เหลือง',
#  'ภูวิจารย์',
#  'ชุนเหล่ย์',
#  'ลูนแฟคทอรี',
#  'ออลมายเบสต์',
#  'วรินดาดำรงผล',
#  'เหรียญดุษฎีมาลาเข็มกรุณา',
#  'พอยลา',
#  'เอ็กซ์ไนน์',
#  'แห่งปัมโปลนา',
#  'บัซนา',
#  'เมนโลพาร์ก',
#  'โมโตครอส',
#  'สโมสรกีฬาแฮร์ทาเบอร์ลิน',
#  'อำเภอเมืองยะลา',
#  'ดุษฎีมาลากุลณอยุธยา',
#  'บาร์ต็อก',
#  'นัตสึโยริตะ',
#  'เฮคแลร์อุนด์คอคยูเอ็มพี',
#  'รถไฟใต้ดินกรุงลอนดอน',
#  'เจ้าฟ้าสิงหราชธานีเจ้าฟ้าหลวงชายแก้ว',
#  'เวิลด์วอร์',
#  'วัดฟ่อนสร้อย',
#  'สำนักงานพัฒนารัฐบาลดิจิทัล',
#  'เทวานฤมิตกุล',
#  'เซ็กเธาว์',
#  'คาราทราว่า',
#  'เหล็งฮู้ชง',
#  'โคเซเบเซร์รา',
#  'สกุลปลาทองทะเล',
#  'เมก้าก็อดซิลลา',
#  'รัฐซูริก',
#  'เสี่ยน',
#  'หลอดเลือดแดงซีลิแอก',
#  'เการพ',
#  'เนทันยาฮู',
#  'สารพัดพิษ',
#  'ชาร์ลีนชอย',
#  'ชาร์ลอท',
#  'อ่าวมารีนา',
#  'เลดีเจน',
#  'เอลเอสโกเรียล',
#  'รัฐที่มีพรรคการเมืองเดียว',
#  'ปะทะกับกลุ่มพันธมิตรฯ',
#  'อุชิยามะยูมิ',
#  'เจ้าหญิงฮิซะโกะพระชายาทะกะมะโดะ',
#  'ถนนหลวง',
#  'เอะอิชิ',
#  'ตำบลโบสถ์',
#  'คิตแฮริงตัน',
#  'ล้อรอ',
#  'คอนเสิร์ตขนนกกับดอกไม้',
#  'แอลป์มาริทิเม',
#  'ภาษาเจอร์มานิค',
#  'ยอดแสบ',
#  'สกาเซลล์',
#  'ภาษาเลสกี',
#  'ลูกทุ่งเอฟเอ็ม',
#  'ไพจิตรกาญจนกุล',
#  'โตเกียวเมโทรสายกินซะ',
#  'อิหม่าม',
#  'ซีโลไฟซิต',
#  'ฟีเทอ',
#  'ออพอเล',
#  'สุรไกร',
#  'เดียร์คเคาท์',
#  'ผมเป็นของคุณไปแล้ว',
#  'คาเวนดิช',
#  'สายใจไทย',
#  'บัญญัติเจตนจันทร์',
#  'แคนต์เลตโก']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %%
def rid_front(text, front):
    if text.startswith(front):
        return text[len(front):]
    else:
        return text

titles_temp = set()
for title in titles:
    title = rid_front(title, "ตำบล")
    title = rid_front(title, "อำเภอ")
    title = rid_front(title, "จังหวัด")    
    title = rid_front(title, "มณฑล")
    title = rid_front(title, "รัฐ")
    
    titles_temp.add(title)
    
titles = titles_temp
    
get_len(titles_temp)
# Out:
# current: 290810
# diff: -3495

# %% [markdown]
# Probably almost all has redirects, but seperate

# %%
get_samples(titles_temp)
# Out:
# ['เส้นทางสายกษัตริย์',
#  'มารีอู',
#  'ปีศาจกระดูกขาว',
#  'จักรพรรดิแฟร์ดีนันด์ที่',
#  'การล้อมกรุงเยรุซาเล็ม',
#  'เครื่องทรงพระพุทธมหามณีรัตนปฏิมากร',
#  'บีซีเพลซ',
#  'พาโซโดเบล',
#  'โบรเน',
#  'พระเจ้าอิชต์วานที่',
#  'โฟว์เซีย',
#  'ซักเกอร์แมน',
#  'ชาวกอท',
#  'ตกที่จังหวัดนครปฐม',
#  'สำเร็จ',
#  'ยุทธนาวีที่ดันโนะอูระ',
#  'การค้าระหว่างประเทศ',
#  'ลิงมังกาเบย์ที่ราบสูง',
#  'มานุษยรูปนิยม',
#  'เมืองกุสินารา',
#  'นายสุรชัย',
#  'อัจฉริยะปัญญานิ่ม',
#  'เต๋าสมชาย',
#  'โจเซ่มาร์ตินส์อาเชม',
#  'ปาเต๊ะ',
#  'โบคาสซา',
#  'เชคนาวาฟ',
#  'ทิพยวไลย์สุพันธุ์วณิช',
#  'เฟิร์น',
#  'สมเด็จพระเจ้าบรมวงศ์เธอกรมพระนครสวรรค์วรพินิต',
#  'ปลาเรนโบว์เทราต์',
#  'แอฟริกาใต้สะฮารา',
#  'ติดอ่าง',
#  'รุ่นเวลเตอร์เวทบุคคลหญิง',
#  'นูร์มูฮัมหมัดตะรากี',
#  'จางยองชิล',
#  'ชุมเห็ดเล็ก',
#  'เทศบาลตำบลหนองควาย',
#  'โซซีบีนีทุนซี',
#  'ร็อธ',
#  'นินเท็นโดดีเอส',
#  'ฟูกูดะ',
#  'ตีโบ',
#  'บางกอกเลิฟสตอรี',
#  'วัดลัดทรายมูล',
#  'อายุที่ยอมให้ร่วมประเวณีได้',
#  'หม่อมเจ้าวิภาวดี',
#  'พริ้งอินทโชติ',
#  'ซิงเกิลแบล็กพิงก์',
#  'ขีปนาวุธ',
#  'โดราเอมอนตอนโนบิตะกับตำนานคนยักษ์สีเขียว',
#  'ฟุตบอลทีมชาติเซนต์คิตส์และเนวิส',
#  'ทีแกน',
#  'แต้ฮั้ว',
#  'ดาควิส',
#  'แสด',
#  'สมบูรณ์ทรัพย์',
#  'ปืนกลแบบ',
#  'ถนนนิเวศรัตน์',
#  'พัว',
#  'บ็อบอาร์มสตรอง',
#  'วัดเกาะแก้วสุทธาราม',
#  'ขั้นตอนวิธีการค้นแบบดีที่สุด',
#  'หลอดเลือดดำเล็ก',
#  'อิซุมิซากาอิ',
#  'แชมปา',
#  'ดาร์บี้อัลลิน',
#  'ชอฮีซินดา',
#  'ระเบียบการคุ้มครองข้อมูลทั่วไป',
#  'บ้านหนองพังแค',
#  'ซามูไรดีปเปอร์เคียว',
#  'เต่าหัวค้อน',
#  'แบบจำลองมี',
#  'โรดรีกูฟราอูชีส',
#  'กระเพาะปลา',
#  'กลุ่มอัปเปอร์แซกซัน',
#  'อยู่โพธิ์',
#  'อังเคโล',
#  'ราชอาณาจักรภูฏาน',
#  'แฟนเทเซีย',
#  'กระบี่อิงฟ้า',
#  'คฤหาสน์ฮาวเวิร์ด',
#  'แอดกินส์',
#  'ตลาดหลักทรัพย์มาดริด',
#  'เกรด',
#  'มัดเราะซะฮ์โกกัลดอช',
#  'คตินิยมเส้นกั้นสี',
#  'ดีเจ',
#  'แม่น้ำยูเฟรทีส',
#  'แกรนด์สแลมแชมเปี้ยนชิพ',
#  'คลองบุน้ำรักษ์',
#  'กลุ่มดาวเปอร์เซอุส',
#  'ตำแหน่งผู้เล่นฟุตบอล',
#  'จังนารา',
#  'สถานีรถไฟหนองแก',
#  'วัดไทรย้อย',
#  'โพด็อลสกี',
#  'ปลาตะพาก',
#  'โตยิเบียฟ',
#  'ราชการข่าวกรองลับ']

# %% [markdown]
# ## Save

# %%
with open("wikipedia_nlp.txt", "w", encoding="utf-8") as f:
    f.write("\n".join(titles))
