# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
len(titles)
# Out:
# 362955

# %%
get_samples(titles)
# Out:
# ['สัญญาณรบกวนจอห์นสัน–นือควิสต์',
#  'วอลเลย์บอลชายทีมชาติปารากวัย',
#  'รังสีเทราเฮิรตซ์',
#  'ปฏิทินโจเกียว',
#  'Diesel_exhaust',
#  'ธิรดา_สนิทวงศ์ชัย',
#  'พระเจ้าเฮโรดมหาราช',
#  'หอยสังข์มะระ',
#  "Wanna_Be_Startin'_Somethin'_2008",
#  'ควีนส์คัพ',
#  'จอมใจเจ้าป่า',
#  'ฮัลโหลวีนัส',
#  'กีฬากระโดดน้ำในโอลิมปิกฤดูร้อน_2020_–_สปริงบอร์ด_3_เมตร_ชายคู่',
#  'มรณกรรม',
#  'ทริปซิน_(Trypsin)',
#  'วัดโรงเข้วนาราม',
#  'Calgary,_Alberta',
#  'บับเบิ้ลฟิคชั่น:_บูม_ออร์_บัสท์',
#  'เนียง',
#  'วังท้ายวัดพระเชตุพนวิมลมังคลาราม',
#  'เมทริกซ์แอร์มิต',
#  'Badis_ruber',
#  'สนามกีฬาริเวอร์ไซด์',
#  'Cayman_Islands',
#  'My_life_as_a_teenage_robot',
#  'ประชาคมฝรั่งเศสแห่งเบลเยียม',
#  'Chancels',
#  'ฮัม_อึน-จอง',
#  'โอลีเฟอร์_ซตริทเซิล',
#  'ค.ศ._915',
#  'ปูมราชธรรม',
#  'Lince_Dorado',
#  'จูจูจู_โบกูระโนะมิราอิ/ไดจินเซ_เนเวอร์บีนเบ็ทเตอร์!',
#  'สุรนันท์_เวชชาชีวะ',
#  'หลวงปู่มั่น_ภูริทตฺโต',
#  'เจ้าชายชาลส์_เอ็ดเวิร์ด_ดยุกแห่งซัคเซิน-โคบูร์กและโกทา',
#  'Kiss_Me_Five',
#  'อาเธอร์_กรีกอเรียน',
#  'ไวเอต',
#  'รูปาตาดีน',
#  'สุรีย์วัลย์_สุริยง',
#  'มักนุส_มุนซเค',
#  'Egyptian_cobra',
#  'สตั๊ก_44',
#  'นอแว',
#  'Development_of_the_human_brain',
#  'การพิมพ์_3_มิติ',
#  'เขาพลองสเตเดียม',
#  'อี_มินโฮ',
#  'ฮานี_(นักร้อง)',
#  "FIFA_U-17_Women's_World_Cup",
#  'สหภาพประชาธิปไตยปาเลสไตน์',
#  '440_ปีก่อนคริสตกาล',
#  'ต๋อง_ศิษย์ฉ่อย',
#  'Vremya',
#  'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน_1968',
#  'Maize_oil',
#  'Madden_NFL_22',
#  'อเมริกาส์_เน็กซ์_ท็อป_โมเดล_,_ฤดูกาลที่_2',
#  'ค่าเฉลี่ย_(แก้ความกำกวม)',
#  'มหาวิทยาลัยมหาจุฬาลงกรณราชวิทยาลัย',
#  'ไมโครพลาสมา',
#  'โพธิสัตว์ศีล',
#  'นางแย้มป่า',
#  'แม่น้ำหวงฉุ่ย',
#  'ค.ศ._1458',
#  'พระเจ้าบรมวงศ์เธอ_พระองค์เจ้าโต_กรมหลวงมหิศวรินทรามเรศร์',
#  'อูโก_กิยามอน',
#  'ประเทศอัฟกานิสถานในโอลิมปิกฤดูร้อน_2012',
#  'คอร์ปุส_คาเวอร์โนซุม_พีนิส',
#  'นักพัฒนาโปรแกรม',
#  "St._Michael's_Church,_Cluj-Napoca",
#  'Sylvie_(Marvel_Cinematic_Universe)',
#  'คิม_ข่าน_ซากิ',
#  'Ginglymostoma',
#  'สาธารณรัฐมองโกเลียในโอลิมปิกฤดูหนาว_2006',
#  'Simeticone',
#  'ทูเดย์วอสอะเฟรีเทล',
#  'นีกอลา_เฌสกีแยร์',
#  'H._s._rhodesiensis',
#  'ปตท._สำรวจและผลิตปิโตรเลียม',
#  'Liebesgruss',
#  'Aya_matsuura',
#  'ซากิ_นากาจิมะ',
#  'วัดวิเวกวายุพัด',
#  'รอย_ฮอดจ์สัน',
#  'ณัฐนนท์_กัจฉปานันท์',
#  'วัดสุวรรณ_(กรุงเทพมหานคร)',
#  'เทค_แบ็ค',
#  'เป็นต่อ_ขั้นเทพ',
#  'เครื่องเร่งอนุภาค',
#  'Fuernrohria',
#  'รัฐอิสราเอลในโอลิมปิกฤดูหนาว_2006',
#  'วอลเลย์บอลในกีฬามหาวิทยาลัยโลกฤดูร้อน_1961',
#  'Blood_test',
#  'เส้นเวลาของสงครามโลกครั้งที่สอง_(1944)',
#  'Narwhal',
#  'ไอ_อนิเมะ',
#  'รายพระนามเจ้านายพระชันษายืนในราชสกุลรัชกาลที่_1_แห่งพระราชวงศ์จักรี',
#  'มือตบ']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

len(titles)
# Out:
# 353833

# %%
get_samples(titles)
# Out:
# ['รัฐปาเลสไตน์ในโอลิมปิกฤดูร้อน_2020',
#  'เรียว_มิยาอิจิ',
#  'The_Love_Machine_วงล้อ_ลุ้นรัก',
#  'มังกี้_ฮีโร่',
#  'ช่องแคบยิบรอลตา',
#  'สิงห์ผจญเพลิง',
#  'จ็อกกิง',
#  'สาธารณรัฐเบลารุสในพาราลิมปิกฤดูร้อน_2012',
#  'เอาดี้',
#  'บริษัท_ไชโยโปรดักชั่นส์_จำกัด',
#  'เยื่อพรหมจรรย์',
#  'เส้นขนานที่_48',
#  'ประเทศแอฟริกาใต้ในโอลิมปิกเยาวชนฤดูร้อน_2014',
#  'Monotrete_leiurus',
#  'โรโบคอป_3',
#  'First_Anglo-Burmese_War',
#  'มหาวิหารตูลูซ',
#  'ไข่มดแดง',
#  'มาฬิศร์_เชยโสภณ',
#  'ล่าคนดุในเมืองเดือด',
#  'Indiana',
#  'โทนี_แอนเดอร์สัน',
#  'มูลนิธิวงดุริยางค์ซิมโฟนีกรุงเทพ',
#  'โทรทัศน์ความละเอียดสูง',
#  'วัดเป่ากั๋ว',
#  'Trachicephalus',
#  'ธงชาติกาตาร์',
#  'แฮรี่',
#  'เดอะ_เมทริกซ์_:_เพาะพันธุ์มนุษย์เหนือโลก_2199',
#  'ปาตานี',
#  'ลาดัก',
#  'Nic_Nemeth',
#  'ราชวงศ์โจวเหนือ',
#  'สึโทะมุ_โคะยะมะ',
#  'วัดหงส์รัตนารามราชวรวิหาร',
#  'เทศบาลเมืองบ้านไผ่',
#  'เรื่องขบขัน',
#  'โรคโลหิตจางเหตุพร่องธาตุเหล็ก',
#  'อัมเปิลเม็นเชิน',
#  'เซนต์ปีเตอร์เบิร์ก',
#  'อินาสึมะอีเลฟเวน_3_เซไคโนะโชวเชน',
#  'รถไฟฟ้าเสิ่นหยาง',
#  'เมืองมิโน',
#  'แบรด_พิทท์',
#  'Bartolomé_Estéban_Murillo',
#  'Academy_Awards/Writing_Screenplay_Adaptation',
#  'Fiji_Banded_Iguana',
#  'ซาลิม_อาลีโยว_อิบรอม',
#  'FC_Groningen',
#  'ประเทศโกตดิวัวร์',
#  'วัดหนองหมูใต้',
#  'ผลงานซิงเกิลของอิล_ดิโว่',
#  'ไทยรัฐ',
#  'ทัลก์',
#  'TOT_S.C.',
#  'ฝันร้าย',
#  'ทิศพายัพ',
#  'Hymenoceridae',
#  'สโมสรฟุตบอลแบล็คพูล',
#  'รัฐมาร์เกรฟบรันเดินบวร์ค',
#  'Nymphenburg_Palace',
#  'เอไลจาห์_วูด',
#  'กองพัน_SOS',
#  'สนามกีฬาชวาหระลาล_เนห์รู',
#  'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน_2020_–_ทีมหญิง',
#  'ประเทศอิตาลีในโอลิมปิกเยาวชนฤดูหนาว_2020',
#  'จิรายุ_ตั้งศรีสุข',
#  'จังหวัดอาร์มาวีร์',
#  'Cross_of_St_James',
#  'โมเดลทางคณิตศาสตร์',
#  'ธงฉาน',
#  'วัดไตรธรรมาราม',
#  'ชิเบนีก',
#  'Viraat_Ramayan_Mandir',
#  'Yorkshire',
#  'ทิคอนเดโรกา',
#  'การเตรียมกาแฟ',
#  'ไม้ที',
#  'Song_Yuvin',
#  'Haliaeetus_leucocephalus',
#  'มาสค์ไรเดอร์_ซีรีส์',
#  'อัคคีภัยครั้งใหญ่ในลอนดอน_ค.ศ._1666',
#  'เจลลี่_ร็อคเก็ต',
#  'ระบบสายตา',
#  'น่ารัก',
#  'ชาวอินเดีย',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติ_ครั้งที่_47',
#  'นักบุญมรณสักขีแห่งประเทศจีน',
#  'Switzerland',
#  'คณะครุศาสตร์_มหาวิทยาลัยราชภัฏอุตรดิตถ์',
#  'สนธิสัญญาทรียานง',
#  'กาหยี',
#  'Dolores_Huerta',
#  'เอดิต_ยอร์ก',
#  'ไรโบส',
#  'เส้นเมริเดียนที่_50',
#  'Dragon_Ball:_The_Path_to_Power',
#  'ที่หยุดรถไฟบ้านโนนผึ้ง',
#  'จรวยพร_ธรณินทร์',
#  'Santisukia_pagetii']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

len(titles)
# Out:
# 465912

# %%
get_samples(titles)
# Out:
# ['เห็ดเนี๋ยวจังจือ',
#  'เกาลัด',
#  'ตั๊บแซ่ลิ้ม',
#  'Saarland',
#  'ลัทธิอนาธิปไตยสังคมนิยม',
#  'ถนนกำแพงเพชร3',
#  'โยชิฮิซะ',
#  'อาบีดิน',
#  'เรือพระราชพีธีกระบวนพยุหยาตราชลมารค',
#  'แม็กนาวอกซ์โอดีสซี',
#  'Mary,Turkmenistan',
#  'อาร์นไฮม',
#  'ครุยวิทยฐานะในสหรัฐ',
#  'เจพีคัลเดอรอน',
#  'วัดซานตามาเรียเดลเลกราซี',
#  'แพนเซอร์เกรนาดีร์',
#  'BlueRiband',
#  'คัมภีร์ในสารบบ',
#  'พ.ศ.2314',
#  'สุลต่านอิสมาอิลเปตรา',
#  'ค.ศ.887',
#  'Cameroun,',
#  'ไฟลัมไลโคไฟตา',
#  'โทะกิฮิโกะ',
#  'ไซโดเรนโก',
#  'Presliophytum',
#  'แอนโทนิโอแบนเดรัส',
#  'พิศวงไทยทอง',
#  'เส้นขนานที่51',
#  'ประเทศลีชเทินชไตน์ในโอลิมปิกฤดูหนาว2018',
#  'แฮร์รี่พอตเตอร์:ฮอกวอตส์มิสทะรี',
#  'ซูเปอร์สตาร์เจวายพี',
#  'เลบรอน',
#  'แอฟริกาเหนือของอิตาลี',
#  'มาร์เซีย',
#  'มหาวิทยาลัยราชภัฏกำแพงเพชร',
#  'พระเจ้าสูรยวรมันที่',
#  'Vault',
#  'WrestleMania17',
#  'โยฮันน์โวล์ฟกังฟอนเกอเท',
#  'กีรติ',
#  'Maxillipiidae',
#  'Pastel',
#  'พระเจ้ามูแห่งบัลแฮ',
#  'ทางหลวงชนบทนบ.1013',
#  'ชิดชนก',
#  'แก่งสะพือ',
#  'เจฟฟรีโอนาเต้',
#  'สติลเล่อร์',
#  'Prakash',
#  'แฮปปี้',
#  'FyodorDostoevsky',
#  'เจ้าหญิงมารี',
#  'มิทาราชิ',
#  'X–เม็น:กำเนิดวูล์ฟเวอรีน',
#  'กรมปฏิบัติการพิเศษหน่วยบัญชาการอากาศโยธิน',
#  'มุอัมมาร์อัลกัดดะฟี',
#  'เทลิโทรมัยซิน',
#  'Octave',
#  'เบเดล',
#  "Notre-Dame-de-l'Assomption",
#  'ภาษาซึนลาว',
#  'Medicalbandwagon',
#  'เต็กเลา',
#  'สกุลปาหนันช้าง',
#  'โกปาอาเมริกา2019กลุ่มบี',
#  'StephanieMcMahon-Helmsley',
#  'พระเจ้าโจวจวง',
#  'เซนได',
#  'ตำบลโจลกอฮ์',
#  'Pitviper',
#  'สมาคมเอเอสทีเอ็ม',
#  'RyoMiyaichi',
#  'ชียากูซิลวา',
#  'รุกขกาลวิทยา',
#  'อะกอบะฮ์',
#  'แบนแนน',
#  'มิซซี่',
#  'Keep',
#  'พิวดีพายปะทะที-ซีรีส์',
#  'JingKe',
#  'แผ่นดินไหวโลมาพรีเอตตา',
#  'วัดหนองเพียร',
#  'ฟุตซอลในเอเชียนอินดอร์เกมส์',
#  'เพลงชาติปาเลสไตน์',
#  'อาหารอันฮุย',
#  'Boutu',
#  'ทราวิสสก็อตต์',
#  'Tabloidpress',
#  'ตอนเย็น',
#  'LudwigIIofBavaria',
#  'เกงซาโตว',
#  'มาลากอน',
#  'ชาวฮังกาเรียนอเมริกัน',
#  'Dekoboko',
#  'แรงปฏิกิริยา',
#  'ชิซากิ',
#  'อ่าวบอธเนีย',
#  'ฟาโรห์เซนุสเรตที่หนึ่ง',
#  'ฮามิลตงซูวาริส']

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

len(titles)
# Out:
# 346494

# %%
get_samples(titles)
# Out:
# ['ปลามางุโระ',
#  'พระปิ่นเกล้าเจ้าอยู่หัว',
#  'ยางซอม',
#  'ปวดหัว',
#  'เอกนิษฐ์ปัญญา',
#  'เห้ง',
#  'การควบคุมอาหารแบบแม็กโครไบโอติกส์',
#  'สายลับเดอะซีรี่ย์',
#  'ฟีนิกซ์อิคคิ',
#  'ดิจิมอนแอดเวนเจอร์',
#  'โลกธรรม๘',
#  'ยูฟ่ารีเจี้ยนส์คัพ',
#  'อยากตาย',
#  'กลุ่มภาษาอาเจะฮ์-จาม',
#  'วงศ์ย่อยปลาหมอจำปะ',
#  'สนฺตงฺกุโร',
#  'ศิวัฒน์โชติชัยชรินทร์',
#  'โกฐสิงคลี',
#  'หน้าต่างสีชมพูประตูสีฟ้า',
#  'ลูกไทย',
#  'ภูมิคุ้มกันรับมา',
#  'สโมสรฟุตบอลนครราชสีมามาสด้าในฤดูกาล2558',
#  'บรันสวิค-วูลเฟนบืตเตล',
#  'พระสุพาหุเถระ',
#  'อูอี',
#  'เดอะออนะระเบิล',
#  'ภูเขาคิตะ',
#  'เอเตียน-หลุยส์มาลุส',
#  'ชูเอาชิลเบร์ตู',
#  'สหพันธ์ฟุตบอลอัฟกานิสถาน',
#  'มายุมิเนดะ',
#  'ค.ศ.2010',
#  'วงศ์ไฮยีนา',
#  'อนิเมะฤดูกาลที่3',
#  'ไมโครฟิลาเมนต์',
#  'มาซาเฮอร์ตา',
#  'ฟุมิโกะอุจิมุระ',
#  'ฟูจิวาระโนะคาเนฟูซะ',
#  'สิรีภรณ์ยุกตะทัต',
#  'คริสตียงเบนเตเก',
#  'พอร์ตแลนด์',
#  'อูโกกาซาเรส',
#  'ปะฉะดะคนเหนือยุทธ',
#  'พรก.',
#  'ป่าพรุโต๊ะแดง',
#  'พระเจ้าอูซะนาที่',
#  'พิชิตศิษย์บางพระจันทร์',
#  'รายชื่อแขกรับเชิญใน',
#  'ปราสาทคาร์ดิฟฟ์',
#  'ฮาราเร',
#  'จ.ม.',
#  'อาร์ชดยุกคาร์ลดยุกแห่งเทเชิน',
#  'โภคกุลกานนท์',
#  'สาปภูษา',
#  'นักบุญแคทเธอรินแห่งอเล็กซานเดรีย',
#  'ดาวแคระน้ำตาล',
#  'แ',
#  'กรมหมื่นพิทยาลงกรณ์',
#  'พ.ศ.1280',
#  'นีเฮา',
#  'อีกอร์สมอลนีคอฟ',
#  'ชาวโครแอต',
#  'สนามรบจำลอง',
#  'ดรีเมอร์',
#  'เหตุการณ์โจมตีเรือประมงไต้หวันโดยยามชายฝั่งฟิลิปปินส์',
#  'พระเจ้าศิริธรรมจักรพรรดิ',
#  'รายนามประธานรัฐสภาไทย',
#  'เทือกเขาเหิงตฺวั้น',
#  'วาราบิโมจิ',
#  'ชางเกียงกุง',
#  'กีฬาโรลเลอร์สกีในกีฬาแห่งชาติครั้งที่47',
#  'เยลี่ว์หร่วน',
#  'ปิแอร์กิลลอเมเฟรเดริกเลอเปล',
#  'ไอค์เคอ',
#  'ตอมาช',
#  'ริ-เซ่',
#  'ปลาหมอออสเซลาลิส',
#  'เค้กวันเกิด',
#  'เตรียมอุดมศึกษา',
#  'รายชื่อผู้เล่นสโมสรฟุตบอลลิเวอร์พูล',
#  'ฟุตบอลลีกคัพ2000นัดชิงชนะเลิศ',
#  'จิซากิ',
#  'พระเจ้าอีริคที่6แห่งเดนมาร์ก',
#  'พระเจ้าน้องยาเธอพระองค์เจ้าดิศวรกุมารกรมหลวงดำรงราชานุภาพ',
#  'ดาวรอบขั้วฟ้าเหนือ',
#  'วัดชิโนรสารามวรวิหาร',
#  'ศิลปะนีโอคลาสสิก',
#  'วัดบางปลา',
#  'ริคกี้"เดอะดราก้อน"สตีมโบ๊ต',
#  'คณะเทคโนโลยีการเกษตรมหาวิทยาลัยบูรพาวิทยาเขตสระแก้ว',
#  'ฟาโรห์เวเนก-เนบตี้',
#  'ซัมซุงกาแลคซีโน้ต4',
#  'เครื่องราชอิสริยาภรณ์อันมีเกียรติแห่งความกล้าหาญ',
#  'องค์การระหว่างประเทศเพื่อการอนุรักษ์ธรรมชาติ',
#  'ยูโกะซัมเป',
#  'สอาดเปี่ยมพงษ์สานต์',
#  'สือชิงเสวียน',
#  'พายุไต้ฝุ่นนิดา',
#  'อักษรอินุกติตุต',
#  'สเปรย์กระป๋อง']

# %% [markdown]
# ### Seperate colon

# %%
len([title for title in titles if ":" in title])
# Out:
# 1465

# %%
[title for title in titles if ":" in title][:50]
# Out:
# ['เลือดชั่ว:เรื่องลับและคำลวงเบื้องหลังบริษัทดาวรุ่งแห่งซิลิคอนแวลลีย์',
#  'เรฟโวลูชั่นส์:',
#  'ทอมแอนเจอร์รี่:',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:ฟิลาเดลเฟีย',
#  'รายชื่อตอนในเบ็นเท็น:อัลติเมทเอเลี่ยน',
#  'คอลล์ออฟดิวตี:มอเดิร์นวอร์แฟร์',
#  'เดอะเลเจนด์ออฟเซลดา:อะลิงก์ทูเดอะแพสต์และโฟร์ซอดส์',
#  'นักรบมนตรา:',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:บรุกลิน',
#  'หวงเฟยหง:ถล่มวังบัวขาว',
#  'คอลล์ออฟดิวตี:มอเดิร์นวอร์แฟร์III',
#  'สไปเดอร์-แมน:ผงาดข้ามจักรวาลแมงมุม',
#  'เคาน์เตอร์-สไตรก์:',
#  'เบอร์ดีวิง:กอล์ฟเกิร์ลสตอรี',
#  'ชิฟท์2:อันลีชด์',
#  'สตาร์เทรค:',
#  'ยอดนักสืบจิ๋วโคนัน:เจ้าสาวฮาโลวีน',
#  'เดอะเลเจนด์ออฟเซลดา:ทไวไลต์พรินเซสส์',
#  'โรบินฮูด:เดอะเลเจนด์ออฟเชอร์วูด',
#  'แอสแซสซินครีด:รีวีเลชั่นส์',
#  'เทอร์มิเนเตอร์:',
#  'คิงดอมส์ออฟแอมะเลอร์:เรกคอนนิ่ง',
#  'มาสค์ไรเดอร์ริวคิ:เอ็ดพิโซดไฟนอล',
#  'มาเลฟิเซนต์:',
#  'ไมเคิลแจ็กสัน:ดิเอ็กซ์เพอร์เรนช์',
#  'เบ็นเท็น:อัลติเมทเอเลี่ยน',
#  'เดอะซิมส์3:เล็ตไนต์',
#  'โคลสคอมแบต:',
#  'คังคุไบ:',
#  'แฮร์รี่พอตเตอร์:ฮอกวอตส์มิสเตอรี',
#  'ยอดนักสืบจิ๋วโคนัน:เรือดำน้ำทมิฬ',
#  'ไฮห์สกูลมิวสิคัล3:ซีเนียร์เยียร์',
#  'กัปตันอเมริกา:ซีวิลวอร์',
#  'อภินิหารตำนานแห่งนาร์เนีย3:ผจญภัยโพ้นทะเล',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:อาร์เอฟโวลูชั่น',
#  'เซกิโระ:',
#  'อิสลาม:ว็อทเดอะเวสเทิร์นนีดส์ทูโนว์',
#  'คอมมานด์แอนด์คองเคอร์:เจเนรัลส์',
#  'จักรวาลภาพยนตร์มาร์เวล:เฟสห้า',
#  'ICD-10บทV,W,X,และY:สาเหตุภายนอกที่ทำให้เกิดพยาธิภาวะและการตาย',
#  'มายเลิฟ:',
#  'นีดฟอร์สปีด:ฮอตเพอร์ซูท',
#  'มาร์เวลสตูดิโอส์:',
#  '6:66ตายไม่ได้ตาย',
#  'ทีนเอจมิวแตนต์นินจาเทอร์เทิลส์:',
#  'ทรานส์ฟอร์เมอร์ส:สงครามไซเบอร์ทรอนไตรภาค',
#  'เมตันเตโคนัง:',
#  'เซอร์ไวเวอร์ปานามา:เกาะอัปยศ',
#  'มิชชั่น:อิมพอสซิเบิ้ล',
#  'เมโทร:']

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    if ":" in title:
        titles_temp.update(title.split(":"))
    else:
        titles_temp.add(title)
    
titles = titles_temp
len(titles)
# Out:
# 345587

# %%
get_samples(titles)
# Out:
# ['นกนางแอ่นบ้าน',
#  'เบบีวอกซ์รีฟ',
#  'จักรพรรดิเว่ยเต้าอู่',
#  'สมบูรณ์ไพรคุก',
#  'เถื่อนเฉือนระห่ำ',
#  'ฟาโรห์อเมนโฮเทปที่หนึ่ง',
#  'ดิเอ็กซ์แฟกเตอร์ประเทศไทย',
#  'ความจำ',
#  'ซีก',
#  'สวนเบญจกิติ',
#  'วอลลิสดัชเชสแห่งวินด์เซอร์',
#  'ภาษาไทอ่ายตน',
#  'ยุวกาชาดไทย',
#  'เดอะเฟซเวียดนาม',
#  'คลองชุมพร',
#  'อาเล็กซ์เพียร์ซ',
#  'ซันไซน์&ซิตี้ไลท์ส',
#  'พ่อครัวตัวจี๊ด',
#  'นกกด',
#  'สกุลนกกระทุง',
#  'สาธารณรัฐอาร์เมเนียในโอลิมปิกฤดูร้อน2000',
#  'ไฟป่าในรัฐฮาวายพ.ศ.2566',
#  'ยูเอวี',
#  'อะกิฮะบะระ',
#  'เจมส์โจเซฟซิลเวสเตอร์',
#  'กรอจแบนด์',
#  'การเชื่อมเหล็ก',
#  'รักซ้อนซ่อนรัก',
#  'ความเอนเอียงโดยความเข้าถึงได้ง่าย',
#  'โคโซคุเซนไทเทอร์โบเรนเจอร์',
#  'จังหวัดนีเด',
#  'ปอมปาดัวร์น้ำเงิน',
#  'จรูญพงศ์พันธุ์ศรีนคร',
#  'ซิมโฟนีหมายเลข8',
#  'หน่วยบัญชาการยุทธการพิเศษสหรัฐ',
#  'ผู้เล่นในเอเชียนคัพ',
#  'สายพันธุ์ของเชื้อโควิด-19',
#  'ชุมนุมสมัยกรุงธนบุรี',
#  'มาสค์ไรเดอร์Xมาสค์ไรเดอร์ไดรฟ์&ไกมุสงครามไรเดอร์ครั้งใหม่',
#  'ยุกต์ส่งไพศาล',
#  'รูเซล',
#  'พระโพธิสัตว์กวนอิมพันมือแห่งกุยชาน',
#  'ต้นพระชัยศรีมหาโพธิ์',
#  '4ต่อ4ฮอลิเดย์',
#  'โบบาเฟตต์',
#  'อาชวดิศดิศกุล',
#  'ชัยสิงห์ที่',
#  'พระชคันนาถ',
#  'โควิดสายพันธุ์เดลต้า',
#  'สฟาลบาร์และยานไมเอน',
#  'เครือข่ายฟ็อกซ์',
#  '๓๑สิงหาคม',
#  'เลี่ยง',
#  'สีสุวัตถิ์ยุตติวงศ์',
#  'ยุคหลังสงครามโลกครั้งที่2',
#  'ฮาเลย์เดวิดสันสตรีทบ็อบ',
#  'โคเรียนแอร์เที่ยวบินที่801',
#  'ประเทศตองงาในโอลิมปิกฤดูหนาว',
#  'พระไพรีพินาศ',
#  'จิรชัยประวิตร',
#  'วอลเลย์บอลชายชิงแชมป์นอร์เซกา2017',
#  'ฟานก็อกฮ์',
#  'ราชปะแตน',
#  'รายพระนามพระมหากษัตริย์แห่งราชอาณาจักรซิซิลีทั้งสอง',
#  'ยุคคาร์โบนิเฟอรัส',
#  'คณะศึกษาศาสตร์มหาวิทยาลัยขอนแก่น',
#  'จังหวัดธัญญบุรี',
#  'สาธารณรัฐเวียดนามใต้',
#  'เลดีเอลิซาเบธ',
#  'ประเทศโมร็อกโกในโอลิมปิก',
#  'การใส่ท่อช่วยหายใจ',
#  'ส.',
#  'อชิระ',
#  'ซากาอิ',
#  'ดุกลำพัน',
#  'บิกแบง',
#  'บาย',
#  'เฮซอน',
#  'รนิล',
#  'พระครูนิทัศนพลธรรม',
#  'ความน่าจะเป็นบนเส้นขนาน',
#  'ทรงสี่เหลี่ยมจัตุรัส',
#  'เก้ามหากาฬ',
#  'คณะอุตสาหกรรมเกษตร',
#  'เจ้าชายลูทวิชแห่งบัทเทินแบร์ค',
#  'สงครามจักรกล',
#  'ชาจิกุ-ซัง',
#  'ซันดากัน',
#  'แหล่งเหมืองหลักแห่งวอลโลเนีย',
#  'สมาชิกวุฒิสภาจังหวัดชัยนาท',
#  'ปาณินท์',
#  'อิมมอร์แทลิที',
#  'คิมโซอึน',
#  'ขอร้อง',
#  'ตรรมันจัณมุกรัตตินัม',
#  'ฮ็อสตีลิอุส',
#  'เขตรักษาพันธุ์สัตว์ป่าเขาสอยดาว',
#  'มะคุระโนะโซชิ',
#  'พงศ์สันต์',
#  'กองทัพปฏิวัติโซมี']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4992

# %%
get_samples(raay)
# Out:
# ['รายการแหล่งมรดกโลกในประเทศพม่า',
#  'รายชื่อแมว',
#  'รายชื่อแหล่งมรดกโลกในประเทศโมร็อกโก',
#  'รายชื่อของเทศบาลในประเทศไทย',
#  'รายชื่อธงในประเทศฟิลิปปินส์',
#  'รายนามบุคคลที่มีชื่อเสียงจากมหาวิทยาลัยขอนแก่น',
#  'รายชื่ออธิบดีกรมประมง',
#  'รายชื่อรองประธานาธิบดีสหรัฐ',
#  'รายชื่อธงในประเทศเวเนซุเอลา',
#  'รายชื่อแหล่งมรดกโลกในยุโรปใต้',
#  'รายชื่อรางวัลที่ซิสตาร์ได้รับและได้เข้าชิง',
#  'รายชื่อการ์ดไดซ์โอ',
#  'รายชื่อตัวละครในเซียนเกมรักขอเป็นเทพนักจีบ',
#  'รายชื่ออุทยานธรณีโลกในทวีปเอเชีย',
#  'รายชื่อโบราณสถานในจังหวัดสกลนครที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายการวันสำคัญทางศาสนาคริสต์',
#  'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย/ว',
#  'รายชื่อแหล่งมรดกโลกในประเทศเลโซโท',
#  'รายชื่อสกุลในวงศ์Histeridae',
#  'รายชื่อทางแยกในเขตจตุจักร',
#  'รายชื่อตัวละครในเรื่อง',
#  'รายชื่อเลขาธิการสมาคมประชาชาติแห่งเอเชียตะวันออกเฉียงใต้',
#  'รายชื่อแหล่งมรดกโลกในประเทศนิวซีแลนด์',
#  'รายชื่อแคว้นของประเทศทาจิกิสถานเรียงตามดัชนีการพัฒนามนุษย์',
#  'รายนามประมุขแห่งรัฐฮังการี',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2506',
#  'รายพระนามพระมเหสีพระสนมเอกพระคู่หมั้นและพระราชธิดาในรัชกาลที่6',
#  'รายชื่อสปีชีส์ในสกุลทุเรียน',
#  'รายชื่อศูนย์การค้าในประเทศไทย',
#  'รายชื่อพายุเฮอริเคนแอตแลนติกที่ถูกถอนชื่อ',
#  'รายชื่อประเทศเรียงตามขนาดเครือข่ายทางรถไฟ',
#  'รายพระนามพระมหากษัตริย์และจักรพรรดิเยอรมนี',
#  'รายชื่อผู้ครองตำแหน่งนางงามจักรวาล',
#  'รายชื่อองค์กรปกครองส่วนท้องถิ่นในจังหวัดอุดรธานี',
#  'รายชื่อผลงานวิดีโอของที-อารา',
#  'รายชื่อภาพยนตร์โดยมาร์เวลคอมิกส์',
#  'รายชื่อโบราณสถานในจังหวัดมหาสารคาม',
#  'รายชื่อผลงานเพลงของไมคุระกิ',
#  'รายชื่อธงในสหรัฐอเมริกา',
#  'รายนามประธานาธิบดีสหรัฐ',
#  'รายชื่อผลงานเพลงของสเตรย์คิดส์',
#  'รายชื่อโบราณสถานในจังหวัดบุรีรัมย์ที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อโบราณสถานในจังหวัดศรีสะเกษที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อเพลงที่บันทึกโดยเทย์เลอร์',
#  'รายชื่อผลงานของเอเคบีโฟร์ตีเอต',
#  'รายพระนามและรายนามผู้เชิญเครื่องพระอิสริยยศ',
#  'รายชื่อประเทศเรียงตามการได้ส่วนแบ่งตลาดจากสมาร์ทโฟน',
#  'รายชื่ออาณาจักรดยุคและขุนนางสืบตระกูลของหมู่เกาะอังกฤษ',
#  'รายชื่อแขกในพระราชพิธีราชาภิเษกของสมเด็จพระเจ้าชาลส์ที่',
#  'รายชื่อตอนในเซียนเกมรัก',
#  'รายชื่อบุคคลสำคัญจากมหาวิทยาลัยสงขลานครินทร์',
#  'รายการเครื่องอิสริยาภรณ์ราชวงศ์ชิง',
#  'รายพระนามและรายนามผู้ได้รับพระราชทานว.ภ.',
#  'รายชื่อพันธุ์ไม้มงคลพระราชทานประจำจังหวัด',
#  'รายชื่อสถานที่ท่องเที่ยวในกรุงเทพมหานคร',
#  'รายนามเวิลด์',
#  'รายพระนามและชื่อบุคคลสำคัญของโลกชาวไทยโดยยูเนสโก',
#  'รายการโทรทัศน์สั้น',
#  'รายชื่อแหล่งมรดกโลกในประเทศโครเอเชีย',
#  'รายชื่อวัดในจังหวัดนนทบุรี',
#  'รายชื่อตอนในการินปริศนาคดีอาถรรพ์',
#  'รายชื่อสวนสัตว์',
#  'รายชื่อนักมวยสากลชาวไทยที่เป็นแชมประดับภูมิภาค',
#  'รายชื่อผู้เล่นในการแข่งขันวอลเลย์บอลหญิงชิงแชมป์สโมสรเอเชีย',
#  'รายพระนามจักรพรรดินีญี่ปุ่น',
#  'รายชื่อสมาชิกวุฒิสภาสหรัฐชุดปัจจุบัน',
#  'รายชื่อรัฐเอกราชเรียงตามสินทรัพย์ต่างประเทศ',
#  'รายพระนามข่านแห่งคาซัค',
#  'รายนามภาพเขียนโดยเลโอนาร์โด',
#  'รายชื่อสนามบินในประเทศไทย',
#  'รายชื่อตัวละครในมิชชั่น',
#  'รายชื่อแชมป์ฟุตบอลเยอรมัน',
#  'รายนามผู้บัญชาการโรงเรียนนายร้อยพระจุลจอมเกล้า',
#  'รายชื่อวัดในจังหวัดสระบุรี',
#  'รายชื่อตัวละครในเกมเรซิเดนต์อีวิล',
#  'รายนามเมธีวิจัยอาวุโสสกว.',
#  'รายชื่อทางแยกในเขตบางกอกน้อย',
#  'รายชื่อเรือสำราญที่ยาวที่สุดในโลก',
#  'รายชื่อแหล่งมรดกโลกในประเทศสวีเดน',
#  'รายชื่อประเทศที่เป็นเกาะ',
#  'รายชื่อโบราณสถานในจังหวัดสุโขทัย/อำเภอเมือง',
#  'รายชื่อเพลงในเรื่องคุณครูจอมเวทเนกิมะ!',
#  'รายชื่อแหล่งมรดกโลกในประเทศศรีลังกา',
#  'รายชื่อตัวละครในเอ็กซีคิวชั่นแนล',
#  'รายชื่อแหล่งมรดกโลกในประเทศโปแลนด์',
#  'รายชื่อตัวละครในโซลอีทเตอร์',
#  'รายชื่อแหล่งมรดกโลกในประเทศไซปรัส',
#  'รายนามรัฐมนตรีช่วยว่าการกระทรวงกลาโหมของไทย',
#  'รายชื่อสายพันธุ์สุนัข',
#  'รายชื่อโบราณสถานในจังหวัดลพบุรีที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายนามเสนาบดีและรัฐมนตรีว่าการกระทรวงยุติธรรม',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์ฮาวาย',
#  'รายชื่อโรงเรียนในจังหวัดแม่ฮ่องสอน',
#  'รายชื่อประเทศเรียงตามผลผลิตลิเธียม',
#  'รายชื่อโรงแรมในประเทศไทย',
#  'รายชื่อตัวละครในเกิดชาตินี้พี่ต้องเทพ',
#  'รายนามหัวหน้ารัฐบาลหญิง',
#  'รายชื่อตอนในอินุยาฉะ',
#  'รายชื่อประเทศเรียงตามจำนวนสนามบินเฮลิคอปเตอร์',
#  'รายการอาการในรหัส']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 57

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°C',
#  'รายานนท์',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายวนปูเลาเกอลาปา',
#  'รายงานอาหาร',
#  'รายูวันปูเลาเกอลาปา',
#  'รายปุระ',
#  'รายงานประจำปี',
#  'รายกอวิช',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายาแห่งรัฐปะลิส',
#  'รายวน',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานการประชุม',
#  'รายาฮีเจา',
#  'รายงานกรณี',
#  'รายาแห่งซาราวะก์',
#  'รายงานเค้ส',
#  'รายตา',
#  'ราย',
#  'รายาบีรู',
#  'รายงานความสุขโลก',
#  'รายงานเฮิร์ช',
#  'รายงานผู้ป่วย',
#  'รายวนปูเลาเกอราปา',
#  'รายาอูงู',
#  'รายงานค่าใช้จ่าย',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายาห์',
#  'รายาผิวขาว',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายนานนท์',
#  'รายยวา',
#  'รายาประไหมสุหรีอากง',
#  'รายาแห่งซาราวัก',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายงานเคส',
#  'รายได้ประชาชาติ',
#  'รายคอวิช',
#  'รายงานทีหลัง',
#  'รายากูนิง',
#  'รายได้',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°ซ.',
#  'รายา',
#  'รายหัว',
#  'รายงานเรื่องอาหาร',
#  'รายได้มูลฐาน']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
len(titles)
# Out:
# 340652

# %%
get_samples(titles)
# Out:
# ['เว่ยเจี้ยน',
#  'ตีนเป็ด',
#  'วัดโพธิวิหาร',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูหนาว1968',
#  'สฺวียฺหวินลี่',
#  'เอ็กซ์พี',
#  'โพรเซสของกระดูกอัลนา',
#  'หนังสือผู้วินิจฉัย',
#  'ความโน้มถ่วงเชิงควอนตัม',
#  'อะลาโหมด',
#  'วัดห้วยบง',
#  'จินปาจิ',
#  'ยอดเขามองต์บลังก์',
#  'ปันวิชัย',
#  'ตามประทีป',
#  'ปะทานุกรมการทำของคาวหวานอย่างฝรั่งแลสยาม',
#  'เปโดรมาริโออัลบาเรซ',
#  'รูดอล์ฟเฮิสส์',
#  'เจ้าหญิงเอลิซาเบธดัชเชสแห่งบราบองต์',
#  'ฟาโรห์ซามาเจิกที่',
#  'สุทินวรรณบวร',
#  'ล้างเผ่าพันธุ์',
#  'กุลจรรยาวิวัฒน์',
#  'แล',
#  'อาเธอร์ฑูตจิ๋วเจาะขุมทรัพย์มหัศจรรย์',
#  'ยุทธการวูสเตอร์',
#  'ซามูไรคิโยโมริ',
#  'ฐณัณญาญ์',
#  'องค์ชายควางแฮ',
#  'ภาวะต้นกำเนิดต่างกัน',
#  'วรกมลชาเตอร์',
#  '5พยัคฆ์พิทักษ์ซุนยัดเซ็น',
#  'สเวดแบร์ย',
#  'รอยนูนรูปกระสวย',
#  'บอสตันมาราธอน',
#  'หมู่เกาะสุรินทร์',
#  'วงศ์ตาล',
#  'เฮิส',
#  'ไฮโก',
#  'คริสตัง',
#  'คุโรโบกุชิ',
#  'ไทยลีก3',
#  'คะสะเนะเตโตะ',
#  'ตลาดท่าเตียน',
#  'สรุปเหรียญโอลิมปิกฤดูหนาว1952',
#  'ธีระพันธ์',
#  'อำเภอธนบุรี',
#  'ทฤษฎีเซต',
#  'รอบสุดท้าย',
#  'กิลฟีชิกูร์สสัน',
#  'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน1992',
#  'รถไฟฟ้าไลท์เรล',
#  'วิภัชชวาท',
#  'แรง',
#  'เอ็นเตอร์เทนเมนต์วีกลี',
#  'ปกติสุรทิน',
#  'ซูตันชะฮ์รีร์',
#  'เดอลูน่า',
#  'โนเกียลูเมีย1320',
#  'กำเนิดสปีชีส์',
#  'บาตูตุด',
#  'โคย',
#  'เบญจรัตน์',
#  'จังหวัดเวียงจันทน์',
#  'กำปั่นกัมปนาทแสนยากร',
#  'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน2020–รอบคัดเลือกชาย',
#  'กระเพาะอาหาร',
#  'จีเอฟดับเบิลยูวูเมนแชมเปี้ยนชิพ',
#  'ก่อนคริสต์ศตวรรษที่',
#  'สมบูรณ์สุขนิยมศิริ',
#  'วอลเลย์บอลหญิงชิงแชมป์สโมสรเอเชีย2017',
#  'ศรสงคราม',
#  'ซานติอาโก้เบอร์นาบิว',
#  'โทรภาพ',
#  'กีฬาเบรกกิ้งในโอลิมปิกฤดูร้อน',
#  'งานเป่ายิ้งฉุบเลือกเซ็มบัตสึบีเอ็นเคโฟร์ตีเอตประจำปี2563',
#  'สุศรุตะ',
#  'ออตโตคาร์ที่2แห่งโบฮีเมีย',
#  'อิตส์พอสซิเบิล',
#  'วิลลีกาบาเยโร',
#  'โมโมโกะทานิ',
#  'รถรางในเวียนนา',
#  'พระราชพงศาวดารไทย',
#  'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–เซเบอร์บุคคลหญิง',
#  'อัลไซโอเน่',
#  'อาร์เอส.ฟิล์มแอนด์ดิสทริบิวชั่น',
#  'อำเภอแจ้ห่ม',
#  'แชร์พอยต์',
#  'ติกรีต',
#  'ยูริชิราโทริ',
#  'รัฐฉัตตีสครห์',
#  'โกะรรันกุฬังงรเทวีเกษตรัง',
#  'เอมีลลูเบต์',
#  'พระเจ้าเฟรดริคที่2แห่งปรัสเซีย',
#  'ปลาบิน',
#  'หมู่เกาะทะเลจีนใต้',
#  'มลรัฐอิลลินอยส์',
#  'วิชิตสุรพงษ์ชัย',
#  'เจ้าฟ้าสิงหาราชธานีเจ้าฟ้าหลวงชายแก้ว',
#  'เอกซ์เรย์']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี

# %%
titles = set([title for title in titles if "พ.ศ." not in title])

len(titles)
# Out:
# 6058

# %%
get_samples(titles)
# Out:
# ['เหตุการณ์ตำรวจปราบจราจลปะทะกับม็อบนปก.หน้าบ้านสี่เสาเทเวศร์22กรกฎาคมพ.ศ.2550',
#  'พ.ศ.600',
#  'พ.ศ.233',
#  'การระบาดของโคโรนาไวรัสในประเทศอินเดียพ.ศ.2563',
#  'นักฟุตบอลเกิดพ.ศ.2521',
#  'จังหวัดกำแพงเพชรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'การปะทุของเอยาฟยาตลาเยอคูตเอิลพ.ศ.2553',
#  'พ.ศ.1776',
#  'การประท้วงในประเทศเบลารุสพ.ศ.2563–2564',
#  'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2501',
#  'พ.ศ.1287',
#  'พ.ศ.1446',
#  'พ.ศ.2221',
#  'พ.ศ.793',
#  'พ.ศ.366',
#  'พ.ศ.2373',
#  'พ.ศ.2475–2482',
#  'ภาพยนตร์ไทยปีพ.ศ.2526',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศเยอรมนีพ.ศ.2563',
#  'คณะตุลาการศาลรัฐธรรมนูญพ.ศ.2549',
#  'พ.ศ.1435',
#  'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'พ.ศ.1385',
#  'พ.ศ.1605',
#  'การจลาจลที่ตันยุงปรียอกพ.ศ.2527',
#  'พ.ศ.2494',
#  'พ.ศ.2245',
#  'พ.ศ.2357',
#  'พ.ศ.322',
#  'พ.ศ.2277',
#  'ปฏิกิริยาของนานาชาติต่อรัฐประหารในประเทศไทยพ.ศ.2549',
#  'การเลือกตั้งประธานาธิบดีสหรัฐพ.ศ.2563',
#  'โทรทัศน์ประเทศไทยในพ.ศ.2539',
#  'พ.ศ.2185',
#  'พ.ศ.2085',
#  'พ.ศ.1805',
#  'พ.ศ.1014',
#  'วิกฤตน้ำยาฆ่าเชื้อถูกเจือจางในประเทศโรมาเนียพ.ศ.2559',
#  'พ.ศ.919',
#  'พ.ศ.1294',
#  'การเลือกตั้งประธานาธิบดีฝรั่งเศสพ.ศ.2508',
#  'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดเชียงใหม่พ.ศ.2563',
#  'พ.ศ.943',
#  'นักดนตรีชาวญี่ปุ่นเกิดพ.ศ.2517',
#  'นักฟุตบอลเกิดพ.ศ.2541',
#  'ภาพยนตร์ชุดทางโทรทัศน์พ.ศ.2551',
#  'ประเทศไทยในพ.ศ.2511',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศเวียดนามพ.ศ.2563',
#  'พ.ศ.2480',
#  'พฤษภาคมพ.ศ.2566',
#  'แผ่นดินไหวในชิลีพ.ศ.2553',
#  'พ.ศ.429',
#  'ประเทศไทยในพ.ศ.2423',
#  'ภาพยนตร์พ.ศ.2555',
#  'พ.ศ.912',
#  'พ.ศ.๒๕๑๙',
#  'พ.ศ.640',
#  'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีไทยพ.ศ.2553',
#  'พ.ศ.1649',
#  'แผ่นดินไหวในมณฑลยูนนานพ.ศ.2554',
#  'ภาพยนตร์พ.ศ.2527',
#  'การลงประชามติว่าด้วยสมาชิกภาพสหภาพยุโรปของสหราชอาณาจักรพ.ศ.2559',
#  'พระราชบัญญัติหลักประกันสุขภาพแห่งชาติพ.ศ.2545',
#  'มิถุนายนพ.ศ.2546',
#  'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'เหตุรถบัสพลิกคว่ำในเวนิสพ.ศ.2566',
#  'การลงประชามติว่าด้วยสถานภาพของมายอตพ.ศ.2552',
#  'แผ่นดินไหวในเปตรีญาพ.ศ.2563',
#  'พ.ศ.63',
#  'ประเทศไทยในพ.ศ.2528',
#  'เหตุโจมตีในชายแดนภาคใต้ของประเทศไทยพ.ศ.2566',
#  'พ.ศ.1551',
#  'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'พ.ศ.1508',
#  'พ.ศ.69',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศนิวซีแลนด์พ.ศ.2563',
#  'ฤดูพายุเฮอริเคนแปซิฟิกพ.ศ.2558',
#  'พ.ศ.1045',
#  'พ.ศ.90',
#  'เหตุกราดยิงในออสโลพ.ศ.2565',
#  'พ.ศ.2540–2549',
#  'พ.ศ.1928–2112',
#  'การเลือกตั้งผู้ว่าราชการกรุงเทพมหานครพ.ศ.2552',
#  'พ.ศ.728',
#  'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'พ.ศ.1252',
#  'พ.ศ.1273',
#  'พ.ศ.๒๕๐๙',
#  'บุคคลที่เกิดในปีพ.ศ.2497',
#  'พ.ศ.1051',
#  'เหตุเครื่องบินตกที่เทือกเขาแอนเดสพ.ศ.2515',
#  'พ.ศ.706',
#  'พ.ศ.๒๕๔๑',
#  'การลงมติเลือกนายกรัฐมนตรีไทยพ.ศ.2544',
#  'บุคคลที่เกิดในปีพ.ศ.2504',
#  'ปฏิกิริยาต่อการประท้วงในประเทศไทยพ.ศ.2563',
#  'แผ่นดินไหวและสึนามิในเซ็นไดพ.ศ.2554',
#  'คดียุบพรรคการเมืองพ.ศ.2549',
#  'พ.ศ.1305',
#  'การเลือกตั้งผู้ว่าราชการกรุงเทพมหานครพ.ศ.2528']

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [titles for titles in titles if "ใน" in titles]
len(nai)
# Out:
# 1587

# %%
[nai][:50]
# Out:
# [['บุคคลที่เสียชีวิตในปีพ.ศ.2563',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศมองโกเลียพ.ศ.2563',
#   'จังหวัดมหาสารคามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุระเบิดในโมกาดิชู14ตุลาคมพ.ศ.2560',
#   'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดน่านในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในเปรูพ.ศ.2550',
#   'ประเทศไทยในพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2382',
#   'แผ่นดินไหวในสุมาตราเมษายนพ.ศ.2553',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'ประเทศไทยในพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2362',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2531',
#   'จังหวัดสมุทรสงครามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'เหตุอุกกาบาตตกในรัสเซียพ.ศ.2556',
#   'อุทกภัยและดินถล่มในประเทศไทยพ.ศ.2554',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2515',
#   'จังหวัดลำปางในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุระเบิดในโมกาดิชูตุลาคมพ.ศ.2565',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2548',
#   'จังหวัดนครสวรรค์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในจี๋จี๋พ.ศ.2542',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2547',
#   'ประเทศไทยในพ.ศ.2504',
#   'แผ่นดินไหวในประเทศเนปาลพฤษภาคมพ.ศ.2558',
#   'ประเทศไทยในพ.ศ.2516',
#   'เหตุเพลิงไหม้และระเบิดในสีตากุณฑะพ.ศ.2565',
#   'ดนตรีเกาหลีใต้ในพ.ศ.2566',
#   'เหตุโจมตีในเบอร์ลินพ.ศ.2559',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2501',
#   'บุคคลที่เกิดในปีพ.ศ.2486',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศมาดากัสการ์พ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2557',
#   'จังหวัดหนองบัวลำภูในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในแคชเมียร์พ.ศ.2548',
#   'จังหวัดสมุทรสาครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ลำดับเหตุการณ์รัฐประหารในประเทศไทยพ.ศ.2549',
#   'แผ่นดินไหวในเกาะซูลาเวซีประเทศอินโดนีเซียพ.ศ.2555',
#   'จังหวัดอุดรธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'บุคคลที่เกิดในปีพ.ศ.2536',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'เหตุโจมตีในวิทยาลัยสารพัดช่างเคียร์ชพ.ศ.2561',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในประเทศพม่าพ.ศ.2553',
#   'จังหวัดอำนาจเจริญในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในประเทศปาปัวนิวกินีพ.ศ.2561',
#   'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'การลงประชามติเกี่ยวกับนโยบายในกัมพูชาพ.ศ.2503',
#   'เหตุกราดยิงในศูนย์การค้าสยามพารากอนพ.ศ.2566',
#   'บุคคลที่เกิดในปีพ.ศ.2500',
#   'ประเทศไทยในพ.ศ.2496',
#   'ประเทศไทยในพ.ศ.2325',
#   'เหตุยิงกันในสทราซบูร์พ.ศ.2561',
#   'ประเทศไทยในพ.ศ.2560',
#   'เหตุโจมตีด้วยขีปนาวุธในแชร์นีฮิวเดือนสิงหาคมพ.ศ.2566',
#   'จังหวัดพิจิตรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'แผ่นดินไหวในมหาสมุทรอินเดียพ.ศ.2555',
#   'ประเทศไทยในพ.ศ.2524',
#   'เหตุเหยียบกันเสียชีวิตในซาบาริมาลาพ.ศ.2554',
#   'จังหวัดนราธิวาสในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การเลือกตั้งในกรุงเทพมหานครพ.ศ.2565',
#   'จังหวัดสมุทรสงครามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'สถาปัตยกรรมในพ.ศ.2555',
#   'รัฐประหารในประเทศอียิปต์พ.ศ.2556',
#   'เหตุแทงคนในนิสพ.ศ.2563',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2530',
#   'จังหวัดสมุทรสงครามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2544',
#   'แผ่นดินไหวในพ.ศ.2554',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2515',
#   'ประเทศไทยในพ.ศ.2329',
#   'เหตุสารฟิโปรนิลปนเปื้อนในไข่พ.ศ.2560',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2554',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศเม็กซิโกพ.ศ.2563',
#   'จังหวัดสุรินทร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศไทยในพ.ศ.2507',
#   'ประเทศไทยในพ.ศ.2478',
#   'ประเทศไทยในพ.ศ.2494',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศลาวพ.ศ.2563',
#   'การเลือกตั้งทั่วไปในประเทศมาเลเซียพ.ศ.2561',
#   'การก่อการกำเริบในสาธารณรัฐมาซิโดเนียพ.ศ.2544',
#   'เหตุจลาจลในแคว้นอังกฤษพ.ศ.2554',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2563',
#   'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การก่อการกำเริบในทิเบตพ.ศ.2502',
#   'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ความไม่สงบนิยมรัสเซียในประเทศยูเครนพ.ศ.2557',
#   'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดเลยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในจังหวัดอิกิเกพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2422',
#   'ประเทศไทยในพ.ศ.2526',
#   'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดสมุทรสาครในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2555',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศนิวซีแลนด์พ.ศ.2563',
#   'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'บุคคลที่เกิดในปีพ.ศ.2501',
#   'จังหวัดกาฬสินธุ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'วิดีโอเกมในพ.ศ.2562',
#   'แผ่นดินไหวในวานพ.ศ.2554',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2559',
#   'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในประเทศชิลีพ.ศ.2553',
#   'เหตุระเบิดในไนจีเรียธันวาคมพ.ศ.2554',
#   'จังหวัดสมุทรปราการในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'แผ่นดินไหวในพ.ศ.2562',
#   'เหตุระเบิดในบาหลีพ.ศ.2545',
#   'การช่วยเหลือด้านมนุษยธรรมต่อเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮกุพ.ศ.2554',
#   'จังหวัดพังงาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุแผ่นดินถล่มในแยร์ดรึมพ.ศ.2563',
#   'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีในประเทศไทยมีนาคมพ.ศ.2554',
#   'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2562',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดประจวบคีรีขันธ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การก่อการกำเริบในลิเบียพ.ศ.2554',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2408',
#   'จังหวัดอุตรดิตถ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'แผ่นดินไหวในเกาะลมบกสิงหาคมพ.ศ.2561',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศเบนินพ.ศ.2563',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2517',
#   'จังหวัดพังงาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'แผ่นดินไหวในประเทศญี่ปุ่นพ.ศ.2554',
#   'เหตุระเบิดในจังหวัดสงขลาพ.ศ.2548',
#   'บุคคลที่เกิดในปีพ.ศ.2510',
#   'จังหวัดภูเก็ตในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศไทยพ.ศ.2563',
#   'บุคคลที่เกิดในปีพ.ศ.2530',
#   'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศซาอุดีอาระเบียพ.ศ.2563',
#   'การประท้วงในเกาหลีใต้พ.ศ.2559–2560',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2493',
#   'จังหวัดอุดรธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'บุคคลที่เกิดในปีพ.ศ.2537',
#   'บุคคลที่เกิดในปีพ.ศ.2473',
#   'แผ่นดินไหวและคลื่นสึนามิในมหาสมุทรอินเดียพ.ศ.2547',
#   'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2380',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2505',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2549',
#   'จังหวัดชัยภูมิในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุโจมตีด้วยขีปนาวุธในวินนึตเซียเดือนกรกฎาคมพ.ศ.2565',
#   'การประท้วงในประเทศเบลารุสพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2529',
#   'ประเทศไทยในพ.ศ.2441',
#   'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดราชบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'เหตุเหมืองถ่านหินในมณฑลเสฉวนและนครปักกิ่งพ.ศ.2555',
#   'จังหวัดฉะเชิงเทราในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2553',
#   'ประเทศไทยในพ.ศ.2428',
#   'จังหวัดนนทบุรีในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2563',
#   'รัฐประหารในประเทศซูดานตุลาคมพ.ศ.2564',
#   'ทุพภิกขภัยในประเทศเอธิโอเปียพ.ศ.2526–2528',
#   'จังหวัดอุดรธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การสังหารหมู่ในนครชิคาโกด้วยยาไทลินอลพ.ศ.2525',
#   'ประเทศไทยในพ.ศ.2480',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2508',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุการณ์อุทกภัยและโคลนถล่ม5จังหวัดในเขตภาคเหนือตอนบนพ.ศ.2549',
#   'แผ่นดินไหวในจังหวัดฟูกูชิมะเมษายนพ.ศ.2554',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศมาดากัสการ์พ.ศ.2563',
#   'โคลนถล่มในมณฑลกานซู่พ.ศ.2553',
#   'การเปลี่ยนชื่อเดือนและสัปดาห์ในประเทศเติร์กเมนิสถานพ.ศ.2545',
#   'รัฐประหารในประเทศกินี-บิสเซาพ.ศ.2555',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศซาอุดีอาระเบียพ.ศ.2563',
#   'การช่วยเหลือด้านมนุษยธรรมต่อเหตุการณ์แผ่นดินไหวและคลื่นสึนามิในเซ็นไดพ.ศ.2554',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศเม็กซิโกพ.ศ.2563',
#   'เหตุเพลิงไหม้ในเคเมโรโวพ.ศ.2561',
#   'วิดีโอเกมในพ.ศ.2556',
#   'จังหวัดสุราษฎร์ธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2509',
#   'จังหวัดชุมพรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2407',
#   'ประเทศไทยในพ.ศ.2379',
#   'เหตุโจมตีในจาการ์ตาพ.ศ.2559',
#   'บุคคลที่เกิดในปีพ.ศ.2476',
#   'เหตุรถไฟตกรางในมณฑลเจียงซีพ.ศ.2553',
#   'ภัยธรรมชาติในประเทศไทยพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2367',
#   'การประท้วงในประเทศนิการากัวพ.ศ.2556–2561',
#   'เหตุโจมตีในมหาวิทยาลัยคาบูลพ.ศ.2563',
#   'เหตุจลาจลในเดลีพ.ศ.2563',
#   'บุคคลที่เสียชีวิตในเดือนมกราคมพ.ศ.2559',
#   'การเลือกตั้งสหพันธรัฐในเยอรมนีพ.ศ.2548',
#   'จังหวัดสิงห์บุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศไทยในพ.ศ.2533',
#   'แผ่นดินไหวและคลื่นสึนามิในเกาะซูลาเวซีพ.ศ.2561',
#   'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'เหตุโจมตีในชายแดนภาคใต้ของประเทศไทยพ.ศ.2566',
#   'ความขัดแย้งในซูดานพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2427',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2551',
#   'จังหวัดนครราชสีมาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในไทยพ.ศ.2557',
#   'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดสระบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2392',
#   'ประเทศไทยในพ.ศ.2495',
#   'เหตุระเบิดในศรีลังกาวันอีสเตอร์พ.ศ.2562',
#   'แผ่นดินไหวในคอสตาริกาพ.ศ.2560',
#   'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'บุคคลที่เกิดในปีพ.ศ.2492',
#   'แผ่นดินไหวในเกาะชวาพ.ศ.2554',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2511',
#   'จังหวัดสระแก้วในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2481',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดอำนาจเจริญในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'แผ่นดินไหวและคลื่นสึนามิในโทโฮะกุพ.ศ.2554',
#   'จังหวัดระยองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การระบาดของสมองอักเสบในรัฐพิหารพ.ศ.2562',
#   'การประท้วงในประเทศศรีลังกาพ.ศ.2565',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2494',
#   'การเลือกตั้งทั่วไปในประเทศภูฏานพ.ศ.2556',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยมกราคมพ.ศ.2551',
#   'บุคคลที่เกิดในปีพ.ศ.2531',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยพ.ศ.2540',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุระเบิดในปูลีอลัมพ.ศ.2564',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยธันวาคมพ.ศ.2551',
#   'การเลือกตั้งทั่วไปในประเทศอินเดียพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2420',
#   'ประเทศไทยในพ.ศ.2421',
#   'การออกเสียงประชามติว่าด้วยสมาชิกภาพในสหภาพยุโรปของสหราชอาณาจักรพ.ศ.2559',
#   'เหตุระเบิดในโมกาดิชูตุลาคมพ.ศ.2560',
#   'ฟ้าหลัวในเอเชียตะวันออกเฉียงใต้พ.ศ.2556',
#   'การประท้วงในประเทศเลบานอนพ.ศ.2562–2563',
#   'แผ่นดินไหวในลมบกกรกฎาคมพ.ศ.2561',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2524',
#   'แผ่นดินไหวในจังหวัดชิบะพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2465',
#   'การเปลี่ยนรัชกาลในประเทศญี่ปุ่นพ.ศ.2562',
#   'แผ่นดินไหวในจังหวัดคุมะโมะโตะพ.ศ.2559',
#   'แผ่นดินไหวในไต้หวันพ.ศ.2559',
#   'แผ่นดินไหวในอีกีเกพ.ศ.2557',
#   'การเลือกตั้งทั่วไปในอินเดียพ.ศ.2557',
#   'แผ่นดินไหวในลมบกพ.ศ.2561',
#   'ประเทศไทยในพ.ศ.2522',
#   'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'รัฐประหารในประเทศไทยพ.ศ.2476',
#   'จังหวัดนครราชสีมาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศไทยในพ.ศ.2394',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2524',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2556',
#   'การระบาดของอหิวาตกโรคในเฮติพ.ศ.2553',
#   'การจลาจลในสาธารณรัฐมาซิโดเนียพ.ศ.2544',
#   'บุคคลที่เกิดในปีพ.ศ.2505',
#   'บุคคลที่เกิดในปีพ.ศ.2520',
#   'ประเทศไทยในพ.ศ.2455',
#   'เพลิงไหม้ครั้งใหญ่ในลอนดอนพ.ศ.2209',
#   'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2556–57',
#   'แผ่นดินไหวในลมบกสิงหาคมพ.ศ.2561',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'การประท้วงในอิรักพ.ศ.2562–2564',
#   'จังหวัดพัทลุงในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การระบาดทั่วของอีโบลาในคีวูพ.ศ.2561–62',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยพ.ศ.2548',
#   'ความพยายามรัฐประหารในประเทศตุรกีพ.ศ.2559',
#   'อนิเมะในปีพ.ศ.2563',
#   'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ฝูงแผ่นดินไหวในหมู่เกาะโทการะพ.ศ.2564',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2488',
#   'การเลือกตั้งทั่วไปในประเทศตองกาพ.ศ.2557',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2535',
#   'ประเทศไทยในพ.ศ.2452',
#   'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'รัฐประหารในประเทศไทยพ.ศ.2519',
#   'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีในประเทศไทยพฤศจิกายนพ.ศ.2554',
#   'แผ่นดินไหวในกือตาห์ยาพ.ศ.2554',
#   'แผ่นดินไหวในเกาะสุมาตราพ.ศ.2565',
#   'ประเทศไทยในพ.ศ.2403',
#   'ประเทศไทยในพ.ศ.2552',
#   'อาชญากรรมสงครามในการรุกรานยูเครนของรัสเซียพ.ศ.2565',
#   'ปฏิกิริยาต่อการประท้วงในประเทศไทยพ.ศ.2563',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2539',
#   'จังหวัดกระบี่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดประจวบคีรีขันธ์ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2563',
#   'แผ่นดินไหวในเฮติพ.ศ.2553',
#   'เหตุระเบิดในแบกแดด17สิงหาคมพ.ศ.2553',
#   'ลำดับเวลารัฐประหารในประเทศไทยพ.ศ.2549',
#   'การประท้วงในอินโดนีเซียพ.ศ.2562',
#   'การจลาจลในเดลีพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2446',
#   'แผ่นดินไหวในหมู่เกาะซามัวพ.ศ.2552',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การลักพาตัวเด็กในระหว่างการรุกรานยูเครนโดยรัสเซียพ.ศ.2565',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2536',
#   'แผ่นดินไหวในจังหวัดฟุกุชิมะพ.ศ.2559',
#   'บุคคลที่เกิดในปีพ.ศ.2506',
#   'เหตุระเบิดในย่างกุ้งพ.ศ.2526',
#   'การลงประชามติเกี่ยวกับรัฐธรรมนูญในกัมพูชาพ.ศ.2502',
#   'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2409',
#   'จังหวัดน่านในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การประท้วงในโบลิเวียพ.ศ.2561-พ.ศ.2562',
#   'แผ่นดินไหวในจูเอ็ทสึพ.ศ.2547',
#   'การประท้วงในประเทศไทยพ.ศ.2563–2565',
#   'การเลือกตั้งในประเทศไทยพ.ศ.2555',
#   'จังหวัดลำปางในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2558',
#   'ประเทศไทยในพ.ศ.2327',
#   'แผ่นดินไหวในปาปัวนิวกินีพ.ศ.2561',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยเมษายนพ.ศ.2549',
#   'แผ่นดินไหวในปิชิเลมูพ.ศ.2553',
#   'ประเทศไทยในพ.ศ.2405',
#   'บุคคลที่เกิดในปีพ.ศ.2496',
#   'การเลือกตั้งทั่วไปในสเปนพ.ศ.2558',
#   'เหตุอาคารถล่มในซาวาร์พ.ศ.2556',
#   'อุทกภัยในโซลพ.ศ.2554',
#   'ความขัดแย้งในกัมพูชาพ.ศ.2380',
#   'บุคคลที่เกิดในปีพ.ศ.2525',
#   'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2519',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยตุลาคมพ.ศ.2549',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศแคนาดาพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2363',
#   'การบุกยึดท่าอากาศยานในประเทศไทยพ.ศ.2551',
#   'เหตุการณ์ความไม่สงบทางการเมืองในประเทศไทยเมษายนพ.ศ.2552',
#   'อนิเมะในปีพ.ศ.2567',
#   'การประท้วงในประเทศคาซัคสถานพ.ศ.2565',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2565',
#   'บุคคลที่เกิดในปีพ.ศ.2480',
#   'แผ่นดินไหวในเกาะสุมาตราเมษายนพ.ศ.2553',
#   'การประท้วงในประเทศอิหร่านพ.ศ.2560',
#   'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2451',
#   'ประเทศไทยในพ.ศ.2477',
#   'บุคคลที่เกิดในปีพ.ศ.2485',
#   'แผ่นดินไหวในพม่าเมษายนพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2417',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2550',
#   'แผ่นดินไหวในโพฮังพ.ศ.2560',
#   'ประเทศไทยในพ.ศ.2454',
#   'แผ่นดินไหวในมณฑลยูนนานกรกฎาคมพ.ศ.2555',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2489',
#   'จังหวัดเชียงรายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การประท้วงในเอกวาดอร์พ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2461',
#   'บุคคลที่เกิดในปีพ.ศ.2503',
#   'ประเทศไทยในพ.ศ.2348',
#   'จังหวัดตรังในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดนราธิวาสในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2501',
#   'อุทกภัยในประเทศมาเลเซียพ.ศ.2549-2550',
#   'บุคคลที่เกิดในปีพ.ศ.2466',
#   'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2545',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุโจมตีในมินยาพ.ศ.2560',
#   'การประท้วงในแอฟริกาเหนือและตะวันออกกลางพ.ศ.2553-2554',
#   'การยุติการออกอากาศโทรทัศน์อนาล็อกในสหรัฐอเมริกาพ.ศ.2552',
#   'จังหวัดอุบลราชธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2519',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2550ในกรุงเทพมหานคร',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2551',
#   'การประท้วงในฮ่องกงพ.ศ.2562–2563',
#   'อุทกภัยในประเทศไทยพ.ศ.2553',
#   'จังหวัดตรังในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดกำแพงเพชรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในจังหวัดมิยางิมีนาคมพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2537',
#   'บุคคลที่เกิดในปีพ.ศ.2465',
#   'แผ่นดินไหวในภาคกลางของอิตาลีสิงหาคมพ.ศ.2559',
#   'จังหวัดตากในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2487',
#   'แผ่นดินไหวในจังหวัดบันเตินพ.ศ.2561',
#   'จังหวัดฉะเชิงเทราในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเรียกร้องให้บัญญัติพุทธศาสนาเป็นศาสนาประจำชาติไทยในรัฐธรรมนูญพ.ศ.2550',
#   'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'คลื่นความร้อนในเอเชียพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2530',
#   'ประเทศไทยในพ.ศ.2413',
#   'จังหวัดลำปางในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2550',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศไต้หวันพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2433',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2565',
#   'ประเทศไทยในพ.ศ.2536',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2505',
#   'แผ่นดินไหวในประเทศเนปาลเมษายนพ.ศ.2558',
#   'จังหวัดปทุมธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในเกาะสุลาเวสีประเทศอินโดนีเซียพ.ศ.2555',
#   'การลงประชามติเกี่ยวกับกฏหมายเลือกตั้งในกัมพูชาพ.ศ.2501',
#   'ประเทศไทยในพ.ศ.2497',
#   'ปฏิกิริยาของนานาชาติต่อรัฐประหารในประเทศไทยพ.ศ.2549',
#   'การก่อการกำเริบในเยเมนพ.ศ.2554–2555',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศแอฟริกาใต้พ.ศ.2563',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'แผ่นดินไหวในจังหวัดฟูกูชิมะพ.ศ.2559',
#   'กีฬาในพ.ศ.2548',
#   'จังหวัดน่านในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2551',
#   'แผ่นดินไหวในจังหวัดฮกไกโดพ.ศ.2561',
#   'ประเทศไทยในพ.ศ.2505',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยพ.ศ.2548',
#   'จังหวัดพิจิตรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'นักฟุตบอลเกิดในพ.ศ.2533',
#   'อุบัติเหตุรถบัสในบัลแกเรียพ.ศ.2564',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'การประท้วงในแคว้นกาตาลุญญาพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2520',
#   'เหตุระเบิดในกรุงเทพมหานครพ.ศ.2555',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2553',
#   'ประเทศไทยในพ.ศ.2492',
#   'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'เหตุดอกไม้ไฟระเบิดในจังหวัดสุพรรณบุรีพ.ศ.2555',
#   'จังหวัดภูเก็ตในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การจลาจลในลอสแอนเจลิสพ.ศ.2535',
#   'เรื่องอื้อฉาวนมในจีนพ.ศ.2551',
#   'ประเทศไทยในพ.ศ.2499',
#   'ประเทศไทยในพ.ศ.2531',
#   'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'แผ่นดินไหวในยูซูพ.ศ.2553',
#   'เหตุไล่แทงในตุรกุพ.ศ.2560',
#   'เหตุระเบิดในการแข่งขันมาราธอนในบอสตันพ.ศ.2556',
#   'แผ่นดินไหวในประเทศฮอนดูรัสพ.ศ.2561',
#   'ประเทศไทยในพ.ศ.2500',
#   'แผ่นดินไหวในมณฑลส่านซีพ.ศ.2099',
#   'ประเทศรัสเซียในพ.ศ.2565',
#   'จังหวัดตากในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'เหตุรถไฟตกรางในฟิลาเดลเฟียพ.ศ.2558',
#   'ประเทศไทยในพ.ศ.2510',
#   'จังหวัดมหาสารคามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดระยองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2544',
#   'รัฐประหารในประเทศไทยพ.ศ.2534',
#   'การประท้วงในประเทศอาร์มีเนียพ.ศ.2561',
#   'จังหวัดมุกดาหารในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การเลือกตั้งสหพันธรัฐในแคนาดาพ.ศ.2549',
#   'การประท้วงในประเทศอิหร่านพ.ศ.2562',
#   'เหตุระเบิดในเบรุตพ.ศ.2563',
#   'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในประเทศภูฏานพ.ศ.2551',
#   'ประเทศไทยในพ.ศ.2395',
#   'คลื่นความร้อนในประเทศอินเดียและปากีสถานพ.ศ.2562',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2516',
#   'เหตุการณ์โรงงานอบลำไยในจังหวัดเชียงใหม่ระเบิดพ.ศ.2542',
#   'บุคคลที่เกิดในปีพ.ศ.2491',
#   'เหตุการณ์น้ำท่วมในประเทศจีนพ.ศ.2474',
#   'คลื่นความเย็นในทวีปยุโรปพ.ศ.2555',
#   'การอดอาหารประท้วงในประเทศไอร์แลนด์พ.ศ.2524',
#   'เหตุระเบิดในสตอกโฮล์มพ.ศ.2553',
#   'รัฐประหารในประเทศไทยพ.ศ.2549',
#   'การประท้วงในประเทศนิการากัวพ.ศ.2561–2565',
#   'อุทกภัยในรัฐเกรละพ.ศ.2561',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'บุคคลที่เกิดในปีพ.ศ.2523',
#   'เหตุเหยียบกันเสียชีวิตในสัพริมลาพ.ศ.2554',
#   'จังหวัดนครราชสีมาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'อุทกภัยในเวนิสพ.ศ.2562',
#   'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดสระแก้วในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2554',
#   'การประท้วงในสเปนพ.ศ.2562',
#   'จังหวัดสุราษฎร์ธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2539',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2498',
#   'ประเทศไทยในพ.ศ.2561',
#   'ประเทศไทยในพ.ศ.2548',
#   'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2401',
#   'การประท้วงในประเทศโปแลนด์ตุลาคมพ.ศ.2563',
#   'เหตุแผ่นดินถล่มในประเทศโคลัมเบียพ.ศ.2558',
#   'จังหวัดระยองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'เหตุระเบิดในกรุงเทพมหานครพ.ศ.2549',
#   'บุคคลที่เกิดในปีพ.ศ.2494',
#   'จังหวัดนครปฐมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2498',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การเลือกตั้งทั่วไปในประเทศมาเลเซียพ.ศ.2556',
#   'ภาวะเศรษฐกิจตกต่ำใหญ่ในอาร์เจนตินาพ.ศ.2541–2545',
#   'รัฐประหารในประเทศไทยพ.ศ.2491',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2490',
#   'รัฐประหารในประเทศไทยพ.ศ.2557',
#   'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2565',
#   'เหตุเรือล่มในทะเลสาบวิกตอเรียพ.ศ.2561',
#   'บุคคลที่เกิดในปีพ.ศ.2541',
#   'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในจังหวัดฟุกุชิมะเมษายนพ.ศ.2554',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2555',
#   'การระบาดทั่วของโคโรนาไวรัสในทวีปยุโรปพ.ศ.2563',
#   'บุคคลที่เกิดในปีพ.ศ.2495',
#   'ประเทศไทยในพ.ศ.2406',
#   'แผ่นดินไหวในชวาตะวันตกพ.ศ.2552',
#   'แผ่นดินไหวในภาคกลางของอิตาลีพ.ศ.2559',
#   'ภัยจากอากาศหนาวจัดทั่วโลกในพ.ศ.2555',
#   'แผ่นดินไหวในชเวโบพ.ศ.2555',
#   'การจลาจลในนูกูอาโลฟาพ.ศ.2549',
#   'อุทกภัยและดินถล่มในภาคใต้ของประเทศไทยพ.ศ.2554',
#   'บุคคลที่เกิดในปีพ.ศ.2479',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2547',
#   'การประท้วงในประเทศโคลอมเบียพ.ศ.2564',
#   'แผ่นดินไหวในซูลาเวซีตะวันตกพ.ศ.2564',
#   'แผ่นดินไหวในสุมาตราพ.ศ.2552',
#   'แผ่นดินไหวในมณฑลยูนนานพ.ศ.2554',
#   'กีฬาในพ.ศ.2549',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2533',
#   'บุคคลที่เกิดในปีพ.ศ.2538',
#   'เหตุไฟฟ้าดับในประเทศเวเนซุเอลาพ.ศ.2562',
#   'บุคคลที่เกิดในปีพ.ศ.2504',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2550',
#   'การระบาดทั่วของโคโรนาไวรัสในสหรัฐพ.ศ.2563',
#   'รัฐประหารในประเทศไทยมิถุนายนพ.ศ.2476',
#   'เหตุโจรกรรมร้านทองในจังหวัดลพบุรีพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2513',
#   'จังหวัดบุรีรัมย์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2547',
#   'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'หมอกควันในเอเชียตะวันออกเฉียงใต้พ.ศ.2556',
#   'จังหวัดสตูลในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การประท้วงต่อต้านรัฐบาลในพม่าพ.ศ.2550',
#   'จังหวัดอ่างทองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดอำนาจเจริญในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในจังหวัดกือตาห์ยาพ.ศ.2554',
#   'อนิเมะในปีพ.ศ.2561',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในอิตาลีพ.ศ.2552',
#   'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐพ.ศ.2552',
#   'เหตุการณ์แผ่นดินไหวในมณฑลเสฉวนพ.ศ.2551',
#   'การประท้วงในประเทศไทยพ.ศ.2563–2564',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2518',
#   'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'แผ่นดินไหวในรัฐเวอร์จิเนียพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2515',
#   'เหตุระเบิดในอิสตันบูลพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2400',
#   'แผ่นดินไหวในพม่าพ.ศ.2554',
#   'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2556',
#   'ประเทศไทยในพ.ศ.2523',
#   'แผ่นดินไหวในจังหวัดมิยะงิพ.ศ.2554',
#   'บุคคลที่เกิดในปีพ.ศ.2534',
#   'ประเทศไทยในพ.ศ.2416',
#   'บุคคลที่เกิดในปีพ.ศ.2533',
#   'ลำดับเหตุการณ์การประท้วงในประเทศไทยพ.ศ.2563–2565',
#   'บุคคลที่เกิดในปีพ.ศ.2515',
#   'การเลือกตั้งทั่วไปในสเปนพ.ศ.2559',
#   'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2547',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'การเลือกตั้งทั่วไปในเดนมาร์กพ.ศ.2558',
#   'รัฐประหารในประเทศไทยพ.ศ.2514',
#   'ประเทศไทยในพ.ศ.2440',
#   'เหตุแผ่นดินถล่มในอาตามิพ.ศ.2564',
#   'จังหวัดราชบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศอินเดียพ.ศ.2563',
#   'การเลือกตั้งระดับท้องถิ่นในกัมพูชาพ.ศ.2555',
#   'รัฐประหารในอิหร่านพ.ศ.2496',
#   'การก่อความไม่สงบในประเทศแอฟริกาใต้พ.ศ.2564',
#   'จังหวัดสุราษฎร์ธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'รัฐประหารในประเทศกาบองพ.ศ.2566',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศลาวพ.ศ.2563',
#   'แผ่นดินไหวในซูลาเวซีพ.ศ.2561',
#   'แผ่นดินไหวในเกาะซูลาเวซีพ.ศ.2561',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2506',
#   'เหตุโจมตีในกาตาลุญญาพ.ศ.2560',
#   'อุทกภัยในประเทศปากีสถานพ.ศ.2553',
#   'จังหวัดอุตรดิตถ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2558',
#   'อุทกภัยในคีวชูพ.ศ.2563',
#   'การระบาดของโคโรนาไวรัสในประเทศเม็กซิโกพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2411',
#   'ประเทศไทยในปีพ.ศ.2475',
#   'ประเทศไทยในพ.ศ.2519',
#   'เหตุระเบิดในประเทศศรีลังกาพ.ศ.2562',
#   'การลงประชามติในกัมพูชาพ.ศ.2488',
#   'บุคคลที่เกิดในปีพ.ศ.2484',
#   'ประเทศไทยในพ.ศ.2432',
#   'เหตุการณ์วางระเบิดรถไฟฟ้าใต้ดินในกรุงมินสก์ประเทศเบลารุสพ.ศ.2554',
#   'บุคคลที่เกิดในปีพ.ศ.2527',
#   'จังหวัดภูเก็ตในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุยิงกันในมีดี-ปีเรเนพ.ศ.2555',
#   'การระบาดของไวรัสอีโบลาในแอฟริกาตะวันตกพ.ศ.2557',
#   'แผ่นดินไหวในจังหวัดทตโตริพ.ศ.2543',
#   'ประเทศไทยในพ.ศ.2471',
#   'จังหวัดฉะเชิงเทราในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2328',
#   'แผ่นดินไหวในประเทศพม่าเมษายนพ.ศ.2559',
#   'บุคคลที่เกิดในปีพ.ศ.2535',
#   'จังหวัดระยองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดตราดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2528',
#   'จังหวัดระยองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'อุทกภัยและโคลนถล่ม5จังหวัดในเขตภาคเหนือตอนล่างพ.ศ.2549',
#   'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2476',
#   'รัฐประหารในอินโดจีนฝรั่งเศสพ.ศ.2488',
#   'จังหวัดตราดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในประเทศตองงาพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2501',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2539',
#   'การระบาดของไวรัสโคโรนาในประเทศอินเดียพ.ศ.2563',
#   'แผ่นดินไหวในจังหวัดนีงาตะพ.ศ.2507',
#   'ปฏิกิริยาต่อการประท้วงในประเทศไทยพ.ศ.2563–2564',
#   'เหตุรถประสานงาในปาปัวนิวกินีพ.ศ.2553',
#   'บุคคลที่เกิดในปีพ.ศ.2477',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศเกาหลีเหนือพ.ศ.2563',
#   'เหตุระเบิดในอิสตันบูลพ.ศ.2553',
#   'บุคคลที่เกิดในปีพ.ศ.2517',
#   'จังหวัดนครปฐมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศไทยในพ.ศ.2542',
#   'จังหวัดเพชรบูรณ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2519',
#   'จังหวัดบุรีรัมย์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'แผ่นดินไหวในจังหวัดมิยางิพฤษภาคมพ.ศ.2564',
#   'การเลือกตั้งสหพันธรัฐในเยอรมนีพ.ศ.2552',
#   'เหตุโจมตีในประเทศอัฟกานิสถานเดือนพฤศจิกายนพ.ศ.2563',
#   'การจลาจลในนูกูอะโลฟาพ.ศ.2549',
#   'เหตุแผ่นดินถล่มในประเทศโคลอมเบียพ.ศ.2558',
#   'ปฏิกิริยาต่อการประท้วงในประเทศไทยพ.ศ.2563–2565',
#   'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2396',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2548',
#   'จังหวัดสุโขทัยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2449',
#   'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'รัฐประหารในประเทศชีลีพ.ศ.2516',
#   'รัฐประหารในเชโกสโลวาเกียพ.ศ.2491',
#   'แผ่นดินไหวในจังหวัดฟูกูชิมะพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2518',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2550',
#   'ประเทศไทยในพ.ศ.2565',
#   'เหตุโจมตีในคาบูลเดือนพฤษภาคมพ.ศ.2560',
#   'เหตุระเบิดในอิสตันบูลธันวาคมพ.ศ.2559',
#   'จังหวัดสมุทรปราการในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดกาฬสินธุ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2480',
#   'จังหวัดกาฬสินธุ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การก่อการกำเริบในซีเรียพ.ศ.2554–2555',
#   'บุคคลที่เกิดในปีพ.ศ.2540',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การเลือกตั้งสภานิติบัญญัติแห่งชาติในเกาหลีใต้พ.ศ.2528',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศแคนาดาพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2556',
#   'เหตุการณ์โจมตีในเบอร์ลินพ.ศ.2559',
#   'เหตุกราดยิงในมินยาพ.ศ.2560',
#   'แผ่นดินไหวในจังหวัดโอซากะพ.ศ.2561',
#   'ข่าวอื้อฉาวในฟุตบอลอิตาลีพ.ศ.2549',
#   'บุคคลที่เกิดในปีพ.ศ.2493',
#   'จังหวัดกำแพงเพชรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'อนิเมะในปีพ.ศ.2565',
#   'การเลือกตั้งสหพันธรัฐในแคนาดาพ.ศ.2558',
#   'วิกฤตการณ์ทางการเงินในเอเชียพ.ศ.2540',
#   'การลงประชามติเกี่ยวกับสนธิสัญญาเจนีวาในกัมพูชาพ.ศ.2498',
#   'การประท้วงในฮ่องกงพ.ศ.2557',
#   'แผ่นดินไหวและคลื่นสึนามิในโทโฮกุพ.ศ.2554',
#   'จังหวัดสุราษฎร์ธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุการณ์ชุมนุมในกรุงเทพมหานคร14ธันวาคมพ.ศ.2562',
#   'จังหวัดเลยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2538',
#   'จังหวัดสมุทรสาครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ทุพภิกขภัยในจะงอยแอฟริกาพ.ศ.2554',
#   'เหตุโจมตีในมาราวีพ.ศ.2560',
#   'แผ่นดินไหวในพม่าพ.ศ.2559',
#   'ไฟป่าในฟอร์ตแมคเมอเรย์พ.ศ.2559',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศญี่ปุ่นพ.ศ.2563',
#   'การประท้วงในโบลิเวียพ.ศ.2562',
#   'การระบาดของโคโรนาไวรัสในประเทศอินเดียพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2434',
#   'อุบัติเหตุเหมืองในโกเปียโปพ.ศ.2553',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2525',
#   'การประท้วงในตูนิเซียพ.ศ.2553-2554',
#   'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2509',
#   'เหตุประท้วงในอียิปต์เนื่องจากไม่พอใจรัฐบาลต่อการสอบสวนการเสียชีวิตของประชาชนพ.ศ.2555',
#   'ประเทศไทยในพ.ศ.2346',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2519',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2514',
#   'เหตุจลาจลในไอร์แลนด์เหนือพ.ศ.2564',
#   'บุคคลที่เกิดในปีพ.ศ.2511',
#   'ประเทศไทยในพ.ศ.2418',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2528',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2553',
#   'ความไม่สงบทางการเมืองในประเทศไทยเมษายนพ.ศ.2552',
#   'จังหวัดสมุทรสาครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2545',
#   'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'คลื่นความร้อนในประเทศอินเดียพ.ศ.2562',
#   'คดีโทรมหญิงในเดลีพ.ศ.2555',
#   'จังหวัดเลยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2353',
#   'การระบาดของโคโรนาไวรัสในประเทศแคนาดาพ.ศ.2563',
#   'จังหวัดเพชรบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'แผ่นดินไหวในประเทศเฮติพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2525',
#   'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดเพชรบูรณ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในญี่ปุ่นพ.ศ.2557',
#   'แผ่นดินไหวในมณฑลยูนนานพ.ศ.2555',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุโจมตีทางอากาศในสลอวิยันสก์เดือนเมษายนพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2368',
#   'เหตุระเบิดในอิสตันบูลมกราคมพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2502',
#   'การระบาดของอีโบลาในแอฟริกาตะวันตกพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2521',
#   'การประท้วงในประเทศพม่าพ.ศ.2564',
#   'เหตุรถไฟตกรางในจังหวัดประจวบคีรีขันธ์พ.ศ.2552',
#   'ประเทศไทยในพ.ศ.2336',
#   'จังหวัดสุรินทร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'อุทกภัยในประเทศจีนพ.ศ.2553',
#   'บุคคลที่เกิดในปีพ.ศ.2516',
#   'การระบาดทั่วของไวรัสโคโรนาในทวีปยุโรปพ.ศ.2563',
#   'เหตุยิงกันในออโรลาพ.ศ.2555',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศภูฏานพ.ศ.2563',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยพ.ศ.2544',
#   'บุคคลที่เกิดในปีพ.ศ.2529',
#   'การเลือกตั้งสหพันธรัฐในเยอรมนีพ.ศ.2556',
#   'ประเทศไทยในพ.ศ.2355',
#   'การเลือกตั้งทั่วไปในประเทศพม่าพ.ศ.2558',
#   'รัฐประหารในประเทศกินีพ.ศ.2564',
#   'ตับอักเสบไม่ทราบสาเหตุในเด็กพ.ศ.2565',
#   'การยุติการออกอากาศโทรทัศน์ระบบแอนะล็อกในสหรัฐพ.ศ.2552',
#   'การประท้วงในประเทศเอสวาตินีพ.ศ.2564',
#   'แผ่นดินไหวในภาคกลางของประเทศอิตาลีสิงหาคมพ.ศ.2559',
#   'จังหวัดบุรีรัมย์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ไฟดับในประเทศอินเดียกรกฎาคมพ.ศ.2555',
#   'ประเทศไทยในพ.ศ.2304',
#   'รัฐประหารในประเทศไทยพ.ศ.2494',
#   'แผ่นดินไหวในมณทลยูนนานกรกฎาคมพ.ศ.2555',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศเกาหลีเหนือพ.ศ.2563',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2521',
#   'รัฐประหารในฟิจิพ.ศ.2530',
#   'เหตุสะพานในโมรพีถล่มพ.ศ.2565',
#   'การประท้วงในประเทศรัสเซียพ.ศ.2564',
#   'จังหวัดร้อยเอ็ดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'จังหวัดตราดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดชัยภูมิในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในพ.ศ.2560',
#   'ภัยพิบัติเรือผู้อพยพในเมซีนีอาพ.ศ.2566',
#   'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในไครสต์เชิร์ชมิถุนายนพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2553',
#   'จังหวัดอุบลราชธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'แผ่นดินไหวในชวาพ.ศ.2561',
#   'เหตุระเบิดในกรุงเทพมหานครพ.ศ.2562',
#   'ประเทศไทยในพ.ศ.2426',
#   'ประเทศไทยในพ.ศ.2473',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2532',
#   'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในประเทศพม่าสิงหาคมพ.ศ.2559',
#   'การประท้วงในลิเบียพ.ศ.2554',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2561',
#   'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุการณ์อุทกภัยและโคลนถล่ม5จังหวัดในเขตภาคเหนือตอนล่างพ.ศ.2549',
#   'การโจมตีทางอากาศใส่อาคารที่อยู่อาศัยในดนีปรอพ.ศ.2566',
#   'จังหวัดเชียงรายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2538',
#   'จังหวัดพิษณุโลกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2560',
#   'การประท้วงในเกาหลีใต้พ.ศ.2559',
#   'การประท้วงในอิรักพ.ศ.2562',
#   'อุทกภัยอันเนื่องจากพายุนกเตนในประเทศไทยพ.ศ.2554',
#   'การประท้วงในประเทศเอสวาตีนีพ.ศ.2564',
#   'วิกฤตการณ์การเมืองในประเทศไทยพ.ศ.2548-2552',
#   'จังหวัดตากในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2384',
#   'ประเทศไทยในพ.ศ.2435',
#   'เหตุโจมตีในนอร์เวย์พ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2464',
#   'จังหวัดตราดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'บุคคลที่เกิดในปีพ.ศ.2518',
#   'การเลือกตั้งสภาร่างรัฐธรรมนูญในกัมพูชาพ.ศ.2536',
#   'การเลือกตั้งทั่วไปในประเทศชิลีพ.ศ.2564',
#   'การประท้วงของกลุ่มนักเรียนในชิลีพ.ศ.2554-2556',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2559',
#   'แผ่นดินไหวในจังหวัดชวาตะวันตกพ.ศ.2552',
#   'จังหวัดร้อยเอ็ดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดราชบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศไทยในพ.ศ.2344',
#   'เหตุโจมตีในดาร์ฟูร์พ.ศ.2563',
#   'จังหวัดมุกดาหารในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การประท้วงในประเทศนิการากัวพ.ศ.2561',
#   'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'จังหวัดพังงาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'แผ่นดินไหวและคลื่นสึนามิในโอกูชิริพ.ศ.2536',
#   'แผ่นดินไหวและสึนามิในเซ็นไดพ.ศ.2554',
#   'จังหวัดนครปฐมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุระเบิดในหาดใหญ่พ.ศ.2549',
#   'การประท้วงในเฮติพ.ศ.2562',
#   'พระราชกำหนดการบริหารราชการในสถานการณ์ฉุกเฉินพ.ศ.2548',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2554',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศมองโกเลียพ.ศ.2563',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยมีนาคมพ.ศ.2535',
#   'การเลือกตั้งสมาชิกวุฒิสภาในประเทศไทยพ.ศ.2549',
#   'ประเทศไทยในพ.ศ.2458',
#   'จังหวัดสุโขทัยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศอิตาลีพ.ศ.2563',
#   'การเลือกตั้งทั่วไปในสเปนพ.ศ.2554',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2524',
#   'บุคคลที่เกิดในปีพ.ศ.2490',
#   'การระบาดของโคโรนาไวรัสในสหรัฐพ.ศ.2563',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2544',
#   'บุคคลที่เกิดในปีพ.ศ.2528',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยพ.ศ.2549',
#   'แผ่นดินไหวในหุบเขาเฟอร์กานาพ.ศ.2554',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศปาปัวนิวกินีพ.ศ.2563',
#   'จังหวัดสิงห์บุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'บุคคลที่เกิดในปีพ.ศ.2469',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยเมษายนพ.ศ.2549',
#   'แผ่นดินไหวในประเทศตุรกีและประเทศซีเรียพ.ศ.2566',
#   'อุทกภัยในประเทศจีนพ.ศ.2554',
#   'ประเทศไทยในพ.ศ.2359',
#   'การประท้วงในเลบานอนพ.ศ.2562',
#   'จังหวัดศรีสะเกษในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในฟูกูชิมะพ.ศ.2564',
#   'เหตุระเบิดในกันดะฮาร์พ.ศ.2564',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2552',
#   'การโจมตีด้วยขีปนาวุธในอูมัญพ.ศ.2566',
#   'เหตุระเบิดในอิสตันบูลพ.ศ.2565',
#   'จังหวัดตรังในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'เหตุจลาจลในอังกฤษพ.ศ.2554',
#   'จังหวัดตรังในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การลงมติไม่ไว้วางใจในประเทศไทยพ.ศ.2552',
#   'การก่อการกำเริบในบูร์กินาฟาโซพ.ศ.2557',
#   'ประเทศไทยในพ.ศ.2438',
#   'ประเทศไทยในพ.ศ.2511',
#   'ดนตรีเกาหลีใต้ในพ.ศ.2565',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'คลื่นความร้อนในประเทศญี่ปุ่นพ.ศ.2561',
#   'จังหวัดสมุทรปราการในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'แผ่นดินไหวในพม่าสิงหาคมพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2415',
#   'จังหวัดสระบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การระบาดทั่วของไวรัสโคโรนาในสหรัฐพ.ศ.2563',
#   'การเลือกตั้งสภาร่างรัฐธรรมนูญในกัมพูชาพ.ศ.2489',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2530',
#   'ไฟไหม้ครั้งใหญ่ในลอนดอนพ.ศ.2209',
#   'ประเทศไทยในพ.ศ.2467',
#   'จังหวัดพิษณุโลกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เหตุโจมตีในแคร์ซอนเดือนพฤษภาคมพ.ศ.2566',
#   'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐอเมริกาพ.ศ.2552',
#   'จังหวัดนราธิวาสในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดภูเก็ตในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2332',
#   'โคลนถล่มขนาดใหญ่ในเมืองอะตะมิพ.ศ.2564',
#   'จังหวัดสระแก้วในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในมณฑลเสฉวนพ.ศ.2551',
#   'บุคคลที่เกิดในปีพ.ศ.2468',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2540',
#   'จังหวัดกระบี่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2542',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2560',
#   'เหตุปะทะในลาฮัดดาตูพ.ศ.2556',
#   'บุคคลที่เกิดในปีพ.ศ.2519',
#   'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในเปตรีญาพ.ศ.2563',
#   'จังหวัดสมุทรสงครามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'จังหวัดเพชรบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'การประท้วงในประเทศไทยพ.ศ.2563',
#   'รัฐประหารในประเทศตุรกีพ.ศ.2559',
#   'ประเทศไทยในพ.ศ.2498',
#   'เหตุการณ์โรงงานอบลำไยระเบิดในจังหวัดเชียงใหม่พ.ศ.2542',
#   'การลงประชามติระดับชาติในประเทศชิลีพ.ศ.2563',
#   'การเลือกตั้งทั่วไปในเดนมาร์กพ.ศ.2554',
#   'จังหวัดอุดรธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'บุคคลที่เกิดในปีพ.ศ.2509',
#   'ฤดูหนาวในประเทศไทยพ.ศ.2558–2559',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#   'จังหวัดสุรินทร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'อนิเมะในปีพ.ศ.2558',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศอิตาลีพ.ศ.2563',
#   'ประเทศไทยในพ.ศ.2360',
#   'การเลือกตั้งทั่วไปในประเทศบราซิลพ.ศ.2561',
#   'การเลือกตั้งซ่อมในประเทศพม่าพ.ศ.2555',
#   'การระบาดของโรคพิษสุนัขบ้าในประเทศไทยพ.ศ.2561',
#   'การเลือกตั้งทั่วไปในประเทศตองกาพ.ศ.2553',
#   'แผ่นดินไหวในรัฐสิกขิมพ.ศ.2554',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2555',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2526',
#   'การต่อต้านอังกฤษในพม่าพ.ศ.2428-2438',
#   'จังหวัดสตูลในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุระเบิดในบอสตันมาราธอนพ.ศ.2556',
#   'ประเทศไทยในพ.ศ.2474',
#   'การจลาจลในสวีเดนพ.ศ.2563',
#   'จังหวัดอุบลราชธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุกราดยิงสปาในแอตแลนตาพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2485',
#   'เหตุเหยียบกันเสียชีวิตในสพริมละพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในเนเธอร์แลนด์พ.ศ.2555',
#   'บุคคลที่เกิดในปีพ.ศ.2481',
#   'ประเทศไทยในพ.ศ.2550',
#   'เหตุยิงกันในลาสเวกัสสตริปพ.ศ.2560',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'อุทกภัยในประเทศไทยพ.ศ.2526',
#   'ภาพยนตร์ที่ออกฉายในปีพ.ศ.2555',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศไทยพ.ศ.2563',
#   'อุทกภัยในประเทศไทยพ.ศ.2538',
#   'จังหวัดมหาสารคามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'อุบัติเหตุเหมืองถ่านหินในประเทศจีนพ.ศ.2555',
#   'เหตุโจมตีด้วยขีปนาวุธในอูมัญพ.ศ.2566',
#   'จังหวัดหนองบัวลำภูในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2552',
#   'จังหวัดร้อยเอ็ดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2535',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'แผ่นดินไหวในจังหวัดคูมาโมโตะพ.ศ.2559',
#   'เหตุระเบิดในคาบูล17สิงหาคมพ.ศ.2562',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยตุลาคมพ.ศ.2549',
#   'ประเทศไทยในพ.ศ.2490',
#   'อนิเมะในปีพ.ศ.2566',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศไทยพ.ศ.2563–2564',
#   'ลำดับเวลารัฐประหารในประเทศไทยพ.ศ.2557',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2526',
#   'จังหวัดประจวบคีรีขันธ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุภาวะพิษแอลกอฮอล์ในรัฐปัญจาบพ.ศ.2563',
#   'การลงประชามติในไทยพ.ศ.2559',
#   'อุทกภัยในรัฐควีนส์แลนด์ธันวาคมพ.ศ.2553-มกราคมพ.ศ.2554',
#   'จังหวัดนครศรีธรรมราชในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ฤดูหนาวในประเทศไทยพ.ศ.2560–2561',
#   'จังหวัดเลยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'จังหวัดศรีสะเกษในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2549',
#   'บุคคลที่เกิดในปีพ.ศ.2539',
#   'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เหตุระเบิดที่มัสยิดในเปศวาร์พ.ศ.2566',
#   'การขายกิจการสถานีโทรทัศน์ในไมอามี่พ.ศ.2551',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศเยอรมนีพ.ศ.2563',
#   'จังหวัดปราจีนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'รัฐประหารในประเทศเมียนมาพ.ศ.2564',
#   'ประเทศไทยในพ.ศ.2398',
#   'แผ่นดินไหวในประเทศอัฟกานิสถานมิถุนายนพ.ศ.2565',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2497',
#   'เหตุฝูงชนเบียดกันจนเสียชีวิตในอีแทว็อนพ.ศ.2565',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2529',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2556',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2522',
#   'จังหวัดสระแก้วในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'วิดีโอเกมในพ.ศ.2552',
#   'ความขัดแย้งนิยมรัสเซียในประเทศยูเครนพ.ศ.2557',
#   'พระราชบัญญัติความสัมพันธ์ภายในครอบครัวพ.ศ.2561',
#   'แผ่นดินไหวในประเทศไทยพ.ศ.2557',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2546',
#   'ผลที่ตามมาจากเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮกุพ.ศ.2554',
#   'เหตุจลาจลในพนมเปญพ.ศ.2546',
#   'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'แผ่นดินไหวในเกาะลมบกกรกฎาคมพ.ศ.2561',
#   'จังหวัดพัทลุงในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การก่อการกำเริบในสาธารณรัฐแมซิโดเนียพ.ศ.2544',
#   'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'บุคคลที่เกิดในปีพ.ศ.2475',
#   'ไฟฟ้าดับในประเทศอินเดียพ.ศ.2555',
#   'ประเทศไทยในพ.ศ.2540',
#   'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#   'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'ประเทศไทยในพ.ศ.2448',
#   'การประท้วงในประเทศอิหร่านพ.ศ.2562–2563',
#   'จังหวัดลำปางในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ไฟป่าในรัสเซียพ.ศ.2553',
#   'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศไทยในพ.ศ.2483',
#   'ริ้วขบวนพระอิสริยยศในพระราชพิธีพระราชทานเพลิงพระศพฯพ.ศ.2551',
#   'จังหวัดมหาสารคามในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2563',
#   'ความไม่สงบในทิเบตพ.ศ.2551',
#   'จังหวัดปทุมธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2512',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'อุทกภัยในประเทศญี่ปุ่นพ.ศ.2561',
#   'จังหวัดอุตรดิตถ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'การเลือกตั้งทั่วไปในประเทศภูฏานพ.ศ.2561',
#   'เหตุโจมตีในปารีสเดือนพฤศจิกายนพ.ศ.2558',
#   'การประท้วงในเฮติพ.ศ.2562–2565',
#   'กรณีล้มการแข่งขันฟุตบอลในประเทศไทยพ.ศ.2560',
#   'ไฟป่าในโบลิเวียพ.ศ.2553',
#   'เหตุเพลิงไหม้ในบากูพ.ศ.2561',
#   'จังหวัดเชียงรายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีในประเทศไทยพ.ศ.2552',
#   'ความขัดแย้งในประเทศซูดานพ.ศ.2566',
#   'แผ่นดินไหวในอาเจะห์พ.ศ.2555',
#   'จังหวัดสมุทรปราการในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'จังหวัดนครสวรรค์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 1587

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['เหตุโจมตีในมหาวิทยาลัยคาบูลพ.ศ.2563',
#  'ประเทศไทยในพ.ศ.2418',
#  'การก่อการกำเริบในทิเบตพ.ศ.2502',
#  'แผ่นดินไหวในจังหวัดชวาตะวันตกพ.ศ.2565',
#  'การเลือกตั้งระดับท้องถิ่นในกัมพูชาพ.ศ.2555',
#  'โทรทัศน์ประเทศไทยในพ.ศ.2538',
#  'เหตุสารฟิโปรนิลปนเปื้อนในไข่พ.ศ.2560',
#  'อุทกภัยในประเทศซูดานพ.ศ.2563',
#  'ประเทศไทยในพ.ศ.2519',
#  'การปิดการเข้าถึงวิกิพีเดียในประเทศตุรกีพ.ศ.2560',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2544',
#  'ความขัดแย้งในประเทศซูดานพ.ศ.2566',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศแซมเบียพ.ศ.2563',
#  'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#  'แผ่นดินไหวในเปรูพ.ศ.2550',
#  'เหตุจลาจลในประเทศอังกฤษพ.ศ.2554',
#  'อนิเมะในปีพ.ศ.2561',
#  'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#  'สถาปัตยกรรมในพ.ศ.2555',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2549',
#  'เหตุระเบิดในอิสตันบูลพ.ศ.2559',
#  'จังหวัดพัทลุงในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'ประเทศไทยในพ.ศ.2509',
#  'ประเทศไทยในพ.ศ.2550',
#  'จังหวัดอำนาจเจริญในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'แผ่นดินไหวและคลื่นสึนามิในเซ็นไดพ.ศ.2554',
#  'จังหวัดอุบลราชธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'บุคคลที่เกิดในปีพ.ศ.2506',
#  'การช่วยเหลือด้านมนุษยธรรมต่อเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮะกุพ.ศ.2554',
#  'บุคคลที่เกิดในปีพ.ศ.2495',
#  'บุคคลที่เกิดในปีพ.ศ.2528',
#  'เหตุระเบิดในประเทศศรีลังกาพ.ศ.2562',
#  'ประเทศไทยในพ.ศ.2400',
#  'การประท้วงในประเทศอิหร่านพ.ศ.2562–2563',
#  'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'ประเทศไทยในพ.ศ.2466',
#  'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'แผ่นดินไหวในคอสตาริกาพ.ศ.2560',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2566',
#  'จังหวัดภูเก็ตในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'การประท้วงในประเทศนิการากัวพ.ศ.2561–2565',
#  'รัฐประหารในประเทศมาลีพ.ศ.2555',
#  'ประเทศไทยในพ.ศ.2336',
#  'ประเทศไทยในพ.ศ.2436',
#  'ประเทศไทยในพ.ศ.2473',
#  'การเปลี่ยนชื่อเดือนและสัปดาห์ในประเทศเติร์กเมนิสถานในพ.ศ.2545',
#  'การประท้วงในจอร์เจียพ.ศ.2554',
#  'รัฐประหารในประเทศไทยพ.ศ.2557',
#  'การลงประชามติในไทยพ.ศ.2559',
#  'เหตุเหยียบกันเสียชีวิตในเมรอนพ.ศ.2564',
#  'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2536',
#  'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2548',
#  'จังหวัดอุตรดิตถ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'ประเทศไทยในพ.ศ.2488',
#  'จังหวัดนครราชสีมาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'การช่วยเหลือด้านมนุษยธรรมต่อเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮกุพ.ศ.2554',
#  'ไฟดับในประเทศอินเดียกรกฎาคมพ.ศ.2555',
#  'รัฐประหารในประเทศชีลีพ.ศ.2516',
#  'ภาพยนตร์ในปีพ.ศ.2542',
#  'แผ่นดินไหวในรัฐเวอร์จิเนียพ.ศ.2554',
#  'การเลือกตั้งสหพันธรัฐในเยอรมนีพ.ศ.2556',
#  'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'เหตุเหยียบกันเสียชีวิตในซาบาริมาลาพ.ศ.2554',
#  'เหตุระเบิดในไนจีเรียธันวาคมพ.ศ.2554',
#  'อุทกภัยในรัฐควีนส์แลนด์ธันวาคมพ.ศ.2553-มกราคมพ.ศ.2554',
#  'จังหวัดพิจิตรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'แผ่นดินไหวในจังหวัดมิยางิพฤษภาคมพ.ศ.2564',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2533',
#  'จังหวัดกระบี่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'เหตุรถไฟตกรางในจังหวัดประจวบคีรีขันธ์พ.ศ.2552',
#  'เหตุโจมตีในนิสพ.ศ.2559',
#  'บุคคลที่เกิดในปีพ.ศ.2536',
#  'แผ่นดินไหวในรัฐวาฮากาพ.ศ.2561',
#  'เหตุอาคารถล่มในซาวาร์พ.ศ.2556',
#  'รัฐประหารในประเทศไทยเมษายนพ.ศ.2476',
#  'เหตุโจมตีในชายแดนภาคใต้ของประเทศไทยพ.ศ.2566',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2481',
#  'แผ่นดินไหวในมหาสมุทรอินเดียพ.ศ.2555',
#  'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2565',
#  'แผ่นดินไหวในชวาพ.ศ.2561',
#  'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#  'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'การเลือกตั้งทั่วไปในเดนมาร์กพ.ศ.2554',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2517',
#  'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2539',
#  'ประเทศไทยในพ.ศ.2450',
#  'แผ่นดินไหวในไต้หวันพ.ศ.2542',
#  'การประท้วงในแอฟริกาเหนือและตะวันออกกลางพ.ศ.2553-2554',
#  'จังหวัดอุทัยธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'บุคคลที่เกิดในปีพ.ศ.2513',
#  'แผ่นดินไหวในลมบกกรกฎาคมพ.ศ.2561',
#  'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'แผ่นดินไหวในแคว้นเอมีเลีย-โรมัญญาพ.ศ.2555',
#  'แผ่นดินไหวในมณฑลยูนนานพ.ศ.2555',
#  'แผ่นดินไหวและสึนามิในเซ็นไดพ.ศ.2554',
#  'แผ่นดินไหวในประเทศญี่ปุ่นพ.ศ.2554',
#  'ประเทศไทยในพ.ศ.2413',
#  'จังหวัดเพชรบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 1582

# %%
get_samples(nai)
# Out:
# ['การประท้วงในฮ่องกงพ.ศ.2557',
#  'จังหวัดนครสวรรค์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#  'แผ่นดินไหวในจังหวัดชวาตะวันตกพ.ศ.2552',
#  'โทรทัศน์ประเทศไทยในพ.ศ.2506',
#  'ประเทศไทยในพ.ศ.2444',
#  'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'ประเทศไทยในพ.ศ.2494',
#  'ประเทศไทยในพ.ศ.2462',
#  'การก่อการกำเริบในซีเรียพ.ศ.2554–2555',
#  'โทรทัศน์ประเทศไทยในพ.ศ.2539',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2527',
#  'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยตุลาคมพ.ศ.2549',
#  'จังหวัดอุทัยธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'เหตุแทงคนในซัสแคตเชวันพ.ศ.2565',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศทาจิกิสถานพ.ศ.2563',
#  'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'ประเทศไทยในพ.ศ.2458',
#  'การลงมติเลือกนายกรัฐมนตรีในประเทศไทยกันยายนพ.ศ.2551',
#  'บุคคลที่เกิดในปีพ.ศ.2477',
#  'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'จังหวัดลำพูนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศแคนาดาพ.ศ.2563',
#  'แผ่นดินไหวในประเทศไต้หวันพ.ศ.2559',
#  'ไฟไหม้ครั้งใหญ่ในลอนดอนพ.ศ.2209',
#  'ประเทศไทยในพ.ศ.2451',
#  'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2525',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยพ.ศ.2549',
#  'การเลือกตั้งประธานาธิบดีสหรัฐในรัฐแคลิฟอร์เนียพ.ศ.2563',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2526',
#  'ความขัดแย้งในกัมพูชาพ.ศ.2383',
#  'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'การประท้วงในประเทศอิหร่านพ.ศ.2560–2561',
#  'ประเทศไทยในพ.ศ.2418',
#  'โทรทัศน์ประเทศไทยในพ.ศ.2498',
#  'เหตุจลาจลในฝรั่งเศสพ.ศ.2561',
#  'รัฐประหารในอินโดจีนฝรั่งเศสพ.ศ.2488',
#  'ประเทศไทยในพ.ศ.2359',
#  'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'การประท้วงในสเปนพ.ศ.2562',
#  'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'ประเทศไทยในพ.ศ.2310',
#  'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'การประท้วงในฮ่องกงพ.ศ.2562–2563',
#  'จังหวัดพิษณุโลกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'ประเทศไทยในพ.ศ.2513',
#  'ประเทศไทยในพ.ศ.2495',
#  'จังหวัดยโสธรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'ทุพภิกขภัยในฮอร์นออฟแอฟริกาพ.ศ.2554',
#  'บุคคลที่เกิดในปีพ.ศ.2470',
#  'ประเทศไทยในพ.ศ.2457',
#  'เหตุเรือบรรทุกน้ำตาลล่มในแม่น้ำเจ้าพระยาพ.ศ.2554',
#  'พระราชกำหนดการบริหารราชการในสถานการณ์ฉุกเฉินพ.ศ.2548',
#  'ประเทศไทยในพ.ศ.2428',
#  'แผ่นดินไหวในลมบกพ.ศ.2561',
#  'เหตุโจมตีในคาบูลเดือนพฤษภาคมพ.ศ.2560',
#  'การประท้วงในประเทศอิหร่านพ.ศ.2560',
#  'บุคคลที่เกิดในปีพ.ศ.2526',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2530',
#  'การระบาดทั่วของโคโรนาไวรัสในทวีปยุโรปพ.ศ.2563',
#  'เหตุจลาจลในแคว้นอังกฤษพ.ศ.2554',
#  'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'การลงประชามติเกี่ยวกับรัฐธรรมนูญในกัมพูชาพ.ศ.2515',
#  'บุคคลที่เกิดในปีพ.ศ.2502',
#  'เหตุการณ์วางระเบิดรถไฟฟ้าใต้ดินในกรุงมินสก์ประเทศเบลารุสพ.ศ.2554',
#  'ประเทศไทยในพ.ศ.2401',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2554',
#  'เหตุระเบิดในอิสตันบูลพ.ศ.2565',
#  'จังหวัดสมุทรสงครามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'ประเทศไทยในพ.ศ.2479',
#  'คลื่นความร้อนในประเทศญี่ปุ่นพ.ศ.2561',
#  'เหตุเพลิงไหม้อาคารสูงในเกาสฺยงพ.ศ.2564',
#  'การปิดการเข้าถึงวิกิพีเดียในประเทศตุรกีพ.ศ.2560',
#  'จังหวัดศรีสะเกษในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'เหตุจลาจลในอังกฤษพ.ศ.2554',
#  'การระบาดของอีโบลาในแอฟริกาตะวันตกพ.ศ.2557',
#  'ประเทศไทยในพ.ศ.2387',
#  'การเลือกตั้งทั่วไปในเนเธอร์แลนด์พ.ศ.2555',
#  'จังหวัดชุมพรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#  'เหตุระเบิดในจังหวัดสงขลาพ.ศ.2548',
#  'พายุหมุนเขตร้อนในพ.ศ.2562',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศอียิปต์พ.ศ.2563',
#  'แผ่นดินไหวในพม่าเมษายนพ.ศ.2559',
#  'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2544',
#  'จังหวัดพะเยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'บุคคลที่เกิดในปีพ.ศ.2520',
#  'การประท้วงในประเทศอิหร่านพ.ศ.2562',
#  'คลื่นความร้อนในเอเชียพ.ศ.2566',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2517',
#  'การออกเสียงประชามติว่าด้วยสมาชิกภาพในสหภาพยุโรปของสหราชอาณาจักรพ.ศ.2559',
#  'ภาพยนตร์ที่ออกฉายในปีพ.ศ.2555',
#  'ประเทศไทยในพ.ศ.2413',
#  'เหตุระเบิดในการาจีพ.ศ.2550',
#  'การเลือกตั้งทั่วไปในกัมพูชาพ.ศ.2509',
#  'การระบาดทั่วของโคโรนาไวรัสในประเทศเกาหลีเหนือพ.ศ.2563']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (222, 58)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศไทยในพ.ศ.2471',
#  'ประเทศไทยในพ.ศ.2446',
#  'ประเทศไทยในพ.ศ.2466',
#  'ประเทศไทยในพ.ศ.2326',
#  'ประเทศไทยในพ.ศ.2508',
#  'ประเทศไทยในพ.ศ.2558',
#  'ประเทศไทยในพ.ศ.2506',
#  'ประเทศไทยในพ.ศ.2503',
#  'ประเทศไทยในพ.ศ.2469',
#  'ประเทศไทยในพ.ศ.2553',
#  'ประเทศไทยในพ.ศ.2304',
#  'ประเทศไทยในพ.ศ.2536',
#  'ประเทศไทยในพ.ศ.2410',
#  'ประเทศไทยในพ.ศ.2381',
#  'ประเทศไทยในพ.ศ.2398',
#  'ประเทศไทยในพ.ศ.2532',
#  'ประเทศไทยในพ.ศ.2510',
#  'ประเทศไทยในพ.ศ.2539',
#  'ประเทศไทยในพ.ศ.2411',
#  'ประเทศไทยพ.ศ.2525',
#  'ประเทศไทยในพ.ศ.2415',
#  'ประเทศไทยในพ.ศ.2560',
#  'ประเทศไทยในพ.ศ.2495',
#  'ประเทศไทยในพ.ศ.2346',
#  'ประเทศไทยในพ.ศ.2441',
#  'ประเทศไทยในพ.ศ.2485',
#  'ประเทศไทยในพ.ศ.2353',
#  'ประเทศไทยในพ.ศ.2382',
#  'ประเทศไทยในพ.ศ.2367',
#  'ประเทศไทยในพ.ศ.2406',
#  'ประเทศไทยในพ.ศ.2545',
#  'ประเทศไทยในพ.ศ.2524',
#  'ประเทศไทยในพ.ศ.2436',
#  'ประเทศรัสเซียในพ.ศ.2566',
#  'ประเทศไทยในพ.ศ.2409',
#  'ประเทศไทยในพ.ศ.2423',
#  'ประเทศไทยในพ.ศ.2534',
#  'ประเทศไทยในพ.ศ.2518',
#  'ประเทศไทยในพ.ศ.2275',
#  'ประเทศไทยในพ.ศ.2541',
#  'ประเทศไทยในพ.ศ.2458',
#  'ประเทศไทยในพ.ศ.2470',
#  'ประเทศไทยในพ.ศ.2414',
#  'ประเทศไทยในพ.ศ.2461',
#  'ประเทศไทยในพ.ศ.2405',
#  'ประเทศไทยในพ.ศ.2490',
#  'ประเทศไทยในปีพ.ศ.2549',
#  'ประเทศไทยในพ.ศ.2488',
#  'ประเทศไทยในพ.ศ.2428',
#  'ประเทศไทยในพ.ศ.2437',
#  'ประเทศไทยในพ.ศ.2502',
#  'ประเทศไทยในพ.ศ.2231',
#  'ประเทศไทยในพ.ศ.2520',
#  'ประเทศไทยในพ.ศ.2360',
#  'ประเทศไทยในพ.ศ.2474',
#  'ประเทศไทยในพ.ศ.2565',
#  'ประเทศไทยในพ.ศ.2412',
#  'ประเทศไทยในพ.ศ.2505',
#  'ประเทศไทยในพ.ศ.2448',
#  'ประเทศไทยในพ.ศ.2489',
#  'ประเทศไทยในพ.ศ.2566',
#  'ประเทศไทยในพ.ศ.2453',
#  'ประเทศไทยในพ.ศ.2434',
#  'ประเทศไทยในพ.ศ.2432',
#  'ประเทศไทยในพ.ศ.2433',
#  'ประเทศไทยในพ.ศ.2380',
#  'ประเทศไทยในพ.ศ.2472',
#  'ประเทศไทยในพ.ศ.2562',
#  'ประเทศไทยในพ.ศ.2501',
#  'ประเทศไทยพ.ศ.2539',
#  'ประเทศไทยในพ.ศ.2547',
#  'ประเทศไทยในพ.ศ.2513',
#  'ประเทศไทยในพ.ศ.2445',
#  'ประเทศไทยในพ.ศ.2408',
#  'ประเทศไทยในพ.ศ.2394',
#  'ประเทศไทยในพ.ศ.2496',
#  'ประเทศไทยในพ.ศ.2521',
#  'ประเทศไทยในปีพ.ศ.2475',
#  'ประเทศไทยในพ.ศ.2468',
#  'ประเทศไทยในพ.ศ.2455',
#  'ประเทศไทยในพ.ศ.2457',
#  'ประเทศไทยในพ.ศ.2478',
#  'ประเทศไทยในพ.ศ.2440',
#  'ประเทศไทยในพ.ศ.2563',
#  'ประเทศไทยในพ.ศ.2384',
#  'ประเทศไทยในพ.ศ.2335',
#  'ประเทศไทยในพ.ศ.2515',
#  'ประเทศไทยในพ.ศ.2512',
#  'ประเทศไทยในพ.ศ.2396',
#  'ประเทศไทยในพ.ศ.2554',
#  'ประเทศไทยพ.ศ.2550',
#  'ประเทศไทยในพ.ศ.2378',
#  'ประเทศไทยในพ.ศ.2392',
#  'ประเทศไทยในพ.ศ.2327',
#  'ประเทศไทยในพ.ศ.2325',
#  'ประเทศไทยในพ.ศ.2486',
#  'ประเทศไทยในพ.ศ.2492',
#  'ประเทศไทยในพ.ศ.2393',
#  'ประเทศไทยพ.ศ.2491',
#  'ประเทศไทยในพ.ศ.2425']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ
