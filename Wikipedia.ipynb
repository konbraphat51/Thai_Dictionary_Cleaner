# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
len(titles)
# Out:
# 362955

# %%
get_samples(titles)
# Out:
# ['โชเนน',
#  'จันนี่_สแกนเดอลัคกี้',
#  'เจ้าหญิงมารี_หลุยส์แห่งเบอร์เบิ้น-ปาร์มา',
#  'รายชื่อหน่วยงานวางระเบียบทางภาษา',
#  'Heteradelphia',
#  'แดนนี_วอร์ด',
#  'Siege_of_Malta_(1565)',
#  'ประเทศนิการากัวในแพนอเมริกันเกมส์',
#  'Shisha',
#  'คะซุโกะ_ทะคัตสึคะซะ',
#  'ช่วนจินก่า',
#  'Gamma_function',
#  'สมเด็จพระเจ้าซาร์นิโคลาสที่_2_แห่งรัสเซีย',
#  'Po',
#  'Jamala',
#  'โจเอล_แคมป์เบลล์',
#  'ทะเลทรายนามิเบีย',
#  'วัดประชาบำรุง_(จังหวัดมหาสารคาม)',
#  'ยุทธการที่ฌ็องบลู_(ค.ศ.1940)',
#  'กระเบนปีศาจญี่ปุ่น',
#  'ชิงกันเซ็ง_E3_ซีรีส์',
#  'หมากรุกญี่ปุ่นสี่คน',
#  'แอร์เอเชีย_เอกซ์',
#  'แมนเชสเตอร์ดาร์บี',
#  'เหตุระเบิดที่บาตา_พ.ศ._2564',
#  'ยุทธการที่แม่น้ำลิส_(ค.ศ._1940)',
#  'กัง_กิยุล',
#  'Rock-Hewn_Churches,_Lalibela',
#  'เดวิด_อิสตัน',
#  'ค.ศ._1381',
#  'บูร์คันคัลดุน',
#  'การจับตำแหน่งข้อต่อ',
#  'เอนริเก_เปญญา_นิเอโต',
#  'อ.โพธิ์ไทร',
#  'ฐิตินันท์_แสงนาค',
#  'In/Spectre',
#  'Phrynoidis_aspera',
#  'ละอองดาว_(นวนิยาย)',
#  'สภาวะเสียการระลึกรู้สัณฐานโดยคลำ',
#  'เกาะสเวตินิโกลา',
#  'อำเภอกุสินารา',
#  'Graz',
#  'วอลเลย์บอลชายไทยเดนมาร์คซูเปอร์ลีก_2016',
#  'คุณทองแดง',
#  'ประวีณวัช_บุญยงค์',
#  'เคราร์ด_เดอูโลเฟอู',
#  'เอฟเอ็ม_(อีพี)',
#  'ประยูร_อุลุชาฎะ',
#  'คณะรัฐมนตรีคณะที่_14_ของไทย',
#  'Brihanmumbai_Municipal_Corporation',
#  'แจ้งวัฒนะ',
#  'สาย_JR_ยะมะโนะเตะ',
#  'ค.ศ._605',
#  'ผู้ว่าฯกทม.',
#  'สถานีดาวคะนอง',
#  'Tulumella',
#  'วัดศาลาแดง',
#  'แอนดราส',
#  'ชินามิ_โทกูนางะ',
#  'วิกิพีเดียภาษาบันยูมาซัน',
#  'เส้นเมริเดียนที่_128_องศาตะวันออก',
#  'ทเวนตีเฟิสต์เซนจูรีเบรกดาวน์',
#  'สถานีรถไฟชินางาวะ',
#  'ดราก้อนบอล_(ภาพยนตร์ชุดทางโทรทัศน์)',
#  'เซเนบเฮนัส',
#  'หยาง_อี่',
#  'รี้ด_(เก็นโซซุยโคเด็น)',
#  'Chubu_International_Airport',
#  'สถาบันข้อมูลขนาดใหญ่_(องค์การมหาชน)',
#  'ฟุตบอลถ้วยพระราชทานประเภท_ก._ประจำปี_2551',
#  'Clara_Sosa',
#  'แหล่งโบราณคดีเมืองศรีมโหสถ',
#  'สะบายดีหลวงพระบาง',
#  'อิริเดียมเตโตรไซด์',
#  'ตำนานสมเด็จพระนเรศวรมหาราช_ภาค_๕_ยุทธหัตถี',
#  'เค้าก่อน_(เพลงยูอาร์บอยทีเจ)',
#  'ห้าอัครบุคคล_(คีตกวี)',
#  'Sulfur',
#  'เอ็มทีวีวิดีโอมิวสิกอวอร์ดส',
#  'Technotronic',
#  'คณะแพทยศาสตร์วชิรพยาบาล',
#  'เรนอินบลัด',
#  'จังหวัดนีแด',
#  'ท็อปเชฟไทยแลนด์_ฤดูกาลที่_1',
#  'Gastrotrich',
#  'Natsuki_Hanae',
#  'วัดธรรมาราม_(อำเภอพระนครศรีอยุธยา)',
#  'เดวิด_คาราดีน',
#  'หลักหิน_วสันตสิทธิ์',
#  'ฮอนด้า_ซีอาร์วี',
#  'ความเอนเอียงโดยทำให้ต่าง',
#  'ครุยเซอร์_มาร์ค_8_ชาลเลนเจอร์',
#  'Kim_Woo-seok_(singer)',
#  'โนะริโอะ_วะกะโมะโตะ',
#  'ราชอาณาจักรฮัชไมต์จอร์แดนในโอลิมปิกฤดูร้อน_2008',
#  'วัดพระศรีรัตนมหาธาตุเชลียงราชวรวิหาร_(พระปรางค์)',
#  'พระมหากษัตริย์แห่งยูโกสลาเวีย',
#  'Creagrocercidae',
#  'สามเกลอข้อโปน',
#  'ชลิตา_เฟื่องอารมณ์']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

len(titles)
# Out:
# 353833

# %%
get_samples(titles)
# Out:
# ['เคียวโกะ_อิโนะอุเอะ',
#  'เหรียญเงินช้างเผือก',
#  'Godzilla_Against_Mechagodzilla',
#  '2011–ปัจจุบัน',
#  'หิรัณยกศิปุ',
#  'พราน',
#  'ออคตาฟ_มีโบ',
#  'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป_พ.ศ._2550',
#  'แมสซีฟแอตแทก',
#  'ศาสนาพุทธในประเทศรัสเซีย',
#  'O._Henry_Award',
#  'วงศ์กวางชะมดป่า',
#  'ปลาแดมเซลฟ้าหางส้ม',
#  'ข้าหลวงต่างพระองค์เครือรัฐออสเตรเลีย',
#  'สโมสรฟุตบอลจังหวัดตราด',
#  'ตำบลเฆร์กู',
#  'อุสมาน_ศรแดง',
#  'อูว์เกอโนต์',
#  'The_Imperial',
#  'ฟิล_ทากูปา',
#  'ดุสิต_เฉลิมแสน',
#  'ลีอาห์_ดีซอน',
#  'Scleropages_aureus',
#  'KC_WEEKLY',
#  'ไอแพด_มินิ',
#  'Labiobarbus',
#  'วัดพันท้ายนรสิงห์',
#  'เหตุการณ์รถไฟชนกันที่ตลิ่งชัน_พ.ศ._2522',
#  'วงศ์นกขาบ',
#  'ภาวะทุพโภชนาการ',
#  'กาเบรียล_คว็อก',
#  'Tragulidae',
#  'แอนดี_เล',
#  'เอ็มเอสเอ็นเมสเซนเจอร์',
#  'การตลาดแบบปากต่อปาก',
#  'า',
#  'Niponiosomatidae',
#  'มหาวิบัตินครดับสูญ',
#  'สาธารณรัฐเอกวาดอร์ในโอลิมปิกฤดูร้อน_1992',
#  'Azerbaijan_Cup',
#  'พระเจ้าฮั่นเซ่าตี้',
#  'ยัน_ฟัน_ไอก์',
#  'บีแยลาวา',
#  'ภาษาซาซากิ',
#  'BUT_/_ไอโช',
#  'เทศบาลตำบลทุ่งเสลี่ยม',
#  'กันทาริยามหาเทวมนเทียร',
#  'ฟิโอดอร์_ดอสโตเยฟสกี',
#  'มหาวิทยาลัยเอ็กซิเตอร์',
#  'พอล_แวน_ไดก์',
#  'Hockey',
#  'สวนลุมพินีวัน',
#  'เกเนอราลพลานอ็อสท์',
#  'Brad_Jones',
#  'Codonanthopsis',
#  'นิกายไวษณพ',
#  'นอร์แมน_เฟกิเดโร',
#  'โรนัลโด้',
#  'สมพงค์_ภูววิมล',
#  'มังกรโคโมโด',
#  'ฟุตบอลถ้วยพระราชทานประเภท_ก._ประจำปี_2557',
#  'ประเทศเนปาลในเอเชียนเกมส์_2006',
#  'Hun_Maneth',
#  'สงครามปราบศึกฮ่อ',
#  'ฟุตซอลในซีเกมส์',
#  'ออร์บิทัล',
#  'การป้องกันมะเร็ง',
#  'พ.ศ._1833',
#  'เอฟเอ_คัพ',
#  'วันเสรีภาพสื่อมวลชนโลก',
#  'คีธ_เบลล์',
#  'พ.ศ._1706',
#  'ปลาไหลช่อ',
#  'วัดเกาะพยาม',
#  'เครื่องราชอิสริยาภรณ์ทริสเติล',
#  '๑๐_พฤษภาคม',
#  'Musa_acuminata_subsp._siamea',
#  'อภิสมัย_ศรีรังสรรค์',
#  'ดานิ_การ์บาฆัล',
#  'วัดวังพระธาตุ',
#  'แม่น้ำเน็คคาร์',
#  'ฟิฟตี้_เซ็นต์',
#  'การเลือกตั้งระบบสัดส่วนแบบเปิด',
#  'สมเด็จพระราชินีมาเรีย_โจเซฟีน_หลุยส์แห่งซาวอย',
#  'วีน-มยิน',
#  'อุทยานรัชกาลที่_๙',
#  'Victor_Emmanuel_II_of_Italy',
#  'อัลบัยฎออ์',
#  'ประเทศเกาหลีเหนือในโอลิมปิกฤดูหนาว_2018',
#  'เควิน_โนแลน',
#  'มิสเตอร์เนชันแนลยูนิเวิร์ส',
#  'พระเทพพัชรญาณมุนี',
#  'กวีไมเคิล_แจ็กสัน',
#  'ญะบัล_อันนูร',
#  'โรคปมประสาทบาซัล',
#  'ทางหลวงแผ่นดินหมายเลข_303',
#  'อิฟไอเวอร์อะบอย',
#  'รายชื่อแหล่งมรดกโลกในประเทศอิหร่าน',
#  '386BSD',
#  'ท่าอากาศยานนานาชาติพาโร']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

len(titles)
# Out:
# 465912

# %%
get_samples(titles)
# Out:
# ['SanAntonio,TX',
#  'เองรีกีดีเซนาฟีร์นังดิช',
#  'ปลาการ์ตูนส้ม',
#  'คาวิกา',
#  'บางกอกซิตี้แชนแนล',
#  'ปีเตอร์เบียร์ดสลีย์',
#  'ตำนานสมเด็จพระนเรศวรมหาราชเดอะซีรีส์',
#  'แลมโบกินี่มูร์เซียลาโก',
#  'al-Razi',
#  'แกลสส์',
#  'เจี้ยนเหวิน',
#  'AgnesChow',
#  'Samart',
#  'กระดูกเอทมอยด์',
#  'ลีก้า',
#  'เข็มกลัดฟิบิวลา',
#  'Shijiazhuang',
#  'พ.ศ.2047',
#  'ปลากะพงแถบน้ำเงิน',
#  'พ.ศ.1123',
#  'เส้นเมริเดียนที่127',
#  'ยูโซ',
#  'ทรีมาโลส',
#  'พระเจ้าหรรษวรมันที่1',
#  'วัดท่าไชยศิริ',
#  'Monumental',
#  'DreamWorks,LLC',
#  'สมเด็จพระราชินีนาถราซอเฮอรินาแห่งมาดากัสการ์',
#  'Internetprotocolsuite',
#  'HighDefinitionTV',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล2022–23',
#  'ล้อตุนกำลัง',
#  'ทาทูอิน',
#  'ตำบลกำแพงเซา',
#  'ฌอห์น',
#  'SACD',
#  'ราชสำนักแห่งเกาหลี',
#  'ชีคมูจิบูร์เราะห์มาน',
#  'ComputerspielemuseumBerlin',
#  'พัชรี',
#  '2248',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าหญิงน้อง',
#  'UniversityofSt.Andrews',
#  'สโมสรฟุตบอลแมนเชสเตอร์ซิตีในฤดูกาล2013–14',
#  'ประกาศสิทธิมนุษยชนและพลเมือง',
#  'กรดไขมันโอเมกา3',
#  'ลี่อิน',
#  'กันดั้มดับเบิ้ลโอ',
#  'พระที่นั่งนิพัทธพงศ์ถาวรวิจิตร',
#  'พรรคนำไทย',
#  'Dyn',
#  'จังหวัดโฮร์โมซกอน',
#  'บุคคลที่เกิดในปีพ.ศ.2534',
#  'เวทมนตร์ใน',
#  'เตกีลาซันไรส์',
#  'ภาษามะนอง',
#  '.ve',
#  'Canisaureus',
#  'โรคสมองบาดเจ็บเรื้อรัง',
#  'ฟาโรห์เซเคมเรคูทาวีโซเบคโฮเทป',
#  'การเคลื่อนลงตามความชัน',
#  'วัคซีนโรคบาดทะยัก',
#  'มหารานีแห่งแผ่นดิน',
#  'Starbucks',
#  'Phalaenopsisamabilis',
#  'MSN',
#  'เตอร์กิชวูแมนส์วอลเลย์บอลลีก',
#  'Huchotaimen',
#  'พระองค์เจ้ามรกฎ',
#  'ดิอิมพอสซิเบิล',
#  'โจมา',
#  'machina',
#  'ยามาซากิซางารุ',
#  'Image',
#  'Triquetrumbone',
#  'นายกรัฐมนตรีบาห์เรน',
#  'Fiorentina',
#  'อัสแซสซินส์ครีด:บลัดไลนส์',
#  'MiguelPérezCuesta',
#  'SuperShowTourConcertAlbum',
#  'พงศาวดารเขมร',
#  'หมึกยักษ์เล็ก',
#  'Goldensnub-nosedmonkey',
#  'ฮิโรโนบุซากางูจิ',
#  'Antrodiacamphorate',
#  'เรือหลวงพลายชุมพล',
#  'กีฬาเรือพายในเอเชียนเกมส์2022',
#  'การพับกระดาษ',
#  'อาคารริงกูเกททาวเวอร์',
#  'ListofcountriesbyGDP',
#  'ยุคอีดีแอคารัน',
#  'PrinceGabrielofThurnandTaxis',
#  'bin',
#  'Groningen',
#  'วีแอลซี',
#  'สามช่า',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:โทรอนโต',
#  'Cynometra',
#  'ยุทธการที่แม่น้ำซอมม์',
#  'อาบุลฮะซันบานีศาดร์']

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

len(titles)
# Out:
# 346494

# %%
get_samples(titles)
# Out:
# ['รายชื่อเจ้าผู้ครองลีชเทินชไตน์',
#  'ฟร็องซัวออลลองด์',
#  'ความบริสุทธิ์',
#  'สมณกรรมาธิการนครรัฐวาติกัน',
#  'โปรแกรมจัดการดาวน์โหลด',
#  'ไมเคิลแจ็กสันกับประเทศไทย',
#  'พรอปเพอร์ตี',
#  'เอ็กซ์เพลส',
#  'จุดไกลดวงอาทิตย์ที่สุด',
#  'ฌอสแปง',
#  'ศรีชัยวัชรบุรี',
#  'พระเจ้าโจวมู่หวัง',
#  'ไมค์เบลส์',
#  'ซูแปร์เลกาฤดูกาล2021–22',
#  'สถานีอวกาศเทียนกง',
#  'พระทีั่นั่งอัมพรสถาน',
#  'ไทยแลนด์ก็อตทาเลนต์ซีซั่นที่2',
#  'ฟูชิเซน',
#  'รายชื่อตัวละครในเรื่อง',
#  'อิชตาลล์',
#  'นีดะ',
#  'ฌอง-ลุกแซสซัส',
#  'คณะรัฐมนตรีไทย',
#  'เจ้าหญิงเอ็มมาแห่งวัลเด็คและไพร์มอนต์',
#  'เมื่อผู้กล้าลาโลกแล้ว!เพราะชาวบ้านอย่างผมเผลอทำผู้กล้าตาย',
#  'พระราชบัญญัติความสัมพันธ์ภายในครอบครัว',
#  'ไคซูเกะ',
#  'ยงยุทธสัจจวานิชย์',
#  'โคโค่แจ๊ซ',
#  'ชีวิตไม่ง่ายของนางร้าย',
#  'อ.ภูผาม่าน',
#  'เมืองฝาง',
#  'ประเทศปากีสถานในโอลิมปิกฤดูร้อน1956',
#  'นกเด้าลม',
#  'วอลเลย์บอลชายชิงแชมป์แอฟริกา2021',
#  'ชาลีผาย',
#  'ประเทศโมซัมบิกในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ไฟลามทุ่ง',
#  'ลิขิตรักตะวันและจันทรา',
#  'หายใจเร็ว',
#  'เวสต์วิค',
#  'พระเจ้าชาร์ลส์ที่',
#  'ยุทธการที่หับป๋า',
#  'รูกกีบีบี',
#  'รูปร้อยเหลี่ยม',
#  'แป้งณัฐธิดา',
#  'ค.ศ.968',
#  'พระเจ้าอัลฟอนโซที่13แห่งสเปน',
#  'อาบราโมวิช',
#  'มายาอลเวง',
#  'มิสเตอร์ดี',
#  'เมาตินี',
#  'โนริอากิฟูจิโมโตะ',
#  'รักโง่ๆ',
#  'จักรพรรดิซีกิสมุนด์แห่งจักรวรรดิโรมันอันศักดิ์สิทธิ์',
#  'ประเทศเนปาลในพาราลิมปิกฤดูร้อน2020',
#  'แบรม',
#  'ซานธอส',
#  'ผ้าซิ่นทิวมุก',
#  'โรงเรียนมัธยมวัดหนองแขม',
#  'ฟูจิที-3',
#  'บ่ายวันอาทิตย์บนเกาะลากร็องด์ยัต',
#  'พระบรมราชินี',
#  'หม่อมหลวงสราลี',
#  'ปาวรตี',
#  'เบนซิมิดาโซล',
#  'พระราชวังเดิม',
#  'วัดแคนอก',
#  'นครปกครองโดยตรงของประเทศจีน',
#  'เคตช์วาโย',
#  'วัดศรีจันทาราม',
#  'กลุ่มดาวตาข่าย',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าวิภาวดีรังสิต',
#  'รายชื่อตัวละครในสาวน้อยยอดนักสืบ',
#  'สตรอนเทียม',
#  'โทะโยะตะ',
#  'สมเด็จพระราชินีนาถแอนน์แห่งเกรตบริเตน',
#  'คนสองเพศ',
#  'วัคซีนลดฤทธิ์',
#  'นิวรอนสั่งการ',
#  'พระวรสารนอกสารบบ',
#  'อาสนวิหารกูต็องส์',
#  'พระสุพรรณนพรัตน์ศิราภรณ์มงคล',
#  'ทากาอากิโทมิมัตสึ',
#  'ท้องฟ้าจำลองเนห์รู',
#  'กองพลยานเกราะดิ่งพสุธาที่1แฮร์มันเกอริง',
#  'การวิจัยเชิงทดลองทางคลินิก',
#  'คลื่นความร้อนในเอเชียพ.ศ.2566',
#  'เจ้าชายจอร์จ',
#  'เกย์-ฟอร์-เพย์',
#  'ในพระนามของพระบิดา',
#  'โกเตง',
#  'ซงโงกุน',
#  'อาวุธยุทธสัมภาระ',
#  'ประเทศเวียดนามในเอเชียนเกมส์1954',
#  'คิมิโนะอุตะ',
#  'สาธารณรัฐเวียดนาม',
#  'สถานีมหาวิทยาลัยเกษตรศาสตร์',
#  'โนลกัลลาเกอส์ไฮฟลายอิงเบิดส์',
#  'อีวานเคร็ก']

# %% [markdown]
# ### Seperate colon

# %%
len([title for title in titles if ":" in title])
# Out:
# 1465

# %%
[title for title in titles if ":" in title][:50]
# Out:
# ['โจโจ้ล่าข้ามศตวรรษ:เครซี่ไดอมอนด์ด้วยรักและใจสลาย',
#  'เดอะเลเจนด์ออฟเซลดา:อะลิงก์ทูเดอะแพสต์',
#  'เวียงกุมกาม:นครใต้พิภพ',
#  'ยอดนักสืบจิ๋วโคนัน:ฝ่าวิกฤติเรือรบมรณะ',
#  'มาสค์ไรเดอร์ไฟซ์เดอะมูฟวี่:สงครามมนุษย์กลายพันธุ์',
#  'อัสแซสซินส์ครีด:ลินนิเอจ',
#  'ดาวน์:',
#  'เอฟรีเดส์:',
#  'สตาร์วอร์ส:เดอะแบดแบตช์',
#  'สตาร์ไดรเวอร์:ทาคุโตะผู้เจิดจรัส',
#  'เทคโอเวอร์:',
#  'โททัลวอร์:',
#  'คังโคเระ:',
#  'รายชื่อตอนในเบ็นเท็น:อัลติเมทเอเลี่ยน',
#  'เมทัลเกียร์โซลิด5:เดอะแฟนทอมเพน',
#  'แบล็กพิงก์:เดอะเวอชวล',
#  'เพอร์ฟูม:',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:อาร์เอฟโวลูชั่น',
#  'ลาพิวตา:',
#  'สตาร์วอร์ส:โรกวัน',
#  'เอาต์เบรก:',
#  'สวิฟต์:',
#  'ยอดนักสืบจิ๋วโคนัน:ปริศนาบนถนนสายมรณะ',
#  'PoliceStory3:SuperCopวิ่งสู้ฟัด3',
#  'เซอร์ไวเวอร์ปานามา:เกาะอัปยศ',
#  'โปเกมอนเรนเจอร์:แชโดวส์ออฟอัลเมีย',
#  'เดิร์จออฟเซอร์เบรัส:',
#  'คอมมานด์แอนด์คองเคอร์:เจเนรัลส์',
#  'เอจออฟมีโธโลจี:เดอะไททันส์',
#  'วิแวร์:เดอะเบสท์ออฟ',
#  'เดอะเลเจนด์ออฟเซลดา:เมเยอราส์แมสก์3D',
#  'ฮอบบิท:',
#  'กันดั้มบิลด์ไฟท์เตอร์ไทร:IslandWars',
#  'ดราก้อนฟอร์ซ:โซลอง,อุลตร้าแมน',
#  'ทูไลตส์:',
#  'สตาร์เทรค:',
#  'รายชื่อตอนCSI:Miami',
#  'เดอะไลออนคิง:',
#  'ดิเอลเดอร์สครอลล์สV:สกายริม',
#  'นีดฟอร์สปีด:เดอะรัน',
#  'รีซิสแตนซ์:',
#  'ลิตเติลนีโม:เดอะดรีมมาสเตอร์',
#  'เรฟโวลูชั่นส์:',
#  'เดอะ100:อะแรงกิงออฟเดอะมอสต์อินฟลูเอนเชียลเพอร์เซินอินฮิสทรี',
#  'อีวานเกเลียน:1.0กำเนิดใหม่วันพิพากษา',
#  'เจเรมีสก็อตต์:เดอะพีเพิลส์ดีไซเนอร์',
#  'บีอินเดอะมิกซ์:',
#  'โซนิคโครนิเคิลส์:',
#  'ดราฟต์:แฮกกิงอีดียู',
#  'ทรี:']

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    if ":" in title:
        titles_temp.update(title.split(":"))
    else:
        titles_temp.add(title)
    
titles = titles_temp
len(titles)
# Out:
# 345587

# %%
get_samples(titles)
# Out:
# ['หฤษฏ์ชีวการุณ',
#  'มหาวิทยาลัยเดอปอล',
#  'โคเมอร์เนตี',
#  'โทนีแบร็กซ์ตัน',
#  'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1920',
#  'เคลลีย์',
#  'ประเทศอิหร่านในโอลิมปิกฤดูหนาว1964',
#  'กิ่งเหมือนแพร',
#  'ขบวนการพลังขั้นสูงโอเรนเจอร์',
#  'ทอเลมีที่',
#  'ค.ศ.1957',
#  'จังหวัดโอต-มาร์น',
#  'ปราสาทพทูย',
#  'ทิโมชาริส',
#  'คาร์เมอร์เรเนบตี้ที่',
#  'หัวไช้เท้า',
#  'พระแม่มาริอัมมัน',
#  'หลวงจีนหอไตร',
#  'ฟิวดัล',
#  'กีฬากรีฑาในซีเกมส์2017–ขว้างค้อนชาย',
#  'มณฑลบุมทัง',
#  'การเปลี่ยนแปลงการปกครอง',
#  'ฟลอร์เอ็กเซอร์ไซส์',
#  'คนอึดตายยาก',
#  'อะตอมมิค',
#  'วารสารฟ้าเดียวกัน',
#  'แม็ทเกรนิง',
#  'วัดดอยงำเมือง',
#  'วชิรวิชญ์ไพศาลกุลวงศ์',
#  'รายนามนายกรัฐมนตรีไทย',
#  'จับหมู',
#  'รายชื่อแหล่งมรดกโลกในประเทศคิวบา',
#  'เภสัชภัณฑ์',
#  'จังหวัดโวกลูซ',
#  'มุรากาวะ',
#  'วัคซีนบีซีจี',
#  'บุคคลที่เกิดในปีพ.ศ.2504',
#  'เงาสมิง',
#  'กอทิก',
#  'ฤดูพายุเฮอร์ริเคนแปซิฟิกพ.ศ.2558',
#  'ปลดหนี้ร้องแลกหนี้',
#  'ยาซูโกะ',
#  'ความสัมพันธ์ไทย-พม่า',
#  'สมบูรณ์ไพรคุก',
#  'เมกะบางนา',
#  'กุญแจเสียง',
#  'วรวุธศรีมะฆะ',
#  'สตาร์มูฟวี่ส์',
#  'สุณัฐชา',
#  'อาร์ชดยุกออตโต',
#  'ตระกูลนักการเมืองในประเทศไทย',
#  'ประวัติการพัฒนายานสตาร์ชิป',
#  'โซโลอาร์ค',
#  'ไคโก้',
#  'รางวัลโวแทร็ง',
#  'การก่อการกำเริบในดอนบัสส์',
#  'ธรรมาธิการี',
#  'บทส่งท้าย',
#  'โรเบิร์ตเรดฟอร์ด',
#  'โรงเรียนดาราคาม',
#  'โตเกียวเกรทแบรส์',
#  'กระแสเอ็ดดี้',
#  'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2024',
#  'ยูกะเทราซากิ',
#  'โรแบร์ทเทาเบอ',
#  'ความจำประกาศ',
#  'ซอกเกอร์',
#  'พระมหากษัตริย์ฮอลแลนด์',
#  'อุธมสิงห์',
#  'บวชเณรหน้าไฟ',
#  'เหงียนถิกีมเงิน',
#  'แลคคัชซึญสกี',
#  'ชาร์ลอตต์ทาวน์',
#  'ประเทศปาเลสไตน์',
#  'อาเลสซันโดรโฟลเรนซี',
#  'เกาะภูเขาไฟ',
#  'ต่อมขับน้ำเมือก',
#  'ทางหลวงแผ่นดินหมายเลข310',
#  'มิชิโกะฮะดะ',
#  'จดหมายเหตุ',
#  'สนามกีฬาฟัลเมอร์',
#  'ซิทรินโกลบอล',
#  'จื่อฉยง',
#  'แอฟริกาตะวันออกของเยอรมนี',
#  'คัตสึมิมากิยามะ',
#  'บูริ',
#  'สมเด็จเจ้าฟ้ากรมพระอนุรักษ์เทเวศร์',
#  'จังหวัดลพบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'โซบะแบบโอกินาวะ',
#  'เทพเอบิซุ',
#  'พ.ศ.359',
#  'พระองค์เจ้าสิงหนาทราชดุรงค์ฤทธิ์',
#  'เอฟเอ็มเอ',
#  'กีฬาไตรกีฬาในโอลิมปิกฤดูร้อน2020',
#  'อันนัม',
#  'กัปตันเลเซอร์ฮอว์ค',
#  'คัมภีร์อรรถกถา',
#  'มิโคลส์',
#  'เคเอ็มเพลเยอร์',
#  'ศิษย์ไตรภูมิ']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4992

# %%
get_samples(raay)
# Out:
# ['รายพระนามและชื่อผู้ได้รับพระราชทานว.ม.ล.',
#  'รายชื่อดาราจักร',
#  'รายชื่อผลงานของ',
#  'รายนามปลัดกระทรวงคมนาคมของไทย',
#  'รายชื่อตอนในซีเอสไอ',
#  'รายพระนามและชื่อผู้ปกครองเอสโตเนีย',
#  'รายพระนามผู้ปกครองมอลดาเวีย',
#  'รายชื่อประเทศเรียงตามอัตราการว่างงาน',
#  'รายชื่อเผ่าพันธุ์ในสตาร์',
#  'รายชื่อผู้ที่ได้รับตำแหน่ง',
#  'รายชื่อวัดในจังหวัดนครศรีธรรมราช',
#  'รายชื่อรางวัลที่ธงไชยแมคอินไตย์ได้รับ',
#  'รายชื่อภาพเขียนโดยโยฮันเนิส',
#  'รายชื่อผู้ได้รับรางวัลเพลงประกอบภาพยนตร์ยอดเยี่ยม',
#  'รายชื่อการออกแบบคบเพลิงโอลิมปิก',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งจอร์แดน',
#  'รายชื่อสัตว์น้ำ',
#  'รายชื่อเพลงหน้าพาทย์',
#  'รายชื่อฟอร์ช็อกและอาฟเตอร์ช็อกจากแผ่นดินไหวและคลื่นสึนามิในโทโฮะกุพ.ศ.2554',
#  'รายชื่อทางแยกในเขตยานนาวา',
#  'รายชื่อโบราณสถานในจังหวัดมหาสารคาม',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐจีน',
#  'รายนามรัฐมนตรีว่าการกระทรวงวิทยาศาสตร์และเทคโนโลยี',
#  'รายชื่อลูกฟุตบอลโอลิมปิกอย่างเป็นทางการ',
#  'รายชื่อแชมป์โลกมวยสากลรุ่นไลท์ฟลายเวท',
#  'รายชื่อวัดในจังหวัดเพชรบูรณ์',
#  'รายนามรัฐมนตรีกระทรวงกลาโหม',
#  'รายนามประธานาธิบดีมาดากัสการ์',
#  'รายพระนามพระมหากษัตริย์และจักรพรรดิเยอรมนี',
#  'รายชื่อแหล่งมรดกโลกในประเทศเวเนซุเอลา',
#  'รายชื่อประเทศเรียงตามการผลิตแมงกานีส',
#  'รายชื่อภาพยนตร์เจมส์บอนด์',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2565',
#  'รายพระนามผู้ปกครองบาวาเรีย',
#  'รายชื่้อผู้นำประเทศ',
#  'รายชื่อตัวละครในค่ายฮาล์ฟบลัด',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2473',
#  'รายชื่อแหล่งมรดกโลกในทวีปเอเชีย',
#  'รายชื่อแหล่งมรดกโลกในประเทศเม็กซิโก',
#  'รายการแหล่งมรดกโลกในประเทศเวียดนาม',
#  'รายชื่อโบราณสถานในจังหวัดหนองบัวลำภู',
#  'รายพระนามสมเด็จพระราชินีแห่งปรัสเซีย',
#  'รายชื่อคณะเทคนิคการแพทย์',
#  'รายนามอธิบดีกรมธนารักษ์',
#  'รายนามประธานาธิบดีเวเนซุเอลา',
#  'รายการตอนในวันพีซ',
#  'รายชื่อผลงานเพลงของนิว',
#  'รายชื่อสายการบินในประเทศลาว',
#  'รายชื่อเครื่องอิสริยาภรณ์ทาจิกีสถาน',
#  'รายชื่อตอนในละคร3หนุ่ม3มุมx2',
#  'รายชื่อบทของเซียนเกมรักขอเป็นเทพนักจีบ',
#  'รายชื่อตอนในLucky☆Star',
#  'รายชื่อนักมวยแชมป์โลกชาวไทย',
#  'รายชื่อเมืองหลวงของรัฐและดินแดนสหภาพในประเทศอินเดีย',
#  'รายชื่อกลุ่มบริษัทและธุรกิจในเครือจีเอ็มเอ็มแกรมมี',
#  'รายชื่อโบราณสถานในจังหวัดพังงา',
#  'รายพระนามรัชทายาทตองงา',
#  'รายได้พื้นฐาน',
#  'รายชื่อโบราณสถานในจังหวัดนครราชสีมา/อำเภอเมือง-อำเภอปักธงชัย',
#  'รายพระนามพระมหากษัตริย์มาดากัสการ์',
#  'รายชื่อของการสังหารหมู่ในประเทศเกาหลีเหนือ',
#  'รายการผลงานของบีเอ็นเคโฟร์ตีเอต',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายชื่อฉบับของมิสแกรนด์อินเตอร์เนชันแนล',
#  'รายชื่อเกิร์ลกรุปในประเทศเกาหลีใต้',
#  'รายชื่อพระราชนิพนธ์ในสมเด็จพระกนิษฐาธิราชเจ้า',
#  'รายชื่อแขนงความรู้',
#  'รายชื่อประเทศที่เข้าร่วมการแข่งขันกีฬาโอลิมปิกฤดูร้อน',
#  'รายชื่อพระเกียรติยศในสมเด็จพระกนิษฐาธิราชเจ้ากรมสมเด็จพระเทพรัตนราชสุดา',
#  'รายชื่อโบราณสถานในจังหวัดอุดรธานี',
#  'รายการตัวละครในดราก้อนบอล',
#  'รายการประชิด',
#  'รายนามนักร้องเพลงลูกกรุง',
#  'รายชื่อผีฝรั่ง',
#  'รายพระนามและรายนามผู้ได้รับพระราชทานป.ภ.',
#  'รายชื่อโบราณสถานในจังหวัดสกลนครที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อรางวัลและการเสนอชื่อที่เกิลส์เจเนอเรชันได้รับ',
#  'รายชื่อนายกรัฐมนตรีมาเลเซีย',
#  'รายนามผู้ครองตำแหน่งมิสเตอร์อินเตอร์เนชันแนล',
#  'รายนามนักมวยสากลชาวไทยที่เป็นแชมป์เงา',
#  'รายนามประธานสภาผู้แทนราษฎรของไทย',
#  'รายพระนามจักรพรรดิจีนในราชวงศ์จิ้น',
#  'รายชื่อพระนิพนธ์ในสมเด็จพระเทพรัตนราชสุดาฯ',
#  'รายชื่อตัวแทนประเทศไทยในการประกวดนางงามชายนานาชาติ',
#  'รายชื่อคำศัพท์เกี่ยวกับศาสนาอิสลาม',
#  'รายชื่อตุ๊กตาสัญลักษณ์โอลิมปิก',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2558',
#  'รายพระนามและชื่อผู้ได้รับพระราชทานร.ว.',
#  'รายพระนามจักรพรรดิจีนในราชวงศ์หมิง',
#  'รายชื่อประมุขแห่งรัฐสหภาพโซเวียต',
#  'รายชื่อเมืองในประเทศแกมเบีย',
#  'รายชื่อนักแสดงในสตาร์',
#  'รายพระนามพระมหากษัตริย์ตาฮีตี',
#  'รายชื่อบุคคลสำคัญจากมหาวิทยาลัยมหิดล',
#  'รายชื่อสโมสรในไทยลีก',
#  'รายนามผู้ประกาศข่าวและผู้รายงานข่าวสถานีโทรทัศน์ทีเอ็นเอ็นช่อง16',
#  'รายชื่อนครในสหรัฐเรียงตามจำนวนประชากร',
#  'รายชื่ออัลบั้มเพลงของพุ่มพวงดวงจันทร์',
#  'รายนามรัฐมนตรีสตรีในคณะรัฐมนตรีไทย',
#  'รายชื่อแหล่งมรดกโลกในประเทศอุซเบกิสถาน']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 57

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายาแห่งซาราวัก',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายได้พื้นฐาน',
#  'รายงานเฮิร์ช',
#  'รายาห์',
#  'รายงานเฮิรส์ช',
#  'รายงานอาหาร',
#  'รายงานค่าใช้จ่าย',
#  'รายงานเค้ส',
#  'รายงานกรณี',
#  'รายาแห่งรัฐปะลิส',
#  'รายาประไหมสุหรีอากง',
#  'รายากับมังกรตัวสุดท้าย',
#  'รายได้',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายาฮีเจา',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°C',
#  'ราย',
#  'รายวนปูเลาเกอลาปา',
#  'รายงานความสุขโลก',
#  'รายได้มูลฐาน',
#  'รายนานนท์',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายานนท์',
#  'รายงานเคส',
#  'รายงานการประชุม',
#  'รายวน',
#  'รายงานคนไข้',
#  'รายูวันปูเลาเกอลาปา',
#  'รายา',
#  'รายงานประจำปี',
#  'รายาผิวขาว',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายคอวิช',
#  'รายาฮีเยา',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°ซ.',
#  'รายาอูงู',
#  'รายยวา',
#  'รายาบีรู',
#  'รายกอวิช',
#  'รายปุระ',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายาแห่งซาราวะก์',
#  'รายหัว',
#  'รายากูนิง',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานทีหลัง']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
len(titles)
# Out:
# 340652

# %%
get_samples(titles)
# Out:
# ['เดอะฟิวเจอร์ซาวด์ออฟลอนดอน',
#  'บียอร์สเตียร์เนบียอร์สัน',
#  'พ.ศ.1066',
#  'มติ',
#  'คาร์ลิโน่',
#  'ซีราคิวส์,ซิซิลี',
#  'ยุคไพลโอซีน',
#  'เหรียญ2เออเรอ',
#  'รูด็อล์ฟเช็งเคอร์',
#  'ยุทธการบาร์เน็ต',
#  'มาอูโร',
#  'เขาไกรลาส',
#  'ไฮไดนามิกเรจน์อิมเมจ',
#  'ลูโซโฟนีเกมส์2017',
#  'สถานีวิทยุโทรทัศน์รัฐสภา',
#  'หนุ่มสาว',
#  'วัดแก้วไพฑูรย์',
#  'หลงต้าน',
#  'วิศวกรรมการผลิต',
#  'ป้อมเบรสต์',
#  'ยาโนชบาโลห์',
#  'จอห์นปอลที่2',
#  'เกวงกา',
#  'กุลรัตนรักษ์',
#  'เดอะบลัดไลน์',
#  'เพชรโพธิ์ทอง',
#  'สมเด็จเจ้านครอินทร์',
#  'กำเนิดใหม่ไอ้มดแดงยุคเรย์วะ',
#  'โรแกน',
#  'เพชรงามชูวัฒนะ',
#  'ความน่าจะเป็นบนเส้นขนาน',
#  'ครกบดยา',
#  '10ก.ย.',
#  'ไอรอนแมน2',
#  'ลักษณะปรากฏ',
#  'กาฟิรโกฏ',
#  'อิมพิเรียลคอลเลจ',
#  'คุนโพ',
#  'สุกุมล',
#  'ตำบลหนองไม้แดง',
#  'จงฉู่หง',
#  'เจ.โคล',
#  'วัดปากคลองหก',
#  'ทวีวงศ์',
#  'กองพลแพนเซอร์เอ็สเอ็สที่12ฮิตเลอร์ยูเกนด์',
#  'ซิมเปิลแพลน',
#  'ร็อกวิธยู',
#  '๒๔มกราคม',
#  'ดาเนียลคาเก',
#  'ชิเงรุมิยะโมะโตะ',
#  'มหาวิทยาลัยเทคโนโลยีแห่งมิวนิก',
#  'ปางนาคาวโลก',
#  'ฮิซาตาดะ',
#  'อังแดรซิลวา',
#  'ไทบีเรี่ยม',
#  'นพปฎลมหาเศวตฉัตร',
#  'โลมาหลังโหนกอินโดแปซิฟิก',
#  'เออร์เนสต์คิง',
#  'ตลาดหลักทรัพย์ฮ่องกง',
#  'กฤษฏ์',
#  'เดอะดับเบิลยูบี',
#  'นอตทิงแฮมฟอเรสต์',
#  'การล้อมเซวัสโตปอล',
#  'พลคำ',
#  'พัฒนพลมินทะขิน',
#  'รุชด์',
#  'ไวทยานนท์',
#  'นักเลงภูเขาทอง',
#  'แอ่งคอนไดลาร์',
#  'มหาวิทยาลัยไรซ์',
#  'แฟนแทสติก',
#  'ประเทศกรีซในโอลิมปิกเยาวชนฤดูหนาว2020',
#  'ธนนนท์กิตติยศ',
#  'รอซเซลิ',
#  'เดชาสุวรรณสุก',
#  'เส้นเมริเดียนที่124องศาตะวันตก',
#  'เมะกะมุซุเมะ',
#  'สไปเดอแมน',
#  'อีเคร์คาซียาส',
#  'ปลากัดป่า',
#  'วัดสีหยัง',
#  'อำเภออัชชัรยะฮ์',
#  'ฮามีดีแยมาร์ชือ',
#  'เครื่องจักสาน',
#  'ตำบลงิ้ว',
#  'เชียร์เชซอฟ',
#  'มัสยิดยาบัลโรดเหร๊าะหม๊ะ',
#  'มาสค์ไรเดอร์ไกมุ',
#  'พาวเวอร์เรนเจอร์ซีโอ',
#  'วัดจตุรมิตรประดิษฐาราม',
#  'ปลาผีเสื้อกลางคืนปากยาว',
#  'อีฮโยริ',
#  'ด็อกซิลามีน',
#  'เซอร์จิโอ',
#  'แม่น้ำเยนีเซย์',
#  'กีฬาทางอากาศในกีฬาแห่งชาติครั้งที่',
#  'เจ้าคณะภาค5',
#  'นิวแฮมไชร์',
#  'คณะสาธารณสุขศาสตร์มหาวิทยาลัยราชภัฏนครราชสีมา',
#  'ยุทธการที่กรุงเฮก']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (5976, 1488)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศเม็กซิโกในโอลิมปิกฤดูร้อน2008',
#  'ประเทศซูรินามในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศสวีเดนในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศสเปนในโอลิมปิกฤดูหนาว1948',
#  'ประเทศเกาหลีใต้ในโอลิมปิก',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1936',
#  'ประเทศฟิลิปปินส์ในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศเม็กซิโกในโอลิมปิกฤดูร้อน1980',
#  'ประเทศจีนในโอลิมปิก',
#  'ประเทศเวียดนามในเอเชียนเกมส์2018',
#  'ประเทศตองกาในโอลิมปิกฤดูร้อน2008',
#  'ประเทศปานามาในโอลิมปิกฤดูร้อน1976',
#  'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1996',
#  'ประเทศบรูไนดารุสซาลามในโอลิมปิกฤดูร้อน2000',
#  'ประเทศสาธารณรัฐโปรตุเกส',
#  'ประเทศอิเควทอเรียลกินีในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'ประเทศทาจิกิสถานในโอลิมปิกฤดูร้อน2012',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1956',
#  'ประเทศไทยในพ.ศ.2462',
#  'ประเทศเลบานอนในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศออสเตรเลียในโอลิมปิกฤดูร้อน',
#  'ประเทศมาลีในพาราลิมปิกฤดูร้อน',
#  'ประเทศนอร์เวย์ในโอลิมปิกฤดูหนาว1972',
#  'ประเทศฮังการีในโอลิมปิกฤดูหนาว1988',
#  'ประเทศบาฮามาสในโอลิมปิกฤดูร้อน1984',
#  'ประเทศคาซัคสถานในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศเวียดนาม',
#  'ประเทศแซมเบียในโอลิมปิกฤดูร้อน2016',
#  'ประเทศแกมเบียในโอลิมปิกฤดูร้อน1984',
#  'ประเทศบาฮามาสในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'ประเทศเลโซโทในโอลิมปิกฤดูร้อน1988',
#  'ประเทศเวเนซุเอลาในโอลิมปิกฤดูร้อน2000',
#  'ประเทศพม่าในโอลิมปิกฤดูร้อน1948',
#  'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน1972',
#  'ประเทศเซอร์เบียและมอนเตเนโกร',
#  'ประเทศคาซัคสถานในโอลิมปิกเยาวชนฤดูหนาว2020',
#  'ประเทศเปรู',
#  'ประเทศมาเลเซียในโอลิมปิกเยาวชนฤดูร้อน2018',
#  'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1992',
#  'ประเทศเอสวาตีนีในโอลิมปิกฤดูร้อน',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1964',
#  'ประเทศเวียดนามในเอเชียนเกมส์ฤดูหนาว2017',
#  'ประเทศคาซัคสถานในโอลิมปิกฤดูร้อน2016',
#  'ประเทศปานามาในโอลิมปิกฤดูร้อน1928',
#  'ประเทศไมโครนีเซียในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศมองโกเลียในเอเชียนเกมส์2010',
#  'ประเทศโคลอมเบียในพาราลิมปิกฤดูร้อน',
#  'ประเทศอิรักในโอลิมปิกฤดูร้อน2012',
#  'ประเทศสเปนในโอลิมปิกฤดูร้อน1996',
#  'ประเทศสเปนในโอลิมปิกฤดูร้อน1988',
#  'ประเทศเกรเนดาในโอลิมปิกฤดูร้อน',
#  'ประเทศแกมเบียในพาราลิมปิกฤดูร้อน',
#  'ประเทศโมร็อกโกในโอลิมปิกฤดูร้อน2000',
#  'ประเทศไทยในซีเกมส์2003',
#  'ประเทศมาเลเซียในซีเกมส์2023',
#  'ประเทศออสเตรเลียในโอลิมปิกฤดูร้อน1948',
#  'ประเทศอาร์มีเนียในโอลิมปิกฤดูร้อน2000',
#  'ประเทศอำนาจนำภูมิภาค',
#  'ประเทศมาเลเซีย',
#  'ประเทศฟิลิปปินส์',
#  'ประเทศบูร์กินาฟาโซในโอลิมปิกฤดูร้อน2008',
#  'ประเทศอาร์เจนตินาในโอลิมปิกฤดูหนาว2018',
#  'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน2012',
#  'ประเทศฮังการีในโอลิมปิกฤดูร้อน1996',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน2004',
#  'ประเทศคีร์กีซสถานในโอลิมปิกฤดูร้อน2024',
#  'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิก',
#  'ประเทศอิหร่านในโอลิมปิกเยาวชนฤดูร้อน2018',
#  'ประเทศรัสเซียในโอลิมปิกฤดูร้อน2008',
#  'ประเทศจีนในเอเชียนเกมส์ฤดูหนาว',
#  'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูร้อน2004',
#  'ประเทศแคเมอรูนในโอลิมปิกฤดูร้อน2020',
#  'ประเทศฟิจิในโอลิมปิก',
#  'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูหนาว1924',
#  'ประเทศโมร็อกโกในโอลิมปิกฤดูหนาว1992',
#  'ประเทศตูนิเซียในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศออสเตรียในโอลิมปิกฤดูร้อน1912',
#  'ประเทศฟิลิปปินส์ในโอลิมปิกฤดูหนาว',
#  'ประเทศโตโกในโอลิมปิก',
#  'ประเทศบัลแกเรียในโอลิมปิกฤดูหนาว2022',
#  'ประเทศจีนไทเปในโอลิมปิกฤดูร้อน1988',
#  'ประเทศจิบูตีในโอลิมปิกฤดูร้อน2012',
#  'ประเทศบังกลาเทศในโอลิมปิกเยาวชนฤดูร้อน2018',
#  'ประเทศโบลิเวียในโอลิมปิกฤดูหนาว2018',
#  'ประเทศไลบีเรียในโอลิมปิกฤดูร้อน2020',
#  'ประเทศเกาหลีเหนือในโอลิมปิกฤดูร้อน2012',
#  'ประเทศที่เข้าร่วมมิสแกรนด์อินเตอร์เนชันแนล',
#  'ประเทศลัตเวียในพาราลิมปิกฤดูร้อน',
#  'ประเทศอาร์มีเนียในโอลิมปิกฤดูหนาว2006',
#  'ประเทศอุรุกวัยในโอลิมปิกฤดูร้อน1996',
#  'ประเทศเลบานอนในโอลิมปิกฤดูหนาว1992',
#  'ประเทศไนจีเรียในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศออสเตรียในโอลิมปิกฤดูร้อน1988',
#  'ประเทศบุรุนดีในพาราลิมปิกฤดูร้อน2012',
#  'ประเทศเช็กโกสโลวาเกียในโอลิมปิกฤดูหนาว1976',
#  'ประเทศโครเอเชียในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศไทยในพาราลิมปิกฤดูร้อน2024',
#  'ประเทศโมนาโกในโอลิมปิกเยาวชนฤดูร้อน2018',
#  'ประเทศเอธิโอเปียในโอลิมปิกฤดูร้อน2000',
#  'ประเทศคอสตาริกาในพาราลิมปิกฤดูร้อน2016']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [titles for titles in titles if "ใน" in titles]
len(nai)
# Out:
# 20880

# %%
[nai][:50]
# Out:
# [['ฟุตบอลในโอลิมปิกฤดูร้อน1948',
#   'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน1928',
#   'สาธารณรัฐประชาธิปไตยประชาชนแอลจีเรียในโอลิมปิกฤดูร้อน1972',
#   'การหลั่งใน',
#   'เหตุสะพานในโมรพีถล่ม',
#   'ประเทศแอลเบเนียในโอลิมปิกเยาวชน',
#   'แผ่นดินไหวในประเทศปาปัวนิวกินี',
#   'ประเทศซาอุดีอาระเบียในโอลิมปิกฤดูร้อน',
#   'สหภาพโซเวียตในโอลิมปิกฤดูหนาว',
#   'สาธารณรัฐรวันดาในโอลิมปิกฤดูร้อน1996',
#   'สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล',
#   'เหตุการณ์สำคัญในสมัยกรุงศรีอยุธยา',
#   'การเลือกตั้งในประเทศอินโดนีเซีย',
#   'การประท้วงโดยเผาตัวตายของชาวทิเบตในประเทศจีน',
#   'รายพระนามจักรพรรดิจีนในราชวงศ์จิ้น',
#   'ประเทศเดนมาร์กในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศอินโดนีเซียในเอเชียนเกมส์ฤดูหนาว2017',
#   'ประเทศไทยในพ.ศ.2490',
#   'พระชายาในเจ้าชายโทะโมะฮิโตะ',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1976',
#   'ศาลทหารในเวลาปกติ',
#   'รายชื่อวัดพุทธในประเทศไทย',
#   'การลงประชามติในประเทศสวิตเซอร์แลนด์ค.ศ.1920',
#   'ทีมผสมในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'กีฬาซอฟท์บอลในโอลิมปิกฤดูร้อน1996',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูหนาว2018',
#   'สงครามกลางเมืองในสเปน',
#   'ประเทศเกาหลีเหนือในเอเชียนเกมส์',
#   'ประเทศบังกลาเทศในโอลิมปิกเยาวชนฤดูร้อน',
#   'การท่องเที่ยวในประเทศญี่ปุ่น',
#   'ธงพระอิสริยยศในประเทศอิหร่าน',
#   'ราชอาณาจักรภูฏานในโอลิมปิกฤดูร้อน1992',
#   'ประเทศเวเนซุเอลาในพาราลิมปิกฤดูร้อน',
#   'ประเทศนอร์เวย์ในพาราลิมปิกฤดูร้อน2020',
#   'วันในสัปดาห์',
#   'ราชรัฐโมนาโกในโอลิมปิกฤดูร้อน1976',
#   'สงครามในดอนบัส',
#   'สาธารณรัฐซาอีร์ในโอลิมปิกฤดูร้อน1992',
#   'ประเทศกัวเตมาลาในพาราลิมปิกฤดูร้อน',
#   'รายชื่อปีในสหราชอาณาจักร',
#   'ประเทศเปรูในโอลิมปิกเยาวชนฤดูร้อน',
#   'สนามกีฬาในร่มแห่งชาติปักกิ่ง',
#   'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน2012',
#   'ราชรัฐลักเซมเบิร์กในโอลิมปิกฤดูร้อน1948',
#   'ประเทศจีนไทเปในโอลิมปิกฤดูร้อน2008',
#   'รายชื่อแหล่งมรดกโลกในทวีปอเมริกา',
#   'สาธารณรัฐคองโกในโอลิมปิกฤดูร้อน2008',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2012–ชายไม่เกิน81กิโลกรัม',
#   'ตัวละครในยอดนักสืบจิ๋วโคนัน',
#   'วอลเลย์บอลหญิงในซีเกมส์2015',
#   'อเมริกันอินเดียนในสหรัฐอเมริกา',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน2024',
#   'ประเทศเลบานอนในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'กีฬาโปโลน้ำในโอลิมปิกฤดูร้อน1992',
#   'สาธารณรัฐสหกรณ์กายอานาในโอลิมปิกฤดูร้อน2000',
#   'สาธารณรัฐประชาชนบังกลาเทศในโอลิมปิกฤดูร้อน1988',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1924',
#   'พระราชนิพนธ์ในพระบาทสมเด็จพระพุทธยอดฟ้าจุฬาโลก',
#   'สาธารณรัฐเวียดนามในโอลิมปิกฤดูร้อน1960',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน1936',
#   'กีฬาเพาะกายในซีเกมส์',
#   'ประเทศกาบองในโอลิมปิกฤดูร้อน2008',
#   'กีฬาเทนนิสในโอลิมปิกฤดูร้อน2020–รอบคัดเลือก',
#   'กีฬายิงธนูในกีฬาแห่งชาติครั้งที่',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูหนาว1960',
#   'การระบาดของไวรัสอีโบลาในประเทศไลบีเรีย',
#   'สาธารณรัฐมองโกเลียในโอลิมปิกฤดูหนาว1968',
#   'ตัวละครในเซนต์เซย์ย่า',
#   'ยูโกสลาเวียในโอลิมปิกฤดูหนาว1948',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน1988',
#   'ประเทศปากีสถานในโอลิมปิกฤดูร้อน1956',
#   'สาธารณรัฐไอร์แลนด์ในโอลิมปิกฤดูร้อน1968',
#   'สาธารณรัฐเวอร์จินไอซ์แลนด์ในโอลิมปิกฤดูร้อน1968',
#   'สาธารณรัฐมอนเตเนโกรในโอลิมปิกฤดูหนาว2014',
#   'ปรากฏการณ์มั่นใจในตัวเองเกิน',
#   'พระวิหารในกรุงเยรูซาเลม',
#   'สโมสรฟุตบอลเรกซัมในฤดูกาล2020–21',
#   'เหตุโจมตีในมินยา',
#   'สโมสรฟุตบอลจังหวัดสุพรรณบุรีในฤดูกาล2560',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูร้อน1972',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–เซเบอร์ทีมชาย',
#   'ประเทศโปแลนด์ในโอลิมปิกฤดูร้อน2016',
#   'รายชื่อตัวละครในกังฟูแพนด้า',
#   'ประเทศปากีสถานในโอลิมปิกฤดูร้อน2000',
#   'กีฬาทางอากาศในกีฬาแห่งชาติครั้งที่44',
#   'รายชื่อตอนในทอล์ก-กะ-เทยTonight',
#   'กีฬาว่ายน้ำในเอเชียนเกมส์2018',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน2024',
#   'ธงในประเทศแคนาดา',
#   'สาธารณรัฐเซเนกัลในโอลิมปิกฤดูร้อน2000',
#   'กีฬายิงปืนในโอลิมปิกฤดูร้อน2020–ปืนยาวอัดลม10เมตรทีมผสม',
#   'แผ่นดินไหวในเกาะโบโฮล',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูร้อน1968',
#   'ประเทศญี่ปุ่นในโอลิมปิกฤดูร้อน1912',
#   'ผู้เล่นในฟุตบอลโลก',
#   'กีฬาแบดมินตันในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'ระบบขนส่งมวลชนความเร็วสูงในประเทศเกาหลีใต้',
#   'กีฬาดำน้ำในเอเชียนเกมส์',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกเยาวชนฤดูร้อน',
#   'เธอฉัน,ในวันฟ้าคราม',
#   'กีฬาสกีข้ามทุ่งในโอลิมปิกเยาวชนฤดูหนาว2020–ประเภทบุคคลชายฟรีสไตล์สปรินท์',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูหนาว1992',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศแซมเบียพ.ศ.2563',
#   'รายชื่อทางแยกในเขตบางนา',
#   'สาธารณรัฐโครเอเชียในโอลิมปิกฤดูหนาว1992',
#   'วอลเลย์บอลหญิงในเอเชียนเกมส์2010',
#   'คู่อภิเษกสมรสในพระมหากษัตริย์และกษัตรีย์แห่งสเปน',
#   'กีฬาแบดมินตันในซีเกมส์',
#   'ประเทศวานูวาตูในโอลิมปิกฤดูร้อน2016',
#   'รายชื่อคู่อภิเษกสมรสในพระมหากษัตริย์และกษัตรีแห่งสเปน',
#   'กีฬายิวยิตสูในเอเชียนเกมส์2022',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1968',
#   'กีฬาว่ายน้ำในซีเกมส์2017–ท่ากบ200เมตรชาย',
#   'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์สกอตแลนด์',
#   'รายชื่อทางแยกในเขตบางกอกน้อย',
#   'สโมสรฟุตบอลจังหวัดตราดในฤดูกาล',
#   'รายชื่อคณะมนุษยศาสตร์ในประเทศไทย',
#   'รายชื่อโบราณสถานในกรุงเทพมหานครที่ขึ้นทะเบียนโดยกรมศิลปากร',
#   'การคมนาคมในประเทศไทย',
#   'รัฐกาตาร์ในเอเชียนเกมส์2010',
#   'เหตุโจมตีผู้เข้าแถวซื้อขนมปังในแชร์นีฮิว',
#   'ประเทศพม่าในเอเชียนเกมส์',
#   'กีฬารักบี้7คนในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'นักกีฬาอิสระในเอเชียนเกมส์',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1957–58',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2550',
#   'รายชื่อโบราณสถานในจังหวัดประจวบคีรีขันธ์ที่ขึ้นทะเบียนโดยกรมศิลปากร',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศซาอุดีอาระเบียพ.ศ.2563',
#   'สาธารณรัฐประชาธิปไตยคองโกในโอลิมปิกฤดูร้อน2024',
#   'ตัวละครในมาจิเรนเจอร์',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน1992',
#   'ฟุตบอลในซีเกมส์',
#   'ประเทศหมู่เกาะโซโลมอนในโอลิมปิกฤดูร้อน2008',
#   'โรคฮีโมฟิเลียในราชวงศ์ยุโรป',
#   'ประเทศกาตาร์ในเอเชียนเกมส์2022',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว1992',
#   'ประเทศกัมพูชาในเอเชียนเกมส์2010',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน1988',
#   'รายชื่อวัดในจังหวัดยโสธร',
#   'รายชื่อสถานีโทรทัศน์ในภูมิภาคเอเชียตะวันออก',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน1996',
#   'ประเทศเกาหลีใต้ในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศมาเลเซียในพาราลิมปิกฤดูร้อน2020',
#   'วัดบางพูดใน',
#   'กีฬาเรือใบในโอลิมปิกฤดูร้อน1992',
#   'ประเทศเซาท์ซูดานในโอลิมปิกฤดูร้อน',
#   'รายชื่อตอนในเส้าหลินสุดยอดพลังแห่งเพลงมวย',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน2000',
#   'ประเทศเกาหลีใต้ในเอเชียนเกมส์ฤดูหนาว2017',
#   'เหตุจลาจลในประเทศอังกฤษพ.ศ.2554',
#   'ประเทศเอธิโอเปียในโอลิมปิกฤดูร้อน',
#   'กีฬาแฮนด์บอลในโอลิมปิกฤดูร้อน2024–รอบคัดเลือกทีมชายโซนเอเชีย',
#   'ประเทศแองโกลาในโอลิมปิกฤดูร้อน2008',
#   'ประเทศอาร์มีเนียในโอลิมปิกฤดูร้อน2004',
#   'สาธารณรัฐทาจิกิสถานในเอเชียนเกมส์2010',
#   'ประเทศจิบูตีในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว1988',
#   'ที่สุดในสามโลก',
#   'เหตุโจมตีในชายแดนภาคใต้ของประเทศไทย',
#   'สาธารณรัฐฟิลิปปินส์ในเอเชียนเกมส์1951',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูร้อน1932',
#   'มรดกโลกในประเทศอินโดนีเซีย',
#   'ประเทศอินเดียในโอลิมปิกฤดูร้อน1988',
#   'อภิธานศัพท์ในอีวานเกเลียน',
#   'สาธารณรัฐเบนินในโอลิมปิกฤดูร้อน1980',
#   'เหตุรถประสานงาในปาปัวนิวกินี',
#   'สโมสรฟุตบอลเอซีมิลานในฤดูกาล',
#   'ประเทศสวาซิแลนด์ในโอลิมปิก',
#   'สนามกีฬาอเนกประสงค์ในร่มแขวงโอตะ',
#   'ประเทศอิรักในเอเชียนบีชเกมส์2010',
#   'สาธารณรัฐทาจิกิสถานในโอลิมปิกฤดูหนาว2002',
#   'กีฬาสกีลีลาในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬาขี่ม้าในแพนอเมริกันเกมส์',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูร้อน2008',
#   'ประเทศตุรกีในโอลิมปิกฤดูร้อน1976',
#   'รายนามผู้นำฝ่ายค้านในสภาผู้แทนราษฎรไทย',
#   'การประท้วงในการากัลปักสถาน',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2024',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูหนาว1948',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน2000–รอบคัดเลือกยิมนาสติกลีลาหญิง',
#   'การขนส่งระบบรางในประเทศนาอูรู',
#   'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล2022–23',
#   'สาธารณรัฐซานมารีโนในโอลิมปิกฤดูร้อน1980',
#   'สาธารณรัฐเอลซัลวาดอร์ในโอลิมปิกฤดูร้อน1988',
#   'หมอกควันในภาคเหนือของประเทศไทย',
#   'กีฬาไคท์บอร์ดในเวิลด์บีชเกมส์2019',
#   'รายชื่อนักร้องและกลุ่มศิลปินในเบเกอรี่มิวสิค',
#   'กีฬากีฑาในโอลิมปิกฤดูร้อน1900',
#   'ตัวละครในทูเลิฟรู',
#   'กีฬาคาราเต้ในกีฬาเยาวชนแห่งชาติครั้งที่33',
#   'การประท้วงในสเปน',
#   'สโมสรฟุตบอลเอสซีจีเมืองทองยูไนเต็ดในฤดูกาล2556',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูหนาว1924',
#   'ผู้เล่นในฟุตบอลชิงแชมป์สโมสรโลก',
#   'ประเทศแองโกลาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'มะเร็งในเด็ก',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูร้อน1936',
#   'ประเทศเยเมนในเอเชียนเกมส์2006',
#   'ประเทศไทยในพ.ศ.2480',
#   'กรีฑาในกีฬาแห่งชาติครั้งที่41–วิ่ง100เมตรชาย',
#   'ประเทศแอลจีเรียในโอลิมปิกฤดูร้อน2020',
#   'ประเทศเลบานอนในโอลิมปิกฤดูหนาว1956',
#   'รายชื่อแหล่งมรดกโลกในประเทศแอลจีเรีย',
#   'กีฬาในพ.ศ.2549',
#   'ประเทศบาฮามาสในโอลิมปิกฤดูร้อน2016',
#   'ประเทศอุซเบกิสถานในเอเชียนเกมส์2006',
#   'คลื่นอากาศหนาวในทวีปอเมริกาเหนือพ.ศ.2557',
#   'สโมสรฟุตบอลสมุทรปราการซิตี้ในฤดูกาล2565–2566',
#   'ฟุตบอลในโอลิมปิกเยาวชน',
#   'รายชื่อตัวละครในซามูไรพเนจร',
#   'สาธารณรัฐเบลารุสในโอลิมปิกฤดูหนาว2018',
#   'ประเทศเปรูในโอลิมปิกฤดูร้อน1968',
#   'ทีมรวมเฉพาะกิจเครือรัฐเอกราชในโอลิมปิกฤดูร้อน1992',
#   'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล2021-22',
#   'รายชื่อตัวละครในลาสต์เอ็กไซล์',
#   'กีฬากรีฑาในซีเกมส์2017–กระโดค้ำถ่อชาย',
#   'ตัวละครในโค้ด',
#   'สาธารณรัฐเอสโตเนียในโอลิมปิกฤดูร้อน2004',
#   'โทรทัศน์ประเทศไทยในค.ศ.1996',
#   'กีฬารักบี้7คนในโอลิมปิกฤดูร้อน2016',
#   'กีฬาคาราเต้ในโอลิมปิกฤดูร้อน2020',
#   'รายชื่อวัดในจังหวัดนราธิวาส',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1932',
#   'ขอแค่เป็นเทพในเงา',
#   'รายชื่อโบราณสถานในกรุงเทพมหานครที่ขึ้นทะเบียนโดยกรมศิลปากร/ฝั่งธนบุรี',
#   'แคว้นในประเทศกรีซ',
#   'รถโดยสารประจำทางในฮานอย',
#   'การระบาดทั่วของโควิด-19ในประเทศแซมเบีย',
#   'ฉัน,ในวันฟ้าคราม',
#   'รายชื่อเมืองในประเทศออสเตรเลีย',
#   'ประเทศเยเมนในโอลิมปิกฤดูร้อน2020',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน2020–ยิมนาสติกสากลบาร์คู่บุคคลชาย',
#   'สโมสรฟุตบอลสวอนซีซิตีในฤดูกาล2015–16',
#   'กีฬาเทควันโดในโอลิมปิกฤดูร้อน2004',
#   'ธงในเบลารุส',
#   'บั๊กโรเจอร์สมนุษย์ในศตวรรษที่25',
#   'กีฬาบาสเกตบอลในกีฬาแห่งชาติครั้งที่47',
#   'ประเทศซีเรียในโอลิมปิกฤดูร้อน2016',
#   'ยูโกสลาเวียในโอลิมปิกฤดูร้อน1936',
#   'กีฬาสเกตลีลาในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'กีฬาลุจในโอลิมปิกฤดูหนาว2018',
#   'กีฬาหมากล้อมในกีฬาแห่งชาติครั้งที่47',
#   'ประเทศจอร์เจียในโอลิมปิก',
#   'ประเทศอินโดนีเซียในโอลิมปิกฤดูร้อน1988',
#   'กีฬาปันจักสีลัตในกีฬาแห่งชาติครั้งที่',
#   'การปฏิวัติในฮังการีค.ศ.1956',
#   'รายชื่อเมืองในประเทศแอนติกาและบาร์บูดา',
#   'ประเทศลิกเตนสไตน์ในโอลิมปิกฤดูหนาว',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1936',
#   'ประเทศอินเดียในโอลิมปิกฤดูหนาว1968',
#   'ประเทศไลบีเรียในพาราลิมปิกฤดูร้อน',
#   'ราชอาณาจักรเนปาลในโอลิมปิกฤดูร้อน2000',
#   'รายชื่อกลุ่มบริษัทและธุรกิจในเครือจีเอ็มเอ็มแกรมมี่',
#   'ประเทศฮังการีในโอลิมปิกฤดูหนาว1960',
#   'ประเทศคิริบาสในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ราชรัฐโมนาโกในโอลิมปิกฤดูร้อน1960',
#   'อัตราส่วนของกรดไขมันในอาหารต่างๆ',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดฉะเชิงเทรา',
#   'รายชื่อตอนในไซคิหนุ่มพลังจิตอลเวง',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูหนาว1972',
#   'ประเทศกัมพูชาในโอลิมปิกฤดูร้อน2016',
#   'กีฬาเทควันโดในโอลิมปิกฤดูร้อน2020–รุ่นไม่เกิน58กิโลกรัมบุคคลชาย',
#   'รายชื่อรหัสอัจฉริยะในเกมจารชนคู่หูอันตราย',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูร้อน1960',
#   'ประเทศไอร์แลนด์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'ในใจของคุโนอิจิสึบากิ',
#   'สาธารณรัฐฟิลิปปินส์ในเอเชียนเกมส์2014',
#   'รายชื่อแหล่งมรดกโลกในประเทศเบลีซ',
#   'ประเทศอุรุกวัยในพาราลิมปิกฤดูร้อน',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–ฟอยล์บุคคลหญิง',
#   'เหตุกราดยิงในออสโลพ.ศ.2565',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'เลือดแข็งตัวในหลอดเลือดแบบกระจาย',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน1992',
#   'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน1964',
#   'ธงในประเทศสิงคโปร์',
#   'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1928',
#   'สาธารณรัฐเซอร์เบียในโอลิมปิกฤดูหนาว',
#   'กีฬาซอฟท์บอลในโอลิมปิกฤดูร้อน2008',
#   'ประเทศอิตาลีในโอลิมปิกฤดูหนาว1984',
#   'สาธารณรัฐมอลโดวาในโอลิมปิกฤดูหนาว2002',
#   'ครุยวิทยฐานะในประเทศไทย',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1948',
#   'ผู้เล่นในฟุตบอลชิงแชมป์แห่งชาติยุโรป2020',
#   'ประเทศออสเตรียในโอลิมปิกฤดูร้อน1984',
#   'บุคคลที่เสียชีวิตในเดือน',
#   'ประเทศตูวาลูในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน2004',
#   'รายพระนามพระภรรยาเจ้าและพระสนมในรัชกาลที่1',
#   'ประเทศรวันดาในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'การใช้พลังงานนิวเคลียร์ในประเทศไทย',
#   'รายชื่อตอนในแฟรี่เทล',
#   'สาธารณรัฐมาซิโดเนียในโอลิมปิกฤดูร้อน2008',
#   'สาธารณรัฐเฮติในโอลิมปิกฤดูร้อน1988',
#   'กีฬาเทควันโดในโอลิมปิกฤดูร้อน2012–หญิงไม่เกิน67กิโลกรัม',
#   'สโมสรฟุตบอลนครราชสีมามาสด้าในฤดูกาล2563–2564',
#   'ประเทศเกาหลีใต้ในโอลิมปิกฤดูร้อน1976',
#   'หลอดเลือดแดงแครอทิดภายใน',
#   'สาธารณรัฐเอลซัลวาดอร์ในโอลิมปิก',
#   'ประเทศกานาในโอลิมปิกฤดูร้อน1964',
#   'รายชื่อโบราณสถานในจังหวัดชัยนาทที่ขึ้นทะเบียนโดยกรมศิลปากร',
#   'กีฬาเซปักตะกร้อในกีฬาแห่งชาติครั้งที่46',
#   'ประเทศชาดในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'รายชื่อวัดในจังหวัดอุทัยธานี',
#   'ประเทศแทนซาเนียในพาราลิมปิกฤดูร้อน2020',
#   'รายชื่อโบราณสถานในจังหวัดอุทัยธานีที่ขึ้นทะเบียนโดยกรมศิลปากร',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน2020–ท่ากรรเชียง200เมตรบุคคลชาย',
#   'ประเทศแคนาดาในโอลิมปิกฤดูหนาว1984',
#   'ประเทศซาอุดีอาระเบียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศบอตสวานาในโอลิมปิกฤดูร้อน2016',
#   'กีฬาเรือใบในโอลิมปิกฤดูร้อน2024–รอบคัดเลือก',
#   'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย/ศ',
#   'อัตเลติโกเดมาดริดในฤดูกาล2020–21',
#   'ประเทศไมโครนีเชียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ยูโกสลาเวียในโอลิมปิกฤดูร้อน1964',
#   'กีฬาโปโลน้ำหญิงในโอลิมปิกฤดูร้อน',
#   'ตัวละครในดราก้อนบอล',
#   'รถไฟความเร็วสูงในแต่ละประเทศ',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน2020รอบคัดเลือกโซนแอฟริกา',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูหนาว1988',
#   'กีฬาฟุตบอลในกีฬาแห่งชาติครั้งที่',
#   'สโมสรฟุตบอลราชนาวีในฤดูกาล',
#   'แผ่นดินไหวและคลื่นสึนามิในโอคุชิริ',
#   'ผู้เล่นในฟีฟ่าคอนเฟเดอเรชันส์คัพ2017',
#   'ประเทศเบลีซในโอลิมปิกฤดูร้อน2008',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน1960',
#   'ประเทศเซียร์ราลีโอนในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศชิลีในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศสิงคโปร์ในซีเกมส์2021',
#   'ความอดอยากในไอร์แลนด์',
#   'รายชื่อโบราณสถานในจังหวัดนครราชสีมาที่ขึ้นทะเบียนโดยกรมศิลปากร',
#   'ฟุตบอลในโอลิมปิกฤดูร้อน1976',
#   'กีฬายิมนาสติกในโอลิมปิก',
#   'ประเทศอิรักในเอเชียนเกมส์2022',
#   'ห้ามใช้พระนามพระเจ้าของเจ้าไปในทางที่ผิด',
#   'การเลือกตั้งสหพันธรัฐในแคนาดาพ.ศ.2558',
#   'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย/ต',
#   'ประเทศนอร์เวย์ในโอลิมปิกฤดูร้อน1924',
#   'เหตุระเบิดในอำเภอหาดใหญ่',
#   'ตัวละครในกันดั้มดับเบิลโอ',
#   'การประท้วงในกัมพูชา',
#   'แผ่นดินไหวและคลื่นสึนามิในบัลดิเบีย',
#   'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน1980',
#   'ประเทศอินเดียในเอเชียนเกมส์ฤดูหนาว',
#   'ประเทศกรีซในโอลิมปิกฤดูร้อน1980',
#   'ประเทศสเปนในโอลิมปิกฤดูหนาว2010',
#   'ประเทศคอโมโรสในโอลิมปิกเยาวชนฤดูร้อน',
#   'สหรัฐในโอลิมปิกฤดูหนาว2010',
#   'จังหวัดกาฬสินธุ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'จังหวัดกาญจนบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'รายชื่อเมืองที่ใหญ่ที่สุดในโลก',
#   'รายชื่อแผ่นดินไหวนำและแผ่นดินไหวตามแผ่นดินไหวและคลื่นสึนามิในโทโฮกุพ.ศ.2554',
#   'อุบัติเหตุเหมืองถ่านหินในประเทศจีน',
#   'ประเทศคอสตาริกาในโอลิมปิกฤดูร้อน2012',
#   'กีฬาฟุตซอลในกีฬาแห่งชาติครั้งที่47',
#   'ประเทศฟิลิปปินส์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'สาธารณรัฐอัปเปอร์วอลตาในโอลิมปิก',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูหนาว1988',
#   'รถโดยสารประจำทางในประเทศไทย',
#   'ประเทศปานามาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2020–แคนู1ฝีพายสปรินท์1,000เมตรบุคคลชาย',
#   'กีฬาฟันดาบในโอลิมปิกเยาวชน',
#   'จังหวัดสระบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'สาธารณรัฐแอฟริกาใต้ในโอลิมปิกฤดูร้อน1936',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูหนาว1994',
#   'พุทธอารามบนภูเขาในเกาหลี',
#   'ประเทศพม่าในโอลิมปิกฤดูร้อน1984',
#   'รายชื่อเครื่องบินพระที่นั่งในพระบรมวงศานุวงศ์ไทย',
#   'ประเทศเบอร์มิวดาในโอลิมปิกฤดูร้อน1964',
#   'ประเทศแคนาดาในโอลิมปิกฤดูหนาว1948',
#   'กีฬาจักรยานในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'เพาะกายในเอเชียนบีชเกมส์',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน2020',
#   'ประเทศไอซ์แลนด์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'สาธารณรัฐโกตดิวัวร์ในโอลิมปิกฤดูร้อน1984',
#   'ปัญหาสิ่งแวดล้อมในประเทศบราซิล',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว2018',
#   'ประเทศกายอานาในโอลิมปิกฤดูร้อน2020',
#   'ธงในสหภาพโซเวียต',
#   'ประเทศลัตเวียในโอลิมปิกฤดูหนาว1924',
#   'ประเทศกาบูเวร์ดีในพาราลิมปิกฤดูร้อน',
#   'สาธารณรัฐเฮติในโอลิมปิกฤดูร้อน',
#   'ประเทศฮังการีในโอลิมปิกฤดูหนาว1956',
#   'รายชื่อธงในกองทัพเรือยูเครน',
#   'รายชื่อมรดกโลกในทวีปยุโรป',
#   'ประเทศเดนมาร์กในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน',
#   'กีฬาเรือใบในโอลิมปิกฤดูร้อน2012',
#   'ประเทศไทยในพ.ศ.2367',
#   'การติดเชื้อในระบบหายใจ',
#   'ออกแบบภายใน',
#   'ประเทศแคนาดาในโอลิมปิก',
#   'รายชื่อแหล่งมรดกโลกในนครรัฐวาติกัน',
#   'ประเทศกัมพูชาในเอเชียนเกมส์2014',
#   'กีฬาฟุตบอลชายในโอลิมปิกฤดูร้อน1980–รอบคัดเลือก',
#   'โรงเรียนในเครือบดินทรเดชา',
#   'สาธารณรัฐแซมเบียในโอลิมปิกฤดูร้อน1968',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2480',
#   'กีฬาบอบสเลในโอลิมปิกฤดูหนาว1924',
#   'สาธารณรัฐซิมบับเวในโอลิมปิกฤดูร้อน1992',
#   'ประเทศชาดในโอลิมปิกฤดูร้อน2012',
#   'ยกน้ำหนักในซีเกมส์',
#   'ประเทศบาห์เรนในโอลิมปิกฤดูร้อน',
#   'ประเทศปากีสถานในเครือจักรภพ',
#   'ประเทศสเปนในโอลิมปิกฤดูร้อน1932',
#   'ปาเลสไตน์ในโอลิมปิกฤดูร้อน1996',
#   'รายชื่อโรงเรียนในจังหวัดระนอง',
#   'สโมสรฟุตบอลเลสเตอร์ซิตีในฤดูกาล2017–18',
#   'ประเทศโมร็อกโกในโอลิมปิกฤดูร้อน',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศเลบานอนในโอลิมปิกฤดูหนาว1980',
#   'รายชื่อแหล่งมรดกโลกในประเทศกาบอง',
#   'สโมสรฟุตบอลจังหวัดเชียงใหม่ในฤดูกาล',
#   'กีฬาแฮนด์บอลชายหาดในเอเชียนบีชเกมส์',
#   'ประเทศมอนเตเนโกรในโอลิมปิกฤดูร้อน2020',
#   'บันทึกไว้ในปฐพี35ปีคาราบาว',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1958–59',
#   'ในประเทศอาร์มีเนีย',
#   'ประเทศอินเดียในโอลิมปิกฤดูร้อน1996',
#   'รายชื่อสายการบินในประเทศลาว',
#   'สาธารณรัฐตูนิเซียในโอลิมปิกฤดูร้อน1984',
#   'กีฬาโปโลน้ำในโอลิมปิกฤดูร้อน1900',
#   'กีฬาเรือแคนูในโอลิมปิกเยาวชนฤดูร้อน',
#   'สโมสรฟุตบอลทอตนัมฮอตสเปอร์ในฤดูกาล1949–50',
#   'รายชื่อพระเกียรติยศในสมเด็จพระกนิษฐาธิราชเจ้ากรมสมเด็จพระเทพรัตนราชสุดา',
#   'สาธารณรัฐไลบีเรียในโอลิมปิกฤดูร้อน2008',
#   'ประเทศสโลวาเกียในโอลิมปิกเยาวชน',
#   'อำเภอในประเทศฝรั่งเศส',
#   'ลำดับเหตุการณ์สำคัญในอาณาจักรอยุธยา',
#   'ประเทศกรีเนดาในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศโตโกในโอลิมปิกฤดูร้อน2016',
#   'การคมนาคมในมาเลเซีย',
#   'เหรียญราชอิสริยาภรณ์อันเป็นบำเหน็จในพระองค์',
#   'กีฬาคริกเกตในโอลิมปิกฤดูร้อน1900',
#   'คนในซีเกมส์',
#   'ศูนย์กีฬาในร่มมารากานังซิญญู',
#   'ควิดดิชในยุคต่างๆ',
#   'ประเทศอิตาลีในโอลิมปิกซ้อน1906',
#   'สโมสรฟุตบอลการท่าเรือในฤดูกาล2563',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน1976',
#   'ศาสนาพุทธในประเทศอุซเบกิสถาน',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'การระบาดของอหิวาตกโรคในถนนบรอดค.ศ.1854',
#   'ตัวละครในจัสติสลีค',
#   'สาธารณรัฐเฮติในโอลิมปิกฤดูร้อน1928',
#   'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน2000',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1986–87',
#   'ประเทศกายอานาในแพนอเมริกันเกมส์',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน1960',
#   'ความขัดแย้งในประเทศซูดานพ.ศ.2566',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน1988',
#   'ประเทศมาลีในโอลิมปิกฤดูร้อน2016',
#   'ประเทศลักเซมเบิร์กในโอลิมปิกฤดูร้อน2024',
#   'การเสด็จออกสีหบัญชรในรัชกาลที่9',
#   'กีฬาชักเย่อในเวิลด์เกมส์2022',
#   'ประเทศโกตดิวัวร์ในพาราลิมปิกฤดูร้อน2012',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูหนาว1976',
#   'กรีฑาชายหาดในเอเชียนบีชเกมส์',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2012–เอเป้ทีมหญิง',
#   'คนหอนขี้เรื้อนในคืนเดือนเสี้ยว',
#   'แผ่นดินไหวและสึนามิในเซ็นไดพ.ศ.2554',
#   'ประเทศกรีซในโอลิมปิกฤดูร้อน1992',
#   'เขตการปกครองในกรุงเทพมหานคร',
#   'สาธารณรัฐลิทัวเนียในโอลิมปิกฤดูร้อน',
#   'การบันทึกภาพในสมอง',
#   'สาธารณรัฐซานมารีโนในโอลิมปิกฤดูหนาว1988',
#   'ผู้เล่นในยูฟ่าเนชันส์ลีก2019รอบสุดท้าย',
#   'ลำดับเหตุการณ์ในประวัติศาสตร์อังกฤษระหว่างปี',
#   'กีฬายิงธนูในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศอิตาลีในโอลิมปิกฤดูหนาว2022',
#   'กีฬาวีลแชร์เทนนิสในกีฬาคนพิการแห่งชาติ',
#   'รายชื่อประเทศในกลุ่มโออีซีดีเรียงตามอัตราการเกิดโรคมะเร็ง',
#   'ประเทศอิเควทอเรียลกินีในโอลิมปิกฤดูร้อน2004',
#   'ประเทศโมร็อกโกในโอลิมปิกฤดูหนาว2014',
#   'กีฬายิงธนูในโอลิมปิกฤดูร้อน2016',
#   'ประเทศเกาหลีเหนือในโอลิมปิกฤดูหนาว1972',
#   'ประเทศลาวในเอเชียนเกมส์2014',
#   'รายชื่อโรงพยาบาลชุมชนในประเทศไทย',
#   'รายชื่อตัวละครในโค้ดกีอัสภาคการปฏิวัติของลูลูช',
#   'กีฬาเรือพายในโอลิมปิกซ้อน1906',
#   'หมู่เกาะบริติชเวอร์จินในโอลิมปิกฤดูร้อน1992',
#   'ประเทศแอลจีเรียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน2012–ฟรีสไตล์ไม่เกิน63กิโลกรัมหญิง',
#   'ศาสนาในประเทศเกาหลี',
#   'อัตราส่วนของกรดไขมันในอาหารต่าง',
#   'สาธารณรัฐลัตเวียในโอลิมปิกฤดูหนาว1998',
#   'ประเทศฮังการีในโอลิมปิกฤดูร้อน2004',
#   'กีฬายิงปืนรณยุทธในกีฬาแห่งชาติ',
#   'ประเทศแทนซาเนียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สโมสรฟุตบอลกระบี่ในฤดูกาล2561',
#   'รายการแหล่งมรดกโลกในประเทศมาเลเซีย',
#   'การครองราชย์ครบรอบแพลทินัมในสมเด็จพระราชินีนาถเอลิซาเบธที่',
#   'ธงในประเทศคาซัคสถาน',
#   'ประเทศบาห์เรนในเอเชียนเกมส์ฤดูหนาว',
#   'ซันซาพุทธอารามบนภูเขาในเกาหลี',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว2010',
#   'ประเทศมาเลเซียในพาราลิมปิกฤดูร้อน2016',
#   'ประเทศจอร์แดนในโอลิมปิก',
#   'เจ้าจอมมารดาสุดในรัชกาลที่5',
#   'รายการตัวละครในวันพีซ',
#   'รายชื่อแหล่งมรดกโลกในประเทศอาเซอร์ไบจาน',
#   'กีฬารักบี้ในโอลิมปิกฤดูร้อน1908',
#   'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูร้อน2004',
#   'การจัดหมวดหมู่ในห้องสมุด',
#   'ประเทศเยเมนในโอลิมปิกเยาวชนฤดูร้อน',
#   'คีตราชนิพนธ์บทเพลงในดวงใจราษฎร์',
#   'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งสวีเดน',
#   'กีฬาฟุตบอลในโอลิมปิกซ้อน1906',
#   'เหตุระเบิดในบาหลี',
#   'กีฬาเทควันโดในโอลิมปิกฤดูร้อน2020–รุ่นไม่เกิน80กิโลกรัมบุคคลชาย',
#   'สาธารณรัฐคีร์กีซในโอลิมปิกฤดูร้อน',
#   'รายชื่อโบราณสถานในจังหวัดพระนครศรีอยุธยา',
#   'ประเทศฮังการีในโอลิมปิกฤดูหนาว1948',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน',
#   'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน1948',
#   'รายชื่อเขตมหานครในประเทศญี่ปุ่น',
#   'ประเทศสโลวีเนียในโอลิมปิกฤดูร้อน',
#   'ประเทศยูเครนในพาราลิมปิกฤดูร้อน2016',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศไต้หวันพ.ศ.2563',
#   'โรคสำลักในหลอดอาหาร',
#   'สาธารณรัฐคาซัคสถานในโอลิมปิกฤดูหนาว2002',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1924',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน1936',
#   'ประเทศเบลารุสในโอลิมปิกฤดูร้อน2020',
#   'คอลัมน์ในคอร์เท็กซ์',
#   'การศึกษาในประเทศกาตาร์',
#   'ประเทศออสเตรียในโอลิมปิกฤดูหนาว1952',
#   'รัฐประหารในประเทศอียิปต์',
#   'เทเบิลเทนนิสในกีฬาแห่งชาติครั้งที่41–ทีมหญิง',
#   'ประเทศรวันดาในโอลิมปิกฤดูร้อน2016',
#   'รายชื่อทางแยกในเขตปทุมวัน',
#   'จังหวัดอุดรธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'กีฬากอล์ฟในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน2012',
#   'นิคมญี่ปุ่นในประเทศปาเลา',
#   'กฎหมายเสรีภาพในการได้ข้อมูลข่าวสาร',
#   'บุคคลที่เกิดในปีพ.ศ.2490',
#   'การระบาดของอาการเยื่อหุ้มสมองอักเสบในแอฟริกาตะวันตกค.ศ.2009-2010',
#   'ของวิเศษในอาณาจักรแห่งกาลเวลา',
#   'ประเทศคองโกในโอลิมปิก',
#   'กีฬาเปตองในเวิลด์เกมส์',
#   'รายชื่อตัวละครในสาวน้อยจอมเวท',
#   'จักรพรรดินีเหรินหูไอในจักรพรรดิซ่งชินจง',
#   'สาธารณรัฐมาลาวีในโอลิมปิกฤดูร้อน1972',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูร้อน1932',
#   'ประเทศโรมาเนียในโอลิมปิกฤดูร้อน1972',
#   'ประเทศกรีเนดาในพาราลิมปิกฤดูร้อน2020',
#   'รายชื่อนักแสดงละครชุดทางโทรทัศน์ในจักรวาลภาพยนตร์มาร์เวล',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน1964',
#   'ประเทศบราซิลในโอลิมปิกฤดูร้อน1956',
#   'กีฬากระโดดน้ำในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'คณะปฏิรูปการปกครองในระบอบประชาธิปไตยอันมีพระมหากษัตริย์ทรงเป็นประมุข',
#   'ประเทศชิลีในโอลิมปิกฤดูหนาว1976',
#   'รายนามองคมนตรีในรัชกาลพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#   'บุคคลที่เกิดในปีพ.ศ.2494',
#   'ประเทศโคลอมเบียในแพนอเมริกันเกมส์',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศเอสวาตีนี',
#   'กีฬาขี่ม้าในกีฬาแห่งชาติครั้งที่',
#   'สุสานอาร์มีเนียในจุลฟา',
#   'รายชื่อธงในคอซอวอ',
#   'จังหวัดศรีสะเกษในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'รายชื่อตัวละครในโกลเดนคามุย',
#   'ราชอาณาจักรตองกาในโอลิมปิกฤดูร้อน2008',
#   'สโมสรฟุตบอลนครราชสีมายูไนเต็ดในฤดูกาล2563',
#   'กีฬาสกีครอสคันทรีในโอลิมปิกฤดูหนาว',
#   'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีในประเทศไทยพฤศจิกายนพ.ศ.2554',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน2016–ทีมชาย–กลุ่มซี',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'ตัวละครในเกมมาริโอ',
#   'เหตุภาวะพิษแอลกอฮอล์ในรัฐปัญจาบพ.ศ.2563',
#   'ประเทศแคเมอรูนในโอลิมปิกฤดูร้อน1992',
#   'ดินแดนอเมริกันซามัวในโอลิมปิกฤดูหนาว2022',
#   'บุคคลที่เกิดในปีพ.ศ.2530',
#   'กีฬาแฮนด์บอลหญิงในโอลิมปิกฤดูร้อน2012–รอบคัดเลือก',
#   'รายชื่อเมืองใหญ่ที่สุดในสหภาพยุโรปเรียงตามจำนวนประชากร',
#   'กีฬาคาราเต้โด้ในกีฬาแห่งชาติครั้งที่44',
#   'วอลเลย์บอลชายในโอลิมปิกฤดูร้อน2008รอบคัดเลือก',
#   'กีฬาเปซาปัลโลในโอลิมปิกฤดูร้อน1952',
#   'กีฬาระบำใต้น้ำในซีเกมส์2015',
#   'ประเทศบราซิลในพาราลิมปิกฤดูร้อน2012',
#   'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน2024',
#   'การประท้วงในประเทศเลบานอนพ.ศ.2561–2562',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน2016–ทีมหญิง–กลุ่มอี',
#   'กีฬาสกีข้ามทุ่งในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'ในสมเด็จพระเจ้าลูกเธอ',
#   'ประเทศเซียร์ราลีโอนในพาราลิมปิกฤดูร้อน',
#   'ประเทศฮังการีในโอลิมปิกฤดูร้อน2016',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน1960',
#   'กีฬายิงปืนในโอลิมปิกฤดูร้อน1936',
#   'หมู่เกาะโซโลมอนในโอลิมปิกฤดูร้อน2016',
#   'ประเทศไมโครนีเซียในโอลิมปิกฤดูร้อน2012',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน2008',
#   'บุคคลที่เกิดในปีพ.ศ.2533',
#   'รายชื่อตอนในเป็นต่อขั้นเทพ',
#   'วัดตะพงใน',
#   'กีฬาวอลเลย์บอลในซีเกมส์2023',
#   'พระราชโอรสในสมเด็จพระมหาจักรพรรดิ',
#   'โบราณสถานและแหล่งประวัติศาสตร์ในแคซ็อง',
#   'กีฬาปีนหน้าผาในโอลิมปิกฤดูร้อน2020–ผสมบุคคลชาย',
#   'สุสานอาร์มีเนียในจูลฆา',
#   'กีฬาบาสเกตบอลชายในโอลิมปิกฤดูร้อน',
#   'แผ่นดินไหวในพม่า',
#   'การเผยแพร่พระพุทธศาสนาในอังกฤษ',
#   'อุทกภัยในประเทศไทยพ.ศ.2555',
#   'สโมสรฟุตบอลอ่างทองในฤดูกาล',
#   'กีฬาโบวลิ่งในเอเชียนเกมส์2014',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว2006',
#   'ประเทศลักเซมเบิร์กในโอลิมปิกฤดูร้อน2016',
#   'สาธารณรัฐชาดในโอลิมปิกฤดูร้อน1992',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดชัยนาท',
#   'ประเทศกินีในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศอิรักในเอเชียนเกมส์2014',
#   'เรือที่เร็วที่สุดในโลก',
#   'ประเทศเดนมาร์กในพาราลิมปิกฤดูร้อน2016',
#   'บังเหียนในมุทราศาสตร์',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกฤดูร้อน1968',
#   'การค้นหาในแนวกว้าง',
#   'อุทกภัยในคีวชูพ.ศ.2563',
#   'กีฬาเทเบิลเทนนิสในโอลิมปิกฤดูร้อน2020–ทีมหญิง',
#   'โรคสติลล์ในผู้ใหญ่',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน2020',
#   'ประเทศมัลดีฟส์ในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศเกาหลีใต้ในโอลิมปิกฤดูหนาว1984',
#   'เขตผู้ว่าราชการในประเทศจอร์แดน',
#   'ประเทศมาลาวีในพาราลิมปิกฤดูร้อน2020',
#   'ลิ่มเลือดในหลอดเลือดดำส่วนลึก',
#   'กีฬาว่ายน้ำในซีเกมส์2017–เดี่ยวผสม200เมตรชาย',
#   'นิคมญี่ปุ่นในปาเลา',
#   'กีฬาปัญจกีฬาในกีฬาแห่งชาติครั้งที่47–ผลการแข่งขัน',
#   'วัดแจ้งใน',
#   'รายชื่อวัดในจังหวัดระนอง',
#   'หมู่เกาะเคย์แมนในโอลิมปิก',
#   'สาธารณรัฐโคลอมเบียในโอลิมปิกฤดูร้อน1976',
#   'กีฬายิมนาสติกชายในโอลิมปิกฤดูร้อน2016–รอบคัดเลือกยิมนาสติกสากลชาย',
#   'แผ่นดินไหวในประเทศปากีสถาน',
#   'กีฬาเพาะกายในกีฬาแห่งชาติ',
#   'รายชื่อตัวละครในนักเตะแข้งสายฟ้าGO',
#   'สหรัฐในโอลิมปิกฤดูร้อน1912',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2000–รอบคัดเลือก',
#   'ฟุตบอลในประเทศนอร์ทมาซิโดเนีย',
#   'การกรองตัวเลขในขอบเขตแบบธรรมดา',
#   'กีฬาเปโลตาบาสก์ในโอลิมปิกฤดูร้อน1992',
#   'รายชื่อวัดในจังหวัดมหาสารคาม',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–วิ่ง1,500เมตรบุคคลชาย',
#   'รายชื่อประเทศในทวีปยุโรปตามขนาดพื้นที่',
#   'ประเทศสเปนในโอลิมปิกฤดูร้อน2016',
#   'ช้างในประเทศไทย',
#   'โทรทัศน์ประเทศไทยใน',
#   'กีฬาวูซูในเอเชียนเกมส์',
#   'ประเทศอินเดียในโอลิมปิกฤดูร้อน1924',
#   'ยาระงับการเกิดก๊าซในทางเดินอาหาร',
#   'สาธารณรัฐมองโกเลียในโอลิมปิกฤดูหนาว1988',
#   'ประเทศตุรกีในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬากรีฑาในซีเกมส์2017–ทุ่มน้ำหนักชาย',
#   'ในสมเด็จพระบวรราชเจ้ามหาศักดิพลเสพ',
#   'ยอดผู้เสียชีวิตจากยานพาหนะในประเทศไทยแบ่งตามปี',
#   'ประเทศฝรั่งเศสในโอลิมปิกเยาวชนฤดูหนาว',
#   'การถือผิวในประเทศแอฟริกาใต้',
#   'กีฬาสกีกระโดดไกลในโอลิมปิกฤดูหนาว2018',
#   'ประเทศแอลจีเรียในโอลิมปิกฤดูร้อน2024',
#   'เสียงในใจ',
#   'ประเทศกรีซในโอลิมปิกฤดูหนาว2022',
#   'ประเทศเกรเนดาในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'มุมปากตกขณะร้องไห้ในทารก',
#   'ธงในสหราชอาณาจักร',
#   'รายชื่อแหล่งมรดกโลกในประเทศวานูวาตู',
#   'กีฬารักบี้ยูเนียนในโอลิมปิกฤดูร้อน',
#   'พายุหิมะในประเทศอิหร่านค.ศ.1972',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2514',
#   'ประเทศสวีเดนในโอลิมปิก',
#   'คณะรัฐมนตรีเงาในคณะรัฐมนตรีชุดที่57และ58ของไทย',
#   'ประเทศโอมานในเอเชียนบีชเกมส์',
#   'ภาษาในประเทศไทย',
#   'ประเทศกินี-บิสเซาในโอลิมปิกฤดูร้อน2000',
#   'หมู่เกาะคุกในโอลิมปิกฤดูร้อน2016',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2020–โรดเรซบุคคลชาย',
#   'รายชื่อแผ่นดินไหวในประเทศญี่ปุ่น',
#   'คัมภีร์ทางศาสนาพุทธในประเทศไทย',
#   'ประเทศเอธิโอเปียในโอลิมปิกฤดูร้อน1956',
#   'ประเทศไอร์แลนด์ในโอลิมปิกฤดูร้อน2012',
#   'เจ้าจอมมารดาอัมพาในรัชกาลที่2',
#   'ประเทศฝรั่งเศสในโอลิมปิกซ้อน',
#   'สาธารณรัฐเบลารุสในโอลิมปิกฤดูร้อน2016',
#   'ประเทศเคนยาในโอลิมปิกฤดูร้อน2000',
#   'ประเทศเบลีซในโอลิมปิกฤดูร้อน2004',
#   'กีฬาฟลอร์บอลในซีเกมส์2019',
#   'สโมสรฟุตบอลนครราชสีมาในฤดูกาล2552',
#   'รายการโทรทัศน์เกมโชว์ในประเทศไทย',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน2020–รุ่นฟลายเวทบุคคลชาย',
#   'ประเทศสเปนในโอลิมปิกฤดูร้อน1960',
#   'ประเทศตองงาในพาราลิมปิกฤดูร้อน',
#   'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน1968',
#   'เหตุจลาจลในประเทศฝรั่งเศส',
#   'กีฬาเรือใบในแพนอเมริกันเกมส์',
#   'ประเทศฮังการีในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สโมสรฟุตบอลแมนเชสเตอร์ซิตีในฤดูกาล2014–15',
#   'วอลเลย์บอลชายในซีเกมส์2015',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูร้อน2016',
#   'รายชื่อพระอิสริยยศและพระเกียรติยศในพระบาทสมเด็จพระจุลจอมเกล้าเจ้าอยู่หัว',
#   'ความไม่สงบนิยมรัสเซียในประเทศยูเครนพ.ศ.2557',
#   'รายชื่อธงชาติในทวีปแอฟริกา',
#   'ประเทศนามิเบียในโอลิมปิกฤดูร้อน2024',
#   'ไวโอลินคอนแชร์โตในบันไดเสียงดีเมเจอร์',
#   'ประเทศเลโซโทในพาราลิมปิกฤดูร้อน',
#   'ประเทศโปแลนด์ในโอลิมปิกฤดูหนาว1994',
#   'ประเทศแคนาดาในพาราลิมปิกฤดูร้อน2020',
#   'กีฬายิงปืนในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'เครือรัฐเปอร์โตริโกในโอลิมปิกฤดูหนาว',
#   'จังหวัดสกลนครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'กีฬาสกีวิบากในเอเชียนเกมส์ฤดูหนาว',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูหนาว1952',
#   'ประเทศแอลเบเนียในโอลิมปิกฤดูร้อน2004',
#   'ประเทศบราซิลในโอลิมปิกฤดูหนาว2002',
#   'ประเทศเซนต์ลูเซียในโอลิมปิกฤดูร้อน',
#   'ฝ่ายค้านในสภาผู้แทนราษฎร',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2012–หญิงไม่เกิน57กิโลกรัม',
#   'ประเทศสเปนในโอลิมปิกฤดูร้อน1968',
#   'ความขัดแย้งนิยมรัสเซียในประเทศยูเครน',
#   'ข้อพิพาทเกี่ยวกับตัวแทนจำหน่ายของเทสลาในสหรัฐ',
#   'กีฬาเรือพายในโอลิมปิกฤดูร้อน1976',
#   'ตัวขยายในคอเคลีย',
#   'กีฬาเรือใบในโอลิมปิกฤดูร้อน1984',
#   'วัดบางคณฑีใน',
#   'การขายกิจการสถานีโทรทัศน์ในไมอามี่',
#   'สาธารณรัฐซิมบับเวในโอลิมปิกฤดูร้อน1988',
#   'ในสมัยสงครามโลกครั้งที่สอง',
#   'ประเทศเบอร์มิวดาในโอลิมปิกฤดูร้อน1952',
#   'จังหวัดร้อยเอ็ดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'พระราชโอรสในฟาโรห์สเนฟรู',
#   'มูลค่าในตัว',
#   'แผ่นดินไหวในมณทลยูนนาน',
#   'สารานุกรมไทยสำหรับเยาวชนโดยพระราชประสงค์ในพระบาทสมเด็จพระเจ้าอยู่หัว',
#   'รายชื่อนครในประเทศบุรุนดี',
#   'รายชื่อตอนในเดอะลูนีย์ทูนส์โชว์',
#   'กีฬาวอลเลย์บอลชายหาดหญิงในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'เหตุระเบิดในลอนดอน',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูหนาว1992',
#   'ประเทศญี่ปุ่นในโอลิมปิกฤดูร้อน2016',
#   'ประเทศตูวาลูในโอลิมปิกฤดูร้อน2008',
#   'เหตุการณ์สำคัญในอาณาจักรอยุธยา',
#   'อัตเลติโกเดมาดริดในฤดูกาล2018–19',
#   'สาธารณรัฐโคลอมเบียในโอลิมปิกฤดูร้อน1956',
#   'ประเทศบราซิลในพาราลิมปิกฤดูร้อน2020',
#   'รถไฟฟ้าในกทม',
#   'กีฬากอล์ฟในกีฬาแห่งชาติครั้งที่47',
#   'ประเทศอิหร่านในโอลิมปิกฤดูหนาว1956',
#   'กีฬายิงธนูในซีเกมส์2017',
#   'กีฬาวอลเลย์บอลในเอเชียนเกมส์2018–ทีมหญิง',
#   'การพนันในประเทศกัมพูชา',
#   'กีฬาสโนว์บอร์ดในโอลิมปิกเยาวชนฤดูหนาว2020–ประเภททีมสกี-สโนว์บอร์ดครอส',
#   'เหตุจลาจลในแคว้นอังกฤษ',
#   'ดัชเชสในบาวาเรีย',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิก1959',
#   'เจ้าหญิงฮิซะโกะพระวรชายาในเจ้าชายโนะริฮิโตะ',
#   'การประท้วงในฮ่องกง',
#   'รายพระนามเจ้านายที่ได้รับการเฉลิมพระยศในสมัยกรุงธนบุรี',
#   'ธงในประเทศเกาหลีใต้',
#   'สาธารณรัฐอาหรับซีเรียในโอลิมปิกฤดูร้อน2000',
#   'วัดป่าพร้าวใน',
#   'การโจมตีท่าอากาศยานในคาบูล',
#   'หมาใน',
#   'สโมสรฟุตบอลนครราชสีมาในฤดูกาล2548',
#   'กีฬาปาร์กัวร์ในเวิลด์เกมส์2022',
#   'รายชื่อแหล่งมรดกโลกในสาธารณรัฐแมซิโดเนีย',
#   'พุทธศาสนาในประเทศศรีลังกา',
#   'กีฬายิงปืนในโอลิมปิกฤดูร้อน1984',
#   'ตัวละครในสมอลล์วิลล์',
#   'การเลือกตั้งทั่วไปในประเทศมาเลเซียพ.ศ.2561',
#   'สหราชอาณาจักรในโอลิมปิกฤดูร้อน1984',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูร้อน1928',
#   'รายชื่อตัวละครในครูพิเศษจอมป่วนรีบอร์น!',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูร้อน1972',
#   'ประเทศเช็กโกสโลวาเกียในโอลิมปิกฤดูหนาว1964',
#   'นักกีฬาโอลิมปิกจากประเทศรัสเซียในโอลิมปิกฤดูหนาว',
#   'วิทยาลัยในวังชาย',
#   'ประเทศอิตาลีในโอลิมปิกฤดูหนาว2010',
#   'รายชื่อโรงเรียนในจังหวัดยโสธร',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2553',
#   'ประเทศจีนในพาราลิมปิกฤดูร้อน',
#   'รายชื่อทางแยกในเขตวังทองหลาง',
#   'การอภิปรายทั่วไปเพื่อลงมติไม่ไว้วางใจรัฐมนตรีในประเทศไทยพ.ศ.2552',
#   'สาธารณรัฐโรดีเซียในโอลิมปิกฤดูร้อน1964',
#   'ธงในประเทศลัตเวีย',
#   'รายชื่อแหล่งมรดกโลกในประเทศลิทัวเนีย',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศแคนาดา',
#   'แผ่นดินไหวในเกาะลมบก',
#   'ประเทศเวียดนามในซีเกมส์2015',
#   'ตัวละครในลัคกี้',
#   'เศรษฐกิจในสหภาพโซเวียต',
#   'ประเทศจีนในโอลิมปิกเยาวชนฤดูร้อน',
#   'ริมฝั่งแม่น้ำแซนในปารีส',
#   'ประเทศแกมเบียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศคิวบาในโอลิมปิก',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในไทยเมษายนพ.ศ.2549',
#   'จังหวัดมหาสารคามในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'รายชื่อแหล่งมรดกโลกในประเทศอิรัก',
#   'สาธารณรัฐอิสลามมอริเตเนียในโอลิมปิกฤดูร้อน',
#   'เหตุยิงกันในทูซอนพ.ศ.2554',
#   'ประเทศติมอร์-เลสเตในโอลิมปิกฤดูร้อน',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–วิ่งข้ามเครื่องกีดขวาง3,000เมตรบุคคลหญิง',
#   'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน1912',
#   'กีฬายิงธนูในโอลิมปิกฤดูร้อน2012–ทีมชาย',
#   'รายชื่อตอนในK-ON!',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2522',
#   'แผ่นดินไหวในซามัว',
#   'การตอบสนองต่อการประท้วงในประเทศไทยพ.ศ.2563',
#   'การช่วยเหลือด้านมนุษยธรรมต่อเหตุการณ์แผ่นดินไหวและคลื่นสึนามิในเซ็นไดพ.ศ.2554',
#   'เจ้าคุณจอมมารดาแพในรัชกาลที่5',
#   'กีฬาฮอกกี้น้ำแข็งในซีเกมส์2017',
#   'กีฬาแฮนด์บอลในกีฬาแห่งชาติครั้งที่44',
#   'รายชื่อแหล่งมรดกโลกในอเมริกาใต้',
#   'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน2020',
#   'สาธารณรัฐประชาชนบังกลาเทศในโอลิมปิกฤดูร้อน2008',
#   'ชื่นฤทัยในธรรม',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1972',
#   'ประเทศนิการากัวในโอลิมปิกฤดูร้อน',
#   'สถิติในโกปาอาเมริกา',
#   'รายพระนามคู่อภิเษกสมรสในพระประมุขฮาวาย',
#   'ในประเทศเบนิน',
#   'กีฬาแกลิกฟุตบอลในโอลิมปิกฤดูร้อน1904',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ราชอาณาจักรเลโซโทในโอลิมปิกฤดูร้อน2000',
#   'กีฬาเบสบอลในโอลิมปิกฤดูร้อน2020–รอบคัดเลือก',
#   'ประเทศอียิปต์ในโอลิมปิกซ้อน',
#   'ธงในคอซอวอ',
#   'ศาสนาพุทธในสหรัฐ',
#   'กีฬาไตรกีฬาในโอลิมปิกฤดูร้อน2020–บุคคลหญิง',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2020–รุ่นน้ำหนักไม่เกิน78กิโลกรัมบุคคลหญิง',
#   'จังหวัดกระบี่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'รายพระนามและชื่อบุคคลที่ทรงอิทธิพลที่สุดในโลกของฟอบส์',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2530',
#   'รายชื่อมณฑลของประเทศจีนเรียงตามผลิตภัณฑ์มวลรวมในประเทศ',
#   'ศาสนาฮินดูในประเทศมาเลเซีย',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดตรัง',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1964',
#   'ประเทศฮัชไมต์จอร์แดนในโอลิมปิกฤดูร้อน2008',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดตราด',
#   'รายชื่อเรือบรรทุกเครื่องบินในประจำการ',
#   'ประเทศฮังการีในโอลิมปิกฤดูร้อน1988',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว2006',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน2012',
#   'ท่าอากาศยานภายในประเทศบีชะฮ์',
#   'ประเทศเนปาลในพาราลิมปิกฤดูร้อน2020',
#   'กรมธนารักษ์ในสมเด็จฯ',
#   'รายชื่อตัวละครในสตาร์',
#   'กีฬาสเกเลตันในโอลิมปิกเยาวชนฤดูหนาว2012',
#   'ประเทศจีนไทเปในโอลิมปิกฤดูร้อน',
#   'กีฬายกน้ำหนักในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูร้อน1988',
#   'ประเทศไทยในพ.ศ.2537',
#   'ประเทศจอร์เจียในโอลิมปิกฤดูหนาว1994',
#   'ประเทศไทยในโอลิมปิกฤดูร้อน1976',
#   'ความพยายามรัฐประหารในสหภาพโซเวียตพ.ศ.2534',
#   'ธงในประเทศเม็กซิโก',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว1952',
#   'กีฬาวูซูในซีเกมส์',
#   'กีฬาบาสเกตบอล3x3ในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศติมอร์-เลสเตในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศจาเมกาในโอลิมปิก',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูร้อน2004',
#   'การประท้วงในโบลิเวียพ.ศ.2561',
#   'กีฬามวยสากลในเอเชียนเกมส์',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน2024–รอบคัดเลือกชาย',
#   'รายชื่อแหล่งมรดกโลกในสาธารณรัฐเช็ก',
#   'ประเทศไทยในค.ศ.2016',
#   'ประเทศเซเชลส์ในโอลิมปิก',
#   'กีฬาแบดมินตันในโอลิมปิกฤดูร้อน1972',
#   'เจ้าจอมมารดาป้อมในรัชกาลที่1',
#   'วอลเลย์บอลในซีเกมส์2015',
#   'พระมเหสีเจ้าจอมพระราชโอรสพระราชธิดาในรัชกาลที่๑',
#   'การฉีดวัคซีนโรคติดเชื้อไวรัสโคโรนา2019ในประเทศสิงคโปร์',
#   'ปรากฏการณ์เชื่อมั่นในตัวเองมากเกินไป',
#   'รายชื่อแหล่งมรดกโลกในประเทศแอฟริกาใต้',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2004',
#   'ประเทศอาร์มีเนียในโอลิมปิกฤดูร้อน2012',
#   'สาธารณรัฐแอลเบเนียในโอลิมปิกฤดูร้อน',
#   'ประเทศอาเซอร์ไบจานในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศมองโกเลียในโอลิมปิกฤดูหนาว',
#   'ชาวไทยในติมอร์-เลสเต',
#   'ประเทศคาซัคสถานในโอลิมปิกฤดูหนาว',
#   'ประเทศไทยในพ.ศ.2560',
#   'ฟุตบอลทีมชาติเยอรมนีในฟุตบอลโลก',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูหนาว1998',
#   'การล่าอาณานิคมในอัฟริกา',
#   'ประเทศอิรักในโอลิมปิกฤดูร้อน2016',
#   'ประเทศอิหร่านในโอลิมปิกฤดูร้อน2024',
#   'อันดับปลาเหล็กใน',
#   'ผู้ทรงอิทธิพลในจีนของฟอร์บ',
#   'สหสาธารณรัฐแทนซาเนียในโอลิมปิก',
#   'ประเทศเปรูในโอลิมปิกฤดูร้อน1988',
#   'การตรวจสอบปริมาณอาหารในกระเพาะ',
#   'สาธารณรัฐสังคมนิยมประชาชนอาหรับลิเบียในโอลิมปิกฤดูร้อน2008',
#   'รายนามศิษย์เก่าโรงเรียนภ.ป.ร.ราชวิทยาลัยในพระบรมราชูปถัมภ์',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–วิ่ง10,000เมตรบุคคลชาย',
#   'ธงเยาวราชฝ่ายใน',
#   'การเลือดออกในกระเพาะอาหารและลำไส้',
#   'กลยุทธ์มีในไม่มี',
#   'เจ้าจอมเลียมในรัชกาลที่5',
#   'ประเทศเคนยาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ราชรัฐลักเซมเบิร์กในโอลิมปิกฤดูร้อน',
#   'ประเทศลิทัวเนียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศฟินลิปปินส์ในซีเกมส์',
#   'อาร์โอซีในโอลิมปิกฤดูร้อน2020',
#   'กีฬามวยสากลในซีเกมส์2017–ผลการแข่งขัน',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน1924',
#   'ช่วงว่างระหว่างรัชกาลในอังกฤษ',
#   'สาธารณรัฐอาร์เมเนียในพาราลิมปิกฤดูหนาว',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน2020รอบคัดเลือก',
#   'ประเทศเคนยาในโอลิมปิก',
#   'สหรัฐในโอลิมปิกฤดูหนาว1976',
#   'สาธารณรัฐซานมารีโนในโอลิมปิกฤดูร้อน2008',
#   'โรคอหิวาต์แอฟริกาในสุกร',
#   'ประเทศสวีเดนในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'กีฬากีฬาทางอากาศในกีฬาแห่งชาติ',
#   'ศาสนาพุทธในประเทศยูเครน',
#   'สาธารณรัฐเซียร์ราลีโอนในโอลิมปิกฤดูร้อน1980',
#   'กีฬาฟุตซอลในซีเกมส์2017–ทีมชาย',
#   'เหตุจลาจลในรัฐยะไข่',
#   'เหตุกราดยิงในมินยาพ.ศ.2560',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูร้อน1928',
#   'สาธารณรัฐหมู่เกาะฟิจิในโอลิมปิกฤดูร้อน1972',
#   'การแสดงช่วงพักครึ่งในซูเปอร์โบวล์ครั้งที่48',
#   'ประเทศฟินแลนด์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศเฮติในโอลิมปิก',
#   'การถ่ายทอดยีนในแนวราบ',
#   'สมาคมฟุตบอลแห่งประเทศไทยในพระบรมราชูปภัมถ์',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2538',
#   'ประเทศปานามาในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1932',
#   'ตัวละครในอภัยมณีซาก้า',
#   'ประเทศสวีเดนในโอลิมปิกฤดูหนาว1952',
#   'ประเทศเซนต์ลูเซียในโอลิมปิกฤดูร้อน2000',
#   'กีฬายิงปืนรณยุทธในกีฬาแห่งชาติครั้งที่46',
#   'กีฬาบอบสเลในโอลิมปิกฤดูหนาว2014',
#   'ประเทศเกาหลีเหนือในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศแซมเบียในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐสโลวักในโอลิมปิกฤดูร้อน2000',
#   'ประเทศสวีเดนในโอลิมปิกฤดูหนาว1994',
#   'กีฬายกน้ำหนักในโอลิมปิกฤดูร้อน2000',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1988',
#   'รายชื่อเมืองในประเทศกัมพูชา',
#   'เทโรในฤดูกาล',
#   'รายชื่อนครในประเทศเกาหลีเหนือ',
#   'ภาวะกรดยูริคในเลือดสูง',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1952',
#   'ประเทศกรีซในโอลิมปิกฤดูหนาว1956',
#   'เหตุรถบรรทุกชนในรัฐเชียปัส',
#   'ประเทศโอมานในโอลิมปิกฤดูร้อน',
#   'ประเทศปากีสถานในเอเชียนเกมส์ฤดูหนาว',
#   'สาธารณรัฐประชาธิปไตยเยอรมนีในโอลิมปิกฤดูหนาว1968',
#   'รายการแหล่งมรดกโลกในประเทศอาเซอร์ไบจาน',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูร้อน1996',
#   'รายชื่อสถานีโทรทัศน์ในภูมิภาคยุโรปตะวันออก',
#   'ประเทศเลบานอนในโอลิมปิกฤดูร้อน2008',
#   'ประเทศโมนาโกในโอลิมปิกฤดูร้อน2012',
#   'โคลนถล่มในมณฑลกานซู',
#   'รายชื่อโบราณสถานในจังหวัดชัยนาท',
#   'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูหนาว1960',
#   'สาธารณรัฐแคเมอรูนในโอลิมปิกฤดูร้อน1976',
#   'ในสวนขวัญ',
#   'ประเทศเม็กซิโกในโอลิมปิกฤดูร้อน1964',
#   'รายชื่อกลุ่มแยกในกองทัพไทย',
#   'ประเทศบุรุนดีในโอลิมปิกฤดูร้อน2004',
#   'ประเทศกาบูเวร์ดีในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศเยอรมนีในโอลิมปิกฤดูหนาว2022',
#   'ประเทศเบลารุสในโอลิมปิกฤดูร้อน2016',
#   'สาธารณรัฐดาโฮเมย์ในโอลิมปิกฤดูร้อน',
#   'บอร์เนียวเหนือในเอเชียนเกมส์1954',
#   'รายชื่อตอนในAssassinationClassroom',
#   'พระราชสันตติวงศ์ในพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราชบรมนาถบพิตร',
#   'สโมสรวอลเลย์บอลชายนครราชสีมาในฤดูกาล2021-22',
#   'การประท้วงในประเทศไทยพ.ศ.2563–2564',
#   'สาธารณรัฐคอสตาริกาในโอลิมปิกฤดูร้อน2000',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน1908',
#   'ประเทศคาซัคสถานในโอลิมปิกฤดูหนาว2002',
#   'ประเทศเลบานอนในเอเชียนเกมส์2018',
#   'งานวิจัยในเมืองจีน',
#   'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'วอลเลย์บอลในเอเชียนเกมส์1986',
#   'จังหวัดน่านในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'นิวเคลียสในสมอง',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน1980',
#   'รายชื่อแผ่นดินไหวนำและแผ่นดินไหวตามแผ่นดินไหวและคลื่นสึนามิในโทโฮะกุ',
#   'ประเทศซูดานใต้ในโอลิมปิกฤดูร้อน2016',
#   'ประเทศฟีจีในโอลิมปิกฤดูร้อน1988',
#   'แผ่นดินไหวในวานพ.ศ.2554',
#   'จังหวัดพัทลุงในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'เจ้าจอมมารดาหม่อมราชวงศ์เนื่องในรัชกาลที่5',
#   'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูหนาว1988',
#   'สาธารณรัฐแอลเบเนียในโอลิมปิกฤดูหนาว2006',
#   'ประเทศเบลารุสในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'จังหวัดเพชรบูรณ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'รายชื่อแหล่งมรดกโลกในประเทศมอลโดวา',
#   'สโมสรฟุตบอลขอนแก่นมอดินแดงในฤดูกาล2564–2565',
#   'ประเทศไทยในพ.ศ.2431',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน1952',
#   'ประเทศเอสโตเนียในโอลิมปิก',
#   'ประเทศเซอร์เบียในโอลิมปิกฤดูร้อน2020',
#   'สิทธิเลสเบี้ยนในไทย',
#   'การลงคะแนนเสียงในประเทศสวิตเซอร์แลนด์',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 11657

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['รัฐอิสราเอลในเอเชียนเกมส์1954',
#  'การท่องเที่ยวในประเทศไอซ์แลนด์',
#  'การก่อการกำเริบในเชเชน',
#  'จังหวัดในประเทศเบลเยียม',
#  'การสังหารหมู่ในนครชิคาโกด้วยยาไทลินอล',
#  'กีฬาไตรกีฬาในซีเกมส์2015',
#  'รายชื่อคณะการแพทย์แผนไทยในประเทศไทย',
#  'กีฬาแบดมินตันในซีเกมส์2023–ทีมหญิง',
#  'มวยสากลในเอเชียนเกมส์2010',
#  'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2544',
#  'การเผยแผ่พระพุทธศาสนาในอังกฤษ',
#  'รายชื่อโบราณสถานในจังหวัดหนองบัวลำภูที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'จังหวัดกระบี่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'รายชื่อวิดีโอที่มียอดผู้ชมไม่ชอบสูงสุดในยูทูบ',
#  'มวยสากลสมัครเล่นในซีเกมส์2015',
#  'ประเทศจิบูตีในพาราลิมปิกฤดูร้อน',
#  'โทรทัศน์ประเทศไทยในค.ศ.1995',
#  'องค์กรคริสตจักรสัมพันธ์ในประเทศไทย',
#  'พระราชพิธีทรงพระผนวชในรัชกาลที่',
#  'ธงในประเทศไทย',
#  'ไทยในอียิปต์',
#  'ยศทหารในกองทัพออสเตรเลีย',
#  'สโมสรฟุตบอลแมนเชสเตอร์ซิตีในฤดูกาล2008–09',
#  'รายชื่อแขกในพระราชพิธีราชาภิเษกของสมเด็จพระเจ้าชาลส์ที่',
#  'ความไม่สงบในจังหวัดชายแดนภาคใต้',
#  'ความขัดแย้งในเซาท์คอร์โดฟาน',
#  'รายชื่อตัวละครในกัลลิเวอร์',
#  'จังหวัดสมุทรสาครในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทย',
#  'กีฬาสกีกระโดดไกลในเอเชียนเกมส์ฤดูหนาว2017',
#  'รายชื่อโบราณสถานในจังหวัดภูเก็ตที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'คณะรัฐมนตรีเงาในคณะรัฐมนตรีคณะที่',
#  'รายชื่อสายการบินในประเทศญี่ปุ่น',
#  'ประเทศเปรูในพาราลิมปิกฤดูร้อน',
#  'ประเทศไทยในพ.ศ.2502',
#  'การสมรสเพศเดียวกันในสเปน',
#  'ในประเทศทาจิกิสถาน',
#  'กีฬากาบัดดีในกีฬาแห่งชาติ',
#  'รายชื่อสนามบินในประเทศไทย',
#  'ไรชส์ค็อมมิสซารีอาทในมอสโกเวียน',
#  'เจ้าจอมมารดาแสงในรัชกาลที่๕',
#  'รายพระนามคู่อภิเษกสมรสในพระประมุขฮาวาย',
#  'กีฬากรีฑาในซีเกมส์2017–10,000เมตรชาย',
#  'ประเทศคีร์กีซสถานในพาราลิมปิกฤดูร้อน2016',
#  'รัฐบัญญัติความเป็นส่วนตัวของผู้บริโภคในรัฐแคลิฟอร์เนีย',
#  'แผ่นดินไหวในชเวโบพ.ศ.2555',
#  'ใบอนุญาตรับชมโทรทัศน์ในสหราชอาณาจักร',
#  'เหตุจลาจลในไอร์แลนด์เหนือพ.ศ.2564',
#  'วัตถุมงคลในศาสนาพุทธ',
#  'นิ่วในไต',
#  'จังหวัดในประเทศไทยเรียงตามจำนวนประชากร',
#  'เทนนิสในเอเชียนเกมส์',
#  'อุทกภัยในประเทศจีนพ.ศ.2553',
#  'รายชื่อแหล่งมรดกโลกในทวีปอเมริกา',
#  'รายชื่อนักแสดงในสตาร์วอร์ส',
#  'รายชื่อแหล่งมรดกโลกในประเทศอาร์มีเนีย',
#  'ประเทศไทยในพ.ศ.2437',
#  'ปานแดงในทารก',
#  'กีฬาว่ายน้ำในซีเกมส์2017–มาราธอนระยะ10กิโลเมตรชาย',
#  'รายชื่อทางหลวงแผ่นดินในประเทศไทย/หมวด1',
#  'บัตรอิเล็กทรอนิกส์ที่ออกโดยราชการในประเทศไทย',
#  'ประเทศไทยในพ.ศ.2517',
#  'รายชื่อโบราณสถานในจังหวัดระนองที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อวัดในจังหวัดนราธิวาส',
#  'กีฬาชักเย่อในกีฬาแห่งชาติครั้งที่46',
#  'ประเทศพม่าในพาราลิมปิกฤดูร้อน2016',
#  'พุทธสถานในพื้นที่โฮรีว-จิ',
#  'อัตเลติโกเดมาดริดในฤดูกาล2018–19',
#  'การลงประชามติในไทย',
#  'เหตุอุกกาบาตตกในรัสเซียพ.ศ.2556',
#  'สโมสรฟุตบอลอาร์มี่ยูไนเต็ดในฤดูกาล2561',
#  'รายชื่อธงในประเทศรัสเซีย',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2531',
#  'รายพระนามจักรพรรดิในยุคห้าราชวงศ์สิบอาณาจักร',
#  'อหิงสาในศาสนาเชน',
#  'กีฬาสเกตความเร็วลู่ในเวิลด์เกมส์',
#  'การประท้วงในประเทศอิหร่านพ.ศ.2560',
#  'การแสดงช่วงพักครึ่งในซูเปอร์โบวล์ครั้งที่48',
#  'การประท้วงในฮ่องกงพ.ศ.2562–2563',
#  'กีฬาปีนหน้าผาในเวิลด์เกมส์',
#  'ปวยร์โตรีโกในพาราลิมปิกฤดูร้อน2016',
#  'รายชื่อเกิร์ลกรุ๊ปในประเทศไทย',
#  'เหตุกราดยิงในศูนย์การค้าสยามพารากอน',
#  'ประเทศจาเมกาในแพนอเมริกันเกมส์',
#  'ประเทศกัวเตมาลาในพาราลิมปิกฤดูร้อน',
#  'กีฬาเรือพายในซีเกมส์2015',
#  'กีฬายิงปืนในกีฬาแห่งชาติครั้งที่41',
#  'สโมสรฟุตบอลเรอัลมาดริดในฤดูกาล2022–23',
#  'โทรทัศน์ประเทศไทยในค.ศ.1977',
#  'การเดินขบวนวันจันทร์ในเยอรมนีตะวันออก',
#  'การปล้นธนาคารในติฟลิสค.ศ.1907',
#  'กีฬาเจ็ตสกีในกีฬาแห่งชาติ',
#  'ความซับซ้อนในการคำนวณ',
#  'รายชื่อแหล่งมรดกโลกในประเทศมาลี',
#  'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'ธงในประเทศอังกฤษ',
#  'ตัวละครในเซียนเกมรักขอเป็นเทพนักจีบ',
#  'กีฬาว่ายน้ำในซีเกมส์2017–ท่ากบ50เมตรหญิง',
#  'รายชื่อแหล่งมรดกโลกในประเทศกาบูเวร์ดี',
#  'การเลือกตั้งในกัมพูชา',
#  'ฟุตบอลหญิงทีมชาติญี่ปุ่นในฟุตบอลโลกหญิง']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 10402

# %%
get_samples(nai)
# Out:
# ['รายชื่อตอนในบ้านสราญแลนด์',
#  'แผ่นดินไหวและคลื่นสึนามิในเซ็นได',
#  'ในจักรพรรดิซ่งฮุ่ยจง',
#  'การให้วัคซีนโควิด-19ในประเทศไทย',
#  'รายชื่อโรงพยาบาลในแชร์นีฮิว',
#  'เหตุระเบิดที่มัสยิดในเปศวาร์',
#  'เรือประเพณีในซีเกมส์2015',
#  'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'รายชื่อแหล่งมรดกโลกในประเทศสวีเดน',
#  'การฉีดวัคซีนโรคติดเชื้อไวรัสโคโรนา2019ในประเทศสิงคโปร์',
#  'รายการแหล่งมรดกโลกในประเทศปาเลสไตน์',
#  'กีฬาวอลเลย์บอลชายในซีเกมส์',
#  'การคมนาคมในประเทศญี่ปุ่น',
#  'การเกษตรในอิหร่าน',
#  'โทรทัศน์ประเทศไทยในค.ศ.1952',
#  'สมาคมสร้างคุณค่าในประเทศไทย',
#  'วอลเลย์บอลหญิงในซีเกมส์',
#  'ปลาที่พบในลุ่มแม่น้ำเจ้าพระยา',
#  'ศาสนาพุทธในประเทศมาเลเซีย',
#  'การลงประชามติเกี่ยวกับสนธิสัญญาเจนีวาในกัมพูชา',
#  'รายชื่อธงในประเทศไอร์แลนด์',
#  'การรุกในอิตาลี',
#  'รัฐประหารในประเทศกาบองพ.ศ.2566',
#  'ตัวละครในสตาร์คราฟต์',
#  'รายชื่อตอนในเลิฟไลฟ์!ซันไชน์!!ปฏิบัติการล่าฝันสคูลไอดอล',
#  'สาธารณรัฐสังคมนิยมเวียดนามในเอเชียนเกมส์2014',
#  'รายชื่อตอนในเซียนเกมรักขอเป็นเทพนักจีบ',
#  'รายพระนามพระภรรยาเจ้าและพระสนมในรัชกาลที่2',
#  'จังหวัดเพชรบูรณ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'การสะสมพลังงานในพายุหมุน',
#  'กลุ่มอาการอักเสบหลายระบบในเด็ก',
#  'พระชายาในเจ้าชายทะกะฮิโตะ',
#  'วงศ์ปลาเหล็กใน',
#  'ในยามแห่งอาวุธกฎหมายทรุดเงียบลง',
#  'การยุบสภาผู้แทนราษฎรในประเทศไทย',
#  'ธงในประเทศเม็กซิโก',
#  'โนบิตะผจญภัยในเกาะมหัศจรรย์',
#  'มณฑลในประเทศเบลเยียม',
#  'รายชื่อโรงเรียนในจังหวัดลำปาง',
#  'ศูนย์แพทยศาสตรศึกษาชั้นคลินิกในประเทศไทย',
#  'อนิเมะในปีพ.ศ.2567',
#  'ในอุ้งมือเหล็ก',
#  'โบว์ลิ่งในกีฬาแห่งชาติครั้งที่41–คะแนนรวมชาย',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งภูฏาน',
#  'ความหลากหลายทางชีวภาพในประเทศอินเดีย',
#  'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2555',
#  'เหตุโจมตีด้วยขีปนาวุธในแซร์ฮียิวกา',
#  'รายชื่อธงในประเทศลิทัวเนีย',
#  'ประเทศอินโดนีเซียในซีเกมส์2015',
#  'ศาสนาอิสลามในประเทศบรูไน',
#  'เหตุจลาจลในลอสแอนเจลิสค.ศ.1992',
#  'รายชื่อโบราณสถานในจังหวัดพระนครศรีอยุธยา/อำเภอพระนครศรีอยุธยา/ซีกตะวันตก',
#  'ในประเทศอาร์มีเนีย',
#  'บริการสุขภาพในประเทศอินเดีย',
#  'รายชื่อวัดในจังหวัดมหาสารคาม',
#  'รายชื่อแหล่งมรดกโลกในประเทศออสเตรีย',
#  'การระบาดทั่วของโคโรนาไวรัสในประเทศเกาหลีเหนือ',
#  'ประเทศมาเลเซียในเอเชียนเกมส์',
#  'การค้นหาในแนวกว้าง',
#  'ในยามแห่งอาวุธกฎหมายทรุดเงียบเสียงลง',
#  'เหตุเหยียบกันเสียชีวิตในพนมเปญ',
#  'โทรทัศน์ประเทศไทยในค.ศ.2013',
#  'ระบบยึดเหนี่ยวเด็กในรถ',
#  'เหตุสะพานถล่มในโมรพี',
#  'ความดันโลหิตในปอดสูงเรื้อรังในทารกแรกเกิด',
#  'กีฬาเปตองในกีฬาแห่งชาติครั้งที่47',
#  'พระราชนิพนธ์ในพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'เทศมณฑลในประวัติศาสตร์อังกฤษ',
#  'รัฐบัญญัติห้ามปกปิดใบหน้าในสาธารณสถาน',
#  'วอลเลย์บอลในเอเชียนเกมส์2010',
#  'กีฬาว่ายน้ำมาราธอนในเอเชียนเกมส์2022',
#  'โรงพยาบาลในประเทศไทย',
#  'กีฬาเทควันโดในซีเกมส์',
#  'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย/ฝ',
#  'ถนนวงแหวนรอบใน',
#  'แผ่นดินไหวในลิสบอน',
#  'รายชื่อตอนในทีน',
#  'รายชื่อตอนในแคลนนาด',
#  'รายชื่อแหล่งมรดกโลกในทวีปยุโรป',
#  'โทรทัศน์ในสหรัฐ',
#  'ยุคก่อนประวัติศาสตร์ในมาเลเซีย',
#  'ราชสันตติวงศ์ในซาร์นีโคไลที่',
#  'การประชุมสุดยอดผู้นำในลิสบอน',
#  'ผู้เล่นในฟุตบอลชิงแชมป์แห่งชาติยุโรป2020',
#  'วัดทองใน',
#  'รายชื่อของการสังหารหมู่ในประเทศมาเลเซีย',
#  'รายชื่อเมืองในประเทศอาร์เจนตินา',
#  'รายชื่อตัวละครในพระอภัยมณี',
#  'เจ้าจอมมารดาหม่อมราชวงศ์เนื่องในรัชกาลที่5',
#  'รายชื่อธงในประเทศเกาหลีใต้',
#  'กีฬาบิลเลียดในกีฬาแห่งชาติ',
#  'สาธารณรัฐประชาธิปไตยติมอร์-เลสเตในซีเกมส์',
#  'ประเทศบาห์เรนในเอเชียนเกมส์2018',
#  'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศไทยพ.ศ.2563',
#  'ประเทศไทยในเวิลด์บีชเกมส์2019',
#  'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'ลำดับเวลารัฐประหารในประเทศไทยพ.ศ.2557',
#  'กีฬาชักเย่อในกีฬาแห่งชาติ',
#  'การออกเสียงในประเทศสวิตเซอร์แลนด์']
