# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
_len = 0
def get_len(titles):
      global _len
            
      current_len = len(titles)
      print(f'current: {current_len}\n'
            f'diff: {current_len - _len}')

      _len = current_len

      return

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
get_len(titles)
# Out:
# current: 362955
# diff: 362955

# %%
get_samples(titles)
# Out:
# ['เกาะคลุ้ม',
#  'ดางาชิ',
#  'นักสืบหุ่นยนต์',
#  'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูหนาว_2014',
#  'รถถังหนักสุดยอด',
#  'ฌอน_คิงสตัน',
#  'Free_&_Easy',
#  'คณะบริหารธุรกิจ_มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'มังกรหยก_2_ภาค_จอมยุทธอินทรี',
#  'แฮ็กเกอร์',
#  'P!nk',
#  'Fabio_Cannavaro',
#  'ระบบประสาทส่วนกลาง',
#  'มะเร็งต่อมน้ำเหลือง',
#  'สัญญาณขัดจังหวะ',
#  '(วอตส์เดอะสตอรี)_มอร์นิงกลอรี?',
#  'Cryptonchidae',
#  'Tsukasa_Hojo',
#  'Birmingham_City_F.C.',
#  'กล้องทาบเงา',
#  'สะพานกีซูนา',
#  'Bellagio_(Italian_region)',
#  'อนุสาวรีย์คู่บารมีกู้แผ่นดิน',
#  'เคมีภาคคำนวณ',
#  'Elaioplast',
#  'ฮัวหิม',
#  'หลินชาง',
#  'เพลงประจำสาธารณรัฐอะดีเกยา',
#  'ข้างขึ้น',
#  'อำเภออัลฮัยมะตุลคอริญียะฮ์',
#  'หนังคัลท์',
#  'สกุลหนูพุก',
#  'ประเทศเปรูในโอลิมปิกฤดูร้อน_1964',
#  'คณะศิลปศาสตร์_มหาวิทยาลัยขอนแก่น',
#  'ยูยะ_อูจิดะ',
#  'กูเกิล',
#  'เพรียวพันธ์_ดามาพงศ์',
#  'Jets_de_Viry-Essonne',
#  'พระองค์เจ้าสิริภาจุฑาภรณ์',
#  'ทิก_กว๋าง_ดึ๊ก',
#  'Deng_Yingchao',
#  '๒๙_กันยายน',
#  'จักรพรรดิเฮเซ',
#  'ฟิฟทีนแอนด์',
#  '345_ปีก่อนคริสตกาล',
#  'Erismadelphus',
#  'Situational_comedy',
#  'ธาตุคาบ_9',
#  '๒๔_กันยายน',
#  'Hua_Chenyu',
#  'BSA',
#  'รัฐสุลต่านมามลุค_(ไคโร)',
#  'อิโรซุกุเซไกโนะอาชิตะการะ',
#  'การท่องเที่ยวในกรุงเทพมหานคร',
#  'ที่ราบสูงเปอร์เซีย',
#  'มลรัฐฟลอริด้า',
#  'เคมบริดจ์_(แก้ความกำกวม)',
#  "Les_Contes_d'Hoffmann",
#  'อนุมาน',
#  'วัดเทพประสิทธิ์คณาวาส',
#  'สาธารณรัฐไซปรัสในโอลิมปิกฤดูหนาว_2014',
#  'บาลี_(แก้ความกำกวม)',
#  'การเขียนคำทับศัพท์ภาษาพม่า',
#  'บันเทิงคดีแนวจินตนิมิต',
#  'บิลเบา',
#  'การท่าเรือไทย_เอฟ.ซี.',
#  'มาร์ชา_โทมาสัน',
#  'Troglotrematidae',
#  'ใบประกอบวิชาชีพครู',
#  'อัลมะฮัลละตุลกุบรอ',
#  'กีฬามวยสากลในโอลิมปิกฤดูร้อน_2024_–_รอบคัดเลือก',
#  'เบอซิติส',
#  'เอ็นดับเบิลยูเอ_สตารร์เคจ',
#  'Rhadinematidae',
#  'นักเศรษฐศาสตร์',
#  'The_WB',
#  'วิทยาลัยชุมชนระนอง_สถาบันวิทยาลัยชุมชน',
#  'พรรคอาเจะฮ์',
#  'ความขัดแย้งในเซาท์คอร์โดฟานและบลูไนล์',
#  'จังหวัดเนโกรสโอเรียนตัล',
#  'นักบุญมัทธิวผู้ประกาศข่าวประเสริฐ',
#  'เกมออฟโธรนส์',
#  'เควิน_มิราลาส',
#  'เท่ง',
#  'สนธิสัญญาวอชิงตัน',
#  'Cherokee',
#  'เดเนธอร์',
#  'เลขาธิการพระราชวัง',
#  'พิกซีส์',
#  'กูดเขากวาง',
#  'คาซึยุกิ_โอกิสึ',
#  'รางวัลชมรมวิจารณ์บันเทิง_สาขานักแสดงนำชายยอดเยี่ยม',
#  'รางวัลภาพยนตร์แห่งชาติ_สุพรรณหงส์_ครั้งที่_14',
#  'Biochemistry',
#  'บางพลู',
#  'อานิส_โรกา',
#  'วอลเลย์บอลในกีฬามหาวิทยาลัยโลก_1959',
#  'LUSS',
#  'แฟบูลาโนวาคริสตัลลิส:_ไฟนอล_แฟนตาซี',
#  'เดเกเลีย']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

get_len(titles)
# Out:
# current: 353833
# diff: -9122

# %%
get_samples(titles)
# Out:
# ['Jiajing_Emperor',
#  'แดร็ก_เรซ_ไทยแลนด์_ฤดูกาลที่_1',
#  'จ้าวกงหมิง',
#  'พระแม่ราธา',
#  'ฟาโรห์เชเนฮ์',
#  'ดิ_อัลบั้ม_ทรี_ฟรีด้อม',
#  'ซารอสดวงอาทิตย์ที่_111',
#  'นโรดม_สีหนุ',
#  'การลงคะแนนแบบคาร์ดินัล',
#  'Gang',
#  'Wb',
#  'Adachi,_Tokyo',
#  'ปลาบู่ทอง',
#  'House_of_Romanov',
#  'รายชื่อแหล่งมรดกโลกในประเทศเอสโตเนีย',
#  'ปราสาทคาสเตลโน-เบรอเทอนูซ์',
#  'Siamosia_thailandica',
#  'ชเต็ฟฟัน_ครา',
#  'สถานีวิทยุโทรทัศน์กองทัพบกช่อง_7',
#  'พ.ศ._413',
#  'พนักงานมหาวิทยาลัย',
#  'แคซ_ฮายาชิ',
#  'เฉลิม_ปานเกิด',
#  'Paul_Allen',
#  'ซิกกราฟ',
#  'Hannibal_Barca',
#  'NGC_6537',
#  'พระเจ้าจองจง_กษัตริย์องค์ที่_3_แห่งโครยอ',
#  'คลับเฮาส์',
#  'จอร์จที่_6_แห่งสหราชอาณาจักร',
#  'แกรนด์ดัชเชส',
#  'การแปลตามตัวอักษร',
#  'เรฟเมีย',
#  'พาราลิมปิกไอร์แลนด์',
#  'บริบูรณ์_จันทร์เรือง',
#  'เอเชียนเกมส์_2023',
#  'กีฬาทางอากาศในกีฬาแห่งชาติ_ครั้งที่_47',
#  'ยุกะ_โอซากิ',
#  'วาด_รวี',
#  'จักรพรรดิซ่งอินจง',
#  'รัฐพล_พรรณเชษฐ์',
#  'Culture_shock',
#  'วรรณกรรมกรีกโบราณ',
#  'กลไกขยายเสียงในคอเคลีย',
#  'สโมสรฟุตบอลทอตแนม_ฮอทสเปอร์',
#  'Kutaisi',
#  'สถานีรถไฟที่วัง',
#  'ตั้ว_ลพานุกรม',
#  'ancient_kingdom',
#  'วงศ์เทียนดอก',
#  'ปัณฑิตา_ภูวิจารย์_เคาวเวลล์',
#  'ฮาเนะดะ',
#  'ญะบัล_อันนะบีชุอัยบ์',
#  'สถานียมราช',
#  'Fujiwara_clan',
#  'มูน_/_บรอสซัม',
#  'ยัง_เซ-ชัน',
#  'The_Tales_of_Hoffmann',
#  'สิ่งก่อสร้างของคริสต์ศาสนา',
#  'Macrophages',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทย_กันยายน_พ.ศ._2535',
#  'การปรับตัวผิด',
#  'แอลแซด_130_กราฟ_เซปเปลิน',
#  'ฟุตบอลชิงถ้วยพระราชทานประเภท_ข._ประจำปี_2552',
#  'คอมมอนบรัชเทลพอสซั่ม',
#  'อรชุน',
#  'เชาะ',
#  'แผ่นช่องรับแสง',
#  'กําแพงเพชรพิทยาคม',
#  '๑๔_พฤษภาคม',
#  'วอลเลย์บอลหญิงชิงแชมป์อเมริกาใต้_1983',
#  'ปกรณัมชุด',
#  'จังหวัดเซลันด์',
#  'ซุปเปอร์โบวล์',
#  '224_Oceana',
#  'Schubert',
#  'บุปผา_นิมมานเหมินท์',
#  'Phormosomatidae',
#  'ศรีเมือง_เจริญศิริ',
#  'ทางหลวงเอเชียสาย_70',
#  'Tré_Cool',
#  'สถานีรถไฟตรอน',
#  'พระนางมารีย์พรหมจารี',
#  'Atum',
#  'คิม_อันโล',
#  'Yakitate!!_Japan',
#  'The_Destination',
#  'การประสูติของพระเยซู',
#  'เมงฮาย',
#  'กุหลาบแดง',
#  'รูมรามา',
#  'พระราชประสิทธิคุณ',
#  'Dendrophthoe_pentandra',
#  'ฮอไรซันฟอร์บิดเดนเวสต์',
#  'โกลด_มอแน',
#  'Curicó',
#  'Niponiosomatidae',
#  'ไฮร็อก',
#  'ผู้เล่นในเอเชียนคัพ_2019',
#  'ทุกขเวทนา']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

get_len(titles)
# Out:
# current: 465912
# diff: 112079

# %%
get_samples(titles)
# Out:
# ['แบลซมาตุยดี',
#  'Meiko',
#  'N.E.R.D',
#  'ทูเซ็ตไวโอลิน',
#  'อ.หัวตะพาน',
#  'การปกป้องชาติจากการเข้าเมืองสหรัฐของผู้ก่อการร้ายต่างด้าว',
#  'สมเด็จพระราชินีซาโลเตลูเปเปาอู',
#  'เจ้าหญิงโซฟีแห่งโฮเอ็นแบร์ก',
#  'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน1996',
#  'ตั๋งห้อง',
#  'Sagala',
#  'รานีนี',
#  'footballerborn1991',
#  'แขวงนาดะ',
#  'อิโมโตะ',
#  'แซ่เห้ง',
#  'มาร์กวี-เอ1',
#  'กามีย์แบร์ตอมีเย',
#  'เส้นขนานที่64องศาเหนือ',
#  'รายชื่อโบราณสถานในจังหวัดอำนาจเจริญที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'พ.ศ.960',
#  'เวนต์สปิลส์',
#  'YooHee-jae',
#  'ไอเอสโอ',
#  'มิสเวิลด์2553',
#  'ความผิดอาญาสงคราม',
#  'หลี่ตายแทนถาว',
#  'ทพ.กฤษดาเรืองอารีย์รัชต์',
#  'อัลเฟรโดดีสเตฟาโน',
#  'กองพิทักษ์การปฏิวัติอิสลาม',
#  'วิทยาลัยอาชีวศึกษามหาสารคามสถาบันการอาชีวศึกษาภาคตะวันออกเฉียงเหนือ๓',
#  'TheCalloftheWild',
#  'พิชชาภา',
#  'อีวาโนเอ',
#  'Ubantu',
#  'เปอตีต์โมนิ',
#  'Oktopus',
#  'สมเด็จพระเจ้าบรมวงศ์เธอเจ้าฟ้าวิจิตรจิรประภาอดุลยาดิเรกรัตนขัตติยราชกุมารี',
#  'ประชาทัณฑ์',
#  'สุภาพรกิตติขจร',
#  'โตฟีงา',
#  'FBT',
#  'ปาทริควิเอร่า',
#  'รายชื่อธงในประเทศอิรัก',
#  'Battlefront',
#  'วีระเศรษฐกุล',
#  'ดยุกแห่งนาร์เก',
#  'อียู-จิน',
#  'ChildrenoftheGrave',
#  'ซัมเมอร์ไทม์แซดเนส',
#  'Odontitella',
#  'Astonish',
#  'Applewatch',
#  'ซัลบาโดดาลี',
#  'บ้านนาเล',
#  'Elbe',
#  'พระที่นั่งจงเหอ',
#  'ลีร็อย',
#  'บาเธเลมีฟานเอค',
#  'กาบริเอลบอริช',
#  'JokerXue',
#  'ยูเฮ',
#  'ฮัมมามัต',
#  'โยฮันมายอร์',
#  'อะยุมุ',
#  'Brownfield',
#  'การแบ่งแยกแอร์ฟวร์ต',
#  'วันไม้เท้าขาว',
#  'กรุงนิวเดลี',
#  'คำรณ',
#  'Labyrinthusosseus',
#  'assault',
#  'Oyakodon',
#  'โอลิมปิกฤดูร้อน1976',
#  'ศัมภาลา',
#  'พ.ศ.2014',
#  'CathedralofPadua',
#  'คณะวิศวกรรมศาสตร์มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'ปาปุรอส',
#  'อะเดโมลา',
#  'AsianFootballConfederation',
#  'สถานีรถไฟหนองน้ำขุ่น',
#  'โพลีไซคลิกอะโรมาติกไฮโดรคาร์บอน',
#  'คนึงพิมพ์ธนพิชชากรณ์',
#  'กรมปรึกษาชาติชั้นสูง',
#  'ประเทศอิรักในโอลิมปิก',
#  'ชอบธรรม',
#  'Epiduralhematoma',
#  'อาสนวิหารวีวีเย',
#  'เดียรถีย์',
#  'ซะรุโทะบิซะซึเกะ',
#  'ประเทศออสเตรเลียในพาราลิมปิกฤดูร้อน',
#  'ขบวนการไดโนเสาร์ประคุ',
#  'โอเดอร์',
#  'กระทรวงในประเทศญี่ปุ่น',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล2012–13',
#  'ยาป้องกันไม่ให้เลือดตัวจับกันเป็นก้อน',
#  'Krystsina',
#  'เสอซื่อม่าน',
#  'วิวาห์ลวง']

# %% [markdown]
# ### Exclude complete non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
#
# intend to remove non named entity which year included

# %%
titles = set([title for title in titles if "พ.ศ." not in title])

get_len(titles)
# Out:
# current: 459718
# diff: -6194

# %%
get_samples(titles)
# Out:
# ['พระเจ้ารอเบิร์ตที่3แห่งสกอตแลนด์',
#  'สมาพันธ์ว่ายน้ำแอฟริกัน',
#  'เจ้าฟ้าชายหลุยส์',
#  'การยิงธนู',
#  'บุศนันทน์อึ๊งบำรุงพันธุ์',
#  'พระเจ้ายูริแห่งโคกูรยอ',
#  'ชวาร์ซวัลด์-ซตาดิโอน',
#  'เทียมศักดิ์',
#  'กรันตูริสโม่สปอร์ต',
#  'nad',
#  'นานาโวะอาการิ',
#  'Veal',
#  'Helens',
#  'เซน-มยิน',
#  'Fukuyama,Hiroshima',
#  'เหตุการณ์ชุมนุมแฟลชม็อป',
#  'ฟุตบอลโลก2022รอบคัดเลือกโซนยุโรป–กลุ่มเอ',
#  '1326',
#  'คายกคณะ',
#  'อีมินนู',
#  'ม้าต๋ง',
#  'กองรบพิเศษที่5',
#  'สตาร์วอร์ส:ไนทส์ออฟดิโอลด์รีพับลิค',
#  'ทีซีแอลคอร์ปอเรชัน',
#  'สารสนเทศการลงทุน',
#  'ซันโครว',
#  'ยะตะโรคุโระกะวะ',
#  'พันเอกวันชนะ',
#  'ดาบอันดูริล',
#  'วัดตาขัน',
#  'HPAaxis',
#  'ข้าวทริติเคลี',
#  'พยาธิ',
#  'แรมซีย์แมกดอนัลด์',
#  'นีกอลาเฌสกีแยร์',
#  'เฮาเวิร์ด',
#  'พระอุโบสถ',
#  'วัดแฮดงยงกุง',
#  'GentaMiura',
#  'พระสี',
#  'Atractosteus',
#  'เส้นขนานที่51องศาเหนือ',
#  'ประยูรศักดิ์',
#  'รางวัลภาพยนตร์แห่งชาติสุพรรณหงส์ครั้งที่2',
#  'รายชื่อเหรียญราชอิสริยาภรณ์ไทย',
#  'พระแม่ปฤถวี',
#  'จื่อตัน',
#  'ภาษานอร์สโบราณ',
#  'อินซิกนีโอรุม',
#  'ซีต้า',
#  'HippolyteFizeau',
#  'เจ้าหญิงฮานาโกะ',
#  'Motors',
#  'เขตธรรมชาติงดงามดีเด่น',
#  'ดรากอนฟอร์ส',
#  'ดับเบิลยูดับเบิลยูอีสแม็คดาวน์',
#  'Nikopol,',
#  'Heihachiro',
#  'ท่าอวกาศยาน',
#  'Eyetail',
#  'เอ๊กจิ๋ว',
#  'ไอริส',
#  'โนเวฟ',
#  'สุซุกิ',
#  'Zekai',
#  'Shangdynasty',
#  'Canterbury,NewZealand',
#  'ถนนเทพคุณากร',
#  'Doyle',
#  'อาร์เอนเอนำรหัส',
#  'โจโจนัส',
#  'แอฟริกาคัพออฟเนชันส์',
#  'รายชื่อรางวัลและการเสนอชื่อที่ภาพยนตร์ในจักรวาลภาพยนตร์มาร์เวลได้รับ',
#  'โงดินห์เสี่ยม',
#  'กีฬาวิ่งสเกตในเอเชียนเกมส์ฤดูหนาว',
#  'บริติชแอร์เวย์เที่ยวบินที่5390',
#  'คลอแรมเฟนิคอล',
#  'มหาวิหารเซนต์พอล',
#  'สาธารณรัฐมาซิโดเนียในโอลิมปิกฤดูร้อน2008',
#  'พระเจ้าคาร์ลที่15แห่งสวีเดน',
#  'Hydraulic',
#  'อาบรักกระบี่คม',
#  'Gallimorphae',
#  'ระบบสัดส่วนแบบบัญชีรายชื่อปิด',
#  'ปลานา',
#  'เจ้าชายภัคคุ',
#  'Viscerocranium',
#  'เดอะทันเดอเรอร์',
#  'RévolutiondeJuillet',
#  'Scandium',
#  'แคว้นโยนก',
#  'ประเทศชิลีในโอลิมปิกฤดูหนาว1948',
#  'ประวัติศาสตร์อัฟกานิสถาน',
#  'RoyalGovernmentoftheNationalUnionofKampuchea',
#  'พลเรือตรีถวัลย์',
#  'ดัชนีความหนาของร่างกาย',
#  'เชอเรียเบลนดี้',
#  'ซีเอฟเอ็นเอ็ม',
#  'เซอร์ไวเวอร์ไทย',
#  'วัดมัชฌิมาราม']

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

get_len(titles)
# Out:
# current: 340300
# diff: -119418

# %%
get_samples(titles)
# Out:
# ['วิมานมะพร้าว',
#  'ชิวแบคก้า',
#  'กรพินธุ์พ่วงโพธิ์',
#  'สโมสรฟุตบอลจุฬาฯยูไนเต็ด',
#  'ฟุตบอลในประเทศรัสเซีย',
#  'อาซิซิ',
#  'ราชอาณาจักรฮัชไมต์จอร์แดนในเอเชียนเกมส์',
#  'พงศ์สันต์ธมฺมเสฎฺโฐ',
#  'คณะรัฐมนตรีสยามคณะที่2',
#  'หวงเฟยหง5สยบจอมสลัด',
#  'ยออานกาบาย',
#  'ศาสตร์คอมพิวเตอร์',
#  'ฮิมูระเคนชิน',
#  'ระบบดาวคู่รังสีเอ็กซ์',
#  'ปลานกขุนทองปากยื่น',
#  'อเล็กซานเดอร์หวัง',
#  'ประเทศกัมพูชาในพาราลิมปิกฤดูร้อน2016',
#  'โลทัสเทมเพิล',
#  'สถานีรถไฟบ้านหนองหมู',
#  'สโตรคออนเทรนท์',
#  'พรีเมียร์ลีกแห่งบอสเนียและเฮอร์เซโกวีนา',
#  'พระราชินีเอลิซาเบธ',
#  'เกิดอวอร์ด',
#  'ชัยวรรมันที่1',
#  'รัฐและดินแดนสหพันธ์ของประเทศมาเลเซีย',
#  'กีฬายิงปืนในเอเชียนเกมส์2022',
#  'โมบิลสูทกันดั้มยูนิคอร์น',
#  'ฟอร์ทีนเนอร์',
#  'ศรีนอก',
#  'ประเทศแคเมอรูนในพาราลิมปิกฤดูร้อน2012',
#  'ขบวนการเคลื่อนไหวแห่งชาบัก',
#  'ฮะรุโนะยุโงะคุชิโระ',
#  'บอสเนีย-เฮอร์เซโกวีนา',
#  'มะสึดะ',
#  'ซานามิเวียร์',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน1992',
#  'อุปรากรกรุงเทพฯ',
#  'ศาสตราจารย์ดัมเบิลดอร์',
#  'จังหวัดอาลป์-มารีตีม',
#  'วอลเลย์บอลชายทีมชาติตูนิเซีย',
#  'พระเจ้าบรมวงศ์เธอกรมหมื่นศรีสุเทพ',
#  'เกวตซัลโกอัตล์',
#  'ภาษากลุ่มคอเคซัส',
#  'จันทนะผะลิน',
#  'ซีวิคไทป์อาร์',
#  'ซูเปอร์โมเดลอินเตอร์เนชันแนล',
#  'ซะชิโกะ',
#  'อำเภอป่าซาง',
#  'วงศ์อิกัวนา',
#  'วีค',
#  'สิงโตมาไซ',
#  'ชยสุริยา',
#  'มอลทิญญา',
#  'วัดกาญจนสิงหาสน์',
#  'โปเตโต้',
#  'สำนักงานคณะกรรมการนโยบายรัฐวิสาหกิจ',
#  'บีอาร์เอ็นโคออร์ดิเนต',
#  'แร่เหล็ก',
#  'วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร',
#  'ปัปเป็ตส์',
#  'การหนีไปอียิปต์',
#  'ถนนเทพรัตน',
#  'พาร์กแอเวนู',
#  'บันทึกรักของพิมพ์ฉวี',
#  'ชาวพยู',
#  'วังราชทัต',
#  'รายชื่อบริษัทอะนิเมะ',
#  'ยศทหารอิหร่าน',
#  'โยริสมาไทจ์เซน',
#  'เสาค้ำ',
#  'เกนก็อบ',
#  'วาญิบ',
#  'จูอี้',
#  'รัฐเทนเนสซี',
#  'คีวเก็ตสึกิ',
#  'เอียรอส',
#  'ต้นฝรั่ง',
#  'อุดซีมาวายามาซีวา',
#  'อาร์มานด์กุยลอแมง',
#  'อาแซดอัลค์มาร์',
#  'ปวรพัฒน์',
#  'พระราชาธิบดีนิโคลัส',
#  'คำสลับอักษร',
#  'อักษรอเวสตัน',
#  'ตำบลกฤษณา',
#  'เกาะคาปรี',
#  'เงื่อนตะคุ',
#  'ภาษาเขมรสูง',
#  'เซอร์ไว',
#  'เมดัน',
#  'เมกะฟอร์ซ',
#  '304ปีก่อนคริสตกาล',
#  'ยฺหวินหนาน',
#  'วาศภูติ',
#  'แขวงคานางาวะ',
#  'พระพรหมวชิรปัญญาจารย์',
#  'ปลาซิวซอ-บว่า',
#  'เกตตา',
#  'เพียนซา',
#  'ซงเหียน']

# %% [markdown]
# ### Seperate by non-thai character
#
# such as ".", ":", "-"

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(re.split("[^\u0E00-\u0E7F]+", title))
    
titles = titles_temp
get_len(titles)
# Out:
# current: 305063
# diff: -35237

# %%
get_samples(titles)
# Out:
# ['จังหวัดของฝรั่งเศส',
#  'อธิบดีกรมโยธาธิการและผังเมือง',
#  'คิระคิระพรีเคียว',
#  'พระราชวังบวรสถานพิมุข',
#  'พระเจ้าสุกโกทนะ',
#  'รอนวีสลีย์',
#  'วัดแก้ว',
#  'มารานัค',
#  'ศูนย์ฌอร์ฌ',
#  'รับน้องกระต่ายซักแก้วไหมคะ',
#  'สังคม',
#  'อารามสตาฟโรโปลีโอส',
#  'พระเจ้าสูรยวรมันที่',
#  'สมเด็จพระเจ้าเอ็ดการ์',
#  'ดินาราซาฟิน่า',
#  'รายนามอธิบดีกรมประมง',
#  'พักฮย็อง',
#  'สนธิสัญญาว่าด้วยการตกลงขั้นสุดท้ายเกี่ยวกับดินแดนเยอรมนี',
#  'ประเทศซิมบับเวในโอลิมปิก',
#  'ไพโรจน์วายุภาพ',
#  'เรือข้ามฟากเกาหลีใต้พลิกคว่ำ',
#  'ถิ่นแสน',
#  'เมสเซอร์ชมิทท์',
#  'แฟรงกลินเพียร์ซ',
#  'วัดโคกหม้อ',
#  'อาติกาห์',
#  'ไอเอ็มไอกาลิว',
#  'หเลพีฑู',
#  'ข้าราชการพลเรือนในสถาบันอุดมศึกษา',
#  'หนึ่งคำที่ล้นใจ',
#  'ฟองน้ำปะการัง',
#  'ไอแซคฮันนี',
#  'พระที่นั่งมหิศรปราสาท',
#  'คิมโย',
#  'ไฮดรอกซิซีน',
#  'รับขวัญ',
#  'สนามกีฬาอีรัมบีตอร์น',
#  'รายชื่อโบราณสถานในจังหวัดอุดรธานีที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'ผีหมอหมอผี',
#  'มิตสึกิไซงะ',
#  'สเตาร์บริดจ์',
#  'อาลิซาเบธแซ๊ดเลอร์',
#  'ซาลิมาสุลต่านบีกัม',
#  'โนบอดี',
#  'คลูช',
#  'ฟินีเชียน',
#  'ปลากระโห้',
#  'อาเบอร์เลอ',
#  'เบอร์แบงค์',
#  'ราอุลบัลเดซ',
#  'สมเด็จพระราชชนนีแห่งโรมาเนีย',
#  'เอฟเคปาร์ตีซาน',
#  'จักรวรรดิอคีเมนิด',
#  'เมืองอานามิซึ',
#  'ดิเอเวอร์ลีบราเธอร์ส',
#  'ชาวอิรักเชื้อสายเติร์กเมน',
#  'ออนอเรฟรากอนาร์',
#  'พระเจ้าโอธอนแห่งกรีซ',
#  'อรสา',
#  'เนอร์วาน่า',
#  'ราชรัฐลีชเทินชไตน์',
#  'เอ็ดการ์ไรต์',
#  'เมืองละมาม',
#  'พชรพลจั่นเที่ยง',
#  'รายชื่อธงในประเทศกรีซ',
#  'โรคพยาธิกีเนีย',
#  'เชวซูยอง',
#  'จิมมี่แครมป์ตัน',
#  'อาร์เตมีเซีย',
#  'วิไซผาภูวนิน',
#  'เดชไอ้ด้วนภาค',
#  'พระเจ้าชุงนยอล',
#  'แอนทิโกนี',
#  'เฮย์',
#  'เดอะเชปออฟวอเทอร์',
#  'เปอร์กินเจ',
#  'ยงยุทธติยะไพรัช',
#  'รุยปาตรีซีอู',
#  'พรายพยากรณ์',
#  'ยูรีธมิกส์',
#  'งูแบล็กแมมบา',
#  'หาดคุจูคุริ',
#  'เฮริฟอร์ดเชอร์',
#  'วัดสิงห์ท่า',
#  'ซามูเอลเบ็คเค็ทท์',
#  'สิทธิของบุตรคนแรก',
#  'เวนเดล',
#  'ยันเดอไบร',
#  'โมเดสต์',
#  'ช็องยุนคยอม',
#  'แยชือสกอลีมอฟสกี',
#  'ขุนคงฤทธิศึกษากร',
#  'อสุภะ',
#  'กรอบมาตรฐานคุณวุฒิ',
#  'ฌูแซฟงตือ',
#  'สโมคตูนอฟสกี',
#  'ชาแซม',
#  'อาวน์ซิตี',
#  'จูบาต่ำ',
#  'สโมสรฟุตบอลวัวชน']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4621

# %%
get_samples(raay)
# Out:
# ['รายชื่อสมาชิกคณะมนตรีความมั่นคงแห่งสหประชาชาติ',
#  'รายชื่อทะเลสาบในประเทศญี่ปุ่น',
#  'รายชื่อธงชาติในเขตโอเชียเนีย',
#  'รายนามรัฐมนตรีว่าการกระทรวงมหาดไทย',
#  'รายชื่ออักษรในภาษาต่างๆแบ่งตามชนิดอักษร',
#  'รายพระนามและรายนามผู้ปกครองลิเบีย',
#  'รายชื่อผู้ครองตำแหน่งมิสแกรนด์อินเตอร์เนชันแนล',
#  'รายพระนามกษัตริย์แห่งอังกฤษ',
#  'รายชื่อรัฐมนตรีประจำสำนักนายกรัฐมนตรีของไทย',
#  'รายชื่อโรงเรียนในจังหวัดนราธิวาส',
#  'รายชื่อองค์กรปกครองส่วนท้องถิ่นในจังหวัดอุดรธานี',
#  'รายพระนามพระมหากษัตริย์อิตาลี',
#  'รายชื่อวัดในจังหวัดสงขลา',
#  'รายชื่อสัตว์เลื้อยคลาน',
#  'รายชื่อบุคคลจากมหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'รายพระนามเจ้าผู้ครองนครเชียงใหม่',
#  'รายชื่อนายกรัฐมนตรีสวีเดน',
#  'รายชื่อรางวัลทางการศึกษานานาชาติของไดซาขุอิเคดะ',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐประชาชนจีน',
#  'รายชื่อแคว้นของประเทศทาจิกิสถานตามดัชนีการพัฒนามนุษย์',
#  'รายชื่อวัดในจังหวัดนราธิวาส',
#  'รายชื่อประธานาธิบดีอินโดนีเซีย',
#  'รายชื่อบริษัทประกันภัยในประเทศไทย',
#  'รายการปริพันธ์ของฟังก์ชันตรีโกณมิติ',
#  'รายนามหัวหน้ารัฐบาลสตรีจากการเลือกตั้งหรือแต่งตั้ง',
#  'รายชื่อละครโทรทัศน์ทางช่องเวิร์คพอยท์',
#  'รายชื่อผลงานของ',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐเวียดนาม',
#  'รายชื่อตัวละครในเรื่องอินาสึมะอีเลฟเวนอาเรสโนะเท็นบิงและโอไรออนโนะโคคุอิน',
#  'รายชื่อไมโครซอฟท์วินโดวส์รุ่นต่างๆ',
#  'รายนามประธานาธิบดีมาดากัสการ์',
#  'รายงานประจำปี',
#  'รายการภาคเช้า',
#  'รายชื่อศิลปินแนวยูโรแดนซ์',
#  'รายนามรัฐมนตรีว่าการกระทรวงสาธารณสุขของไทย',
#  'รายชื่อโรงเรียนในจังหวัดนครราชสีมา',
#  'รายพระนามพระมหากษัตริย์มาดากัสการ์',
#  'รายชื่อบัญชีทวิตเตอร์ที่มีผู้ติดตามมากที่สุด',
#  'รายชื่อเพย์',
#  'รายการวันสำคัญเกี่ยวกับวิดีโอเกม',
#  'รายการเครื่องอิสริยาภรณ์สาธารณรัฐประชาชนจีน',
#  'รายชื่อแบบดึงลง',
#  'รายชื่อแชมป์เปี้ยนทั้งหมดของ',
#  'รายชื่อแม่น้ำในประเทศกัมพูชา',
#  'รายชื่อผลงานเพลงของเอ็นซีที',
#  'รายชื่อประเทศเรียงตามการผลิตไทเทเนียม',
#  'รายชื่อผลงานของเวิร์คพอยท์เอ็นเทอร์เทนเมนท์',
#  'รายชื่อผลงานทั้งหมดของแอลัน',
#  'รายชื่อรางวัลของวงเกิล์สเจเนอเรชั่น',
#  'รายชื่อโรงเรียนในจังหวัดเชียงใหม่',
#  'รายชื่อรัฐในสหรัฐอเมริกา',
#  'รายชื่ออาหารจากเต้าหู้',
#  'รายนามผู้ว่าราชการรัฐซาราวัก',
#  'รายชื่อปีในโทรทัศน์ตามประเทศ',
#  'รายพระนามสมเด็จพระราชินีและจักรพรรดินีแห่งเกาหลี',
#  'รายชื่อสะพานแขวนที่ยาวที่สุดในโลก',
#  'รายชื่อนักเขียนบันเทิงคดีแนววิทยาศาสตร์',
#  'รายชื่อผู้ดำรงตำแหน่งมิสไทยแลนด์เวิลด์',
#  'รายชื่อรุ่นของไมโครซอฟต์วินโดวส์',
#  'รายนามรัฐมนตรีว่การกระทรวงวัฒนธรรม',
#  'รายพระนามพระมหากษัตริย์โมร็อกโก',
#  'รายชื่อสายการบินในประเทศบรูไน',
#  'รายชื่ออัลบั้มเพลงที่ขับร้องโดยยอดรักสลักใจ',
#  'รายนามรัฐมนตรีช่วยว่าการกระทรวงมหาดไทยของไทย',
#  'รายชื่อตัวละครในนาร์เนีย',
#  'รายชื่อตอนเคโรโระ',
#  'รายชื่อโบราณสถานในจังหวัดยโสธร',
#  'รายชื่อดินแดนที่ถูกครอบครองโดยจักรวรรดินิยมญี่ปุ่น',
#  'รายชื่อประธานาธิบดีสาธารณรัฐฝรั่งเศส',
#  'รายชื่อส่วนหัวของเอชทีทีพี',
#  'รายชื่อผู้ชนะชาร์ตโชว์แชมเปียน',
#  'รายชื่อแหล่งมรดกโลกในประเทศกรีซ',
#  'รายชื่อแหล่งมรดกโลกในประเทศกาตาร์',
#  'รายชื่อผลงานเพลงของไมคุระกิ',
#  'รายชื่อนครที่ใหญ่ที่สุดในโลก',
#  'รายพระนามและรายนามที่จุดกระถางคบเพลิงโอลิมปิก',
#  'รายชื่อโบราณสถานในจังหวัดชุมพร',
#  'รายชื่อตอนในอนิเมะเรื่อง',
#  'รายชื่อเครื่องดนตรี',
#  'รายชื่อธงประจำแคว้นในฝรั่งเศส',
#  'รายพระนามพระมหากษัตริย์ไรอาเตีย',
#  'รายชื่อผู้ได้รับรางวัลบทภาพยนตร์ดัดแปลงยอดเยี่ยมรางวัลภาพยนตร์ไทย',
#  'รายชื่อเผ่าพันธุ์ในสตาร์',
#  'รายนามประธานรัฐสภา',
#  'รายชื่อบุคคลที่เป็นประธานในพิธีเปิดโอลิมปิก',
#  'รายชื่อนักกีฬาเอ็นบีเอ',
#  'รายชื่อเครื่องอิสริยาภรณ์โมซัมบิก',
#  'รายพระนามพระมหากษัตริย์สวาซิแลนด์',
#  'รายชื่อทางแยกในเขตบางรัก',
#  'รายนามบุคคลจากมหาวิทยาลัยศรีนครินทรวิโรฒ',
#  'รายชื่อวัดในจังหวัดนครสวรรค์',
#  'รายพระนามพระมหากษัตริย์ซาอุดิอาระเบีย',
#  'รายชื่อพระราชนิพนธ์ในสมเด็จพระเทพรัตนราชสุดาฯสยามบรมราชกุมารี',
#  'รายชื่อแชมป์ฟุตบอลเยอรมัน',
#  'รายนามผู้อำนวยการสถานศึกษาโรงเรียนสวนกุหลาบวิทยาลัยนนทบุรี',
#  'รายชื่อสถาบันแพทยศาสตร์ในประเทศไทย',
#  'รายชื่อตัวการ์ตูนของซานริโอ',
#  'รายนามคู่สมรสนายกรัฐมนตรีของไทย',
#  'รายพระนามเทวดาแห่งโชคลาภ',
#  'รายชื่อไวรัสคอมพิวเตอร์']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 55

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายาอูงู',
#  'รายคอวิช',
#  'รายยวา',
#  'รายงานผู้ป่วย',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายาแห่งรัฐปะลิส',
#  'รายากูนิง',
#  'รายาแห่งซาราวะก์',
#  'รายาห์',
#  'รายงานประจำปี',
#  'รายานนท์',
#  'รายงานเฮิร์ช',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายนานนท์',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายได้พื้นฐาน',
#  'รายงานเค้ส',
#  'รายงานคนไข้',
#  'รายกอวิช',
#  'รายตา',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายวนปูเลาเกอราปา',
#  'รายงานเคส',
#  'รายงานทีหลัง',
#  'รายาประไหมสุหรีอากง',
#  'รายวน',
#  'ราย',
#  'รายาบีรู',
#  'รายหัว',
#  'รายงานกรณี',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายาแห่งซาราวัก',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายากับมังกรตัวสุดท้าย',
#  'รายงานค่าใช้จ่าย',
#  'รายงานความสุขโลก',
#  'รายวนปูเลาเกอลาปา',
#  'รายได้',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายปุระ',
#  'รายงานการประชุม',
#  'รายา',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายาฮีเจา',
#  'รายูวันปูเลาเกอลาปา',
#  'รายงานเรื่องอาหาร',
#  'รายาผิวขาว']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
get_len(titles)
# Out:
# current: 300497
# diff: -4566

# %%
get_samples(titles)
# Out:
# ['ไมซ์',
#  'สรพงศ์ชาตรี',
#  'สมเด็จพระราชินีแคทเธอรีน',
#  'พระมหาเทวีจิระประภา',
#  'รถไฟฟ้าคุนหมิงสาย',
#  'ลิมบานออัสเตรอ',
#  'มาลีเอตัวตานุมาฟิลิที่',
#  'วงออร์เคสตร้า',
#  'ศิษย์ไตรภูมิ',
#  'ไม่รักดี',
#  'อเลสซานดร้าแอมโบรซิโอ้',
#  'เรือบรรทุกเครื่องบินโซริว',
#  'การแบ่งประเภทวัตถุโดยใช้คุณสมบัติเชิงแม่เหล็ก',
#  'ธงนิศานสาหิบ',
#  'เวอร์ชวลริแอลลิที',
#  'มิซาโกะ',
#  'จักรพรรดิลูกิอุส',
#  'อาเกจิมิตสึฮิเดะ',
#  'ต้นตาลตัวผู้',
#  'อี่พ่อครัวตัวจี๊ดหัวใจคับโลก',
#  'เชอวาลีเยเดอโบเรอการ์',
#  'ซีเมาซาบรอซา',
#  'ถนนนครไชยศรี',
#  'ฟาโรห์เทพแห่งโลก',
#  'แซมโชติบัณฑ์',
#  'ยุทธการที่อะกาบา',
#  'สยามฟิวเจอร์ดีเวลอปเมนท์',
#  'คณะกรรมการโอลิมปิกดัตช์',
#  '้',
#  'วัดเลาเต่า',
#  'พายุโคอินุ',
#  'คณพันธ์',
#  'ของโมเดอร์นา',
#  'ทสึมิเระ',
#  'ปกฺากะญอ',
#  'รอยประสาน',
#  'พรรคซาบาห์ก้าวหน้า',
#  'จางเจี่ยนจือ',
#  'เมืองฮะบิกิโนะ',
#  'เพลงภัทรวีศรีสันติสุข',
#  'เกล็นน์โคลส',
#  'มาทิลดาแห่งบริเตนใหญ่',
#  'ยูนูซ',
#  'มักซ์เวล',
#  'ฮูบาสแตง',
#  'ทางรถไฟสายแม่กลอง',
#  'พิกซาร์',
#  'เพลงชาติบอสเนียและเฮอร์เซโกวีนา',
#  'โวลฟรัทส์เฮาเซิน',
#  'เอเลนอร์แห่งออสเตรียสมเด็จพระราชินีแห่งโปรตุเกส',
#  'โซกำโคย',
#  'พระนางติโลกจุฑาเทวี',
#  'กานาพรีเมียร์ลีก',
#  'ท่าอากาศยานแม่สะเรียง',
#  'โมนา',
#  'เอ็มเอฟเค',
#  'วัดราชบัลลังก์ประดิษฐาราม',
#  'ยิงธนูชิงแชมป์โลก',
#  'พิพิธภัณฑ์บริติช',
#  'เขาไท่',
#  'หมีดำเอเชีย',
#  'วาเลนตินามัตวิเยนโก',
#  'แฮร์ฟุต',
#  'ฟูริงานะ',
#  'พระเจ้าบรมวงศ์เธอพระองค์เจ้าโตกรมหลวงมหิศวรินทรามเรศร์',
#  'จักรพรรดิเว่ยหมิงตี้',
#  'ประเทศรัสเซียในโอลิมปิกเยาวชนฤดูร้อน',
#  'นกกระตั้วดำหางขาว',
#  'เดดเมานท์เดธเพลย์',
#  'จิกะบิตต่อวินาที',
#  'พัททริคซึสคินท์',
#  'ลูโดวีกาแห่งออสเตรีย',
#  'บริเวณห้าแยกปากเกร็ด',
#  'แขวงชัง',
#  'ไวรัสเวสต์ไนล์',
#  'ธงขบวนการปฏิวัติอาหรับ',
#  'บริษัทอินเดียตะวันออกของเนเธอร์แลนด์',
#  'ชัยเดชนารายณ์มหาราช',
#  'จอช',
#  'มุนิน',
#  'วอลเลย์บอลหญิงทีมชาติจอร์แดน',
#  'วอลเลย์บอลยุวชนหญิงอายุไม่เกิน',
#  'วันเดอร์ฟูล',
#  'กาลีดู',
#  'เสนาหอย',
#  'โทลเลน',
#  'บานประตูวิหารวัดพระฝาง',
#  'สำลี',
#  'สหวิช',
#  'อจักส์',
#  'ไฟเตอร์ส',
#  'วงศ์เอลิฟานติดี',
#  'ไตตัสบรัมเบิล',
#  'ทะกะชิอินะกะชิ',
#  'มณฑลสงวนเสริมศรี',
#  'เขาสมอคอน',
#  'ซ็อนโบรัม',
#  'มหาวิหารนักบุญไอแซค',
#  'ไลกา',
#  'พระวรวงศ์เธอพระองค์เจ้าปิยบุตร']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal ranks and titles
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# No need processing -> name redirection of wikipedia already covered this problem.

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [title for title in titles if "ใน" in titles]
len(nai)
# Out:
# 300497

# %%
[nai][:50]
# Out:
# [['',
#   'เพศศาสตร์',
#   'สมเด็จเจ้าฟ้าอาภรณ์',
#   'โวโรเนจ',
#   'สมเด็จพระจักรพรรดินีเสี้ยวเจ๋ออี้',
#   'คู่กัดฟัดไม่เลิก',
#   'วิมลโนช',
#   'สวิชญาวาทะพุกกะณะ',
#   'เมแกนมาร์เกิล',
#   'การลอบปลงพระชนม์อาร์ชดยุกฟรันทซ์แฟร์ดีนันท์แห่งออสเตรีย',
#   'โค้ง',
#   'อย่าง',
#   'ความสมเหตุสมผลเชิงสถิติของข้อสรุป',
#   'กึไรรู',
#   'นาตาลีวูด',
#   'บุตรสมบัติ',
#   'คลองเฉลิมชัยพัฒนา',
#   'การเสนอตัวเป็นเจ้าภาพโอลิมปิกเยาวชนฤดูร้อน',
#   'หาญจางสิทธิ์',
#   'แพนโนเนีย',
#   'ถนนเอเชีย',
#   'โพสต์พังก์รีไววัล',
#   'ดีแอนด์อี',
#   'กรดยูริก',
#   'นำชัย',
#   'พระยาอนิรุทธเทวา',
#   'สนามจุฬาฯ',
#   'สโมสรฟุตบอลทวีวัฒนา',
#   'เจมส์ฮอร์เนอร์',
#   'เอากุสเทอแห่งบาวาเรีย',
#   'ลายอาแคนธัส',
#   'การรุกรานรัสเซียของสวีเดน',
#   'จังหวัดวาล',
#   'โมโมโกะ',
#   'เกออร์กีนาฟ็อนวิลเช็ค',
#   'พื้นที่ธรรมชาติและประวัติศาสตร์หุบเขาจิ่วจ้ายโกว',
#   'ในประเทศอิหร่าน',
#   'กวางเจา',
#   'เหตุระเบิดในไนจีเรีย',
#   'ภาคีเจได',
#   'มายุชินโจ',
#   'กรมหมื่นพิทักษ์ภูเบศร์',
#   'บุษปะเกศ',
#   'นะโอะกิ',
#   'เตอร์กิชแอร์ไลน์',
#   'แคลเซียมฟลูออไรด์',
#   'โย่งพิษณุโลก',
#   'มุคฮ์ทาร์โมฮัมเหม็ดฮัสซิน',
#   'โฮมสเตย์',
#   'พระธาตุจอมจ้อ',
#   'แกรนด์ดัชชีตอสคานา',
#   'อินะโมะโตะ',
#   'รอสเซลิ',
#   'พูนทรัพย์',
#   'ทัวร์ริสเตอร์',
#   'บอลเชวิค',
#   'สินาตรา',
#   'โอคิอายุเรียวทาโร่',
#   'เทือกเขาพิเรนีส',
#   'แดล',
#   'ธงเรดดัสเตอร์',
#   'ฟิลิปปิน',
#   'โอซึซึกิโมโมชิกิ',
#   'วัตถุขนาดเล็กในระบบสุริยะ',
#   'โครเอเชียและเซอร์เบีย',
#   'ฟุตบอลทีมชาติเดนมาร์ก',
#   'อัลวาร์อาลโต',
#   'สถานีนครหลวงเวียงจันทน์',
#   'ดิจิมอนภาคธรรมดา',
#   'ฟาโรห์ยากาเรบ',
#   'โรงเรียนดงใหญ่วิทยาคม',
#   'บอมเบอร์แมนไลฟ์',
#   'เวกเตอร์สเปซ',
#   'นาธานโจนส์',
#   'การใช้จิตเวชศาสตร์โดยมิชอบทางการเมือง',
#   'รัฐสภาศรีลังกา',
#   'วัฒนาสิทธิวัง',
#   'นูเจนต์',
#   'อันเดรเทอร์ชเตเกิน',
#   'ประกายเพชร',
#   'หลักเกณฑ์การทับศัพท์ของราชบัณฑิตยสถานและสำนักงานราชบัณฑิตยสภา',
#   'จานโลเรนโซแบร์นินี',
#   'วีทรีโอ',
#   'บอรุค',
#   'ซาอุด',
#   'ภาษาปะหล่อง',
#   'เออแฌนวียอแล',
#   'เจงฮุ่ง',
#   'บดินทร์',
#   'ภาษาไลเดีย',
#   'ฟาเรนไฮต์',
#   'เฮลมี',
#   'ปราซาดูกูแมร์ซียู',
#   'จัสต์บี',
#   'นักพรตหญิง',
#   'การ์โลสมูรีโย',
#   'ตระกูลมินาโมโตะ',
#   'ถนนเจ้าคำรบ',
#   'วินสโมคซันจิ',
#   'ลำหยง',
#   'ชวาลตันพิพัทธ์',
#   'ตราสัญลักษณ์พระราชพิธีมหามงคลเฉลิมพระชนมพรรษา๘๐พรรษา๕ธันวาคมพุทธศักราช๒๕๕๐',
#   'แบล็กแจ๊ก',
#   'ถลกบาตร',
#   'ลือประเสริฐ',
#   'ทากาชิโคริโมโตะ',
#   'ทีโม',
#   'ซับพลู',
#   'วงปี่พาทย์มอญ',
#   'อาร์คาดิอุสซ์มิลิค',
#   'สเปซแมน',
#   'จังหวัดอิวาเตะ',
#   'ฮันส์โอสเตอร์',
#   'มหาวิทยาลัยศรีนครินทรวิโรฒปทุมวัน',
#   'องค์การบริหารการบินแห่งชาติ',
#   'เมซานีน',
#   'กองกำลังภาคพื้นอากาศคาซัคสถาน',
#   'อันโซฮี',
#   'จักรวรรดิเซลจุคอันยิ่งใหญ่',
#   'เทลมอน',
#   'ภาษาปาเลปะหล่อง',
#   'พร็อสต์',
#   'โลกาวินาศ',
#   'ฟุตบอลลีก',
#   'วัดเจดีย์หอย',
#   'คัทเธอรีนแห่งอรากอน',
#   'บิลลี่เดอะคิด',
#   'ช่องกกหู',
#   'การเข้าฌาน',
#   'วัดเรียวอัง',
#   'สัจพจน์การเลือก',
#   'ล้มละลาย',
#   'พระสุตตันตปิฎก',
#   'ทตสึกาวะ',
#   'ฟุตบอลลีกโทรฟี',
#   'เทียกี',
#   'พระราชพงศาวดารกรุงสยาม',
#   'นิวคิดส์ออนเดอะบล็อก',
#   'โมแยง',
#   'ยุคมืดของกัมพูชา',
#   'มาร์กโนเบิล',
#   'เอลฟ์ประจำบ้าน',
#   'เอเลนอร์แห่งออสเตรียสมเด็จพระราชินีแห่งโปรตุเกส',
#   'สถานีรถไฟซัปโปะโระ',
#   'สเปลล์เช็ก',
#   'กลีบด้านหน้า',
#   'เมืองเวียงพูคา',
#   'ลาซานยา',
#   'ดิสซิเดีย',
#   'สถานีรถไฟบ้านวะตะแบก',
#   'ปาแย',
#   'ไรอันแอร์เที่ยวบินที่',
#   'เออเวนจ์',
#   'พีค็อก',
#   'อินฟันตาอูลาเลียแห่งสเปน',
#   'หาญสุจินต์',
#   'ทากางิ',
#   'จุ๊บวุฒินันต์ภิรมย์ภักดี',
#   'ไวกิกี',
#   'ยุทธการโคมากิและนางากูเตะ',
#   'ไครต์เชิร์ช',
#   'รัฐโลเออร์ออสเตรีย',
#   'อักษรแอราเมอิก',
#   'เมืองโยะโกะซุกะ',
#   'ท่ากายี',
#   'ลิปดา',
#   'ฟาทาอิโอนิเคเค',
#   'วีแกนแอทเลติก',
#   'อาหารทางการแพทย์',
#   'ฟาซิโอ',
#   'อ่าววากาซะ',
#   'ฮอโลมัมน์',
#   'โดยคำแนะนำและยินยอม',
#   'จรวดหลายลำกล้องแบบดีทีไอ',
#   'โนริยะกิ',
#   'โรคโมโน',
#   'หนังกำลังภายใน',
#   'แองกัสกันน์',
#   'มาสค์ไรเดอร์ดีเคดออลไรเดอร์ปะทะไดช็อกเกอร์',
#   'เดอร์วีล',
#   'ขบวนการหน้ากากกายฟอคส์ในประเทศไทย',
#   'แทรริชเซอร์ดูว์ดุกเดอแบรี',
#   'โจเซปฟอร์เลนเซ',
#   'ลูลูงา',
#   'ดรีส์เมอร์เทนส์',
#   'เทพอาเตน',
#   'ร็อบสันวอลตัน',
#   'สวนสมเด็จพระศรีนครินทร์ชุมพร',
#   'สวนิต',
#   'รางรักพรางใจ',
#   'เยียน',
#   'เมียนมาอีโคโนมิกโฮลดิงส์',
#   'เฉลิมพงษ์สวัสดิ์',
#   'เจ้าชายยูจีนแห่งซาวอย',
#   'จิวะไซโต',
#   'ดาเนียลอักเกอร์',
#   'การบุกขึ้นเหนือของจูเกอเหลียง',
#   'วิสัญญีแพทย์',
#   'เจียรสุข',
#   'ฮาเกียโซเฟีย',
#   'พระศรีสุชาดา',
#   'ภาษามโร',
#   'ต้นแบบนอร์ดิก',
#   'ชัยชนะของเจได',
#   'จักรพรรดิคลาอุดิอุส',
#   'เวือง',
#   'วอลเลย์บอลชายทีมชาติคูเวต',
#   'บรู๊ซวิลลิส',
#   'รัศมีแข',
#   'ปลาจีน',
#   'สมเด็จพระศรีนครินทราบรมราชชนนี',
#   'ลือลิยอ',
#   'กีฬาเยาวชนเอเชียตะวันออก',
#   'มูคะนะซะกิ',
#   'การแยกผู้ป่วย',
#   'เรือยูเอสเอสเอนเทอร์ไพรซ์',
#   'เจรีฮัลลิเวลล์',
#   'โคลเซ',
#   'เอลโตรีโต',
#   'และโบท',
#   'ซุยเกตสึ',
#   'โฮโลซีน',
#   'เกษมจันทร์แก้ว',
#   'การระเบิดกัมปนาท',
#   'ชิเงรุ',
#   'เขตโฎนปึญ',
#   'ซิตฮาธอร์ยูเนต',
#   'ดรงค์',
#   'เหตุฆาตกรรมเซซีล',
#   'ปลาเข็มช้าง',
#   'คลองคูเมืองธนบุรีฝั่งตะวันตก',
#   'ยุทธการที่ลองถั่น',
#   'โมริโคโกโร่',
#   'ทีม็อนเว็ลเลินร็อยเทอร์',
#   'ภารต้า',
#   'วอลเลย์บอลชายทีมชาติอุรุกวัย',
#   'เหตุแผ่นดินถล่มในแยร์ดรึม',
#   'สโมสรฟุตบอลช้างเผือกเชียงใหม่',
#   'จักรวรรดิแมนจูกัว',
#   'เจ้าหญิงอีมานปาห์ลาวี',
#   'บล็อกดินซีเมนต์',
#   'เครสแจน',
#   'มหาวิทยาลัยวิทยาศาสตร์สุขภาพ',
#   'อะมะเตะระสุ',
#   'ฟาโรห์เมนทูโฮเทไป',
#   'พักซ็อนโฮ',
#   'ดอกไม้เพชรฆาต',
#   '๑๒พฤศจิกายน',
#   'ฮิซะตะดะ',
#   'พระราชวังฤดูหนาว',
#   'รุสลี',
#   'เซกิงาฮาระ',
#   'สถาบันวิจัยโนมูระ',
#   'รัฐสภาคองเกรสแห่งสหรัฐอเมริกา',
#   'ทรงสี่หน้าตัดมุม',
#   'คาร์ลอสเบลา',
#   'กีฬาฮ็อคกี้น้ำแข็งในโอลิมปิก',
#   'กล้ามเนื้ออินฟีเรียร์ออบลีก',
#   'กงเต',
#   'บิวาโกะ',
#   'รถไฟใต้ดินเทศบาลโยะโกะฮะมะ',
#   'จักรพรรดิซ่งเหญินจง',
#   'ภาษาสินธ์',
#   'พิพิธภัณฑ์แห่งชาติสวิส',
#   'สถานีรถไฟโยโยงิ',
#   'ราฟาแอลกามาชู',
#   'สโมสรฟุตบอลเซบียา',
#   'องค์ชายแฮยัง',
#   'บิรง',
#   'สมเด็จพระราชินีคาโรลีนแห่งแอนสแพค',
#   'กาหลมหรทึก',
#   'รัฐนิวบรันสวิก',
#   'ภาษาผู้น้อย',
#   'เบียวาปอดลัสกา',
#   'บะอู',
#   'แคว้นศักดินาฮิโรชิมะ',
#   'ซนนาอึน',
#   'ตำบลทุ่งฝน',
#   'แชริตี้เบอร์เบจ',
#   'ลิแกนด์',
#   'นักฟุตบอลเกิดใน',
#   'วัดโสภาราม',
#   'สตอลแมน',
#   'ยองซัม',
#   'การปรับตัว',
#   'ครรชิต',
#   'กองซุนของ',
#   'เจ้าแม่กวนอิม',
#   'ปลาสลิดทะเล',
#   'ถนนสุรวงศ์',
#   'นอวีซาด',
#   'เห่าช้าง',
#   'แอนดิกาเปอร์กาซา',
#   'อิลเซอ',
#   'โรงแรมแมนดารินโอเรียนเต็ล',
#   'เบ๋านินห์',
#   'ที่หยุดรถไฟท่าม่วง',
#   'อคิลลีส',
#   'อำเภออัมพวา',
#   'ปรากฎการณ์โลกร้อน',
#   'บริษัทอู่กรุงเทพ',
#   'วัดใหม่เจริญธรรม',
#   'โมะ',
#   'ขนฺธสโร',
#   'ไฟรบูร์กอิมไบรส์เกา',
#   'เสี่ยวซิน',
#   'และช่วงเวลาแห่งชะตากรรมของโกสต์',
#   'เดอะบูลเบิร์ด',
#   'เครือปรอกช้าง',
#   'เคย์จิ',
#   'ทะเลสาบแวแนร์น',
#   'ยอดม่วง',
#   'รอบคัดเลือกกลุ่มเอฟ',
#   'วัดรวกบางบำหรุ',
#   'พระครูพิพิธประชานาถ',
#   'เวเนเชียน',
#   'ท่าช้างวังหลวง',
#   'โรงเรียนพ่อมดแม่มดและเวทมนตร์ศาสตร์ฮอกวอตส์',
#   'เทศมณฑลแชฮ์เรซอ',
#   'อาร์มาดิลโล่แคระ',
#   'อันดับหนูผีช้าง',
#   'โจรันเจ้าหญิงแห่งหิมะและเลือด',
#   'ประวัติศาสตร์สหรัฐอเมริกา',
#   'เสรีนครจักรวรรดิฟรังค์ฟวร์ท',
#   'ทูนิส',
#   'เดอะทาทามิกาแล็กซี',
#   'มี่',
#   'อีเล็คทอรัลพาลาทิเนท',
#   'วัดโพธิ์ธาตุ',
#   'ดิอัมโบรซิโอ',
#   'ชิตพรกำลังมาก',
#   'วาร์แทน',
#   'พระเจ้าบรมวงศ์เธอกรมหมื่นมเหศวรศิววิลาส',
#   'สโมสรฟุตบอลบาร์เซโลน่า',
#   'แองเจลิส',
#   'แม่น้ำอัตตาบาส์',
#   'กันดั้มวิง',
#   'คาลอส',
#   'ตัวละครในเรื่องเซนต์เซย่า',
#   'สายการบินอัฟริคิยาห์เที่ยวบิน',
#   'อี่พ่อครัวตัวจี๊ดหัวใจคับโลก',
#   'ทอกอนโทโมร์',
#   'ลูกไม้',
#   'ควันนัม',
#   'แนวร่วมปิตุภูมิเวียดนาม',
#   'เอร์นันกอร์เตส',
#   'ริซะโกะ',
#   'ภาษาอึมปือ',
#   'อนุสรายังตรง',
#   'ชั่วโมงต้องมนต์',
#   'วัดพระขวาง',
#   'ท็อปไลน์มิวสิค',
#   'เจ้าเจตคุปต์',
#   'การสับเปลี่ยนของโครโมโซมแบบโรเบิร์ตโซเนียน',
#   'แดเนียลเว็บเบอร์',
#   'ชาญพวงเพ็ชร์',
#   'ปราชญ์หนึ่งในใต้หล้ากับตราสุดอัปยศ',
#   'ซูเปอร์มารีน',
#   'เทอร์มาแกนต์',
#   'วัดพะโคะ',
#   '๒พฤศจิกายน',
#   'ระบบตะกร้าสินค้า',
#   'ซะกุมะ',
#   'เควินลูดอล์ฟ',
#   'เหตุการณ์พายุหมุนนาร์กิส',
#   'ชาอู่หลง',
#   'การถ่ายโอน',
#   'ปลาบู่หิน',
#   'ฟองเตซี',
#   'แฟนด้อม',
#   'มาร์คุสว็อล์ฟ',
#   'เทศบาลตำบลสุวรรณคูหา',
#   'อักษรอาหรับสำหรับภาษาแอฟริกัน',
#   'ประวัติมหาวิทยาลัยมหิดล',
#   'เทงโกกุ',
#   'ทิงส์',
#   'แมททิวฟอกซ์',
#   'ประเทศนอร์เวย์ในโอลิมปิก',
#   'ปากกาเคมี',
#   'ปางเรือนแก้ว',
#   'สังศิตพิริยะรังสรรค์',
#   'ปานตะวันและปานวาด',
#   'สปอร์ตไบก์',
#   'สกุลปลาดุกทะเล',
#   'หน่วยเวกา',
#   'จ้าวเสี่ยน',
#   'โจเซโทดะ',
#   'ภาษาที่ใช้ในประเทศไทย',
#   'เยีย',
#   'จากัวรันดี',
#   'แอชลีย์ทีสเดล',
#   'กลุ่มโบราณสถานแห่งฮัมปี',
#   'การป้องกันค่าว่าง',
#   'สถาบัน',
#   'ยีนออโตโซมเด่น',
#   'โรงพยาบาลพุทธชินราชพิษณุโลก',
#   'กิโกเฟร์เมเนีย',
#   'การปรับตัวต่อการเปลี่ยนแปลงสภาพภูมิอากาศ',
#   'ตีหญ้าให้งูตื่น',
#   'เอชเคทีโฟร์ตีเอต',
#   'มิสแกรนด์จีน',
#   'เตียวก๊ก',
#   'เอ็มเพก',
#   'เครือข่ายสังคมออนไลน์',
#   'มาทิลดาแห่งแฟลนเดิร์สสมเด็จพระราชินีแห่งอังกฤษ',
#   'สามเหลี่ยมกลับรถจักร',
#   'เบซิกตัสจิมนัสติกคูลูบู',
#   'ประธานาธิบดีอียิปต์',
#   'ยุทธการมาร์เก็ตการ์เดน',
#   'ตำบลบางหญ้าแพรก',
#   'โคะโนะมิทะเกะชิ',
#   'อาร์ตติส',
#   'โรงพยาบาลโรงเรียนนายร้อยพระจุลจอมเกล้า',
#   'สางห่า',
#   'รัฐสภาสั้น',
#   'โมรันบ็อง',
#   'แฮหัวฮุย',
#   'สกอตแลนด์ยาร์ด',
#   'บ็อบอาร์มสตรอง',
#   'ม้าลายหัวใจเร็วจิ๊ดด',
#   'บันทึกพระนามแห่งเมดิเนตฮาบู',
#   'ชาลีเอี่ยมกระสินธุ์',
#   'เขตซุมิดะ',
#   'โซราจิฮิเดอากิ',
#   'น้ำตาแสงไต้',
#   'สึเระซูเระชิลเดรน',
#   'ไดโอด',
#   '๒',
#   'สกอตต์บราวน์',
#   'บลิซซาร์ด',
#   'สตีเฟนสเตรนจ์',
#   'เมกีวเลิฟซอง',
#   'เฟรดดี้ไฮร์มอร์',
#   'อนันตปุระสาหิบ',
#   'ออฟสยันนีโควา',
#   'ปังคุง',
#   'คราเคน',
#   'อินทิเกรต',
#   'แอ๊บแซงต์',
#   'สกุลปลาส่อ',
#   'ทิมเคฮิลล์',
#   'โนะโบะรุ',
#   'เจอร์ซี่',
#   'อาร์ชดัชเชสโรสแห่งออสเตรีย',
#   'กีฬาว่ายน้ำในกีฬาคนพิการแห่งชาติ',
#   'เคิสท์',
#   'วันปรีดีพนมยงค์',
#   'วงจรไฟตอน',
#   'ฟินช์',
#   'แคลวินฟิลลิปส์',
#   'ไลต์บอดี',
#   'อียอน',
#   'ฟุตบอลทีมชาติสหรัฐอเมริกา',
#   'เอเชี่ยนมาเชี่ยลอาร์ทเกมส์ครั้งที่',
#   'ช่อห้าพลัง',
#   'บอดี้เมคเกอร์โคลีเซียม',
#   'ควอนตัมดอท',
#   'เทรซครุซชินนาด้า',
#   'เซอร์ชา',
#   'พระเจ้าอะโฮเออิตู',
#   'ป่านทอง',
#   'แซร์บี',
#   'อุตรประเทศ',
#   'ยานลีเชตสกี',
#   'ณรงค์กิตติขจร',
#   'สารานุกรมประเทศจีน',
#   'ชนร่อนเร่',
#   'มอร์แกนแอนด์โค',
#   'พระมหาสมปอง',
#   'ยศทหารกองทัพโซเวียตค',
#   'เอ็มบีทีเอ',
#   'ผักเบี้ยใหญ่',
#   'ตัวดำเนินการโมเมนตัมเชิงมุม',
#   'ตัวอักษรกรีก',
#   'สโมสรฟุตบอลมหาวิทยาลัยนอร์ทกรุงเทพ',
#   'จูบิโลอิวะตะ',
#   'อิสฮักซ์ไซ',
#   '๒๐',
#   'สาธารณรัฐเติร์กเมนิสถานในโอลิมปิกฤดูร้อน',
#   'ทฤษฎีออโตมาตา',
#   'กรุงออตตาวา',
#   'ประเทศฟลานเดอร์',
#   'จอห์นนีเลเวอร์',
#   'กริสโตฟาโน',
#   'ราชอาณาจักรแฟรงค์ตะวันตก',
#   'การเลือกตั้งทั่วไปเซ็มบัตสึบีเอ็นเคโฟร์ตีเอต',
#   'กล้องโทรทรรศน์สึบารุ',
#   'นาโอมิโอโซระ',
#   'มุสตาฟาเคมาลอตาเติร์ก',
#   'รัสต์อินพีซ',
#   'วาลวีชนี',
#   'ถนนเลียบเนิน',
#   'สึกูบะ',
#   'โยะเซะอิ',
#   'เนเบตธิอา',
#   'บัตเตอร์นัทสควอช',
#   'หอยทากจอมซิ่งสายฟ้า',
#   'ซางยาง',
#   'หินเธาว์',
#   'ฮัว',
#   'นักฟุตบอลแห่งปีของสมาคมผู้สื่อข่าวฟุตบอล',
#   'ธาตุไฟ',
#   'พิอาจิโอ',
#   'ลาบูม',
#   'ชนเบอร์เบอร์',
#   'อ๊อดคีรีบูน',
#   'การระดมยิงคาโงชิมะ',
#   'ซอยข้าใครอย่าแตะ',
#   'ตู้ซ่อนผี',
#   'แดนมหัศจรรย์',
#   'พันล้านปี',
#   'ปลาไข่อองเล็ก',
#   'เบงคลูรู',
#   'อัลฟาโรเมโอ',
#   'อาเลกซียาเกอรุตซาชู',
#   'เขตบางกอกใหญ่',
#   'อันวัร',
#   'คโลนาซาแปม',
#   'ซิเบรียน',
#   'ขวัญจิต',
#   'ดัชชีนอร์ม็องดี',
#   'อาร์มีนีอาบีเลอเฟ็ลท์',
#   'ฮงยุนซอง',
#   'หนังสือพิมพ์คมชัดลึก',
#   'สุดาวรรณ',
#   'แก้วพนมวันณอยุธยา',
#   'คริสเตนวิก',
#   'วงศ์ปลาลิ้นหมาตาข้างขวา',
#   'แบบจำลองเทคนิคัลเลอร์',
#   'ผู้กล่าวคำปฏิญาณตนในพิธีเปิดกีฬาโอลิมปิก',
#   'ศาสนาพุทธในประเทศจีน',
#   'โรเบิร์ตชูมันน์',
#   'อิบันเปเรซ',
#   'หัตถ์จักรพรรดิ',
#   'เป็นโดโป',
#   'เอลิซาเบทเทย์เลอร์',
#   'อุเทนเตชะไพบูลย์',
#   'สไปรท์',
#   'องค์ประกัน',
#   'ปลัดทบวงทหารอากาศสหรัฐ',
#   'การละหมาด',
#   'เบร์เกต์ซูเปอร์เอตังดาร์ท',
#   'ธนาชะนะบุตร',
#   'วิทยากรเชียงกูล',
#   'คนตัดคนภาคพิเศษตอนกำเนิดเกาจิ้ง',
#   'ทิวเขารูเวนซอรี',
#   'เฮดโค้ช',
#   'นุ้ย',
#   'ดอกเตอร์โรแมนติก',
#   'หมวยจิ้นดิ้นก้องโลก',
#   'ทางน้ำโค้งตวัด',
#   'เลอมวน',
#   'วัดปทุมวารี',
#   'เพลงของเซลีน',
#   'วัดเมืองปอน',
#   'รับคำท้าจากพระเจ้า',
#   'ทากาโกะชิมาซุ',
#   'โนะบุยุคิ',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศปาปัวนิวกินี',
#   'หรุ่นเริงรมย์',
#   'ประสาทการได้ยิน',
#   'จุดสุดเสียวไทยแลนด์',
#   'โฟลเรียนอโปลิส',
#   'คุมอง',
#   'ไวเปอร์',
#   'โรงเรียนอรุณประดิษฐ',
#   'แอนโกรีไรซ์',
#   'ปูซานเกมส์',
#   'จังหวัดเวนิส',
#   'วงปี่พาทย์ไม้นวม',
#   'เดอะเปี่ยมส์',
#   'ขนมจาก',
#   'นายกรัฐมนตรีจีน',
#   'พระอ่อน',
#   'หูจิ่นเทา',
#   'หลี่อี้เฟิง',
#   'ชีววิทยา',
#   'อาดอลฟ์',
#   'พระเจ้าเจี่ย',
#   'สิ้นสุดทางเพื่อน',
#   'อาณาจักรจ๊ก',
#   'พระซุกบิน',
#   'วีลาร์เดอออนกูร์',
#   'การรับรู้การเคลื่อนไหว',
#   'ศรัณยูวินัยพานิช',
#   'สึมิเระ',
#   'ความตกลงอาเซียนว่าด้วยมลพิษจากหมอกควันข้ามแดน',
#   'พิมพ์',
#   'พระเจ้าฝรั่งมังฆ้อง',
#   'กระสุนยาง',
#   'จินโหย่วจือ',
#   'ขุนคลัง',
#   'นายกรัฐมนตรีกรีซ',
#   'อ่าวอีเดน',
#   'เฮริฮอร์',
#   'การขัดขืนอย่างอารยะ',
#   'ความไวและความจำเพาะ',
#   'ไทแอมเฟนิคอล',
#   'จรินยาอักษรนันทน์',
#   'วรนุชวงศ์สวรรค์',
#   'กีฬากาบัดดีในเอเชียนเกมส์',
#   'ผัดซีอิ้ว',
#   'ดอยท์ชลันด์ลีด',
#   'เฉลิมศักดิ์อักขี',
#   'เดอะโรแมนติกมิวสิคัล',
#   'ประเภทของประชาธิปไตย',
#   'การก่อการกำเริบวอร์ซอ',
#   'ปีเตอร์ซุนเด',
#   'เปิดเทอมไปรบ',
#   'การไม่พูด',
#   'ฆอร์เกราฟาเอลวีเดลา',
#   'ชลอกิตฺติสาโร',
#   'ราชวงศ์ที่สิบสองแห่งอียิปต์',
#   'การจัดการของเสียในประเทศไทย',
#   'อักเสบ',
#   'ประเทศมอลตา',
#   'ประเทศกายอานา',
#   'คณะผู้แทนทางการทูตของประเทศตองกา',
#   'สโมสรวอลเล่ย์บอลนครราชสีมา',
#   'นิกิติน',
#   'อักเนสโยอาควิม',
#   'โฮลดิ้งส์',
#   'ประชาบูรณธนิต',
#   'ออทโทเฮิลเดอร์',
#   'พระองค์เจ้าชุมพลสมโภช',
#   'ข้าวหมูสับ',
#   'สภานิติบัญญัติกวม',
#   'ซาราบาเรลลิส',
#   'ปลาพรม',
#   'กุล',
#   'ไมโครซอฟท์ออฟฟิศ',
#   'ทางเดินปัสสาวะ',
#   'พระปัจเจกพุทธเจ้า',
#   'ด้วงกว่างสามเขาเขาใหญ่',
#   'สมเด็จพระเจ้าลูกเธอพระนารายณ์ราชกุมาร',
#   'อาร์คดัชเชสโมนิก้าแห่งออสเตรีย',
#   'สุลต่านอัรเราะชีดแห่งโมร็อกโก',
#   'พระราชพงศาวดารกรุงเก่าฉบับหลวงประเสริฐอักษรนิติ์',
#   'โยชิกาวะ',
#   'เชอร์รีเมจิกถ้า',
#   'วิลายาเนอซับรามาเนียนรามจันทร์',
#   'น่วมเศรษฐจันทร',
#   'เหตุเรือข้ามฟากเกาหลีใต้พลิกคว่ำ',
#   'วัดสุปัฏนารามวรวิหาร',
#   'ฮูลิโอ',
#   'ฉบับการ์ตูน',
#   'ศาลเจ้าสึรูงาโอกะฮาจิมัง',
#   'ไบรอันต์',
#   'วัดอู่ทรายคำ',
#   'บลูทั้งค์',
#   'การตั้งครรภ์ไข่ปลาอุก',
#   'เดอะเวิร์ก',
#   'กลุ่มภาคใต้',
#   'ปทุม',
#   'หัตถ์เทวดา',
#   'หม้อหุงข้าว',
#   'ยิตส์ฮัก',
#   'ชื่อบุคคลพม่า',
#   'บรูโนมาร์ตินส์อินดี',
#   'แม่น้ำดูโร',
#   'พยางค์เปิด',
#   'ต่อมใต้สมอง',
#   'นะงะเระยะมะ',
#   'นีลา',
#   'ติ๊กกัญญารัตน์',
#   'เงามรณะ',
#   '๒๘มกราคม',
#   'เจลล้างมือ',
#   'โมนีคาฟอนฮับส์บวร์ค',
#   'การแยกความเชื่อออกเป็นสองขั้ว',
#   'แอควิเทเนีย',
#   'โบสถ์ยิวยูบิแลอุม',
#   'ณภัทร',
#   'อำนวยจนฺทสโร',
#   'อุบัติการณ์สุสานโกเบงเหลง',
#   'อาโอคิกาฮาระ',
#   'การเลือกตั้งสมาชิกสภากรุงเทพมหานคร',
#   'มะซะรุ',
#   'อับดุลนาเซร์',
#   'กริตติ',
#   'สจวร์ตแฟนซี',
#   'บุปผา',
#   'คาโรลัสลินเนียส',
#   'จอห์นเฮอร์เชล',
#   'เย็ชช็อนเน็ค',
#   'ระวีกิ่งคำวงศ์',
#   'เทศบาลเมืองปากแพรก',
#   'โรงเรียนรัชชประภาวิทยาคม',
#   'พีเอทีเอช',
#   'ปูบก',
#   'มุกตะดาอัศศ็อดรฺ',
#   'การหมุนรอบตัวเอง',
#   'พระเจ้าบรมวงศ์เธอพระองค์เจ้าประไพศรีสอาด',
#   'อาร์ชดัชเชสโรซาแห่งออสเตรีย',
#   'โมเดิร์นไลฟ์อิสรับบีซ',
#   'กะอฺบะฮฺ',
#   'เซล',
#   'น้องหมวยก่อเกียรติยิม',
#   'ประเทศอาร์มีเนียในโอลิมปิกเยาวชน',
#   'อัมเพิลเม็นเชิน',
#   'ลีแดย็อง',
#   'เกบนีเวลล์',
#   'อลิเชีย',
#   'เพอรอกซิโซม',
#   'ยึมกิจจแส',
#   'ยายาซูมาโฮโร',
#   'สมเด็จช่วง',
#   'เรเน่เดอซาเยียร์',
#   'ตราบุรฉัตร',
#   'คาซึยะคาเมนาชิ',
#   'ทะเลคารา',
#   'ปริยะวิมลโนช',
#   'สวยพิฆาต',
#   'การกลั่นทำลาย',
#   'คันนิ่งแฮม',
#   'อัลอัดวะฮ์',
#   'หาดคุจูคุริ',
#   'วิทยาการทำอาหาร',
#   'บาบิโลนซู',
#   'ธัมมิกประชาธิปไตย',
#   'วัดพลับพลา',
#   'โซลิงเงิน',
#   'เพอร์วาฮาเอนเอลฤดูกาล',
#   'แขวงโนยังจิน',
#   'หม่อมราชวงศ์จันทร์แรมศิริโชค',
#   'พระจงพุทธสโร',
#   'เซาเปาลูอารีน่า',
#   'โมหิณี',
#   'คลีโอพัตรา',
#   'ซาโต',
#   'เก็ตซัลโกอาตล์',
#   'บูกิตเมอระฮ์',
#   'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#   'ระเบิดเวลา',
#   'ดิลิเชียส',
#   'โบฮัน',
#   'หลุยส์แห่งออร์เลอ็องสมเด็จพระราชินีแห่งสเปน',
#   'สมมาสราชสีมา',
#   'อิโยะสกาย',
#   'ขีปนาวุธร่อน',
#   'อาร์ชดัชเชสมาเรียคาโรลีเนอแห่งออสเตรีย',
#   'ปาเตรีย',
#   'เบ็กแฮม',
#   'อักษรสรทะ',
#   'ชีล่า',
#   'แรคำประโดยคำ',
#   'กริตวิเคน',
#   'คายัค',
#   'ความหนาแน่นวิกฤต',
#   'ริวเฮ',
#   'หมู่เกาะอาลิวเชียน',
#   'เบนแจมิน',
#   'กาฌัก',
#   'สฐิรพงษ์อาจหาญ',
#   'ซูเกชิโระ',
#   'ฮิวจ์แจ็คแมน',
#   'มิดเดิลเวท',
#   'นาราชา',
#   'ศิลปชัยชาญเฉลิม',
#   'อานนท์สายแสงจันทร์',
#   'กริสเตียนดากีโอ',
#   'บัลโฟร์',
#   'จดหมายเหตุบางกอก',
#   'นีเดอร์ไบเอิร์น',
#   'โจบานี',
#   'รณฤทธิชัย',
#   'อิเคดะเทรุมาสะ',
#   'หม่อมเจ้าสุมณีนงเยาว์ดิศกุล',
#   'ชินโนะสึเกะทาจิบานะ',
#   'กากาอูซียา',
#   'ราชอาณาจักรอาร์ลส์',
#   'วินิเชียส',
#   'ฟลีกีอัส',
#   'เรย์มิลแลนด์',
#   'สุเทพวงศ์คำแหง',
#   'โชมองต์',
#   'กีฬายิมนาสติกในซีเกมส์',
#   'โครแอทและเซิร์บ',
#   'ซูบารุชิบูตานิ',
#   'เจ็ทลี',
#   'ออกัสตัสฟิทซ์รอยดยุกที่',
#   'เมืองฟ้าเล็ก',
#   'แอเวร์ตง',
#   'เขตมิสซังจันทบุรี',
#   'วินิจเลิศรัตนชัย',
#   'สถาบันมะเร็งดยุค',
#   'ดีแล็ป',
#   'มหิดลอดุลยเดช',
#   'สาธุ',
#   'ฉางเอ๋อ',
#   'เรืออูต่างด้าว',
#   'อันดรีย์กลัชเชนโก',
#   'วอตช์โอเอส',
#   'เจ้าหญิงกาโรลีนเจ้าหญิงแห่งฮาโนเวอร์',
#   'พระองค์เจ้าประภา',
#   'ผ้าคลุมหน้า',
#   'ฮอกรี',
#   'สะพานช่องนนทรี',
#   'ลดาวัลลิ์',
#   'เป้ย',
#   'จังหวัดคันลูรังเนโกรส',
#   'พระราชอาณาจักรไทย',
#   'สิงห์นักปั่น',
#   'การเขียนคำทับศัพท์ภาษาอิตาลี',
#   'การควบคุมทางวิทยาศาสตร์',
#   'ฝ่ายค้านในสภาผู้แทนราษฎร',
#   'ยิชรีบอม',
#   'เปแปงเดอะชอร์ท',
#   'แม่น้ำจนาพ',
#   'พงษ์มณี',
#   'ปลากดขี้ลิง',
#   'มักกะห์',
#   'ออนอเรฟรากอนาร์',
#   'อุณหภูมิกายต่ำผิดปกติ',
#   'มูย',
#   'โยะชิซะวะฮิโตะมิ',
#   'โปลิเทคนิคลานนา',
#   'เอ็กซ์แอลสเต็ป',
#   'หริทวาระ',
#   'ไซโคอะคูสติกส์',
#   'เซแด็ส',
#   'เรชาดีแยมาร์ชือ',
#   'แคมป์เบิล',
#   'รถไฟฟ้าปารีสสาย',
#   'คำนาม',
#   'ฟังก์ร็อก',
#   'สเตฟานเซสเซยง',
#   'เทศบาลเมืองบัวขาว',
#   'ธัญสกพันสิทธิวรกุล',
#   'มินิชิงกันเซ็ง',
#   'วันวินจ',
#   'จังหวัดบามียาน',
#   'เบเคตอาเตน',
#   'ณัฐพงษ์สุปริยศิลป์',
#   'ค่างหัวมงกุฎ',
#   'โทรทัศน์ความคมชัดสูง',
#   'เหตุการณ์รถตู้สาธารณะถูกชนบนทางยกระดับอุตราภิมุข',
#   'รัฐสภานิวแคลิโดเนีย',
#   'วิทยาลัยอินเตอร์เทคลำปาง',
#   'บักติยารี',
#   'น้ำตกดอยหมอก',
#   'ตรันหญ่ายกว่าง',
#   'เสียงปล่อยโดยหู',
#   'อเล็กซานดราแห่งบาเดิน',
#   'ลัทธิสมัยใหม่นิยม',
#   'การปะทุของเขาตัมโบราค',
#   'เบนิโต',
#   'ซูกห์บายาร์',
#   'เจเจฟิลด์',
#   'ยุทธพงษ์ศรีละคร',
#   'พระเหมกเถระ',
#   'การขนส่งระบบรางในประเทศญี่ปุ่น',
#   'ยูเชนีในบาวาเรีย',
#   'เนลลี่',
#   'คิมเมล',
#   'เซลติกพาร์ค',
#   'สมเด็จพระราชินีแห่งฮังการี',
#   'บุญยรัตกลิน',
#   'เกรจวาเลนไทน์',
#   'พงษ์ปุณณกันต์',
#   'คุรุอังคัท',
#   'มหาวิหารเซนต์เบซิล',
#   'วัดนางเหล้า',
#   'ม่วงเจริญ',
#   'ซิสเตอเรียน',
#   'ชาวเบงกอลี',
#   'เอ็กเบิร์ตกษัตริย์แห่งเวสเซ็กซ์',
#   'เต่าร้างยักษ์',
#   'อรรถกรศิริลัทธยากร',
#   'การ์ธนิกซ์',
#   'ธนชาติ',
#   'ฟิสต์ออฟเดอะนอร์ทสตาร์',
#   'คลองสนามชัย',
#   'ชูนาครห์',
#   'ฮูกุมกานุนปาฮัง',
#   'เจ้าหญิงเฟริยาล',
#   'เคานต์',
#   'โกโดยสายการบินโอเรียนท์ไทยแอร์ไลน์',
#   'อนิจจลักษณะ',
#   'บรัก',
#   'ท่าอากาศยานนานาชาติเจิ้งโจวซินเจิ้ง',
#   'รัตนพรชัย',
#   'ท่าอากาศยานนานาชาติเศาะลาละฮ์',
#   'ลัลณ์ลลินเตจะสาเวศซ์',
#   'ศูนย์แพทยศาสตรศึกษาชั้นคลินิกโรงพยาบาลเจ้าพระยาอภัยภูเบศร',
#   'พีเอ็ม',
#   'แชงการ์',
#   'ข้ออักเสบรูมาตอยด์ในเด็ก',
#   'คอร์บูซิเอ',
#   'วัดเสด็จปทุมธานี',
#   'ท่าอากาศยานนานาชาติคาบูล',
#   'เฟสห้า',
#   'ชีปอลาตา',
#   'เหมะมูล',
#   'รถถังขนาดกลาง',
#   'การค้าปลีก',
#   'ฉัตรโชติกเสถียร',
#   'มูโซ',
#   'ศิริวัฒน์สิริวฑฺฒโน',
#   'ซีมันตรินี',
#   'ชเตททิน',
#   'มิสซิสยูนิเวิร์สไทยแลนด์',
#   'รถไฟฟ้าเฉลิมพระเกียรตื',
#   'กวางซู',
#   'ชาลส์บรอนสัน',
#   'โชคชัย',
#   'โครงการสิ่งแวดล้อมแห่งสหประชาชาติ',
#   'อัสมีร์',
#   'นายกรัฐมนตรีแห่งสหราชอาณาจักร',
#   'ซินจู๋',
#   'พิคาชูส์แอดเวนเจอร์',
#   'พระภูมิเจ้าที่',
#   'ฮาเซะ',
#   'ศรายุทธสมพิมพ์',
#   'แก้วใส',
#   'ประชาบดีโคตมี',
#   'เลฌียงโดเนอร์',
#   'ราชวงศ์โอกกากะ',
#   'โกลเด้นไชล์ด',
#   'โตกุกาวะอิเอยาสุ',
#   'แฮร์โรลด์',
#   'ฝั่งทะเลบาร์บารี',
#   'ไพรัตน์เดชะรินทร์',
#   'อเวนจ์',
#   'วายร้ายหัวใจฮีโร่',
#   'คอนแสตนติอัสคลอรัส',
#   'สถานีรถไฟถนนฟินเดอร์',
#   'อริญากร',
#   'เดอะจีโอเมเตอส์สเกตช์แพด',
#   'ณปภาตันตระกูล',
#   'ทอมชทาร์เคอ',
#   'พระอัครชายาเธอพระองค์เจ้าสายสวลีภิรมย์กรมขุนสุทธาสินีนาฏ',
#   'วัดสังกัสรัตนคีรี',
#   'กอ',
#   'เกลแบร์',
#   'ฌูลรีเม',
#   'บัญชีรายชื่อดาวฤกษ์ของสมาคมดาราศาสตร์',
#   'ออริกาโน',
#   'วัดนางนอง',
#   'อัลกอร์',
#   'อิลเลีย',
#   'อีออน',
#   'แบเรียมเปอร์ออกไซด์',
#   'สงครามแอลจีเรีย',
#   'แนชั่นแนลเรสต์ลิงแอไลแอนซ์',
#   'ดนตรีคลาสสิค',
#   'กีฬาซอฟต์เทนนิสในกีฬาแห่งชาติ',
#   'มาซิโดเนียโบราณ',
#   'เจ้าหญิงคริสตีนาแห่งเนเธอร์แลนด์',
#   'ไฮเมเนียส',
#   'บารอเนต',
#   'ครูบ้านนอกบ้านหนองฮีใหญ่',
#   'การแร็ป',
#   'วัดธรรมสถิติ์วราราม',
#   'การทับศัพท์ตามระบบของราชบัณฑิตยสถาน',
#   '๘๔',
#   'คุประตกุล',
#   'สำนักงานกองทุนสนับสนุนการวิจัย',
#   'ลิลี่โรช์ฟอร์ต',
#   'สินเชื่อซับไพรม์',
#   'วงรอบซารอส',
#   'วัดเวฬุราชิณ',
#   'มิเชลล์ไฟเฟอร์',
#   'การกดภูมิคุ้มกัน',
#   'โรคกลัวที่โล่ง',
#   'เจอรัลด์ฟอร์ด',
#   'การประยุกต์ใช้สภาพนำยวดยิ่ง',
#   'ฟาโรห์เตติ',
#   'วัดโฮรีวจิ',
#   'เจเจโปรเจกต์',
#   'เบลีซ',
#   'เฮนเบน',
#   'ฟิชสปา',
#   'ผู้ใคร่เด็ก',
#   'ลำใย',
#   'เทพปกรณัม',
#   'กระทรวงโครงสร้างพื้นฐานและการบริหารจัดการน้ำ',
#   'ตอนคิตตี้กาลอร์ล้างแค้น',
#   'วอลเลย์บอลเยาวชนหญิงชิงแชมป์อาเซียนครั้งที่',
#   'อาสนวิหารอัสสัมชัญ',
#   'แคเธอรินแห่งวาลัว',
#   'ไมโครเลนส์ของแรงโน้มถ่วง',
#   'แฝดคนละฝาของอันนะซัง',
#   'ปภทพรศิริรักษ์นภา',
#   'ถนนนักสู้',
#   'ร็อคกี้',
#   'สัลเลขนา',
#   'โซชิเอตัสยูโรเปอา',
#   'อาเซอร์ไบจานแอร์ไลน์',
#   'การคุกเข่าของวิลลี',
#   'พันธุ์ฤทธิ์',
#   'ปลาม้ามังกร',
#   'วาฬบาลีน',
#   'วังจะบังตีกอ',
#   'แอปโซลูท',
#   'โรงพยาบาลนครธน',
#   'สุมิตราสุจริตกุล',
#   'ผู้ชายรักร่วมเพศ',
#   'พุทธชยันตี',
#   'การปะทุของภูเขาไฟฟุจิปีโฮเอ',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 5483

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['พระมหากษัตริย์ในปรัสเซีย',
#  'แผ่นดินไหวและคลื่นสึนามิในมหาสมุทรอินเดีย',
#  'โฆษณาชวนเชื่อในนาซีเยอรมนี',
#  'คอเลสเตอรอลในเลือดแบบไม่ดี',
#  'ประเทศอิสราเอลในเอเชียนเกมส์',
#  'วันหยุดในประเทศลัตเวีย',
#  'โรงเรียนอุบลรัตนราชกัญญาราชวิทยาลัยนครปฐมในพระอุปถัมภ์',
#  'ลัทธิเต๋าในเกาหลี',
#  'หมายเลขโทรศัพท์ในประเทศตองงา',
#  'ประเทศโรมาเนียในพาราลิมปิกฤดูร้อน',
#  'ในจักรพรรดิซ่งฮุ่ยจง',
#  'การอพยพในสหภาพโซเวียต',
#  'ธงในประเทศญี่ปุ่น',
#  'ในสมเด็จพระบรมโอรสาธิราชฯ',
#  'ฟุตซอลในซีเกมส์',
#  'จักรพรรดินีเหรินหูไอในจักรพรรดิซ่งชินจง',
#  'หลักความสอดคล้องในตัวเองของนาฟวิคัฟ',
#  'ดัชเชสเฮ็ลเลนาอ็อยเกเนียในบาวาเรีย',
#  'การประท้วงต่อต้านรัฐบาลในพม่า',
#  'การเคลื่อนที่ในรอบวัน',
#  'เหตุการณ์สำคัญในสมัยกรุงศรีอยุธยา',
#  'กีฬาปันจักสีลัตในกีฬาแห่งชาติครั้งที่',
#  'สตรีในประเทศสิงคโปร์',
#  'เขตในประเทศอินเดีย',
#  'ลัทธิจักรวรรดินิยมในเอเชีย',
#  'ตำแหน่งฝ่ายใน',
#  'ธงในประเทศเบลเยียม',
#  'ดอกไม้ในใจ',
#  'การรบในตูนีเซีย',
#  'สมาคมสถาปนิกสยามในพระบรมราชูปถัมภ์',
#  'การประมวลผลให้เป็นความกลัวในสมอง',
#  'โฆษณาชวนเชื่อในประเทศญี่ปุ่น',
#  'การปราบปรามคอมมิวนิสต์ในประเทศไทย',
#  'กีฬากีฬาทางอากาศในกีฬาแห่งชาติครั้งที่',
#  'กรีฑาในซีเกมส์',
#  'การเข้าแทรกแซงของสหรัฐอเมริกาในชิลี',
#  'แผ่นดินไหวและคลื่นสึนามิในอูนเซน',
#  'สัตว์ในตำนาน',
#  'การทำงานในสมองกับการนั่งสมาธิ',
#  'ในประเทศอังกฤษ',
#  'สิทธิมนุษยชนในประเทศกัมพูชา',
#  'เจ้าจอมหม่อมราชวงศ์เฉียดในรัชกาลที่',
#  'ตัวละครในจีทีโอ',
#  'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดขอนแก่น',
#  'แผ่นดินไหวในมณทลยูนนาน',
#  'ประเทศไนเจอร์ในพาราลิมปิกฤดูร้อน',
#  'พินทุในความหมายทางศาสนา',
#  'กีฬาเซปักตะกร้อในกีฬาแห่งชาติ',
#  'ฝุ่นควันในเอเชียตะวันออกเฉียงใต้ค',
#  'ในสหภาพโซเวียต',
#  'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดกาฬสินธุ์',
#  'มรดกโลกในประเทศกัมพูชา',
#  'การโจมตีด้วยขีปนาวุธในอูมัญ',
#  'สาธารณรัฐมองโกเลียในเอเชียนเกมส์',
#  'กีฬาซอฟท์เทนนิสในกีฬาแห่งชาติครั้งที่',
#  'ความหลากหลายทางชีวภาพในประเทศลาว',
#  'การเลือกตั้งประธานาธิบดีสหรัฐในรัฐแคลิฟอร์เนีย',
#  'ฝ่ายค้านในรัฐสภา',
#  'ลูกเสือและเนตรนารีในกัมพูชา',
#  'แวมไพร์ในสวน',
#  'การฆาตกรรมหมู่ในนครชิคาโกด้วยยาไทลินอล',
#  'บันทึกรักในเมืองเล็ก',
#  'อุทยานประวัติศาสตร์ในประเทศไทย',
#  'อุทกภัยจากธารน้ำแข็งแตกในรัฐอุตตราขัณฑ์',
#  'แผ่นดินไหวในจังหวัดนีงาตะค',
#  'ความอดอยากครั้งใหญ่ในไอร์แลนด์',
#  'ความลำเอียงทางคตินิยมในวิกิพีเดีย',
#  'โรงเรียนสตรีวิทยา๒ในพระราชูปถัมภ์สมเด็จพระศรีนครินทราบรมราชชนนี',
#  'ตัวละครสำคัญในอาณาจักรแห่งกาลเวลา',
#  'ธงในกองทัพรัสเซีย',
#  'แนวฟันในหิน',
#  'ประเทศเคนยาในพาราลิมปิกฤดูร้อน',
#  'เหตุเพลิงไหม้โกดังเก็บวิสกี้ในดับลิน',
#  'ศาสนาพุทธในประเทศกัมพูชา',
#  'ตัวละครอื่นในลอร์ดออฟเดอะริงส์',
#  'อุทกภัยและดินถล่มในภาคใต้',
#  'การระบาดของโคโรนาไวรัสในประเทศอิตาลี',
#  'การท่องเที่ยวในกรุงเทพมหานคร',
#  'กีฬากีฬาเอ็กซ์ตรีมในกีฬาแห่งชาติครั้งที่',
#  'ศาสนาอิสลามในประเทศมาเลเซีย',
#  'สนามบินในประเทศไทย',
#  'เจ้าจอมมารดาเขียนในรัชกาลที่',
#  'โซเวียตในเบรสท์',
#  'ปลายอุโมงค์แห่งคำบอกลาในหน้าร้อน',
#  'กีฬาจักรยานในซีเกมส์',
#  'สงครามในดอนบัส',
#  'มุมปากตกขณะร้องไห้ในทารก',
#  'ติดเชื้อราในหู',
#  'พระวรชายาในเจ้าชายทะกะฮิโตะ',
#  'ข้อกล่าวหาการทุจริตในโครงการก่อสร้างท่าอากาศยานสุวรรณภูมิ',
#  'เหตุกราดยิงโบสถ์ในซัตเทอร์แลนด์สปริงส์',
#  'สัตว์ประหลาดในแฟรนไชส์เอเลี่ยน',
#  'ความหลากหลายทางชีวภาพในประเทศบอตสวานา',
#  'ประเทศบาร์เบโดสในแพนอเมริกันเกมส์',
#  'ภาวะความดันเลือดในปอดสูงในทารกแรกเกิด',
#  'ราชอาณาจักรบาห์เรนในเอเชียนเกมส์',
#  'หนังสือพิมพ์ในประเทศไทย',
#  'สถาปัตยกรรมภายใน',
#  'พระนามทรงกรมของพระราชโอรสพระราชธิดาในรัชกาลที่๕',
#  'การขนส่งระบบรางในประเทศญี่ปุ่น']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 5108

# %%
get_samples(nai)
# Out:
# ['กีฬาบาสเก็ตบอลในกีฬาแห่งชาติครั้งที่',
#  'เหตุเรือบรรทุกน้ำตาลล่มในแม่น้ำเจ้าพระยา',
#  'การลงประชามติสนธิสัญญามาสทริชต์ในฝรั่งเศส',
#  'พระราชโอรสในฟาโรห์สเนฟรู',
#  'อัมพาตเป็นระยะจากโพแทสเซียมในเลือดต่ำเกิน',
#  'ตราแผ่นดินในทวีปโอเชียเนีย',
#  'การตั้งครรภ์ในช่องท้อง',
#  'กีฬารักบี้ในเอเชียนเกมส์',
#  'การใช้ถ้อยคำในธุลีปริศนา',
#  'ภาวะกรดมาโลนิกและกรดเมทิลมาโลนิกในปัสสาวะ',
#  'โรงเรียนราชประชาสมาสัยฝ่ายมัธยมรัชดาภิเษกในพระบรมราชูปถัมภ์',
#  'ฮีโมโกลบินในเม็ดเลือดเฉลี่ย',
#  'เจ้าจอมแจ่มในรัชกาลที่',
#  'ในประเทศอียิปต์',
#  'หลอดเลือดอุดตันในปอด',
#  'สตรีในประเทศสิงคโปร์',
#  'พิธีสารเลือกรับเรื่องความเกี่ยวพันของเด็กในความขัดแย้งกันด้วยอาวุธ',
#  'วิดีโอเกมในประเทศไทย',
#  'โปโลในซีเกมส์ค',
#  'พระราชพิธีทวีธาภิเษกในรัชกาลที่',
#  'ช็อกจากการติดเชื้อในกระแสเลือด',
#  'การท่องเที่ยวในประเทศอุรุกวัย',
#  'ภาพยนตร์ในปี',
#  'และพื้นที่ภาษาในประเทศเบลเยียม',
#  'จังหวัดในประเทศเกาหลีใต้',
#  'และจวนตระกูลขงในชฺวีฟู่',
#  'เจ้าจอมอิ่มย่าหรันในรัชกาลที่',
#  'เจ้าจอมมารดาสุดในรัชกาลที่',
#  'ในประเทศสเปน',
#  'สภาใน',
#  'เวลาในประเทศเลบานอน',
#  'เจ้าจอมช้อยในรัชกาลที่',
#  'ตัวละครในแขนกล',
#  'เหตุโจมตีในจาการ์ตา',
#  'เขตผู้ว่าราชการในประเทศจอร์แดน',
#  'ประเทศอิหร่านในเอเชียนเกมส์',
#  'พืชพันธุ์ในประเทศมาซิโดเนียเหนือ',
#  'ลิ่มเลือดในหลอดเลือดดำสมอง',
#  'ตัวละครในวัยซนคนการ์ตูน',
#  'การทำลายป่าในประเทศกัมพูชา',
#  'เหตุเพลิงไหม้อาคารสูงในเกาสฺยง',
#  'พระตำหนักในพระราชวังดุสิต',
#  'เหตุการณ์การสูญพันธุ์ในยุคครีเทเชียส',
#  'เมืองในประเทศลาว',
#  'ประเทศอิรักในเอเชียนบีชเกมส์',
#  'ลำดับเวลาในแฮร์รี่',
#  'ทางหลวงที่ยาวที่สุดในประเทศไทย',
#  'เจ้าจอมมารดานุ้ยใหญ่ในรัชกาลที่',
#  'วันหยุดในประเทศบรูไน',
#  'สิทธิของกลุ่มบุคคลที่มีความหลากหลายทางเพศในประเทศไทย',
#  'ผู้กล้าในตำนาน',
#  'แก๊สในลำไส้',
#  'กีฬากาบัดดี้ในเอเชียนเกมส์',
#  'มะเร็งในวัยเด็ก',
#  'วันหยุดในประเทศพม่า',
#  'แผ่นดินไหวในจังหวัดคูมาโมโตะ',
#  'ในประเทศอิตาลี',
#  'พื้นที่สงวนชีวมณฑลโลกในประเทศไทย',
#  'ประเทศอารูบาในแพนอเมริกันเกมส์',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศแอฟริกาใต้',
#  'การศึกษาในลาว',
#  'สิทธิมนุษยชนในสหภาพโซเวียต',
#  'จังหวัดในประเทศไทย',
#  'อากาศยานในราชการไทย',
#  'ในประเทศญี่ปุ่น',
#  'ตำหนิในงานเชื่อม',
#  'จักรวรรดิจีนยืนยงในจักรวาลอย่างกล้าหาญ',
#  'แผ่นดินไหวในไครสต์เชิร์ช',
#  'บั๊คโรเจอร์มนุษย์ในศตวรรษที่',
#  'โทรทัศน์ในสหรัฐอเมริกา',
#  'กีฬาอควาธลอนในเวิลด์บีชเกมส์',
#  'ความขัดแย้งในประเทศซูดาน',
#  'สาธารณรัฐประชาธิปไตยประชาชนเกาหลีในเอเชียนเกมส์',
#  'ตัวละครในสแลมดังก์',
#  'กลุ่มโรงเรียนในเครือบดินทรเดชา',
#  'รถรางในเวียนนา',
#  'การระบาดของอาการเยื่อหุ้มสมองอักเสบในแอฟริกาตะวันตกค',
#  'ทางด่วนในประเทศอินเดีย',
#  'เปอร์โตริโกในแพนอเมริกันเกมส์',
#  'เจ้าหญิงโนบุโกะพระชายาในเจ้าชายโทโมฮิโตะ',
#  'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชา',
#  'ในพระบรมราชูปถัมภ์',
#  'หวังในธรรม',
#  'วัดบางเตยใน',
#  'ระบบสองพรรคการเมืองในประเทศไทย',
#  'ในสมเด็จพระบวรราชเจ้ามหาเสนานุรักษ์',
#  'ศาสนาพุทธในประเทศยูเครน',
#  'นิวเคลียสในสมอง',
#  'จังหวัดนราธิวาสในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'กฎผลรวมในการหาอนุพันธ์',
#  'ทุพภิกขภัยครั้งใหญ่ในไอร์แลนด์',
#  'การเรียกร้องให้บัญญัติศาสนาพุทธเป็นศาสนาประจำชาติในรัฐธรรมนูญแห่งราชอาณาจักรไทย',
#  'การจัดการสตริงในภาษาซี',
#  'สื่อลามกอนาจารในอินเตอร์เน็ต',
#  'อัตราส่วนความสามารถในการจ่ายดอกเบี้ย',
#  'รัฐเดลาแวร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรค',
#  'กีฬาซอฟต์บอลในกีฬาแห่งชาติครั้งที่',
#  'ศาลอาญาระหว่างประเทศในอดีตยูโกสลาเวีย',
#  'กีฬาซอฟท์เทนนิสในซีเกมส์',
#  'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป']

# %% [markdown]
# Most of these are still non-named-entity
#
# Seems to be difficult to get named-entity title...
#
# Exclude all "ใน"
#
# **HELP NEEDED**

# %%
titles = set([title for title in titles if "ใน" not in title])

get_len(titles)
# Out:
# current: 293408
# diff: -7089

# %%
get_samples(titles)
# Out:
# ['โทโฮกุซุนโกะ',
#  'หันตรีบาร์นี',
#  'อาร์มองด์',
#  'ฌูลส์รีเมต์',
#  'ดับเบิลยูดับเบิลยูอีซูเปอร์โชว์',
#  'ถนัดศรี',
#  'มีแชลเดอเบร',
#  'ปลาหมึกจัมโบ้',
#  'ซุนดาน',
#  'ลินเนิร์ดสกินเนิร์ด',
#  'โอมาฮา',
#  'แคทีเลียง',
#  'สโมสรฟุตบอลโรงเรียนกีฬาเทศบาลนครนครราชสีมา',
#  'การ์ปัชโช',
#  'แกตา',
#  'หม่อมเจ้าคัสตาวัส',
#  'ฮานะโนะเอน',
#  'ไฮน์ริชกุสทัฟมักนุส',
#  'ถิรชัยอ',
#  'อนุภาคพระเจ้า',
#  'อะเล็กซานเดอร์ปุชกิน',
#  'อาม็อกเตร็ย',
#  'พินัยกรรม',
#  'เสฎฐวุฒิ',
#  'มึนส์เทอร์',
#  'โรคอารมณ์สองขั้วเป็นสเปกตรัม',
#  'เอริชฮาร์ทมัน',
#  'ฮอสเซน',
#  'ศรีวราห์',
#  'แครา',
#  'วัดถ้ำกลองเพล',
#  'หงส์กู่',
#  'วัดท้องคุ้ง',
#  'รหัสทางภูมิศาสตร์',
#  'เซฟโปรซิล',
#  'เกราร์ดปิเก',
#  'ถุงหุ้มข้อไหล่อักเสบยึดติด',
#  'พระบวรราชวัง',
#  'จอห์นโตแช็ก',
#  'มงต์โซโร',
#  'จิระพันธิ์',
#  'ปูลุงจี',
#  'อมรินทร์ทีวี',
#  'ปืนสั้นอัดลม',
#  'เอาเตอร์เฮบริดีส',
#  'โอซาโกะ',
#  'เอ็ดเวิร์ดเจ้าชายดำ',
#  'ดยุกแห่งกัลลิเอรา',
#  'พริษฐ์วัชรสินธุ',
#  'ภูเขาโทกาจิ',
#  'เจ้าชายเอากุสท์วิลเฮ็ล์มแห่งปรัสเซีย',
#  'ชาวอเมริกันเชื้อสายไทย',
#  'แลงเกวจ',
#  'เตอูเบ',
#  'องค์การบริหารส่วนตำบลท่าไร่',
#  'อมรินทร์ทีวีเอชดี',
#  'สถานีโทรทัศน์ทีวีบี',
#  'ยุกิรุ',
#  'อายูมิอิโต้',
#  'ริยันกาจันทา',
#  'อะคะโฮะชิ',
#  'ชิโนล่า',
#  'ซ่งเสินจง',
#  'จักรพรรดิฮั่นอู่ตี้',
#  'ไทยแลนด์มอเตอร์ไซค์เคิลกรังด์ปรีซ์',
#  'ทารุสุเกะ',
#  'วงศ์โลมามหาสมุทร',
#  'วิดีโอเกมผู้เล่นเดี่ยว',
#  'เพราะรักใช่เปล่า',
#  'วิทยาลัยอาชีวศึกษาร้อยเอ็ด',
#  'การแข่งขันระหว่าง',
#  'ยูสิด',
#  'สถานีผิงกั่วหยวน',
#  'สุทัตตาภักดิ์บริรักษ์ภูมินทร์',
#  'วรินดา',
#  'เทศบาลเมืองบ้านหมี่',
#  'กลุ่มเกาะอาร์กติก',
#  'กล้ามเนื้อดีเพรสเซอร์ซูเปอร์ซิลิไอ',
#  'หม่อมหลวงชูชาติกำภู',
#  'หลวงปู่มั่นภูริทตฺโต',
#  'มาลามาลาจ็อง',
#  'มิดไนต์พาเหรด',
#  'นิธินาฏราชนิยม',
#  'ประสาทไทรเจมินัล',
#  'วัดพระพุทธบาทบัวบาน',
#  'วิทยาลัยการฝึกหัดครู',
#  'โมกสยาม',
#  'สมเด็จพระเจ้านิโคลัสที่',
#  'วิศวกรรมอิเล็กทรอนิกส์',
#  'ดีโอโก้',
#  'ยานจู่โจมแอคคลาเมเตอร์เซคอัน',
#  'พระพุทธรูปที่ยังไม่สมบูรณ์',
#  'การบุกครองยูโกสลาเวีย',
#  'ฆวนการ์ซิอาโปสติโก',
#  'รูเพิร์ทกรินท์',
#  'แมงดาทะเล',
#  'ก้าวแรกสู่สังเวียน',
#  'ปีแยร์อึนกูว์เริงซีซา',
#  'หลุยส์ซุลลิแวน',
#  'ลำดับการสืบราชสันตติวงศ์อดีตออสเตรีย']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (398, 1250)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศฮอลแลนด์',
#  'ประเทศเยอรมนีตะวันตก',
#  'ประเทศตองงา',
#  'ประเทศเกาหลีเหนือกับอาวุธอานุภาพทำลายล้างสูง',
#  'ประเทศคองโก',
#  'ประเทศมาเลเซีย',
#  'ประเทศภูฏาน',
#  'ประเทศคอซอวอ',
#  'ประเทศอิเควทอเรียลกินี',
#  'ประเทศนามิเบีย',
#  'ประเทศอินโดนีเชีย',
#  'ประเทศกรีซ',
#  'ประเทศเซนต์ลูเชีย',
#  'ประเทศบัลกาเรีย',
#  'ประเทศซานมาริโน',
#  'ประเทศทาจิกิสถาน',
#  'ประเทศเอธิโอเปีย',
#  'ประเทศจาเมกา',
#  'ประเทศสมมุติ',
#  'ประเทศมาลากาซี',
#  'ประเทศมาดากัสการ์',
#  'ประเทศนีวเว',
#  'ประเทศอาหรับ',
#  'ประเทศฟีจี',
#  'ประเทศเช็กเกีย',
#  'ประเทศสาธารณรัฐประชาชนจีน',
#  'ประเทศตูนิเซีย',
#  'ประเทศที่มีอดีตเป็นแดนนักโทษ',
#  'ประเทศกินีบิสเซา',
#  'ประเทศที่เป็นเกาะ',
#  'ประเทศโกตดิวัวร์',
#  'ประเทศไต้หวัน',
#  'ประเทศสิงคโปร์',
#  'ประเทศปานามา',
#  'ประเทศซูดาน',
#  'ประเทศเอสวาตินี',
#  'ประเทศคูเวต',
#  'ประเทศอุรุกวัย',
#  'ประเทศฝรั่งเศส',
#  'ประเทศสาธารณรัฐออสเตรีย',
#  'ประเทศเซาท์ซูดาน',
#  'ประเทศโซมาเลีย',
#  'ประเทศอินโดนีเซีย',
#  'ประเทศด้อยพัฒนา',
#  'ประเทศเฮติ',
#  'ประเทศไอร์แลนด์เหนือ',
#  'ประเทศโปรตุเกส',
#  'ประเทศเมียนม่าร์',
#  'ประเทศซินต์มาร์เติน',
#  'ประเทศบาร์เบโดส',
#  'ประเทศสาธารณรัฐฝรั่งเศส',
#  'ประเทศอิตาลี',
#  'ประเทศคิวบา',
#  'ประเทศสมมติ',
#  'ประเทศโซมาลีแลนด์',
#  'ประเทศบังคลาเทศ',
#  'ประเทศเวียตนาม',
#  'ประเทศโดมินิกัน',
#  'ประเทศเนเธอแลนด์',
#  'ประเทศโครเอเชียกับสกุลเงินยูโร',
#  'ประเทศอุตสาหกรรมใหม่',
#  'ประเทศวานัวตู',
#  'ประเทศเยอรมนี',
#  'ประเทศอูกันดา',
#  'ประเทศสาธารณรัฐอิตาลี',
#  'ประเทศโอมาน',
#  'ประเทศอาร์เมเนีย',
#  'ประเทศนิคารากัว',
#  'ประเทศเชกโกสโลวาเกีย',
#  'ประเทศเบลเยียม',
#  'ประเทศซาอุดีอารเบีย',
#  'ประเทศปากีสถาน',
#  'ประเทศลิธูเอเนีย',
#  'ประเทศเซนต์คิตส์และเนวิส',
#  'ประเทศอัลบาเนีย',
#  'ประเทศแอลเบเนีย',
#  'ประเทศมาเลเชีย',
#  'ประเทศอัฟกานิสถาน',
#  'ประเทศกาน่า',
#  'ประเทศบัลเกเรีย',
#  'ประเทศอภิมหาอำนาจ',
#  'ประเทศไทย',
#  'ประเทศโคลัมเบีย',
#  'ประเทศตะวันตก',
#  'ประเทศมอนเตเนโกร',
#  'ประเทศสวาซิแลนด์',
#  'ประเทศเซนต์วินเซนต์และเกรนาดีนส์',
#  'ประเทศอัลจีเรีย',
#  'ประเทศแอนทีกาและบาร์บิวดา',
#  'ประเทศอิสราเอล',
#  'ประเทศฝรั่งเศศ',
#  'ประเทศทิเบต',
#  'ประเทศอินโดเนเซีย',
#  'ประเทศเชโกสโลวาเกีย',
#  'ประเทศเอลซัลวาดอร์',
#  'ประเทศจีน',
#  'ประเทศเลโซโท',
#  'ประเทศฝรั่งเศสแผ่นดินใหญ่',
#  'ประเทศออสเตรเลีย',
#  'ประเทศบาสก์']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ
