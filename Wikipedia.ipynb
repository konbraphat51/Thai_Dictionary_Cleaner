# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
len(titles)
# Out:
# 362955

# %%
get_samples(titles)
# Out:
# ['โชเนน',
#  'จันนี่_สแกนเดอลัคกี้',
#  'เจ้าหญิงมารี_หลุยส์แห่งเบอร์เบิ้น-ปาร์มา',
#  'รายชื่อหน่วยงานวางระเบียบทางภาษา',
#  'Heteradelphia',
#  'แดนนี_วอร์ด',
#  'Siege_of_Malta_(1565)',
#  'ประเทศนิการากัวในแพนอเมริกันเกมส์',
#  'Shisha',
#  'คะซุโกะ_ทะคัตสึคะซะ',
#  'ช่วนจินก่า',
#  'Gamma_function',
#  'สมเด็จพระเจ้าซาร์นิโคลาสที่_2_แห่งรัสเซีย',
#  'Po',
#  'Jamala',
#  'โจเอล_แคมป์เบลล์',
#  'ทะเลทรายนามิเบีย',
#  'วัดประชาบำรุง_(จังหวัดมหาสารคาม)',
#  'ยุทธการที่ฌ็องบลู_(ค.ศ.1940)',
#  'กระเบนปีศาจญี่ปุ่น',
#  'ชิงกันเซ็ง_E3_ซีรีส์',
#  'หมากรุกญี่ปุ่นสี่คน',
#  'แอร์เอเชีย_เอกซ์',
#  'แมนเชสเตอร์ดาร์บี',
#  'เหตุระเบิดที่บาตา_พ.ศ._2564',
#  'ยุทธการที่แม่น้ำลิส_(ค.ศ._1940)',
#  'กัง_กิยุล',
#  'Rock-Hewn_Churches,_Lalibela',
#  'เดวิด_อิสตัน',
#  'ค.ศ._1381',
#  'บูร์คันคัลดุน',
#  'การจับตำแหน่งข้อต่อ',
#  'เอนริเก_เปญญา_นิเอโต',
#  'อ.โพธิ์ไทร',
#  'ฐิตินันท์_แสงนาค',
#  'In/Spectre',
#  'Phrynoidis_aspera',
#  'ละอองดาว_(นวนิยาย)',
#  'สภาวะเสียการระลึกรู้สัณฐานโดยคลำ',
#  'เกาะสเวตินิโกลา',
#  'อำเภอกุสินารา',
#  'Graz',
#  'วอลเลย์บอลชายไทยเดนมาร์คซูเปอร์ลีก_2016',
#  'คุณทองแดง',
#  'ประวีณวัช_บุญยงค์',
#  'เคราร์ด_เดอูโลเฟอู',
#  'เอฟเอ็ม_(อีพี)',
#  'ประยูร_อุลุชาฎะ',
#  'คณะรัฐมนตรีคณะที่_14_ของไทย',
#  'Brihanmumbai_Municipal_Corporation',
#  'แจ้งวัฒนะ',
#  'สาย_JR_ยะมะโนะเตะ',
#  'ค.ศ._605',
#  'ผู้ว่าฯกทม.',
#  'สถานีดาวคะนอง',
#  'Tulumella',
#  'วัดศาลาแดง',
#  'แอนดราส',
#  'ชินามิ_โทกูนางะ',
#  'วิกิพีเดียภาษาบันยูมาซัน',
#  'เส้นเมริเดียนที่_128_องศาตะวันออก',
#  'ทเวนตีเฟิสต์เซนจูรีเบรกดาวน์',
#  'สถานีรถไฟชินางาวะ',
#  'ดราก้อนบอล_(ภาพยนตร์ชุดทางโทรทัศน์)',
#  'เซเนบเฮนัส',
#  'หยาง_อี่',
#  'รี้ด_(เก็นโซซุยโคเด็น)',
#  'Chubu_International_Airport',
#  'สถาบันข้อมูลขนาดใหญ่_(องค์การมหาชน)',
#  'ฟุตบอลถ้วยพระราชทานประเภท_ก._ประจำปี_2551',
#  'Clara_Sosa',
#  'แหล่งโบราณคดีเมืองศรีมโหสถ',
#  'สะบายดีหลวงพระบาง',
#  'อิริเดียมเตโตรไซด์',
#  'ตำนานสมเด็จพระนเรศวรมหาราช_ภาค_๕_ยุทธหัตถี',
#  'เค้าก่อน_(เพลงยูอาร์บอยทีเจ)',
#  'ห้าอัครบุคคล_(คีตกวี)',
#  'Sulfur',
#  'เอ็มทีวีวิดีโอมิวสิกอวอร์ดส',
#  'Technotronic',
#  'คณะแพทยศาสตร์วชิรพยาบาล',
#  'เรนอินบลัด',
#  'จังหวัดนีแด',
#  'ท็อปเชฟไทยแลนด์_ฤดูกาลที่_1',
#  'Gastrotrich',
#  'Natsuki_Hanae',
#  'วัดธรรมาราม_(อำเภอพระนครศรีอยุธยา)',
#  'เดวิด_คาราดีน',
#  'หลักหิน_วสันตสิทธิ์',
#  'ฮอนด้า_ซีอาร์วี',
#  'ความเอนเอียงโดยทำให้ต่าง',
#  'ครุยเซอร์_มาร์ค_8_ชาลเลนเจอร์',
#  'Kim_Woo-seok_(singer)',
#  'โนะริโอะ_วะกะโมะโตะ',
#  'ราชอาณาจักรฮัชไมต์จอร์แดนในโอลิมปิกฤดูร้อน_2008',
#  'วัดพระศรีรัตนมหาธาตุเชลียงราชวรวิหาร_(พระปรางค์)',
#  'พระมหากษัตริย์แห่งยูโกสลาเวีย',
#  'Creagrocercidae',
#  'สามเกลอข้อโปน',
#  'ชลิตา_เฟื่องอารมณ์']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

len(titles)
# Out:
# 353833

# %%
get_samples(titles)
# Out:
# ['เคียวโกะ_อิโนะอุเอะ',
#  'เหรียญเงินช้างเผือก',
#  'Godzilla_Against_Mechagodzilla',
#  '2011–ปัจจุบัน',
#  'หิรัณยกศิปุ',
#  'พราน',
#  'ออคตาฟ_มีโบ',
#  'จังหวัดแม่ฮ่องสอนในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป_พ.ศ._2550',
#  'แมสซีฟแอตแทก',
#  'ศาสนาพุทธในประเทศรัสเซีย',
#  'O._Henry_Award',
#  'วงศ์กวางชะมดป่า',
#  'ปลาแดมเซลฟ้าหางส้ม',
#  'ข้าหลวงต่างพระองค์เครือรัฐออสเตรเลีย',
#  'สโมสรฟุตบอลจังหวัดตราด',
#  'ตำบลเฆร์กู',
#  'อุสมาน_ศรแดง',
#  'อูว์เกอโนต์',
#  'The_Imperial',
#  'ฟิล_ทากูปา',
#  'ดุสิต_เฉลิมแสน',
#  'ลีอาห์_ดีซอน',
#  'Scleropages_aureus',
#  'KC_WEEKLY',
#  'ไอแพด_มินิ',
#  'Labiobarbus',
#  'วัดพันท้ายนรสิงห์',
#  'เหตุการณ์รถไฟชนกันที่ตลิ่งชัน_พ.ศ._2522',
#  'วงศ์นกขาบ',
#  'ภาวะทุพโภชนาการ',
#  'กาเบรียล_คว็อก',
#  'Tragulidae',
#  'แอนดี_เล',
#  'เอ็มเอสเอ็นเมสเซนเจอร์',
#  'การตลาดแบบปากต่อปาก',
#  'า',
#  'Niponiosomatidae',
#  'มหาวิบัตินครดับสูญ',
#  'สาธารณรัฐเอกวาดอร์ในโอลิมปิกฤดูร้อน_1992',
#  'Azerbaijan_Cup',
#  'พระเจ้าฮั่นเซ่าตี้',
#  'ยัน_ฟัน_ไอก์',
#  'บีแยลาวา',
#  'ภาษาซาซากิ',
#  'BUT_/_ไอโช',
#  'เทศบาลตำบลทุ่งเสลี่ยม',
#  'กันทาริยามหาเทวมนเทียร',
#  'ฟิโอดอร์_ดอสโตเยฟสกี',
#  'มหาวิทยาลัยเอ็กซิเตอร์',
#  'พอล_แวน_ไดก์',
#  'Hockey',
#  'สวนลุมพินีวัน',
#  'เกเนอราลพลานอ็อสท์',
#  'Brad_Jones',
#  'Codonanthopsis',
#  'นิกายไวษณพ',
#  'นอร์แมน_เฟกิเดโร',
#  'โรนัลโด้',
#  'สมพงค์_ภูววิมล',
#  'มังกรโคโมโด',
#  'ฟุตบอลถ้วยพระราชทานประเภท_ก._ประจำปี_2557',
#  'ประเทศเนปาลในเอเชียนเกมส์_2006',
#  'Hun_Maneth',
#  'สงครามปราบศึกฮ่อ',
#  'ฟุตซอลในซีเกมส์',
#  'ออร์บิทัล',
#  'การป้องกันมะเร็ง',
#  'พ.ศ._1833',
#  'เอฟเอ_คัพ',
#  'วันเสรีภาพสื่อมวลชนโลก',
#  'คีธ_เบลล์',
#  'พ.ศ._1706',
#  'ปลาไหลช่อ',
#  'วัดเกาะพยาม',
#  'เครื่องราชอิสริยาภรณ์ทริสเติล',
#  '๑๐_พฤษภาคม',
#  'Musa_acuminata_subsp._siamea',
#  'อภิสมัย_ศรีรังสรรค์',
#  'ดานิ_การ์บาฆัล',
#  'วัดวังพระธาตุ',
#  'แม่น้ำเน็คคาร์',
#  'ฟิฟตี้_เซ็นต์',
#  'การเลือกตั้งระบบสัดส่วนแบบเปิด',
#  'สมเด็จพระราชินีมาเรีย_โจเซฟีน_หลุยส์แห่งซาวอย',
#  'วีน-มยิน',
#  'อุทยานรัชกาลที่_๙',
#  'Victor_Emmanuel_II_of_Italy',
#  'อัลบัยฎออ์',
#  'ประเทศเกาหลีเหนือในโอลิมปิกฤดูหนาว_2018',
#  'เควิน_โนแลน',
#  'มิสเตอร์เนชันแนลยูนิเวิร์ส',
#  'พระเทพพัชรญาณมุนี',
#  'กวีไมเคิล_แจ็กสัน',
#  'ญะบัล_อันนูร',
#  'โรคปมประสาทบาซัล',
#  'ทางหลวงแผ่นดินหมายเลข_303',
#  'อิฟไอเวอร์อะบอย',
#  'รายชื่อแหล่งมรดกโลกในประเทศอิหร่าน',
#  '386BSD',
#  'ท่าอากาศยานนานาชาติพาโร']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

len(titles)
# Out:
# 465912

# %%
get_samples(titles)
# Out:
# ['SanAntonio,TX',
#  'เองรีกีดีเซนาฟีร์นังดิช',
#  'ปลาการ์ตูนส้ม',
#  'คาวิกา',
#  'บางกอกซิตี้แชนแนล',
#  'ปีเตอร์เบียร์ดสลีย์',
#  'ตำนานสมเด็จพระนเรศวรมหาราชเดอะซีรีส์',
#  'แลมโบกินี่มูร์เซียลาโก',
#  'al-Razi',
#  'แกลสส์',
#  'เจี้ยนเหวิน',
#  'AgnesChow',
#  'Samart',
#  'กระดูกเอทมอยด์',
#  'ลีก้า',
#  'เข็มกลัดฟิบิวลา',
#  'Shijiazhuang',
#  'พ.ศ.2047',
#  'ปลากะพงแถบน้ำเงิน',
#  'พ.ศ.1123',
#  'เส้นเมริเดียนที่127',
#  'ยูโซ',
#  'ทรีมาโลส',
#  'พระเจ้าหรรษวรมันที่1',
#  'วัดท่าไชยศิริ',
#  'Monumental',
#  'DreamWorks,LLC',
#  'สมเด็จพระราชินีนาถราซอเฮอรินาแห่งมาดากัสการ์',
#  'Internetprotocolsuite',
#  'HighDefinitionTV',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล2022–23',
#  'ล้อตุนกำลัง',
#  'ทาทูอิน',
#  'ตำบลกำแพงเซา',
#  'ฌอห์น',
#  'SACD',
#  'ราชสำนักแห่งเกาหลี',
#  'ชีคมูจิบูร์เราะห์มาน',
#  'ComputerspielemuseumBerlin',
#  'พัชรี',
#  '2248',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าหญิงน้อง',
#  'UniversityofSt.Andrews',
#  'สโมสรฟุตบอลแมนเชสเตอร์ซิตีในฤดูกาล2013–14',
#  'ประกาศสิทธิมนุษยชนและพลเมือง',
#  'กรดไขมันโอเมกา3',
#  'ลี่อิน',
#  'กันดั้มดับเบิ้ลโอ',
#  'พระที่นั่งนิพัทธพงศ์ถาวรวิจิตร',
#  'พรรคนำไทย',
#  'Dyn',
#  'จังหวัดโฮร์โมซกอน',
#  'บุคคลที่เกิดในปีพ.ศ.2534',
#  'เวทมนตร์ใน',
#  'เตกีลาซันไรส์',
#  'ภาษามะนอง',
#  '.ve',
#  'Canisaureus',
#  'โรคสมองบาดเจ็บเรื้อรัง',
#  'ฟาโรห์เซเคมเรคูทาวีโซเบคโฮเทป',
#  'การเคลื่อนลงตามความชัน',
#  'วัคซีนโรคบาดทะยัก',
#  'มหารานีแห่งแผ่นดิน',
#  'Starbucks',
#  'Phalaenopsisamabilis',
#  'MSN',
#  'เตอร์กิชวูแมนส์วอลเลย์บอลลีก',
#  'Huchotaimen',
#  'พระองค์เจ้ามรกฎ',
#  'ดิอิมพอสซิเบิล',
#  'โจมา',
#  'machina',
#  'ยามาซากิซางารุ',
#  'Image',
#  'Triquetrumbone',
#  'นายกรัฐมนตรีบาห์เรน',
#  'Fiorentina',
#  'อัสแซสซินส์ครีด:บลัดไลนส์',
#  'MiguelPérezCuesta',
#  'SuperShowTourConcertAlbum',
#  'พงศาวดารเขมร',
#  'หมึกยักษ์เล็ก',
#  'Goldensnub-nosedmonkey',
#  'ฮิโรโนบุซากางูจิ',
#  'Antrodiacamphorate',
#  'เรือหลวงพลายชุมพล',
#  'กีฬาเรือพายในเอเชียนเกมส์2022',
#  'การพับกระดาษ',
#  'อาคารริงกูเกททาวเวอร์',
#  'ListofcountriesbyGDP',
#  'ยุคอีดีแอคารัน',
#  'PrinceGabrielofThurnandTaxis',
#  'bin',
#  'Groningen',
#  'วีแอลซี',
#  'สามช่า',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:โทรอนโต',
#  'Cynometra',
#  'ยุทธการที่แม่น้ำซอมม์',
#  'อาบุลฮะซันบานีศาดร์']

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

len(titles)
# Out:
# 346494

# %%
get_samples(titles)
# Out:
# ['รายชื่อเจ้าผู้ครองลีชเทินชไตน์',
#  'ฟร็องซัวออลลองด์',
#  'ความบริสุทธิ์',
#  'สมณกรรมาธิการนครรัฐวาติกัน',
#  'โปรแกรมจัดการดาวน์โหลด',
#  'ไมเคิลแจ็กสันกับประเทศไทย',
#  'พรอปเพอร์ตี',
#  'เอ็กซ์เพลส',
#  'จุดไกลดวงอาทิตย์ที่สุด',
#  'ฌอสแปง',
#  'ศรีชัยวัชรบุรี',
#  'พระเจ้าโจวมู่หวัง',
#  'ไมค์เบลส์',
#  'ซูแปร์เลกาฤดูกาล2021–22',
#  'สถานีอวกาศเทียนกง',
#  'พระทีั่นั่งอัมพรสถาน',
#  'ไทยแลนด์ก็อตทาเลนต์ซีซั่นที่2',
#  'ฟูชิเซน',
#  'รายชื่อตัวละครในเรื่อง',
#  'อิชตาลล์',
#  'นีดะ',
#  'ฌอง-ลุกแซสซัส',
#  'คณะรัฐมนตรีไทย',
#  'เจ้าหญิงเอ็มมาแห่งวัลเด็คและไพร์มอนต์',
#  'เมื่อผู้กล้าลาโลกแล้ว!เพราะชาวบ้านอย่างผมเผลอทำผู้กล้าตาย',
#  'พระราชบัญญัติความสัมพันธ์ภายในครอบครัว',
#  'ไคซูเกะ',
#  'ยงยุทธสัจจวานิชย์',
#  'โคโค่แจ๊ซ',
#  'ชีวิตไม่ง่ายของนางร้าย',
#  'อ.ภูผาม่าน',
#  'เมืองฝาง',
#  'ประเทศปากีสถานในโอลิมปิกฤดูร้อน1956',
#  'นกเด้าลม',
#  'วอลเลย์บอลชายชิงแชมป์แอฟริกา2021',
#  'ชาลีผาย',
#  'ประเทศโมซัมบิกในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ไฟลามทุ่ง',
#  'ลิขิตรักตะวันและจันทรา',
#  'หายใจเร็ว',
#  'เวสต์วิค',
#  'พระเจ้าชาร์ลส์ที่',
#  'ยุทธการที่หับป๋า',
#  'รูกกีบีบี',
#  'รูปร้อยเหลี่ยม',
#  'แป้งณัฐธิดา',
#  'ค.ศ.968',
#  'พระเจ้าอัลฟอนโซที่13แห่งสเปน',
#  'อาบราโมวิช',
#  'มายาอลเวง',
#  'มิสเตอร์ดี',
#  'เมาตินี',
#  'โนริอากิฟูจิโมโตะ',
#  'รักโง่ๆ',
#  'จักรพรรดิซีกิสมุนด์แห่งจักรวรรดิโรมันอันศักดิ์สิทธิ์',
#  'ประเทศเนปาลในพาราลิมปิกฤดูร้อน2020',
#  'แบรม',
#  'ซานธอส',
#  'ผ้าซิ่นทิวมุก',
#  'โรงเรียนมัธยมวัดหนองแขม',
#  'ฟูจิที-3',
#  'บ่ายวันอาทิตย์บนเกาะลากร็องด์ยัต',
#  'พระบรมราชินี',
#  'หม่อมหลวงสราลี',
#  'ปาวรตี',
#  'เบนซิมิดาโซล',
#  'พระราชวังเดิม',
#  'วัดแคนอก',
#  'นครปกครองโดยตรงของประเทศจีน',
#  'เคตช์วาโย',
#  'วัดศรีจันทาราม',
#  'กลุ่มดาวตาข่าย',
#  'พระเจ้าวรวงศ์เธอพระองค์เจ้าวิภาวดีรังสิต',
#  'รายชื่อตัวละครในสาวน้อยยอดนักสืบ',
#  'สตรอนเทียม',
#  'โทะโยะตะ',
#  'สมเด็จพระราชินีนาถแอนน์แห่งเกรตบริเตน',
#  'คนสองเพศ',
#  'วัคซีนลดฤทธิ์',
#  'นิวรอนสั่งการ',
#  'พระวรสารนอกสารบบ',
#  'อาสนวิหารกูต็องส์',
#  'พระสุพรรณนพรัตน์ศิราภรณ์มงคล',
#  'ทากาอากิโทมิมัตสึ',
#  'ท้องฟ้าจำลองเนห์รู',
#  'กองพลยานเกราะดิ่งพสุธาที่1แฮร์มันเกอริง',
#  'การวิจัยเชิงทดลองทางคลินิก',
#  'คลื่นความร้อนในเอเชียพ.ศ.2566',
#  'เจ้าชายจอร์จ',
#  'เกย์-ฟอร์-เพย์',
#  'ในพระนามของพระบิดา',
#  'โกเตง',
#  'ซงโงกุน',
#  'อาวุธยุทธสัมภาระ',
#  'ประเทศเวียดนามในเอเชียนเกมส์1954',
#  'คิมิโนะอุตะ',
#  'สาธารณรัฐเวียดนาม',
#  'สถานีมหาวิทยาลัยเกษตรศาสตร์',
#  'โนลกัลลาเกอส์ไฮฟลายอิงเบิดส์',
#  'อีวานเคร็ก']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 5011

# %%
get_samples(raay)
# Out:
# ['รายชื่อไลต์โนเวลในซอร์ดอาร์ตออนไลน์',
#  'รายชื่อผลงานอัลบั้มเพลงของเซลีน',
#  'รายชื่อปลัดกระทรวงศึกษาธิการของไทย',
#  'รายพระนามคู่สมรสในพระจักรพรรดิแห่งรัสเซีย',
#  'รายชื่อไมโครซอฟต์วินโดวส์รุ่นต่างๆ',
#  'รายชื่อนายกรัฐมนตรีอินเดีย',
#  'รายชื่อบุคคลจากมหาวิทยาลัยกรุงเทพ',
#  'รายนามผู้ประกาศข่าวและผู้รายงานข่าวสถานีวิทยุโทรทัศน์ไทยทีวีสีช่อง3',
#  'รายชื่อเวทมนตร์คาถาในแฮร์รี่',
#  'รายชื่อแหล่งมรดกโลกในประเทศออสเตรเลีย',
#  'รายชื่อแหล่งมรดกโลกในหมู่เกาะมาร์แชลล์',
#  'รายนามผู้บัญชาการทหารเรือไทย',
#  'รายชื่อบุคคลสำคัญจากมหาวิทยาลัยเชียงใหม่',
#  'รายชื่อเครื่องอิสริยาภรณ์อาเซอร์ไบจาน',
#  'รายชื่อแหล่งมรดกโลกในประเทศกรีซ',
#  'รายนามศิษย์เก่าโรงเรียนภ.ป.ร.ราชวิทยาลัยในพระบรมราชูปถัมภ์',
#  'รายชื่อตัวละครในร็อคแมน',
#  'รายพระนามพระกุลเชษฐ์ในราชวงศ์จักรี',
#  'รายการข้าม',
#  'รายพระนามและรายนามผู้ได้รับพระราชทานร.ว.',
#  'รายการประเทศตามการคาดหมายคงชีพ',
#  'รายชื่อโบราณสถานในจังหวัดนครศรีธรรมราชที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อละครโทรทัศน์ทางสถานีโทรทัศน์ช่องจีเอ็มเอ็ม25',
#  'รายชื่อเคานท์พาลาไทน์แห่งซไวบรึคเค็น',
#  'รายชื่อชาวไทยที่มีอายุเกิน',
#  'รายการแหล่งมรดกโลกในประเทศเติร์กเมนิสถาน',
#  'รายนามผู้ปกครองร่วมอันดอร์รา',
#  'รายนามประธานฟีฟ่า',
#  'รายการธงในประเทศลาว',
#  'รายชื่อโบราณสถานในจังหวัดชัยภูมิ',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์เดนมาร์ก',
#  'รายชื่อภาพยนตร์ของพิกซาร์',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งอิรัก',
#  'รายชื่อประเทศเรียงตามการบริโภคน้ำมัน',
#  'รายพระนามเจ้าผู้ครองรัฐกาตาร์',
#  'รายชื่อประเทศเรียงตามการส่งออกรถยนต์',
#  'รายาอูงู',
#  'รายชื่อผลงานของผลิตโชค',
#  'รายชื่อผลงานของอุรัสยา',
#  'รายชื่อเกมปี',
#  'รายพระนามพระประมุขทิเบต',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2476',
#  'รายชื่อนายกรัฐมนตรีเดนมาร์ก',
#  'รายชื่อบทภาพยนตร์ยอดเยี่ยม',
#  'รายชื่อโบราณสถานในจังหวัดสระบุรี',
#  'รายชื่อแหล่งมรดกโลกในประเทศสโลวีเนีย',
#  'รายยวา',
#  'รายชื่อสิ่งมีชีวิตที่ถูกตั้งชื่อตามคนดัง',
#  'รายชื่อโบราณสถานในจังหวัดอุทัยธานี',
#  'รายชื่อประเทศตามจำนวนประชากร',
#  'รายชื่อวิดีโอเกมปี',
#  'รายชื่อรหัสไปรษณีย์ไทยเรียงตามจังหวัด',
#  'รายชื่อนางแบบวิกตอเรียส์ซีเคร็ต',
#  'รายชื่อโบราณสถานในจังหวัดนครราชสีมา',
#  'รายชื่อนายกรัฐมนตรีในสมเด็จพระเจ้าจอร์จที่6',
#  'รายนามนักประพันธ์และรายชื่อวรรณกรรมที่ได้รับรางวัลพานแว่นฟ้า',
#  'รายพระนาม',
#  'รายนามเสนาบดีและรัฐมนตรีว่าการกระทรวงการคลัง',
#  'รายชื่อธงในกองทัพยูเครน',
#  'รายนามบุคคลสำคัญจากมหาวิทยาลัยธรรมศาสตร์',
#  'รายชื่อทางแยกในเขตมีนบุรี',
#  'รายชื่อฟอร์ช็อกและอาฟเตอร์ช็อกจากแผ่นดินไหวและคลื่นสึนามิในโทโฮะกุ',
#  'รายการแหล่งมรดกโลกในประเทศอุซเบกิสถาน',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์เนเธอร์แลนด์',
#  'รายชื่อฝนดาวตก',
#  'รายชื่อนวนิยายกำลังภายใน',
#  'รายชื่อสะพานในประเทศไทย',
#  'รายชื่อสงครามกลางเมืองของอังกฤษ',
#  'รายชื่อศิลปินกลุ่มเกาหลีใต้',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์แห่งเบลเยียม',
#  'รายพระนามจักรพรรดิแห่งจักรวรรดิเม็กซิโก',
#  'รายชื่อผู้ครองตำแหน่งมิสเตอร์โกลบอล',
#  'รายพระนามจักรพรรดิแห่งออสเตรีย',
#  'รายชื่อผลงานเพลงของวงบีสต์',
#  'รายชื่อสถานีโทรทัศน์ญี่ปุ่น',
#  'รายพระนามเจ้านายที่ได้รับการเฉลิมพระยศในสมัยกรุงรัตนโกสินทร์',
#  'รายชื่อผลงานเพลงของวงทูเอเอ็ม',
#  'รายชื่อธงชาติในทวีปอเมริกาเหนือ',
#  'รายชื่อธาตุเรียงตามเลขอะตอม',
#  'รายชื่อทางแยกในเขตธนบุรี',
#  'รายชื่อวัดในจังหวัดสมุทรสงคราม',
#  'รายชื่อสมรภูมิและยุทธการในสงครามกลางเมืองอเมริกา',
#  'รายชื่อประเทศเรียงตามระดับความสูงเฉลี่ย',
#  'รายชื่อตลาดหลักทรัพย์ในทวีปแอฟริกา',
#  'รายชื่อประเทศเรียงตามการส่งออกเครื่องบินและยานอวกาศ',
#  'รายนามองคมนตรีในรัชกาลสมเด็จพระเจ้าอยู่หัวมหาวชิราลงกรณ',
#  'รายชื่อประธานาธิบดีสาธารณรัฐจีน',
#  'รายชื่อหมา',
#  'รายนามผู้อำนวยการสถานศึกษา',
#  'รายชื่อประเทศเรียงตามการได้ส่วนแบ่งตลาดจากสมาร์ทโฟน',
#  'รายนามประมุขแห่งรัฐยูโกสลาเวีย',
#  'รายชื่อโรงเรียนในจังหวัดลำปาง',
#  'รายชื่อนักแสดงในสตาร์วอร์ส',
#  'รายชื่อสายการบินในมาเก๊า',
#  'รายชื่อแหล่งมรดกโลกในประเทศเม็กซิโก',
#  'รายชื่อเกมคอมพิวเตอร์และวิดีโอเกมเรียงตามประเภท',
#  'รายชื่อโบราณสถานในจังหวัดสมุทรสงครามที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่ออัลบั้มของ',
#  'รายชื่อมลรัฐและดินแดนของสหรัฐอเมริกาเรียงตามจำนวนประชากร',
#  'รายชื่อเมืองหลวงทางประวัติศาสตร์ของอียิปต์']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 57

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายาแห่งรัฐปะลิส',
#  'รายกอวิช',
#  'รายาอูงู',
#  'รายาห์',
#  'รายงานเฮิร์ช',
#  'รายหัว',
#  'รายได้ประชาชาติ',
#  'รายได้มูลฐาน',
#  'รายงานเคส',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายงานกรณี',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°C',
#  'รายงานประจำปี',
#  'รายากับมังกรตัวสุดท้าย',
#  'รายงานเค้ส',
#  'รายาบีรู',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายงานความสุขโลก',
#  'รายงานเฮิรส์ช',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายากูนิง',
#  'รายาฮีเจา',
#  'รายงานการประชุม',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง:ทัศนมิติโลก',
#  'รายงานคนไข้',
#  'รายาฮีเยา',
#  'ราย',
#  'รายวนปูเลาเกอราปา',
#  'รายานนท์',
#  'รายาผิวขาว',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายได้',
#  'รายาประไหมสุหรีอากง',
#  'รายนานนท์',
#  'รายูวันปูเลาเกอลาปา',
#  'รายงานทีหลัง',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายาแห่งซาราวัก',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง:ทัศนมิติโลก',
#  'รายาแห่งซาราวะก์',
#  'รายงานค่าใช้จ่าย',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง:ทัศนมิติโลก',
#  'รายงานอาหาร',
#  'รายวนปูเลาเกอลาปา',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายได้พื้นฐาน',
#  'รายปุระ',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°ซ.']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
len(titles)
# Out:
# 341540

# %%
get_samples(titles)
# Out:
# ['ฮูมัต',
#  'ริงโกะอูเอดะ',
#  'ไอโอเนีย',
#  'เซอร์ไวเวอร์ฟิจิ',
#  'ฮวนมิโร',
#  'พายุไต้ฝุ่นนิดา',
#  'ซีมาน',
#  'สมเด็จพระจักรพรรดิแห่งรัสเซีย',
#  'นกจมูกหลอดยักษ์ขั้วโลกใต้',
#  'สโลนเกรตวอลล์',
#  'นักบุญซาราห์',
#  'หม่อมเจ้าวัฒนา',
#  'ท่าสาทร',
#  'รัฐเอกราชซามัวในโอลิมปิกฤดูร้อน1996',
#  'วัดลาดหญ้าแพรก',
#  'พรอดิวซ์แคมป์2020',
#  'ชู้รักเลดี้แชตเตอร์เลย์',
#  'รามาวตาร',
#  'ภูมิแผ่นดินนวมินทร์มหาราชา',
#  'สมิงพยู',
#  'สำนักงานการบังคับใช้กฎหมายยาเสพติดแห่งประเทศฟิลิปปินส์',
#  'ดำรงดิศ',
#  'ซาร์อีวานที่5',
#  'กรสวัสดิ์',
#  'บักกวย',
#  'สโมสรฟุตบอลกองเรือยุทธการ',
#  'หลวงพ่อวิริยังค์สิรินธโร',
#  'เจือง',
#  'สุสานแห่งฮาลิคาร์นัสเซิส',
#  'กีฬาโปโลน้ำในซีเกมส์2013',
#  'จิงหยู',
#  'เอเชียนพาราเกมส์',
#  'กรกฏธนภัทร',
#  'สุทิน',
#  'ลิปกลอส',
#  'แบบจำลองการสะท้อนแบบฟ็อง',
#  'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูร้อน2012',
#  'เมย์กิว',
#  'วัดบางพลีใหญ่ใน',
#  'อิ้งค์',
#  'วัดห้วยลี่จังหวัดสระบุรี',
#  'ทิมมอร์เฮาส์',
#  'เธอเอาใจฉันไป',
#  'เกาะเชียงจานเชียน',
#  'จางจื่ออี้',
#  'ประเทศปาเลาในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'โอชอนิสซี',
#  'อีมิลเฮสกีย์',
#  'ภาษาเมเกรเลีย',
#  'อะเลกเซย์กูโรแพทกิน',
#  'คอนสตันติน',
#  'นนทรีย์',
#  'นาโชบิดัล',
#  'วัคซีนโควิด-19ของไฟเซอร์-ไบออนเทค',
#  'ชีดา',
#  'ระหว่างเราและดอกไม้ไฟ',
#  'แนวร่วมปลดปล่อยแห่งชาติประชาชนเขมร',
#  'อ.บ้านม่วง',
#  'แมนซูร์',
#  'เส้นโค้งคีลิง',
#  'พระอุมา',
#  'โจไกซัง',
#  'เจ้าชายไฮน์ริช',
#  'วากามูราซากิ',
#  'เหตุรถบรรทุกชนในรัฐเชียปัส',
#  'ปวีร์',
#  'กระทรวงโภชนาการและการเกษตรไรช์',
#  'เลปลูสกร็องซูกเซเดอเซลีนดียง',
#  'เรนาโตคอนสตันติโน',
#  'ฟลัค',
#  '52ปีก่อนคริสตกาล',
#  'เจเนอรัลมอเตอร์',
#  'ไทยแลนด์มาสเตอร์',
#  'แฟนปะทะทีมโปรด',
#  'มิซากินาโกะ',
#  'ซีซ่าร์',
#  'คาสเซิลวาเนียIIเบลมอนต์สรีเวงก์',
#  'เจ้าชายอาซิมบินนาเยฟ',
#  'มนุษย์',
#  'สัดส่วนทอง',
#  'ยุทธการที่คาร์คอฟครั้งที่',
#  'พระศรีรังคนาถ',
#  'พานิชภักดิ์',
#  'สุภาว์',
#  'นันชะระ',
#  'ผักกระชับ',
#  'สนามบินนานาชาติจอห์นเอฟ.เคนเนดี',
#  'หงส์ขาวคอดำ',
#  'โรคปิแอร์-โรแบง',
#  'โทแจจ็อง',
#  'ประเทศนอร์เวย์ในโอลิมปิกฤดูร้อน2020',
#  'เซนต์โล',
#  'รถไฟใต้ดินหนานจิงสายS6',
#  'หม่อมราชวงศ์ชิต',
#  'ค.ศ.1255',
#  'โมเลกุลขนาดใหญ่',
#  'หน่วยเอสโอเอส',
#  'เชฟิกจาเฟโรวิช',
#  'โอลิมปิกฤดูร้อน1968',
#  'กีฬาสกีนอร์ดิกผสมในโอลิมปิกเยาวชนฤดูหนาว2020–ประเภทบุคคลชายนอร์มอลฮิลล์6กิโลเมตร']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Include monks nicknames
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
