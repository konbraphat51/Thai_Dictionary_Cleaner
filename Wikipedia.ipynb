# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
len(titles)
# Out:
# 362955

# %%
get_samples(titles)
# Out:
# ['สัญญาณรบกวนจอห์นสัน–นือควิสต์',
#  'วอลเลย์บอลชายทีมชาติปารากวัย',
#  'รังสีเทราเฮิรตซ์',
#  'ปฏิทินโจเกียว',
#  'Diesel_exhaust',
#  'ธิรดา_สนิทวงศ์ชัย',
#  'พระเจ้าเฮโรดมหาราช',
#  'หอยสังข์มะระ',
#  "Wanna_Be_Startin'_Somethin'_2008",
#  'ควีนส์คัพ',
#  'จอมใจเจ้าป่า',
#  'ฮัลโหลวีนัส',
#  'กีฬากระโดดน้ำในโอลิมปิกฤดูร้อน_2020_–_สปริงบอร์ด_3_เมตร_ชายคู่',
#  'มรณกรรม',
#  'ทริปซิน_(Trypsin)',
#  'วัดโรงเข้วนาราม',
#  'Calgary,_Alberta',
#  'บับเบิ้ลฟิคชั่น:_บูม_ออร์_บัสท์',
#  'เนียง',
#  'วังท้ายวัดพระเชตุพนวิมลมังคลาราม',
#  'เมทริกซ์แอร์มิต',
#  'Badis_ruber',
#  'สนามกีฬาริเวอร์ไซด์',
#  'Cayman_Islands',
#  'My_life_as_a_teenage_robot',
#  'ประชาคมฝรั่งเศสแห่งเบลเยียม',
#  'Chancels',
#  'ฮัม_อึน-จอง',
#  'โอลีเฟอร์_ซตริทเซิล',
#  'ค.ศ._915',
#  'ปูมราชธรรม',
#  'Lince_Dorado',
#  'จูจูจู_โบกูระโนะมิราอิ/ไดจินเซ_เนเวอร์บีนเบ็ทเตอร์!',
#  'สุรนันท์_เวชชาชีวะ',
#  'หลวงปู่มั่น_ภูริทตฺโต',
#  'เจ้าชายชาลส์_เอ็ดเวิร์ด_ดยุกแห่งซัคเซิน-โคบูร์กและโกทา',
#  'Kiss_Me_Five',
#  'อาเธอร์_กรีกอเรียน',
#  'ไวเอต',
#  'รูปาตาดีน',
#  'สุรีย์วัลย์_สุริยง',
#  'มักนุส_มุนซเค',
#  'Egyptian_cobra',
#  'สตั๊ก_44',
#  'นอแว',
#  'Development_of_the_human_brain',
#  'การพิมพ์_3_มิติ',
#  'เขาพลองสเตเดียม',
#  'อี_มินโฮ',
#  'ฮานี_(นักร้อง)',
#  "FIFA_U-17_Women's_World_Cup",
#  'สหภาพประชาธิปไตยปาเลสไตน์',
#  '440_ปีก่อนคริสตกาล',
#  'ต๋อง_ศิษย์ฉ่อย',
#  'Vremya',
#  'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน_1968',
#  'Maize_oil',
#  'Madden_NFL_22',
#  'อเมริกาส์_เน็กซ์_ท็อป_โมเดล_,_ฤดูกาลที่_2',
#  'ค่าเฉลี่ย_(แก้ความกำกวม)',
#  'มหาวิทยาลัยมหาจุฬาลงกรณราชวิทยาลัย',
#  'ไมโครพลาสมา',
#  'โพธิสัตว์ศีล',
#  'นางแย้มป่า',
#  'แม่น้ำหวงฉุ่ย',
#  'ค.ศ._1458',
#  'พระเจ้าบรมวงศ์เธอ_พระองค์เจ้าโต_กรมหลวงมหิศวรินทรามเรศร์',
#  'อูโก_กิยามอน',
#  'ประเทศอัฟกานิสถานในโอลิมปิกฤดูร้อน_2012',
#  'คอร์ปุส_คาเวอร์โนซุม_พีนิส',
#  'นักพัฒนาโปรแกรม',
#  "St._Michael's_Church,_Cluj-Napoca",
#  'Sylvie_(Marvel_Cinematic_Universe)',
#  'คิม_ข่าน_ซากิ',
#  'Ginglymostoma',
#  'สาธารณรัฐมองโกเลียในโอลิมปิกฤดูหนาว_2006',
#  'Simeticone',
#  'ทูเดย์วอสอะเฟรีเทล',
#  'นีกอลา_เฌสกีแยร์',
#  'H._s._rhodesiensis',
#  'ปตท._สำรวจและผลิตปิโตรเลียม',
#  'Liebesgruss',
#  'Aya_matsuura',
#  'ซากิ_นากาจิมะ',
#  'วัดวิเวกวายุพัด',
#  'รอย_ฮอดจ์สัน',
#  'ณัฐนนท์_กัจฉปานันท์',
#  'วัดสุวรรณ_(กรุงเทพมหานคร)',
#  'เทค_แบ็ค',
#  'เป็นต่อ_ขั้นเทพ',
#  'เครื่องเร่งอนุภาค',
#  'Fuernrohria',
#  'รัฐอิสราเอลในโอลิมปิกฤดูหนาว_2006',
#  'วอลเลย์บอลในกีฬามหาวิทยาลัยโลกฤดูร้อน_1961',
#  'Blood_test',
#  'เส้นเวลาของสงครามโลกครั้งที่สอง_(1944)',
#  'Narwhal',
#  'ไอ_อนิเมะ',
#  'รายพระนามเจ้านายพระชันษายืนในราชสกุลรัชกาลที่_1_แห่งพระราชวงศ์จักรี',
#  'มือตบ']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

len(titles)
# Out:
# 353833

# %%
get_samples(titles)
# Out:
# ['รัฐปาเลสไตน์ในโอลิมปิกฤดูร้อน_2020',
#  'เรียว_มิยาอิจิ',
#  'The_Love_Machine_วงล้อ_ลุ้นรัก',
#  'มังกี้_ฮีโร่',
#  'ช่องแคบยิบรอลตา',
#  'สิงห์ผจญเพลิง',
#  'จ็อกกิง',
#  'สาธารณรัฐเบลารุสในพาราลิมปิกฤดูร้อน_2012',
#  'เอาดี้',
#  'บริษัท_ไชโยโปรดักชั่นส์_จำกัด',
#  'เยื่อพรหมจรรย์',
#  'เส้นขนานที่_48',
#  'ประเทศแอฟริกาใต้ในโอลิมปิกเยาวชนฤดูร้อน_2014',
#  'Monotrete_leiurus',
#  'โรโบคอป_3',
#  'First_Anglo-Burmese_War',
#  'มหาวิหารตูลูซ',
#  'ไข่มดแดง',
#  'มาฬิศร์_เชยโสภณ',
#  'ล่าคนดุในเมืองเดือด',
#  'Indiana',
#  'โทนี_แอนเดอร์สัน',
#  'มูลนิธิวงดุริยางค์ซิมโฟนีกรุงเทพ',
#  'โทรทัศน์ความละเอียดสูง',
#  'วัดเป่ากั๋ว',
#  'Trachicephalus',
#  'ธงชาติกาตาร์',
#  'แฮรี่',
#  'เดอะ_เมทริกซ์_:_เพาะพันธุ์มนุษย์เหนือโลก_2199',
#  'ปาตานี',
#  'ลาดัก',
#  'Nic_Nemeth',
#  'ราชวงศ์โจวเหนือ',
#  'สึโทะมุ_โคะยะมะ',
#  'วัดหงส์รัตนารามราชวรวิหาร',
#  'เทศบาลเมืองบ้านไผ่',
#  'เรื่องขบขัน',
#  'โรคโลหิตจางเหตุพร่องธาตุเหล็ก',
#  'อัมเปิลเม็นเชิน',
#  'เซนต์ปีเตอร์เบิร์ก',
#  'อินาสึมะอีเลฟเวน_3_เซไคโนะโชวเชน',
#  'รถไฟฟ้าเสิ่นหยาง',
#  'เมืองมิโน',
#  'แบรด_พิทท์',
#  'Bartolomé_Estéban_Murillo',
#  'Academy_Awards/Writing_Screenplay_Adaptation',
#  'Fiji_Banded_Iguana',
#  'ซาลิม_อาลีโยว_อิบรอม',
#  'FC_Groningen',
#  'ประเทศโกตดิวัวร์',
#  'วัดหนองหมูใต้',
#  'ผลงานซิงเกิลของอิล_ดิโว่',
#  'ไทยรัฐ',
#  'ทัลก์',
#  'TOT_S.C.',
#  'ฝันร้าย',
#  'ทิศพายัพ',
#  'Hymenoceridae',
#  'สโมสรฟุตบอลแบล็คพูล',
#  'รัฐมาร์เกรฟบรันเดินบวร์ค',
#  'Nymphenburg_Palace',
#  'เอไลจาห์_วูด',
#  'กองพัน_SOS',
#  'สนามกีฬาชวาหระลาล_เนห์รู',
#  'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน_2020_–_ทีมหญิง',
#  'ประเทศอิตาลีในโอลิมปิกเยาวชนฤดูหนาว_2020',
#  'จิรายุ_ตั้งศรีสุข',
#  'จังหวัดอาร์มาวีร์',
#  'Cross_of_St_James',
#  'โมเดลทางคณิตศาสตร์',
#  'ธงฉาน',
#  'วัดไตรธรรมาราม',
#  'ชิเบนีก',
#  'Viraat_Ramayan_Mandir',
#  'Yorkshire',
#  'ทิคอนเดโรกา',
#  'การเตรียมกาแฟ',
#  'ไม้ที',
#  'Song_Yuvin',
#  'Haliaeetus_leucocephalus',
#  'มาสค์ไรเดอร์_ซีรีส์',
#  'อัคคีภัยครั้งใหญ่ในลอนดอน_ค.ศ._1666',
#  'เจลลี่_ร็อคเก็ต',
#  'ระบบสายตา',
#  'น่ารัก',
#  'ชาวอินเดีย',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติ_ครั้งที่_47',
#  'นักบุญมรณสักขีแห่งประเทศจีน',
#  'Switzerland',
#  'คณะครุศาสตร์_มหาวิทยาลัยราชภัฏอุตรดิตถ์',
#  'สนธิสัญญาทรียานง',
#  'กาหยี',
#  'Dolores_Huerta',
#  'เอดิต_ยอร์ก',
#  'ไรโบส',
#  'เส้นเมริเดียนที่_50',
#  'Dragon_Ball:_The_Path_to_Power',
#  'ที่หยุดรถไฟบ้านโนนผึ้ง',
#  'จรวยพร_ธรณินทร์',
#  'Santisukia_pagetii']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

len(titles)
# Out:
# 465912

# %%
get_samples(titles)
# Out:
# ['เห็ดเนี๋ยวจังจือ',
#  'เกาลัด',
#  'ตั๊บแซ่ลิ้ม',
#  'Saarland',
#  'ลัทธิอนาธิปไตยสังคมนิยม',
#  'ถนนกำแพงเพชร3',
#  'โยชิฮิซะ',
#  'อาบีดิน',
#  'เรือพระราชพีธีกระบวนพยุหยาตราชลมารค',
#  'แม็กนาวอกซ์โอดีสซี',
#  'Mary,Turkmenistan',
#  'อาร์นไฮม',
#  'ครุยวิทยฐานะในสหรัฐ',
#  'เจพีคัลเดอรอน',
#  'วัดซานตามาเรียเดลเลกราซี',
#  'แพนเซอร์เกรนาดีร์',
#  'BlueRiband',
#  'คัมภีร์ในสารบบ',
#  'พ.ศ.2314',
#  'สุลต่านอิสมาอิลเปตรา',
#  'ค.ศ.887',
#  'Cameroun,',
#  'ไฟลัมไลโคไฟตา',
#  'โทะกิฮิโกะ',
#  'ไซโดเรนโก',
#  'Presliophytum',
#  'แอนโทนิโอแบนเดรัส',
#  'พิศวงไทยทอง',
#  'เส้นขนานที่51',
#  'ประเทศลีชเทินชไตน์ในโอลิมปิกฤดูหนาว2018',
#  'แฮร์รี่พอตเตอร์:ฮอกวอตส์มิสทะรี',
#  'ซูเปอร์สตาร์เจวายพี',
#  'เลบรอน',
#  'แอฟริกาเหนือของอิตาลี',
#  'มาร์เซีย',
#  'มหาวิทยาลัยราชภัฏกำแพงเพชร',
#  'พระเจ้าสูรยวรมันที่',
#  'Vault',
#  'WrestleMania17',
#  'โยฮันน์โวล์ฟกังฟอนเกอเท',
#  'กีรติ',
#  'Maxillipiidae',
#  'Pastel',
#  'พระเจ้ามูแห่งบัลแฮ',
#  'ทางหลวงชนบทนบ.1013',
#  'ชิดชนก',
#  'แก่งสะพือ',
#  'เจฟฟรีโอนาเต้',
#  'สติลเล่อร์',
#  'Prakash',
#  'แฮปปี้',
#  'FyodorDostoevsky',
#  'เจ้าหญิงมารี',
#  'มิทาราชิ',
#  'X–เม็น:กำเนิดวูล์ฟเวอรีน',
#  'กรมปฏิบัติการพิเศษหน่วยบัญชาการอากาศโยธิน',
#  'มุอัมมาร์อัลกัดดะฟี',
#  'เทลิโทรมัยซิน',
#  'Octave',
#  'เบเดล',
#  "Notre-Dame-de-l'Assomption",
#  'ภาษาซึนลาว',
#  'Medicalbandwagon',
#  'เต็กเลา',
#  'สกุลปาหนันช้าง',
#  'โกปาอาเมริกา2019กลุ่มบี',
#  'StephanieMcMahon-Helmsley',
#  'พระเจ้าโจวจวง',
#  'เซนได',
#  'ตำบลโจลกอฮ์',
#  'Pitviper',
#  'สมาคมเอเอสทีเอ็ม',
#  'RyoMiyaichi',
#  'ชียากูซิลวา',
#  'รุกขกาลวิทยา',
#  'อะกอบะฮ์',
#  'แบนแนน',
#  'มิซซี่',
#  'Keep',
#  'พิวดีพายปะทะที-ซีรีส์',
#  'JingKe',
#  'แผ่นดินไหวโลมาพรีเอตตา',
#  'วัดหนองเพียร',
#  'ฟุตซอลในเอเชียนอินดอร์เกมส์',
#  'เพลงชาติปาเลสไตน์',
#  'อาหารอันฮุย',
#  'Boutu',
#  'ทราวิสสก็อตต์',
#  'Tabloidpress',
#  'ตอนเย็น',
#  'LudwigIIofBavaria',
#  'เกงซาโตว',
#  'มาลากอน',
#  'ชาวฮังกาเรียนอเมริกัน',
#  'Dekoboko',
#  'แรงปฏิกิริยา',
#  'ชิซากิ',
#  'อ่าวบอธเนีย',
#  'ฟาโรห์เซนุสเรตที่หนึ่ง',
#  'ฮามิลตงซูวาริส']

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

len(titles)
# Out:
# 346494

# %%
get_samples(titles)
# Out:
# ['ปลามางุโระ',
#  'พระปิ่นเกล้าเจ้าอยู่หัว',
#  'ยางซอม',
#  'ปวดหัว',
#  'เอกนิษฐ์ปัญญา',
#  'เห้ง',
#  'การควบคุมอาหารแบบแม็กโครไบโอติกส์',
#  'สายลับเดอะซีรี่ย์',
#  'ฟีนิกซ์อิคคิ',
#  'ดิจิมอนแอดเวนเจอร์',
#  'โลกธรรม๘',
#  'ยูฟ่ารีเจี้ยนส์คัพ',
#  'อยากตาย',
#  'กลุ่มภาษาอาเจะฮ์-จาม',
#  'วงศ์ย่อยปลาหมอจำปะ',
#  'สนฺตงฺกุโร',
#  'ศิวัฒน์โชติชัยชรินทร์',
#  'โกฐสิงคลี',
#  'หน้าต่างสีชมพูประตูสีฟ้า',
#  'ลูกไทย',
#  'ภูมิคุ้มกันรับมา',
#  'สโมสรฟุตบอลนครราชสีมามาสด้าในฤดูกาล2558',
#  'บรันสวิค-วูลเฟนบืตเตล',
#  'พระสุพาหุเถระ',
#  'อูอี',
#  'เดอะออนะระเบิล',
#  'ภูเขาคิตะ',
#  'เอเตียน-หลุยส์มาลุส',
#  'ชูเอาชิลเบร์ตู',
#  'สหพันธ์ฟุตบอลอัฟกานิสถาน',
#  'มายุมิเนดะ',
#  'ค.ศ.2010',
#  'วงศ์ไฮยีนา',
#  'อนิเมะฤดูกาลที่3',
#  'ไมโครฟิลาเมนต์',
#  'มาซาเฮอร์ตา',
#  'ฟุมิโกะอุจิมุระ',
#  'ฟูจิวาระโนะคาเนฟูซะ',
#  'สิรีภรณ์ยุกตะทัต',
#  'คริสตียงเบนเตเก',
#  'พอร์ตแลนด์',
#  'อูโกกาซาเรส',
#  'ปะฉะดะคนเหนือยุทธ',
#  'พรก.',
#  'ป่าพรุโต๊ะแดง',
#  'พระเจ้าอูซะนาที่',
#  'พิชิตศิษย์บางพระจันทร์',
#  'รายชื่อแขกรับเชิญใน',
#  'ปราสาทคาร์ดิฟฟ์',
#  'ฮาราเร',
#  'จ.ม.',
#  'อาร์ชดยุกคาร์ลดยุกแห่งเทเชิน',
#  'โภคกุลกานนท์',
#  'สาปภูษา',
#  'นักบุญแคทเธอรินแห่งอเล็กซานเดรีย',
#  'ดาวแคระน้ำตาล',
#  'แ',
#  'กรมหมื่นพิทยาลงกรณ์',
#  'พ.ศ.1280',
#  'นีเฮา',
#  'อีกอร์สมอลนีคอฟ',
#  'ชาวโครแอต',
#  'สนามรบจำลอง',
#  'ดรีเมอร์',
#  'เหตุการณ์โจมตีเรือประมงไต้หวันโดยยามชายฝั่งฟิลิปปินส์',
#  'พระเจ้าศิริธรรมจักรพรรดิ',
#  'รายนามประธานรัฐสภาไทย',
#  'เทือกเขาเหิงตฺวั้น',
#  'วาราบิโมจิ',
#  'ชางเกียงกุง',
#  'กีฬาโรลเลอร์สกีในกีฬาแห่งชาติครั้งที่47',
#  'เยลี่ว์หร่วน',
#  'ปิแอร์กิลลอเมเฟรเดริกเลอเปล',
#  'ไอค์เคอ',
#  'ตอมาช',
#  'ริ-เซ่',
#  'ปลาหมอออสเซลาลิส',
#  'เค้กวันเกิด',
#  'เตรียมอุดมศึกษา',
#  'รายชื่อผู้เล่นสโมสรฟุตบอลลิเวอร์พูล',
#  'ฟุตบอลลีกคัพ2000นัดชิงชนะเลิศ',
#  'จิซากิ',
#  'พระเจ้าอีริคที่6แห่งเดนมาร์ก',
#  'พระเจ้าน้องยาเธอพระองค์เจ้าดิศวรกุมารกรมหลวงดำรงราชานุภาพ',
#  'ดาวรอบขั้วฟ้าเหนือ',
#  'วัดชิโนรสารามวรวิหาร',
#  'ศิลปะนีโอคลาสสิก',
#  'วัดบางปลา',
#  'ริคกี้"เดอะดราก้อน"สตีมโบ๊ต',
#  'คณะเทคโนโลยีการเกษตรมหาวิทยาลัยบูรพาวิทยาเขตสระแก้ว',
#  'ฟาโรห์เวเนก-เนบตี้',
#  'ซัมซุงกาแลคซีโน้ต4',
#  'เครื่องราชอิสริยาภรณ์อันมีเกียรติแห่งความกล้าหาญ',
#  'องค์การระหว่างประเทศเพื่อการอนุรักษ์ธรรมชาติ',
#  'ยูโกะซัมเป',
#  'สอาดเปี่ยมพงษ์สานต์',
#  'สือชิงเสวียน',
#  'พายุไต้ฝุ่นนิดา',
#  'อักษรอินุกติตุต',
#  'สเปรย์กระป๋อง']

# %% [markdown]
# ### Seperate colon

# %%
len([title for title in titles if ":" in title])
# Out:
# 1465

# %%
[title for title in titles if ":" in title][:50]
# Out:
# ['เลือดชั่ว:เรื่องลับและคำลวงเบื้องหลังบริษัทดาวรุ่งแห่งซิลิคอนแวลลีย์',
#  'เรฟโวลูชั่นส์:',
#  'ทอมแอนเจอร์รี่:',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:ฟิลาเดลเฟีย',
#  'รายชื่อตอนในเบ็นเท็น:อัลติเมทเอเลี่ยน',
#  'คอลล์ออฟดิวตี:มอเดิร์นวอร์แฟร์',
#  'เดอะเลเจนด์ออฟเซลดา:อะลิงก์ทูเดอะแพสต์และโฟร์ซอดส์',
#  'นักรบมนตรา:',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:บรุกลิน',
#  'หวงเฟยหง:ถล่มวังบัวขาว',
#  'คอลล์ออฟดิวตี:มอเดิร์นวอร์แฟร์III',
#  'สไปเดอร์-แมน:ผงาดข้ามจักรวาลแมงมุม',
#  'เคาน์เตอร์-สไตรก์:',
#  'เบอร์ดีวิง:กอล์ฟเกิร์ลสตอรี',
#  'ชิฟท์2:อันลีชด์',
#  'สตาร์เทรค:',
#  'ยอดนักสืบจิ๋วโคนัน:เจ้าสาวฮาโลวีน',
#  'เดอะเลเจนด์ออฟเซลดา:ทไวไลต์พรินเซสส์',
#  'โรบินฮูด:เดอะเลเจนด์ออฟเชอร์วูด',
#  'แอสแซสซินครีด:รีวีเลชั่นส์',
#  'เทอร์มิเนเตอร์:',
#  'คิงดอมส์ออฟแอมะเลอร์:เรกคอนนิ่ง',
#  'มาสค์ไรเดอร์ริวคิ:เอ็ดพิโซดไฟนอล',
#  'มาเลฟิเซนต์:',
#  'ไมเคิลแจ็กสัน:ดิเอ็กซ์เพอร์เรนช์',
#  'เบ็นเท็น:อัลติเมทเอเลี่ยน',
#  'เดอะซิมส์3:เล็ตไนต์',
#  'โคลสคอมแบต:',
#  'คังคุไบ:',
#  'แฮร์รี่พอตเตอร์:ฮอกวอตส์มิสเตอรี',
#  'ยอดนักสืบจิ๋วโคนัน:เรือดำน้ำทมิฬ',
#  'ไฮห์สกูลมิวสิคัล3:ซีเนียร์เยียร์',
#  'กัปตันอเมริกา:ซีวิลวอร์',
#  'อภินิหารตำนานแห่งนาร์เนีย3:ผจญภัยโพ้นทะเล',
#  'เอ็นเอ๊กซ์ทีเทคโอเวอร์:อาร์เอฟโวลูชั่น',
#  'เซกิโระ:',
#  'อิสลาม:ว็อทเดอะเวสเทิร์นนีดส์ทูโนว์',
#  'คอมมานด์แอนด์คองเคอร์:เจเนรัลส์',
#  'จักรวาลภาพยนตร์มาร์เวล:เฟสห้า',
#  'ICD-10บทV,W,X,และY:สาเหตุภายนอกที่ทำให้เกิดพยาธิภาวะและการตาย',
#  'มายเลิฟ:',
#  'นีดฟอร์สปีด:ฮอตเพอร์ซูท',
#  'มาร์เวลสตูดิโอส์:',
#  '6:66ตายไม่ได้ตาย',
#  'ทีนเอจมิวแตนต์นินจาเทอร์เทิลส์:',
#  'ทรานส์ฟอร์เมอร์ส:สงครามไซเบอร์ทรอนไตรภาค',
#  'เมตันเตโคนัง:',
#  'เซอร์ไวเวอร์ปานามา:เกาะอัปยศ',
#  'มิชชั่น:อิมพอสซิเบิ้ล',
#  'เมโทร:']

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    if ":" in title:
        titles_temp.update(title.split(":"))
    else:
        titles_temp.add(title)
    
titles = titles_temp
len(titles)
# Out:
# 345587

# %%
get_samples(titles)
# Out:
# ['นกนางแอ่นบ้าน',
#  'เบบีวอกซ์รีฟ',
#  'จักรพรรดิเว่ยเต้าอู่',
#  'สมบูรณ์ไพรคุก',
#  'เถื่อนเฉือนระห่ำ',
#  'ฟาโรห์อเมนโฮเทปที่หนึ่ง',
#  'ดิเอ็กซ์แฟกเตอร์ประเทศไทย',
#  'ความจำ',
#  'ซีก',
#  'สวนเบญจกิติ',
#  'วอลลิสดัชเชสแห่งวินด์เซอร์',
#  'ภาษาไทอ่ายตน',
#  'ยุวกาชาดไทย',
#  'เดอะเฟซเวียดนาม',
#  'คลองชุมพร',
#  'อาเล็กซ์เพียร์ซ',
#  'ซันไซน์&ซิตี้ไลท์ส',
#  'พ่อครัวตัวจี๊ด',
#  'นกกด',
#  'สกุลนกกระทุง',
#  'สาธารณรัฐอาร์เมเนียในโอลิมปิกฤดูร้อน2000',
#  'ไฟป่าในรัฐฮาวายพ.ศ.2566',
#  'ยูเอวี',
#  'อะกิฮะบะระ',
#  'เจมส์โจเซฟซิลเวสเตอร์',
#  'กรอจแบนด์',
#  'การเชื่อมเหล็ก',
#  'รักซ้อนซ่อนรัก',
#  'ความเอนเอียงโดยความเข้าถึงได้ง่าย',
#  'โคโซคุเซนไทเทอร์โบเรนเจอร์',
#  'จังหวัดนีเด',
#  'ปอมปาดัวร์น้ำเงิน',
#  'จรูญพงศ์พันธุ์ศรีนคร',
#  'ซิมโฟนีหมายเลข8',
#  'หน่วยบัญชาการยุทธการพิเศษสหรัฐ',
#  'ผู้เล่นในเอเชียนคัพ',
#  'สายพันธุ์ของเชื้อโควิด-19',
#  'ชุมนุมสมัยกรุงธนบุรี',
#  'มาสค์ไรเดอร์Xมาสค์ไรเดอร์ไดรฟ์&ไกมุสงครามไรเดอร์ครั้งใหม่',
#  'ยุกต์ส่งไพศาล',
#  'รูเซล',
#  'พระโพธิสัตว์กวนอิมพันมือแห่งกุยชาน',
#  'ต้นพระชัยศรีมหาโพธิ์',
#  '4ต่อ4ฮอลิเดย์',
#  'โบบาเฟตต์',
#  'อาชวดิศดิศกุล',
#  'ชัยสิงห์ที่',
#  'พระชคันนาถ',
#  'โควิดสายพันธุ์เดลต้า',
#  'สฟาลบาร์และยานไมเอน',
#  'เครือข่ายฟ็อกซ์',
#  '๓๑สิงหาคม',
#  'เลี่ยง',
#  'สีสุวัตถิ์ยุตติวงศ์',
#  'ยุคหลังสงครามโลกครั้งที่2',
#  'ฮาเลย์เดวิดสันสตรีทบ็อบ',
#  'โคเรียนแอร์เที่ยวบินที่801',
#  'ประเทศตองงาในโอลิมปิกฤดูหนาว',
#  'พระไพรีพินาศ',
#  'จิรชัยประวิตร',
#  'วอลเลย์บอลชายชิงแชมป์นอร์เซกา2017',
#  'ฟานก็อกฮ์',
#  'ราชปะแตน',
#  'รายพระนามพระมหากษัตริย์แห่งราชอาณาจักรซิซิลีทั้งสอง',
#  'ยุคคาร์โบนิเฟอรัส',
#  'คณะศึกษาศาสตร์มหาวิทยาลัยขอนแก่น',
#  'จังหวัดธัญญบุรี',
#  'สาธารณรัฐเวียดนามใต้',
#  'เลดีเอลิซาเบธ',
#  'ประเทศโมร็อกโกในโอลิมปิก',
#  'การใส่ท่อช่วยหายใจ',
#  'ส.',
#  'อชิระ',
#  'ซากาอิ',
#  'ดุกลำพัน',
#  'บิกแบง',
#  'บาย',
#  'เฮซอน',
#  'รนิล',
#  'พระครูนิทัศนพลธรรม',
#  'ความน่าจะเป็นบนเส้นขนาน',
#  'ทรงสี่เหลี่ยมจัตุรัส',
#  'เก้ามหากาฬ',
#  'คณะอุตสาหกรรมเกษตร',
#  'เจ้าชายลูทวิชแห่งบัทเทินแบร์ค',
#  'สงครามจักรกล',
#  'ชาจิกุ-ซัง',
#  'ซันดากัน',
#  'แหล่งเหมืองหลักแห่งวอลโลเนีย',
#  'สมาชิกวุฒิสภาจังหวัดชัยนาท',
#  'ปาณินท์',
#  'อิมมอร์แทลิที',
#  'คิมโซอึน',
#  'ขอร้อง',
#  'ตรรมันจัณมุกรัตตินัม',
#  'ฮ็อสตีลิอุส',
#  'เขตรักษาพันธุ์สัตว์ป่าเขาสอยดาว',
#  'มะคุระโนะโซชิ',
#  'พงศ์สันต์',
#  'กองทัพปฏิวัติโซมี']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4992

# %%
get_samples(raay)
# Out:
# ['รายการแหล่งมรดกโลกในประเทศพม่า',
#  'รายชื่อแมว',
#  'รายชื่อแหล่งมรดกโลกในประเทศโมร็อกโก',
#  'รายชื่อของเทศบาลในประเทศไทย',
#  'รายชื่อธงในประเทศฟิลิปปินส์',
#  'รายนามบุคคลที่มีชื่อเสียงจากมหาวิทยาลัยขอนแก่น',
#  'รายชื่ออธิบดีกรมประมง',
#  'รายชื่อรองประธานาธิบดีสหรัฐ',
#  'รายชื่อธงในประเทศเวเนซุเอลา',
#  'รายชื่อแหล่งมรดกโลกในยุโรปใต้',
#  'รายชื่อรางวัลที่ซิสตาร์ได้รับและได้เข้าชิง',
#  'รายชื่อการ์ดไดซ์โอ',
#  'รายชื่อตัวละครในเซียนเกมรักขอเป็นเทพนักจีบ',
#  'รายชื่ออุทยานธรณีโลกในทวีปเอเชีย',
#  'รายชื่อโบราณสถานในจังหวัดสกลนครที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายการวันสำคัญทางศาสนาคริสต์',
#  'รายชื่ออักษรย่อของโรงเรียนในประเทศไทย/ว',
#  'รายชื่อแหล่งมรดกโลกในประเทศเลโซโท',
#  'รายชื่อสกุลในวงศ์Histeridae',
#  'รายชื่อทางแยกในเขตจตุจักร',
#  'รายชื่อตัวละครในเรื่อง',
#  'รายชื่อเลขาธิการสมาคมประชาชาติแห่งเอเชียตะวันออกเฉียงใต้',
#  'รายชื่อแหล่งมรดกโลกในประเทศนิวซีแลนด์',
#  'รายชื่อแคว้นของประเทศทาจิกิสถานเรียงตามดัชนีการพัฒนามนุษย์',
#  'รายนามประมุขแห่งรัฐฮังการี',
#  'รายชื่อภาพยนตร์ไทยพ.ศ.2506',
#  'รายพระนามพระมเหสีพระสนมเอกพระคู่หมั้นและพระราชธิดาในรัชกาลที่6',
#  'รายชื่อสปีชีส์ในสกุลทุเรียน',
#  'รายชื่อศูนย์การค้าในประเทศไทย',
#  'รายชื่อพายุเฮอริเคนแอตแลนติกที่ถูกถอนชื่อ',
#  'รายชื่อประเทศเรียงตามขนาดเครือข่ายทางรถไฟ',
#  'รายพระนามพระมหากษัตริย์และจักรพรรดิเยอรมนี',
#  'รายชื่อผู้ครองตำแหน่งนางงามจักรวาล',
#  'รายชื่อองค์กรปกครองส่วนท้องถิ่นในจังหวัดอุดรธานี',
#  'รายชื่อผลงานวิดีโอของที-อารา',
#  'รายชื่อภาพยนตร์โดยมาร์เวลคอมิกส์',
#  'รายชื่อโบราณสถานในจังหวัดมหาสารคาม',
#  'รายชื่อผลงานเพลงของไมคุระกิ',
#  'รายชื่อธงในสหรัฐอเมริกา',
#  'รายนามประธานาธิบดีสหรัฐ',
#  'รายชื่อผลงานเพลงของสเตรย์คิดส์',
#  'รายชื่อโบราณสถานในจังหวัดบุรีรัมย์ที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อโบราณสถานในจังหวัดศรีสะเกษที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายชื่อเพลงที่บันทึกโดยเทย์เลอร์',
#  'รายชื่อผลงานของเอเคบีโฟร์ตีเอต',
#  'รายพระนามและรายนามผู้เชิญเครื่องพระอิสริยยศ',
#  'รายชื่อประเทศเรียงตามการได้ส่วนแบ่งตลาดจากสมาร์ทโฟน',
#  'รายชื่ออาณาจักรดยุคและขุนนางสืบตระกูลของหมู่เกาะอังกฤษ',
#  'รายชื่อแขกในพระราชพิธีราชาภิเษกของสมเด็จพระเจ้าชาลส์ที่',
#  'รายชื่อตอนในเซียนเกมรัก',
#  'รายชื่อบุคคลสำคัญจากมหาวิทยาลัยสงขลานครินทร์',
#  'รายการเครื่องอิสริยาภรณ์ราชวงศ์ชิง',
#  'รายพระนามและรายนามผู้ได้รับพระราชทานว.ภ.',
#  'รายชื่อพันธุ์ไม้มงคลพระราชทานประจำจังหวัด',
#  'รายชื่อสถานที่ท่องเที่ยวในกรุงเทพมหานคร',
#  'รายนามเวิลด์',
#  'รายพระนามและชื่อบุคคลสำคัญของโลกชาวไทยโดยยูเนสโก',
#  'รายการโทรทัศน์สั้น',
#  'รายชื่อแหล่งมรดกโลกในประเทศโครเอเชีย',
#  'รายชื่อวัดในจังหวัดนนทบุรี',
#  'รายชื่อตอนในการินปริศนาคดีอาถรรพ์',
#  'รายชื่อสวนสัตว์',
#  'รายชื่อนักมวยสากลชาวไทยที่เป็นแชมประดับภูมิภาค',
#  'รายชื่อผู้เล่นในการแข่งขันวอลเลย์บอลหญิงชิงแชมป์สโมสรเอเชีย',
#  'รายพระนามจักรพรรดินีญี่ปุ่น',
#  'รายชื่อสมาชิกวุฒิสภาสหรัฐชุดปัจจุบัน',
#  'รายชื่อรัฐเอกราชเรียงตามสินทรัพย์ต่างประเทศ',
#  'รายพระนามข่านแห่งคาซัค',
#  'รายนามภาพเขียนโดยเลโอนาร์โด',
#  'รายชื่อสนามบินในประเทศไทย',
#  'รายชื่อตัวละครในมิชชั่น',
#  'รายชื่อแชมป์ฟุตบอลเยอรมัน',
#  'รายนามผู้บัญชาการโรงเรียนนายร้อยพระจุลจอมเกล้า',
#  'รายชื่อวัดในจังหวัดสระบุรี',
#  'รายชื่อตัวละครในเกมเรซิเดนต์อีวิล',
#  'รายนามเมธีวิจัยอาวุโสสกว.',
#  'รายชื่อทางแยกในเขตบางกอกน้อย',
#  'รายชื่อเรือสำราญที่ยาวที่สุดในโลก',
#  'รายชื่อแหล่งมรดกโลกในประเทศสวีเดน',
#  'รายชื่อประเทศที่เป็นเกาะ',
#  'รายชื่อโบราณสถานในจังหวัดสุโขทัย/อำเภอเมือง',
#  'รายชื่อเพลงในเรื่องคุณครูจอมเวทเนกิมะ!',
#  'รายชื่อแหล่งมรดกโลกในประเทศศรีลังกา',
#  'รายชื่อตัวละครในเอ็กซีคิวชั่นแนล',
#  'รายชื่อแหล่งมรดกโลกในประเทศโปแลนด์',
#  'รายชื่อตัวละครในโซลอีทเตอร์',
#  'รายชื่อแหล่งมรดกโลกในประเทศไซปรัส',
#  'รายนามรัฐมนตรีช่วยว่าการกระทรวงกลาโหมของไทย',
#  'รายชื่อสายพันธุ์สุนัข',
#  'รายชื่อโบราณสถานในจังหวัดลพบุรีที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'รายนามเสนาบดีและรัฐมนตรีว่าการกระทรวงยุติธรรม',
#  'รายพระนามคู่อภิเษกสมรสในพระมหากษัตริย์ฮาวาย',
#  'รายชื่อโรงเรียนในจังหวัดแม่ฮ่องสอน',
#  'รายชื่อประเทศเรียงตามผลผลิตลิเธียม',
#  'รายชื่อโรงแรมในประเทศไทย',
#  'รายชื่อตัวละครในเกิดชาตินี้พี่ต้องเทพ',
#  'รายนามหัวหน้ารัฐบาลหญิง',
#  'รายชื่อตอนในอินุยาฉะ',
#  'รายชื่อประเทศเรียงตามจำนวนสนามบินเฮลิคอปเตอร์',
#  'รายการอาการในรหัส']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 57

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°C',
#  'รายานนท์',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายวนปูเลาเกอลาปา',
#  'รายงานอาหาร',
#  'รายูวันปูเลาเกอลาปา',
#  'รายปุระ',
#  'รายงานประจำปี',
#  'รายกอวิช',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายาแห่งรัฐปะลิส',
#  'รายวน',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานการประชุม',
#  'รายาฮีเจา',
#  'รายงานกรณี',
#  'รายาแห่งซาราวะก์',
#  'รายงานเค้ส',
#  'รายตา',
#  'ราย',
#  'รายาบีรู',
#  'รายงานความสุขโลก',
#  'รายงานเฮิร์ช',
#  'รายงานผู้ป่วย',
#  'รายวนปูเลาเกอราปา',
#  'รายาอูงู',
#  'รายงานค่าใช้จ่าย',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายาห์',
#  'รายาผิวขาว',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายนานนท์',
#  'รายยวา',
#  'รายาประไหมสุหรีอากง',
#  'รายาแห่งซาราวัก',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายงานเคส',
#  'รายได้ประชาชาติ',
#  'รายคอวิช',
#  'รายงานทีหลัง',
#  'รายากูนิง',
#  'รายได้',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน1.5°ซ.',
#  'รายา',
#  'รายหัว',
#  'รายงานเรื่องอาหาร',
#  'รายได้มูลฐาน']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
len(titles)
# Out:
# 340652

# %%
get_samples(titles)
# Out:
# ['เว่ยเจี้ยน',
#  'ตีนเป็ด',
#  'วัดโพธิวิหาร',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูหนาว1968',
#  'สฺวียฺหวินลี่',
#  'เอ็กซ์พี',
#  'โพรเซสของกระดูกอัลนา',
#  'หนังสือผู้วินิจฉัย',
#  'ความโน้มถ่วงเชิงควอนตัม',
#  'อะลาโหมด',
#  'วัดห้วยบง',
#  'จินปาจิ',
#  'ยอดเขามองต์บลังก์',
#  'ปันวิชัย',
#  'ตามประทีป',
#  'ปะทานุกรมการทำของคาวหวานอย่างฝรั่งแลสยาม',
#  'เปโดรมาริโออัลบาเรซ',
#  'รูดอล์ฟเฮิสส์',
#  'เจ้าหญิงเอลิซาเบธดัชเชสแห่งบราบองต์',
#  'ฟาโรห์ซามาเจิกที่',
#  'สุทินวรรณบวร',
#  'ล้างเผ่าพันธุ์',
#  'กุลจรรยาวิวัฒน์',
#  'แล',
#  'อาเธอร์ฑูตจิ๋วเจาะขุมทรัพย์มหัศจรรย์',
#  'ยุทธการวูสเตอร์',
#  'ซามูไรคิโยโมริ',
#  'ฐณัณญาญ์',
#  'องค์ชายควางแฮ',
#  'ภาวะต้นกำเนิดต่างกัน',
#  'วรกมลชาเตอร์',
#  '5พยัคฆ์พิทักษ์ซุนยัดเซ็น',
#  'สเวดแบร์ย',
#  'รอยนูนรูปกระสวย',
#  'บอสตันมาราธอน',
#  'หมู่เกาะสุรินทร์',
#  'วงศ์ตาล',
#  'เฮิส',
#  'ไฮโก',
#  'คริสตัง',
#  'คุโรโบกุชิ',
#  'ไทยลีก3',
#  'คะสะเนะเตโตะ',
#  'ตลาดท่าเตียน',
#  'สรุปเหรียญโอลิมปิกฤดูหนาว1952',
#  'ธีระพันธ์',
#  'อำเภอธนบุรี',
#  'ทฤษฎีเซต',
#  'รอบสุดท้าย',
#  'กิลฟีชิกูร์สสัน',
#  'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน1992',
#  'รถไฟฟ้าไลท์เรล',
#  'วิภัชชวาท',
#  'แรง',
#  'เอ็นเตอร์เทนเมนต์วีกลี',
#  'ปกติสุรทิน',
#  'ซูตันชะฮ์รีร์',
#  'เดอลูน่า',
#  'โนเกียลูเมีย1320',
#  'กำเนิดสปีชีส์',
#  'บาตูตุด',
#  'โคย',
#  'เบญจรัตน์',
#  'จังหวัดเวียงจันทน์',
#  'กำปั่นกัมปนาทแสนยากร',
#  'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน2020–รอบคัดเลือกชาย',
#  'กระเพาะอาหาร',
#  'จีเอฟดับเบิลยูวูเมนแชมเปี้ยนชิพ',
#  'ก่อนคริสต์ศตวรรษที่',
#  'สมบูรณ์สุขนิยมศิริ',
#  'วอลเลย์บอลหญิงชิงแชมป์สโมสรเอเชีย2017',
#  'ศรสงคราม',
#  'ซานติอาโก้เบอร์นาบิว',
#  'โทรภาพ',
#  'กีฬาเบรกกิ้งในโอลิมปิกฤดูร้อน',
#  'งานเป่ายิ้งฉุบเลือกเซ็มบัตสึบีเอ็นเคโฟร์ตีเอตประจำปี2563',
#  'สุศรุตะ',
#  'ออตโตคาร์ที่2แห่งโบฮีเมีย',
#  'อิตส์พอสซิเบิล',
#  'วิลลีกาบาเยโร',
#  'โมโมโกะทานิ',
#  'รถรางในเวียนนา',
#  'พระราชพงศาวดารไทย',
#  'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–เซเบอร์บุคคลหญิง',
#  'อัลไซโอเน่',
#  'อาร์เอส.ฟิล์มแอนด์ดิสทริบิวชั่น',
#  'อำเภอแจ้ห่ม',
#  'แชร์พอยต์',
#  'ติกรีต',
#  'ยูริชิราโทริ',
#  'รัฐฉัตตีสครห์',
#  'โกะรรันกุฬังงรเทวีเกษตรัง',
#  'เอมีลลูเบต์',
#  'พระเจ้าเฟรดริคที่2แห่งปรัสเซีย',
#  'ปลาบิน',
#  'หมู่เกาะทะเลจีนใต้',
#  'มลรัฐอิลลินอยส์',
#  'วิชิตสุรพงษ์ชัย',
#  'เจ้าฟ้าสิงหาราชธานีเจ้าฟ้าหลวงชายแก้ว',
#  'เอกซ์เรย์']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [titles for titles in titles if "ใน" in titles]
len(nai)
# Out:
# 18740

# %%
[nai][:50]
# Out:
# [['ประเทศเลโซโทในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศกาบูเวร์ดีในโอลิมปิกฤดูร้อน2008',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศมองโกเลียพ.ศ.2563',
#   'กีฬากระโดดน้ำในโอลิมปิกฤดูร้อน2024–รอบคัดเลือก',
#   'กีฬาบิลเลียดในกีฬาแห่งชาติครั้งที่45',
#   'สมาคมกีฬากรีฑาแห่งประเทศไทยในพระบรมราชูปถัมภ์',
#   'ประเทศจีนในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน2000',
#   'ประเทศญี่ปุ่นในพาราลิมปิกฤดูร้อน',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูร้อน1972',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูหนาว1928',
#   'การลงมติเลือกนายกรัฐมนตรีในประเทศไทย',
#   'ประเทศบราซิลในพาราลิมปิกฤดูร้อน2012',
#   'ประเทศอินเดียในโอลิมปิกฤดูร้อน1964',
#   'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูร้อน2004',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูร้อน2020',
#   'บุคคลที่เกิดในปีพ.ศ.2536',
#   'ในทวีปแอฟริกา',
#   'ประเทศจีนในโอลิมปิก',
#   'สนามกีฬาในร่มกลางเทศบาลโอซากะ',
#   'ประเทศกรีซในโอลิมปิกฤดูร้อน1936',
#   'ประเทศซิมบับเวในโอลิมปิกฤดูร้อน2016',
#   'ประเทศอินเดียในพาราลิมปิกฤดูร้อน2020',
#   'ตัวละครที่ปรากฎใน',
#   'ประเทศฟินแลนด์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'เหตุโจมตีด้วยขีปนาวุธในแชร์นีฮิวเดือนสิงหาคมพ.ศ.2566',
#   'จังหวัดพิจิตรในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศสิงคโปร์ในโอลิมปิก',
#   'สโมสรฟุตบอลมหาวิทยาลัยเกษตรศาสตร์ในฤดูกาล2560',
#   'รัฐอิสราเอลในโอลิมปิก',
#   'ประเทศไนเจอร์ในโอลิมปิกฤดูร้อน',
#   'ธงต่างๆในประเทศเคนยา',
#   'กีฬาฟุตบอลในซีเกมส์2013',
#   'สาธารณรัฐโบลิเวียในโอลิมปิกฤดูร้อน1988',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2020–เปอร์ซูตทีมหญิง',
#   'กีฬากรีฑาในซีเกมส์2017–กระโดดค้ำถ่อชาย',
#   'ประเทศไทยในพ.ศ.2422',
#   'ประเทศอินเดียในโอลิมปิกฤดูร้อน1984',
#   'เจ้าจอมมารดาแก้วในรัชกาลที่3',
#   'กีฬากรีฑาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ทางหลวงที่ยาวที่สุดในประเทศไทย',
#   'วอลเลย์บอลชายในโอลิมปิกฤดูร้อน2012รอบคัดเลือก',
#   'บันทึกการประชุมของสยามสมาคมในพระบรมราชูปถัมภ์',
#   'กรีฑาในกีฬาแห่งชาติครั้งที่41–วิ่งฮาร์ฟมาราธอน21กิโลเมตรชาย',
#   'กีฬาเรือพายในโอลิมปิกฤดูร้อน1928',
#   'ประเทศซีเรียในเอเชียนเกมส์2018',
#   'ประเทศญี่ปุ่นในโอลิมปิกฤดูร้อน1952',
#   'ชิงร้อยชิงล้านครั้งหนึ่งในชีวิต',
#   'ประเทศออสเตรียในโอลิมปิกฤดูหนาว',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1952',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูร้อน1996',
#   'ประเทศสวีเดนในพาราลิมปิกฤดูร้อน',
#   'แผ่นดินไหวในประเทศญี่ปุ่นพ.ศ.2554',
#   'ประเทศฮังการีในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศเซนต์ลูเชียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'นโยบายแยกคนต่างผิวในแอฟริกาใต้',
#   'เหตุประท้วงในอียิปต์เนื่องจากไม่พอใจรัฐบาลต่อการสอบสวนการเสียชีวิตของประชาชน',
#   'ประเทศจีนไทเปในโอลิมปิกฤดูร้อน2012',
#   'กีฬาสกีผสมในโอลิมปิก',
#   'ประเทศบัลแกเรียในโอลิมปิกฤดูร้อน2024',
#   'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน2000',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกฤดูหนาว2002',
#   'ประเทศฮังการีในโอลิมปิก',
#   'กีฬาเคอร์ลิงในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'ประเทศเลบานอนในโอลิมปิกฤดูหนาว2010',
#   'ประเทศไนเจอร์ในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูหนาว2010',
#   'การขนส่งระบบรางในประเทศเยอรมนี',
#   'กีฬาฮอกกี้ในเอเชียนเกมส์',
#   'ประเทศไทยในพ.ศ.2379',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศเม็กซิโก',
#   'ประเทศออสเตรียในพาราลิมปิกฤดูหนาว2010',
#   'ในประเทศซิมบับเว',
#   'วอลเลย์บอลในโอลิมปิกรอบคัดเลือกระดับโลกและโซนเอเชีย',
#   'ในทำเนียบขาว',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–วิ่ง5,000เมตรบุคคลชาย',
#   'สาธารณรัฐทาจิกิสถานในเอเชียนเกมส์',
#   'เหตุโจมตีในมหาวิทยาลัยคาบูล',
#   'ประเทศเปรูในโอลิมปิกฤดูหนาว2010',
#   'กีฬาเรือพายในโอลิมปิกฤดูร้อน2016',
#   'กีฬากอล์ฟในโอลิมปิกฤดูร้อน2020–บุคคลชาย',
#   'ข้าพเจ้าเชื่อวางใจในพระเจ้า',
#   'กีฬาขี่ม้าในโอลิมปิกฤดูร้อน1932',
#   'ประเทศไทยในพ.ศ.2465',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2020–คายัค1ฝีพายสปรินท์1,000เมตรบุคคลชาย',
#   'กีฬากระโดดน้ำในซีเกมส์2019',
#   'ประเทศเยอรมนีในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศรัสเซียใน',
#   'ประเทศมอลโดวาในโอลิมปิกฤดูหนาว',
#   'ตัวละครในยอดนักสืบจิ๋ว',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูร้อน1932',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน2004',
#   'ประเทศจีนในเอเชียนอินดอร์เกมส์2005',
#   'สงครามในอัฟกานิสถาน',
#   'แผ่นดินไหวในเฮติพ.ศ.2553',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน2020–ยิมนาสติกสากลชายรอบคัดเลือก',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'เทศบาลในประเทศไทย',
#   'ซากดึกดำบรรพ์ในช่วงการเปลี่ยนแปลง',
#   'ประเทศนอร์เวย์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศฟีจีในโอลิมปิกฤดูร้อน2000',
#   'กีฬาขี่ม้าในแพนอเมริกันเกมส์',
#   'การคมนาคมในกัวลาลัมเปอร์',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1948',
#   'เหตุการณ์สำคัญในรัชสมัยสมเด็จพระเจ้าตากสินมหาราช',
#   'ประเทศคิวบาในโอลิมปิกฤดูร้อน2012',
#   'ราชอาณาจักรเลโซโทในโอลิมปิกฤดูร้อน',
#   'นักกีฬาคณะกรรมการโอลิมปิกรัสเซียในโอลิมปิกฤดูร้อน2020',
#   'ประเทศตูนิเซียในโอลิมปิกฤดูร้อน2012',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูร้อน1924',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูร้อน2024',
#   'กีฬาสเกตความเร็วระยะสั้นในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศเอริเทรียในโอลิมปิกฤดูร้อน2012',
#   'ประเทศโมซัมบิกในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'สาธารณรัฐฮอนดูรัสในโอลิมปิกฤดูร้อน2008',
#   'ตัวละครในจีทีโอคุณครูพันธุ์หายาก',
#   'เอชไอวี/เอดส์ในแอฟริกา',
#   'สาธารณรัฐสังคมนิยมเวียดนามในโอลิมปิกฤดูร้อน1956',
#   'กีฬาโรคในโอลิมปิกฤดูร้อน1904',
#   'กีฬาโปโลน้ำในโอลิมปิกฤดูร้อน1928',
#   'ราชอาณาจักรสวาซิแลนด์ในโอลิมปิกฤดูร้อน1984',
#   'ตัวละครในLucky☆Star',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2551',
#   'เซปักตะกร้อในเอเชียนเกมส์2014',
#   'ฟุตบอลในโอลิมปิกฤดูร้อน1980',
#   'ประเทศบอตสวานาในโอลิมปิก',
#   'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิกฤดูร้อน2016',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1988',
#   'เหตุกราดยิงโบสถ์ในชาร์ลสตัน',
#   'ประเทศจาเมกาในโอลิมปิกฤดูหนาว1988',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน1920',
#   'ประเทศลิทัวเนียในโอลิมปิกฤดูร้อน2024',
#   'กีฬามวยในซีเกมส์',
#   'โบว์ลิ่งในกีฬาแห่งชาติครั้งที่41–หญิงเดี่ยว',
#   'ปริมาณเฉลี่ยของฮีโมโกลบินในเม็ดเลือดแดง',
#   'รัฐคูเวตในโอลิมปิกฤดูร้อน1984',
#   'ประเทศชิลีในพาราลิมปิกฤดูร้อน2020',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน1928',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน2012–ฟรีสไตล์ไม่เกิน74กิโลกรัมชาย',
#   'ประเทศมอลตาในโอลิมปิกฤดูหนาว2018',
#   'วิทยาลัยในวังหญิง',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน1992',
#   'กีฬารักบี้ในโอลิมปิกฤดูร้อน1908',
#   'เบลเยียมในสงครามโลกครั้งที่สอง',
#   'ประเทศออสเตรียในพาราลิมปิกฤดูร้อน2016',
#   'ประเทศไทยในโอลิมปิกฤดูร้อน2020',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดชุมพร',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว1980',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล2006–07',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูร้อน1900',
#   'เนเธอร์แลนด์แอนทิลลิสในโอลิมปิกฤดูร้อน',
#   'สหราชอาณาจักรในโอลิมปิกฤดูหนาว2010',
#   'จังหวัดจันทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'ประเทศฮังการีในโอลิมปิกฤดูร้อน1976',
#   'กีฬายิงปืนในเอเชียนเกมส์2014',
#   'วิกฤตการณ์ในประเทศเวเนซุเอลา',
#   'สโมสรวอลเลย์บอลชายนครราชสีมาในฤดูกาล2018–19',
#   'พระราชสกุลวงศ์ในรัชกาลปัจจุบัน',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน1980',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1975–76',
#   'จังหวัดนครพนมในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'โซชีเอตาสปอร์ตีวากัลโชนาโปลีในฤดูกาล2019–20',
#   'แผ่นดินไหวและคลื่นสึนามิในทะเลญี่ปุ่น',
#   'ประเทศเยอรมนีในพาราลิมปิกฤดูร้อน2016',
#   'การเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2565',
#   'วัดบางพลีใหญ่ใน',
#   'ปลาที่ว่ายในสนามฟุตบอล',
#   'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'ประเทศชิลีในโอลิมปิกฤดูหนาว1964',
#   'สโมสรฟุตบอลขอนแก่นในฤดูกาล2561',
#   'สาธารณรัฐมอนเตเนโกรในโอลิมปิกฤดูหนาว2010',
#   'ประเทศโรมาเนียในโอลิมปิกฤดูหนาว1964',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกฤดูร้อน1964',
#   'โรคระบาดครั้งใหญ่ในกรุงลอนดอน',
#   'ประเทศมองโกเลียในพาราลิมปิกฤดูร้อน2016',
#   'การสมรสเพศเดียวกันในแคนาดา',
#   'ประเทศเลบานอนในเอเชียนเกมส์2006',
#   'กีฬาฟุตบอลชายในโอลิมปิกฤดูร้อน2020–รอบคัดเลือก',
#   'มณฑลในเบลเยียม',
#   'ประเทศออสเตรียในโอลิมปิกฤดูหนาว1988',
#   'กีฬาเทนนิสในเอเชียนเกมส์2014',
#   'การเลือกตั้งระดับท้องถิ่นในกัมพูชาพ.ศ.2555',
#   'แบดมินตันทีมชายในเอเชียนเกมส์',
#   'สโมสรฟุตบอลอินแตร์นาซีโอนาเลมีลาโนในฤดูกาล',
#   'เวทมนตร์ในคุณครูจอมเวทเนกิมะ!',
#   'ประเทศเลบานอนในโอลิมปิกฤดูหนาว1984',
#   'เขตบริหารพิเศษฮ่องกงในเอเชียนเกมส์2022',
#   'ผู้กล่าวคำปฏิญาณตนในพิธีเปิดกีฬาโอลิมปิก',
#   'เจ้าคุณจอมมารดาแพในรัชกาลที่5',
#   'สโมสรฟุตบอลสิงห์เชียงรายยูไนเต็ดในฤดูกาล2561',
#   'ประเทศฝรั่งเศสในโอลิมปิก',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1900',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2476',
#   'SchoolDays-เธอฉัน,ในวันฟ้าคราม',
#   'กีฬาสกีกระโดดไกลในโอลิมปิกเยาวชนฤดูหนาว2012',
#   'นักกีฬาโอลิมปิกอิสระในโอลิมปิกฤดูร้อน',
#   'หมู่เกาะเคย์แมนในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'สาธารณรัฐสังคมนิยมเวียดนามในเอเชียนเกมส์1954',
#   'ชินลงในซีเกมส์',
#   'การก่อการกำเริบในลิเบีย',
#   'ประเทศมาดากัสการ์ในโอลิมปิกฤดูหนาว2022',
#   'สโมสรฟุตบอลอินแตร์นาซีโอนาเลมีลาโนในฤดูกาล2020–21',
#   'ขบวนการหน้ากากกายฟอกส์ในประเทศไทย',
#   'สโมสรฟุตบอลลีโอเชียงรายยูไนเต็ดในฤดูกาล2564–2565',
#   'ประเทศโรมาเนียในโอลิมปิกฤดูหนาว2018',
#   'วอลเลย์บอลชายในโอลิมปิกรอบคัดเลือกโซนเอเชีย2020',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูร้อน1952',
#   'ประเทศไทยในพ.ศ.2449',
#   'รัฐประหารในประเทศชีลีพ.ศ.2516',
#   'กีฬาโครเกในโอลิมปิกฤดูร้อน1900',
#   'เหตุโจมตีในคาบูลเดือนพฤษภาคมพ.ศ.2560',
#   'กีฬาเทเบิลเทนนิสในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูหนาว1980',
#   'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน1988',
#   'บุคคลที่เกิดในปีพ.ศ.2540',
#   'แผ่นดินไหวในจังหวัดโอซากะพ.ศ.2561',
#   'อนิเมะในปีพ.ศ.2565',
#   'ทางหลวงพิเศษระหว่างเมืองในประเทศไทย',
#   'กีฬากระโดดน้ำในโอลิมปิกฤดูร้อน2012',
#   'กีฬาหมากล้อมในเอเชียนเกมส์',
#   'จักรวรรดิจีนยืนยงในจักรวาลอย่างกล้าหาญ',
#   'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในโอลิมปิกฤดูหนาว1998',
#   'รัฐกาตาร์ในโอลิมปิก',
#   'มาเก๊าในพาราลิมปิกฤดูร้อน',
#   'อเมริกันซามัวในโอลิมปิก',
#   'กีฬาคนพิการในประเทศไทย',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูหนาว1998',
#   'ประเทศอินโดนีเซียในโอลิมปิก',
#   'กีฬากระโดดน้ำในโอลิมปิกฤดูร้อน1932',
#   'ธงในประเทศมอลตา',
#   'กีฬามวยในซีเกมส์2013',
#   'ประเทศตุรกีในโอลิมปิกฤดูหนาว1964',
#   'กีฬาฟุตบอลชายในโอลิมปิกฤดูร้อน1980–รอบคัดเลือก',
#   'ความไม่สงบนิยมรัสเซียในประเทศยูเครน',
#   'รถยนต์พระที่นั่งในสมเด็จพระบรมโอรสาธิราชฯ',
#   'วันที่ในจักรวาลสตาร์วอร์ส',
#   'ประเทศเยอรมนีในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สถิติในฟุตบอลโลก2018',
#   'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน2000',
#   'เหตุแผ่นดินถล่มในประเทศโคลอมเบีย',
#   'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูหนาว2006',
#   'สาธารณรัฐฟิลิปปินส์ในโอลิมปิกฤดูร้อน2004',
#   'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน1976',
#   'การเลือกตั้งทั่วไปในประเทศพม่าพ.ศ.2558',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1920',
#   'อาการเหมือนมีก้อนในลำคอ',
#   'การไปรษณีย์ในประเทศไทย',
#   'รักร่วมเพศในประเทศญี่ปุ่น',
#   'สิทธิในการถูกลืม',
#   'จังหวัดชัยภูมิในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'การฉีดวัคซีนโรคติดเชื้อไวรัสโคโรนา2019ในประเทศไทย',
#   'ดาวเคราะห์ในระบบดาวคู่',
#   'ศาสนาพุทธในประเทศอินโดนีเซีย',
#   'การระบาดทั่วของโควิด-19ในประเทศมาดากัสการ์',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกฤดูร้อน',
#   'เจ้าจอมมารดาน้อยในรัชกาลที่4',
#   'สถิติในฟีฟ่าคอนเฟเดอเรชันส์คัพ',
#   'ประเทศปากีสถานในเอเชียนเกมส์ฤดูหนาว2017',
#   'ประเทศเวเนซุเอลาในโอลิมปิกฤดูร้อน2000',
#   'อาวุธและวิชาโจมตีในเทพมรณะ',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน1996',
#   'การประท้วงในเกาหลีใต้พ.ศ.2559',
#   'กีฬาคริกเกตในโอลิมปิกฤดูร้อน1900',
#   'สาธารณรัฐมาดากัสการ์ในโอลิมปิกฤดูร้อน1972',
#   'สาธารณรัฐโครเอเชียในโอลิมปิกฤดูร้อน2008',
#   'ประเทศโบลิเวียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2012–ฟอยล์ทีมหญิง',
#   'ราชอาณาจักรสวาซิแลนด์ในโอลิมปิกฤดูร้อน1988',
#   'ประเทศตองงาในพาราลิมปิกฤดูร้อน',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–ฟอยล์บุคคลหญิง',
#   'ประเทศแทนซาเนียในโอลิมปิกฤดูร้อน1984',
#   'ราชอาณาจักรสวาซิแลนด์ในโอลิมปิก',
#   'องค์การนักศึกษาในประเทศไทย',
#   'ประเทศตูนิเซียในโอลิมปิกฤดูร้อน2020',
#   'ประเทศยูเครนในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'นักกีฬาโอลิมปิกเฉพาะบุคคลในเอเชียนบีชเกมส์',
#   'สาธารณรัฐซาอีร์ในโอลิมปิกฤดูร้อน1992',
#   'ประเทศเช็กโกสโลวาเกียในโอลิมปิกฤดูหนาว1960',
#   'กีฬาฟุตบอลในเอเชียนเกมส์2018–ทีมชาย',
#   'รถยนต์พระที่นั่งในสมเด็จพระนางเจ้าสิริกิติ์พระบรมราชินีนาถ',
#   'ภาวะมีกรดไอโซวาลิริกในเลือด',
#   'กีฬาแบดมินตันในกีฬาแห่งชาติ',
#   'กีฬาซอฟต์เทนนิสในเอเชียนเกมส์2022',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูหนาว1960',
#   'ประเทศญี่ปุ่นในกีฬาภูมิภาคเอเชียตะวันออก1993',
#   'ประเทศอันดอร์ราในพาราลิมปิกฤดูร้อน2012',
#   'ประเทศกรีเนดาในโอลิมปิกฤดูร้อน2020',
#   'จังหวัดพิษณุโลกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'กีฬามวยปล้ำชายหาดในเวิลด์บีชเกมส์',
#   'สหพันธรัฐเซนต์คิตส์และเนวิสในโอลิมปิกฤดูร้อน1996',
#   'สโมสรฟุตบอลบาร์เซโลนาในฤดูกาล2013–14',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–วิ่ง400เมตรบุคคลหญิง',
#   'ประเทศมองโกเลียในโอลิมปิกฤดูหนาว',
#   'ละครใน',
#   'ประเทศสวีเดนในโอลิมปิกฤดูหนาว1928',
#   'ประเทศอิตาลีในโอลิมปิกฤดูร้อน1960',
#   'สาธารณรัฐโดมินิกันในพาราลิมปิกฤดูร้อน',
#   'สาธารณรัฐสังคมนิยมเวียดนามในโอลิมปิก',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน1992',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1987–88',
#   'มุมปากตกขณะร้องไห้ในทารก',
#   'ธงในประเทศเวลส์',
#   'กีฬาโครเก็ตในโอลิมปิกฤดูร้อน1900',
#   'กีฬาฟันดาบในโอลิมปิกฤดูร้อน2020–ฟอยล์บุคคลชาย',
#   'ประเทศซูดานในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศไทยในพ.ศ.2474',
#   'เทเบิลเทนนิสในซีเกมส์',
#   'ระบบการเขียนในอเมริกากลาง',
#   'พระราชสวามีและพระมเหสีในพระมหากษัตริย์แห่งสหราชอาณาจักร',
#   'ประเทศโกตดิวัวร์ในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศเบลีซในโอลิมปิกฤดูร้อน1976',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'อุทกภัยในประเทศไทยพ.ศ.2538',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน2020–ทีมหญิง',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูร้อน1996',
#   'เขตบริหารพิเศษฮ่องกงในเอเชียนเกมส์2018',
#   'เรือดำน้ำในอาเซียน',
#   'อัตราเร็วในวงโคจร',
#   'ประเทศโมร็อกโกในโอลิมปิกฤดูร้อน2004',
#   'ประเทศซามัวในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศบาฮามาสในโอลิมปิกฤดูร้อน2016',
#   'สาธารณรัฐประชาชนจีนในโอลิมปิกฤดูหนาว2002',
#   'กีฬายิงธนูในโอลิมปิกฤดูร้อน2020–ทีมหญิง',
#   'ฟันกรามซี่ในสุด',
#   'ธงในประเทศยิบบอลตาร์',
#   'ประเทศเลบานอนในเอเชียนเกมส์ฤดูหนาว',
#   'นิคมประชาชนชาวยูเครนในประเทศแมนจู',
#   'ประเทศเลโซโทในโอลิมปิกฤดูร้อน2000',
#   'โทรทัศน์ประเทศไทยในค.ศ.1977',
#   'ประเทศโคลอมเบียในโอลิมปิกฤดูร้อน2012',
#   'กีฬายิงปืนในโอลิมปิกฤดูร้อน1912',
#   'ประเทศญี่ปุ่นในปี',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน2020–3x3ทีมชาย',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2020–บีเอ็มเอ็กซ์ฟรีสไตล์บุคคลชาย',
#   'กีฬาเบสบอลในโอลิมปิกฤดูร้อน1956',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน2020–ว่ายผลัดท่าผสม4×100เมตรทีมผสม',
#   'แผ่นดินไหวในเกาะลมบกกรกฎาคมพ.ศ.2561',
#   'สโมสรฟุตบอลอาร์เซนอลในฤดูกาล',
#   'ประเทศลัตเวียในโอลิมปิกฤดูร้อน2024',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน2020–รอบคัดเลือกหญิง',
#   'สาธารณรัฐคองโกในโอลิมปิกฤดูร้อน1996',
#   'ประเทศคาซัคสถานในโอลิมปิกฤดูหนาว',
#   'ประเทศซูรินามในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'พระนามทรงกรมของพระราชโอรสและพระราชธิดาในรัชกาลที่๒',
#   'ประเทศเวียดนามในซีเกมส์2023',
#   'จังหวัดมหาสารคามในการเลือกตั้งนายกองค์การบริหารส่วนจังหวัดในประเทศไทยพ.ศ.2563',
#   'เจ้าชายในหอคอยแห่งลอนดอน',
#   'กีฬาสควอชในซีเกมส์2015',
#   'ประเทศอิหร่านในโอลิมปิกฤดูหนาว1956',
#   'ประเทศแอฟริกาใต้ในพาราลิมปิกฤดูร้อน1964',
#   'ประเทศออสเตรียในโอลิมปิกฤดูร้อน1996',
#   'ประเทศคอโมโรสในโอลิมปิกฤดูร้อน2012',
#   'แบดมินตันทีมหญิงในเอเชียนเกมส์2014',
#   'สาธารณรัฐปารากวัยในโอลิมปิกฤดูร้อน1996',
#   'การประท้วงในประเทศซูดานพ.ศ.2561–2562',
#   'สโมสรวอลเลย์บอลชายนครราชสีมาในฤดูกาล2017–18',
#   'ซีลอนในโอลิมปิกฤดูร้อน',
#   'กีฬายูโดในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ศาสนาในประเทศลาว',
#   'เขตบริหารพิเศษฮ่องกงในโอลิมปิกฤดูร้อน2000',
#   'พุทธศาสนาในประเทศศรีลังกา',
#   'กีฬาเรือพายในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ประเทศเบนินในโอลิมปิกฤดูร้อน2020',
#   'ราชรัฐลักเซมเบิร์กในโอลิมปิกฤดูร้อน1968',
#   'เข็มราชการในพระองค์',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูหนาว2010',
#   'โมเสสในทัศนะของอิสลาม',
#   'ประเทศนิการากัวในโอลิมปิกฤดูร้อน2016',
#   'สโมสรฟุตบอลสุพรรณบุรีในฤดูกาล2559',
#   'ประเทศอิตาลีในโอลิมปิกฤดูร้อน1936',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน1936',
#   'ผู้เล่นในฟุตบอลชิงแชมป์แห่งชาติยุโรป2020',
#   'เรื่องอื้อฉาวในโบฮีเมีย',
#   'การระบาดทั่วของโควิด-19ในประเทศทาจิกิสถาน',
#   'สโมสรฟุตบอลเรกซัมในฤดูกาล2023–24',
#   'ตัวละครในโค้ดกีอัส',
#   'ประเทศเวเนซุเอลาในโอลิมปิกฤดูหนาว2014',
#   'ประเทศเกาหลีเหนือในโอลิมปิกฤดูหนาว2018',
#   'สาธารณรัฐไซปรัสในโอลิมปิกฤดูร้อน1996',
#   'กีฬาวอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน2012–รอบคัดเลือก',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2020–จักรยานทางไกลบุคคลหญิง',
#   'สาธารณรัฐประชาธิปไตยประชาชนเกาหลีในโอลิมปิกฤดูหนาว',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2008',
#   'กีฬาจานร่อนในเวิลด์เกมส์2022',
#   'กีฬาเบสบอลในโอลิมปิกฤดูร้อน2020–รอบคัดเลือก',
#   'กีฬาเฌอเดอโปมในโอลิมปิกฤดูร้อน1908',
#   'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิกเยาวชนฤดูร้อน',
#   'เด่นทักษิณศูนย์กีฬาน้อยใน',
#   'เจ้านายพระชันษายืนในราชสกุลรัชกาลที่3แห่งพระราชวงศ์จักรี',
#   'สหภาพเมียนมาร์ในโอลิมปิกฤดูร้อน2000',
#   'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'ประเทศแองโกลาในโอลิมปิกฤดูร้อน2000',
#   'ความผิดปกติในความคิด',
#   'กีฬาวอลเลย์บอลชายหาดในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'การก่อกำเริบในหุบเขาเพรเชวอ',
#   'ประเทศมอริเตเนียในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศแอลจีเรียในพาราลิมปิก',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1995–96',
#   'ฮอกกี้ในซีเกมส์2015',
#   'ประเทศสวีเดนในโอลิมปิกฤดูหนาว1976',
#   'การบันทึกภาพในประสาท',
#   'ในพระบรมราชูปถัมภ์',
#   'ประเทศไทยในพ.ศ.2514',
#   'สาธารณรัฐเฮติในโอลิมปิกฤดูร้อน1984',
#   'กีฬาลูชในโอลิมปิกเยาวชนฤดูหนาว2012',
#   'การช่วยเหลือด้านมนุษยธรรมต่อเหตุแผ่นดินไหวและคลื่นสึนามิในโทโฮกุ',
#   'สภาคริสตจักรในประเทศไทย',
#   'กีฬายิงธนูในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐยูกันดาในโอลิมปิก',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1924',
#   'ประเทศจิบูตีในโอลิมปิกฤดูร้อน2000',
#   'เหตุรถบัสพลิกคว่ำในเวนิสพ.ศ.2566',
#   'สโมสรฟุตบอลชลบุรีในฤดูกาล',
#   'รัฐเดลาแวร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรค.ศ.1798',
#   'กีฬาสเกตความเร็วในโอลิมปิกเยาวชนฤดูหนาว2020–ประเภทบุคคลชาย1,500เมตร',
#   'เบลารุสภายใต้การยึดครองของเยอรมันในสงครามโลกครั้งที่สอง',
#   'แผ่นดินไหวในอิยาเปล',
#   'ประเทศนอร์ทมาซิโดเนียในโอลิมปิกฤดูร้อน',
#   'อัคคีภัยครั้งใหญ่ในกรุงโรม',
#   'ราชอาณาจักรกัมพูชาในเอเชียนเกมส์1954',
#   'สาธารณรัฐเอสโตเนียในโอลิมปิกฤดูร้อน2000',
#   'การระบาดทั่วของโควิด-19ในสาธารณรัฐประชาชนโดเนตสค์',
#   'ประเทศอาเซอร์ไบจานในโอลิมปิกเยาวชนฤดูหนาว',
#   'ราชรัฐอันดอร์ราในโอลิมปิกฤดูร้อน1984',
#   'เหตุโจมตีในลีแยฌ',
#   'กีฬาคอร์ฟบอลในโอลิมปิกฤดูร้อน1920',
#   'กีฬาระบำใต้น้ำในโอลิมปิกฤดูร้อน2020–หญิงคู่',
#   'กีฬาแฟลกฟุตบอลในเวิลด์เกมส์',
#   'วอลเลย์บอลในกีฬามหาวิทยาลัยโลกฤดูร้อน1973',
#   'ประเทศเลบานอนในโอลิมปิกฤดูหนาว1956',
#   'ลัทธิคอมมิวนิสต์ในประเทศไทย',
#   'ประเทศเฮติในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'กีฬาขี่ม้าในซีเกมส์2015',
#   'สวนสาธารณะในกรุงเทพมหานคร',
#   'บุคคลที่เกิดในปีพ.ศ.2522',
#   'ประเทศไทยในพ.ศ.2469',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูร้อน1980',
#   'สถิติในฟุตบอลชิงแชมป์แห่งชาติยุโรป2016',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูหนาว1988',
#   'ราชอาณาจักรสวาซิแลนด์ในโอลิมปิกฤดูหนาว',
#   'กีฬายิงปืนในโอลิมปิกฤดูร้อน1964',
#   'อารูบาในโอลิมปิก',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน1912',
#   'ประเทศอาร์เจนตินาในโอลิมปิกฤดูร้อน1924',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูร้อน1992',
#   'กีฬาคริกเก็ตในโอลิมปิกฤดูร้อน1900',
#   'การขนส่งระบบรางในประเทศเนปาล',
#   'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล2007–08',
#   'มรดกโลกในประเทศฝรั่งเศส',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน2020',
#   'รัฐประหารในเชโกสโลวาเกีย',
#   'ประเทศปานามาในโอลิมปิก',
#   'กีฬาหมากรุกจีนในเอเชียนเกมส์',
#   'ปาเลสไตน์ในเอเชียนเกมส์2014',
#   'ธงต่างๆในประเทศเยอรมนี',
#   'สโมสรฟุตบอลจังหวัดอุดรธานีในฤดูกาล2561',
#   'สหพันธรัฐรัสเซียในโอลิมปิกฤดูหนาว1998',
#   'ประเทศตุรกีในโอลิมปิกฤดูร้อน1956',
#   'การระบาดทั่วของโควิด-19ในประเทศเม็กซิโก',
#   'ประเทศนาอูรูในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2020–รุ่นน้ำหนักไม่เกิน81กิโลกรัมบุคคลชาย',
#   'สาธารณรัฐอิสลามอัฟกานิสถานในโอลิมปิกฤดูร้อน1996',
#   'สาธารณรัฐอิสลามอิหร่านในโอลิมปิกฤดูร้อน1976',
#   'จังหวัดพระนครศรีอยุธยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศเชโกสโลวาเกียในโอลิมปิกฤดูหนาว1928',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน1980',
#   'สาธารณรัฐสังคมนิยมเวียดนามในเอเชียนเกมส์2006',
#   'กีฬาฮอกกี้ในโอลิมปิกเยาวชนฤดูร้อน',
#   'แผ่นดินไหวในลิสบอน',
#   'สาธารณรัฐแซมเบียในโอลิมปิกฤดูร้อน2008',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูร้อน1904',
#   'หูชั้นในอักเสบ',
#   'สโมสรฟุตบอลลิเวอร์พูลในฤดูกาล1961–62',
#   'ประเทศแองโกลาในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สตรีในประเทศอัฟกานิสถาน',
#   'หมู่เกาะเคย์แมนในโอลิมปิกฤดูร้อน2012',
#   'สาธารณรัฐประชาธิปไตยเซาตูเมและปรินซิปีในโอลิมปิกฤดูร้อน2004',
#   'สาธารณรัฐมองโกเลียในโอลิมปิกฤดูร้อน1992',
#   'ประเทศกินีในโอลิมปิกฤดูร้อน1988',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2020–คายัค1ฝีพายสปรินท์200เมตรบุคคลหญิง',
#   'ประเทศกรีซในโอลิมปิกซ้อน1906',
#   'การเผยแผ่ศาสนาอิสลามในประเทศอินโดนีเซีย',
#   'กีฬาสกีกระโดดไกลในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'คลื่นความร้อนในเอเชีย',
#   'สาธารณรัฐเบลารุสในโอลิมปิกฤดูหนาว2002',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูหนาว1994',
#   'สาธารณรัฐฟิลิปปินส์ในโอลิมปิกฤดูหนาว1972',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2024–รอบคัดเลือก',
#   'สาธารณรัฐเวอร์จินไอซ์แลนด์ในโอลิมปิกฤดูร้อน2016',
#   'กีฬาสควอชในเวิลด์เกมส์2022',
#   'ประเทศไทยในพ.ศ.2431',
#   'การเดินป่าในเพชรพระอุมา',
#   'สาธารณรัฐเอสโตเนียในโอลิมปิกฤดูหนาว2006',
#   'กีฬาแฮนด์บอลหญิงในโอลิมปิกฤดูร้อน',
#   'ประเทศแอฟริกาใต้ในพาราลิมปิกฤดูร้อน2020',
#   'กีฬาว่ายน้ำในเอเชียนเกมส์2018',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน1988',
#   'โคลนถล่มขนาดใหญ่ในเมืองอะตะมิ',
#   'กีฬาคริกเกตในกีฬาแห่งชาติ',
#   'กีฬาฮ็อคกี้น้ำแข็งในโอลิมปิก',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน1948',
#   'ศูนย์งานแสดงสินค้าในเอ็กซ์โป',
#   'ประเทศลิเบียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1924',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูหนาว1960',
#   'ฝ่ายปกครองทหารในสหภาพโซเวียต',
#   'แผนแม่บทระบบขนส่งมวลชนในกรุงเทพมหานครและพื้นที่ต่อเนื่อง',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน2012–ฟรีสไตล์ไม่เกิน120กิโลกรัมชาย',
#   'เหตุระเบิดในสตอกโฮล์ม',
#   'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน1988',
#   'สาธารณรัฐไนเจอร์ในโอลิมปิกฤดูร้อน2000',
#   'ประเทศลาวในโอลิมปิกเยาวชนฤดูร้อน',
#   'ยูโกสลาเวียในโอลิมปิกฤดูร้อน1968',
#   'ที่ตั้งของโลกในจักรวาล',
#   'เหตุจลาจลในเดลี',
#   'ประเทศซิมบับเวในโอลิมปิกเยาวชนฤดูร้อน',
#   'พิธีสวนสนามกองทัพเยอรมัน–โซเวียตในเบรสต์-ลีตอฟสค์',
#   'กีฬาสกีกระโดดไกลในโอลิมปิกฤดูหนาว2014',
#   'คอลัมน์เซลล์ประสาทในคอร์เท็กซ์',
#   'ประเทศเบลารุสในพาราลิมปิกฤดูร้อน2016',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน1996',
#   'ในยามแห่งอาวุธกฎหมายทรุดเงียบเสียงลง',
#   'จังหวัดมุกดาหารในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'สาธารณรัฐจีนในโอลิมปิกฤดูหนาว1976',
#   'ประเทศโรมาเนียในโอลิมปิก',
#   'สาธารณรัฐอาหรับในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐโตโกในโอลิมปิกฤดูร้อน1992',
#   'ยูโดในเอเชียนเกมส์2014',
#   'กีฬาคาราเต้ในกีฬาเยาวชนแห่งชาติ',
#   'กีฬาทวิกีฬาฤดูหนาวในโอลิมปิกเยาวชนฤดูหนาว2020–ประเภทสปรินท์บุคคลหญิง',
#   'การสังหารหมู่ในรัฐยะไข่',
#   'ตัวละครในทีมเดมอน',
#   'กีฬาแบดมินตันในซีเกมส์2019–ทีมชาย',
#   'อุทกภัยและดินถล่มในประเทศไทย',
#   'กีฬาบอบสเลในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'ประเทศวานูวาตูในโอลิมปิกฤดูร้อน2012',
#   'เจ้าจอมละม้ายในรัชกาลที่5',
#   'กีฬาขี่ม้าในโอลิมปิกฤดูร้อน2020–อีเวนติงประเภททีม',
#   'ประเทศออสเตรเลียในแปซิฟิกเกมส์2023',
#   'ประเทศโมร็อกโกในโอลิมปิกฤดูร้อน1988',
#   'ความพยายามรัฐประหารในประเทศตุรกี',
#   'เหตุโจมตีในอิสตันบูลพ.ศ.2559',
#   'สโมสรฟุตบอลเชลซีในฤดูกาล2023–24',
#   'ประเทศเกาหลีใต้ในเอเชียนเกมส์1954',
#   'ประเทศเกรเนดาในโอลิมปิกฤดูร้อน2012',
#   'ประเทศจอร์แดนในเอเชียนเกมส์',
#   'ประเทศมองโกเลียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'กีฬาว่ายน้ำในกีฬาทางน้ำชิงแชมป์โลก2023',
#   'อาร์โอซีในโอลิมปิกฤดูหนาว2022',
#   'กีฬาเรือแคนูในโอลิมปิกฤดูร้อน2020–คายัค1ฝีพายสลาลอมบุคคลชาย',
#   'ประเทศโมซัมบิกในพาราลิมปิกฤดูร้อน2016',
#   'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1976',
#   'กีฬาว่ายน้ำสระเปิดในเวิลด์บีชเกมส์2019',
#   'กีฬาฮอกกี้ในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'การก่อการกำเริบในเบอร์ลินตะวันออก',
#   'สโมสรฟุตบอลมหาวิทยาลัยเกษตรศาสตร์ในฤดูกาล2561',
#   'ประเทศดอมินีกาในโอลิมปิกฤดูหนาว2014',
#   'หมู่เกาะแฟโรในพาราลิมปิกฤดูร้อน2020',
#   'กีฬาสโนว์บอร์ดในโอลิมปิกฤดูหนาว2022',
#   'ภาวะเลือดแข็งตัวในหลอดเลือดแบบแพร่กระจาย',
#   'บุคคลที่เสียชีวิตในปีพ.ศ.2523',
#   'การขนส่งระบบรางในประเทศกัมพูชา',
#   'การประท้วงในประเทศคิวบาพ.ศ.2564',
#   'กีฬากรีฑาในซีเกมส์2017–กระโดค้ำถ่อชาย',
#   'จังหวัดสุพรรณบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'เขตบริหารพิเศษมาเก๊าในเอเชียนเกมส์ฤดูหนาว',
#   'กีฬาแกลิกฟุตบอลในโอลิมปิกฤดูร้อน1904',
#   'ยุคเรอเนซองส์ในฝรั่งเศส',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน1972',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน1932',
#   'แผ่นดินไหวในจังหวัดบันเติน',
#   'ประเทศอาร์เจนตินาในโอลิมปิก1996',
#   'การขนส่งในประเทศกัมพูชา',
#   'ประเทศรัสเซียในพ.ศ.2566',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศบังกลาเทศพ.ศ.2563',
#   'ชุดชั้นใน',
#   'ประเทศฮังการีในโอลิมปิกเยาวชนฤดูร้อน',
#   'นิวเคลียสในสมอง',
#   'ประเทศไทยในพ.ศ.2362',
#   'กีฬารักบี้7คนในเอเชียนเกมส์2022',
#   'สโมสรฟุตบอลบางกอกกล๊าสในฤดูกาล2560',
#   'สโมสรฟุตบอลจังหวัดราชบุรีในฤดูกาล2560',
#   'กีฬากรีฑาในซีเกมส์2017–5000เมตรชาย',
#   'ผู้เข้าร่วมโอลิมปิกโดยอิสระในโอลิมปิกฤดูร้อน1992',
#   'สาธารณรัฐเฮติในโอลิมปิก',
#   'ประเทศเซนต์วินเซนต์และเกรนาดีนส์ในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'กีฬายูโดในโอลิมปิกฤดูร้อน2012',
#   'คาบในตารางธาตุ',
#   'การเลือกตั้งทั่วไปในประเทศพม่าพ.ศ.2553',
#   'เจ้าจอมมารดาทองสุกในรัชกาลที่1',
#   'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน2024',
#   'ประเทศกานาในเครือจักรภพ',
#   'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน2004',
#   'สัมผัสใน',
#   'ประเทศฟีจีในโอลิมปิกฤดูร้อน2012',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูหนาว1984',
#   'การขนส่งระบบรางในประเทศพม่า',
#   'ประเทศไอร์แลนด์ในโอลิมปิกฤดูร้อน2020',
#   'ราชอาณาจักรซาอุดีอาระเบียในโอลิมปิกฤดูร้อน1972',
#   'จีในประเทศไทย',
#   'ประเทศคิวบาในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'อุทกภัยจากธารน้ำแข็งแตกในรัฐอุตตราขัณฑ์',
#   'มวยสากลสมัครเล่นในเอเชียนเกมส์',
#   'ประเทศออสเตรียในโอลิมปิกฤดูร้อน1964',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'ประเทศมาลีในโอลิมปิกฤดูร้อน2020',
#   'เพื่อนสมัยเด็กที่เคยคิดว่าเป็นผู้ชายดันกลายเป็นสาวสวยในโรงเรียนใหม่',
#   'ประเทศโมร็อกโกในโอลิมปิกฤดูหนาว2022',
#   'สิทธิ์เกย์ในไทย',
#   'ตัวละครในแฟรนไชส์เดอะลาวด์เฮาส์',
#   'ประเทศไทยในพ.ศ.2408',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน1908',
#   'ประเทศโรมาเนียในโอลิมปิกฤดูหนาว1998',
#   'จังหวัดตราดในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'กีฬาเคอร์ลิงในโอลิมปิกฤดูหนาว',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว1972',
#   'ทีมนักกีฬาผู้ลี้ภัยในโอลิมปิกฤดูร้อน2020',
#   'บุคคลที่เกิดในปีพ.ศ.2530',
#   'ศาสนาอิสลามในประเทศอังกฤษ',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1952',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชาพ.ศ.2505',
#   'ประเทศชิลีในโอลิมปิกฤดูร้อน1996',
#   'ประเทศมัลดีฟส์ในเอเชียนเกมส์2014',
#   'ราชอาณาจักรซาอุดีอาระเบียในโอลิมปิกฤดูร้อน1988',
#   'สหพันธ์สาธารณรัฐอิรักในโอลิมปิกฤดูร้อน2000',
#   'การปฏิวัติในฮังการี',
#   'ประเทศโซมาเลียในโอลิมปิกฤดูร้อน2012',
#   'สโมสรฟุตบอลไบเอิร์นมิวนิกในฤดูกาล2017–18',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศซาอุดีอาระเบีย',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศซาอุดีอาระเบียพ.ศ.2563',
#   'การจลาจลในสโลวาเกีย',
#   'ประเทศรัสเซียในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'การลงคะแนนแบบหลายรอบในทันที',
#   'ประเทศแอฟริกาใต้ในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'เหตุรถไฟตกรางในมณฑลเจียงซีพ.ศ.2553',
#   'ประเทศเฮติในโอลิมปิกฤดูหนาว',
#   'การเลือกตั้งสหพันธรัฐในเยอรมนีพ.ศ.2548',
#   'แผลในกระเพาะ',
#   'ประเทศบราซิลในโอลิมปิกฤดูร้อน2016',
#   'ประเทศไทยในพ.ศ.2427',
#   'กีฬาสเกตบอร์ดในโอลิมปิกฤดูร้อน2024',
#   'กีฬาขี่ม้าในโอลิมปิกฤดูร้อน1948',
#   'ประเทศไทยในโอลิมปิกฤดูร้อน1996',
#   'สาธารณรัฐอิสลามอิหร่านในโอลิมปิก',
#   'ลำดับชั้นของทูตสวรรค์ในศาสนาคริสต์',
#   'ประเทศกรีซในโอลิมปิกฤดูร้อน1912',
#   'ชินลงในซีเกมส์2013',
#   'ประเทศอุซเบกิสถานในเอเชียนเกมส์',
#   'ตัวละครในโอซาร์ก',
#   'ประเทศโปรตุเกสในโอลิมปิกฤดูหนาว',
#   'ประเทศบูร์กินาฟาโซในโอลิมปิกฤดูร้อน2012',
#   'กีฬาแร็กเกตบอลในเวิลด์เกมส์',
#   'กรุงเทพมหานครในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'กีฬาฮอกกี้ในโอลิมปิกฤดูร้อน1988',
#   'ประเทศปากีสถานในเอเชียนเกมส์2006',
#   'บุคคลที่เกิดในปีพ.ศ.2520',
#   'ประเทศเชโกสโลวาเกียในโอลิมปิกฤดูหนาว',
#   'สาธารณรัฐหมู่เกาะฟิจิในโอลิมปิกฤดูหนาว1994',
#   'กีฬาจักรยานในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬาลอนโบวล์สในกีฬาแห่งชาติ',
#   'ประเทศอิสราเอลในโอลิมปิกฤดูหนาว2022',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน1964',
#   'พระชายาในเจ้าชายยาซูฮิโตะ',
#   'ประเทศกัมพูชาในโอลิมปิกฤดูร้อน',
#   'ประเทศบราซิลในโอลิมปิกฤดูร้อน2012',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน1980',
#   'สร้างตำนานในสองโลก',
#   'ประเทศรัสเซียในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ธงต่างๆในประเทศโอมาน',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยเมษายนพ.ศ.2549',
#   'ประเทศโอมานในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'นักกีฬาโอลิมปิกอิสระในโอลิมปิกฤดูร้อน2016',
#   'สาธารณรัฐคาซัคสถานในเอเชียนเกมส์2014',
#   'โครงการรถไฟความเร็วสูงในประเทศไทย',
#   'ประเทศเวเนซุเอลาในโอลิมปิกฤดูหนาว2006',
#   'การลงประชามติในประเทศสวิตเซอร์แลนด์ค.ศ.1908',
#   'ฟุตบอลในโอลิมปิกฤดูร้อน1952',
#   'เขียนในใจ',
#   'สวนสนามเยอรมัน–โซเวียตในเบรสต์-ลีตอฟสค์',
#   'สาธารณรัฐแอฟริกากลางในโอลิมปิกฤดูร้อน2012',
#   'ประเทศเม็กซิโกในโอลิมปิกฤดูร้อน2008',
#   'ประเทศเม็กซิโกในโอลิมปิกฤดูร้อน2000',
#   'ซิงเกิลประจำตัวละครในเค-อง!ก๊วนดนตรีแป๋วแหวว',
#   'สาธารณรัฐกัวเตมาลาในโอลิมปิกฤดูหนาว1988',
#   'ข้อเท็จจริงทางประวัติศาสตร์ในสามก๊ก',
#   'ประเทศเซนต์ลูเชียในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'สาธารณรัฐสังคมนิยมเวียดนามในโอลิมปิกฤดูร้อน1952',
#   'สาธารณรัฐเช็กในโอลิมปิกฤดูหนาว2014',
#   'ประเทศไทยในโอลิมปิกฤดูร้อน1972',
#   'กีฬาฟุตบอลในซีเกมส์2017–ทีมหญิง',
#   'แผ่นดินไหวและสึนามิในเซ็นได',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2550',
#   'ประเทศแคนาดาในพาราลิมปิกฤดูหนาว2010',
#   'ประเทศดอมินีกาในโอลิมปิกฤดูร้อน2008',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน1900',
#   'สาธารณรัฐแอฟริกากลางในโอลิมปิกฤดูร้อน1988',
#   'ประเทศเปรูในโอลิมปิกฤดูร้อน1900',
#   'สาธารณรัฐไอร์แลนด์ในโอลิมปิกฤดูร้อน1988',
#   'ประเทศปากีสถานในโอลิมปิกฤดูร้อน1992',
#   'แผ่นดินไหวในจังหวัดบันเตินพ.ศ.2561',
#   'ประเทศอัฟกานิสถานในโอลิมปิกฤดูร้อน2020',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูร้อน1996',
#   'กีฬากรีฑาในซีเกมส์2013',
#   'ประเทศโรมาเนียในโอลิมปิกฤดูหนาว',
#   'ประเทศลักเซมเบิร์กในโอลิมปิกฤดูหนาว2018',
#   'ประเทศชาดในโอลิมปิกฤดูร้อน1972',
#   'ภาพยนตร์จีนกำลังภายใน',
#   'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน2020',
#   'กีฬาเทควันโดในโอลิมปิกฤดูร้อน2012–หญิงไม่เกิน57กิโลกรัม',
#   'กีฬาทวิกีฬาในเอเชียนเกมส์ฤดูหนาว',
#   'กีฬาปัญจกีฬาสมัยใหม่ในโอลิมปิกฤดูร้อน1972',
#   'การตรวจพิจารณาในประเทศไทย',
#   'ธงในประเทศกานา',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน2020–รุ่นไลท์เวทบุคคลชาย',
#   'ประเทศญี่ปุ่นในโอลิมปิกฤดูร้อน1968',
#   'กีฬาเรือใบในโอลิมปิกฤดูร้อน1920',
#   'กีฬายิงธนูในโอลิมปิกฤดูร้อน1980',
#   'การประท้วงในแคว้นกาตาลุญญาพ.ศ.2562',
#   'กีฬายกน้ำหนักในโอลิมปิกฤดูร้อน2008',
#   'อาการเลือดออกในกระเพาะและลำไส้',
#   'สาธารณรัฐปาเลาในโอลิมปิกฤดูร้อน',
#   'การขนส่งในประเทศบรูไน',
#   'กีฬาวอลเลย์บอลชายหาดในโอลิมปิกฤดูร้อน',
#   'ประเทศเลบานอนในโอลิมปิกฤดูร้อน1996',
#   'สาธารณรัฐสโลวีเนียในโอลิมปิกฤดูหนาว2002',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน2016รอบคัดเลือกโซนแอฟริกา',
#   'การลงประชามติในประเทศสวิตเซอร์แลนด์ค.ศ.1923',
#   'ในศาสนาซิกข์',
#   'กีฬาฟันดาบในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ยูโกสลาเวียในโอลิมปิกฤดูหนาว1936',
#   'สิทธิมนุษยชนในประเทศกัมพูชา',
#   'กองทัพโปแลนด์ในตะวันออก',
#   'ตัวละครในกัชเบล',
#   'มาเก๊าในเอเชียนเกมส์ฤดูหนาว2017',
#   'ประเทศปากีสถานในเอเชียนเกมส์',
#   'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน1988',
#   'วันหยุดในประเทศยูเครน',
#   'ประเทศเซียร์ราลีโอนในโอลิมปิกฤดูร้อน2020',
#   'ประเทศกรีซในโอลิมปิกฤดูหนาว1992',
#   'วอลเลย์บอลในกีฬามหาวิทยาลัยโลก1963',
#   'ประเทศเลบานอนในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬาชี่นโล่นในซีเกมส์',
#   'ประเทศเกาหลีเหนือในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ตัวละครในวรรณกรรมสำนักพยัคฆ์มังกร',
#   'ผู้เล่นในฟุตบอลเอเชียเยาวชนอายุไม่เกิน23ปี2022',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูร้อน1968',
#   'ประเทศโปรตุเกสในโอลิมปิกฤดูร้อน',
#   'สหพันธรัฐเซนต์คิตส์และเนวิสในโอลิมปิกฤดูร้อน2004',
#   'กีฬาบาสเกตบอลในซีเกมส์2019',
#   'องค์การสวนสัตว์ในพระบรมราชูปถัมภ์',
#   'ประเทศอิรักในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'เรือสำราญที่ใหญ่ที่สุดในโลก',
#   'ฟุตบอลในโอลิมปิกฤดูร้อน1972',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูหนาว1984',
#   'ประเทศดอมินีกาในโอลิมปิกฤดูร้อน1996',
#   'ราชอาณาจักรบาห์เรนในโอลิมปิกฤดูร้อน2004',
#   'ความอดอยากในไอร์แลนด์',
#   'ประเทศเบอร์มิวดาในพาราลิมปิกฤดูร้อน2012',
#   'กรีฑาในซีเกมส์2013',
#   'กรีฑาในกีฬาแห่งชาติครั้งที่41–วิ่ง5,000เมตรชาย',
#   'ประเทศนอร์เวย์ในโอลิมปิกฤดูหนาว1948',
#   'พระราชกรณียกิจทรงเยือนต่างประเทศในรัชกาลที่9',
#   'ของวิเศษในอาณาจักรแห่งกาลเวลา',
#   'สาธารณรัฐซูดานในโอลิมปิกฤดูร้อน1988',
#   'เปียโนโซนาตาหมายเลข14ในบันไดเสียงซีชาร์ปไมเนอร์',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2020',
#   'สาธารณรัฐอิเควทอเรียลกินีในโอลิมปิกฤดูร้อน1988',
#   'ประเทศไนเจอร์ในโอลิมปิก',
#   'ปาเลสไตน์ในโอลิมปิกฤดูร้อน2012',
#   'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน2020',
#   'สโมสรฟุตบอลนครราชสีมายูไนเต็ดในฤดูกาล2563-64',
#   'กีฬาคาราเต้ในโอลิมปิกฤดูร้อน2020',
#   'จักรยานในซีเกมส์',
#   'อันดับปลาเหล็กใน',
#   'การเพาะเลี้ยงปลาแซลมอนในน้ำ',
#   'กีฬาเทเบิลเทนนิสในโอลิมปิกฤดูร้อน2012–รอบคัดเลือก',
#   'ประเทศเติร์กเมนิสถานในเอเชียนเกมส์2018',
#   'กีฬาสเกตลีลาในโอลิมปิกเยาวชน',
#   'ประเทศเอริเทรียในโอลิมปิกฤดูหนาว2022',
#   'ประเทศปาเลาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'เยื่อห้องหูชั้นใน',
#   'สาธารณรัฐโดมินิกันในโอลิมปิกฤดูร้อน2020',
#   'สหพันธ์สาธารณรัฐเยอรมนีในโอลิมปิกฤดูหนาว1980',
#   'ประเทศญี่ปุ่นในเอเชียนเกมส์2022',
#   'สาธารณรัฐเคนยาในโอลิมปิกฤดูร้อน2000',
#   'สนามบินในประเทศไทย',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน2000–รอบคัดเลือกยิมนาสติกลีลาหญิง',
#   'โทรทัศน์ประเทศไทยในพ.ศ.2539',
#   'การก่อการกำเริบในบูร์กินาฟาโซ',
#   'ประเทศซูรินามในโอลิมปิกฤดูร้อน2012',
#   'อาวุธปืนในเพชรพระอุมา',
#   'สาธารณรัฐอิสลามอิหร่านในโอลิมปิกฤดูร้อน1996',
#   'จังหวัดนครนายกในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศไทยในพ.ศ.2542',
#   'จังหวัดชัยนาทในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#   'ประเทศเบอร์มิวดาในโอลิมปิกฤดูร้อน1988',
#   'เหตุระเบิดในอัดดุญัยล์',
#   'เหตุระเบิดในประเทศศรีลังกา',
#   'ธงในประเทศเกาหลีใต้',
#   'สาธารณรัฐอิสลามอิหร่านในโอลิมปิกฤดูหนาว1968',
#   'สาธารณรัฐยูกันดาในโอลิมปิกฤดูร้อน1992',
#   'กีฬายิมนาสติกในโอลิมปิกฤดูร้อน2020–ยิมนาสติกสากลม้ากระโดดบุคคลชาย',
#   'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐ',
#   'ประเทศมอริเชียสในโอลิมปิกฤดูร้อน2020',
#   'สาธารณรัฐมาดากัสการ์ในโอลิมปิก',
#   'สหราชอาณาจักรในโอลิมปิกฤดูร้อน1912',
#   'ประเทศเลโซโทในพาราลิมปิกฤดูร้อน2020',
#   'การขนส่งระบบรางในประเทศเวียดนาม',
#   'รัฐอิสราเอลในโอลิมปิกฤดูหนาว1994',
#   'ประเทศโซมาเลียในโอลิมปิกฤดูร้อน2016',
#   'ประเทศดอมินีกาในโอลิมปิกเยาวชนฤดูร้อน',
#   'สนามแข่งขันในโอลิมปิกฤดูร้อน',
#   'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน2004',
#   'สาธารณรัฐยูกันดาในโอลิมปิกฤดูร้อน1996',
#   'การเลิกทาสและไพร่ในประเทศไทย',
#   'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน2012',
#   'กีฬาเรือพายในโอลิมปิกเยาวชน',
#   'ประเทศตุรกีในโอลิมปิกฤดูหนาว2018',
#   'กีฬาขี่ม้าในเอเชียนเกมส์',
#   'ประเทศตุรกีในโอลิมปิกซ้อน',
#   'ประเทศบัลแกเรียในโอลิมปิกฤดูร้อน1956',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน1984',
#   'กีฬาทวิกีฬาฤดูหนาวในโอลิมปิกฤดูหนาว2018',
#   'ธงในประเทศอียิปต์',
#   'กีฬามวยสากลสมัครเล่นในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'สโมสรฟุตบอลห้วยแถลงเอฟซีในฤดูกาล2559',
#   'ประเทศกรีซในโอลิมปิกฤดูร้อน2012',
#   'กีฬาเซปักตะกร้อในซีเกมส์2013',
#   'ประเทศไทยในพ.ศ.2336',
#   'สโมสรฟุตบอลอาร์เซนอลในฤดูกาล2013–14',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศภูฏานพ.ศ.2563',
#   'กีฬาบาสเกตบอลชายในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'กีฬากรีฑาในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศคิวบาในโอลิมปิกฤดูร้อน1968',
#   'ประเทศอิสราเอลในพาราลิมปิกฤดูร้อน2020',
#   'ประเทศอินโดนีเซียในโอลิมปิกฤดูร้อน2020',
#   'เซปักตะกร้อในซีเกมส์2013',
#   'ประเทศฟิลิปปินส์ในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'ฟุตบอลในโอลิมปิกฤดูร้อน1900',
#   'ประเทศแอลจีเรียในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน2020–ทีมชาย–รอบชิงชนะเลิศ',
#   'กีฬากรีฑาในโอลิมปิกฤดูร้อน2020–กระโดดไกลบุคคลหญิง',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2553',
#   'สาธารณรัฐแคเมอรูนในโอลิมปิกฤดูร้อน2004',
#   'ประเทศโปรตุเกสในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'การเลือกตั้งทั่วไปในสหราชอาณาจักรพ.ศ.2560',
#   'สาธารณรัฐเช็กในโอลิมปิกฤดูร้อน2012',
#   'เจ้าจอมหม่อมราชวงศ์แป้วในรัชกาลที่5',
#   'กรุงเทพมหานครในกีฬาแห่งชาติครั้งที่42',
#   'ประเทศเลโซโทในโอลิมปิกฤดูร้อน2004',
#   'กีฬาเบรกแดนซ์ในเอเชียนเกมส์',
#   'ประเทศคอโมโรสในโอลิมปิกฤดูร้อน2020',
#   'กีฬาสกีลงเขาในโอลิมปิกฤดูหนาว2014–ประเภทดาวน์ฮิลล์ชาย',
#   'ฟุตบอลในประเทศไซปรัส',
#   'ประเทศลิทัวเนียในพาราลิมปิกฤดูร้อน2016',
#   'ประเทศบราซิลในโอลิมปิกฤดูหนาว',
#   'การเจริญของประสาทในมนุษย์',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน1896–กรีก-โรมันชาย',
#   'ราชรัฐลิกเตนสไตน์ในโอลิมปิกฤดูหนาว2002',
#   'รถไฟในประเทศไทย',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูหนาว2002',
#   'สาธารณรัฐลิทัวเนียในโอลิมปิกฤดูร้อน2008',
#   'จังหวัดสุโขทัยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศไทยในเอเชียนบีชเกมส์',
#   'กีฬาว่ายน้ำในโอลิมปิกฤดูร้อน1896–กะลาสีเรือฟรีสไตล์100เมตรชาย',
#   'บุคคลที่เกิดในปีพ.ศ.2528',
#   'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูร้อน2024',
#   'ประเทศนอร์เวย์ในโอลิมปิกฤดูร้อน2008',
#   'ประเทศหมู่เกาะโซโลมอนในโอลิมปิกฤดูร้อน',
#   'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล2018–19',
#   'ตัวละครในเรื่องมืออสูรล่าปิศาจ',
#   'แผ่นดินไหวในฟูกูชิมะพ.ศ.2564',
#   'ประเทศเฮติในโอลิมปิกเยาวชนฤดูร้อน2014',
#   'สโมสรฟุตบอลโปลิศเทโรในฤดูกาล2561',
#   'ประเทศไทยในพ.ศ.2511',
#   'จังหวัดสงขลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2566',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน1920',
#   'สหพันธ์สาธารณรัฐเยอรมนีในพาราลิมปิกฤดูหนาว',
#   'ประเทศกาบองในโอลิมปิกฤดูร้อน2020',
#   'ธงในประเทศจีน',
#   'สหภาพรัฐเซอร์เบียและมอนเตเนโกรในโอลิมปิกฤดูร้อน',
#   'ธงในประเทศสวีเดน',
#   'ฤดูหนาวในประเทศไทยพ.ศ.2558–2559',
#   'ประเทศฝรั่งเศสในพาราลิมปิกฤดูหนาว2010',
#   'จังหวัดอุตรดิตถ์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'สหราชอาณาจักรในโอลิมปิก',
#   'สโมสรฟุตบอลเวสต์แฮมยูไนเต็ดในฤดูกาล',
#   'ประเทศอาร์เจนตินาในแพนอเมริกันเกมส์',
#   'กีฬาซอฟท์บอลในกีฬาแห่งชาติครั้งที่46',
#   'ศาลทหารในเวลาไม่ปกติ',
#   'การจัดการสตริงในภาษาซี',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว2002',
#   'ประเทศไทยในพ.ศ.2550',
#   'ประเทศแทนซาเนียในพาราลิมปิกฤดูร้อน',
#   'ประเทศกินีในโอลิมปิกฤดูร้อน2008',
#   'การก่อการกำเริบคอมมิวนิสต์ในประเทศมาเลเซีย',
#   'ความอดอยากมันฝรั่งในไอร์แลนด์',
#   'ประเทศเกาหลีใต้ในโอลิมปิกฤดูร้อน1992',
#   'ประเทศสโลวีเนียในพาราลิมปิกฤดูร้อน2016',
#   'กีฬาฟิสต์บอลในเวิลด์เกมส์2022',
#   'นิกายในศาสนาพุทธ',
#   'สาธารณรัฐกัวเตมาลาในโอลิมปิกฤดูร้อน1992',
#   'คนในอากาศ',
#   'ประเทศกรีซในพาราลิมปิกฤดูหนาว2010',
#   'ประเทศแอฟริกาใต้ในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'สาธารณรัฐเอกวาดอร์ในโอลิมปิกฤดูร้อน1924',
#   'เบสบอลในกีฬามหาวิทยาลัยโลกฤดูร้อน',
#   'ประเทศตรินิแดดและโตเบโกในโอลิมปิก',
#   'กีฬาจักรยานในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'ยูโกสลาเวียในโอลิมปิกฤดูร้อน1960',
#   'สงครามโซเวียตในอัฟกานิสถาน',
#   'สาธารณรัฐซิมบับเวในโอลิมปิกฤดูร้อน1980',
#   'ประเทศออสเตรียในพาราลิมปิกฤดูร้อน2012',
#   'ประเทศจีนในเอเชียนบีชเกมส์2008',
#   'ประเทศปานามาในโอลิมปิกเยาวชนฤดูร้อน2018',
#   'ผู้เล่นในฟุตบอลอาเซียนชิงแชมป์เยาวชนอายุไม่เกิน',
#   'ศาสนาในประเทศกาตาร์',
#   'ประเทศบราซิลในโอลิมปิกเยาวชนฤดูหนาว',
#   'พระชายาในเจ้าชายทากาฮิโตะ',
#   'ประเทศสวีเดนในโอลิมปิกฤดูร้อน2004',
#   'ประเทศคาซัคสถานในโอลิมปิกฤดูร้อน2024',
#   'รัฐกาตาร์ในโอลิมปิกฤดูร้อน1996',
#   'ประเทศบาฮามาสในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศชิลีในโอลิมปิกฤดูร้อน2024',
#   'สาธารณรัฐมาลีในโอลิมปิกฤดูร้อน2000',
#   'ศูนย์กีฬาน้อยใน',
#   'กีฬาว่ายน้ำในซีเกมส์2017–ท่ากรรเชียง50เมตรชาย',
#   'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูร้อน1912',
#   'ประเทศชิลีในโอลิมปิกเยาวชนฤดูหนาว2020',
#   'สาธารณรัฐไซปรัสในโอลิมปิกฤดูหนาว1992',
#   'ประเทศโปแลนด์ในโอลิมปิกฤดูร้อน1952',
#   'ข่าวในพระราชสำนัก',
#   'ประเทศรวันดาในพาราลิมปิกฤดูร้อน2016',
#   'ประเทศซูรินามในโอลิมปิกฤดูร้อน1996',
#   'ประเทศนอร์ทมาซิโดเนียในโอลิมปิกฤดูหนาว2022',
#   'กองอำนวยการรักษาความมั่นคงภายในราชอาณาจักร',
#   'ประเทศไทยในพ.ศ.2543',
#   'ประเทศซามัวในโอลิมปิกฤดูร้อน2016',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน2020–ฟรีสไตล์รุ่นน้ำหนักไม่เกิน65กิโลกรัมบุคคลชาย',
#   'โควิด19ในประเทศไทย',
#   'กีฬากาบัดดีในเอเชียนเกมส์2018',
#   'ราชรัฐลักเซมเบิร์กในโอลิมปิกฤดูร้อน1992',
#   'สาธารณรัฐชาดในโอลิมปิกฤดูร้อน1984',
#   'เหตุไฟฟ้าดับในประเทศเวเนซุเอลา',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน2008–รอบคัดเลือก',
#   'สาธารณรัฐอิสลามอัฟกานิสถานในโอลิมปิกฤดูร้อน1972',
#   'กีฬาซอฟท์เทนนิสในซีเกมส์',
#   'ลำดับเหตุการณ์ในประวัติศาสตร์อังกฤษระหว่างปี',
#   'สาธารณรัฐอิสลามอัฟกานิสถานในโอลิมปิกฤดูร้อน',
#   'ในสวนขวัญ',
#   'กีฬาในประเทศกาตาร์',
#   'จังหวัดพะเยาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศเบนินในโอลิมปิกเยาวชนฤดูร้อน2010',
#   'ประเทศกรีเนดาในโอลิมปิกฤดูร้อน',
#   'รักบี้ในเอเชียนเกมส์2014',
#   'สาธารณรัฐคองโกในโอลิมปิกฤดูร้อน2020',
#   'กีฬาฮอกกี้หญิงในโอลิมปิกฤดูร้อน2016–รอบคัดเลือก',
#   'ประเทศฟิลิปปินส์ในเอเชียนเกมส์2014',
#   'จังหวัดบึงกาฬในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'ประเทศเอริเทรียในโอลิมปิก',
#   'แผ่นดินไหวในรัฐเวอร์จิเนีย',
#   'จีนไทเปในเอเชียนบีชเกมส์2010',
#   'ประเทศอาร์เจนตินาในพาราลิมปิกฤดูหนาว',
#   'นิกายในศาสนาฮินดู',
#   'ประเทศมองโกเลียในโอลิมปิกฤดูร้อน2008',
#   'จังหวัดตากในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#   'สโมสรฟุตบอลการท่าเรือในฤดูกาล2559',
#   'สาธารณรัฐอิสลามมอริเตเนียในโอลิมปิกฤดูร้อน',
#   'กีฬาเบสบอลในโอลิมปิกฤดูร้อน2020',
#   'การลงประชามติในประเทศสวิตเซอร์แลนด์ค.ศ.1931',
#   'ปัญหาสิ่งแวดล้อมในประเทศไทย',
#   'ตระกูลนักการเมืองในประเทศไทย',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน2000',
#   'ประเทศดอมินีกาในโอลิมปิกฤดูร้อน2012',
#   'ประเทศตุรกีในโอลิมปิกฤดูร้อน1992',
#   'ประเทศโปแลนด์ในโอลิมปิกฤดูหนาว1992',
#   'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#   'เครือรัฐเปอร์โตริโกในโอลิมปิกฤดูร้อน1960',
#   'เรือโดยสารคลองในประเทศไทย',
#   'ประเทศเปรูในโอลิมปิกเยาวชนฤดูร้อน',
#   'เนเธอร์แลนด์แอนทิลลิสในโอลิมปิกฤดูหนาว1992',
#   'จังหวัดระนองในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#   'ประเทศออสเตรเลียในพาราลิมปิกฤดูร้อน2016',
#   'แผ่นดินไหวในจังหวัดฟุกุชิมะ',
#   'ทุพภิกขภัยในจงอยแอฟริกาพ.ศ.2554',
#   'เหตุระเบิดในเบรุต',
#   'ประเทศออสเตรเลียในโอลิมปิกฤดูหนาว1972',
#   'สหรัฐอเมริกาในโอลิมปิกฤดูร้อน1920',
#   'วอลเลย์บอลหญิงในกีฬามหาวิทยาลัยโลก2013',
#   'ประเทศเดนมาร์กในโอลิมปิกฤดูร้อน2004',
#   'กีฬาคริกเกตในกีฬาเยาวชนแห่งชาติ',
#   'สาธารณรัฐเวอร์จินไอซ์แลนด์ในโอลิมปิกฤดูร้อน1984',
#   'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน2020–ทีมชาย',
#   'กีฬาระบำใต้น้ำในโอลิมปิกฤดูร้อน2012–รอบคัดเลือก',
#   'กีฬากรีฑาในกีฬาเยาวชนแห่งชาติครั้งที่29',
#   'ประเทศฟินแลนด์ในโอลิมปิกฤดูร้อน1928',
#   'ประเทศอินเดียในเอเชียนเกมส์2018',
#   'สาธารณรัฐไอร์แลนด์ในโอลิมปิกฤดูร้อน1948',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 9538

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['หลังรัฐประหารในประเทศไทย',
#  'นักกีฬาจากรัฐคูเวตในเอเชียนเกมส์2010',
#  'พระราชสันตติวงศ์ในสมเด็จพระบรมราชินีนาถวิกตอเรีย',
#  'ประเทศญี่ปุ่นในเอเชียนเกมส์',
#  'นักกีฬาอิสระในเอเชียนเกมส์',
#  'สโมสรฟุตบอลเรอัลมาดริดในฤดูกาล2023–24',
#  'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล2009–10',
#  'กล้องจุลทรรศน์แบบส่องกราดในอุโมงค์',
#  'โบว์ลิ่งในกีฬาแห่งชาติครั้งที่41–ทีมชาย3คน',
#  'ประเทศชิลีในแพนอเมริกันเกมส์',
#  'สโมสรฟุตบอลจังหวัดอุดรธานีในฤดูกาล2561',
#  'วัตถุมงคลในศาสนาพุทธ',
#  'เจ้าหญิงมาซาโกะพระชายาในเจ้าชายสึเนฮิซะ',
#  'กีฬาปัญจกีฬาสมัยใหม่ในแพนอเมริกันเกมส์2023',
#  'นักฟุตบอลที่เกิดในปี',
#  'ร็อคแมน6การต่อสู้ครั้งยิ่งใหญ่ในประวัติศาสตร์!!',
#  'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'ประเทศไทยในพ.ศ.2562',
#  'รัฐประหารในประเทศพม่า',
#  'ประเทศไทยในพ.ศ.2550',
#  'การกบฏโรฮิงยาในพม่าตะวันตก',
#  'ในสมเด็จพระเจ้าลูกเธอ',
#  'โบว์ลิ่งในเอเชียนเกมส์2014',
#  'ตัวละครที่ปรากฎใน',
#  'กองทัพอากาศสหรัฐในประเทศไทย',
#  'บุคคลที่เสียชีวิตในเดือน',
#  'ประเทศเช็กเกียในพาราลิมปิกฤดูร้อน2016',
#  'ขบวนการก่อกวนความปลอดภัยในอาเจะห์',
#  'การเปลี่ยนผ่านในราชสำนักญี่ปุ่น,2019',
#  'กีฬายกน้ำหนักในกีฬาแห่งชาติครั้งที่47',
#  'การประท้วงในประเทศเบลารุสพ.ศ.2563–2564',
#  'เบสบอลในกีฬามหาวิทยาลัยโลกฤดูร้อน2015',
#  'เขตในเบลเยียม',
#  'พระนามทรงกรมของพระราชโอรสพระราชธิดาในรัชกาลที่๑',
#  'ภารกิจสหประชาชาติในซูดานใต้',
#  'บาสเกตบอลในเอเชียนเกมส์1954',
#  'กีฬาเบสบอลในเอเชียนเกมส์2018',
#  'แผ่นดินไหวในเกาะฮาวายพ.ศ.2561',
#  'แบดมินตันทีมหญิงในเอเชียนเกมส์',
#  'ประเทศมองโกเลียในเอเชียนเกมส์2010',
#  'องค์การบริหารส่วนตำบลในคลองบางปลากด',
#  'เสรีภาพในทางความคิด',
#  'เหตุระเบิดในเบรุตพ.ศ.2563',
#  'ในประเทศรัสเซีย',
#  'กีฬายิมนาสติกกายกรรมในเวิลด์เกมส์2017',
#  'แผ่นดินไหวและคลื่นสึนามิในเกาะซูลาเวซีพ.ศ.2561',
#  'ความขัดแย้งในซูดาน',
#  'กีฬามวยปล้ำในเอเชียนเกมส์',
#  'เจ้าจอมมารดาอิ่มในรัชกาลที่1',
#  'ประเทศเซอร์เบียในพาราลิมปิกฤดูร้อน',
#  'ลูกเสือและเนตรนารีในกัมพูชา',
#  'ประเทศไทยในพ.ศ.2412',
#  'ประเทศเปรูในพาราลิมปิกฤดูร้อน2016',
#  'การลงมติเลือกนายกรัฐมนตรีในประเทศไทย',
#  'กระทรวงในประเทศอินเดีย',
#  'ฟอสเตอร์โฮม..บ้านของผองเพื่อนในจินตนาการ',
#  'กรีฑาในกีฬาแห่งชาติครั้งที่41–วิ่ง400เมตรชาย',
#  'บุคคลที่เสียชีวิตในปีพ.ศ.2543',
#  'ภาวะความดันในปอดสูงของทารกแรกเกิด',
#  'เจ็ดสิ่งมหัศจรรย์ของโลกในยุคใหม่',
#  'การเลือกตั้งสหพันธรัฐในออสเตรเลียพ.ศ.2559',
#  'ประเทศไทยในพ.ศ.2480',
#  'ประเทศไทยในพ.ศ.2304',
#  'การขนส่งระบบรางในประเทศฟิลิปปินส์',
#  'สาธารณรัฐประชาชนจีนในเอเชียนเกมส์',
#  'โรคกระดูกอ่อนในเด็ก',
#  'แผ่นดินไหวในพ.ศ.2560',
#  'ผู้เล่นในฟุตบอลชิงถ้วยพระราชทานคิงส์คัพครั้งที่46',
#  'การนำคอมพิวเตอร์มาช่วยในการผลิต',
#  'วิวัฒนาการของกระดูกหูเพื่อการได้ยินในสัตว์เลี้ยงลูกด้วยนม',
#  'ว่าราชการในวัด',
#  'เสมหะในคอ',
#  'สาธารณรัฐประชาชนบังกลาเทศในเอเชียนเกมส์2010',
#  'มรดกโลกที่ตกอยู่ในสภาวะอันตราย',
#  'สโมสรฟุตบอลนครราชสีมาห้วยแถลงยูไนเต็ดในฤดูกาล2562',
#  'ศาสนาพุทธในเอเชียตะวันออกเฉียงใต้',
#  'ความหลากหลายทางชีวภาพในประเทศบราซิล',
#  'โรคสติลล์ที่เริ่มเป็นในผู้ใหญ่',
#  'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐอเมริกา',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยพ.ศ.2550ในกรุงเทพมหานคร',
#  'พระราชโอรสในทุตโมสที่หนึ่ง',
#  'จังหวัดปัตตานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2550',
#  'ประเทศอินโดนีเซียในเอเชียนเกมส์2022',
#  'ความเกี่ยวพันของเด็กในความขัดแย้งกันด้วยอาวุธ',
#  'ประเทศมาเลเซียในซีเกมส์2023',
#  'เจ้าจอมอิ่มในรัชกาลที่3',
#  'กีฬาฟลอร์บอลในเวิลด์เกมส์',
#  'ธงในประเทศลัตเวีย',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล1975–76',
#  'การศึกษาในลาว',
#  'พุทธสถานในพื้นที่โฮรีว-จิ',
#  'สถิติในฟุตบอลชิงแชมป์แห่งชาติยุโรป',
#  'การศึกษาในประเทศไทย',
#  'การเลือกตั้งในประเทศไทยครั้งที่12',
#  'ประเทศฟิลิปปินส์ในซีเกมส์2015',
#  'ทำเนียบกำลังรบในยุทธการที่เดียนเบียนฟู',
#  'กีฬารักบี้ฟุตบอลในกีฬาแห่งชาติครั้งที่41',
#  'คลื่นความเย็นในทวีปยุโรปพ.ศ.2555',
#  'ประเทศกาตาร์ในเอเชียนเกมส์ฤดูหนาว',
#  'สโมสรฟุตบอลไบเอิร์นมิวนิกในฤดูกาล']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 8283

# %%
get_samples(nai)
# Out:
# ['สาธารณรัฐประชาชนจีนในเอเชียนเกมส์2010',
#  'เจ้าจอมเพิ่มในรัชกาลที่5',
#  'ตรุษจีนในนครสวรรค์',
#  'การประท้วงในอิรักพ.ศ.2562–2564',
#  'ฉัน,ในวันฟ้าคราม',
#  'การประท้วงในจอร์เจียพ.ศ.2554',
#  'บุคคลที่เกิดในปีพ.ศ.2494',
#  'ธงในโครเอเชีย',
#  'การเปลี่ยนแปลงในระดับจิตวิญญาณ',
#  'จังหวัดชลบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2562',
#  'การระบาดทั่วของโควิด-19ในประเทศพม่า',
#  'กีฬาเทควันโดในกีฬาแห่งชาติ',
#  'กรีฑาในกีฬาแห่งชาติครั้งที่41–วิ่ง1,500เมตรชาย',
#  'การก่อการกำเริบในเบอร์ลินตะวันออกค.ศ.1953',
#  'บุคคลที่เกิดในปีพ.ศ.2475',
#  'ประเทศเยเมนในเอเชียนเกมส์2022',
#  'กีฬาเรือพายในกีฬาแห่งชาติครั้งที่45',
#  'การลงประชามติในประเทศสวิตเซอร์แลนด์ค.ศ.1876',
#  'อยากเห็นท้องฟ้าเป็นอย่างในฝัน',
#  'สหรัฐอาหรับเอมิเรตส์ในเอเชียนเกมส์2010',
#  'สถิติในฟีฟ่าคอนเฟเดอเรชันส์คัพ2017',
#  'กีฬาโปโลน้ำในซีเกมส์2017–ทีมหญิง',
#  'กีฬาวูซูในซีเกมส์2017',
#  'รักร่วมเพศในประเทศไทย',
#  'เธอไม่ควรเข้ามาในชีวิต',
#  'ความเข้มข้นเฉลี่ยของฮีโมโกลบินในเม็ดเลือดแดง',
#  'กีฬาแบดมินตันในซีเกมส์2013',
#  'การศึกษาภาษาญี่ปุ่นในสหรัฐอเมริกา',
#  'เหตุการณ์ชุมนุมในกรุงเทพมหานคร14ธันวาคมพ.ศ.2562',
#  'ตัวละครในเรื่องมืออสูรล่าปิศาจ',
#  'โรงเรียนในเครือบดินทรเดชา',
#  'แปซิฟิกใต้ในอาณัติ',
#  'ประเทศอินโดนีเซียในเอเชียนเกมส์2006',
#  'กลุ่มโบราณสถานพระราชวังโปตาลาในลาซ่า',
#  'รัฐในอารักขา',
#  'การประท้วงในประเทศเลบานอน',
#  'กลุ่มในและกลุ่มนอก',
#  'ประเทศไทยในพ.ศ.2363',
#  'ฟุตซอลในซีเกมส์2013',
#  'จังหวัดยะลาในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2554',
#  'ต้มเครื่องในหมู',
#  'กรีฑาชายหาดในเอเชียนบีชเกมส์2014',
#  'กีฬายิมนาสติกในซีเกมส์2015',
#  'คณะเผยแพร่ศาสนาแอละโมในแซนแอนโทนีโอ',
#  'เหตุกราดยิงในออสโลพ.ศ.2565',
#  'วอลเลย์บอลในซีเกมส์',
#  'ประเทศเวียดนามในซีเกมส์2015',
#  'พระราชโอรสในรัชกาลที่',
#  'การระบาดทั่วของโควิด-19ในประเทศบูร์กินาฟาโซ',
#  'เจ้านายพระชันษายืนในราชสกุลรัชกาลที่',
#  'เหตุระเบิดในบาหลี',
#  'เจ้าจอมมารดาดวงคำในรัชกาลที่4',
#  'ซอฟต์เทนนิสในกีฬาแห่งชาติครั้งที่',
#  'เหตุการณ์รถไฟชนรถบัสในจังหวัดฉะเชิงเทรา',
#  'อุทกภัยและดินถล่มในภาคตะวันตกเฉียงใต้ของประเทศญี่ปุ่น',
#  'ลักเซมเบิร์กในสงครามโลกครั้งที่สอง',
#  'ประเทศไทยในพ.ศ.2492',
#  'เหตุโจมตีในอัลมินยาพ.ศ.2560',
#  'ศาสนาอิสลามในสหราชอาณาจักร',
#  'ในฝัน',
#  'การระบาดของอหิวาตกโรคในเฮติพ.ศ.2553',
#  'การรับบุคคลเข้าศึกษาในสถาบันอุดมศึกษาในประเทศไทย',
#  'การเผยแผ่พระพุทธศาสนาในสหรัฐอเมริกา',
#  'กีฬากาบัดดีในเอเชียนเกมส์',
#  'โรงเรียนการกุศลของวัดในพระพุทธศาสนา',
#  'ฟุตบอลในประเทศอังกฤษ',
#  'เนื่องในโอกาสการจัดงานฉลองสิริราชสมบัติครบ',
#  'กีฬาว่ายน้ำมาราธอนในเอเชียนเกมส์',
#  'การบันทึกภาพในสมอง',
#  'ในประเทศอาร์มีเนีย',
#  'เวลาในประเทศตุรกี',
#  'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐพ.ศ.2552',
#  'โครงข่ายระบบรถไฟฟ้าในประเทศไทย',
#  'ประเทศปากีสถานในเอเชียนบีชเกมส์2010',
#  'ประเทศอินโดนีเซียในซีเกมส์2007',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทยกันยายนพ.ศ.2535',
#  'จังหวัดในประเทศญี่ปุ่น',
#  'ความขัดแย้งในประเทศซูดานพ.ศ.2566',
#  'ประเทศรัสเซียใน',
#  'หมายเลขโทรศัพท์ในประเทศตองกา',
#  'สกิลโกงไร้เทียมทานสร้างตำนานในสองโลก-ชีวิตพลิกผันด้วยการอัปเลเวล-',
#  'ศาสนาอิสลามในประเทศตุรกี',
#  'จังหวัดนนทบุรีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไปพ.ศ.2548',
#  'จังหวัดปทุมธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'ในยามแห่งอาวุธกฎหมายทรุดเงียบลง',
#  'พระราชสันตติวงศ์ในสมเด็จพระเจ้าจอร์จที่3',
#  'กีฬาปีนหน้าผาในเวิลด์เกมส์',
#  'เหตุเพลิงไหม้อาคารในโจฮันเนสเบิร์กพ.ศ.2566',
#  'บ้านแถวในเมือง',
#  'มนุษย์เล็กในเปลือกสมอง',
#  'โทรทัศน์ประเทศไทยในค.ศ.1998',
#  'ในสมัยสงครามโลกครั้งที่สอง',
#  'ประเทศไทยในค.ศ.2018',
#  'อาณาจักรในอาร์ดา',
#  'ฟุตบอลในประเทศโครเอเชีย',
#  'กรีฑาชายหาดในเอเชียนบีชเกมส์',
#  'แผ่นดินไหวในจังหวัดนีงาตะ',
#  'แผ่นดินไหวในประเทศอัฟกานิสถานมิถุนายนพ.ศ.2565',
#  'เรือแคนูในซีเกมส์2013',
#  'การรุกรานของมองโกลในยุโรป']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (5976, 1488)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศไมโครนีเซียในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศออสเตรียในโอลิมปิกฤดูหนาว1968',
#  'ประเทศแอนติกาและบาร์บูดาในพาราลิมปิกฤดูร้อน',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน2012',
#  'ประเทศกานาในโอลิมปิกฤดูร้อน1972',
#  'ประเทศซูดานใต้ในโอลิมปิกฤดูร้อน2020',
#  'ประเทศจีน',
#  'ประเทศตุรกีในโอลิมปิกฤดูร้อน1976',
#  'ประเทศนอร์เวย์ในโอลิมปิกฤดูหนาว1952',
#  'ประเทศเบนินในโอลิมปิกฤดูร้อน1992',
#  'ประเทศพม่าในโอลิมปิกฤดูร้อน1980',
#  'ประเทศเกาหลีเหนือในเอเชียนเกมส์2022',
#  'ประเทศแคนาดาในโอลิมปิกฤดูร้อน1912',
#  'ประเทศโกตดิวัวร์ในโอลิมปิกฤดูร้อน1968',
#  'ประเทศฟีจีในโอลิมปิกฤดูร้อน1988',
#  'ประเทศแอลเบเนียในโอลิมปิกเยาวชนฤดูหนาว2020',
#  'ประเทศวานูวาตูในโอลิมปิกเยาวชนฤดูร้อน2010',
#  'ประเทศไทยในพ.ศ.2525',
#  'ประเทศบรูไนดารุสซาลามในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศเนเธอร์แลนด์ในโอลิมปิกฤดูหนาว1988',
#  'ประเทศจีนในพาราลิมปิกฤดูร้อน2012',
#  'ประเทศอียิปต์ในโอลิมปิกฤดูร้อน1984',
#  'ประเทศจอร์เจียในโอลิมปิกฤดูหนาว2018',
#  'ประเทศเกาหลีเหนือในโอลิมปิกฤดูร้อน2008',
#  'ประเทศชิลีในโอลิมปิกฤดูร้อน1924',
#  'ประเทศคอสตาริกาในพาราลิมปิกฤดูร้อน2012',
#  'ประเทศอิตาลีในโอลิมปิกฤดูร้อน2016',
#  'ประเทศเนปาลในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูหนาว2018',
#  'ประเทศบราซิลในพาราลิมปิกฤดูร้อน2020',
#  'ประเทศไทยในเอเชียนเกมส์1994',
#  'ประเทศโปแลนด์ในโอลิมปิกฤดูร้อน1964',
#  'ประเทศพม่าในโอลิมปิกฤดูร้อน1972',
#  'ประเทศกาตาร์ในโอลิมปิก',
#  'ประเทศแทนซาเนียในโอลิมปิกฤดูร้อน2008',
#  'ประเทศลิเบียในโอลิมปิกฤดูร้อน2020',
#  'ประเทศไทยในพ.ศ.2428',
#  'ประเทศเบลเยียมในโอลิมปิกฤดูร้อน1968',
#  'ประเทศไทยในโอลิมปิกฤดูร้อน',
#  'ประเทศกายอานาในพาราลิมปิกฤดูร้อน',
#  'ประเทศนอร์เวย์ในโอลิมปิกฤดูหนาว1928',
#  'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน1908',
#  'ประเทศจีนในโอลิมปิกเยาวชนฤดูหนาว',
#  'ประเทศนิวซีแลนด์ในโอลิมปิกฤดูร้อน1968',
#  'ประเทศจาเมกาในโอลิมปิกฤดูหนาว1994',
#  'ประเทศเกาหลีใต้ในโอลิมปิกฤดูร้อน2016',
#  'ประเทศมองโกเลียในโอลิมปิกฤดูร้อน2008',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน1996',
#  'ประเทศปารากวัยในโอลิมปิกฤดูร้อน',
#  'ประเทศบรูไนดารุสซาลามในโอลิมปิกฤดูร้อน1988',
#  'ประเทศอิตาลีในโอลิมปิกฤดูหนาว1952',
#  'ประเทศเยอรมนี',
#  'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูร้อน1924',
#  'ประเทศออสเตรียในโอลิมปิกฤดูหนาว2014',
#  'ประเทศลาวในเอเชียนเกมส์2006',
#  'ประเทศเบอร์มิวดาในโอลิมปิกฤดูร้อน1984',
#  'ประเทศตองงาในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศฟินแลนด์ในโอลิมปิกฤดูหนาว2018',
#  'ประเทศศรีลังกาในเอเชียนเกมส์2014',
#  'ประเทศสเปนในโอลิมปิกฤดูหนาว1980',
#  'ประเทศอิรักในโอลิมปิก',
#  'ประเทศเอลซัลวาดอร์ในโอลิมปิกฤดูร้อน2016',
#  'ประเทศฟินแลนด์ในโอลิมปิกฤดูหนาว1968',
#  'ประเทศเอริเทรียในโอลิมปิกฤดูร้อน2012',
#  'ประเทศอุซเบกิสถานในเอเชียนเกมส์2022',
#  'ประเทศศรีลังกาในเอเชียนเกมส์2010',
#  'ประเทศต่ำ',
#  'ประเทศเซาตูแมอีปริงซีปในโอลิมปิกเยาวชนฤดูร้อน2018',
#  'ประเทศบราซิลในโอลิมปิกฤดูหนาว1992',
#  'ประเทศเติร์กเมนิสถานในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศเซนต์คิตส์และเนวิส',
#  'ประเทศตรินิแดดและโตเบโกในโอลิมปิกฤดูร้อน1980',
#  'ประเทศวานูวาตูในโอลิมปิกฤดูร้อน2020',
#  'ประเทศโรมาเนียในโอลิมปิกฤดูร้อน1924',
#  'ประเทศนามิเบียในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศญี่ปุ่นในโอลิมปิกฤดูหนาว1932',
#  'ประเทศบรูไนดารุสซาลามในซีเกมส์2015',
#  'ประเทศโกตดิวัวร์ในโอลิมปิกฤดูร้อน2024',
#  'ประเทศไทยในพ.ศ.2419',
#  'ประเทศเซนต์ลูเชียในโอลิมปิกฤดูร้อน2020',
#  'ประเทศไทยในพ.ศ.2446',
#  'ประเทศไทยในพ.ศ.2425',
#  'ประเทศฟีจีในโอลิมปิกฤดูหนาว2002',
#  'ประเทศซานมารีโนในโอลิมปิกฤดูหนาว',
#  'ประเทศจาเมกาในโอลิมปิกฤดูร้อน',
#  'ประเทศญี่ปุ่นในโอลิมปิกเยาวชนฤดูร้อน2014',
#  'ประเทศกรีซในโอลิมปิกฤดูร้อน2024',
#  'ประเทศอิสราเอลในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศออสเตรียในโอลิมปิกฤดูหนาว1972',
#  'ประเทศโครเอเชียในโอลิมปิกฤดูร้อน2008',
#  'ประเทศบัลแกเรียในโอลิมปิกเยาวชนฤดูหนาว2020',
#  'ประเทศอิหร่านในโอลิมปิกฤดูหนาว2014',
#  'ประเทศนิการากัวในพาราลิมปิกฤดูร้อน2016',
#  'ประเทศอุซเบกิสถานในเอเชียนเกมส์2014',
#  'ประเทศโมซัมบิกในโอลิมปิกฤดูร้อน2024',
#  'ประเทศเฮติในโอลิมปิกเยาวชนฤดูร้อน',
#  'ประเทศไทยในเวิลด์เกมส์2017',
#  'ประเทศเช็กโกสโลวาเกียในโอลิมปิกฤดูหนาว1984',
#  'ประเทศสเปนในโอลิมปิกฤดูร้อน2012',
#  'ประเทศบรูไนดารุสซาลามในโอลิมปิกฤดูร้อน1996']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ
