# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random
import re

# %%
random.seed(334)

# %%
def get_samples(titles_set, n=100):
    return random.sample(list(titles_set), n)

# %%
_len = 0
def get_len(titles):
      global _len
            
      current_len = len(titles)
      print(f'current: {current_len}\n'
            f'diff: {current_len - _len}')

      _len = current_len

      return

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = set(f.read().splitlines())
    
get_len(titles)
# Out:
# current: 362955
# diff: 362955

# %%
get_samples(titles)
# Out:
# ['เกาะคลุ้ม',
#  'ดางาชิ',
#  'นักสืบหุ่นยนต์',
#  'สาธารณรัฐโปรตุเกสในโอลิมปิกฤดูหนาว_2014',
#  'รถถังหนักสุดยอด',
#  'ฌอน_คิงสตัน',
#  'Free_&_Easy',
#  'คณะบริหารธุรกิจ_มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'มังกรหยก_2_ภาค_จอมยุทธอินทรี',
#  'แฮ็กเกอร์',
#  'P!nk',
#  'Fabio_Cannavaro',
#  'ระบบประสาทส่วนกลาง',
#  'มะเร็งต่อมน้ำเหลือง',
#  'สัญญาณขัดจังหวะ',
#  '(วอตส์เดอะสตอรี)_มอร์นิงกลอรี?',
#  'Cryptonchidae',
#  'Tsukasa_Hojo',
#  'Birmingham_City_F.C.',
#  'กล้องทาบเงา',
#  'สะพานกีซูนา',
#  'Bellagio_(Italian_region)',
#  'อนุสาวรีย์คู่บารมีกู้แผ่นดิน',
#  'เคมีภาคคำนวณ',
#  'Elaioplast',
#  'ฮัวหิม',
#  'หลินชาง',
#  'เพลงประจำสาธารณรัฐอะดีเกยา',
#  'ข้างขึ้น',
#  'อำเภออัลฮัยมะตุลคอริญียะฮ์',
#  'หนังคัลท์',
#  'สกุลหนูพุก',
#  'ประเทศเปรูในโอลิมปิกฤดูร้อน_1964',
#  'คณะศิลปศาสตร์_มหาวิทยาลัยขอนแก่น',
#  'ยูยะ_อูจิดะ',
#  'กูเกิล',
#  'เพรียวพันธ์_ดามาพงศ์',
#  'Jets_de_Viry-Essonne',
#  'พระองค์เจ้าสิริภาจุฑาภรณ์',
#  'ทิก_กว๋าง_ดึ๊ก',
#  'Deng_Yingchao',
#  '๒๙_กันยายน',
#  'จักรพรรดิเฮเซ',
#  'ฟิฟทีนแอนด์',
#  '345_ปีก่อนคริสตกาล',
#  'Erismadelphus',
#  'Situational_comedy',
#  'ธาตุคาบ_9',
#  '๒๔_กันยายน',
#  'Hua_Chenyu',
#  'BSA',
#  'รัฐสุลต่านมามลุค_(ไคโร)',
#  'อิโรซุกุเซไกโนะอาชิตะการะ',
#  'การท่องเที่ยวในกรุงเทพมหานคร',
#  'ที่ราบสูงเปอร์เซีย',
#  'มลรัฐฟลอริด้า',
#  'เคมบริดจ์_(แก้ความกำกวม)',
#  "Les_Contes_d'Hoffmann",
#  'อนุมาน',
#  'วัดเทพประสิทธิ์คณาวาส',
#  'สาธารณรัฐไซปรัสในโอลิมปิกฤดูหนาว_2014',
#  'บาลี_(แก้ความกำกวม)',
#  'การเขียนคำทับศัพท์ภาษาพม่า',
#  'บันเทิงคดีแนวจินตนิมิต',
#  'บิลเบา',
#  'การท่าเรือไทย_เอฟ.ซี.',
#  'มาร์ชา_โทมาสัน',
#  'Troglotrematidae',
#  'ใบประกอบวิชาชีพครู',
#  'อัลมะฮัลละตุลกุบรอ',
#  'กีฬามวยสากลในโอลิมปิกฤดูร้อน_2024_–_รอบคัดเลือก',
#  'เบอซิติส',
#  'เอ็นดับเบิลยูเอ_สตารร์เคจ',
#  'Rhadinematidae',
#  'นักเศรษฐศาสตร์',
#  'The_WB',
#  'วิทยาลัยชุมชนระนอง_สถาบันวิทยาลัยชุมชน',
#  'พรรคอาเจะฮ์',
#  'ความขัดแย้งในเซาท์คอร์โดฟานและบลูไนล์',
#  'จังหวัดเนโกรสโอเรียนตัล',
#  'นักบุญมัทธิวผู้ประกาศข่าวประเสริฐ',
#  'เกมออฟโธรนส์',
#  'เควิน_มิราลาส',
#  'เท่ง',
#  'สนธิสัญญาวอชิงตัน',
#  'Cherokee',
#  'เดเนธอร์',
#  'เลขาธิการพระราชวัง',
#  'พิกซีส์',
#  'กูดเขากวาง',
#  'คาซึยุกิ_โอกิสึ',
#  'รางวัลชมรมวิจารณ์บันเทิง_สาขานักแสดงนำชายยอดเยี่ยม',
#  'รางวัลภาพยนตร์แห่งชาติ_สุพรรณหงส์_ครั้งที่_14',
#  'Biochemistry',
#  'บางพลู',
#  'อานิส_โรกา',
#  'วอลเลย์บอลในกีฬามหาวิทยาลัยโลก_1959',
#  'LUSS',
#  'แฟบูลาโนวาคริสตัลลิส:_ไฟนอล_แฟนตาซี',
#  'เดเกเลีย']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# This also covers "Include monks nicknames"
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %%
def extract_bracket(input_string):
    pattern = r'([^\(]+)\(([^)]+)\)'
    match = re.match(pattern, input_string)
    
    if match:
        a = match.group(1).strip()
        b = match.group(2).strip()
        
        # many has space("_") before bracket
        if a[-1] == "_":
            a = a[:-1]
            
        return [a, b]
    else:
        return [input_string]

[extract_bracket("บรั่นดี_(วงดนตรี)"), extract_bracket("บรั่นดี")]
# Out:
# [['บรั่นดี', 'วงดนตรี'], ['บรั่นดี']]

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(extract_bracket(title))
    
titles = titles_temp

get_len(titles)
# Out:
# current: 353833
# diff: -9122

# %%
get_samples(titles)
# Out:
# ['Jiajing_Emperor',
#  'แดร็ก_เรซ_ไทยแลนด์_ฤดูกาลที่_1',
#  'จ้าวกงหมิง',
#  'พระแม่ราธา',
#  'ฟาโรห์เชเนฮ์',
#  'ดิ_อัลบั้ม_ทรี_ฟรีด้อม',
#  'ซารอสดวงอาทิตย์ที่_111',
#  'นโรดม_สีหนุ',
#  'การลงคะแนนแบบคาร์ดินัล',
#  'Gang',
#  'Wb',
#  'Adachi,_Tokyo',
#  'ปลาบู่ทอง',
#  'House_of_Romanov',
#  'รายชื่อแหล่งมรดกโลกในประเทศเอสโตเนีย',
#  'ปราสาทคาสเตลโน-เบรอเทอนูซ์',
#  'Siamosia_thailandica',
#  'ชเต็ฟฟัน_ครา',
#  'สถานีวิทยุโทรทัศน์กองทัพบกช่อง_7',
#  'พ.ศ._413',
#  'พนักงานมหาวิทยาลัย',
#  'แคซ_ฮายาชิ',
#  'เฉลิม_ปานเกิด',
#  'Paul_Allen',
#  'ซิกกราฟ',
#  'Hannibal_Barca',
#  'NGC_6537',
#  'พระเจ้าจองจง_กษัตริย์องค์ที่_3_แห่งโครยอ',
#  'คลับเฮาส์',
#  'จอร์จที่_6_แห่งสหราชอาณาจักร',
#  'แกรนด์ดัชเชส',
#  'การแปลตามตัวอักษร',
#  'เรฟเมีย',
#  'พาราลิมปิกไอร์แลนด์',
#  'บริบูรณ์_จันทร์เรือง',
#  'เอเชียนเกมส์_2023',
#  'กีฬาทางอากาศในกีฬาแห่งชาติ_ครั้งที่_47',
#  'ยุกะ_โอซากิ',
#  'วาด_รวี',
#  'จักรพรรดิซ่งอินจง',
#  'รัฐพล_พรรณเชษฐ์',
#  'Culture_shock',
#  'วรรณกรรมกรีกโบราณ',
#  'กลไกขยายเสียงในคอเคลีย',
#  'สโมสรฟุตบอลทอตแนม_ฮอทสเปอร์',
#  'Kutaisi',
#  'สถานีรถไฟที่วัง',
#  'ตั้ว_ลพานุกรม',
#  'ancient_kingdom',
#  'วงศ์เทียนดอก',
#  'ปัณฑิตา_ภูวิจารย์_เคาวเวลล์',
#  'ฮาเนะดะ',
#  'ญะบัล_อันนะบีชุอัยบ์',
#  'สถานียมราช',
#  'Fujiwara_clan',
#  'มูน_/_บรอสซัม',
#  'ยัง_เซ-ชัน',
#  'The_Tales_of_Hoffmann',
#  'สิ่งก่อสร้างของคริสต์ศาสนา',
#  'Macrophages',
#  'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรในประเทศไทย_กันยายน_พ.ศ._2535',
#  'การปรับตัวผิด',
#  'แอลแซด_130_กราฟ_เซปเปลิน',
#  'ฟุตบอลชิงถ้วยพระราชทานประเภท_ข._ประจำปี_2552',
#  'คอมมอนบรัชเทลพอสซั่ม',
#  'อรชุน',
#  'เชาะ',
#  'แผ่นช่องรับแสง',
#  'กําแพงเพชรพิทยาคม',
#  '๑๔_พฤษภาคม',
#  'วอลเลย์บอลหญิงชิงแชมป์อเมริกาใต้_1983',
#  'ปกรณัมชุด',
#  'จังหวัดเซลันด์',
#  'ซุปเปอร์โบวล์',
#  '224_Oceana',
#  'Schubert',
#  'บุปผา_นิมมานเหมินท์',
#  'Phormosomatidae',
#  'ศรีเมือง_เจริญศิริ',
#  'ทางหลวงเอเชียสาย_70',
#  'Tré_Cool',
#  'สถานีรถไฟตรอน',
#  'พระนางมารีย์พรหมจารี',
#  'Atum',
#  'คิม_อันโล',
#  'Yakitate!!_Japan',
#  'The_Destination',
#  'การประสูติของพระเยซู',
#  'เมงฮาย',
#  'กุหลาบแดง',
#  'รูมรามา',
#  'พระราชประสิทธิคุณ',
#  'Dendrophthoe_pentandra',
#  'ฮอไรซันฟอร์บิดเดนเวสต์',
#  'โกลด_มอแน',
#  'Curicó',
#  'Niponiosomatidae',
#  'ไฮร็อก',
#  'ผู้เล่นในเอเชียนคัพ_2019',
#  'ทุกขเวทนา']

# %% [markdown]
# ### Seperate/Integrate space
# Handle the seperated words as different words + Connect them and handle them as one word

# %% [markdown]
# ("Seperate space between names" also covered by this)
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %%
titles_temp = set()

for title in titles:
    # "space" of the title is replaced by "_" in the data
    words = title.split("_")
    
    # as different words
    titles_temp.update(words)
    
    # connect and as one word
    titles_temp.add("".join(words))
        
titles = titles_temp

get_len(titles)
# Out:
# current: 465912
# diff: 112079

# %%
get_samples(titles)
# Out:
# ['แบลซมาตุยดี',
#  'Meiko',
#  'N.E.R.D',
#  'ทูเซ็ตไวโอลิน',
#  'อ.หัวตะพาน',
#  'การปกป้องชาติจากการเข้าเมืองสหรัฐของผู้ก่อการร้ายต่างด้าว',
#  'สมเด็จพระราชินีซาโลเตลูเปเปาอู',
#  'เจ้าหญิงโซฟีแห่งโฮเอ็นแบร์ก',
#  'ปวยร์โตรีโกในโอลิมปิกฤดูร้อน1996',
#  'ตั๋งห้อง',
#  'Sagala',
#  'รานีนี',
#  'footballerborn1991',
#  'แขวงนาดะ',
#  'อิโมโตะ',
#  'แซ่เห้ง',
#  'มาร์กวี-เอ1',
#  'กามีย์แบร์ตอมีเย',
#  'เส้นขนานที่64องศาเหนือ',
#  'รายชื่อโบราณสถานในจังหวัดอำนาจเจริญที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'พ.ศ.960',
#  'เวนต์สปิลส์',
#  'YooHee-jae',
#  'ไอเอสโอ',
#  'มิสเวิลด์2553',
#  'ความผิดอาญาสงคราม',
#  'หลี่ตายแทนถาว',
#  'ทพ.กฤษดาเรืองอารีย์รัชต์',
#  'อัลเฟรโดดีสเตฟาโน',
#  'กองพิทักษ์การปฏิวัติอิสลาม',
#  'วิทยาลัยอาชีวศึกษามหาสารคามสถาบันการอาชีวศึกษาภาคตะวันออกเฉียงเหนือ๓',
#  'TheCalloftheWild',
#  'พิชชาภา',
#  'อีวาโนเอ',
#  'Ubantu',
#  'เปอตีต์โมนิ',
#  'Oktopus',
#  'สมเด็จพระเจ้าบรมวงศ์เธอเจ้าฟ้าวิจิตรจิรประภาอดุลยาดิเรกรัตนขัตติยราชกุมารี',
#  'ประชาทัณฑ์',
#  'สุภาพรกิตติขจร',
#  'โตฟีงา',
#  'FBT',
#  'ปาทริควิเอร่า',
#  'รายชื่อธงในประเทศอิรัก',
#  'Battlefront',
#  'วีระเศรษฐกุล',
#  'ดยุกแห่งนาร์เก',
#  'อียู-จิน',
#  'ChildrenoftheGrave',
#  'ซัมเมอร์ไทม์แซดเนส',
#  'Odontitella',
#  'Astonish',
#  'Applewatch',
#  'ซัลบาโดดาลี',
#  'บ้านนาเล',
#  'Elbe',
#  'พระที่นั่งจงเหอ',
#  'ลีร็อย',
#  'บาเธเลมีฟานเอค',
#  'กาบริเอลบอริช',
#  'JokerXue',
#  'ยูเฮ',
#  'ฮัมมามัต',
#  'โยฮันมายอร์',
#  'อะยุมุ',
#  'Brownfield',
#  'การแบ่งแยกแอร์ฟวร์ต',
#  'วันไม้เท้าขาว',
#  'กรุงนิวเดลี',
#  'คำรณ',
#  'Labyrinthusosseus',
#  'assault',
#  'Oyakodon',
#  'โอลิมปิกฤดูร้อน1976',
#  'ศัมภาลา',
#  'พ.ศ.2014',
#  'CathedralofPadua',
#  'คณะวิศวกรรมศาสตร์มหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'ปาปุรอส',
#  'อะเดโมลา',
#  'AsianFootballConfederation',
#  'สถานีรถไฟหนองน้ำขุ่น',
#  'โพลีไซคลิกอะโรมาติกไฮโดรคาร์บอน',
#  'คนึงพิมพ์ธนพิชชากรณ์',
#  'กรมปรึกษาชาติชั้นสูง',
#  'ประเทศอิรักในโอลิมปิก',
#  'ชอบธรรม',
#  'Epiduralhematoma',
#  'อาสนวิหารวีวีเย',
#  'เดียรถีย์',
#  'ซะรุโทะบิซะซึเกะ',
#  'ประเทศออสเตรเลียในพาราลิมปิกฤดูร้อน',
#  'ขบวนการไดโนเสาร์ประคุ',
#  'โอเดอร์',
#  'กระทรวงในประเทศญี่ปุ่น',
#  'สโมสรฟุตบอลแมนเชสเตอร์ยูไนเต็ดในฤดูกาล2012–13',
#  'ยาป้องกันไม่ให้เลือดตัวจับกันเป็นก้อน',
#  'Krystsina',
#  'เสอซื่อม่าน',
#  'วิวาห์ลวง']

# %% [markdown]
# ### Exclude complete non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
#
# intend to remove non named entity which year included

# %%
titles = set([title for title in titles if "พ.ศ." not in title])

get_len(titles)
# Out:
# current: 459718
# diff: -6194

# %%
get_samples(titles)
# Out:
# ['พระเจ้ารอเบิร์ตที่3แห่งสกอตแลนด์',
#  'สมาพันธ์ว่ายน้ำแอฟริกัน',
#  'เจ้าฟ้าชายหลุยส์',
#  'การยิงธนู',
#  'บุศนันทน์อึ๊งบำรุงพันธุ์',
#  'พระเจ้ายูริแห่งโคกูรยอ',
#  'ชวาร์ซวัลด์-ซตาดิโอน',
#  'เทียมศักดิ์',
#  'กรันตูริสโม่สปอร์ต',
#  'nad',
#  'นานาโวะอาการิ',
#  'Veal',
#  'Helens',
#  'เซน-มยิน',
#  'Fukuyama,Hiroshima',
#  'เหตุการณ์ชุมนุมแฟลชม็อป',
#  'ฟุตบอลโลก2022รอบคัดเลือกโซนยุโรป–กลุ่มเอ',
#  '1326',
#  'คายกคณะ',
#  'อีมินนู',
#  'ม้าต๋ง',
#  'กองรบพิเศษที่5',
#  'สตาร์วอร์ส:ไนทส์ออฟดิโอลด์รีพับลิค',
#  'ทีซีแอลคอร์ปอเรชัน',
#  'สารสนเทศการลงทุน',
#  'ซันโครว',
#  'ยะตะโรคุโระกะวะ',
#  'พันเอกวันชนะ',
#  'ดาบอันดูริล',
#  'วัดตาขัน',
#  'HPAaxis',
#  'ข้าวทริติเคลี',
#  'พยาธิ',
#  'แรมซีย์แมกดอนัลด์',
#  'นีกอลาเฌสกีแยร์',
#  'เฮาเวิร์ด',
#  'พระอุโบสถ',
#  'วัดแฮดงยงกุง',
#  'GentaMiura',
#  'พระสี',
#  'Atractosteus',
#  'เส้นขนานที่51องศาเหนือ',
#  'ประยูรศักดิ์',
#  'รางวัลภาพยนตร์แห่งชาติสุพรรณหงส์ครั้งที่2',
#  'รายชื่อเหรียญราชอิสริยาภรณ์ไทย',
#  'พระแม่ปฤถวี',
#  'จื่อตัน',
#  'ภาษานอร์สโบราณ',
#  'อินซิกนีโอรุม',
#  'ซีต้า',
#  'HippolyteFizeau',
#  'เจ้าหญิงฮานาโกะ',
#  'Motors',
#  'เขตธรรมชาติงดงามดีเด่น',
#  'ดรากอนฟอร์ส',
#  'ดับเบิลยูดับเบิลยูอีสแม็คดาวน์',
#  'Nikopol,',
#  'Heihachiro',
#  'ท่าอวกาศยาน',
#  'Eyetail',
#  'เอ๊กจิ๋ว',
#  'ไอริส',
#  'โนเวฟ',
#  'สุซุกิ',
#  'Zekai',
#  'Shangdynasty',
#  'Canterbury,NewZealand',
#  'ถนนเทพคุณากร',
#  'Doyle',
#  'อาร์เอนเอนำรหัส',
#  'โจโจนัส',
#  'แอฟริกาคัพออฟเนชันส์',
#  'รายชื่อรางวัลและการเสนอชื่อที่ภาพยนตร์ในจักรวาลภาพยนตร์มาร์เวลได้รับ',
#  'โงดินห์เสี่ยม',
#  'กีฬาวิ่งสเกตในเอเชียนเกมส์ฤดูหนาว',
#  'บริติชแอร์เวย์เที่ยวบินที่5390',
#  'คลอแรมเฟนิคอล',
#  'มหาวิหารเซนต์พอล',
#  'สาธารณรัฐมาซิโดเนียในโอลิมปิกฤดูร้อน2008',
#  'พระเจ้าคาร์ลที่15แห่งสวีเดน',
#  'Hydraulic',
#  'อาบรักกระบี่คม',
#  'Gallimorphae',
#  'ระบบสัดส่วนแบบบัญชีรายชื่อปิด',
#  'ปลานา',
#  'เจ้าชายภัคคุ',
#  'Viscerocranium',
#  'เดอะทันเดอเรอร์',
#  'RévolutiondeJuillet',
#  'Scandium',
#  'แคว้นโยนก',
#  'ประเทศชิลีในโอลิมปิกฤดูหนาว1948',
#  'ประวัติศาสตร์อัฟกานิสถาน',
#  'RoyalGovernmentoftheNationalUnionofKampuchea',
#  'พลเรือตรีถวัลย์',
#  'ดัชนีความหนาของร่างกาย',
#  'เชอเรียเบลนดี้',
#  'ซีเอฟเอ็นเอ็ม',
#  'เซอร์ไวเวอร์ไทย',
#  'วัดมัชฌิมาราม']

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = set(titles_temp)

get_len(titles)
# Out:
# current: 340300
# diff: -119418

# %%
get_samples(titles)
# Out:
# ['วิมานมะพร้าว',
#  'ชิวแบคก้า',
#  'กรพินธุ์พ่วงโพธิ์',
#  'สโมสรฟุตบอลจุฬาฯยูไนเต็ด',
#  'ฟุตบอลในประเทศรัสเซีย',
#  'อาซิซิ',
#  'ราชอาณาจักรฮัชไมต์จอร์แดนในเอเชียนเกมส์',
#  'พงศ์สันต์ธมฺมเสฎฺโฐ',
#  'คณะรัฐมนตรีสยามคณะที่2',
#  'หวงเฟยหง5สยบจอมสลัด',
#  'ยออานกาบาย',
#  'ศาสตร์คอมพิวเตอร์',
#  'ฮิมูระเคนชิน',
#  'ระบบดาวคู่รังสีเอ็กซ์',
#  'ปลานกขุนทองปากยื่น',
#  'อเล็กซานเดอร์หวัง',
#  'ประเทศกัมพูชาในพาราลิมปิกฤดูร้อน2016',
#  'โลทัสเทมเพิล',
#  'สถานีรถไฟบ้านหนองหมู',
#  'สโตรคออนเทรนท์',
#  'พรีเมียร์ลีกแห่งบอสเนียและเฮอร์เซโกวีนา',
#  'พระราชินีเอลิซาเบธ',
#  'เกิดอวอร์ด',
#  'ชัยวรรมันที่1',
#  'รัฐและดินแดนสหพันธ์ของประเทศมาเลเซีย',
#  'กีฬายิงปืนในเอเชียนเกมส์2022',
#  'โมบิลสูทกันดั้มยูนิคอร์น',
#  'ฟอร์ทีนเนอร์',
#  'ศรีนอก',
#  'ประเทศแคเมอรูนในพาราลิมปิกฤดูร้อน2012',
#  'ขบวนการเคลื่อนไหวแห่งชาบัก',
#  'ฮะรุโนะยุโงะคุชิโระ',
#  'บอสเนีย-เฮอร์เซโกวีนา',
#  'มะสึดะ',
#  'ซานามิเวียร์',
#  'ประเทศไอซ์แลนด์ในโอลิมปิกฤดูร้อน1992',
#  'อุปรากรกรุงเทพฯ',
#  'ศาสตราจารย์ดัมเบิลดอร์',
#  'จังหวัดอาลป์-มารีตีม',
#  'วอลเลย์บอลชายทีมชาติตูนิเซีย',
#  'พระเจ้าบรมวงศ์เธอกรมหมื่นศรีสุเทพ',
#  'เกวตซัลโกอัตล์',
#  'ภาษากลุ่มคอเคซัส',
#  'จันทนะผะลิน',
#  'ซีวิคไทป์อาร์',
#  'ซูเปอร์โมเดลอินเตอร์เนชันแนล',
#  'ซะชิโกะ',
#  'อำเภอป่าซาง',
#  'วงศ์อิกัวนา',
#  'วีค',
#  'สิงโตมาไซ',
#  'ชยสุริยา',
#  'มอลทิญญา',
#  'วัดกาญจนสิงหาสน์',
#  'โปเตโต้',
#  'สำนักงานคณะกรรมการนโยบายรัฐวิสาหกิจ',
#  'บีอาร์เอ็นโคออร์ดิเนต',
#  'แร่เหล็ก',
#  'วัดพระเชตุพนวิมลมังคลารามราชวรมหาวิหาร',
#  'ปัปเป็ตส์',
#  'การหนีไปอียิปต์',
#  'ถนนเทพรัตน',
#  'พาร์กแอเวนู',
#  'บันทึกรักของพิมพ์ฉวี',
#  'ชาวพยู',
#  'วังราชทัต',
#  'รายชื่อบริษัทอะนิเมะ',
#  'ยศทหารอิหร่าน',
#  'โยริสมาไทจ์เซน',
#  'เสาค้ำ',
#  'เกนก็อบ',
#  'วาญิบ',
#  'จูอี้',
#  'รัฐเทนเนสซี',
#  'คีวเก็ตสึกิ',
#  'เอียรอส',
#  'ต้นฝรั่ง',
#  'อุดซีมาวายามาซีวา',
#  'อาร์มานด์กุยลอแมง',
#  'อาแซดอัลค์มาร์',
#  'ปวรพัฒน์',
#  'พระราชาธิบดีนิโคลัส',
#  'คำสลับอักษร',
#  'อักษรอเวสตัน',
#  'ตำบลกฤษณา',
#  'เกาะคาปรี',
#  'เงื่อนตะคุ',
#  'ภาษาเขมรสูง',
#  'เซอร์ไว',
#  'เมดัน',
#  'เมกะฟอร์ซ',
#  '304ปีก่อนคริสตกาล',
#  'ยฺหวินหนาน',
#  'วาศภูติ',
#  'แขวงคานางาวะ',
#  'พระพรหมวชิรปัญญาจารย์',
#  'ปลาซิวซอ-บว่า',
#  'เกตตา',
#  'เพียนซา',
#  'ซงเหียน']

# %% [markdown]
# ### Seperate by non-thai character
#
# such as ".", ":", "-"

# %% [markdown]
# Yes, definetly `:` used for subtitles

# %%
titles_temp = set()

for title in titles:
    titles_temp.update(re.split("[^\u0E00-\u0E7F]+", title))
    
titles = titles_temp
get_len(titles)
# Out:
# current: 305063
# diff: -35237

# %%
get_samples(titles)
# Out:
# ['จังหวัดของฝรั่งเศส',
#  'อธิบดีกรมโยธาธิการและผังเมือง',
#  'คิระคิระพรีเคียว',
#  'พระราชวังบวรสถานพิมุข',
#  'พระเจ้าสุกโกทนะ',
#  'รอนวีสลีย์',
#  'วัดแก้ว',
#  'มารานัค',
#  'ศูนย์ฌอร์ฌ',
#  'รับน้องกระต่ายซักแก้วไหมคะ',
#  'สังคม',
#  'อารามสตาฟโรโปลีโอส',
#  'พระเจ้าสูรยวรมันที่',
#  'สมเด็จพระเจ้าเอ็ดการ์',
#  'ดินาราซาฟิน่า',
#  'รายนามอธิบดีกรมประมง',
#  'พักฮย็อง',
#  'สนธิสัญญาว่าด้วยการตกลงขั้นสุดท้ายเกี่ยวกับดินแดนเยอรมนี',
#  'ประเทศซิมบับเวในโอลิมปิก',
#  'ไพโรจน์วายุภาพ',
#  'เรือข้ามฟากเกาหลีใต้พลิกคว่ำ',
#  'ถิ่นแสน',
#  'เมสเซอร์ชมิทท์',
#  'แฟรงกลินเพียร์ซ',
#  'วัดโคกหม้อ',
#  'อาติกาห์',
#  'ไอเอ็มไอกาลิว',
#  'หเลพีฑู',
#  'ข้าราชการพลเรือนในสถาบันอุดมศึกษา',
#  'หนึ่งคำที่ล้นใจ',
#  'ฟองน้ำปะการัง',
#  'ไอแซคฮันนี',
#  'พระที่นั่งมหิศรปราสาท',
#  'คิมโย',
#  'ไฮดรอกซิซีน',
#  'รับขวัญ',
#  'สนามกีฬาอีรัมบีตอร์น',
#  'รายชื่อโบราณสถานในจังหวัดอุดรธานีที่ขึ้นทะเบียนโดยกรมศิลปากร',
#  'ผีหมอหมอผี',
#  'มิตสึกิไซงะ',
#  'สเตาร์บริดจ์',
#  'อาลิซาเบธแซ๊ดเลอร์',
#  'ซาลิมาสุลต่านบีกัม',
#  'โนบอดี',
#  'คลูช',
#  'ฟินีเชียน',
#  'ปลากระโห้',
#  'อาเบอร์เลอ',
#  'เบอร์แบงค์',
#  'ราอุลบัลเดซ',
#  'สมเด็จพระราชชนนีแห่งโรมาเนีย',
#  'เอฟเคปาร์ตีซาน',
#  'จักรวรรดิอคีเมนิด',
#  'เมืองอานามิซึ',
#  'ดิเอเวอร์ลีบราเธอร์ส',
#  'ชาวอิรักเชื้อสายเติร์กเมน',
#  'ออนอเรฟรากอนาร์',
#  'พระเจ้าโอธอนแห่งกรีซ',
#  'อรสา',
#  'เนอร์วาน่า',
#  'ราชรัฐลีชเทินชไตน์',
#  'เอ็ดการ์ไรต์',
#  'เมืองละมาม',
#  'พชรพลจั่นเที่ยง',
#  'รายชื่อธงในประเทศกรีซ',
#  'โรคพยาธิกีเนีย',
#  'เชวซูยอง',
#  'จิมมี่แครมป์ตัน',
#  'อาร์เตมีเซีย',
#  'วิไซผาภูวนิน',
#  'เดชไอ้ด้วนภาค',
#  'พระเจ้าชุงนยอล',
#  'แอนทิโกนี',
#  'เฮย์',
#  'เดอะเชปออฟวอเทอร์',
#  'เปอร์กินเจ',
#  'ยงยุทธติยะไพรัช',
#  'รุยปาตรีซีอู',
#  'พรายพยากรณ์',
#  'ยูรีธมิกส์',
#  'งูแบล็กแมมบา',
#  'หาดคุจูคุริ',
#  'เฮริฟอร์ดเชอร์',
#  'วัดสิงห์ท่า',
#  'ซามูเอลเบ็คเค็ทท์',
#  'สิทธิของบุตรคนแรก',
#  'เวนเดล',
#  'ยันเดอไบร',
#  'โมเดสต์',
#  'ช็องยุนคยอม',
#  'แยชือสกอลีมอฟสกี',
#  'ขุนคงฤทธิศึกษากร',
#  'อสุภะ',
#  'กรอบมาตรฐานคุณวุฒิ',
#  'ฌูแซฟงตือ',
#  'สโมคตูนอฟสกี',
#  'ชาแซม',
#  'อาวน์ซิตี',
#  'จูบาต่ำ',
#  'สโมสรฟุตบอลวัวชน']

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %%
# lists ariticles all starts from "ราย"
# Observe them first

raay = [title for title in titles if title.startswith("ราย")]
len(raay)
# Out:
# 4621

# %%
get_samples(raay)
# Out:
# ['รายชื่อสมาชิกคณะมนตรีความมั่นคงแห่งสหประชาชาติ',
#  'รายชื่อทะเลสาบในประเทศญี่ปุ่น',
#  'รายชื่อธงชาติในเขตโอเชียเนีย',
#  'รายนามรัฐมนตรีว่าการกระทรวงมหาดไทย',
#  'รายชื่ออักษรในภาษาต่างๆแบ่งตามชนิดอักษร',
#  'รายพระนามและรายนามผู้ปกครองลิเบีย',
#  'รายชื่อผู้ครองตำแหน่งมิสแกรนด์อินเตอร์เนชันแนล',
#  'รายพระนามกษัตริย์แห่งอังกฤษ',
#  'รายชื่อรัฐมนตรีประจำสำนักนายกรัฐมนตรีของไทย',
#  'รายชื่อโรงเรียนในจังหวัดนราธิวาส',
#  'รายชื่อองค์กรปกครองส่วนท้องถิ่นในจังหวัดอุดรธานี',
#  'รายพระนามพระมหากษัตริย์อิตาลี',
#  'รายชื่อวัดในจังหวัดสงขลา',
#  'รายชื่อสัตว์เลื้อยคลาน',
#  'รายชื่อบุคคลจากมหาวิทยาลัยเทคโนโลยีราชมงคลรัตนโกสินทร์',
#  'รายพระนามเจ้าผู้ครองนครเชียงใหม่',
#  'รายชื่อนายกรัฐมนตรีสวีเดน',
#  'รายชื่อรางวัลทางการศึกษานานาชาติของไดซาขุอิเคดะ',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐประชาชนจีน',
#  'รายชื่อแคว้นของประเทศทาจิกิสถานตามดัชนีการพัฒนามนุษย์',
#  'รายชื่อวัดในจังหวัดนราธิวาส',
#  'รายชื่อประธานาธิบดีอินโดนีเซีย',
#  'รายชื่อบริษัทประกันภัยในประเทศไทย',
#  'รายการปริพันธ์ของฟังก์ชันตรีโกณมิติ',
#  'รายนามหัวหน้ารัฐบาลสตรีจากการเลือกตั้งหรือแต่งตั้ง',
#  'รายชื่อละครโทรทัศน์ทางช่องเวิร์คพอยท์',
#  'รายชื่อผลงานของ',
#  'รายนามประธานาธิบดีแห่งสาธารณรัฐเวียดนาม',
#  'รายชื่อตัวละครในเรื่องอินาสึมะอีเลฟเวนอาเรสโนะเท็นบิงและโอไรออนโนะโคคุอิน',
#  'รายชื่อไมโครซอฟท์วินโดวส์รุ่นต่างๆ',
#  'รายนามประธานาธิบดีมาดากัสการ์',
#  'รายงานประจำปี',
#  'รายการภาคเช้า',
#  'รายชื่อศิลปินแนวยูโรแดนซ์',
#  'รายนามรัฐมนตรีว่าการกระทรวงสาธารณสุขของไทย',
#  'รายชื่อโรงเรียนในจังหวัดนครราชสีมา',
#  'รายพระนามพระมหากษัตริย์มาดากัสการ์',
#  'รายชื่อบัญชีทวิตเตอร์ที่มีผู้ติดตามมากที่สุด',
#  'รายชื่อเพย์',
#  'รายการวันสำคัญเกี่ยวกับวิดีโอเกม',
#  'รายการเครื่องอิสริยาภรณ์สาธารณรัฐประชาชนจีน',
#  'รายชื่อแบบดึงลง',
#  'รายชื่อแชมป์เปี้ยนทั้งหมดของ',
#  'รายชื่อแม่น้ำในประเทศกัมพูชา',
#  'รายชื่อผลงานเพลงของเอ็นซีที',
#  'รายชื่อประเทศเรียงตามการผลิตไทเทเนียม',
#  'รายชื่อผลงานของเวิร์คพอยท์เอ็นเทอร์เทนเมนท์',
#  'รายชื่อผลงานทั้งหมดของแอลัน',
#  'รายชื่อรางวัลของวงเกิล์สเจเนอเรชั่น',
#  'รายชื่อโรงเรียนในจังหวัดเชียงใหม่',
#  'รายชื่อรัฐในสหรัฐอเมริกา',
#  'รายชื่ออาหารจากเต้าหู้',
#  'รายนามผู้ว่าราชการรัฐซาราวัก',
#  'รายชื่อปีในโทรทัศน์ตามประเทศ',
#  'รายพระนามสมเด็จพระราชินีและจักรพรรดินีแห่งเกาหลี',
#  'รายชื่อสะพานแขวนที่ยาวที่สุดในโลก',
#  'รายชื่อนักเขียนบันเทิงคดีแนววิทยาศาสตร์',
#  'รายชื่อผู้ดำรงตำแหน่งมิสไทยแลนด์เวิลด์',
#  'รายชื่อรุ่นของไมโครซอฟต์วินโดวส์',
#  'รายนามรัฐมนตรีว่การกระทรวงวัฒนธรรม',
#  'รายพระนามพระมหากษัตริย์โมร็อกโก',
#  'รายชื่อสายการบินในประเทศบรูไน',
#  'รายชื่ออัลบั้มเพลงที่ขับร้องโดยยอดรักสลักใจ',
#  'รายนามรัฐมนตรีช่วยว่าการกระทรวงมหาดไทยของไทย',
#  'รายชื่อตัวละครในนาร์เนีย',
#  'รายชื่อตอนเคโรโระ',
#  'รายชื่อโบราณสถานในจังหวัดยโสธร',
#  'รายชื่อดินแดนที่ถูกครอบครองโดยจักรวรรดินิยมญี่ปุ่น',
#  'รายชื่อประธานาธิบดีสาธารณรัฐฝรั่งเศส',
#  'รายชื่อส่วนหัวของเอชทีทีพี',
#  'รายชื่อผู้ชนะชาร์ตโชว์แชมเปียน',
#  'รายชื่อแหล่งมรดกโลกในประเทศกรีซ',
#  'รายชื่อแหล่งมรดกโลกในประเทศกาตาร์',
#  'รายชื่อผลงานเพลงของไมคุระกิ',
#  'รายชื่อนครที่ใหญ่ที่สุดในโลก',
#  'รายพระนามและรายนามที่จุดกระถางคบเพลิงโอลิมปิก',
#  'รายชื่อโบราณสถานในจังหวัดชุมพร',
#  'รายชื่อตอนในอนิเมะเรื่อง',
#  'รายชื่อเครื่องดนตรี',
#  'รายชื่อธงประจำแคว้นในฝรั่งเศส',
#  'รายพระนามพระมหากษัตริย์ไรอาเตีย',
#  'รายชื่อผู้ได้รับรางวัลบทภาพยนตร์ดัดแปลงยอดเยี่ยมรางวัลภาพยนตร์ไทย',
#  'รายชื่อเผ่าพันธุ์ในสตาร์',
#  'รายนามประธานรัฐสภา',
#  'รายชื่อบุคคลที่เป็นประธานในพิธีเปิดโอลิมปิก',
#  'รายชื่อนักกีฬาเอ็นบีเอ',
#  'รายชื่อเครื่องอิสริยาภรณ์โมซัมบิก',
#  'รายพระนามพระมหากษัตริย์สวาซิแลนด์',
#  'รายชื่อทางแยกในเขตบางรัก',
#  'รายนามบุคคลจากมหาวิทยาลัยศรีนครินทรวิโรฒ',
#  'รายชื่อวัดในจังหวัดนครสวรรค์',
#  'รายพระนามพระมหากษัตริย์ซาอุดิอาระเบีย',
#  'รายชื่อพระราชนิพนธ์ในสมเด็จพระเทพรัตนราชสุดาฯสยามบรมราชกุมารี',
#  'รายชื่อแชมป์ฟุตบอลเยอรมัน',
#  'รายนามผู้อำนวยการสถานศึกษาโรงเรียนสวนกุหลาบวิทยาลัยนนทบุรี',
#  'รายชื่อสถาบันแพทยศาสตร์ในประเทศไทย',
#  'รายชื่อตัวการ์ตูนของซานริโอ',
#  'รายนามคู่สมรสนายกรัฐมนตรีของไทย',
#  'รายพระนามเทวดาแห่งโชคลาภ',
#  'รายชื่อไวรัสคอมพิวเตอร์']

# %% [markdown]
# Some seems to be not related to list-article.(Such as names, "รายยวา")
#
# Exclude them in rule-base

# %%
#check if it is a list article in rule-based
def is_list_article(title):
    # a few articles have miss-tone-mark
    # -> check without tone-mark
    title_no_tone = pythainlp.util.remove_tonemark(title)
    
    return (title_no_tone.startswith("รายการ")
        or title_no_tone.startswith("รายชือ")
        or title_no_tone.startswith("รายพระ")
        or title_no_tone.startswith("รายนาม"))

# %%
not_list = []

for title in raay:
    
    if is_list_article(title):
        continue
    
    not_list.append(title)
    
len(not_list)
# Out:
# 55

# %%
#check
get_samples(not_list, 50)
# Out:
# ['รายาอูงู',
#  'รายคอวิช',
#  'รายยวา',
#  'รายงานผู้ป่วย',
#  'รายงานอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายงานเรื่องอาหารโภชนาการกิจกรรมทางกายและการป้องกันมะเร็ง',
#  'รายาแห่งรัฐปะลิส',
#  'รายากูนิง',
#  'รายาแห่งซาราวะก์',
#  'รายาห์',
#  'รายงานประจำปี',
#  'รายานนท์',
#  'รายงานเฮิร์ช',
#  'รายได้พื้นฐานถ้วนหน้าในประเทศบราซิล',
#  'รายนานนท์',
#  'รายงานพิเศษว่าด้วยภาวะโลกร้อน',
#  'รายงานกรุงบูดาเปสต์เรื่องการประกันความมั่นคง',
#  'รายได้พื้นฐาน',
#  'รายงานเค้ส',
#  'รายงานคนไข้',
#  'รายกอวิช',
#  'รายตา',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพสมเด็จเจ้าฟ้าฯกรมหลวงนราธิวาสราชนครินทร์',
#  'รายวนปูเลาเกอราปา',
#  'รายงานเคส',
#  'รายงานทีหลัง',
#  'รายาประไหมสุหรีอากง',
#  'รายวน',
#  'ราย',
#  'รายาบีรู',
#  'รายหัว',
#  'รายงานกรณี',
#  'รายละเอียดพระราชพิธีพระราชทานเพลิงพระศพ',
#  'รายาแห่งซาราวัก',
#  'รายงานเรื่องอาหารโภชนาการการออกกำลังกายและการป้องกันมะเร็ง',
#  'รายากับมังกรตัวสุดท้าย',
#  'รายงานค่าใช้จ่าย',
#  'รายงานความสุขโลก',
#  'รายวนปูเลาเกอลาปา',
#  'รายได้',
#  'รายาประไหมสุหรีอากงตวนกูฮัจญะห์ฮามินะห์ฮาไมดุน',
#  'รายปุระ',
#  'รายงานการประชุม',
#  'รายา',
#  'รายละเอียดพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#  'รายชิ่อสนามกีฬาเรียงตามความจุ',
#  'รายาฮีเจา',
#  'รายูวันปูเลาเกอลาปา',
#  'รายงานเรื่องอาหาร',
#  'รายาผิวขาว']

# %%
# exclude from the main list
titles_temp = set()
for title in titles:
    if not is_list_article(title):
        titles_temp.add(title)
        
titles = titles_temp
get_len(titles)
# Out:
# current: 300497
# diff: -4566

# %%
get_samples(titles)
# Out:
# ['ไมซ์',
#  'สรพงศ์ชาตรี',
#  'สมเด็จพระราชินีแคทเธอรีน',
#  'พระมหาเทวีจิระประภา',
#  'รถไฟฟ้าคุนหมิงสาย',
#  'ลิมบานออัสเตรอ',
#  'มาลีเอตัวตานุมาฟิลิที่',
#  'วงออร์เคสตร้า',
#  'ศิษย์ไตรภูมิ',
#  'ไม่รักดี',
#  'อเลสซานดร้าแอมโบรซิโอ้',
#  'เรือบรรทุกเครื่องบินโซริว',
#  'การแบ่งประเภทวัตถุโดยใช้คุณสมบัติเชิงแม่เหล็ก',
#  'ธงนิศานสาหิบ',
#  'เวอร์ชวลริแอลลิที',
#  'มิซาโกะ',
#  'จักรพรรดิลูกิอุส',
#  'อาเกจิมิตสึฮิเดะ',
#  'ต้นตาลตัวผู้',
#  'อี่พ่อครัวตัวจี๊ดหัวใจคับโลก',
#  'เชอวาลีเยเดอโบเรอการ์',
#  'ซีเมาซาบรอซา',
#  'ถนนนครไชยศรี',
#  'ฟาโรห์เทพแห่งโลก',
#  'แซมโชติบัณฑ์',
#  'ยุทธการที่อะกาบา',
#  'สยามฟิวเจอร์ดีเวลอปเมนท์',
#  'คณะกรรมการโอลิมปิกดัตช์',
#  '้',
#  'วัดเลาเต่า',
#  'พายุโคอินุ',
#  'คณพันธ์',
#  'ของโมเดอร์นา',
#  'ทสึมิเระ',
#  'ปกฺากะญอ',
#  'รอยประสาน',
#  'พรรคซาบาห์ก้าวหน้า',
#  'จางเจี่ยนจือ',
#  'เมืองฮะบิกิโนะ',
#  'เพลงภัทรวีศรีสันติสุข',
#  'เกล็นน์โคลส',
#  'มาทิลดาแห่งบริเตนใหญ่',
#  'ยูนูซ',
#  'มักซ์เวล',
#  'ฮูบาสแตง',
#  'ทางรถไฟสายแม่กลอง',
#  'พิกซาร์',
#  'เพลงชาติบอสเนียและเฮอร์เซโกวีนา',
#  'โวลฟรัทส์เฮาเซิน',
#  'เอเลนอร์แห่งออสเตรียสมเด็จพระราชินีแห่งโปรตุเกส',
#  'โซกำโคย',
#  'พระนางติโลกจุฑาเทวี',
#  'กานาพรีเมียร์ลีก',
#  'ท่าอากาศยานแม่สะเรียง',
#  'โมนา',
#  'เอ็มเอฟเค',
#  'วัดราชบัลลังก์ประดิษฐาราม',
#  'ยิงธนูชิงแชมป์โลก',
#  'พิพิธภัณฑ์บริติช',
#  'เขาไท่',
#  'หมีดำเอเชีย',
#  'วาเลนตินามัตวิเยนโก',
#  'แฮร์ฟุต',
#  'ฟูริงานะ',
#  'พระเจ้าบรมวงศ์เธอพระองค์เจ้าโตกรมหลวงมหิศวรินทรามเรศร์',
#  'จักรพรรดิเว่ยหมิงตี้',
#  'ประเทศรัสเซียในโอลิมปิกเยาวชนฤดูร้อน',
#  'นกกระตั้วดำหางขาว',
#  'เดดเมานท์เดธเพลย์',
#  'จิกะบิตต่อวินาที',
#  'พัททริคซึสคินท์',
#  'ลูโดวีกาแห่งออสเตรีย',
#  'บริเวณห้าแยกปากเกร็ด',
#  'แขวงชัง',
#  'ไวรัสเวสต์ไนล์',
#  'ธงขบวนการปฏิวัติอาหรับ',
#  'บริษัทอินเดียตะวันออกของเนเธอร์แลนด์',
#  'ชัยเดชนารายณ์มหาราช',
#  'จอช',
#  'มุนิน',
#  'วอลเลย์บอลหญิงทีมชาติจอร์แดน',
#  'วอลเลย์บอลยุวชนหญิงอายุไม่เกิน',
#  'วันเดอร์ฟูล',
#  'กาลีดู',
#  'เสนาหอย',
#  'โทลเลน',
#  'บานประตูวิหารวัดพระฝาง',
#  'สำลี',
#  'สหวิช',
#  'อจักส์',
#  'ไฟเตอร์ส',
#  'วงศ์เอลิฟานติดี',
#  'ไตตัสบรัมเบิล',
#  'ทะกะชิอินะกะชิ',
#  'มณฑลสงวนเสริมศรี',
#  'เขาสมอคอน',
#  'ซ็อนโบรัม',
#  'มหาวิหารนักบุญไอแซค',
#  'ไลกา',
#  'พระวรวงศ์เธอพระองค์เจ้าปิยบุตร']

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal ranks and titles
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Handle ใน
# Many non-named entity titles uses "ใน"

# %%
nai = [titles for titles in titles if "ใน" in titles]
len(nai)
# Out:
# 7089

# %%
[nai][:50]
# Out:
# [['ในประเทศอิหร่าน',
#   'เหตุระเบิดในไนจีเรีย',
#   'วัตถุขนาดเล็กในระบบสุริยะ',
#   'หนังกำลังภายใน',
#   'ขบวนการหน้ากากกายฟอคส์ในประเทศไทย',
#   'เหตุแผ่นดินถล่มในแยร์ดรึม',
#   'กีฬาฮ็อคกี้น้ำแข็งในโอลิมปิก',
#   'นักฟุตบอลเกิดใน',
#   'ตัวละครในเรื่องเซนต์เซย่า',
#   'ปราชญ์หนึ่งในใต้หล้ากับตราสุดอัปยศ',
#   'ประเทศนอร์เวย์ในโอลิมปิก',
#   'ภาษาที่ใช้ในประเทศไทย',
#   'กีฬาว่ายน้ำในกีฬาคนพิการแห่งชาติ',
#   'สาธารณรัฐเติร์กเมนิสถานในโอลิมปิกฤดูร้อน',
#   'ผู้กล่าวคำปฏิญาณตนในพิธีเปิดกีฬาโอลิมปิก',
#   'ศาสนาพุทธในประเทศจีน',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศปาปัวนิวกินี',
#   'กีฬากาบัดดีในเอเชียนเกมส์',
#   'การจัดการของเสียในประเทศไทย',
#   'ประเทศอาร์มีเนียในโอลิมปิกเยาวชน',
#   'กีฬายิมนาสติกในซีเกมส์',
#   'ฝ่ายค้านในสภาผู้แทนราษฎร',
#   'การขนส่งระบบรางในประเทศญี่ปุ่น',
#   'ยูเชนีในบาวาเรีย',
#   'ข้ออักเสบรูมาตอยด์ในเด็ก',
#   'กีฬาซอฟต์เทนนิสในกีฬาแห่งชาติ',
#   'ธงชาติในทวีปอเมริกาใต้',
#   'ประเทศมองโกเลียในพาราลิมปิกฤดูร้อน',
#   'การเรียกร้องให้บัญญัติพุทธศาสนาเป็นศาสนาประจำชาติในรัฐธรรมนูญแห่งราชอาณาจักรไทย',
#   'การเพาะเลี้ยงพืชและสัตว์ในน้ำ',
#   'เรือพายในเอเชียนเกมส์',
#   'ประเทศเคนยาในโอลิมปิกฤดูร้อน',
#   'สถาบันเทคโนโลยีแห่งสหพันธ์สวิสในซือริช',
#   'ปรากฏการณ์เกิดในตา',
#   'เข็มราชการในพระองค์',
#   'หมากรุกจีนในเอเชียนเกมส์',
#   'กีฬากระโดดน้ำในซีเกมส์',
#   'การอดอาหารประท้วงในประเทศไอร์แลนด์',
#   'ยศทหารในกองทัพสวีเดน',
#   'ประเทศกินีบิสเซาในโอลิมปิกเยาวชนฤดูร้อน',
#   'แผ่นดินไหวในลิสบอน',
#   'ความไม่สงบในประเทศฝรั่งเศสพฤษภาคมค',
#   'การศึกษาในประเทศอินเดีย',
#   'อัลบั้มประจำตัวละครในฮายาเตะพ่อบ้านประจัญบาน',
#   'ตัวละครในซีรีส์อาร์คเดอะแลด',
#   'เจ้าจอมมารดาทับทิมในรัชกาลที่',
#   'การเลือกตั้งในประเทศเยอรมนี',
#   'กีฬาปีนหน้าผาในกีฬาแห่งชาติครั้งที่',
#   'ยางพาราในประเทศไทย',
#   'ธงในประเทศอินเดีย',
#   'ทีมผสมในโอลิมปิกเยาวชนฤดูร้อน',
#   'ราชอาณาจักรฮัชไมต์จอร์แดนในเอเชียนเกมส์',
#   'กระทรวงในประเทศพม่า',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศเม็กซิโก',
#   'ตัวละครในทูเลอว์รู',
#   'ชาวไทยในโมซัมบิก',
#   'ภารกิจผจญภัยในอวกาศของครูวดรากอน',
#   'ศาสนาอิสลามในประเทศอังกฤษ',
#   'ราชอาณาจักรภูฏานในโอลิมปิกฤดูร้อน',
#   'ความขัดแย้งในประเทศซูดาน',
#   'ราชรัฐลักเซมเบิร์กในโอลิมปิกฤดูหนาว',
#   'เหตุเพลิงไหม้โรงพยาบาลในปียาตราเนอัมตส์',
#   'สาธารณรัฐทาจิกิสถานในโอลิมปิกฤดูหนาว',
#   'หวังในธรรม',
#   'เจ้าจอมหม่อมราชวงศ์แป้มในรัชกาลที่',
#   'ประเทศกาบองในโอลิมปิกเยาวชนฤดูร้อน',
#   'เหตุกราดยิงสปาในแอตแลนตา',
#   'พระราชนิพนธ์ในพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราช',
#   'กีฬาฮอกกี้น้ำแข็งในซีเกมส์',
#   'การลงประชามติในประเทศสวิตเซอร์แลนด์ค',
#   'พระราชธิดาในทุตโมสที่สาม',
#   'ธงต่างๆในประเทศสหราชอาณาจักร',
#   'การระบาดทั่วของไวรัสโคโรนาในประเทศบังกลาเทศ',
#   'อาชญากรรมในประเทศลาว',
#   'ธงในประเทศนอร์เวย์',
#   'ศาสนาอิสลามในประเทศเช็กเกีย',
#   'วิกฤติเศรษฐกิจในอาร์เจนตินา',
#   'ธงในประเทศโคลอมเบีย',
#   'สาธารณรัฐโมซัมบิกในโอลิมปิกฤดูร้อน',
#   'คัมภีร์ในสารบบ',
#   'หนึ่งในทรวง',
#   'สตรอเบอรี่ชอร์ตเค้กผจญภัยในเบอร์รี่บิตตี้แลนด์',
#   'พระผู้สร้างในศาสนาพุทธ',
#   'การก่อกำเริบในหุบเขาเพรเชวอ',
#   'เหตุระเบิดในโรงพยาบาลอัลอะฮ์ลีอัลอะเราะบี',
#   'ประเทศไทยในซีเกมส์',
#   'ประเทศสิงคโปร์ในซีเกมส์',
#   'โรงเรียนสายปัญญาในพระบรมราชินูปถัมภ์',
#   'ประเทศอาเซอร์ไบจานในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬาเรือยาวมังกรในเอเชียนเกมส์',
#   'ในประเทศมาเลเซีย',
#   'บอร์เนียวเหนือในโอลิมปิกฤดูร้อน',
#   'ประเทศบราซิลในโอลิมปิกเยาวชนฤดูหนาว',
#   'ผู้อ้างสิทธิ์ในราชบัลลังก์',
#   'สาธารณรัฐเคนยาในโอลิมปิกฤดูร้อน',
#   'ประเทศบาฮามาสในโอลิมปิก',
#   'กีฬาสเกเลตันในโอลิมปิกเยาวชนฤดูหนาว',
#   'รัฐประหารในฟีจี',
#   'พรรณไม้ในวรรณคดี',
#   'การเลือกตั้งในสหรัฐอเมริกา',
#   'ประเทศฮังการีในโอลิมปิกเยาวชน',
#   'ประเทศลิเบียในโอลิมปิกเยาวชนฤดูร้อน',
#   'สาธารณรัฐซานมารีโนในโอลิมปิกฤดูหนาว',
#   'ประเทศกาตาร์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'ภาษีอากรในประเทศออสเตรเลีย',
#   'ประเทศเซเนกัลในพาราลิมปิกฤดูร้อน',
#   'กล้องจุลทรรศน์แบบส่องกราดในอุโมงค์',
#   'บริการสุขภาพในประเทศไทย',
#   'กีฬาแฮนด์บอลชายหาดในเอเชียนบีชเกมส์',
#   'ประเทศเซนต์ลูเชียในโอลิมปิก',
#   'ประเทศกานาในโอลิมปิก',
#   'เหตุยิงกันในสทราซบูร์',
#   'ประเทศสวีเดนในโอลิมปิกซ้อน',
#   'มันผิดรึไงถ้าใจอยากจะพบรักในดันเจี้ยน',
#   'มรดกโลกในประเทศทาจิกิสถาน',
#   'ประเทศโมซัมบิกในโอลิมปิกฤดูร้อน',
#   'เจ้าหญิงโนะบุโกะพระวรชายาในเจ้าชายโทะโมะฮิโตะ',
#   'การหลั่งใน',
#   'ข้อมูลอุปกรณ์และความหมายในเรื่องอีวานเกเลียน',
#   'ไทยในสวีเดน',
#   'ประเทศออสเตรียในโอลิมปิกฤดูหนาว',
#   'กลยุทธ์ในสามก๊ก',
#   'ประเทศนิวฟันด์แลนด์ในเครือจักรภพ',
#   'อิรุมะคุงผจญในแดนปีศาจ',
#   'ประเทศโครเอเชียในโอลิมปิกเยาวชนฤดูหนาว',
#   'พายุหิมะในประเทศอิหร่าน',
#   'สถาปัตยกรรมใน',
#   'ฟุตบอลในประเทศบอสเนียและเฮอร์เซโกวีนา',
#   'ศาสนาอิสลามในประเทศญี่ปุ่น',
#   'อำเภอในประเทศอินเดีย',
#   'การประท้วงในอียิปต์',
#   'กีฬานำทางในเวิลด์เกมส์',
#   'มณฑลในประวัติศาสตร์ของอังกฤษ',
#   'เจ้าจอมมารดาปรางใหญ่ในรัชกาลที่',
#   'ธงพระอิสริยยศในประเทศอิหร่าน',
#   'พระราชโอรสในสมเด็จพระไชยราชาธิราช',
#   'ศาสนาพุทธในประเทศไทย',
#   'ธงในประเทศนิวซีแลนด์',
#   'ธรรมเนียมพระยศและบรรดาศักดิ์ในราชวงศ์โชซ็อน',
#   'พระราชพิธีบรมราชาภิเษกในรัชกาลที่',
#   'สูญหายในการรบ',
#   'ประเทศอาร์มีเนียในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศอิรักในโอลิมปิกฤดูร้อน',
#   'กีฬาบริดจ์ในกีฬาแห่งชาติครั้งที่',
#   'สาธารณรัฐแอฟริกาใต้ในโอลิมปิก',
#   'ประเทศซาอุดีอาระเบียในโอลิมปิกเยาวชนฤดูร้อน',
#   'สาธารณรัฐประชาชนบังกลาเทศในโอลิมปิก',
#   'ประวัติศาสตร์ของมวยปล้ำอาชีพในสหรัฐ',
#   'แผ่นดินไหวในจูเอ็ทสึ',
#   'ทางไหลเวียนเลือดยังคงอยู่แบบทารกในครรภ์',
#   'ประเทศเฮติในพาราลิมปิกฤดูร้อน',
#   'เจ้าจอมมารดานุ้ยเล็กในสมเด็จพระบวรราชเจ้ามหาสุรสิงหนาท',
#   'จีนไทเปในเอเชียนเกมส์',
#   'ประเทศอินโดนีเซียในโอลิมปิกเยาวชนฤดูร้อน',
#   'อารูบาในโอลิมปิกเยาวชนฤดูร้อน',
#   'ตัวละครในเรื่องดราก้อนบอลแซด',
#   'ชุมชนในเบลเยียม',
#   'กีฬาวีลแชร์เทนนิสในกีฬาคนพิการแห่งชาติครั้งที่',
#   'แผ่นดินไหวในประเทศตุรกีและประเทศซีเรีย',
#   'กีฬาสกีลีลาในเอเชียนเกมส์ฤดูหนาว',
#   'พระนิพนธ์ในสมเด็จพระเจ้าพี่นางเธอเจ้าฟ้ากัลยาณิวัฒนากรมหลวงนราธิวาสราชนครินทร์',
#   'ประเทศซามัวในโอลิมปิก',
#   'ประเทศมอริเชียสในพาราลิมปิกฤดูร้อน',
#   'กีฬาเพาะกายในซีเกมส์',
#   'ประเทศอันดอร์ราในพาราลิมปิกฤดูร้อน',
#   'สาธารณรัฐมาลาวีในโอลิมปิก',
#   'รักร่วมเพศในประเทศไทย',
#   'ธงในประเทศเดนมาร์ก',
#   'กีฬามวยปล้ำในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐประชาชนจีนในเอเชียนบีชเกมส์',
#   'เทเบิลเทนนิสในซีเกมส์',
#   'ประเทศฝรั่งเศสในพาราลิมปิกฤดูหนาว',
#   'สโมสรฟุตบอลชัยนาทฮอร์นบิลในฤดูกาล',
#   'กีฬาสเกตความเร็วถนนในเวิลด์เกมส์',
#   'ประเทศตูนิเซียในพาราลิมปิกฤดูร้อน',
#   'กีฬาอีสปอร์ตในกีฬาแห่งชาติ',
#   'ยศทหารในกองทัพฝรั่งเศส',
#   'กีฬากรีฑาในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศนิวซีแลนด์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'ธงชาติในทวีปเอเชีย',
#   'สหภาพรัฐเซอร์เบียและมอนเตเนโกรในโอลิมปิก',
#   'ผู้เล่นในฟุตบอลชิงถ้วยพระราชทานคิงส์คัพ',
#   'ประเทศแอลเบเนียในโอลิมปิกเยาวชน',
#   'ประเทศจอร์เจียในพาราลิมปิกฤดูร้อน',
#   'กีฬากระโดดน้ำในโอลิมปิก',
#   'คอเลสเตอรอลในเลือดที่ไม่ดี',
#   'แผ่นดินไหวในคาบสมุทรโนโตะค',
#   'ประเทศเปรูในโอลิมปิกฤดูร้อน',
#   'ประเทศเขตร้อนในโอลิมปิกฤดูหนาว',
#   'กีฬาบาสเกตบอลหญิงในโอลิมปิกฤดูร้อน',
#   'การระบาดทั่วของไวรัสโคโรนาในทำเนียบขาว',
#   'กีฬาฟุตบอลชายในโอลิมปิกฤดูร้อน',
#   'ชาวจีนในเคนยา',
#   'การเจริญของประสาทในมนุษย์',
#   'ไฟช่วยในการปรับโฟกัสโดยอัตโนมัติ',
#   'ประเทศนามิเบียในโอลิมปิกฤดูร้อน',
#   'การเลือกตั้งทั่วไปในประเทศอินเดีย',
#   'การระบาดทั่วของโคโรนาไวรัสในสหรัฐ',
#   'ยศทหารในกองทัพนิวซีแลนด์',
#   'เหตุการณ์วางระเบิดรถไฟฟ้าใต้ดินในกรุงมินสก์',
#   'เยื่อหุ้มสมองชั้นใน',
#   'มหาวิหารในสหราชอาณาจักร',
#   'กำลังภายใน',
#   'กฎหมายเกี่ยวกับต้นไม้ใหญ่ในเมืองในประเทศไทย',
#   'สาธารณรัฐแอฟริกากลางในโอลิมปิก',
#   'ประเทศเลบานอนในเอเชียนเกมส์ฤดูหนาว',
#   'เจ้าหญิงเซะสึโกะพระวรชายาในเจ้าชายยะซุฮิโตะ',
#   'โรงพยาบาลในประเทศไทย',
#   'ประเทศเซนต์วินเซนต์และเกรนาดีนส์ในพาราลิมปิกฤดูร้อน',
#   'ภาพยนตร์ที่ออกฉายในปี',
#   'ประเทศบาห์เรนในพาราลิมปิกฤดูร้อน',
#   'การถ่ายทอดยีนในแนวราบ',
#   'บุคคลที่ทรงอิทธิพลที่สุดในโลก',
#   'ภาวะพิษเหตุติดเชื้อในทารกแรกเกิด',
#   'นิกายในศาสนาฮินดู',
#   'ประเทศสโลวีเนียในพาราลิมปิกฤดูร้อน',
#   'สนามกีฬาในร่มออซอดี',
#   'ศาสตราจารย์ในสหรัฐอเมริกา',
#   'อุทยานแห่งชาติที่ใหญ่ที่สุดในโลก',
#   'ตารางเวลาในแฮร์รี่พอตเตอร์',
#   'เหตุโจมตีทางอากาศใส่โรงละครในมารีอูปอล',
#   'หมู่เกาะเคย์แมนในโอลิมปิกฤดูร้อน',
#   'ประเทศสวีเดนในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศลาวในโอลิมปิก',
#   'ชาวไทยในติมอร์',
#   'สถานีโทรทัศน์ภาคพื้นดินในประเทศไทย',
#   'ในสมเด็จพระราชินีนาถเอลิซาเบธที่',
#   'เจ้าจอมเนื่องในรัชกาลที่',
#   'ธงในประเทศฟินแลนด์',
#   'โนอาห์ในทัศนะของศาสนาอิสลาม',
#   'นักกีฬาโอลิมปิกจากประเทศรัสเซียในโอลิมปิก',
#   'สหพันธ์สาธารณรัฐอิรักในโอลิมปิก',
#   'การเดินป่าในเพชรพระอุมา',
#   'ประเทศชิลีในโอลิมปิกเยาวชนฤดูหนาว',
#   'สนามกีฬาอเนกประสงค์ในร่มแขวงโอตะ',
#   'ประเทศตูนิเซียในโอลิมปิก',
#   'กรีฑาในซีเกมส์',
#   'กีฬาแฮนด์บอลในโอลิมปิก',
#   'การเลือกตั้งในสหรัฐค',
#   'กีฬายิงปืนในเอเชียนเกมส์',
#   'เหตุโจมตีด้วยขีปนาวุธในแซร์ฮียิวกา',
#   'การก่อการกำเริบในเบอร์ลินตะวันออก',
#   'สงกรานต์ในประเทศไทย',
#   'กีฬาฟุตบอลหญิงในโอลิมปิกฤดูร้อน',
#   'ประเทศนอร์ทมาซิโดเนียในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬาสเกตบอร์ดในโอลิมปิกฤดูร้อน',
#   'นางในใจกล้า',
#   'ประเทศอิตาลีในโอลิมปิกเยาวชนฤดูหนาว',
#   'สุขอนามัยในการนอนหลับ',
#   'ดินแดนอเมริกันซามัวในโอลิมปิก',
#   'สาธารณรัฐเช็กในพาราลิมปิกฤดูหนาว',
#   'ประเทศนอร์ทมาซิโดเนียในโอลิมปิก',
#   'วัดบางคนทีใน',
#   'ยศข้าราชการพลเรือนในราชสำนัก',
#   'กีฬาวอลเลย์บอลในกีฬาแห่งชาติครั้งที่',
#   'อุทยานเฉลิมพระเกียรติในหลวงรัชกาลที่เก้า',
#   'เวลาในประเทศชิลี',
#   'เขตบริหารพิเศษฮ่องกงในพาราลิมปิกฤดูร้อน',
#   'ฮ่องกงในเอเชียนบีชเกมส์',
#   'ประเทศฝรั่งเศสในโอลิมปิกฤดูร้อน',
#   'การเจริญของเอ็มบริโอในสัตว์',
#   'นครราชสีมาในกีฬาแห่งชาติครั้งที่',
#   'สาธารณรัฐอาหรับเยเมนในโอลิมปิกฤดูร้อน',
#   'เพลงรักในสายลมหนาว',
#   'เจ้าจอมมารดาแสในรัชกาลที่',
#   'ในศาสนาพุทธ',
#   'การเลือกตั้งในกัมพูชา',
#   'ประเทศเปรูในโอลิมปิกเยาวชนฤดูร้อน',
#   'วัดบางซ้ายใน',
#   'มวยในซีเกมส์',
#   'สโมสรฟุตบอลอยุธยายูไนเต็ดในฤดูกาล',
#   'ฟุตบอลในเอเชียนเกมส์',
#   'จังหวัดพัทลุงในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'ธงเยาวราชฝ่ายใน',
#   'ความเอนเอียงในการตีพิมพ์',
#   'ประเทศปาปัวนิวกีนีในโอลิมปิกเยาวชนฤดูร้อน',
#   'ราชรัฐในจักรวรรดิโรมันอันศักดิ์สิทธิ์',
#   'ธงในประเทศเคนยา',
#   'สาธารณรัฐฟิลิปปินส์ในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐประชาธิปไตยเซาตูเมและปรินซีปีในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศเอริเทรียในโอลิมปิกเยาวชนฤดูร้อน',
#   'มรดกโลกในประเทศอินเดีย',
#   'ประเทศอียิปต์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'การเลือกตั้งสมาชิกสภาผู้แทนราษฎรสหรัฐในรัฐเดลาแวร์ค',
#   'ประเทศเช็กเกียในพาราลิมปิกฤดูร้อน',
#   'จังหวัดเลยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'ประเทศภูฏานในโอลิมปิก',
#   'ประเทศเอธิโอเปียในโอลิมปิก',
#   'ราชสกุลวงศ์ในรัชกาลปัจจุบัน',
#   'ประเทศกรีเนดาในโอลิมปิก',
#   'ซาลามานเดอร์ในตำนาน',
#   'ประเทศไซปรัสในโอลิมปิกเยาวชนฤดูหนาว',
#   'เขียนในใจร้องในเพลง',
#   'การตรวจเลือดแฝงในอุจจาระ',
#   'ในห้อง',
#   'รัฐบัญญัติห้ามปกปิดใบหน้าในสาธารณสถาน',
#   'ประเทศเบลเยียมในพาราลิมปิกฤดูร้อน',
#   'ดาราศาสตร์ในปีค',
#   'อาณาจักรในอาร์ดา',
#   'ธงในประเทศแอลเบเนีย',
#   'ประเทศอุซเบกิสถานในพาราลิมปิกฤดูร้อน',
#   'การหมิ่นประมาทในประเทศไทย',
#   'เหตุระเบิดโรงแรมในไบรตัน',
#   'สโมสรฟุตบอลทอตนัมฮอตสเปอร์ในฤดูกาล',
#   'ความดันเลือดในปอดสูง',
#   'รถไฟชานเมืองในประเทศอินเดีย',
#   'กีฬากอล์ฟในโอลิมปิกเยาวชนฤดูร้อน',
#   'วอลเลย์บอลชายในเอเชียนเกมส์',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศมองโกเลีย',
#   'ธงในประเทศโครเอเชีย',
#   'โคลนถล่มในมณฑลกานซู',
#   'ศูนย์ประชุมเฉลิมพระเกียรติในโอกาสฉลองพระชนมายุ',
#   'ลำดับเวลาของจังหวัดในประเทศไทย',
#   'สภาตึกสูงและที่อยู่อาศัยในเมือง',
#   'ฟุตบอลทีมชาติบริเตนใหญ่และไอร์แลนด์เหนือในโอลิมปิก',
#   'สหสาธารณรัฐอาหรับในโอลิมปิก',
#   'ประเทศญี่ปุ่นในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬากีฬาทางอากาศในกีฬาแห่งชาติ',
#   'สโมสรฟุตบอลแอร์ฟอร์ซเซ็นทรัลในฤดูกาล',
#   'การทิ้งระเบิดที่เดรสเดินในสงครามโลกครั้งที่สอง',
#   'ประเทศเอสโตเนียในโอลิมปิกฤดูร้อน',
#   'ดินแดนกวมของสหรัฐอเมริกาในโอลิมปิกฤดูหนาว',
#   'วอลเลย์บอลหญิงในโอลิมปิกรอบคัดเลือกระดับโลกและโซนเอเชีย',
#   'กีฬาสกีลงเขาในเอเชียนเกมส์ฤดูหนาว',
#   'สาธารณสุขในประเทศเวียดนาม',
#   'สื่อในประเทศอิหร่าน',
#   'ในรัชกาลที่',
#   'ในประเทศอังกฤษ',
#   'ประเทศไทยในกีฬามหาวิทยาลัยโลก',
#   'ประเทศไทยในสงครามเวียดนาม',
#   'ประเทศฮังการีในพาราลิมปิกฤดูร้อน',
#   'โบรุสเซียดอร์ทมุนด์ในฤดูกาล',
#   'สาธารณรัฐทาจิกิสถานในเอเชียนเกมส์',
#   'สถาปัตยกรรมการก่อสร้างมหาวิหารในอังกฤษในยุคกลาง',
#   'เจ้าจอมมารดาทิพเกษรในรัชกาลที่',
#   'ลัทธิจักรวรรดินิยมในเอเชีย',
#   'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน',
#   'เพื่อนแท้ในป่าใหญ่',
#   'การประท้วงในอินโดนีเซีย',
#   'กีฬาเนตบอลในกีฬาแห่งชาติครั้งที่',
#   'สโมสรฟุตบอลนิวคาสเซิลยูไนเต็ดในฤดูกาล',
#   'สโมสรฟุตบอลนครราชสีมาห้วยแถลงยูไนเต็ดในฤดูกาล',
#   'ความเอนเอียงโดยการมองในแง่ร้าย',
#   'เหตุโจมตีด้วยขีปนาวุธในอูมัญ',
#   'ตัวละครในทีมเดมอนเดวิลแบ๊ทส์',
#   'การเลือดออกในกระเพาะอาหารและลำไส้',
#   'กีฬาโปโลน้ำในโอลิมปิก',
#   'กีฬาว่ายน้ำในโอลิมปิกเยาวชน',
#   'ประเทศเซอร์เบียในโอลิมปิกฤดูร้อน',
#   'การยุติการออกอากาศโทรทัศน์แอนะล็อกในสหรัฐอเมริกา',
#   'ตัวละครในซากุระมือปราบไพ่ทาโรต์',
#   'แคว้นในซาอุดีอาระเบีย',
#   'การยุติการออกอากาศโทรทัศน์ระบบแอนะล็อกในสหรัฐ',
#   'ประเทศเบลเยียมในพาราลิมปิกฤดูหนาว',
#   'องค์การบริหารชั่วคราวแห่งสหประชาชาติในกัมพูชา',
#   'ในใจของคุโนอิจิสึบากิ',
#   'สาธารณรัฐคอสตาริกาในโอลิมปิกฤดูร้อน',
#   'การตรวจพิจารณาในสหภาพโซเวียต',
#   'เจ้าหลวงน้อยใน',
#   'กีฬาโปโลน้ำในกีฬาทางน้ำชิงแชมป์โลก',
#   'ประเทศอุซเบกิสถานในโอลิมปิก',
#   'กีฬาฟุตบอลในโอลิมปิกเยาวชนฤดูร้อน',
#   'พุทธศาสนาในซินเจียงอุยกูร์และเอเชียกลาง',
#   'ประเทศเกรเนดาในพาราลิมปิกฤดูร้อน',
#   'กีฬายกน้ำหนักในโอลิมปิกซ้อน',
#   'ปฏิกิริยาต่อการประท้วงในประเทศไทย',
#   'เจ้าจอมมารดาเรือนในรัชกาลที่',
#   'ที่ตั้งของโลกในเอกภพ',
#   'หมายเลขโทรศัพท์ในประเทศตองกา',
#   'ฮ่องกงในเอเชียนเกมส์ฤดูหนาว',
#   'ประเทศซูดานในโอลิมปิกฤดูร้อน',
#   'โครงการสนับสนุนการจัดตั้งห้องเรียนวิทยาศาสตร์ในโรงเรียนโดยการกำกับดูแลของมหาวิทยาลัย',
#   'สาธารณรัฐโรดีเชียในโอลิมปิกฤดูร้อน',
#   'กีฬาซอฟต์เทนนิสในกีฬาแห่งชาติครั้งที่',
#   'ตัวนำยวดยิ่งในสารประกอบ',
#   'เรือใบในเอเชียนเกมส์',
#   'ประเทศเยอรมนีในพาราลิมปิกฤดูร้อน',
#   'ประเทศรัสเซียในโอลิมปิก',
#   'อำเภอเขื่องใน',
#   'และพ่อในบางครั้งคราว',
#   'ในทวีปยุโรป',
#   'ประเทศสวีเดนในโอลิมปิกฤดูหนาว',
#   'กีฬาระบำใต้น้ำในซีเกมส์',
#   'การล่าอาณานิคมในแอฟริกา',
#   'ประเทศยูกันดาในโอลิมปิก',
#   'เหตุเหยียบกันเสียชีวิตในโซล',
#   'พระราชพิธีราชาภิเษกสมรสในพระบาทสมเด็จพระปรมินทรมหาภูมิพลอดุลยเดช',
#   'การระบาดของไวรัสซิกาในทวีปอเมริกา',
#   'นักกีฬาโอลิมปิกอิสระในโอลิมปิก',
#   'ความฝันในหอแดง',
#   'คนในอากาศ',
#   'การกรองตัวเลขในขอบเขตแบบธรรมดา',
#   'โรแบร์โตในวัยหนุ่ม',
#   'ประเทศอิสราเอลในโอลิมปิกเยาวชนฤดูหนาว',
#   'วงศ์ปลาเหล็กใน',
#   'การต่อต้านอังกฤษในพม่า',
#   'จังหวัดภาคใต้เรียงตามผลิตภัณฑ์มวลรวมภายในจังหวัด',
#   'ปราสาทหินวัดพูและสิ่งก่อสร้างใกล้เคียงในแขวงจำปาสัก',
#   'ยศข้าราชการพลเรือนในราชสำนักในอดีต',
#   'ดาบจันทร์ในบ่อ',
#   'ตัวละครที่ปรากฎใน',
#   'ขอแค่เป็นเทพในเงา',
#   'เหตุโจมตีในลีแอจ',
#   'กษัตริย์ในปรัสเซีย',
#   'พิพิธภัณฑ์ความโหดร้ายป่าเถื่อนในสงครามของอเมริกาซินช็อน',
#   'กีฬาคริกเกตในโอลิมปิกฤดูร้อน',
#   'การละเมิดลิขสิทธิ์ในประเทศไทย',
#   'เหตุเพลิงไหม้เรือข้ามฟากในประเทศบังกลาเทศ',
#   'ประเทศเนเธอร์แลนด์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศปากีสถานในเอเชียนบีชเกมส์',
#   'เหตุยิงกันในโรงเรียนประถมแซนดีฮุก',
#   'เขตบริหารพิเศษมาเก๊าในเอเชียนบีชเกมส์',
#   'ประเทศกานาในเครือจักรภพ',
#   'ฝ่ายสัมพันธมิตรในสงครามโลกครั้งที่หนึ่ง',
#   'ขุดเหมืองในทะเล',
#   'เหตุระเบิดในย่างกุ้ง',
#   'กำเนิดในระบบประสาท',
#   'ศาสนาในประเทศกาตาร์',
#   'เซลล์ประสาทสองขั้วในเรตินา',
#   'ประเทศกรีเนดาในโอลิมปิกฤดูร้อน',
#   'เรือสำราญที่ใหญ่ที่สุดในโลก',
#   'ปัญหาสิ่งแวดล้อมในประเทศจีน',
#   'เหตุแผ่นดินถล่มในอาตามิ',
#   'จีนไทเปในโอลิมปิก',
#   'โลกในดวงตาข้าพเจ้า',
#   'ประเทศนามิเบียในพาราลิมปิกฤดูร้อน',
#   'กีฬาคนพิการในประเทศไทย',
#   'กางเกงในสตรี',
#   'วอลเลย์บอลหญิงในโอลิมปิกฤดูร้อน',
#   'พระเยซูผจญพายุในทะเลแกลิลี',
#   'ตัวละครในแคลนนาด',
#   'ประเทศเกาหลีใต้ในเอเชียนเกมส์ฤดูหนาว',
#   'กระดูกปลายแขนอันในอยูทางนิ้วก้อย',
#   'สถานที่ท่องเที่ยวและที่พักในจังหวัดอ่างทอง',
#   'ความอดอยากครั้งใหญ่ในไอร์แลนด์',
#   'กีฬาเปซาปัลโลในโอลิมปิกฤดูร้อน',
#   'สโมสรฟุตบอลนครราชสีมาในฤดูกาล',
#   'ประเทศซิมบับเวในพาราลิมปิกฤดูร้อน',
#   'กระทรวงในประเทศฝรั่งเศส',
#   'ประเทศจีนในเอเชียนเกมส์ฤดูหนาว',
#   'เหตุเพลิงไหม้ในบากู',
#   'ดินแดนในเรื่องพระอภัยมณี',
#   'สหภาพเมียนมาร์ในโอลิมปิกฤดูร้อน',
#   'ขี่ม้าในซีเกมส์',
#   'ประเทศเซาท์ซูดานในโอลิมปิกฤดูร้อน',
#   'ประเทศจีนในโอลิมปิกเยาวชนฤดูหนาว',
#   'ล่าขุมทรัพย์สุดขอบฟ้าในคิวบา',
#   'ประเทศเอกวาดอร์ในโอลิมปิกฤดูหนาว',
#   'กีฬาชักเย่อในโอลิมปิก',
#   'การบุกยึดท่าอากาศยานในประเทศไทย',
#   'กีฬาเปตองในกีฬาแห่งชาติ',
#   'ตัวละครในเซนต์เซย่า',
#   'ประเทศเบลเยียมในโอลิมปิกเยาวชน',
#   'สโมสรฟุตบอลสุรนารีแบล็คแคทในฤดูกาล',
#   'เวลาในประเทศอินโดนีเซีย',
#   'เลือดออกในเนื้อปอด',
#   'กีฬากอล์ฟในโอลิมปิกเยาวชน',
#   'แผ่นดินไหวและคลื่นสึนามิในโอกูชิริ',
#   'ศาสนาอิสลามในประเทศอิรัก',
#   'เหตุการณ์สำคัญในรัชสมัยสมเด็จพระเจ้ากรุงธนบุรี',
#   'ประเทศแทนซาเนียในโอลิมปิก',
#   'การฟ้องเจ้าหน้าที่ชั้นสูงในทางอาญา',
#   'เจ้าหญิงมะซะโกะพระชายาในเจ้าชายสึเนะฮิซะ',
#   'สหรัฐในโอลิมปิกฤดูหนาว',
#   'ประเทศเนปาลในเอเชียนเกมส์',
#   'สาธารณรัฐไอร์แลนด์ในโอลิมปิกฤดูหนาว',
#   'ดวงใจในมนตรา',
#   'จังหวัดหนองคายในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'ทรัพยากรธรรมชาติในประเทศไทย',
#   'ประเทศออสเตรเลียในพาราลิมปิกฤดูหนาว',
#   'พระนามทรงกรมของพระราชโอรสพระราชธิดาในรัชกาลที่',
#   'กีฬาฮอกกี้ในกีฬาแห่งชาติ',
#   'การพนันในประเทศกัมพูชา',
#   'ประเทศไซปรัสในโอลิมปิก',
#   'พระมเหสีในทุตโมสที่หนึ่ง',
#   'ปรากฏการณ์เชื่อมั่นในตัวเองเกิน',
#   'แผ่นดินไหวและคลื่นสึนามิในเซ็นได',
#   'หมู่บ้านโบราณในอานฮุยตอนใต้ซีตี้และหงชุน',
#   'ประเทศอาเซอร์ไบจานในพาราลิมปิกฤดูร้อน',
#   'การขนส่งระบบรางในประเทศไทย',
#   'ประเทศแอลเบเนียในโอลิมปิกฤดูหนาว',
#   'การประท้วงในฮ่องกง',
#   'ธรรมเนียมพระยศและบรรดาศักดิ์ในราชวงศ์โชซอล',
#   'ตำหนิในงานเชื่อม',
#   'สาธารณรัฐคองโกในโอลิมปิก',
#   'หากต้นไม้ล้มในป่า',
#   'ออสตราเลเชียในโอลิมปิก',
#   'ประเทศเซาท์ซูดานในโอลิมปิก',
#   'พระคริสต์ผจญพายุในทะเลกาลิลี',
#   'สถานเอกอัครราชทูตสหรัฐในกรุงเตหะราน',
#   'กีฬาคริกเกตในกีฬาแห่งชาติครั้งที่',
#   'กีฬาฟุตบอลในโอลิมปิกฤดูร้อน',
#   'ฆาตกรรมในวงบริดจ์',
#   'ไทยในติมอร์ตะวันออก',
#   'สาธารณรัฐเซเนกัลในโอลิมปิกฤดูร้อน',
#   'สหภาพโซเวียตในโอลิมปิกฤดูร้อน',
#   'ศาสนาในประเทศพม่า',
#   'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดจันทบุรี',
#   'คันอะไรในกุงเกง',
#   'เพราะพระเจ้าเลือกเลยได้เกิดใหม่มาเลี้ยงสไลม์ในต่างโลก',
#   'สาธารณรัฐโกตดิวัวร์ในโอลิมปิก',
#   'กีฬาเคอลิ่งในโอลิมปิก',
#   'เหตุระเบิดในเมืองซูราบายา',
#   'กีฬากอล์ฟในเอเชียนเกมส์',
#   'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชา',
#   'ประเทศคอสตาริกาในพาราลิมปิกฤดูร้อน',
#   'ประเทศคีร์กีซสถานในพาราลิมปิกฤดูร้อน',
#   'อาชญากรรมในประเทศไทย',
#   'ประเทศเซนต์ลูเชียในโอลิมปิกฤดูร้อน',
#   'ความทรงจำในการรับรู้อากัปกิริยา',
#   'พระราชธิดาในสมเด็จพระเจ้าอยู่หัวบรมโกศ',
#   'ประเทศทาจิกิสถานในพาราลิมปิกฤดูร้อน',
#   'ในประเทศเม็กซิโก',
#   'ประเทศในทวีปยุโรป',
#   'พิธีสารเลือกรับเรื่องความเกี่ยวพันของเด็กในความขัดแย้งกันด้วยอาวุธ',
#   'พระราชพิธีเฉลิมพระชนมพรรษาในรัชกาลที่',
#   'ตัวละครในครูพิเศษจอมป่วน',
#   'ประเทศไทยในเอ็กซ์โป',
#   'ธงในประเทศโคลัมเบีย',
#   'สถาบันอุดมศึกษาที่เก่าแก่ที่สุดในประเทศไทย',
#   'วัดครุใน',
#   'ประเทศอัฟกานิสถานในโอลิมปิก',
#   'สาธารณรัฐแองโกลาในโอลิมปิกฤดูร้อน',
#   'ตัวเลขในวัฒนธรรมจีน',
#   'พระราชสันตติวงศ์ในพระบาทสมเด็จพระจอมเกล้าเจ้าอยู่หัว',
#   'แผ่นดินไหวในประเทศฮอนดูรัส',
#   'จักรวาลในเรื่องเดอะ',
#   'ประเทศยูเครนในโอลิมปิกเยาวชนฤดูร้อน',
#   'สเปกตรัมในโรคอารมณ์สองขั้ว',
#   'มวยสากลสมัครเล่นในเอเชียนเกมส์',
#   'เจ้าคุณจอมมารดาแพในรัชกาลที่',
#   'ตัวละครในทูเลิฟรู',
#   'การบังคับใช้กฎหมายในประเทศเกาหลีเหนือ',
#   'วอลเลย์บอลหญิงในเอเชียนเกมส์',
#   'กระบวนทัศน์ในการพัฒนาโปรแกรม',
#   'สหรัฐในโอลิมปิกซ้อน',
#   'ประเทศฮังการีในโอลิมปิกฤดูหนาว',
#   'กรุงเทพมหานครในกีฬาแห่งชาติครั้งที่',
#   'ตัวละครในนินจาคาถาโอ้โฮเฮะ',
#   'รถยนต์พระที่นั่งในสมเด็จพระเจ้าลูกเธอเจ้าฟ้าจุฬาภรณ์วลัยลักษณอัครราชกุมารี',
#   'ของที่ระลึกเนื่องในโอกาสฉลองสิริราชสมบัติครบ๖๐ปี',
#   'กีฬาฟันดาบในซีเกมส์',
#   'หมู่เกาะเวอร์จินของสหรัฐอเมริกาในแพนอเมริกันเกมส์',
#   'สูญหายในการปฏิบัติหน้าที่',
#   'วัดบางเตยใน',
#   'ที่สุดในสามโลก',
#   'ใบอนุญาตรับชมโทรทัศน์ในสหราชอาณาจักร',
#   'การขนส่งระบบรางในประเทศออสเตรีย',
#   'ตัวละครในไฟนอลแฟนตาซี',
#   'การประท้วงในลิเบีย',
#   'กีฬาสกีลีลาในโอลิมปิกเยาวชนฤดูหนาว',
#   'หญิงในโอลิมปิกฤดูร้อน',
#   'การเปรียบเทียบยศทหารแอฟริกาใต้ในยุคการถือผิว',
#   'ประเทศปากีสถานในเอเชียนเกมส์',
#   'พระราชชายาเจ้าดารารัศมีในพระบาทสมเด็จพระจุลจอมเกล้าเจ้าอยู่หัว',
#   'กีฬาฟุตบอลในโอลิมปิกเยาวชน',
#   'รถรางในเวียนนา',
#   'ภาพยนตร์ในประเทศรัสเซีย',
#   'อันนาในบาวาเรีย',
#   'เปลือกชั้นใน',
#   'ภูมิภาคในประเทศญี่ปุ่น',
#   'หนังสือพิมพ์ในประเทศไทย',
#   'เครือรัฐเปอร์โตริโกในโอลิมปิกฤดูร้อน',
#   'การปล้นธนาคารในติฟลิส',
#   'กัญชาในประเทศไทย',
#   'การให้กำเนิดเซลล์ในระบบประสาท',
#   'ร้อนใน',
#   'ประเทศเยเมนใต้ในโอลิมปิกฤดูร้อน',
#   'กีฬาปีนหน้าผาในเวิลด์เกมส์',
#   'โครงกระดูกภายใน',
#   'ประเทศเม็กซิโกในโอลิมปิก',
#   'เซซาเรียในคาพะโดเคีย',
#   'วิกฤตการณ์การเมืองในประเทศไทย',
#   'เหตุการณ์ความไม่สงบในฟุตบอลถ้วยพระราชทานก',
#   'แผ่นดินไหวในเกาะอาวาจิค',
#   'ตำแหน่งฝ่ายใน',
#   'ประเทศเกาหลีใต้ในโอลิมปิก',
#   'การเซ็นเซอร์อินเทอร์เน็ตในประเทศจีน',
#   'เศรษฐกิจในสหภาพโซเวียต',
#   'ช่วงเวลาในมะดีนะฮ์',
#   'การรุกรานของมองโกลในฮังการี',
#   'วัดในจังหวัดอุตรดิตถ์',
#   'สาธารณรัฐซูรินาเมในโอลิมปิก',
#   'ภาษีในประเทศออสเตรเลีย',
#   'กีฬาบาสเกตบอลในกีฬาแห่งชาติ',
#   'การเลือกตั้งชุมชนในประเทศกัมพูชา',
#   'สาธารณรัฐแอฟริกาใต้ในโอลิมปิกฤดูหนาว',
#   'ตัวละครในชานะ',
#   'ประเทศกาบูเวร์ดีในพาราลิมปิกฤดูร้อน',
#   'เจ้านายพระชันษายืนในราชสกุลรัชกาลที่',
#   'ประเทศเซาตูแมอีปริงซีปในพาราลิมปิกฤดูร้อน',
#   'ประชากรในประเทศกัมพูชา',
#   'กลุ่มภายในและกลุ่มภายนอก',
#   'ประเทศเบลเยียมในโอลิมปิกฤดูหนาว',
#   'การประท้วงต่อต้านรัฐบาลในพม่า',
#   'ในประเทศยูเครน',
#   'วัดบางขุนเทียนใน',
#   'การพนันในประเทศไทย',
#   'ปัญหาความไม่สงบใน',
#   'เหตุโจมตีในบาร์เซโลนา',
#   'อาจารย์และบุคลากรในฮอกวอตส์',
#   'แผ่นดินไหวในประเทศเฮติ',
#   'กีฬายิงธนูในเวิลด์เกมส์',
#   'การเห็นคุณค่าในตัวเอง',
#   'พระวรชายาในเจ้าชายฟุมิฮิโตะ',
#   'ประเทศสวิตเซอร์แลนด์ในโอลิมปิกฤดูหนาว',
#   'การค้นหาในแนวลึกแบบวนเพิ่มความลึก',
#   'จังหวัดเชียงใหม่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'สถิติในเอเอฟเอฟซูซูกิคัพ',
#   'ศาสนาในประเทศติมอร์',
#   'ลวดลายในธรรมชาติ',
#   'ในยามแห่งอาวุธกฎหมายทรุดเงียบเสียงลง',
#   'เจ้าจอมมารดาดวงคำในรัชกาลที่',
#   'ประเทศเติร์กเมนิสถานในพาราลิมปิกฤดูร้อน',
#   'เลือดในอุจจาระ',
#   'ประเทศอินเดียในเอเชียนเกมส์',
#   'ประเทศรัสเซียในโอลิมปิกเยาวชน',
#   'หน่วยการบริหารในประเทศฝรั่งเศส',
#   'อุบลราชธานีในกีฬาแห่งชาติครั้งที่',
#   'ประเทศปาเลาในโอลิมปิกเยาวชนฤดูร้อน',
#   'แผ่นดินไหวในถังชาน',
#   'โทรทัศน์ประเทศจีนในค',
#   'กีฬาเรือใบในกีฬาแห่งชาติครั้งที่',
#   'สโมสรฟุตบอลสุโขทัยในฤดูกาล',
#   'กีฬาเทเบิลเทนนิสในซีเกมส์',
#   'และสภาพแวดล้อมในการทำงาน',
#   'สโมสรฟุตบอลการท่าเรือในฤดูกาล',
#   'ฮอโลคอสต์ในโปแลนด์',
#   'ประเทศบัลแกเรียในพาราลิมปิกฤดูหนาว',
#   'ประเทศปานามาในโอลิมปิกฤดูร้อน',
#   'ท่าอากาศยานในประเทศญี่ปุ่น',
#   'เอธิโอเปียในโอลิมปิก',
#   'เรื่องอื้อฉาวในโบฮีเมีย',
#   'ระบบขนส่งทางรางในเขตเมือง',
#   'ธงต่างๆในประเทศแอฟริกาใต้',
#   'ยศทหารในกองทัพออสเตรเลีย',
#   'เมืองในเซบู',
#   'เหตุสะพานในโมรพีถล่ม',
#   'แผ่นดินไหวในจังหวัดชิบะค',
#   'ประเทศบราซิลในโอลิมปิกฤดูร้อน',
#   'ตัวละครในก้านกล้วย',
#   'ฟุตบอลหญิงทีมชาติญี่ปุ่นในฟุตบอลโลกหญิง',
#   'โรคเฮโมฟีเลียในราชวงศ์ยุโรป',
#   'ประเทศแอนทีกาและบาร์บิวดาในโอลิมปิกเยาวชนฤดูร้อน',
#   'ศาสนาในทวีปยุโรป',
#   'ป้ายจราจรในประเทศกัมพูชา',
#   'เหตุภาวะพิษแอลกอฮอล์ในรัฐปัญจาบ',
#   'การเพาะเลี้ยงปลาแซลมอนในน้ำ',
#   'ประเทศเช็กโกสโลวาเกียในโอลิมปิกฤดูร้อน',
#   'หลักความสอดคล้องในตัวเองของนาวิคอฟ',
#   'ประเทศโครเอเชียในโอลิมปิกฤดูร้อน',
#   'กีฬาขี่ม้าในแพนอเมริกันเกมส์',
#   'ประวัติศาสตร์ของมวยปล้ำอาชีพในสหรัฐอเมริกา',
#   'สถานีครุใน',
#   'ประเทศยูกันดาในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬาในเวิลด์เกมส์',
#   'อัลบั้มในฮายาเตะพ่อบ้านประจัญบาน',
#   'ประเทศเอสโตเนียในโอลิมปิก',
#   'ตัวละครในซีรีส์อาร์กเดอะแลด',
#   'กีฬาเจ็ตสกีในกีฬาแห่งชาติ',
#   'ประเทศสวีเดนในโอลิมปิก',
#   'สมาคมในประเทศไทย',
#   'สโมสรฟุตบอลเชียงรายยูไนเต็ดในฤดูกาล',
#   'สาธารณรัฐเวียดนามในโอลิมปิกฤดูร้อน',
#   'พระราชพิธีกาญจนาภิเษกในสมเด็จพระราชินีนาถวิกตอเรีย',
#   'การประท้วงในเอกวาดอร์',
#   'ประเทศไนเจอร์ในพาราลิมปิกฤดูร้อน',
#   'ดินแดนกวมของสหรัฐในโอลิมปิกเยาวชนฤดูร้อน',
#   'ชาติต่างๆในสหราชอาณาจักร',
#   'ภาวะมีโซเดียมในเลือดน้อยเกิน',
#   'ศาสนาในประเทศมาเลเซีย',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศมาดากัสการ์',
#   'ร็อคแมนที่ปรากฏใน',
#   'สมาคมกีฬาคนพิการแห่งประเทศไทยในพระบรมราชูปถัมภ์',
#   'ประเทศคอซอวอในโอลิมปิก',
#   'การเลือกตั้งประธานาธิบดีสหรัฐในรัฐแคลิฟอร์เนีย',
#   'สหรัฐในพาราลิมปิกฤดูร้อน',
#   'เวลาในประเทศไต้หวัน',
#   'ปุ่มในของท้ายทอย',
#   'ธงชาติประเทศในทวีปอเมริกา',
#   'เจ้าจอมมารดาหม่อมราชวงศ์เกสรในรัชกาลที่',
#   'ประเทศในโลก',
#   'สถิติในฟีฟ่าคอนเฟเดอเรชันส์คัพ',
#   'ฝีในตับ',
#   'การเจริญของเอ็มบริโอในพืช',
#   'เพชรในเพลง',
#   'เจ้าหญิงเซะสึโกะพระชายาในเจ้าชายยะซุฮิโตะ',
#   'เจ้าจอมมารดาเที่ยงในรัชกาลที่',
#   'การขนส่งระบบรางในประเทศฟิลิปปินส์',
#   'แผ่นดินไหวในประเทศเนปาล',
#   'การขนส่งในประเทศเวียดนาม',
#   'ฟุตซอลในเอเชียนอินดอร์',
#   'จังหวัดขอนแก่นในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'สิทธิในสุขภาพ',
#   'เวลาในประเทศตุรกี',
#   'นิกายในคริสต์ศาสนา',
#   'เหตุโจมตีทางอากาศในสลอวิยันสก์',
#   'ลิ่มเลือดในหลอดเลือดดำส่วนลึก',
#   'ประเทศบอสเนียและเฮอร์เซโกวีนาในโอลิมปิกฤดูร้อน',
#   'ในบันไดเสียงซีไมเนอร์',
#   'การประท้วงในประเทศอิหร่าน',
#   'โรคไหลตายในเด็ก',
#   'ศาสนาอิสลามในสหราชอาณาจักร',
#   'โทรทัศน์ในสหรัฐ',
#   'อ็อยเกเนียในบาวาเรีย',
#   'การพินทุในทางศาสนา',
#   'สาธารณรัฐอิสลามมอริเตเนียในโอลิมปิกฤดูร้อน',
#   'ประเทศโรมาเนียในโอลิมปิกเยาวชนฤดูร้อน',
#   'การเลือกตั้งทั่วไปในสเปน',
#   'ประเทศกาตาร์ในเอเชียนเกมส์',
#   'ศาสนาพุทธในเอเชียใต้',
#   'การประเมินกรณีข้อกังวลเรื่องสิทธิมนุษยชนในซินเจียงโดยสำนักสิทธิมนุษยชนสหประชาชาติ',
#   'ประเทศอิตาลีในโอลิมปิกฤดูหนาว',
#   'ความขัดแย้งในซูดาน',
#   'โครงการรถไฟความเร็วสูงในประเทศไทย',
#   'ดินแดนในภาวะทรัสตีโซมาเลีย',
#   'ในโอลิมปิกฤดูร้อน',
#   'พุทธศาสนาในไทย',
#   'ศาสนาพุทธในประเทศญี่ปุ่น',
#   'การยุบสภาผู้แทนราษฎรในประเทศไทย',
#   'ทางด่วนในประเทศจีน',
#   'กีฬาฟันดาบในโอลิมปิกเยาวชนฤดูร้อน',
#   'คลื่นความร้อนในเอเชีย',
#   'แผ่นดินไหวในประเทศปากีสถาน',
#   'เมืองในประเทศลาว',
#   'การเลือกตั้งทั่วไปในประเทศเบนิน',
#   'เหมือนมีก้อนในลำคอ',
#   'การก่อการกำเริบในซีเรีย',
#   'ประเทศไทยในโอลิมปิกเยาวชนฤดูร้อน',
#   'พระวรชายาในเจ้าชายโนะบุฮิโตะ',
#   'สวีเดนในช่วงสงครามโลกครั้งที่สอง',
#   'ศาสนาฮินดูในเวียดนาม',
#   'การจลาจลในสาธารณรัฐมาซิโดเนีย',
#   'ผู้คุมเสียงในสภา',
#   'กีฬาเรือประเพณีในซีเกมส์',
#   'การสังหารหมู่ในนครชิคาโกด้วยยาไทลินอล',
#   'สาธารณรัฐประชาธิปไตยเยอรมนีในโอลิมปิกฤดูร้อน',
#   'ตัวละครในโดราเอมอน',
#   'ความขัดแย้งในเซาท์คอร์โดฟานและบลูไนล์',
#   'อนุสรณ์สถานแด่ชาวยิวผู้ถูกสังหารในยุโรป',
#   'เขตผู้ว่าราชการในประเทศจอร์แดน',
#   'บุปผาในกุณฑีทอง',
#   'เจ้าจอมมารดาเจ้าหญิงจวนในสมเด็จพระเจ้ากรุงธนบุรี',
#   'คดีฆาตกรรมในตระกูลอินุงามิ',
#   'อุทยานแห่งชาติในภาคอีสาน',
#   'สาธารณรัฐมอนเตเนโกรในโอลิมปิกฤดูร้อน',
#   'เนเธอร์แลนด์แอนทิลลีสในโอลิมปิก',
#   'ควิดดิชในยุคต่างๆ',
#   'ประเทศกรีซในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬายิมนาสติกแอโรบิกในเวิลด์เกมส์',
#   'การปฏิวัติและการแทรกแซงในฮังการี',
#   'ตัวละครที่ปรากฏในร็อคแมน',
#   'ตัวละครในกัชเบล',
#   'กีฬาบอบสเลในโอลิมปิกเยาวชนฤดูหนาว',
#   'ประเทศลิกเตนสไตน์ในโอลิมปิกฤดูหนาว',
#   'จังหวัดอุบลราชธานีในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'ประเทศพม่าในซีเกมส์',
#   'ธงต่างๆในประเทศอินเดีย',
#   'การแบ่งเขตบริหารในอิหร่าน',
#   'พระพุทธเจ้าในอดีต',
#   'ประเทศเคนยาในโอลิมปิกฤดูหนาว',
#   'สโมสรวอลเลย์บอลชายนครราชสีมาในฤดูกาล',
#   'อัตราส่วนของกรดไขมันในอาหารต่างๆ',
#   'ฟุตบอลชายหาดในเอเชียนบีชเกมส์',
#   'รถยนต์พระที่นั่งในสมเด็จพระนางเจ้าสิริกิติ์',
#   'การปล้นธนาคารในติฟลิสค',
#   'สิทธิในการถูกลืม',
#   'ประเทศเฮติในโอลิมปิกฤดูร้อน',
#   'ชาในสหราชอาณาจักร',
#   'เยื่อกั้นหูชั้นใน',
#   'โดราเอมอนตอนโนบิตะผจญภัยในเกาะมหัศจรรย์',
#   'การบังคับใช้กฎหมายในประเทศสโลวีเนีย',
#   'รัฐกาตาร์ในเอเชียนเกมส์',
#   'ในปี',
#   'ประเทศเวเนซุเอลาในโอลิมปิกฤดูร้อน',
#   'วอลเลย์บอลหญิงในโอลิมปิกรอบคัดเลือกระดับโลก',
#   'ประเทศอินโดนีเซียในเอเชียนเกมส์ฤดูหนาว',
#   'ลมในกระเพาะลำไส้',
#   'มวยปล้ำในเอเชียนเกมส์',
#   'เจ้าหญิงคิกูโกะพระชายาในเจ้าชายโนบูฮิโตะ',
#   'สาธารณรัฐซาเอียร์ในโอลิมปิก',
#   'กาลครั้งหนึ่งในดินแดนทางเหนือ',
#   'ประเทศมอริเตเนียในโอลิมปิกฤดูร้อน',
#   'หมู่เกาะแฟโรในพาราลิมปิก',
#   'อาวุธและวิชาโจมตีในเทพมรณะ',
#   'พระปฐมวงศ์ในพระบรมราชวงศ์จักรี',
#   'สโมสรฟุตบอลสวอนซีซิตีในฤดูกาล',
#   'ครูโฮชิดาวในดงสาวป่วน',
#   'ประเทศบรูไนในซีเกมส์',
#   'สิ่งก่อสร้างที่สูงที่สุดในโลก',
#   'ประเทศอิสราเอลในโอลิมปิกเยาวชน',
#   'สาธารณรัฐกานาในโอลิมปิกฤดูหนาว',
#   'การลงคะแนนเลือกตั้งในสวิตเซอร์แลนด์',
#   'ประเทศไนจีเรียในโอลิมปิก',
#   'แผ่นดินไหวในเกาะฮาวาย',
#   'เหตุการณ์โจมตีในเบอร์ลิน',
#   'สโมสรวอลเลย์บอลหญิงนครราชสีมาในฤดูกาล',
#   'ประเทศหมู่เกาะโซโลมอนในโอลิมปิก',
#   'ศาสนาพุทธในเอเชียกลาง',
#   'ประเทศบัลแกเรียในโอลิมปิกเยาวชนฤดูร้อน',
#   'เจ้าจอมมารดาแย้มในรัชกาลที่',
#   'พระราชสันตติวงศ์ในพระเจ้าคริสเตียนที่',
#   'ธงในสหภาพโซเวียต',
#   'โบราณสถานในเมืองเพชร',
#   'ผู้นำฝ่ายสัมพันธมิตรในสงครามโลกครั้งที่สอง',
#   'วัดบางน้อยใน',
#   'ศาสนาอิสลามในประเทศมาดากัสการ์',
#   'ในสาธารณรัฐประชาชนลูฮันสค์',
#   'สงครามกองโจรในรัฐบอลติก',
#   'โล่ในตรา',
#   'เทพเจ้าในห้องสิน',
#   'แผ่นดินไหวในเกาะสุลาเวสี',
#   'น้ำในท่อสมองไขสันหลัง',
#   'ตราประจำพระองค์ในประเทศไทย',
#   'ดอยใน',
#   'ประเทศอันดอร์ราในโอลิมปิกเยาวชนฤดูร้อน',
#   'ศาสนาในประเทศอิรัก',
#   'โรงเรียนปิยชาติพัฒนาในพระราชูปถัมภ์ฯ',
#   'สาธารณรัฐอาหรับซีเรียในเอเชียนเกมส์',
#   'รถไฟฟ้าในกทม',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศเม็กซิโก',
#   'กีฬาเบรกแดนซ์ในโอลิมปิกฤดูร้อน',
#   'การผลิตข้าวในประเทศไทย',
#   'คดีเขาพระวิหารกัมพูชากับไทยในคริสต์ศักราช',
#   'การระบาดทั่วของโคโรนาไวรัสในประเทศบังกลาเทศ',
#   'กีฬาฟันดาบในโอลิมปิกซ้อน',
#   'ประเทศมาดากัสการ์ในโอลิมปิกฤดูร้อน',
#   'รถโดยสารประจำทางไฟฟ้าในเปียงยาง',
#   'เจ้าจอมมารดาหรุ่นในรัชกาลที่',
#   'การเคารพธงชาติในประเทศไทย',
#   'การเลือกตั้งแบบบัญชีรายชื่อในประเทศไทย',
#   'มหาวิทยาลัยในกำกับของรัฐ',
#   'สโมสรฟุตบอลจังหวัดนครราชสีมาในฤดูกาล',
#   'กีฬาโรลเลอร์สเกตในโอลิมปิกเยาวชนฤดูร้อน',
#   'ปาเลสไตน์ในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศหมู่เกาะโซโลมอนในโอลิมปิกฤดูร้อน',
#   'สาธารณรัฐจีนในโอลิมปิกฤดูหนาว',
#   'การล้อมปราบนักศึกษาประชาชนในมหาวิทยาลัยธรรมศาสตร์',
#   'ประเทศเซาตูเมและปรินซิปีในโอลิมปิกฤดูร้อน',
#   'เมืองและหมู่บ้านในประเทศบาร์เบโดส',
#   'โปโลในซีเกมส์',
#   'ธงต่างๆในประเทศอังกฤษ',
#   'องค์การสวนสัตว์ในพระบรมราชูปถัมภ์',
#   'ประเทศกินีบิสเซาในโอลิมปิก',
#   'ตัวละครในอินุยาฉะเทพอสูรจิ้งจอกเงิน',
#   'ประเทศเซเชลส์ในโอลิมปิก',
#   'กีฬาว่ายน้ำในกีฬาแห่งชาติ',
#   'ประเทศยูกันดาในพาราลิมปิกฤดูร้อน',
#   'โฆษณาชวนเชื่อในประเทศญี่ปุ่นในช่วงสงครามโลกครั้งที่',
#   'สาธารณรัฐคอสตาริกาในโอลิมปิกฤดูหนาว',
#   'การท่องเที่ยวในประเทศอาร์มีเนีย',
#   'รัฐบาลทหารของกองทัพสหรัฐในเกาหลี',
#   'การทำให้เป็นจีนในทิเบต',
#   'ประเทศแทนซาเนียในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศมอนเตเนโกรในโอลิมปิกฤดูร้อน',
#   'การลงประชามติการปกครองตนเองในนูแวล',
#   'เจ้าจอมปุกในรัชกาลที่',
#   'ประเทศในยูโรเปียนเกมส์',
#   'กีฬาซอฟต์บอลในเอเชียนเกมส์',
#   'คดีปิตุฆาตในโทะชิงิ',
#   'และบทพากย์รามเกียรติ์ในรัชกาลที่',
#   'การประท้วงในแอฟริกาเหนือและตะวันออกกลาง',
#   'สงครามในอัฟกานิสถาน',
#   'การติดเชื้อในระบบหายใจ',
#   'กีฬากาบัดดี้ในกีฬาเยาวชนแห่งชาติครั้งที่',
#   'กีฬาเทเบิลเทนนิสในโอลิมปิกฤดูร้อน',
#   'กีฬาฟุตซอลในโอลิมปิกเยาวชนฤดูร้อน',
#   'การเสริมสร้างกองทัพในเอเชียตะวันออกเฉียงใต้',
#   'เหตุโจมตีผู้เข้าแถวซื้อขนมปังในแชร์นีฮิว',
#   'พุทธศาสนาในประเทศอียิปต์',
#   'วิกฤตการณ์ทางการเงินในเอเชีย',
#   'ตัวละครในจัสติส',
#   'ในสวนขวัญ',
#   'แผ่นดินไหวในประเทศไทย',
#   'วัดบางด้วนใน',
#   'รัฐในคาบสมุทรบอลข่าน',
#   'ตัวละครในพลังอักษะ',
#   'สโมสรฟุตบอลเรอัลมาดริดในฤดูกาล',
#   'เชลยศึกชาวญี่ปุ่นในสหภาพโซเวียต',
#   'กีฬาวูซูในเวิลด์เกมส์',
#   'เกิดใหม่เป็นขุนนางไปผจญภัยในต่างโลก',
#   'นักดำน้ำในถ้ำ',
#   'ส่งเสริมศิลปาชีพในสมเด็จพระนางเจ้าสิริกิติ์พระบรมราชินีนาถ',
#   'การติดเชื้อในกระแสเลือดในทารกแรกเกิด',
#   'สาธารณรัฐประชาธิปไตยคองโกในพาราลิมปิกฤดูร้อน',
#   'สาธารณรัฐแคเมอรูนในโอลิมปิกฤดูหนาว',
#   'พระราชพิธีทรงผนวชในรัชกาลที่',
#   'กีฬาลีลาศในซีเกมส์',
#   'การประท้วงในแคว้นกาตาลุญญา',
#   'รถไฟฟ้าในประเทศไทย',
#   'ริ้วขบวนในพระราชพิธีถวายพระเพลิงพระบรมศพพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราชฯ',
#   'สาธารณรัฐประชาธิปไตยคองโกในโอลิมปิกฤดูร้อน',
#   'วิทยาศาสตร์และเทคโนโลยีในเนเธอร์แลนด์',
#   'สโมสรฟุตบอลบีจีปทุมยูไนเต็ดในฤดูกาล',
#   'ข้อพิพาทเกี่ยวกับตัวแทนจำหน่ายของเทสลาในสหรัฐ',
#   'การประท้วงในจอร์เจีย',
#   'ประเทศกินีในพาราลิมปิกฤดูร้อน',
#   'ประเทศตุรกีในโอลิมปิกเยาวชนฤดูหนาว',
#   'กีฬาแบดมินตันในโอลิมปิก',
#   'ประเทศมอนเตเนโกรในโอลิมปิกเยาวชนฤดูร้อน',
#   'ประเทศเซเชลส์ในพาราลิมปิกฤดูร้อน',
#   'น้ำคร่ำอุดตันในกระแสเลือด',
#   'ธงในประเทศโอมาน',
#   'ประเทศโซมาเลียในพาราลิมปิกฤดูร้อน',
#   'วันหยุดในศาสนาคริสต์',
#   'แผ่นดินไหวและคลื่นสึนามิในอูนเซนค',
#   'กีฬาวอลเลย์บอลชายหาดในเอเชียนเกมส์',
#   'ประเทศในเครือจักรภพ',
#   'ภาวะกรดมาโลนิกและกรดเมทิลมาโลนิกในปัสสาวะ',
#   'ประเทศปารากวัยในแพนอเมริกันเกมส์',
#   'เหตุเหยียบกันเสียชีวิตในพนมเปญ',
#   'จังหวัดสุโขทัยในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#   'วิวัฒนาการกระดูกเล็กเพื่อได้ยินในสัตว์เลี้ยงลูกด้วยนม',
#   'ธงในหน่วยราชการรัสเซีย',
#   'บีเทิลเมเนียในสหราชอาณาจักร',
#   'เหตุโจมตีในค็องส์แบร์ก',
#   'ประเทศรวันดาในโอลิมปิก',
#   'ประเทศแคเมอรูนในโอลิมปิกเยาวชนฤดูร้อน',
#   'ปาเลสไตน์ในโอลิมปิก',
#   'กีฬาเทนนิสในโอลิมปิกเยาวชน',
#   'ประเทศซาอุดีอาระเบียในโอลิมปิกฤดูร้อน',
#   'เหตุโจมตีในมหาวิทยาลัยคาบูล',
#   'ธงในประเทศโปรตุเกส',
#   'ประเทศซานมารีโนในโอลิมปิกเยาวชนฤดูหนาว',
#   'สิทธิในอาหาร',
#   'สนามกีฬาในร่มวินเซนส์',
#   'มีเมตฮีโมโกลบินในเลือด',
#   'ความขัดแย้งกรณีโรฮิงยาในพม่าตะวันตก',
#   'ประกายจ้าในตาเธอ',
#   'หมู่เกาะเคย์แมนในโอลิมปิกเยาวชนฤดูร้อน',
#   'วอลเลย์บอลในลูโซโฟนีเกมส์',
#   'อลิซในแดนมหัศจรรย์',
#   'การสังคายนาพระธรรมวินัยในพุทธศาสนา',
#   'เจ้าจอมน้อมในรัชกาลที่',
#   'กีฬาวอลเลย์บอลชายหาดในโอลิมปิกฤดูร้อน',
#   'ชาวจีนในประเทศปากีสถาน',
#   'ประเทศโมนาโกในโอลิมปิกเยาวชนฤดูร้อน',
#   'การแปลผลให้เป็นความกลัวในสมอง',
#   'คริสตจักรอีแวนเจลิกในเยอรมนี',
#   'การรุกรานของอนารยชนในยุโรป',
#   'การเปลี่ยนแปลงสภาพภูมิอากาศในรัฐแคลิฟอร์เนีย',
#   'พระราชสันตติวงศ์ในพระบาทสมเด็จพระมหาภูมิพลอดุลยเดชมหาราช',
#   'ต้มเครื่องในหมู',
#   'ประเทศอุซเบกิสถานในโอลิมปิกเยาวชนฤดูร้อน',
#   'กีฬาโปโลน้ำในโอลิมปิกฤดูร้อน',
#   'เจ้าจอมมารดาแสงในรัชกาลที่๕',
#   'ชาวไทยในประเทศพม่า',
#   'ประเทศชาดในโอลิมปิกเยาวชนฤดูร้อน',
#   'เหรียญดุษฎีมาลาเข็มราชการในพระองค์',
#   'หลังรัฐประหารในประเทศไทย',
#   'พระราชประวัติก่อนเสด็จขึ้นครองราชย์ของสมเด็จพระเจ้ากรุงธนบุรีในอภินิหารบรรพบุรุษ',
#   'ในรัสเซีย',
#   'ความหลากหลายทางชีวภาพในประเทศบราซิล',
#   'ประเทศลัตเวียในพาราลิมปิกฤดูร้อน',
#   'ราชอาณาจักรซาอุดีอาระเบียในโอลิมปิกฤดูร้อน',
#   'กีฬาวอลเลย์บอลหญิงในเอเชียนเกมส์',
#   'พระพุทธศาสนาในประเทศกัมพูชา',
#   'การปั่นจักรยานในเนเธอร์แลนด์',
#   'ธงในประเทศเวลส์',
#   'เทวสิทธิของพระมหากษัตริย์ในการปกครอง',
#   'แผ่นดินไหวในหมู่เกาะซามัว',
#   'เหตุระเบิดในบาหลี',
#   'ฟุตบอลในประเทศเกาหลีใต้',
#   'ฝ่ายสัมพันธมิตรในสงครามโลกครั้งที่',
#   'ชนพื้นเมืองในทวีปอเมริกา',
#   'ภาวะมีไตรเมทิลามีนในปัสสาวะ',
#   'พระชายาในเจ้าชายฟูมิฮิโตะ',
#   'ตายในการรบ',
#   'โรงเรียนสาธิตมหาวิทยาลัยราชภัฏวไลยอลงกรณ์ในพระบรมราชูปถัมภ์',
#   'ธงต่างๆในสหราชอาณาจักร',
#   'ผู้เล่นในเอเอฟเอฟ',
#   'อุปกรณ์ไฟฟ้าในพื้นที่อันตราย',
#   'ชาวไทยในอินเดีย',
#   'ประเทศโมร็อกโกในโอลิมปิกเยาวชน',
#   'ปรากฏการณ์โลกร้อนในยุคกลาง',
#   'การประท้วงในเลบานอน',
#   'การประท้วงของชาวนาในประเทศอินเดีย',
#   'ประเทศนอร์เวย์ในโอลิมปิกเยาวชนฤดูหนาว',
#   'ธงในประเทศเบลารุส',
#   'ประเทศโอมานในเอเชียนบีชเกมส์',
#   'สาธารณรัฐปาเลาในโอลิมปิกฤดูร้อน',
#   'การเมืองในเนเธอร์แลนด์',
#   'ฟุตบอลในประเทศญี่ปุ่น',
#   'พืชพันธุ์ในประเทศมาซิโดเนีย',
#   'กระทรวงในรัฐบาลกลางแห่งสหรัฐ',
#   'กีฬาลาครอสส์ในโอลิมปิกฤดูร้อน',
#   'เหตุกราดยิงในโรงเรียนประถมรอบบ์',
#   'กีฬายิวยิตสูในกีฬาแห่งชาติครั้งที่',
#   'ภาวะกรดยูริคในเลือดสูง',
#   'กีฬายิมนาสติกในกีฬาแห่งชาติครั้งที่',
#   'ข้อเท็จจริงทางประวัติศาสตร์ในสามก๊ก',
#   'ประเทศอินโดนีเซียในโอลิมปิก',
#   'ฟุตบอลในกีฬามหาวิทยาลัยโลกฤดูร้อน',
#   'ในพระบาทสมเด็จพระเจ้าอยู่หัวภูมิพลอดุลยเดช',
#   'คณะเผยแพร่ศาสนาแอละโมในแซนแอนโทนีโอ',
#   'ตัวละครในเรื่องเรฟผจญภัยเหนือโลก',
#   'สหพันธรัฐรัสเซียในโอลิมปิกฤดูร้อน',
#   'เจ้าหญิงฮิซะโกะพระวรชายาในเจ้าชายโนะริฮิโตะ',
#   'พิธีอภิเษกในศาสนา',
#   'ประเทศบัลแกเรียในโอลิมปิกฤดูร้อน',
#   ...]]

# %% [markdown]
# Some are named-entity, others are not.
# What if try rule-based?

# %% [markdown]
# #### Exclude Onlympics

# %%
nai = [title for title in titles if ("ใน" in title) and ("โอลิมปิก" not in title)]

len(nai)
# Out:
# 5483

# %% [markdown]
# 50% of "ใน" was about Olympics..!

# %%
get_samples(nai)
# Out:
# ['พระมหากษัตริย์ในปรัสเซีย',
#  'แผ่นดินไหวและคลื่นสึนามิในมหาสมุทรอินเดีย',
#  'โฆษณาชวนเชื่อในนาซีเยอรมนี',
#  'คอเลสเตอรอลในเลือดแบบไม่ดี',
#  'ประเทศอิสราเอลในเอเชียนเกมส์',
#  'วันหยุดในประเทศลัตเวีย',
#  'โรงเรียนอุบลรัตนราชกัญญาราชวิทยาลัยนครปฐมในพระอุปถัมภ์',
#  'ลัทธิเต๋าในเกาหลี',
#  'หมายเลขโทรศัพท์ในประเทศตองงา',
#  'ประเทศโรมาเนียในพาราลิมปิกฤดูร้อน',
#  'ในจักรพรรดิซ่งฮุ่ยจง',
#  'การอพยพในสหภาพโซเวียต',
#  'ธงในประเทศญี่ปุ่น',
#  'ในสมเด็จพระบรมโอรสาธิราชฯ',
#  'ฟุตซอลในซีเกมส์',
#  'จักรพรรดินีเหรินหูไอในจักรพรรดิซ่งชินจง',
#  'หลักความสอดคล้องในตัวเองของนาฟวิคัฟ',
#  'ดัชเชสเฮ็ลเลนาอ็อยเกเนียในบาวาเรีย',
#  'การประท้วงต่อต้านรัฐบาลในพม่า',
#  'การเคลื่อนที่ในรอบวัน',
#  'เหตุการณ์สำคัญในสมัยกรุงศรีอยุธยา',
#  'กีฬาปันจักสีลัตในกีฬาแห่งชาติครั้งที่',
#  'สตรีในประเทศสิงคโปร์',
#  'เขตในประเทศอินเดีย',
#  'ลัทธิจักรวรรดินิยมในเอเชีย',
#  'ตำแหน่งฝ่ายใน',
#  'ธงในประเทศเบลเยียม',
#  'ดอกไม้ในใจ',
#  'การรบในตูนีเซีย',
#  'สมาคมสถาปนิกสยามในพระบรมราชูปถัมภ์',
#  'การประมวลผลให้เป็นความกลัวในสมอง',
#  'โฆษณาชวนเชื่อในประเทศญี่ปุ่น',
#  'การปราบปรามคอมมิวนิสต์ในประเทศไทย',
#  'กีฬากีฬาทางอากาศในกีฬาแห่งชาติครั้งที่',
#  'กรีฑาในซีเกมส์',
#  'การเข้าแทรกแซงของสหรัฐอเมริกาในชิลี',
#  'แผ่นดินไหวและคลื่นสึนามิในอูนเซน',
#  'สัตว์ในตำนาน',
#  'การทำงานในสมองกับการนั่งสมาธิ',
#  'ในประเทศอังกฤษ',
#  'สิทธิมนุษยชนในประเทศกัมพูชา',
#  'เจ้าจอมหม่อมราชวงศ์เฉียดในรัชกาลที่',
#  'ตัวละครในจีทีโอ',
#  'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดขอนแก่น',
#  'แผ่นดินไหวในมณทลยูนนาน',
#  'ประเทศไนเจอร์ในพาราลิมปิกฤดูร้อน',
#  'พินทุในความหมายทางศาสนา',
#  'กีฬาเซปักตะกร้อในกีฬาแห่งชาติ',
#  'ฝุ่นควันในเอเชียตะวันออกเฉียงใต้ค',
#  'ในสหภาพโซเวียต',
#  'เขตเลือกตั้งสมาชิกสภาผู้แทนราษฎรในจังหวัดกาฬสินธุ์',
#  'มรดกโลกในประเทศกัมพูชา',
#  'การโจมตีด้วยขีปนาวุธในอูมัญ',
#  'สาธารณรัฐมองโกเลียในเอเชียนเกมส์',
#  'กีฬาซอฟท์เทนนิสในกีฬาแห่งชาติครั้งที่',
#  'ความหลากหลายทางชีวภาพในประเทศลาว',
#  'การเลือกตั้งประธานาธิบดีสหรัฐในรัฐแคลิฟอร์เนีย',
#  'ฝ่ายค้านในรัฐสภา',
#  'ลูกเสือและเนตรนารีในกัมพูชา',
#  'แวมไพร์ในสวน',
#  'การฆาตกรรมหมู่ในนครชิคาโกด้วยยาไทลินอล',
#  'บันทึกรักในเมืองเล็ก',
#  'อุทยานประวัติศาสตร์ในประเทศไทย',
#  'อุทกภัยจากธารน้ำแข็งแตกในรัฐอุตตราขัณฑ์',
#  'แผ่นดินไหวในจังหวัดนีงาตะค',
#  'ความอดอยากครั้งใหญ่ในไอร์แลนด์',
#  'ความลำเอียงทางคตินิยมในวิกิพีเดีย',
#  'โรงเรียนสตรีวิทยา๒ในพระราชูปถัมภ์สมเด็จพระศรีนครินทราบรมราชชนนี',
#  'ตัวละครสำคัญในอาณาจักรแห่งกาลเวลา',
#  'ธงในกองทัพรัสเซีย',
#  'แนวฟันในหิน',
#  'ประเทศเคนยาในพาราลิมปิกฤดูร้อน',
#  'เหตุเพลิงไหม้โกดังเก็บวิสกี้ในดับลิน',
#  'ศาสนาพุทธในประเทศกัมพูชา',
#  'ตัวละครอื่นในลอร์ดออฟเดอะริงส์',
#  'อุทกภัยและดินถล่มในภาคใต้',
#  'การระบาดของโคโรนาไวรัสในประเทศอิตาลี',
#  'การท่องเที่ยวในกรุงเทพมหานคร',
#  'กีฬากีฬาเอ็กซ์ตรีมในกีฬาแห่งชาติครั้งที่',
#  'ศาสนาอิสลามในประเทศมาเลเซีย',
#  'สนามบินในประเทศไทย',
#  'เจ้าจอมมารดาเขียนในรัชกาลที่',
#  'โซเวียตในเบรสท์',
#  'ปลายอุโมงค์แห่งคำบอกลาในหน้าร้อน',
#  'กีฬาจักรยานในซีเกมส์',
#  'สงครามในดอนบัส',
#  'มุมปากตกขณะร้องไห้ในทารก',
#  'ติดเชื้อราในหู',
#  'พระวรชายาในเจ้าชายทะกะฮิโตะ',
#  'ข้อกล่าวหาการทุจริตในโครงการก่อสร้างท่าอากาศยานสุวรรณภูมิ',
#  'เหตุกราดยิงโบสถ์ในซัตเทอร์แลนด์สปริงส์',
#  'สัตว์ประหลาดในแฟรนไชส์เอเลี่ยน',
#  'ความหลากหลายทางชีวภาพในประเทศบอตสวานา',
#  'ประเทศบาร์เบโดสในแพนอเมริกันเกมส์',
#  'ภาวะความดันเลือดในปอดสูงในทารกแรกเกิด',
#  'ราชอาณาจักรบาห์เรนในเอเชียนเกมส์',
#  'หนังสือพิมพ์ในประเทศไทย',
#  'สถาปัตยกรรมภายใน',
#  'พระนามทรงกรมของพระราชโอรสพระราชธิดาในรัชกาลที่๕',
#  'การขนส่งระบบรางในประเทศญี่ปุ่น']

# %% [markdown]
# #### Exclude sports
# such as "สโมสรฟุตบอลแบล็กเบิร์นโรเวอส์ในฤดูกาล"

# %%
nai = [title for title in nai if ("ฤดู" not in title)]

len(nai)
# Out:
# 5108

# %%
get_samples(nai)
# Out:
# ['กีฬาบาสเก็ตบอลในกีฬาแห่งชาติครั้งที่',
#  'เหตุเรือบรรทุกน้ำตาลล่มในแม่น้ำเจ้าพระยา',
#  'การลงประชามติสนธิสัญญามาสทริชต์ในฝรั่งเศส',
#  'พระราชโอรสในฟาโรห์สเนฟรู',
#  'อัมพาตเป็นระยะจากโพแทสเซียมในเลือดต่ำเกิน',
#  'ตราแผ่นดินในทวีปโอเชียเนีย',
#  'การตั้งครรภ์ในช่องท้อง',
#  'กีฬารักบี้ในเอเชียนเกมส์',
#  'การใช้ถ้อยคำในธุลีปริศนา',
#  'ภาวะกรดมาโลนิกและกรดเมทิลมาโลนิกในปัสสาวะ',
#  'โรงเรียนราชประชาสมาสัยฝ่ายมัธยมรัชดาภิเษกในพระบรมราชูปถัมภ์',
#  'ฮีโมโกลบินในเม็ดเลือดเฉลี่ย',
#  'เจ้าจอมแจ่มในรัชกาลที่',
#  'ในประเทศอียิปต์',
#  'หลอดเลือดอุดตันในปอด',
#  'สตรีในประเทศสิงคโปร์',
#  'พิธีสารเลือกรับเรื่องความเกี่ยวพันของเด็กในความขัดแย้งกันด้วยอาวุธ',
#  'วิดีโอเกมในประเทศไทย',
#  'โปโลในซีเกมส์ค',
#  'พระราชพิธีทวีธาภิเษกในรัชกาลที่',
#  'ช็อกจากการติดเชื้อในกระแสเลือด',
#  'การท่องเที่ยวในประเทศอุรุกวัย',
#  'ภาพยนตร์ในปี',
#  'และพื้นที่ภาษาในประเทศเบลเยียม',
#  'จังหวัดในประเทศเกาหลีใต้',
#  'และจวนตระกูลขงในชฺวีฟู่',
#  'เจ้าจอมอิ่มย่าหรันในรัชกาลที่',
#  'เจ้าจอมมารดาสุดในรัชกาลที่',
#  'ในประเทศสเปน',
#  'สภาใน',
#  'เวลาในประเทศเลบานอน',
#  'เจ้าจอมช้อยในรัชกาลที่',
#  'ตัวละครในแขนกล',
#  'เหตุโจมตีในจาการ์ตา',
#  'เขตผู้ว่าราชการในประเทศจอร์แดน',
#  'ประเทศอิหร่านในเอเชียนเกมส์',
#  'พืชพันธุ์ในประเทศมาซิโดเนียเหนือ',
#  'ลิ่มเลือดในหลอดเลือดดำสมอง',
#  'ตัวละครในวัยซนคนการ์ตูน',
#  'การทำลายป่าในประเทศกัมพูชา',
#  'เหตุเพลิงไหม้อาคารสูงในเกาสฺยง',
#  'พระตำหนักในพระราชวังดุสิต',
#  'เหตุการณ์การสูญพันธุ์ในยุคครีเทเชียส',
#  'เมืองในประเทศลาว',
#  'ประเทศอิรักในเอเชียนบีชเกมส์',
#  'ลำดับเวลาในแฮร์รี่',
#  'ทางหลวงที่ยาวที่สุดในประเทศไทย',
#  'เจ้าจอมมารดานุ้ยใหญ่ในรัชกาลที่',
#  'วันหยุดในประเทศบรูไน',
#  'สิทธิของกลุ่มบุคคลที่มีความหลากหลายทางเพศในประเทศไทย',
#  'ผู้กล้าในตำนาน',
#  'แก๊สในลำไส้',
#  'กีฬากาบัดดี้ในเอเชียนเกมส์',
#  'มะเร็งในวัยเด็ก',
#  'วันหยุดในประเทศพม่า',
#  'แผ่นดินไหวในจังหวัดคูมาโมโตะ',
#  'ในประเทศอิตาลี',
#  'พื้นที่สงวนชีวมณฑลโลกในประเทศไทย',
#  'ประเทศอารูบาในแพนอเมริกันเกมส์',
#  'การระบาดทั่วของไวรัสโคโรนาในประเทศแอฟริกาใต้',
#  'การศึกษาในลาว',
#  'สิทธิมนุษยชนในสหภาพโซเวียต',
#  'จังหวัดในประเทศไทย',
#  'อากาศยานในราชการไทย',
#  'ในประเทศญี่ปุ่น',
#  'ตำหนิในงานเชื่อม',
#  'จักรวรรดิจีนยืนยงในจักรวาลอย่างกล้าหาญ',
#  'แผ่นดินไหวในไครสต์เชิร์ช',
#  'บั๊คโรเจอร์มนุษย์ในศตวรรษที่',
#  'โทรทัศน์ในสหรัฐอเมริกา',
#  'กีฬาอควาธลอนในเวิลด์บีชเกมส์',
#  'ความขัดแย้งในประเทศซูดาน',
#  'สาธารณรัฐประชาธิปไตยประชาชนเกาหลีในเอเชียนเกมส์',
#  'ตัวละครในสแลมดังก์',
#  'กลุ่มโรงเรียนในเครือบดินทรเดชา',
#  'รถรางในเวียนนา',
#  'การระบาดของอาการเยื่อหุ้มสมองอักเสบในแอฟริกาตะวันตกค',
#  'ทางด่วนในประเทศอินเดีย',
#  'เปอร์โตริโกในแพนอเมริกันเกมส์',
#  'เจ้าหญิงโนบุโกะพระชายาในเจ้าชายโทโมฮิโตะ',
#  'การเลือกตั้งสมาชิกสมัชชาแห่งชาติเป็นการทั่วไปในกัมพูชา',
#  'ในพระบรมราชูปถัมภ์',
#  'หวังในธรรม',
#  'วัดบางเตยใน',
#  'ระบบสองพรรคการเมืองในประเทศไทย',
#  'ในสมเด็จพระบวรราชเจ้ามหาเสนานุรักษ์',
#  'ศาสนาพุทธในประเทศยูเครน',
#  'นิวเคลียสในสมอง',
#  'จังหวัดนราธิวาสในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป',
#  'กฎผลรวมในการหาอนุพันธ์',
#  'ทุพภิกขภัยครั้งใหญ่ในไอร์แลนด์',
#  'การเรียกร้องให้บัญญัติศาสนาพุทธเป็นศาสนาประจำชาติในรัฐธรรมนูญแห่งราชอาณาจักรไทย',
#  'การจัดการสตริงในภาษาซี',
#  'สื่อลามกอนาจารในอินเตอร์เน็ต',
#  'อัตราส่วนความสามารถในการจ่ายดอกเบี้ย',
#  'รัฐเดลาแวร์ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรค',
#  'กีฬาซอฟต์บอลในกีฬาแห่งชาติครั้งที่',
#  'ศาลอาญาระหว่างประเทศในอดีตยูโกสลาเวีย',
#  'กีฬาซอฟท์เทนนิสในซีเกมส์',
#  'จังหวัดแพร่ในการเลือกตั้งสมาชิกสภาผู้แทนราษฎรไทยเป็นการทั่วไป']

# %% [markdown]
# Most of these are still non-named-entity
#
# Seems to be difficult to get named-entity title...
#
# Exclude all "ใน"
#
# **HELP NEEDED**

# %%
titles = set([title for title in titles if "ใน" not in title])

get_len(titles)
# Out:
# current: 293408
# diff: -7089

# %%
get_samples(titles)
# Out:
# ['โทโฮกุซุนโกะ',
#  'หันตรีบาร์นี',
#  'อาร์มองด์',
#  'ฌูลส์รีเมต์',
#  'ดับเบิลยูดับเบิลยูอีซูเปอร์โชว์',
#  'ถนัดศรี',
#  'มีแชลเดอเบร',
#  'ปลาหมึกจัมโบ้',
#  'ซุนดาน',
#  'ลินเนิร์ดสกินเนิร์ด',
#  'โอมาฮา',
#  'แคทีเลียง',
#  'สโมสรฟุตบอลโรงเรียนกีฬาเทศบาลนครนครราชสีมา',
#  'การ์ปัชโช',
#  'แกตา',
#  'หม่อมเจ้าคัสตาวัส',
#  'ฮานะโนะเอน',
#  'ไฮน์ริชกุสทัฟมักนุส',
#  'ถิรชัยอ',
#  'อนุภาคพระเจ้า',
#  'อะเล็กซานเดอร์ปุชกิน',
#  'อาม็อกเตร็ย',
#  'พินัยกรรม',
#  'เสฎฐวุฒิ',
#  'มึนส์เทอร์',
#  'โรคอารมณ์สองขั้วเป็นสเปกตรัม',
#  'เอริชฮาร์ทมัน',
#  'ฮอสเซน',
#  'ศรีวราห์',
#  'แครา',
#  'วัดถ้ำกลองเพล',
#  'หงส์กู่',
#  'วัดท้องคุ้ง',
#  'รหัสทางภูมิศาสตร์',
#  'เซฟโปรซิล',
#  'เกราร์ดปิเก',
#  'ถุงหุ้มข้อไหล่อักเสบยึดติด',
#  'พระบวรราชวัง',
#  'จอห์นโตแช็ก',
#  'มงต์โซโร',
#  'จิระพันธิ์',
#  'ปูลุงจี',
#  'อมรินทร์ทีวี',
#  'ปืนสั้นอัดลม',
#  'เอาเตอร์เฮบริดีส',
#  'โอซาโกะ',
#  'เอ็ดเวิร์ดเจ้าชายดำ',
#  'ดยุกแห่งกัลลิเอรา',
#  'พริษฐ์วัชรสินธุ',
#  'ภูเขาโทกาจิ',
#  'เจ้าชายเอากุสท์วิลเฮ็ล์มแห่งปรัสเซีย',
#  'ชาวอเมริกันเชื้อสายไทย',
#  'แลงเกวจ',
#  'เตอูเบ',
#  'องค์การบริหารส่วนตำบลท่าไร่',
#  'อมรินทร์ทีวีเอชดี',
#  'สถานีโทรทัศน์ทีวีบี',
#  'ยุกิรุ',
#  'อายูมิอิโต้',
#  'ริยันกาจันทา',
#  'อะคะโฮะชิ',
#  'ชิโนล่า',
#  'ซ่งเสินจง',
#  'จักรพรรดิฮั่นอู่ตี้',
#  'ไทยแลนด์มอเตอร์ไซค์เคิลกรังด์ปรีซ์',
#  'ทารุสุเกะ',
#  'วงศ์โลมามหาสมุทร',
#  'วิดีโอเกมผู้เล่นเดี่ยว',
#  'เพราะรักใช่เปล่า',
#  'วิทยาลัยอาชีวศึกษาร้อยเอ็ด',
#  'การแข่งขันระหว่าง',
#  'ยูสิด',
#  'สถานีผิงกั่วหยวน',
#  'สุทัตตาภักดิ์บริรักษ์ภูมินทร์',
#  'วรินดา',
#  'เทศบาลเมืองบ้านหมี่',
#  'กลุ่มเกาะอาร์กติก',
#  'กล้ามเนื้อดีเพรสเซอร์ซูเปอร์ซิลิไอ',
#  'หม่อมหลวงชูชาติกำภู',
#  'หลวงปู่มั่นภูริทตฺโต',
#  'มาลามาลาจ็อง',
#  'มิดไนต์พาเหรด',
#  'นิธินาฏราชนิยม',
#  'ประสาทไทรเจมินัล',
#  'วัดพระพุทธบาทบัวบาน',
#  'วิทยาลัยการฝึกหัดครู',
#  'โมกสยาม',
#  'สมเด็จพระเจ้านิโคลัสที่',
#  'วิศวกรรมอิเล็กทรอนิกส์',
#  'ดีโอโก้',
#  'ยานจู่โจมแอคคลาเมเตอร์เซคอัน',
#  'พระพุทธรูปที่ยังไม่สมบูรณ์',
#  'การบุกครองยูโกสลาเวีย',
#  'ฆวนการ์ซิอาโปสติโก',
#  'รูเพิร์ทกรินท์',
#  'แมงดาทะเล',
#  'ก้าวแรกสู่สังเวียน',
#  'ปีแยร์อึนกูว์เริงซีซา',
#  'หลุยส์ซุลลิแวน',
#  'ลำดับการสืบราชสันตติวงศ์อดีตออสเตรีย']

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ
#
# There are "ประเทศ..." patterns and "รัฐ" patterns (such as Palestine)

# %%
pratheet = [title for title in titles if title.startswith("ประเทศ")]
rath = [title for title in titles if title.startswith("รัฐ")]

len(pratheet), len(rath)
# Out:
# (398, 1250)

# %%
get_samples(pratheet)
# Out:
# ['ประเทศฮอลแลนด์',
#  'ประเทศเยอรมนีตะวันตก',
#  'ประเทศตองงา',
#  'ประเทศเกาหลีเหนือกับอาวุธอานุภาพทำลายล้างสูง',
#  'ประเทศคองโก',
#  'ประเทศมาเลเซีย',
#  'ประเทศภูฏาน',
#  'ประเทศคอซอวอ',
#  'ประเทศอิเควทอเรียลกินี',
#  'ประเทศนามิเบีย',
#  'ประเทศอินโดนีเชีย',
#  'ประเทศกรีซ',
#  'ประเทศเซนต์ลูเชีย',
#  'ประเทศบัลกาเรีย',
#  'ประเทศซานมาริโน',
#  'ประเทศทาจิกิสถาน',
#  'ประเทศเอธิโอเปีย',
#  'ประเทศจาเมกา',
#  'ประเทศสมมุติ',
#  'ประเทศมาลากาซี',
#  'ประเทศมาดากัสการ์',
#  'ประเทศนีวเว',
#  'ประเทศอาหรับ',
#  'ประเทศฟีจี',
#  'ประเทศเช็กเกีย',
#  'ประเทศสาธารณรัฐประชาชนจีน',
#  'ประเทศตูนิเซีย',
#  'ประเทศที่มีอดีตเป็นแดนนักโทษ',
#  'ประเทศกินีบิสเซา',
#  'ประเทศที่เป็นเกาะ',
#  'ประเทศโกตดิวัวร์',
#  'ประเทศไต้หวัน',
#  'ประเทศสิงคโปร์',
#  'ประเทศปานามา',
#  'ประเทศซูดาน',
#  'ประเทศเอสวาตินี',
#  'ประเทศคูเวต',
#  'ประเทศอุรุกวัย',
#  'ประเทศฝรั่งเศส',
#  'ประเทศสาธารณรัฐออสเตรีย',
#  'ประเทศเซาท์ซูดาน',
#  'ประเทศโซมาเลีย',
#  'ประเทศอินโดนีเซีย',
#  'ประเทศด้อยพัฒนา',
#  'ประเทศเฮติ',
#  'ประเทศไอร์แลนด์เหนือ',
#  'ประเทศโปรตุเกส',
#  'ประเทศเมียนม่าร์',
#  'ประเทศซินต์มาร์เติน',
#  'ประเทศบาร์เบโดส',
#  'ประเทศสาธารณรัฐฝรั่งเศส',
#  'ประเทศอิตาลี',
#  'ประเทศคิวบา',
#  'ประเทศสมมติ',
#  'ประเทศโซมาลีแลนด์',
#  'ประเทศบังคลาเทศ',
#  'ประเทศเวียตนาม',
#  'ประเทศโดมินิกัน',
#  'ประเทศเนเธอแลนด์',
#  'ประเทศโครเอเชียกับสกุลเงินยูโร',
#  'ประเทศอุตสาหกรรมใหม่',
#  'ประเทศวานัวตู',
#  'ประเทศเยอรมนี',
#  'ประเทศอูกันดา',
#  'ประเทศสาธารณรัฐอิตาลี',
#  'ประเทศโอมาน',
#  'ประเทศอาร์เมเนีย',
#  'ประเทศนิคารากัว',
#  'ประเทศเชกโกสโลวาเกีย',
#  'ประเทศเบลเยียม',
#  'ประเทศซาอุดีอารเบีย',
#  'ประเทศปากีสถาน',
#  'ประเทศลิธูเอเนีย',
#  'ประเทศเซนต์คิตส์และเนวิส',
#  'ประเทศอัลบาเนีย',
#  'ประเทศแอลเบเนีย',
#  'ประเทศมาเลเชีย',
#  'ประเทศอัฟกานิสถาน',
#  'ประเทศกาน่า',
#  'ประเทศบัลเกเรีย',
#  'ประเทศอภิมหาอำนาจ',
#  'ประเทศไทย',
#  'ประเทศโคลัมเบีย',
#  'ประเทศตะวันตก',
#  'ประเทศมอนเตเนโกร',
#  'ประเทศสวาซิแลนด์',
#  'ประเทศเซนต์วินเซนต์และเกรนาดีนส์',
#  'ประเทศอัลจีเรีย',
#  'ประเทศแอนทีกาและบาร์บิวดา',
#  'ประเทศอิสราเอล',
#  'ประเทศฝรั่งเศศ',
#  'ประเทศทิเบต',
#  'ประเทศอินโดเนเซีย',
#  'ประเทศเชโกสโลวาเกีย',
#  'ประเทศเอลซัลวาดอร์',
#  'ประเทศจีน',
#  'ประเทศเลโซโท',
#  'ประเทศฝรั่งเศสแผ่นดินใหญ่',
#  'ประเทศออสเตรเลีย',
#  'ประเทศบาสก์']

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ
