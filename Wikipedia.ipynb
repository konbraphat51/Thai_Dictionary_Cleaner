# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = f.read().splitlines()
    
len(titles)
# Out:
# 362955

# %%
random.sample(titles, 100)
# Out:
# ['ซัลวาตอร์_มุนดี_(เลโอนาร์โด)',
#  'อุลโม',
#  'ภูเข้',
#  'ราชอาณาจักรฮัชไมต์จอร์แดนในโอลิมปิกฤดูร้อน_1988',
#  'Taksinus',
#  'พลตำรวจเอกวสิษฐ_เดชกุญชร',
#  'พระบาทรามเชิงไพร',
#  'ฟุตบอลโต๊ะ',
#  'คอลตัน_เฮย์เนส',
#  'Alex_Meraz',
#  'ตะพาบสวน',
#  'รายชื่อตอนในคุณครูจอมเวท_เนกิมะ!',
#  'Hedychium_flavum',
#  'อักษรพักปา',
#  'คัมภีร์ชั้นรอง',
#  'Annual_plant',
#  'ลาร์เฟอร์รารี่',
#  'Microsoft_Math',
#  'Min_Letya_of_Ava',
#  'Ottoa',
#  'กง_มย็อง',
#  'แอนโตนิโอ_คาร์ลอส_โจบิม',
#  'ดาวแคระน้ำตาล',
#  'ซีเอ็น_ทาวเวอร์',
#  'เพลงประจำชาติโปแลนด์',
#  'เจ้าฟ้ามหาวชิราวุธ',
#  'ออลบอร์',
#  'Yoshi',
#  'สมาคมนักข่าวนักหนังสือพิมพ์แห่งประเทศไทย',
#  'อาร์เทอร์_โชเปนฮอยเออร์',
#  'Calamus_(palm)',
#  'ขบวนการจารชน_โกบัสเตอร์ส',
#  'Unterfranken',
#  'เวิลด์เรสต์ลิงเอ็นเตอร์เทนเมนต์',
#  'ฟุตบอลโลก_1950',
#  'คลอร์เตตราไซคลีน',
#  'ประเทศเซนต์ลูเชียในโอลิมปิกฤดูร้อน_2024',
#  'Rustavi',
#  'Anaheim,_California',
#  'วัดไทยสิริราชคฤห์',
#  'คาร์คิฟ',
#  'ภัยพิบัติวันขอบคุณพระเจ้า',
#  'คอร์เทกซ์การเห็นสัมพันธ์',
#  'ยูซาวะ_(จังหวัดอากิตะ)',
#  'ရခုိင္\u200c',
#  'เหตุการณ์โรงงานอบลำใยระเบิด_พ.ศ._2542',
#  'คะสึชิกะ',
#  'ยอดหญิง_ตำนานศิลป์_ซินยุนบก',
#  'Super_Mario_64',
#  'โรงเรียนเบญจมราชูทิศ_นครศรีธรรมราช',
#  'สมเด็จพระเจ้าพี่นางเธอ_เจ้าฟ้ากัลยาณิวัฒนา_กรมหลวงนราธิวาส_ราชนครินทร์',
#  'Fukuoka_Airport',
#  'ปางสะดุ้งมาร',
#  'สุริยา_คล่องผจญ',
#  'เวลาในประเทศเลบานอน',
#  'แคตตาล็อกเฮนรี_เดรเพอร์',
#  'ประตูหลัง_(ความมั่นคงของระบบคอมพิวเตอร์)',
#  'เจสส์_กลินน์',
#  'บรรพชิต',
#  'วงศ์ปลาหนวดฤาษี',
#  'Alberto_Del_Rio',
#  'ปลาหมูฮ่องเต้',
#  '12_มี.ค.',
#  'Gift_(แก้ความกำกวม)',
#  'เจ้าหญิงซีนาตี_เซเอโซแห่งเลโซโท',
#  'โฟร์อีฟ',
#  'รายชื่อโบราณสถานในจังหวัดปัตตานี',
#  'นกกระจาบควาย',
#  'กลาดโน',
#  'คอร์ดาตา',
#  'ราชวงศ์ฉีเหนือ',
#  'มงแต็สกีเยอ',
#  'หนังสือปกอ่อน',
#  'หูก',
#  'กบฏเมืองแมนแดนสันติ',
#  'แอร์วีน_แอนกาแป็ต',
#  'ผักเขียด',
#  'ความส่องสว่างของอุปราคา',
#  'มณฑลการปกครองของสหราชอาณาจักร',
#  'เอฟเอพรีเมียร์ลีก_ฤดูกาล_1993–94',
#  'Emanuel_Steward',
#  'ยุทธการที่วุร์สเตอร์',
#  'องค์การบริหารส่วนตำบลอากาศ',
#  'เจิ่น_วัน_ซวน',
#  'Abuja',
#  'วิริฒิพา_ภักดีประสงค์',
#  'โปรสเปอรีดัด',
#  'การเพิ่มองค์ประกอบของเซลล์',
#  'อียอน_อี._เช._เบรอตียานู',
#  'สัตว์น้ำต่างถิ่น',
#  'วิวัฒนาการของกระดูกเล็กสำหรับได้ยินของสัตว์เลี้ยงลูกด้วยนม',
#  'ปริพันธ์รีมัน',
#  'เหตุแทงคนในนิส_พ.ศ._2563',
#  'บทนำทฤษฎีสัมพัทธภาพทั่วไป',
#  'ประเทศเยอรมนีในโอลิมปิก',
#  'กองทัพสหรัฐ',
#  'ยานอวกาศโคลัมเบีย',
#  'เทรียร์',
#  'แคราย',
#  'Elfen_Lied']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Seperate space
# Handle the seperated words as different words

# %%
titles_temp = []

for title in titles:
    # "space" of the title is replaced by "_" in the data
    for word in title.split("_"):
        titles_temp.append(word)
        
titles = titles_temp

len(titles)
# Out:
# 619124

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = titles_temp

len(titles)
# Out:
# 406281

# %%
random.sample(titles, 100)
# Out:
# ['เซดิลลา',
#  'เอ็ดนา',
#  'ซื้องานวิจัย',
#  'โบลเดอร์',
#  'แอนติบอดีลบล้างฤทธิ์',
#  'ชากา',
#  'ชิวเชิง',
#  '(วงดนตรี)',
#  'จังหวัดเมิซ',
#  'คาร์ลอส',
#  'เรย์นะ',
#  'ประเภทบุคคลชายผสม',
#  'รายชื่อตอนในปริ๊นซ์',
#  'นิมิตซ์',
#  'สตาร์',
#  'สตีเฟน',
#  'การเสด็จสู่วาแรน',
#  'ฉาย',
#  'เรือกรรเชียงคู่พายเดี่ยว',
#  'ทะเลดอนฮวน',
#  'เมตร',
#  'มุกดา',
#  'ชินลง',
#  'เด็กหญิงไม้ขีดไฟ',
#  'เธอทำให้ได้รู้',
#  'ฮวนอี้',
#  'เดอนี',
#  'คาร์ล',
#  'ธงชาติปานามา',
#  'ราชิด',
#  'ตำบลหัวทุ่ง',
#  'กลมกล่อม',
#  'สาธารณรัฐบุรุนดี',
#  'มาร์แชลล์',
#  'ดยุกแห่งซัคเซิน-โคบวร์คและโกทา',
#  'องค์การต่อต้านฟาสซิสต์',
#  'กลึงกล่อม',
#  'ดยุกแห่งกัลลิเอรา',
#  'ฤดูกาล',
#  'ฤดูกาล',
#  'ไฮโดรมอร์โฟน',
#  'ฟิลิปป์ที่',
#  'นางเบญจกาย',
#  'รายชื่อนครในประเทศกัมพูชา',
#  'เวลาสุริยะจริง',
#  'เคียฟ',
#  'วังสวนบ้านแก้ว',
#  'จิงจฺวี่',
#  'จักรพรรดิหลิวซ่งเหวิน',
#  'จิรโรจน์',
#  'การเปิดเผยอัตลักษณ์ทางเพศของตน',
#  '(จังหวัดนครศรีธรรมราช)',
#  'เจ้าฟ้า',
#  'อุดม',
#  'อิเล็คโทรนิก้า',
#  'จักรพรรดิมัคซีมีลีอานที่',
#  'โทเกลัง',
#  'ฮาโลเนน',
#  'ซุนโกคู',
#  'กองทัพที่',
#  'บรานาห์',
#  'ไอชิน',
#  'ปลาสีนวล',
#  'ภาษาโวลอฟ',
#  'ประเทศเอธิโอเปียในพาราลิมปิกฤดูร้อน',
#  'พระมหากษัตริย์สหราชอาณาจักร',
#  'รางวัลนาฏราช',
#  'โรคลมชักชนิดต่อเนื่อง',
#  'ประเทศกานาในโอลิมปิกฤดูหนาว',
#  'จุฬาลงกรณ์',
#  'ทางรถไฟสายปากน้ำ',
#  'รัซเซลล์',
#  'แห่งเอ็สเอ็ส',
#  'ครั้งที่',
#  'แมโครโมเลกุล',
#  'กีฬาฟุตบอลในกีฬาแห่งชาติครั้งที่',
#  'อีฟว์',
#  'เพนกวินแมเจลเล็น',
#  'ไซเซฟ',
#  'เจโรม',
#  'ฮิสทรี',
#  'กำฟ้า',
#  'มนัสวิน',
#  'บราเธอร์ส',
#  'สหพันธ์ฟุตบอลฮังการี',
#  '(วงดนตรี)',
#  'บรูตัส',
#  'กนู',
#  'ฮันกย็อง',
#  'จุลละมณฑล',
#  'ฮูดลัมแฮฟวัค',
#  'แมงมุมแม่ม่ายดำ',
#  'พรรคเตลังคนะ',
#  'ฤดูกาล',
#  'เส้นเมริเดียนที่',
#  'ฮัน-บย็อล',
#  'วี.ลีก',
#  'จังหวัดโกรนิงเงิน',
#  'พระเจ้าบรมวงศ์เธอ',
#  'ใต้ทะเล']

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %% [markdown]
# ### Seperate space between names
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Include monks nicknames
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
