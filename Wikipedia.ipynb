# %% [markdown]
# # Wikipedia Title
#
# Using [thwiki-latest-all-titles-in-ns0](https://dumps.wikimedia.org/thwiki/latest/)

# %%
import pythainlp
import random

# %%
random.seed(334)

# %% [markdown]
# ## Import data

# %%
with open("thwiki-latest-all-titles-in-ns0", encoding="utf-8") as f:
    titles = f.read().splitlines()
    
len(titles)
# Out:
# 362955

# %%
random.sample(titles, 100)
# Out:
# ['ความส่องสว่างของอุปราคา',
#  'เฮนรีที่_6_แห่งเยอรมนี',
#  'สมเด็จพระเจ้าหลานเธอ_เจ้าฟ้าบุญเมือง_กรมหลวงธิเบศรบดินทร์',
#  'โรงยิมเปียงยาง',
#  'กวีโดเนียมอนเตเชลีโอ',
#  'ไทยแลนด์_อเมเจอร์ลีก_ฤดูกาล_2562_–_โซนภาคเหนือ',
#  'แว่วเสียงเรไร',
#  'โบสถ์นักบุญซีโมนและนักบุญเฮเลนา',
#  'พระราชวังหลวงเซ็นโต',
#  'อะโรวาน่า',
#  'เกาะกวาดัลคะแนล',
#  'ดิวิชันไลโคไฟตา',
#  'ซุ่นกุ้ยเหริน',
#  'ดึสเซิลดอร์ฟ',
#  'กีฬาบาสเกตบอลในโอลิมปิกฤดูร้อน_1996',
#  'ซุนดาโมจิ',
#  'เปาโล_เฟร์ไรรา',
#  'ประเทศซาอุดีอารเบีย',
#  'นะระ_(เมือง)',
#  'กั๊ตจัง',
#  'มิซาร์_ชิด',
#  'สกุลกะทกรก',
#  'มอนบูโช',
#  'รายชื่อกษัตริย์เกาหลี',
#  'อ.โคกสูง',
#  'ภาษาออสเซเตียน',
#  'ตะวัน_ศรีปาน',
#  'ปาโบล_เอสโคบา',
#  'การขยายในคอร์เทกซ์',
#  'ค.ศ._1186',
#  'ค.ศ._1520',
#  'กูปปะลิงส์',
#  'สตาร์_วอร์ส:_สงครามโคลน_(ภาพยนตร์)',
#  'พสิษฐ์_ธนชัยบุญยรัตน์',
#  'เอลล่า_ฟิตเจอรัลด์',
#  'วันทหารม้า',
#  'สมเด็จพระสันตะปาปาจอห์นที่_23',
#  'มารีนาดากลูเรีย',
#  'รัฐบาลประชาคมผู้พูดภาษาเยอรมัน',
#  'นครลำปาง_(แก้ความกำกวม)',
#  'ตำบลแอฆีลีเยโจนูบี',
#  'ฮีโร่ขี้อาย_หัวใจไฟเตอร์',
#  'ดับเบิลยูดับเบิลยูอี_เวิลด์เฮฟวี่เวท_แชมเปียนชิพ',
#  'รีอา_(ดาวบริวาร)',
#  'พ.ศ._1036',
#  'ชินวุฒ_อินทรคูสิน',
#  'ล่าข้ามศตวรรษ',
#  'วาสนา_สิทธิเวช',
#  'โรงเรียนม่วงสามสิบอัมพวันวิทยา',
#  'สารให้ความหวาน',
#  'ย่าหยา',
#  'เตลังคานาราษฎรสมิติ',
#  '1900_(แก้ความกำกวม)',
#  'สเต็พเพ็นวูลฟ์',
#  'ปรงเขา',
#  'รซมะฮ์_มันโซร์',
#  'อาร์เอ็นเอไวรัส',
#  'จิบะ',
#  'ชาวสโลวีน',
#  'สมเด็จพระเจ้าวิลเลมที่_3_แห่งเนเธอร์แลนด์',
#  'แกรนด์ดัชเชสเยเลนา_วลาดีมีรอฟนาแห่งรัสเซีย',
#  'ลอสแองเจลิส',
#  'โรคกล้ามเนื้อเสียการประสานงานจากสมองน้อยและไขสันหลังที่ถ่ายทอดทางโครโมโซมเพศแบบด้อย',
#  'พระมหาปชาบดีเถรี',
#  'คลองบางนางเกรง',
#  'โรบิน_(ตัวละคร)',
#  'เป้_สเลอ',
#  'พระเจ้าซาร์อีวาน_สเตฟานแห่งบัลแกเรีย',
#  'การทอดไมตรี',
#  'ไบโอส',
#  'อัลแบร์โต_อากวิลานี่',
#  'แอฟริกาคัพออฟเนชันส์_2019_กลุ่ม_เอ',
#  'สังสาระวัฏ',
#  'พ.ศ._2251',
#  'ฟุตบอลทีมชาติสกอตแลนด์',
#  'ปลากระเบนแม่กลอง',
#  'ตระกูลภาษาออสโตรเนเชียน',
#  'กรีนบุ๊ค',
#  'อิวาเตะ_(เมือง)',
#  'รศ.ดร.อิสสรีย์_หรรษาจรูญโรจน์',
#  'นาโต',
#  'ผู้ใหญ่',
#  'สหพันธรัฐรัสเซียในโอลิมปิกฤดูหนาว_2002',
#  'เจมส์_(วงดนตรี)',
#  'แม่น้ำอากูซัน',
#  'มานวยล์_แซตเทอร์นิโน่_ดา_กอสตา',
#  'ซิกนัส_(Siarnaq)',
#  'ระบบอัตโนมัติ',
#  'ประเทศรวันดาในโอลิมปิก',
#  'ประวัติศาสตร์ประเทศกรีซ',
#  'ซอนนี่_มานาคาเน่',
#  'มาร์ติน_ชเกอร์เตล',
#  'แชมป์สแมคดาวน์แทกทีม_WWE',
#  'มึนส์เทอร์',
#  'เกวลิน_ศรีวรรณา',
#  'สาธารณรัฐคิวบา',
#  'ประเทศอินโดนีเซียในเอเชียนเกมส์_1951',
#  'พระมหาโพธิวงศาจารย์',
#  'อำเภอมัซฮัร',
#  'ภาษาจอร์เจีย']

# %% [markdown]
# ## Clean
# This wii be the criteria: [วิกิพีเดีย:ชื่อบทความ](https://th.wikipedia.org/wiki/%E0%B8%A7%E0%B8%B4%E0%B8%81%E0%B8%B4%E0%B8%9E%E0%B8%B5%E0%B9%80%E0%B8%94%E0%B8%B5%E0%B8%A2:%E0%B8%8A%E0%B8%B7%E0%B9%88%E0%B8%AD%E0%B8%9A%E0%B8%97%E0%B8%84%E0%B8%A7%E0%B8%B2%E0%B8%A1)

# %% [markdown]
# ### Exclude non-Thai
# > ชื่อหัวข้อควรเป็นอักษรไทย
# > ...
# > ทั้งนี้ มีข้อยกเว้นบางประการที่ไม่ต้องใช้อักษรไทยเป็นชื่อบทความ

# %%
# simply exclude titles that have no Thai characters
titles_temp = [title for title in titles if pythainlp.util.countthai(title) > 0.1]
titles = titles_temp

len(titles)
# Out:
# 284298

# %%
random.sample(titles, 100)
# Out:
# ['มิตต์_รอมนี่ย์',
#  'อะมอนอะมาร์ท',
#  'เคที_โฮลมส์',
#  'ทีมชาติที่ลงแข่งขันฟุตบอลโลก_รุ่นอายุไม่เกิน_20_ปี',
#  'สโมสรฟุตบอลพัทยา',
#  'สาธารณรัฐฟิลิปปินส์ที่หนึ่ง',
#  'อ.พัฒนานิคม',
#  'พระแม่มารีบนระเบียง_(บอตติเชลลี)',
#  'กรุงโรม',
#  'รัชทายาทโดยพฤตินัย',
#  'เครื่องหมายและ',
#  'คอร์_พัลโมนาลี',
#  'ไชยา_สิงห์ชัชวาลย์',
#  'พลพจน์_พูลนิล',
#  'กล้องจุลทรรศน์อิเล็กตรอนชนิดส่องกราด',
#  'เซอร์เบียนซูเปอร์ลีกา',
#  'ชาลส์_วีตสตัน',
#  'ชาวลัตเวีย',
#  'ซีเวิร์ต',
#  'บอมบาร์ดิเอร์_ซีอาร์เจ',
#  'รดมยศ_มาตเจือ',
#  'มเหสี_(แก้ความกำกวม)',
#  'โอเอะคาคิ',
#  'บรรพต_วีระรัฐ',
#  'เฮลโลเวิลด์',
#  '์',
#  'การลงประชามติการเลือกตั้งประธานาธิบดีฝรั่งเศสผ่านหลักการออกเสียงทั่วไป',
#  'พ.ศ._789',
#  'นัตสึมิ_ทาคาโมริ',
#  'อ.พิบูลย์รักษ์',
#  'พระเจ้าชาร์ลส์ที่_1_แห่งซิซิลี',
#  'ศิลปะเกี่ยวกับความตาย',
#  'ตำบลซีกอร์',
#  'กลุ่มภาษาสแกนดิเนเวีย',
#  'เฟร์นันดินญู',
#  'พัก_กึนฮเย',
#  'องค์การบริหารส่วนตำบลช้างเผือก_(จังหวัดเชียงใหม่)',
#  'พระแก้วมรกต',
#  'อุมแบร์โตที่_2_แห่งอิตาลี',
#  'พรินเตอร์อิงค์เจ็ต',
#  'อิมเพรสชันนิซึมยุคหลัง',
#  'ทางหลวงแผ่นดินหมายเลข_216',
#  'แคโรทีน',
#  'คณะเภสัชศาสตร์_มหาวิทยาลัยพะเยา',
#  'สนธิสัญญาเคลลอก–บริยอง',
#  'โก_(โปเกมอน)',
#  'วิคเตอร์_โอซิมเฮน',
#  'วัดทวีวัฒนาราม',
#  'เดอะโมสต์บิวตีฟูลเกิร์ลอินเดอะเวิลด์_(เพลงพรินซ์)',
#  'กรุงปราก',
#  'สถานีวิทยุโทรทัศน์แห่งชาติอิตาลี',
#  '211_อิซอลดา',
#  'ครี้ด_บ่มแชมป์เลือดนักชก',
#  'เจ้าชมพู',
#  'ลิซาร์ด_(หนังสือการ์ตูน)',
#  'บ็อบ_ฮิคกี้',
#  'พระเยซูเรียกนักบุญแม็ทธิว_(คาราวัจโจ)',
#  'เขตอาดาจิ',
#  'อะเพลซวิทโนเนม',
#  'โดเมน',
#  'โรงพยาบาลบ้านแพ้ว',
#  'บันดาร์_เบรา',
#  'สมาคมวอลเลย์บอลจีน',
#  'พระเจ้าวาสลัฟที่_3_แห่งโบฮีเมีย',
#  'อะเลคซันดร์_รุตสคอย',
#  'ข้อความคาดการณ์ของก็อลท์บัค',
#  'อุกฤษณ์_วงศ์มีมา',
#  'โรซา_เมนเดส',
#  'กระจับนก',
#  'เรือดำน้ำแบบ_039เอ',
#  'ปลาวาฬหัวทุย',
#  'แพทย์แผนไทย',
#  'เรื่องอื้อฉาวเบอร์ฮัดการพัฒนา_1มาเลเซีย',
#  'สตาดีโอโอลิมปีโกโตริโน',
#  'วัดตะเคียน_(จังหวัดนนทบุรี)',
#  'ศูนย์ควบคุมและป้องกันโรคแห่งยุโรป',
#  'ประวัติโรงเรียนสามัคคีวิทยาคม',
#  'อี_ฟอร์_แอล_เอม',
#  'ขุนปลดปรปักษ์',
#  'นอนหลับ',
#  'กลุ่มดาวช่างแกะสลัก',
#  'โปรคารีโอต',
#  'ดับเบิลยูซีดับเบิลยู_อินเตอร์เนชั่นแนล_เวิลด์เฮฟวี่เวท_แชมเปี้ยนชิพ',
#  'จู_ปาเจี้ย',
#  'คณะผู้แทนสังเกตการณ์ของสหประชาชาติประจำชายแดนอิรัก–คูเวต',
#  'อะกริวอลเทอิก',
#  'พระเจ้าบรมวงศ์เธอ_พระองค์เจ้าลดาวัลย์_กรมหมื่นภูมินทรภักดี',
#  'เบอร์เคเลียม',
#  'เปอร์โตรีโก',
#  'กีฬาวอลเลย์บอลในโอลิมปิกฤดูร้อน_2024',
#  'ตำบลคำหว้า',
#  'คดีระหว่างโรกับเวด',
#  'ปลุกปั่นให้ขัดขืนอำนาจปกครอง',
#  'ค.ศ._599',
#  'สาธารณรัฐอัลไต',
#  'ทรีตเมนต์แอ็กชั่นแคมเปญ',
#  'จุงอิจิ_อินาโมโตะ',
#  'พ.ศ._492',
#  'สาบานว่าพูดจริง_To_Tell_The_Truth',
#  'ประเทศสเปนในโอลิมปิกฤดูร้อน_1984']

# %% [markdown]
# ### Seperate ()
# > พยายามหลีกเลี่ยงการใช้ วงเล็บ หรือเครื่องหมายอื่นที่ไม่เกี่ยวกับชื่อบทความ ถ้าไม่จำเป็น
# >
# > วงเล็บต่อท้ายใช้เพื่อแก้ความกำกวม เช่น บาท (สกุลเงิน) กับ บาท (ร้อยกรอง) และในการเขียนให้เว้นวรรคระหว่างคำและวงเล็บ เช่น บาท (สกุลเงิน) ไม่ใช่ บาท(สกุลเงิน) ถ้าคำมีความหมายเดียว หรือไม่คาดว่าจะกำกวมกับเรื่องอื่น ให้ใช้ บัว แทนที่จะเป็น บัว (พรรณไม้)

# %% [markdown]
# ### Exclude List
# > "รายชื่อ"สำหรับบทความที่มีลักษณะรวบรวมรายการ ให้ขึ้นต้นด้วยคำว่า "รายชื่อ" สำหรับรายการของวิสามานยนามหรือชื่อเฉพาะ (proper name) ล้วน ส่วนกรณีที่เหลือทั้งหมด ให้ใช้ "รายการ" เช่น
# > ...
# > สำหรับบทความที่รวบรวมรายการพระนามเจ้า ให้ใช้ "รายพระนาม" และหากมีทั้งเจ้าและสามัญชน ให้ใช้ "รายพระนามและชื่อ"
# > ...
# > สำหรับรายชื่อตอน หรือรายชื่อตัวละคร ให้เขียนในลักษณะ
# >
# > รายชื่อตัวละครใน{ชื่อเรื่อง} เช่น   รายชื่อตัวละครในมาจิเรนเจอร์
# > รายชื่อตอนใน{ชื่อเรื่อง} เช่น รายชื่อตอนในน้องสาวของผมไม่น่ารักขนาดนั้นหรอก

# %% [markdown]
# ### Seperate space between names
# > หลักการทั่วไปคือให้ใช้ชื่อที่เป็นที่รู้จักมากที่สุด โดยไม่ต้องมีคำนำหน้าชื่อ รวมทั้ง นาย/นาง/นางสาว คุณหญิง/ท่านผู้หญิง หรือ ยศ และตำแหน่งวิชาการ ดูเพิ่มที่ ยศหรือตำแหน่ง
# >
# > ใช้ ทักษิณ ชินวัตร แทนที่ พันตำรวจโท ดร. ทักษิณ ชินวัตร
#
# Also exclude dot initials
# > ชื่อที่มีจุดหลังชื่อ ภาษาไทยหรือภาษาอื่น ให้เว้นวรรคหนึ่งครั้งหลังจุด
# >
# > ใช้ ป. อินทรปาลิต แทนที่ ป.อินทรปาลิต
# > จอร์จ เอช. ดับเบิลยู. บุช

# %% [markdown]
# ### Get the names of The Royal Family
# > คำนำหน้าพระนามของกษัตริย์
# > ให้กษัตริย์ไทยที่ราชาภิเษกแล้ว ใช้คำนำหน้าชื่อว่า "พระบาทสมเด็จพระ" ถ้ายังไม่ราชาภิเษก ใช้ "สมเด็จพระ"
# > กษัตริย์ไทยในอดีต ใช้ "สมเด็จพระ" แต่อาจใช้ตามความนิยม เช่น "ขุนหลวง," "พ่อขุน," "พระยา"
#
# List of royal
# https://th.wikipedia.org/wiki/%E0%B8%9E%E0%B8%A3%E0%B8%B0%E0%B8%A2%E0%B8%A8%E0%B9%80%E0%B8%88%E0%B9%89%E0%B8%B2%E0%B8%99%E0%B8%B2%E0%B8%A2%E0%B9%84%E0%B8%97%E0%B8%A2
#
# **If this is rude, this should be altered**

# %% [markdown]
# ### Include monks nicknames
# > พระสงฆ์ไทยทรงสมณศักดิ์ ให้นำสมณศักดิ์หรือราชทินนามขึ้นต้น ตามด้วยวงเล็บชื่อและฉายา
# > พระพรหมคุณาภรณ์ (ประยุทธ์ ปยุตโต)
# > สมเด็จพระพุฒาจารย์ (โต พรหมรังสี)
# > สมเด็จพระพุฒาจารย์ (เกี่ยว อุปเสโณ)

# %% [markdown]
# ### Process country names
# > ใช้ชื่อ "ประเทศ..." เช่น ประเทศญี่ปุ่น ดูเพิ่ม วิกิพีเดีย:โครงการวิกิประเทศ

# %% [markdown]
# ### Dictricts names
# > ให้มีคำว่า ตำบล อำเภอ จังหวัด มณฑล รัฐ กำกับด้วย เช่น อำเภอจอมทอง จังหวัดเชียงใหม่ มณฑลหูหนาน รัฐแทสเมเนีย รัฐฮาวาย ฯลฯ

# %% [markdown]
# ### Remove years
# > การเขียนปีศักราช ให้ใช้ปีพุทธศักราชเป็นหลัก และใช้ตัวเลขอารบิกโดยเขียนในรูปแบบ — พ.ศ. 2547 — โดยเว้นวรรคระหว่าง พ.ศ. และ ตัวเลข ดูเพิ่มที่ วิกิพีเดีย:โครงการวันเดือนปี
